# %% [markdown]
# ## Purpose of this notebook
#
# What you can do about phrases and patterns in spacy.
#
#
# Before we get into it, it should be pointed out that
# - you can express more complex types of patterns, see https://spacy.io/api/matcher#patterns
# - You could extend this to more complex tasks, like maybe rule-based phrase and named entity extraction.
#   - ...though you might base that on more specific existing code like PhraseMatcher and EntityRuler,
#     which may work faster and/or annotate automatically.
#   - and in the case of NER would probaly still be less effective than existing trained NER model components
#
# We will demonstrate that somewhat in the process.

# %% [markdown]
# [The things we can match tokens on](https://spacy.io/usage/rule-based-matching#adding-patterns-attributes) are mostly attributes already on the Token object, so if you've already worked with spacy, you should recognize most as things you can also access via code (e.g. from the [Token documentation](https://spacy.io/api/token#attributes) and our [spacy intro notebook](methods_nlp__spacy_basics.ipynb)):
# - `ORTH` or `TEXT` - the text as-is
# - `LENGTH` - length of TEXT
# - `LOWER` - the lowercase version of the text
# - `NORM` - the normalized version (seems to do things like resolve contractions, and otherwise often be the lemmatizer output?)
# - `LEMMA` - lemmatixed
# - `SHAPE` - alphabetic characters become X or x, numeric by d, and sequences of the same are truncated after 4, so e.g. Katherine80 would become Xxxxxdd
# - `POS` - coarse tagging  (often following wider conventions), e.g. `NOUN`; many models follow [a relatively universal parts-of-speech set](https://universaldependencies.org/u/pos/)
#   - (so often `ADJ`, `ADP`, `ADV`, `AUX`, `CCONJ`, `DET`, `INTJ`, `NOUN`, `NUM`, `PART`, `PRON`, `PROPN`, `PUNCT`, `SCONJ`, `SYM`, `VERB`, `X` -- but you should check for each model)
# - `TAG` - finer tagging than POS
#   - (easily model/language specific, e.g. `'N|soort|ev|basis|zijd|stan'`)
# - `MORPH` - morphological properties
#   - (easily model/language specific, something like `Gender=Com|Number=Sing`)
#   - note that this supports `{"MORPH": {"IS_SUBSET": ["Number=Sing", "Gender=Neut"]}}`
#
# - `DEP` - dependency relation in the parse ([this takes some more typing to specfy](https://spacy.io/usage/rule-based-matching#dependencymatcher))
# - `IS_SENT_START`
# - `IS_LOWER`, `IS_UPPER`, `IS_TITLE`; `IS_PUNCT`, `IS_SPACE`, `IS_STOP`; `IS_ALPHA`, `IS_ASCII`, `IS_DIGIT`; `LIKE_NUM`, `LIKE_URL`, `LIKE_EMAIL`
# - `_` accesses custom attributes

# %% [markdown]
# Also,
# * you can add the optional `OP`, a [quantifier](https://spacy.io/usage/rule-based-matching#quantifiers) (that uses a syntax muc like regexes)
#   - `?`, `+`, `*`, `{n}`, `{n,m}`, `{n,}`, `{,m}`
#   - ...and `!` which means it must _not_ match (match 0 times at this point)
#     - TOFIGURE: (does it consume so mean an "anything but this?" -- or does it _not_ consume and mean more of a negative lookahead?)
#   - consider e.g. `{'POS':'ADJ', 'OP':'*'}, {"POS": {"REGEX": "(NOUN|PROPN)"}}`
#
# * instead of the value being one literal scring, you can make it a dict and add one of the following:
#   - use `==`, `>=`, `<=`, `>`, `<`
#     - consider e.g. `{"LENGTH": {">=": 10}}`
#   - use `IN`, `NOT_IN`, `IS_SUBSET`, `IS_SUPERSET`, `INTERSECTS` to compare with lists
#     - consider e.g. `{"POS": {"IN":["NOUN","PROPN"]} }` or `{"MORPH": {"IS_SUBSET": ["Number=Sing", "Gender=Neut"]}}`
#
#   - invoke [the regex operator](https://spacy.io/usage/rule-based-matching#regex)
#     - consider e.g. `{"TEXT": {"REGEX": "deff?in[ia]tely"}}`, or `{"TAG": {"REGEX": "^N"}`
#   - invoke [the fuzzy operator](https://spacy.io/usage/rule-based-matching#fuzzy)
#     - which (by default) matches an [edit distance](https://en.wikipedia.org/wiki/Edit_distance#Example) of 2, so e.g. `{"FUZZY": "favorite"}` will match  "favourite", "favorites", and "gavorite".
#
#   - some combinations, e.g. `{"FUZZY": {"IN": ["awesome", "cool", "wonderful"]}}}`
#
# * 'match _any_ one token' can be done with `{}`
#   - TOFIGURE: does that mean `{'OP':'+'}` matches one or more?

# %% [markdown]
# ## Enough words, let's start doing things

# %%
import spacy
import spacy.matcher
from spacy.matcher import Matcher
import spacy.displacy

import wetsuite.helpers.spacy
import wetsuite.datasets


# some example data to use later
some_cvdr_text        = wetsuite.datasets.load('cvdr-mostrecent-text').data.random_values(250)
some_rechtspraak_text = list( case.get('bodytext')   for case in wetsuite.datasets.load('rechtspraaknl-struc').data.random_values(250) )

# %% [markdown]
# ### How do I put patterns in, how do I get matches out?
#
# Both depends a little on whether you are are using a separate Matcher, or are adding a Ruler to the model object.
#
# Chances are you'll end up on something more visual while experimenting,
# and something more succinct once you're using this as a tool.

# %% [markdown]
# #### bare Matcher
#
# A Matcher is a separate thing that you can run on a document.
#
# You attach it to an existing pipeline - in part just because _something_ needs to create the tokens-with-attributes we will match on.
#
# For example:

# %%
dutch  = spacy.load('nl_core_news_lg')

matcher = spacy.matcher.Matcher(dutch.vocab)
#            pattern name      pattern 
matcher.add("HW_MetPunct",    [   [{"LOWER": "hallo"}, {"IS_PUNCT": True},           {"LOWER": "wereld"}]  ])
matcher.add("HW_Opt",         [   [{"LOWER": "hallo"}, {"IS_PUNCT": True, "OP":'*'}, {"LOWER": "wereld"}]  ])  # punctuation is optional in this one (so matches both in the example)
# note that the pattern is a list of lists. This is because you can have multiple patterns for one rule (e.g. to specify some variants), so far we have just one.

doc = dutch("De hallo, wereld test.  Eerste patroon matcht niet op hallo wereld.")
print( 'Sentence tokens: ', list( repr(tok) for tok in doc ) ) # (just to point out what the token and their text are)

for match_id, start, end in matcher( doc ):   # running that Matcher will return a sequence of matches   (note: end is exclusive)
    match_str  = dutch.vocab.strings[match_id] # (spacy makes a point of having an integer representation of everything it might store; this gets a get string representation of the pattern name, and is optional if you don't care)
    match_span = doc[start:end]  # fetch as span, mostly because it's the easiest way to get the .text again:
    print(f"Pattern {repr(match_str):15s} matches token {start:3d}..{end-1:<3d}  which is the text {repr(match_span.text)}")
# Out:
# Sentence tokens:  ['De', 'hallo', ',', 'wereld', 'test', '.', ' ', 'Eerste', 'patroon', 'matcht', 'niet', 'op', 'hallo', 'wereld', '.']
# Pattern 'HW_MetPunct'   matches token   1..3    which is the text 'hallo, wereld'
# Pattern 'HW_Opt'        matches token   1..3    which is the text 'hallo, wereld'
# Pattern 'HW_Opt'        matches token  12..13   which is the text 'hallo wereld'

# %%
# Let's make a slightly more interesting example, and run on some real data
# let's look for   one or more adjectives,  before  <a noun or proper noun>.

an_pattern = [
    [ 
        {"POS":"ADJ",   "OP":"+"},        # "+" means one or more  
        {"POS":{"IN":["NOUN","PROPN"]} } 
    ],
]
matcher = spacy.matcher.Matcher(dutch.vocab)
matcher.add("adjective-noun", an_pattern)

doc = dutch( some_cvdr_text[0] )
for _match_id, start, end in matcher(doc):
    print( doc[start:end].text, end='\n' )
# Out:
# onroerende zaakbelastingen
# onroerende zaken
# directe belastingen
# onroerende zaak
# persoonlijk recht
# onroerende zaak
# onroerende zaak
# onroerende zaak
# volgtijdig gebruik
# onroerende zaak
# onroerende zaak
# basisregistratie kadaster
# onroerende zaak
# onroerende zaak
# onroerende zaken
# onroerende zaak
# onroerende zaken
# onroerende zaak
# onroerende zaak
# onroerende zaken
# onroerende zaak
# onroerende zaak
# onroerende zaken
# onroerende zaak
# overeenkomstige toepassing
# tweede lid
# onroerende zaken
# open grond
# onroerende zaken
# openbare eredienst
# openbare bezinningssamenkomsten
# levensbeschouwelijke aard
# onroerende zaken
# zodanige onroerende zaken
# onroerende zaken
# volledige rechtsbevoegdheid
# openbaar vervoer
# publiekrechtelijke rechtspersonen
# zodanige werken
# ander afvalwater
# publiekrechtelijke rechtspersonen
# zodanige werken
# onroerende zaak
# onroerende zaken
# publieke dienst
# onroerende zaken
# zodanige onroerende zaken
# onroerende zaken
# zodanige onroerende zaken
# onroerende zaken
# zodanige onroerende zaken
# eerste lid
# onroerende zaken
# onroerende zaak
# onroerende zaken
# onroerende zaken
# gehele euro's
# eerste lid
# gelijke termijnen
# laatste dag
# eerste lid
# automatische betalingsincasso
# kleine afrondingsverschillen
# maandelijkse termijnen
# eerste termijn
# Nadere regels
# nadere regels
# tweede lid
# belastbare feiten
# eerste dag
# onroerende zaakbelastingen

# %% [markdown]
# #### EntityRuler, or preferably SpanRuler
#
# When using spacy to collect and _combine_ different kinds of annotation,
# you might want to visualize all the things you have,
# i.e. marked it up on the document object, and show that.
#
# If this is your goal, switch from a Matcher to either a Spanruler or an EntityRuler,
# which work in _almost_ the same way, but are set on the document object (in `.spans` and `.ents`, respectively),
# and there is out-of-the-box visualizaton for both.
#
# <!-- -->
#
# Using an EntityRuler makes it easy to visualize exactly as we previously did with entities, but has an already-mentioned problem:
# Entities are assumed to never overlap, so matches will be silently dropped when they overlap,
# with other matches or with entities that e.g. existing NER added.
# (You can disable existing NER, but it may defeat the point of combining things; there is no way to avoid dropping overlapping matches).
#
# <!-- -->
#
# ...which is why spacy recommends using SpanRuler instead.
# Visualizing spans isn't as compact exactly _because_ it is capable of displaying overlapping spans.
#
# Note that `.spans` is not just a list of matches, but is made to spans from different, named sources.
# As such, `.spans` is a dict from a useful name to a list of spans.
# SpanRuler defaults to add in the key `'ruler'`, which is why we have to explicitly tell it that
# in the second visualization below.
#
# Note that the way you hand in the pattern into Rulers is a _little_ different from Matchers,
# and the same between these two Rulers:

# %%
# using EntityRuler:
dutch_with_er  = spacy.load('nl_core_news_lg')
dutch_with_er.remove_pipe("ner")  # the existing NER just happens to _NOT_ clash on this specific sentence (so you could comment this to see both) but in general you cannot assume that
ruler = dutch_with_er.add_pipe("entity_ruler")
ruler.add_patterns( [ {'label':'ADJ_N',  "pattern":[ {"POS":"ADJ", "OP":"+"},  {"POS":{"IN":["NOUN","PROPN"]} }  ]} ] )

doc = dutch_with_er("""Onder de naam "afvalstoffenheffing" wordt een directe belasting geheven als bedoeld inartikel 15.33 van de Wet milieubeheer;artikel 15.33 van de Wet milieubeheer; de afvalstoffenheffing als bedoeld in deze verordening en de daarbij behorende tarieventabel wordt naar afzonderlijke grondslagen geheven ter zake van het feitelijk gebruik van een perceel ten aanzien waarvan krachtensartikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van huishoudelijke afvalstoffen geldt.artikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van huishoudelijke afvalstoffen geldt.""")
spacy.displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Onder de naam &quot;afvalstoffenheffing&quot; wordt een
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     directe belasting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ_N</span>
# </mark>
#  geheven als bedoeld inartikel 15.33 van de Wet milieubeheer;artikel 15.33 van de Wet milieubeheer; de afvalstoffenheffing als bedoeld in deze verordening en de daarbij behorende tarieventabel wordt naar
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     afzonderlijke grondslagen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ_N</span>
# </mark>
#  geheven ter zake van het
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feitelijk gebruik
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ_N</span>
# </mark>
#  van een perceel ten aanzien waarvan krachtensartikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     huishoudelijke afvalstoffen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ_N</span>
# </mark>
#  geldt.artikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     huishoudelijke afvalstoffen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ_N</span>
# </mark>
#  geldt.</div></span>

# %%
# using SpanRuler and its visualization instead:
dutch_with_sr  = spacy.load('nl_core_news_lg')
ruler = dutch_with_sr.add_pipe("span_ruler")
ruler.add_patterns( [ {'label':'ADJ_N',  "pattern":[  {"POS":"ADJ",  "OP":"+"},  {"POS":{"IN":["NOUN","PROPN"]} }  ],} ] )

doc = dutch_with_sr("""Onder de naam "afvalstoffenheffing" wordt een directe belasting geheven als bedoeld inartikel 15.33 van de Wet milieubeheer;artikel 15.33 van de Wet milieubeheer; de afvalstoffenheffing als bedoeld in deze verordening en de daarbij behorende tarieventabel wordt naar afzonderlijke grondslagen geheven ter zake van het feitelijk gebruik van een perceel ten aanzien waarvan krachtensartikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van huishoudelijke afvalstoffen geldt.artikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van huishoudelijke afvalstoffen geldt.""")
doc.spans

spacy.displacy.render(doc, style='span', options={"spans_key":"ruler"}, jupyter=True) # we have to tell it which source of spans we want; SpanRuler uses 'ruler'
# Out:
# <span class="tex2jax_ignore"><div class="spans" style="line-height: 2.5; direction: ltr">Onder de naam &quot; afvalstoffenheffing &quot; wordt een
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     directe
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ADJ_N
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     belasting
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# geheven als bedoeld inartikel 15.33 van de Wet milieubeheer;artikel 15.33 van de Wet milieubeheer ; de afvalstoffenheffing als bedoeld in deze verordening en de daarbij behorende tarieventabel wordt naar
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     afzonderlijke
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ADJ_N
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     grondslagen
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# geheven ter zake van het
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     feitelijk
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ADJ_N
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     gebruik
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# van een perceel ten aanzien waarvan krachtensartikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     huishoudelijke
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ADJ_N
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     afvalstoffen
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# geldt.artikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     huishoudelijke
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ADJ_N
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     afvalstoffen
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# geldt . </div></span>

# %% [markdown]
# <!--
# #### Manually
#
# When you have specific things you want to do, you might get more creative with code.
#
# Say, "I want only adjective-noun pairs from the sentences that mention appellant(/e/es), and want to count how of they they occur":
#
# count = collections.defaultdict(int)
# for text in some_rechtspraak_text:
#     doc = dutch( text )
#     for sent in doc.sents:
#         if not 'appellant' in sent.text.lower():
#             continue
#         for _, start_i, end_i in matcher( sent ):
#             count[ sent[ start_i : end_i ].text.strip() ] += 1
#
# for str, count in sorted( count.items(), key=lambda x:x[1], reverse=True):
#     print( f'{count:5d}  {str}')
#     #if count<3:
#     #    break
# -->

# %% [markdown]
# ### Making life a little easier?
#
# These rules are... verbose.   They are not fun to write, so don't exactly invite working on improving them.
#
# Could we make our own little rule system to make that less typing?
#
# Yes, though there are some very real limitations to doing this:
# - it's shorter, but it's also another thing to learn
# - it's just for simpler patterns - it's easily _less_ expressive and it does _not_ allow everything that you can specify at spacy level
#
# ...but it could be nice to do some quick tests.

# %%
def expand_pats(patstring):
    """ Takes a singular string with some specific pattern names,
        Returns a spacy pattern that has expanded those pattern names to  actual patterns,
        e.g.:: 
            'behandeld op DATELIKE' 
        becomes::
            [{'LOWER': 'behandeld'}, {'LOWER': 'op'}, {'LIKE_NUM': True}, {'POS': 'PROPN'}, {'LIKE_NUM': True}]

        Just a makeshift experiment to see how useful this idea can be.
        The existing patterns are uppercased to make it less likely to clash with a literal word.
        
        To see how this is intended to be used, see the creation of the Matcher below this definition 
    """
    pats = {
        'DPN':      [{'POS':'DET', 'OP':'*'}, {'POS':'PRON', 'OP':'*'}, {"POS": {"REGEX": "(NOUN|PROPN)"}}],
        'ADJN':     [{'POS':'DET', 'OP':'*'}, {'POS':'ADJ', 'OP':'*'}, {"POS": {"REGEX": "(NOUN|PROPN)"}}],
        'ADJ':      [{'POS':'ADJ', 'OP':'+'}],
        'V':        [{"POS": {"IN": ["VERB", "AUX"]}}],
        #'V':        [{"POS": {"REGEX": "(VERB|AUX)"}}],
        #'ANYPLUS':  [{"TEXT": {"REGEX": "."}, 'OP':'+'}], #figure out whether there is a better/faster way to match any token
        #'ANYSTAR':  [{"TEXT": {"REGEX": "."}, 'OP':'*'}],
        'ANYPLUS':  [{'OP':'+'}], #figure out whether there is a better/faster way to match any token
        'ANYSTAR':  [{'OP':'*'}],
        'DATELIKE': [{"LIKE_NUM": True}, {"POS": "PROPN"}, {"LIKE_NUM": True}],
    }
    ret = []
    for part in patstring.split():
        if part == part.lower():
            ret.append( {'LOWER':part} )  # in theory we could also normalize that to use LEMMA, and catch inflections
        else:
            if part in pats:
                ret.extend( pats[part] )
            else:
                print('Do not know pattern %r'%part)
    return ret


dutch  = spacy.load('nl_core_news_lg')

matcher = Matcher(dutch.vocab)

# for comparison, first spacy's own style...   (which is actually necessary for this nontrivial pattern)
matcher.add( 'deze v|u|a|b|v V', [ [
        {"LOWER":   {"IN":["deze", "dit"]}},
        {"LOWER":   {"IN":["verordening", "uitspraak", "arrest", "beschikking", "vonnis"]}},
        {"POS": {"IN":["VERB","AUX"]} },
        {'OP':'+'},
        {"LIKE_NUM": True}, {"POS": "PROPN"}, {"LIKE_NUM": True}
],] )

# ...and then our brief one  (lowercase means words to match, uppercase means a thing that expand_pats probably expands)
for pat in (
        #'ADJN heeft V dat',
        #'zou zijn V door',
        #'gelet op de ADJN',
        #'ADJ rechten',
        #'de beschuldigingen ANYPLUS zijn',
        #'aan de hand van het ADJN',
        #'aan de hand van de ADJN',
        #'volgens ADJN',
        #'gaat ADJN uit van',
        #'gaan ADJN uit van',
        'behandeld op DATELIKE',
        'uitgesproken ANYSTAR op DATELIKE',
        'uitgesproken ANYSTAR van DATELIKE',
        'uitspraak ANYPLUS DATELIKE',
        #'voorlopig karakter', 'niet bindend', #'bodemprocedure',
        #'nadere stukken',
        #'ADJN concludeert',
        #'ADJN voert verweer',
    ):
    ep = expand_pats(pat)
    matcher.add( pat, [ep] )

# %%
# Okay, now run that on some actual data - specifically some court cases
for case in wetsuite.datasets.load('rechtspraaknl-struc').data.random_values( 250 ):
    print( 'In document', case['identifier'])

    doc = dutch( case.get('bodytext') )

    for sent in doc.sents:
        for match_id, start, end in matcher( sent ):
            match_str = dutch.vocab.strings[match_id]  # Get string representation, seems to point out the pattern name is added to the vocab too, presumably to have an integer-only representation?
            match_span = sent[start:end]  # The matched span
            print(f"  pattern:{repr(match_str):35s} matches:  {repr(match_span.text)}")
# Out:
# In document ECLI:NL:GHLEE:2010:BN8169
# In document ECLI:NL:PHR:2011:BO5254
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak een bestuursbesluit in stand gelaten, dan staat dit er in beginsel aan in de weg dat de strafrechter het verweer dat het besluit ten onrechte is genomen zelfstandig onderzoekt en daarop beslist (HR 24 september 2002'
# In document ECLI:NL:RBGEL:2022:4102
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 27 juli 2022'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. E. Boerwinkel en in het openbaar uitgesproken op 27 juli 2022'
# In document ECLI:NL:RBOBR:2016:6592
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 28 november 2016'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is op tegenspraak gewezen naar aanleiding van het onderzoek ter terechtzitting van 14 november 2016'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 28 november 2016'
# In document ECLI:NL:GHAMS:2015:5022
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 1 december 2015'
# In document ECLI:NL:RBOBR:2017:3709
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 12 juli 2017'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is op tegenspraak\n gewezen naar aanleiding van het onderzoek ter terechtzitting van 28 juni 2017'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 12 juli 2017'
# In document ECLI:NL:RBGEL:2013:1612
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken ter openbare terechtzitting van deze rechtbank op 15 juli 2013'
# In document ECLI:NL:RBLEE:2001:AB0914
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak:\t4 april 2001'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken door de rolrechter op 4 april 2001'
# In document ECLI:NL:RBZWB:2022:6914
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze uitspraak is gedaan door mr. L.P. Hertsig, rechter, in aanwezigheid van mr. P.H.M. Verdonschot, griffier, op 18 november 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is gedaan door mr. L.P. Hertsig, rechter, in aanwezigheid van mr. P.H.M. Verdonschot, griffier, op 18 november 2022'
# In document ECLI:NL:CRVB:2016:1954
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 26 mei 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Den Haag van \n19 februari 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak op het hoger beroep tegen de uitspraak van de rechtbank Den Haag van \n19 februari 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 18 augustus 2011'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 26 mei 2016'
# In document ECLI:NL:RBSGR:2009:BJ1281
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 9 juni 2009'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak in verzekering en voorlopige hechtenis doorgebracht, bij de tenuitvoerlegging van het onvoorwaardelijk gedeelte van de haar opgelegde gevangenisstraf geheel in mindering zal worden gebracht;\n\nin verzekering gesteld op\t\t\t\t\t: 4 november 2008'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak in verzekering en voorlopige hechtenis doorgebracht, bij de tenuitvoerlegging van het onvoorwaardelijk gedeelte van de haar opgelegde gevangenisstraf geheel in mindering zal worden gebracht;\n\nin verzekering gesteld op\t\t\t\t\t: 4 november 2008,\nin voorlopige hechtenis gesteld op\t\t\t\t: 7 november 2008'
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken ter openbare terechtzitting van 9 juni 2009'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door\nmrs\tVan Rens,\tvoorzitter,\n\tVan Dorp en Royakkers,\trechters,\nin tegenwoordigheid van mr. Dekker,\tgriffier,\n\nen uitgesproken ter openbare terechtzitting van 9 juni 2009'
# In document ECLI:NL:GHDHA:2017:2665
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken ter openbare terechtzitting van 26 september 2017'
# In document ECLI:NL:RBROT:2023:11495
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak beslist de voorzieningenrechter op het verzoek om de openbaarmaking van het boetebesluit van 22 september 2023'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak beslist de voorzieningenrechter op het verzoek om de openbaarmaking van het boetebesluit van 22 september 2023'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van Beroep voor het bedrijfsleven (CBB) van 8 maart 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van deze rechtbank van 21 juni 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het CBb van 15 mei 2014'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het CBb van 14 augustus 2018'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het CBb van 15 mei 2014'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van Beroep voor het bedrijfsleven (CBb) van 14 februari 2014'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het CBb van 14 augustus 2018'
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak eerdergenoemde uitspraak van het CBb van 14 augustus 2018'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak eerdergenoemde uitspraak van het CBb van 14 augustus 2018'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het CBb van 2 november 2021'
# In document ECLI:NL:RBALK:2007:BB7340
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak kan doen over de vraag die partijen verdeeld houdt, namelijk of de arbeidsovereenkomst op enig moment voorafgaande aan de indiening van het verzoekschrift reeds is geëindigd, aldus vaste rechtspraak van de Hoge Raad (bijvoorbeeld HR 16 april 1999'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze beschikking is gegeven door mr. R.C. Schlingemann, kantonrechter, bijgestaan door de griffier en op 16 augustus 2007'
# In document ECLI:NL:RBNHO:2016:9344
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak op bezwaar met dagtekening 1 december 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het Gerechtshof Amsterdam van 19 juli 2012'
# In document ECLI:NL:RBNHO:2018:11068
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken op de openbare terechtzitting van 13 december 2018'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door\nmr. J.M. Sassenburg, voorzitter,\nmr. J.W. Moors en mr. E.M. van Poecke, rechters,\nin tegenwoordigheid van de griffier mr. L.L. de Vries,\nen uitgesproken op de openbare terechtzitting van 13 december 2018'
# In document ECLI:NL:RBNNE:2021:5373
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen naar aanleiding van het onderzoek ter terechtzitting van 7 december 2021'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken ter openbare terechtzitting van deze rechtbank op 21 december 2021'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. G.W.G. Wijnands, voorzitter, mr. M.J. Dijkstra en mr. B.F. Hammerle, rechters, bijgestaan door mr. D.H. Röben, griffier, en uitgesproken ter openbare terechtzitting van deze rechtbank op 21 december 2021'
# In document ECLI:NL:PHR:2012:BU7250
# In document ECLI:NL:GHSHE:2010:BU3862
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak worden begroot op € 894,00 aan salaris advocaat;\n\nin de hoofdzaak: \n  \nverwijst de zaak naar de rol van 13 juli 2010'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak worden begroot op € 894,00 aan salaris advocaat;\n\nin de hoofdzaak: \n  \nverwijst de zaak naar de rol van 13 juli 2010'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken door de rolraadsheer op 1 juni 2010'
# In document ECLI:NL:HR:1997:ZD0733
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 3 juni 1997'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen door de vice-president Hermans als voorzitter, en de raadsheren Keijzer, Koster, Schipper en Aaftink, in bijzijn van de griffier Bogaert, en uitgesproken op 3 juni 1997'
# In document ECLI:NL:RBALK:2006:AX4874
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 8 mei 2006'
# In document ECLI:NL:RBHAA:2011:BV7763
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de enkelvoudige kamer van 21 december 2011'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling Bestuursrechtspraak op 3 december 2008'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak moeten doen voor 23 november 2011'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 21 december 2011'
# In document ECLI:NL:RVS:2012:BY3706
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 21 november 2012'
#   pattern:'behandeld op DATELIKE'             matches:  'behandeld op 31 juli 2012'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling van 18 februari 2004'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 21 november 2012'
# In document ECLI:NL:GHAMS:2023:1712
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 18 juli 2023'
# In document ECLI:NL:GHSHE:2019:4250
# In document ECLI:NL:RBAMS:2020:4504
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is op tegenspraak gewezen naar aanleiding van het onderzoek op de terechtzitting van 27 augustus 2020'
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken op de openbare terechtzitting van deze rechtbank van 10 september 2020'
# In document ECLI:NL:RBARN:2012:3822
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak dat de keuze van een deskundige de keuze van zijn/haar methode impliceert (Rechtbank Arnhem 10 oktober 2007'
# In document ECLI:NL:CRVB:2002:AF1318
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 22 maart 2001'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 22 maart 2001 het tegen het besluit van 17 januari 2000'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 18 oktober 2002'
# In document ECLI:NL:RBZWB:2022:905
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze uitspraak is gedaan door mr. drs. E.J. Govaers, rechter, in aanwezigheid van R.V. van Vliet, griffier, op 23 februari 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is gedaan door mr. drs. E.J. Govaers, rechter, in aanwezigheid van R.V. van Vliet, griffier, op 23 februari 2022'
# In document ECLI:NL:GHDHA:2016:108
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak:\t27 januari 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak:\t27 januari 2016\nTEGENSPRAAK\n\nGerechtshof Den Haag\nmeervoudige kamer voor strafzaken\n\nArrest\n\ngewezen op het hoger beroep tegen het vonnis van de rechtbank Den Haag van 21 november 2014'
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken op de openbare terechtzitting van het hof van 27 januari 2016'
# In document ECLI:NL:PHR:2005:AU4787
# In document ECLI:NL:CRVB:2020:1726
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 20 februari 2018'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 4 augustus 2020'
# In document ECLI:NL:PHR:2004:AO0965
# In document ECLI:NL:RBUTR:2012:BY2545
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 18 oktober 2012'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. J.J.M. de Laat en in het openbaar uitgesproken op 18 oktober 2012'
# In document ECLI:NL:GHARL:2021:7127
# In document ECLI:NL:GHARL:2020:7675
# In document ECLI:NL:RBAMS:2024:3473
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken op de zitting van 11 juni 2024'
# In document ECLI:NL:RBSGR:2010:BO8867
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de AbRvS van 27 mei 2008'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de AbRvS van 26 mei 2010'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 24 december 2010'
# In document ECLI:NL:RBROT:2018:9327
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 24 oktober 2018'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. C. Bouwman en in het bijzijn van mr. S. Lankhaar, griffier, in het openbaar uitgesproken op 24 oktober 2018'
# In document ECLI:NL:RBOBR:2020:1267
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 25 februari 2020'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze beschikking is gegevens door mr. J.M.P. Willemse-Schwering, rechter, tevens kinderrechter, en in het openbaar uitgesproken op 25 februari 2020'
# In document ECLI:NL:RBNHO:2021:3702
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 21 december 2011'
# In document ECLI:NL:OGEAA:2022:568
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is een vervolg op het tussenvonnis van 12 mei 2021'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. J.J. Verhoeven, rechter in dit gerecht, en werd uitgesproken ter openbare terechtzitting van woensdag 26 januari 2022'
# In document ECLI:NL:GHSGR:2009:BM3994
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak\t\t: 11 november 2009'
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken ter openbare terechtzitting van 11 november 2009'
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken ter openbare terechtzitting van 14 april 2010'
# In document ECLI:NL:RBOVE:2021:4354
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen naar aanleiding van het onderzoek op de openbare terechtzitting van \n8 november 2021'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. M. van Berlo, voorzitter, mr. M. Melaard en mr. D. ten Boer, rechters, in tegenwoordigheid van mr. J.M. van Westerlaak, griffier, en is in het openbaar uitgesproken op: 22 november 2021'
# In document ECLI:NL:RBMNE:2024:1233
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 5 maart 2024'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is uitgesproken in het openbaar op 5 maart 2024'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 28 april 2021'
# In document ECLI:NL:CRVB:2004:AO8650
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 1 maart 2000'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak in zoverre in de plaats treedt van het besluit van 20 juli 1998'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 29 april 2004'
# In document ECLI:NL:GHSHE:2022:2540
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken door de rolraadsheer op 26 juli 2022'
# In document ECLI:NL:RBDHA:2022:15490
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 8 juli 20206'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de ABRvS van 30 november 20227'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 30 november 20228'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is uitgesproken in het openbaar en bekendgemaakt op:\n\n27 december 2022'
# In document ECLI:NL:RBAMS:2009:BP3283
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 18 november 2009'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. A.W.H. Vink, mr. A.P. Schoonbrood - Wessels en mr. M.R. Jöbsis en in het openbaar uitgesproken op 18 november 2009'
# In document ECLI:NL:RVS:2007:BA7618
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 20 juni 2007'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  "uitspraak in zaak no. AWB 05/1448 van de rechtbank\n's-Hertogenbosch van 8 september 2006"
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 8 september 2006'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 8 september 2006, verzonden op 20 september 2006'
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak hebben het college bij brief van 26 oktober 2006'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak hebben het college bij brief van 26 oktober 2006'
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak hebben het college bij brief van 26 oktober 2006, bij de Raad van State ingekomen op 27 oktober 2006'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak hebben het college bij brief van 26 oktober 2006, bij de Raad van State ingekomen op 27 oktober 2006'
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak hebben het college bij brief van 26 oktober 2006, bij de Raad van State ingekomen op 27 oktober 2006, en Brabants Dagblad bij brief van 30 oktober 2006'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak hebben het college bij brief van 26 oktober 2006, bij de Raad van State ingekomen op 27 oktober 2006, en Brabants Dagblad bij brief van 30 oktober 2006'
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak hebben het college bij brief van 26 oktober 2006, bij de Raad van State ingekomen op 27 oktober 2006, en Brabants Dagblad bij brief van 30 oktober 2006, bij de Raad van State ingekomen op 31 oktober 2006'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak hebben het college bij brief van 26 oktober 2006, bij de Raad van State ingekomen op 27 oktober 2006, en Brabants Dagblad bij brief van 30 oktober 2006, bij de Raad van State ingekomen op 31 oktober 2006'
#   pattern:'behandeld op DATELIKE'             matches:  'behandeld op 17 april 2007'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 26 april 2006'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak moet worden vernietigd, voor zover daarbij is nagelaten te oordelen over het beroep van Brabants Dagblad tegen het besluit van 4 april 2005'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  "uitspraak van de rechtbank 's-Hertogenbosch van 8 september 2006"
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  "uitspraak van de rechtbank 's-Hertogenbosch van 8 september 2006 in zaak no. AWB 05/1448, voor zover daarbij is nagelaten te oordelen over het beroep van Brabants Dagblad B.V. tegen het besluit van het college van gedeputeerde staten van Noord-Brabant van 4 april 2005"
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  "uitspraak van de rechtbank 's-Hertogenbosch van 8 september 2006 in zaak no. AWB 05/1448, voor zover daarbij is nagelaten te oordelen over het beroep van Brabants Dagblad B.V. tegen het besluit van het college van gedeputeerde staten van Noord-Brabant van 4 april 2005 voor zover betrekking hebbend op het verzoek om openbaarmaking van de stukken inzake [functionaris 1];\n\nIII. \xa0 \xa0verklaart het bij de rechtbank ingestelde beroep in zoverre gegrond;\n\nIV. \xa0 \xa0vernietigt het besluit van het college van gedeputeerde staten van Noord-Brabant van 4 april 2005"
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  "uitspraak van de rechtbank 's-Hertogenbosch van 8 september 2006"
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  "uitspraak van de rechtbank 's-Hertogenbosch van 8 september 2006 in zaak no. AWB 05/1448, voor zover daarbij is nagelaten te oordelen over het beroep van Brabants Dagblad B.V. tegen het besluit van het college van gedeputeerde staten van Noord-Brabant van 4 april 2005 voor zover betrekking hebbend op het verzoek om openbaarmaking van de stukken inzake [functionaris 1];\n\nIII. \xa0 \xa0verklaart het bij de rechtbank ingestelde beroep in zoverre gegrond;\n\nIV. \xa0 \xa0vernietigt het besluit van het college van gedeputeerde staten van Noord-Brabant van 4 april 2005, voor zover betrekking hebbend op het verzoek om openbaarmaking van de stukken inzake [functionaris 1], behoudens voor zover het de in overweging 2.7.4 bedoelde passages betreft;\n\nV. \xa0 \xa0vernietigt de uitspraak van de rechtbank 's-Hertogenbosch van 8 september 2006"
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 20 juni 2007'
# In document ECLI:NL:HR:2015:714
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen door de vice-president W.A.M. van Schendel als voorzitter, en de raadsheren B.C. de Savornin Lohman en H.A.G. Splinter-van Kan, in bijzijn van de waarnemend griffier J.D.M. Hart, en uitgesproken ter openbare terechtzitting van\n\n24 maart 2015'
# In document ECLI:NL:RBOVE:2024:2878
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 31 mei 2024'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. G.H. Meijer, voorzitter, mr. D.E. Schaap en \nmr. M.W. Eshuis, rechters, in tegenwoordigheid van mr. A. de Bruin, griffier, en is in het openbaar uitgesproken op 31 mei 2024'
# In document ECLI:NL:RBZWB:2024:1132
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 26 januari 2024'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze uitspraak is gedaan door mr. S.W.M. Speekenbrink, kantonrechter, bijgestaan door de griffier E. Alekperov, en in het openbaar uitgesproken op 26 januari 2024'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is gedaan door mr. S.W.M. Speekenbrink, kantonrechter, bijgestaan door de griffier E. Alekperov, en in het openbaar uitgesproken op 26 januari 2024'
# In document ECLI:NL:RVS:2007:BB9933
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 7 december 2007'
#   pattern:'behandeld op DATELIKE'             matches:  'behandeld op 26 november 2007'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 7 december 2007'
# In document ECLI:NL:RBROT:2016:10403
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 16 november 2016'
# In document ECLI:NL:GHSGR:2011:BR3963
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak:\t2 augustus 2011'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  "uitspraak:\t2 augustus 2011\nTEGENSPRAAK\n\nGerechtshof te 's-Gravenhage\nmeervoudige kamer voor strafzaken\n\nArrest\n\ngewezen op het hoger beroep tegen het vonnis van de rechtbank Rotterdam van 7 december 2010"
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen naar aanleiding van het onderzoek op de terechtzitting in eerste aanleg en het onderzoek op de terechtzitting in hoger beroep van dit hof van 19 juli 2011'
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken op de openbare terechtzitting van het hof van 2 augustus 2011'
# In document ECLI:NL:CRVB:2005:AS4579
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Zutphen van 7 oktober 2003'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 5 januari 2005'
# In document ECLI:NL:GHARL:2013:BZ3492
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Leeuwarden van 14 april 2011'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak van de eerste meervoudige belastingkamer\n\nop het hoger beroep van\n\nX wonende te Z, (hierna: belanghebbende),\n\ntegen de uitspraak van de rechtbank Leeuwarden van 14 april 2011'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 14 april 2011'
# In document ECLI:NL:CBB:2021:333
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van 16 juli 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van 9 januari 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van 16 juli 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 23 juli 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 23 juli 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 25 februari 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 25 februari 2020 (ECLI:NL:CBB:2020:114, onder 6.7) ontstaat de last op 1 januari 2018'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 23 juli 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van 25 februari 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 25 februari 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 25 februari 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 23 juli 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van 12 januari 2021'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van 19 januari 2021'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van 7 januari 2020'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 23 maart 2021'
# In document ECLI:NL:CBB:2018:641
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 4 december 2018'
# In document ECLI:NL:CRVB:2008:BD4156
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 5 juni 2008'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 31 augustus 2006'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 5 juni 2008'
# In document ECLI:NL:RBMNE:2016:2967
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 15 juni 2016'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. F.C. Burgers, kantonrechter, en is in het openbaar uitgesproken op 15 juni 2016'
# In document ECLI:NL:GHSHE:2008:BG1423
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken door de rolraadsheer op 7 oktober 2008'
# In document ECLI:NL:RBROT:2021:9905
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van Beroep voor het bedrijfsleven (CBb) van 24 november 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 10 juni 2021'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het CBb van 10 november 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het CBb van 10 november 2020 (ECLI:NL:CBB:2020:810) en naar het arrest van 12 september 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van Beroep voor het bedrijfsleven van 16 januari 2017'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is in het openbaar gedaan op 12 oktober 2021'
# In document ECLI:NL:RBZWB:2020:1513
# In document ECLI:NL:PHR:2006:AV6025
# In document ECLI:NL:OGEAA:2016:498
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken ter openbare terechtzitting van dit gerecht op 11 juli 2016'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door de rechter mr. M.T. Paulides en uitgesproken ter openbare terechtzitting van dit gerecht op 11 juli 2016'
# In document ECLI:NL:RVS:2013:CA3679
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 19 juni 2013'
#   pattern:'behandeld op DATELIKE'             matches:  'behandeld op 25 september 2012'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 19 juni 2013'
# In document ECLI:NL:RBLEE:2007:AZ5681
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze beschikking is gegeven op 03 januari 2007'
# In document ECLI:NL:GHAMS:2016:4199
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 18 oktober 2016'
# In document ECLI:NL:GHARL:2024:4471
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak d.d.:\t4 juli 2024'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen naar aanleiding van het onderzoek op de terechtzitting van het hof van 13 juni 2024'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Hoge Raad van 28 juni 2022'
# In document ECLI:NL:RBOVE:2021:2417
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken door mr. A.M.S. Kuipers op 8 juni 2021'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. A. Smedes, kantonrechter, en in het openbaar uitgesproken door mr. A.M.S. Kuipers op 8 juni 2021'
# In document ECLI:NL:RBSHE:2003:AF4958
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 25 februari 2003'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. J.F.M. Strijbos, voorzieningenrechter, en uitgesproken ter openbare terechtzitting van  25 februari 2003'
# In document ECLI:NL:RBDHA:2019:5286
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling bestuursrechtspraak van de Raad van State (de Afdeling) van 23 december 2013'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling van 3 augustus 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van rechtbank Den Haag, zittingsplaats Rotterdam, ongegrond verklaard (ECLI:NL:RBROT:2015:1936) en dit oordeel is in rechte vast komen te staan door de uitspraak van de Afdeling van 3 augustus 2015'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze uitspraak is in het openbaar gedaan en bekendgemaakt op 8 april 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is in het openbaar gedaan en bekendgemaakt op 8 april 2019'
# In document ECLI:NL:RVS:2024:939
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 6 maart 2024'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Den Haag van 3 maart 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak op het hoger beroep van:\n[appellant], wonend te Den Haag,\nappellant,\ntegen de uitspraak van de rechtbank Den Haag van 3 maart 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 6 maart 2024\nAFDELING\nBESTUURSRECHTSPRAAK\nUitspraak op het hoger beroep van:\n[appellant], wonend te Den Haag,\nappellant,\ntegen de uitspraak van de rechtbank Den Haag van 3 maart 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 3 maart 2022'
#   pattern:'behandeld op DATELIKE'             matches:  'behandeld op 11 december 2023'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 26 juli 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 26 juli 2022, ECLI:NL:RVS:2022:2138, heeft de voorzieningenrechter van de Afdeling bij wijze van voorlopige voorziening het college opgedragen uiterlijk op 2 augustus 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling van 23 oktober 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank vernietigen en, doende wat de rechtbank had behoren te doen, het beroep van [appellant] tegen het besluit van het college van 1 december 2021'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Den Haag van 3 maart 2022'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 6 maart 2024'
# In document ECLI:NL:GHDHA:2022:367
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken ter openbare terechtzitting van 28 februari 2022'
# In document ECLI:NL:GHARL:2017:9470
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen door mr. J.H. Kuiper, mr. O.E. Mulder en mr. D.J. Keur en is door de rolraadsheer, in tegenwoordigheid van de griffier, in het openbaar uitgesproken op \n31 oktober 2017'
# In document ECLI:NL:RVS:2008:BD8337
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 23 juli 2008'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak in zaak nr. 06/2941 van de rechtbank Amsterdam van 4 oktober 2007'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 4 oktober 2007'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 4 oktober 2007, verzonden op 5 oktober 2007'
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak heeft [appellant] bij brief, bij de Raad van State ingekomen op 12 november 2007'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak heeft [appellant] bij brief, bij de Raad van State ingekomen op 12 november 2007'
#   pattern:'behandeld op DATELIKE'             matches:  'behandeld op 23 april 2007'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak om die reden te vernietigen omdat de omstandigheid dat voor de behandeling van het desbetreffende hoger beroep wel een toevoeging is verleend, wat daar ook van zij, onverlet laat dat de rechtbank, zoals hiervoor is overwogen, terecht heeft overwogen dat de raad de door [appellant] op 29 maart 2005'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 23 juli 2008'
# In document ECLI:NL:RBROT:2019:802
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 28 januari 2019.2885/676'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. A.F.L. Geerdes en in het openbaar uitgesproken op 28 januari 2019.2885/676'
# In document ECLI:NL:RBLIM:2023:255
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis heeft het gerechtshof in hoger beroep bij arrest van 11 december 2018'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 12 januari 2023'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. A.M. Koster-van der Linden en in het openbaar uitgesproken op 12 januari 2023'
# In document ECLI:NL:CRVB:2001:AE8593
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 27 augustus 1998'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 27 augustus 1998 de tegen de besluiten van 22 oktober 1997'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 27 augustus 1998 de tegen de besluiten van 22 oktober 1997 en 24 oktober 1997'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 27 februari 2001'
# In document ECLI:NL:RBMNE:2019:5516
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Centrale Raad van Beroep (CRvB) van 29 mei 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de CRvB van 15 november 2018'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 22 november 2019'
# In document ECLI:NL:RBMNE:2013:3305
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 9 augustus 2013'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. J.J.M. de Laat, kantonrechter, en is in aanwezigheid van de griffier in het openbaar uitgesproken op 9 augustus 2013'
# In document ECLI:NL:GHSHE:2015:1342
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken door de rolraadsheer op 14 april 2015'
# In document ECLI:NL:GHARL:2015:2296
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak d.d.:\t31 maart 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak d.d.:\t31 maart 2015\nTEGENSPRAAK\nPromis\n\nVerkort arrest van de meervoudige kamer voor strafzaken\ngewezen op het hoger beroep, ingesteld tegen het vonnis van de politierechter in de rechtbank Oost-Nederland van 4 februari 2013'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen naar aanleiding van het onderzoek op de terechtzitting van het hof van 17 maart 2015'
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken.\n\nProces-verbaal van het in dezelfde zaak voorgevallene ter openbare terechtzitting van het gerechtshof van 31 maart 2015'
# In document ECLI:NL:RBROT:2020:10670
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak in verzekering en in voorlopige hechtenis is doorgebracht, bij de uitvoering van de opgelegde werkstraf in mindering wordt gebracht volgens de maatstaf van twee uren per dag, zodat na deze aftrek\n\n52 (tweeënvijftig) uur\nte verrichten werkstraf resteert;\n\nbeveelt dat, voor het geval de veroordeelde de werkstraf niet naar behoren verricht, vervangende jeugddetentie zal worden toegepast voor de duur van\n\n26 (zesentwintig) dagen\n;\n\nheft op het bevel tot voorlopige hechtenis van de verdachte, die bij eerdere beslissing is geschorst;\n\nveroordeelt de ouders van verdachte hoofdelijk met zijn mededaders, om tegen behoorlijk bewijs van kwijting aan de benadeelde partij [naam slachtoffer 1] , te betalen een bedrag van\n\n€ 4.159,90 (zegge: vierduizendhonderdnegenenvijftig euro en negentig eurocent),\nbestaande uit € 159,90 aan materiële schade en € 4.000,00 aan immateriële schade, te vermeerderen met de wettelijke rente hierover vanaf 24 maart 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak in verzekering en in voorlopige hechtenis is doorgebracht, bij de uitvoering van de opgelegde werkstraf in mindering wordt gebracht volgens de maatstaf van twee uren per dag, zodat na deze aftrek\n\n52 (tweeënvijftig) uur\nte verrichten werkstraf resteert;\n\nbeveelt dat, voor het geval de veroordeelde de werkstraf niet naar behoren verricht, vervangende jeugddetentie zal worden toegepast voor de duur van\n\n26 (zesentwintig) dagen\n;\n\nheft op het bevel tot voorlopige hechtenis van de verdachte, die bij eerdere beslissing is geschorst;\n\nveroordeelt de ouders van verdachte hoofdelijk met zijn mededaders, om tegen behoorlijk bewijs van kwijting aan de benadeelde partij [naam slachtoffer 1] , te betalen een bedrag van\n\n€ 4.159,90 (zegge: vierduizendhonderdnegenenvijftig euro en negentig eurocent),\nbestaande uit € 159,90 aan materiële schade en € 4.000,00 aan immateriële schade, te vermeerderen met de wettelijke rente hierover vanaf 24 maart 2020 tot aan de dag der algehele voldoening;\n\nbepaalt dat de ouders van de verdachte bij gehele of gedeeltelijke betaling door de mededaders van de verdachte aan benadeelde partij [naam slachtoffer 1] , zullen zijn bevrijd tot de hoogte van het betaalde bedrag; \n\nverklaart benadeelde partij [naam slachtoffer 1] niet-ontvankelijk in het resterende deel van de vordering; bepaalt dat dit deel van de vordering slechts kan worden aangebracht bij de burgerlijke rechter;\n\nveroordeelt de ouders van verdachte in de proceskosten door de benadeelde partij [naam slachtoffer 1] gemaakt, tot op heden aan de zijde van de benadeelde partij begroot op € 10,36 en in de kosten ten behoeve van de tenuitvoerlegging nog te maken;\n\nveroordeelt de ouders van verdachte hoofdelijk met zijn mededaders, om tegen behoorlijk bewijs van kwijting aan de benadeelde partij [naam slachtoffer 4] , wettelijk vertegenwoordigd door [naam slachtoffer 1] , te betalen een bedrag van\n\n€ 4.100,00  (zegge: eenenveertighonderd euro),\nbestaande uit € 100,00 aan materiële schade en € 4.000,00 aan immateriële schade, te vermeerderen met de wettelijke rente hierover vanaf 24 maart 2020'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op de openbare terechtzitting van deze rechtbank op 15 oktober 2020'
# In document ECLI:NL:RBNHO:2021:4698
# In document ECLI:NL:RBOBR:2017:69
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is op tegenspraak gewezen naar aanleiding van het onderzoek ter terechtzitting van 8 en 22 december 2016'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 5 januari 2017'
# In document ECLI:NL:RBNHO:2023:6409
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 10 juli 2023'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. J.H. Gisolf en in het openbaar uitgesproken op 10 juli 2023'
# In document ECLI:NL:RBDHA:2024:1298
# In document ECLI:NL:RBHAA:2012:BV3157
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in tegenwoordigheid van de griffier op 27 januari 2012'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. E. Jochem en in het openbaar uitgesproken in tegenwoordigheid van de griffier op 27 januari 2012'
# In document ECLI:NL:RBNHO:2023:10740
# In document ECLI:NL:GHLEE:2012:BX0826
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak d.d.:\t9 juli 2012'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen naar aanleiding van het onderzoek op de terechtzittingen van het hof van 5 januari 2012'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen naar aanleiding van het onderzoek op de terechtzittingen van het hof van 5 januari 2012, 5 maart 2012'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen naar aanleiding van het onderzoek op de terechtzittingen van het hof van 5 januari 2012, 5 maart 2012 en 21 juni 2012'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen naar aanleiding van het onderzoek op de terechtzittingen van het hof van 5 januari 2012, 5 maart 2012 en 21 juni 2012 voortgezet op 25 juni 2012'
# In document ECLI:NL:CRVB:2000:AA7223
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 20 oktober 1997'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 20 oktober 1997'
# In document ECLI:NL:RBGEL:2021:5789
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken ter openbare terechtzitting van deze rechtbank op 29 oktober 2021'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. T.N. Ritzer (voorzitter), mr. M.C. van der Mei en mr. G.L.C. van den Bosch, rechters, in tegenwoordigheid van mr. M.M. Aalbers, griffier, en uitgesproken ter openbare terechtzitting van deze rechtbank op 29 oktober 2021'
# In document ECLI:NL:RBROT:2010:BM5265
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 28 april 2004'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 20 mei 2010'
# In document ECLI:NL:HR:2005:AR8661
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 4 januari 2005'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen door de vice-president C.J.G. Bleichrodt als voorzitter, en de raadsheren J.P. Balkema en A.J.A. van Dorst, in bijzijn van de waarnemend-griffier J.D.M. Hart, en uitgesproken op 4 januari 2005'
# In document ECLI:NL:RBROT:2022:8093
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 14 september 2022'
# In document ECLI:NL:RBOBR:2013:2856
# In document ECLI:NL:CRVB:2004:AS2529
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak wordt onder gedaagde tevens verstaan het Lisv.\n\nAppellant heeft hoger beroep ingesteld tegen de tussen partijen op 12 maart 2002'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak wordt onder gedaagde tevens verstaan het Lisv.\n\nAppellant heeft hoger beroep ingesteld tegen de tussen partijen op 12 maart 2002'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar \nop 16 december 2004'
# In document ECLI:NL:RBAMS:2015:651
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 11 februari 2015'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. N.C.H. Blankevoort, mr. H.J. Fehmers en mr. M.E.M. James-Pater en in het openbaar uitgesproken op 11 februari 2015'
# In document ECLI:NL:RVS:2024:1845
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 3 mei 2024'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  "uitspraak van de rechtbank Den Haag, zittingsplaats 's-Hertogenbosch, van 25 maart 2024"
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  "uitspraak van de rechtbank Den Haag, zittingsplaats 's-Hertogenbosch, van 25 maart 2024 in zaak nr. NL24.10404 in het geding tussen:\n[de vreemdeling]\nen\nde staatssecretaris van Justitie en Veiligheid\nProcesverloop\nBij besluit van 8 maart 2024"
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 25 maart 2024'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 3 mei 2024'
# In document ECLI:NL:RVS:2022:3202
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 9 november 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Den Haag van 11 oktober 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak van de voorzieningenrechter van de Afdeling bestuursrechtspraak van de Raad van State op een verzoek om het treffen van een voorlopige voorziening (artikel 8:81 van de Algemene wet bestuursrecht) en, met toepassing van artikel 92 van de Vw 2000, op het hoger beroep van:\n[de vreemdeling], mede voor haar minderjarige kinderen,\nappellante,\ntegen de uitspraak van de rechtbank Den Haag van 11 oktober 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 11 oktober 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 20 april 2022'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 20 april 2022, ECLI:NL:RVS:2022:1129, onder 5, over toepassing van artikel 1(D) van het Vluchtelingenverdrag en artikel 12, eerste lid, aanhef en onder a, van de Kwalificatierichtlijn en het arrest van het Hof van Justitie van 3 maart 2022'
# In document ECLI:NL:RVS:2017:3121
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 15 november 2017'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Den Haag, nevenzittingsplaats Rotterdam, van 18 november 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 18 november 2016'
#   pattern:'behandeld op DATELIKE'             matches:  'behandeld op 3 oktober 2017'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 28 mei 2008'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 12 juli 2012'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling van 29 februari 2012'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 15 november 2017'
# In document ECLI:NL:RBLIM:2013:5263
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken ter openbare zitting op 6 september 2013'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. M.C.A.E. van Binnebeke, voorzitter, mr. M.B. Bax en \nmr. W.H.B. Dreissen, rechters, in tegenwoordigheid van L.A.J.W. Schoutese, griffier, en is uitgesproken ter openbare zitting op 6 september 2013'
# In document ECLI:NL:CRVB:2024:123
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 19 januari 2024'
# In document ECLI:NL:RVS:2017:973
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 6 april 2017'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Den Haag, zittingsplaats Utrecht, van 13 februari 2017'
# ...
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 20 mei 2009'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 15 juni 2016'
# In document ECLI:NL:GHARN:2012:BW3384
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Arnhem van 7 juli 2011'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak van de eerste meervoudige belastingkamer\n\nop het hoger beroep van\n\nX te Z (hierna: belanghebbende)\n\ntegen de uitspraak van de rechtbank Arnhem van 7 juli 2011'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 7 juli 2011'
# In document ECLI:NL:RBZWB:2018:6413
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze uitspraak is gedaan op 9 november 2018'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is gedaan op 9 november 2018'
# In document ECLI:NL:RBMNE:2017:793
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 22 februari 2017'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. J.K.J. van den Boom en in het openbaar uitgesproken op 22 februari 2017'
# In document ECLI:NL:RBLEE:2004:AR2134
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak: 14 september 2004'
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken ter openbare terechtzitting van 14 september 2004'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. C.M. Telman, voorzieningenrechter, en in aanwezigheid van de griffier uitgesproken ter openbare terechtzitting van 14 september 2004'
# In document ECLI:NL:PHR:2017:1233
# In document ECLI:NL:GHSHE:2015:2582
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 26 juni 2015'
# In document ECLI:NL:GHAMS:2020:1036
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 7 april 2020'
# In document ECLI:NL:RBALK:2011:BU8340
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 15 december 2011'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. E.J. van der Molen en in het openbaar uitgesproken op 15 december 2011'
# In document ECLI:NL:RBNHO:2023:3844
# In document ECLI:NL:RVS:2020:2113
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 2 september 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Overijssel van 14 juni 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak op het hoger beroep van:\n[appellant], wonend te [woonplaats],\nappellant,\ntegen de uitspraak van de rechtbank Overijssel van 14 juni 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 2 september 2020\nAFDELING\nBESTUURSRECHTSPRAAK\nUitspraak op het hoger beroep van:\n[appellant], wonend te [woonplaats],\nappellant,\ntegen de uitspraak van de rechtbank Overijssel van 14 juni 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 14 juni 2019'
#   pattern:'behandeld op DATELIKE'             matches:  'behandeld op 24 juli 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 17 juli 2019'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 2 september 2020'
# In document ECLI:NL:RBSGR:2008:BG5749
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van \n24 september 2008'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van \n24 september 2008 (LJN: BF2133) geoordeeld dat artikel 156, eerste lid, van de Gemeentewet de ingevolge artikel 10:15 van de Awb vereiste wettelijke grondslag biedt voor de overdracht aan het college van de bevoegdheid van de raad om te beslissen op planschadeverzoeken die vóór 1 september 2005'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 29 augustus 2007'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 29 oktober 2008'
# In document ECLI:NL:CRVB:2009:BI5926
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank ’s-Gravenhage van 22 september 2008'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 22 mei 2009'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 22 september 2008'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 22 september 2008, als bedoeld in artikel 8:86 van de Algemene wet bestuursrecht (Awb), heeft de rechtbank het tegen het besluit van 20 maart 2008'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 18 november 2003'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 22 mei 2009'
# In document ECLI:NL:RBROT:2024:4819
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de enkelvoudige kamer van 16 mei 2024'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 16 mei 2024'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze uitspraak is uitgesproken in het openbaar op 16 mei 2024'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is uitgesproken in het openbaar op 16 mei 2024'
# In document ECLI:NL:GHSHE:2020:544
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak\t: 5 februari 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  "Uitspraak\t: 5 februari 2020\nTEGENSPRAAK\n\nArrest van de meervoudige kamer voor strafzaken van het gerechtshof\n's-Hertogenbosch\n\ngewezen op het hoger beroep, ingesteld tegen het vonnis van de politierechter in de rechtbank Oost-Brabant van 31 augustus 2018"
# In document ECLI:NL:GHARL:2022:4581
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 7 juni 2022'
# In document ECLI:NL:RBROT:2021:10162
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 13 september 2021'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze beschikking is gegeven door mr. H. Benaissa, kinderrechter, in tegenwoordigheid van\n\nJ.A. van Soest als griffier en in het openbaar uitgesproken op 13 september 2021'
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze beschikking is vastgesteld op 27 september 2021'
# In document ECLI:NL:RBMNE:2022:7
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is op tegenspraak gewezen naar aanleiding van het onderzoek dat achter gesloten deuren heeft plaatsgevonden op de terechtzitting van 14 december 2021'
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken op de openbare terechtzitting van 4 januari 2022'
# In document ECLI:NL:CBB:2002:AF3252
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 19 december 2002'
# In document ECLI:NL:GHARN:2012:BY3990
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak is het hof in zijn beslissing van 1 oktober 2012'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is het hof in zijn beslissing van 1 oktober 2012'
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze uitspraak is het hof in zijn beslissing van 1 oktober 2012 (LJN: BX8788) teruggekomen op zijn eerdere opvatting (Hof Arnhem 30 mei 2011'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is het hof in zijn beslissing van 1 oktober 2012 (LJN: BX8788) teruggekomen op zijn eerdere opvatting (Hof Arnhem 30 mei 2011'
# In document ECLI:NL:RBAMS:2012:BX2641
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak bevat onder meer de volgende overwegingen:\n“2.18 Bij brief van 1 november 2010'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 20 juli 2012'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. S.P. Pompe, voorzieningenrechter, bijgestaan door mr. M. Balk, griffier, en in het openbaar uitgesproken op 20 juli 2012'
# In document ECLI:NL:RBROT:2022:5510
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak in verzekering en in voorlopige hechtenis is doorgebracht, bij de uitvoering van de opgelegde gevangenisstraf in mindering wordt gebracht, voor zover deze tijd niet reeds op een andere vrijheidsstraf in mindering is gebracht;\n\nveroordeelt de verdachte om tegen behoorlijk bewijs van kwijting aan de benadeelde partij [benadeelde01] , te betalen een bedrag van\n\n€ 5.000\n, - (zegge: vijfduizend euro), bestaande uit immateriële schade, te vermeerderen met de wettelijke rente hierover vanaf 9 juni 2019'
# In document ECLI:NL:RBSGR:2002:AD9567
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken ter openbare terechtzitting van deze rechtbank van 25 februari 2002'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door\nmrs Quadekker,\tvoorzitter,\nWattèl en Goudswaard,\trechters,\nin tegenwoordigheid van mr Vreeling,\tgriffier,\nen uitgesproken ter openbare terechtzitting van deze rechtbank van 25 februari 2002'
# In document ECLI:NL:RBROT:2021:13280
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het College van beroep voor het bedrijfsleven (CBb) van 3 maart 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling bestuursrechtspraak van de Raad van State (de Afdeling) van 28 oktober 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het CBb van 10 december 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling bestuursrechtspraak van de Raad van State (de Afdeling) van 28 oktober 2020 (ECLI:NL:RVS:2020:2571) en naar de uitspraak van het CBb van 10 december 2019'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van het CBb van 10 december 2019 (ECLI:NL:CBB:2019:662), waaruit volgt dat een last kan worden opgelegd indien een overtreding heeft plaatsgevonden en gevaar voor herhaling voor de hand ligt.\n\n5.3\nDe rechtbank volgt [eiseres] ten slotte niet in haar standpunt dat de gedragslijnen niet in tijd beperkt zijn, nu uit het wijzigingsbesluit blijkt dat de termijn van deze gedragslijnen tot 11 augustus 2020'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling bestuursrechtspraak van de Raad van State (de Afdeling) van 28 oktober 2020 (ECLI:NL:RVS:2020:2571) en naar de uitspraak van het CBb van 10 december 2019 (ECLI:NL:CBB:2019:662), waaruit volgt dat een last kan worden opgelegd indien een overtreding heeft plaatsgevonden en gevaar voor herhaling voor de hand ligt.\n\n5.3\nDe rechtbank volgt [eiseres] ten slotte niet in haar standpunt dat de gedragslijnen niet in tijd beperkt zijn, nu uit het wijzigingsbesluit blijkt dat de termijn van deze gedragslijnen tot 11 augustus 2020'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 21 december 2021'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak is uitgesproken in het openbaar op 21 december 2021'
# In document ECLI:NL:RBMNE:2018:3247
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 18 juli 2018'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. A.F. Hermans en in het openbaar uitgesproken op 18 juli 2018'
# In document ECLI:NL:RVS:2017:2084
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 2 augustus 2017'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 28 april 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 6 juli 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 28 april 2016 en bij uitspraak van 6 juli 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 6 juli 2016 heeft de rechtbank de door [wederpartij] daartegen ingestelde beroepen gegrond verklaard, de besluiten op bezwaar vernietigd en de besluiten van 21 juli 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 28 april 2016 en bij uitspraak van 6 juli 2016 heeft de rechtbank de door [wederpartij] daartegen ingestelde beroepen gegrond verklaard, de besluiten op bezwaar vernietigd en de besluiten van 21 juli 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 6 juli 2016 heeft de rechtbank de door [wederpartij] daartegen ingestelde beroepen gegrond verklaard, de besluiten op bezwaar vernietigd en de besluiten van 21 juli 2015, 22 juli 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 28 april 2016 en bij uitspraak van 6 juli 2016 heeft de rechtbank de door [wederpartij] daartegen ingestelde beroepen gegrond verklaard, de besluiten op bezwaar vernietigd en de besluiten van 21 juli 2015, 22 juli 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 6 juli 2016 heeft de rechtbank de door [wederpartij] daartegen ingestelde beroepen gegrond verklaard, de besluiten op bezwaar vernietigd en de besluiten van 21 juli 2015, 22 juli 2015 en 14 september 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 28 april 2016 en bij uitspraak van 6 juli 2016 heeft de rechtbank de door [wederpartij] daartegen ingestelde beroepen gegrond verklaard, de besluiten op bezwaar vernietigd en de besluiten van 21 juli 2015, 22 juli 2015 en 14 september 2015'
#   pattern:'behandeld op DATELIKE'             matches:  'behandeld op 6 maart 2017'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 8 juni 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling van\xa0 6 juli 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de Afdeling van 6 juli 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 8 juni 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van 8 juni 2016'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 2 augustus 2017'
# In document ECLI:NL:CRVB:2024:665
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 4 april 2024'
# In document ECLI:NL:CRVB:2020:2758
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak;\n- verklaart het beroep gegrond en vernietigt het besluit van 22 juni 2018'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak;\n- verklaart het beroep gegrond en vernietigt het besluit van 22 juni 2018;\n- draagt het college op een nieuwe beslissing op het bezwaar tegen het besluit van 13 februari 2018'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 3 november 2020'
# In document ECLI:NL:CRVB:2018:137
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank \nZeeland-West-Brabant van 11 februari 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak: 10 januari 2018'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 10 januari 2018'
# In document ECLI:NL:GHDHA:2016:1783
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak van de meervoudige belastingkamer van 21 juni 2016'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak van de rechtbank Den Haag (de Rechtbank) van 9 juli 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'Uitspraak van de meervoudige belastingkamer van 21 juni 2016\n\nin het geding tussen:\n\n      [X] , wonende te [Z] , belanghebbende,\n\nen\n\nde inspecteur van de Belastingdienst, kantoor Hoofddorp, de Inspecteur,\n\ninzake het hoger beroep van belanghebbende tegen de uitspraak van de rechtbank Den Haag (de Rechtbank) van 9 juli 2015'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak op bezwaar van 17 april 2014'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak op bezwaar van 17 april 2014'
#   pattern:'uitspraak ANYPLUS DATELIKE'        matches:  'uitspraak op bezwaar van 17 april 2014'

# %% [markdown]
# # Discussion
#
# Pattern matching can be great,
# but you probably want to know its limitations before you spend a lot of time
# discovering that it _isn't_ enough for your purposes, or at least, how much work it will be.
#
#
# One of the things to realize is that pattern matching only ever reports what it matches,
# and examples that look great are usually the patterns that are _very_ regular.
#
# If what you need is exact and rigid matching, great!
#
# Yet the more varied, the more _natural_ text is, the harder that is to do,
# amd **it will not tell you what you are missing**, what you need to improve.
#
# That's your job, as your own technician.
