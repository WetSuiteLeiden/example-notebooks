# %% [markdown]
# <a href="https://colab.research.google.com/github/WetSuiteLeiden/example-notebooks/blob/main/research-methods/methods_nlp__patterns_spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For local installs you can install the package once.   In colab you get a disposable environment and will have to start with this install each time. 
# !pip3 -q install wetsuite -U

# %%
# !python -m spacy download nl_core_news_lg

# %% [markdown]
# ## Purpose of this notebook
#
# What you can do about phrases and patterns in spacy.
#
#
# Before we get into it, it should be pointed out that
# - you can express more complex types of patterns, see https://spacy.io/api/matcher#patterns
# - You could extend this to more complex tasks, like maybe rule-based phrase and named entity extraction.
#   - ...though you might base that on more specific existing code like PhraseMatcher and EntityRuler,
#     which may work faster and/or annotate automatically.
#   - and in the case of NER would probaly still be less effective than existing trained NER model components
# - natural language is too flexible -- **you will likely find this approach lacking and incomplete** except for some specific tasks
#
# We will demonstrate that somewhat in the process.

# %% [markdown]
# [The things we can match tokens on](https://spacy.io/usage/rule-based-matching#adding-patterns-attributes) are mostly attributes already on the Token object, so if you've already worked with spacy, you should recognize most as things you can also access via code (e.g. from the [Token documentation](https://spacy.io/api/token#attributes) and our [spacy intro notebook](methods_nlp__spacy_basics.ipynb)):
# - `ORTH` or `TEXT` - the text as-is
# - `LENGTH` - length of TEXT
# - `LOWER` - the lowercase version of the text
# - `NORM` - the normalized version (seems to do things like resolve contractions, and otherwise often be the lemmatizer output?)
# - `LEMMA` - lemmatixed
# - `SHAPE` - alphabetic characters become X or x, numeric by d, and sequences of the same are truncated after 4, so e.g. Katherine80 would become Xxxxxdd
# - `POS` - coarse tagging  (often following wider conventions), e.g. `NOUN`; many models follow [a relatively universal parts-of-speech set](https://universaldependencies.org/u/pos/)
#   - (so often `ADJ`, `ADP`, `ADV`, `AUX`, `CCONJ`, `DET`, `INTJ`, `NOUN`, `NUM`, `PART`, `PRON`, `PROPN`, `PUNCT`, `SCONJ`, `SYM`, `VERB`, `X` -- but you should still check for each model)
# - `TAG` - finer tagging than POS
#   - (often specific to the given model and language, e.g. `'N|soort|ev|basis|zijd|stan'`)
# - `MORPH` - morphological properties
#   - (often specific to the given model and language, e.g. `Gender=Com|Number=Sing`)
#   - note that this supports `{"MORPH": {"IS_SUBSET": ["Number=Sing", "Gender=Neut"]}}`
#
# - `DEP` - dependency relation in the parse ([this takes some more typing to specfy](https://spacy.io/usage/rule-based-matching#dependencymatcher))
# - `IS_SENT_START`
# - `IS_LOWER`, `IS_UPPER`, `IS_TITLE`; `IS_PUNCT`, `IS_SPACE`, `IS_STOP`; `IS_ALPHA`, `IS_ASCII`, `IS_DIGIT`; `LIKE_NUM`, `LIKE_URL`, `LIKE_EMAIL`
# - `_` accesses custom attributes

# %% [markdown]
# Also,
# * you can add the optional `OP`, a [quantifier](https://spacy.io/usage/rule-based-matching#quantifiers) (that uses a syntax muc like regexes)
#   - `?`, `+`, `*`, `{n}`, `{n,m}`, `{n,}`, `{,m}`
#   - ...and `!` which means it must _not_ match (match 0 times at this point)
#     - TOFIGURE: (does it consume so mean an "anything but this?" -- or does it _not_ consume and mean more of a negative lookahead?)
#   - consider e.g. `{'POS':'ADJ', 'OP':'*'}, {"POS": {"REGEX": "(NOUN|PROPN)"}}`
#
# * instead of the value being one literal scring, you can make it a dict and add one of the following:
#   - use `==`, `>=`, `<=`, `>`, `<`
#     - consider e.g. `{"LENGTH": {">=": 10}}`
#   - use `IN`, `NOT_IN`, `IS_SUBSET`, `IS_SUPERSET`, `INTERSECTS` to compare with lists
#     - consider e.g. `{"POS": {"IN":["NOUN","PROPN"]} }` or `{"MORPH": {"IS_SUBSET": ["Number=Sing", "Gender=Neut"]}}`
#
#   - invoke [the regex operator](https://spacy.io/usage/rule-based-matching#regex)
#     - consider e.g. `{"TEXT": {"REGEX": "deff?in[ia]tely"}}`, or `{"TAG": {"REGEX": "^N"}`
#   - invoke [the fuzzy operator](https://spacy.io/usage/rule-based-matching#fuzzy)
#     - which (by default) matches an [edit distance](https://en.wikipedia.org/wiki/Edit_distance#Example) of 2, so e.g. `{"FUZZY": "favorite"}` will match  "favourite", "favorites", and "gavorite".
#
#   - some combinations, e.g. `{"FUZZY": {"IN": ["awesome", "cool", "wonderful"]}}}`
#
# * 'match _any_ one token' can be done with `{}`
#   - TOFIGURE: does that mean `{'OP':'+'}` matches one or more?

# %% [markdown]
# ## Enough words and lists, let's start doing things

# %%
import spacy
import spacy.matcher
from spacy.matcher import Matcher
import spacy.displacy

import wetsuite.helpers.spacy
import wetsuite.datasets


# some example data to use later
some_cvdr_text        = wetsuite.datasets.load('cvdr-mostrecent-text').data.random_values(250)
some_rechtspraak_text = list( case.get('bodytext')   for case in wetsuite.datasets.load('rechtspraaknl-struc').data.random_values(250) )

# %% [markdown]
# ### How do I put patterns in, how do I get matches out?
#
# Both depends a little on whether you are are using a separate Matcher, or are adding a Ruler to the model object.
#
# Chances are you'll end up on something visual while experimenting,
# but something more succinct once you're using this as a tool.

# %% [markdown]
# #### bare Matcher
#
# A Matcher is a separate thing that you can run on a document.
#
# You attach it to an existing pipeline - in part just because _something_ needs to create the tokens-with-attributes we will match on.
#
# For example:

# %%
dutch  = spacy.load('nl_core_news_lg')

matcher = spacy.matcher.Matcher(dutch.vocab)
#            pattern name      pattern 
matcher.add("HW_MetPunct",    [   [{"LOWER": "hallo"}, {"IS_PUNCT": True},           {"LOWER": "wereld"}]  ])
matcher.add("HW_Opt",         [   [{"LOWER": "hallo"}, {"IS_PUNCT": True, "OP":'*'}, {"LOWER": "wereld"}]  ])  # punctuation is optional in this one (so matches both in the example)
# note that the pattern is a list of lists. This is because you can have multiple patterns for one rule (e.g. to specify some variants), so far we have just one.

doc = dutch("De hallo, wereld test.  Eerste patroon matcht niet op hallo wereld.")
print( 'Sentence tokens: ', list( repr(tok) for tok in doc ) ) # (just to point out what the token and their text are)

for match_id, start, end in matcher( doc ):   # running that Matcher will return a sequence of matches   (note: end is exclusive)
    match_str  = dutch.vocab.strings[match_id] # (spacy makes a point of having an integer representation of everything it might store; this gets a get string representation of the pattern name, and is optional if you don't care)
    match_span = doc[start:end]  # fetch as span, mostly because it's the easiest way to get the .text again:
    print(f"Pattern {repr(match_str):15s} matches token {start:3d}..{end-1:<3d}  which is the text {repr(match_span.text)}")
# Out:
# Sentence tokens:  ['De', 'hallo', ',', 'wereld', 'test', '.', ' ', 'Eerste', 'patroon', 'matcht', 'niet', 'op', 'hallo', 'wereld', '.']
# Pattern 'HW_MetPunct'   matches token   1..3    which is the text 'hallo, wereld'
# Pattern 'HW_Opt'        matches token   1..3    which is the text 'hallo, wereld'
# Pattern 'HW_Opt'        matches token  12..13   which is the text 'hallo wereld'

# %%
# Let's make a slightly more interesting example, and run on some real data
# let's look for   one or more adjectives,  before  <a noun or proper noun>.

an_pattern = [
    [ 
        {"POS":"ADJ",   "OP":"+"},        # "+" means one or more  
        {"POS":{"IN":["NOUN","PROPN"]} } 
    ],
]
matcher = spacy.matcher.Matcher(dutch.vocab)
matcher.add("adjective-noun", an_pattern)

doc = dutch( some_cvdr_text[0] )
for _match_id, start, end in matcher(doc):
    print( doc[start:end].text, end='\n' )
# Out:
# onroerende zaakbelastingen
# onroerende zaken
# directe belastingen
# onroerende zaak
# persoonlijk recht
# onroerende zaak
# onroerende zaak
# onroerende zaak
# volgtijdig gebruik
# onroerende zaak
# onroerende zaak
# basisregistratie kadaster
# onroerende zaak
# onroerende zaak
# onroerende zaken
# onroerende zaak
# onroerende zaken
# onroerende zaak
# onroerende zaak
# onroerende zaken
# onroerende zaak
# onroerende zaak
# onroerende zaken
# onroerende zaak
# overeenkomstige toepassing
# tweede lid
# onroerende zaken
# open grond
# onroerende zaken
# openbare eredienst
# openbare bezinningssamenkomsten
# levensbeschouwelijke aard
# onroerende zaken
# zodanige onroerende zaken
# onroerende zaken
# volledige rechtsbevoegdheid
# openbaar vervoer
# publiekrechtelijke rechtspersonen
# zodanige werken
# ander afvalwater
# publiekrechtelijke rechtspersonen
# zodanige werken
# onroerende zaak
# onroerende zaken
# publieke dienst
# onroerende zaken
# zodanige onroerende zaken
# onroerende zaken
# zodanige onroerende zaken
# onroerende zaken
# zodanige onroerende zaken
# eerste lid
# onroerende zaken
# onroerende zaak
# onroerende zaken
# onroerende zaken
# gehele euro's
# eerste lid
# gelijke termijnen
# laatste dag
# eerste lid
# automatische betalingsincasso
# kleine afrondingsverschillen
# maandelijkse termijnen
# eerste termijn
# Nadere regels
# nadere regels
# tweede lid
# belastbare feiten
# eerste dag
# onroerende zaakbelastingen

# %% [markdown]
# #### EntityRuler, or preferably SpanRuler
#
# When using spacy to collect and _combine_ different kinds of annotation,
# you might want to have them be marked up on the document object,
# to make it easier to visualize.
#
# If this is your goal, switch from a Matcher to either a Spanruler or an EntityRuler,
# which work in _almost_ the same way, but are set on the document object (in `.spans` and `.ents`, respectively),
# and there is out-of-the-box visualizaton for both.
#
# <!-- -->
#
# Using an EntityRuler makes it easy to visualize exactly as we previously did with entities, but has an already-mentioned problem:
# Entities are assumed to never overlap, so matches will be silently dropped when they overlap,
# with other matches or with entities that e.g. existing NER added.
# (You can disable existing NER, but it may defeat the point of combining things; there is no way to avoid dropping overlapping matches).
#
# <!-- -->
#
# ...which is why spacy recommends using SpanRuler instead.
# Visualizing spans isn't as compact exactly _because_ it is capable of displaying overlapping spans.
#
# Note that `.spans` is not just a list of matches, but is made to spans from different, named sources.
# As such, `.spans` is a dict from a useful name to a list of spans.
# SpanRuler defaults to add in the key `'ruler'`, which is why we have to explicitly tell it that
# in the second visualization below.
#
# Note that the way you hand in the pattern into Rulers is a _little_ different from Matchers,
# and the same between these two Rulers:

# %%
# using EntityRuler:
dutch_with_er  = spacy.load('nl_core_news_lg')

# remove the existing NER  (happens to _NOT_ clash on this specific sentence, but in general you cannot assume that)
dutch_with_er.remove_pipe("ner")  

# create our own rules
ruler = dutch_with_er.add_pipe("entity_ruler")
ruler.add_patterns( [ {'label':'ADJ_N',  "pattern":[ {"POS":"ADJ", "OP":"+"},  {"POS":{"IN":["NOUN","PROPN"]} }  ]} ] )

# run, show output
doc = dutch_with_er("""Onder de naam "afvalstoffenheffing" wordt een directe belasting geheven als bedoeld inartikel 15.33 van de Wet milieubeheer;artikel 15.33 van de Wet milieubeheer; de afvalstoffenheffing als bedoeld in deze verordening en de daarbij behorende tarieventabel wordt naar afzonderlijke grondslagen geheven ter zake van het feitelijk gebruik van een perceel ten aanzien waarvan krachtensartikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van huishoudelijke afvalstoffen geldt.artikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van huishoudelijke afvalstoffen geldt.""")
spacy.displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Onder de naam &quot;afvalstoffenheffing&quot; wordt een
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     directe belasting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ_N</span>
# </mark>
#  geheven als bedoeld inartikel 15.33 van de Wet milieubeheer;artikel 15.33 van de Wet milieubeheer; de afvalstoffenheffing als bedoeld in deze verordening en de daarbij behorende tarieventabel wordt naar
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     afzonderlijke grondslagen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ_N</span>
# </mark>
#  geheven ter zake van het
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     feitelijk gebruik
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ_N</span>
# </mark>
#  van een perceel ten aanzien waarvan krachtensartikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     huishoudelijke afvalstoffen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ_N</span>
# </mark>
#  geldt.artikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     huishoudelijke afvalstoffen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ADJ_N</span>
# </mark>
#  geldt.</div></span>

# %%
# using SpanRuler and its visualization instead:
dutch_with_sr  = spacy.load('nl_core_news_lg')
ruler = dutch_with_sr.add_pipe("span_ruler")
ruler.add_patterns( [ {'label':'ADJ_N',  "pattern":[  {"POS":"ADJ",  "OP":"+"},  {"POS":{"IN":["NOUN","PROPN"]} }  ],} ] )

doc = dutch_with_sr("""Onder de naam "afvalstoffenheffing" wordt een directe belasting geheven als bedoeld inartikel 15.33 van de Wet milieubeheer;artikel 15.33 van de Wet milieubeheer; de afvalstoffenheffing als bedoeld in deze verordening en de daarbij behorende tarieventabel wordt naar afzonderlijke grondslagen geheven ter zake van het feitelijk gebruik van een perceel ten aanzien waarvan krachtensartikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van huishoudelijke afvalstoffen geldt.artikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van huishoudelijke afvalstoffen geldt.""")
doc.spans

spacy.displacy.render(doc, style='span', options={"spans_key":"ruler"}, jupyter=True) # we have to tell it which source of spans we want; SpanRuler uses 'ruler'
# Out:
# <span class="tex2jax_ignore"><div class="spans" style="line-height: 2.5; direction: ltr">Onder de naam &quot; afvalstoffenheffing &quot; wordt een
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     directe
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ADJ_N
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     belasting
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# geheven als bedoeld inartikel 15.33 van de Wet milieubeheer;artikel 15.33 van de Wet milieubeheer ; de afvalstoffenheffing als bedoeld in deze verordening en de daarbij behorende tarieventabel wordt naar
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     afzonderlijke
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ADJ_N
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     grondslagen
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# geheven ter zake van het
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     feitelijk
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ADJ_N
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     gebruik
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# van een perceel ten aanzien waarvan krachtensartikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     huishoudelijke
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ADJ_N
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     afvalstoffen
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# geldt.artikel 10.21en10.22 van de Wet milieubeheereen verplichting tot het inzamelen van
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     huishoudelijke
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         ADJ_N
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     afvalstoffen
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# </span>
# geldt . </div></span>

# %% [markdown]
# <!--
# #### Manually
#
# When you have specific things you want to do, you might get more creative with code.
#
# Say, "I want only adjective-noun pairs from the sentences that mention appellant(/e/es), and want to count how of they they occur":
#
# count = collections.defaultdict(int)
# for text in some_rechtspraak_text:
#     doc = dutch( text )
#     for sent in doc.sents:
#         if not 'appellant' in sent.text.lower():
#             continue
#         for _, start_i, end_i in matcher( sent ):
#             count[ sent[ start_i : end_i ].text.strip() ] += 1
#
# for str, count in sorted( count.items(), key=lambda x:x[1], reverse=True):
#     print( f'{count:5d}  {str}')
#     #if count<3:
#     #    break
# -->

# %% [markdown]
# ### Making life a little easier?
#
# These rules are... verbose.   They are not fun to write, so don't exactly invite working on improving them.
#
# Could we make our own little rule system to make that less typing?
#
# Yes, though there are some very real limitations to doing this:
# - it's shorter, but it's also another thing to learn
# - it's just for simpler patterns
#
# Such experiments are easily _less_ expressive, and it does _not_ allow everything that you can specify at spacy level.
#
# ...but it could be nice to do some quick tests.

# %%
_pats = {
        'DET':        [{'POS':'DET', 'OP':'+'}],
        'DPN':        [{'POS':'DET', 'OP':'*'}, {'POS':'PRON', 'OP':'*'}, {"POS": {"REGEX": "(NOUN|PROPN)"}}],
        'ADJN':       [{'POS':'DET', 'OP':'*'}, {'POS':'ADJ', 'OP':'*'}, {"POS": {"REGEX": "(NOUN|PROPN)"}}],
        'ADJ':        [{'POS':'ADJ', 'OP':'+'}],
        'V':          [{"POS": {"IN": ["VERB", "AUX"]}}],   # or perhaps [{"POS": {"REGEX": "(VERB|AUX)"}}],
        'ANYPLUS':    [{'OP':'+'}],     # any token, one  or more times
        'ANYMAX7':    [{'OP':'{1,7}'}], # any token, one to seven times
        'ANYSTAR':    [{'OP':'*'}],     # any token, zero or more times
        'DATELIKE':   [{"LIKE_NUM": True}, {"POS": "PROPN"}, {"LIKE_NUM": True}],
        'LEGALEVENT': [{"LOWER":   {"IN":["verordening", "exploot", "uitspraak", "arrest", "tussenarrest", "beschikking", "besluit", "uitspraak", "vonnis", "hoger beroep"]}}]
    }

def expand_pats(patstring):
    """ Takes a singular string with some specific pattern names,
        Returns a spacy pattern that has expanded those pattern names to  actual patterns,
        e.g.:: 
            'behandeld op DATELIKE' 
        becomes::
            [{'LOWER': 'behandeld'}, {'LOWER': 'op'}, {'LIKE_NUM': True}, {'POS': 'PROPN'}, {'LIKE_NUM': True}]

        Just a makeshift experiment to see how useful this idea can be.
        The existing patterns are uppercased to make it less likely to clash with a literal word.
        
        To see how this is intended to be used, see the creation of the Matcher below this definition 
    """
    ret = []
    for part in patstring.split():
        if part == part.lower():
            # not a pattern - match literally, lowercase.
            #   in theory we could also normalize that to use LEMMA, and catch inflections
            ret.append( {'LOWER':part} )  
        else:
            if part in _pats:
                ret.extend( _pats[part] )
            else:
                print('Do not know pattern %r'%part)
    return ret

# %%
import spacy
from spacy.matcher import Matcher
dutch  = spacy.load('nl_core_news_lg')

matcher = Matcher(dutch.vocab)

# for comparison, first add one rule with spacy's own style
# to express   deze|dit verordening|uitspraak|arrrest|beschilling|vonnis bunch-of-words date-like thing
#    (...which is actually necessary for this nontrivial, fairly restrictive pattern
matcher.add( 'deze v|u|a|b|v V', [ [
        {"LOWER":   {"IN":["deze", "dit"]}},
        {"LOWER":   {"IN":["verordening", "uitspraak", "arrest", "beschikking", "vonnis"]}},
        {"POS": {"IN":["VERB","AUX"]} },
        {'OP':'+'}, # any token, one or more
        {"LIKE_NUM": True}, {"POS": "PROPN"}, {"LIKE_NUM": True} # date-like
],] )

# ...and then a bunch with our style  
#    (which are expanded to spacy's; lowercase means words to match, uppercase means a thing that expand_pats probably expands)
for pat in (
        'behandeld op DATELIKE',
        'uitgesproken ANYSTAR op DATELIKE',
        'uitgesproken ANYSTAR van DATELIKE',
        'LEGALEVENT openbaar ANYPLUS uitgesproken',
        'LEGALEVENT van ANYMAX7 DATELIKE',

        'aan de hand van het ADJN',
        'aan de hand van de ADJN',
        'volgens ADJN',
        'gelet op de ADJN',
        
        'heeft ANYPLUS bezwaar',
        'heeft ANYPLUS verklaard',
        'heeft ANYPLUS gekeerd',
        'geconcludeerd tot DPN',
        'is ANYPLUS ingesteld',

        'proceskosten',

        'DPN gelast',
        'DPN benoemd',
        'DPN geformuleerd',
        
        'ADJN heeft V dat',
        'zou zijn V door',
        'gaat ADJN uit van',
        'ADJN concludeert',
        'ADJN voert verweer',
        #vernietigt 
        'verwijst nar DPN',
        'veroordeelt ANYPLUS tot DPN',
        'verklaart ANYPLUS ongegrond',
        'verklaart ANYPLUS gegrond',
        'verklaart ANYPLUS uitvoerbaar',
        'verklaart ANYSTAR dat ANYPLUS verschuldigt', 
        #'ADJ rechten',
        
    ):
    ep = expand_pats(pat)
    matcher.add( pat, [ep] )

# %%
import wetsuite.datasets
import re
# Okay, now run that on some actual data - specifically some court cases
for case in wetsuite.datasets.load('rechtspraaknl-struc').data.random_values( 25 ):
    print( 'In document', case['identifier'])

    bodytext = case.get('bodytext')
    bodytext = bodytext.replace('[','').replace(']','') # aimed at quick and dirty removal of bracket from e.g. [eiseres]
    doc = dutch( bodytext )

    for sent in doc.sents:
        senttext = re.sub('\s+',' ',sent.text) # mostly for our own output, parsing doesn't care so much.
        for match_id, start, end in matcher( sent ):
            match_str = dutch.vocab.strings[match_id]  # Get string representation, seems to point out the pattern name is added to the vocab too, presumably to have an integer-only representation?
            match_span = sent[start:end]  # The matched span
            print(f"  pattern:{repr(match_str):35s} matches:  {repr(match_span.text):60s} in {repr(senttext)}")    
#            print(f"  in sentence:   ")
# Out:
# In document ECLI:NL:GHAMS:2020:507
#   pattern:'LEGALEVENT van ANYMAX7 DATELIKE'   matches:  'beschikking van de kantonrechter in de rechtbank Amsterdam van 7 september 2018' in '1 Procesverloop appellanten zijn bij beroepschrift, ingekomen bij de griffie van het hof op 7 december 2018, in hoger beroep gekomen van een beschikking van de kantonrechter in de rechtbank Amsterdam van 7 september 2018, in deze zaak onder vermelding van bovengenoemd zaaknummer gegeven tussen appellanten als verzoekers en de VvE als verweerster. '
#   pattern:'volgens ADJN'                      matches:  'volgens ieders respectievelijk breukdeel'                   in 'Bij het beroepschrift hebben appellanten acht grieven (waarvan één grief abusievelijk ongenummerd is gebleven) aangevoerd, hun oorspronkelijke verzoek gewijzigd en geconcludeerd, kort gezegd, dat het hof de bestreden beschikking zal vernietigen en hun vervangende machtiging in de zin van artikel 5:121 BW zal verlenen om ten laste van de VvE over te gaan tot primair het aanbrengen van een zelfdragende waterdichte betonnen kelderbak binnen de bestaande constructie op de wijze als omschreven in het deskundigenrapport onder ‘optie 2’ en subsidiair het aanbrengen van een bekuiping en injectie op de voorwaarden die het hof juist acht (waaronder verstrekking van deugdelijke garanties alsmede verzekering voor vervolgschade), alsmede op de voet van artikel 5:121 lid 2 BW zal bepalen dat de eigenaren volgens ieders respectievelijk breukdeel zullen bijdragen in de kosten, met veroordeling van de VvE in de proceskosten van beide instanties, de kosten van het deskundigenrapport daaronder begrepen, voorts zal bepalen dat de VvE de door appellanten reeds betaalde proceskosten zal restitueren en ten slotte zal bepalen dat appellanten binnen de VvE niet zal behoeven bij te dragen in de kostenveroordeling. '
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'Bij het beroepschrift hebben appellanten acht grieven (waarvan één grief abusievelijk ongenummerd is gebleven) aangevoerd, hun oorspronkelijke verzoek gewijzigd en geconcludeerd, kort gezegd, dat het hof de bestreden beschikking zal vernietigen en hun vervangende machtiging in de zin van artikel 5:121 BW zal verlenen om ten laste van de VvE over te gaan tot primair het aanbrengen van een zelfdragende waterdichte betonnen kelderbak binnen de bestaande constructie op de wijze als omschreven in het deskundigenrapport onder ‘optie 2’ en subsidiair het aanbrengen van een bekuiping en injectie op de voorwaarden die het hof juist acht (waaronder verstrekking van deugdelijke garanties alsmede verzekering voor vervolgschade), alsmede op de voet van artikel 5:121 lid 2 BW zal bepalen dat de eigenaren volgens ieders respectievelijk breukdeel zullen bijdragen in de kosten, met veroordeling van de VvE in de proceskosten van beide instanties, de kosten van het deskundigenrapport daaronder begrepen, voorts zal bepalen dat de VvE de door appellanten reeds betaalde proceskosten zal restitueren en ten slotte zal bepalen dat appellanten binnen de VvE niet zal behoeven bij te dragen in de kostenveroordeling. '
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'Bij het beroepschrift hebben appellanten acht grieven (waarvan één grief abusievelijk ongenummerd is gebleven) aangevoerd, hun oorspronkelijke verzoek gewijzigd en geconcludeerd, kort gezegd, dat het hof de bestreden beschikking zal vernietigen en hun vervangende machtiging in de zin van artikel 5:121 BW zal verlenen om ten laste van de VvE over te gaan tot primair het aanbrengen van een zelfdragende waterdichte betonnen kelderbak binnen de bestaande constructie op de wijze als omschreven in het deskundigenrapport onder ‘optie 2’ en subsidiair het aanbrengen van een bekuiping en injectie op de voorwaarden die het hof juist acht (waaronder verstrekking van deugdelijke garanties alsmede verzekering voor vervolgschade), alsmede op de voet van artikel 5:121 lid 2 BW zal bepalen dat de eigenaren volgens ieders respectievelijk breukdeel zullen bijdragen in de kosten, met veroordeling van de VvE in de proceskosten van beide instanties, de kosten van het deskundigenrapport daaronder begrepen, voorts zal bepalen dat de VvE de door appellanten reeds betaalde proceskosten zal restitueren en ten slotte zal bepalen dat appellanten binnen de VvE niet zal behoeven bij te dragen in de kostenveroordeling. '
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'De VvE en belanghebbenden sub 2 en sub 3 hebben een verweerschrift, met producties, ingediend en geconcludeerd, kort gezegd, dat het hof bij beschikking, uitvoerbaar bij voorraad, de beschikking waarvan beroep zal bekrachtigen, met veroordeling van appellanten in de proceskosten, met nakosten en wettelijke rente.'
#   pattern:'DPN benoemd'                       matches:  'adviseur benoemd'                                           in 'In een eerdere procedure in 2012, die diverse geschillen betrof tussen appellanten enerzijds en de VvE en belanghebbenden sub 2 en sub 3 anderzijds, heeft de kantonrechter na een gezamenlijk verzoek van partijen, Y als bindend adviseur benoemd. (viii) '
#   pattern:'volgens ADJN'                      matches:  'volgens optie'                                              in 'Herstel volgens optie 2 levert gedurende lange tijd (>50 jaar)'
#   pattern:'volgens ADJN'                      matches:  'volgens optie'                                              in 'Herstel volgens optie 3 vergt aanzienlijk hogere kosten, maar levert een fundering op die gedurende lange tijd (>50 jaar)'
#   pattern:'volgens ADJN'                      matches:  'volgens Optie'                                              in 'appellanten hebben in eerste aanleg verzocht, kort gezegd, dat de kantonrechter vervangende machtiging verleent om de werkzaamheden te laten uitvoeren volgens Optie 2 uit het deskundigenrapport, door Van den Berg & Van Os, waarbij de kosten van de werkzaamheden voor rekening van de VvE komen, met uitzondering van de kosten van sloop (en opbouw) van het interieur van appellanten en de kosten die verband houden met het uitdiepen van de kelderbak, die eveneens voor rekening van appellanten dienen te komen.'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'De kantonrechter heeft bij de beschikking waarvan beroep, kort gezegd, het verzoek afgewezen en appellanten veroordeeld in de proceskosten.'
#   pattern:'volgens ADJN'                      matches:  'volgens ieders respectievelijk breukdeel'                   in 'appellanten hebben met hun verzoek tevens de in artikel 5:121 lid 2 BW besloten liggende vraag aan de orde gesteld in welke verhouding de appartementseigenaars in de kosten van uitvoering van optie 2 dienen bij te dragen, waarbij zij het standpunt innemen dat de eigenaren volgens ieders respectievelijk breukdeel ( belanghebbenden sub 2 en sub 3 voor 6/10 deel, zijzelf voor 4/10 deel) moeten bijdragen in die kosten.'
#   pattern:'volgens ADJN'                      matches:  'volgens het deskundigenrapport'                             in 'Die stuclaag is volgens het deskundigenrapport aanwezig geweest vanaf de bouw van het souterrain tot aan 1998, toen deze laag vermoedelijk gebreken vertoonde waardoor zich toen lekkages voordeden, wat de verkoper ( X ) aanleiding heeft gegeven tot het uitvoeren van herstel bestaande uit het verwijderen van de waterdichte stuclaag en het injecteren van de wanden.'
#   pattern:'volgens ADJN'                      matches:  'Volgens het deskundigenrapport'                             in 'Volgens het deskundigenrapport heeft dit herstel niet blijvend geleid tot een waterdichte constructie, zijn er, voor zover uit de beschikbare gegevens valt af te leiden, door appellanten geen aanpassingen uitgevoerd die van invloed zijn geweest op de lekkages – zodat het feit dat in opdracht van appellanten de muren van het souterrain in 2006, 2008 en 2010 zijn geïnjecteerd, in dit opzicht niet relevant is – en zal door het verwijderen van de kim/plint tussen april en juni 1998 de invloed van de lekkages sinds die tijd verder zijn toegenomen.'
#   pattern:'volgens ADJN'                      matches:  'volgens het deskundigenrapport'                             in 'Daarbij tekent het hof aan dat volgens het deskundigenrapport niet valt vast te stellen op welk tijdstip die kim/plint is verwijderd, al is er de verklaring van A dat dit per abuis is gebeurd door een bedrijf dat in opdracht van appellanten handelde.'
#   pattern:'volgens ADJN'                      matches:  'volgens het deskundigenrapport'                             in 'Die oorzaak is volgens het deskundigenrapport geweest het ontbreken van een waterdichte voorziening in de souterrainconstructie, het feit dat de vanaf de bouw aanwezige, waterdichte stuclaag op de wanden van het souterrain in 1998 vermoedelijk gebreken vertoonde, waardoor zich toen lekkages voordeden.'
#   pattern:'volgens ADJN'                      matches:  'volgens de VvE'                                             in 'Omdat het, ook volgens de VvE en belanghebbenden sub 2 en sub 3 , een gemeenschappelijk gedeelte van het pand betreft, zijn de kosten van onderhoud en herstel van de (waterdichtheid van de) wanden van het souterrain voor rekening van de gezamenlijke eigenaars, zodat de VvE hiervoor kan worden aangesproken.'
#   pattern:'volgens ADJN'                      matches:  'volgens ieders respectievelijk breukdeel'                   in 'Daarbij is het aan partijen zelf om te stellen en toe te lichten in welke verhouding zij als appartementseigenaars in de kosten van uitvoering van optie 2 dienen bij te dragen, waarbij zij onder meer dienen aan te geven op welke grond(en) en in hoeverre zou moeten worden afgeweken van het uitgangspunt (zie artikel 3 aanhef en sub a j▫ artikel 2 lid 3 van het toepasselijke Modelreglement 1983) dat de eigenaren volgens ieders respectievelijk breukdeel ( belanghebbenden sub 2 en sub 3 voor 6/10 deel, zijzelf voor 4/10 deel) moeten bijdragen in die kosten.'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 18 februari 2020'                           in 'D.J. van der Kwaak, M.A. Wabeke en E.M. Polak en door de rolraadsheer in het openbaar uitgesproken op 18 februari 2020. '
# In document ECLI:NL:GHLEE:2006:AV8708
#   pattern:'volgens ADJN'                      matches:  'Volgens de Tremanormen'                                     in 'Volgens de Tremanormen dient de behoefte van het kind te worden afgeleid uit de CBS-Nibud tabel met betrekking tot het eigen aandeel in de kosten van kinderen. 9.'
#   pattern:'volgens ADJN'                      matches:  'volgens het hof'                                            in 'Deze fictie brengt volgens het hof mee dat, anders dan de man stelt, het feit dat partijen niet meer samenwoonden ten tijde van de geboorte van de minderjarige, niet relevant is voor het bepalen van de behoefte van de minderjarige. 15.'
#   pattern:'aan de hand van de ADJN'           matches:  'aan de hand van de inkomens'                                in 'Gelet op het voorgaande acht het hof het redelijk om de behoefte van de minderjarige te bepalen aan de hand van de inkomens van beide partijen, ook nu partijen reeds vóór de geboorte van de minderjarige uit elkaar zijn gegaan. 17.'
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft ter zitting verklaard'                                in 'De man heeft ter zitting verklaard dat deze voorziening een aanvulling op zijn pensioen betreft.'
#   pattern:'gelet op de ADJN'                  matches:  'Gelet op de omstandigheid'                                  in 'Gelet op de omstandigheid dat de man blijkens de hiervoor weergegeven draagkrachtberekeningen de in de beschikking waarvan beroep vastgestelde bijdrage ad euro 300,- per maand kan betalen en nu uit de draagkrachtberekening van de vrouw d.d. 20 september 2004, die de man niet heeft weersproken, niet blijkt dat de draagkracht van de vrouw meer bedraagt dan de resterende behoefte van het kind per maand, zal voormelde bijdrage aan de man worden opgelegd en behoeft de draagkracht van de vrouw geen verdere behandeling. '
# In document ECLI:NL:RBGEL:2018:5765
#   pattern:'ADJN heeft V dat'                  matches:  'de artsen heeft meegedeeld dat'                             in 'Eén van de artsen heeft meegedeeld dat de toestand van eiser 1 na het weekeinde opnieuw zou worden beoordeeld.'
#   pattern:'ADJN heeft V dat'                  matches:  'artsen heeft meegedeeld dat'                                in 'Eén van de artsen heeft meegedeeld dat de toestand van eiser 1 na het weekeinde opnieuw zou worden beoordeeld.'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'zij partij zijn bij de geneeskundige behandelingsovereenkomst, tot het voortzetten van de behandelingsovereenkomst, op straffe van een in goede justitie te bepalen dwangsom, dan wel wordt de voorzieningenrechter verzocht een bepaalde termijn te stellen waarin de behandelingsovereenkomst nog moet worden voortgezet, met veroordeling van CWZ in de proceskosten.'
#   pattern:'ADJN voert verweer'                matches:  'CWZ voert verweer'                                          in 'CWZ voert verweer. 3.3. '
#   pattern:'volgens ADJN'                      matches:  'volgens vaste jurisprudentie'                               in 'De rechter kan dat oordeel volgens vaste jurisprudentie slechts marginaal toetsen.'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'eiser 1 zal als de in het ongelijk gestelde partij in de proceskosten worden veroordeeld.'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'De voorzieningenrechter 5.1. wijst de vorderingen af, 5.2. veroordeelt gezamenlijke eisers in de proceskosten, aan de zijde van CWZ tot op heden begroot op € 1.606,00, 5.3. veroordeelt gezamenlijke eisers in de na dit vonnis ontstane kosten, begroot op € 157,00 aan salaris advocaat, te vermeerderen, onder de voorwaarde dat gezamenlijke eisers niet binnen 14 dagen na aanschrijving aan het vonnis heeft voldaan en er vervolgens betekening van de uitspraak heeft plaatsgevonden, met een bedrag van € 82,00 aan salaris advocaat en de explootkosten van betekening van de uitspraak, 5.4. verklaart dit vonnis wat betreft de kostenveroordeling uitvoerbaar bij voorraad.'
#   pattern:'verklaart ANYPLUS uitvoerbaar'     matches:  'verklaart dit vonnis wat betreft de kostenveroordeling uitvoerbaar' in 'De voorzieningenrechter 5.1. wijst de vorderingen af, 5.2. veroordeelt gezamenlijke eisers in de proceskosten, aan de zijde van CWZ tot op heden begroot op € 1.606,00, 5.3. veroordeelt gezamenlijke eisers in de na dit vonnis ontstane kosten, begroot op € 157,00 aan salaris advocaat, te vermeerderen, onder de voorwaarde dat gezamenlijke eisers niet binnen 14 dagen na aanschrijving aan het vonnis heeft voldaan en er vervolgens betekening van de uitspraak heeft plaatsgevonden, met een bedrag van € 82,00 aan salaris advocaat en de explootkosten van betekening van de uitspraak, 5.4. verklaart dit vonnis wat betreft de kostenveroordeling uitvoerbaar bij voorraad.'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. D.M.I. de Waele en in het openbaar uitgesproken op \n17 december 2018' in 'Dit vonnis is gewezen door mr. D.M.I. de Waele en in het openbaar uitgesproken op 17 december 2018 in tegenwoordigheid van de griffier, terwijl de overwegingen waarop de beslissing stoelt afzonderlijk zijn vastgelegd op 8 januari 2019. '
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op \n17 december 2018 in tegenwoordigheid van de griffier, terwijl de overwegingen waarop de beslissing stoelt afzonderlijk zijn vastgelegd op 8 januari 2019' in 'Dit vonnis is gewezen door mr. D.M.I. de Waele en in het openbaar uitgesproken op 17 december 2018 in tegenwoordigheid van de griffier, terwijl de overwegingen waarop de beslissing stoelt afzonderlijk zijn vastgelegd op 8 januari 2019. '
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. D.M.I. de Waele en in het openbaar uitgesproken op \n17 december 2018 in tegenwoordigheid van de griffier, terwijl de overwegingen waarop de beslissing stoelt afzonderlijk zijn vastgelegd op 8 januari 2019' in 'Dit vonnis is gewezen door mr. D.M.I. de Waele en in het openbaar uitgesproken op 17 december 2018 in tegenwoordigheid van de griffier, terwijl de overwegingen waarop de beslissing stoelt afzonderlijk zijn vastgelegd op 8 januari 2019. '
# In document ECLI:NL:RBROT:2021:9079
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft verweerder het bezwaar'                               in 'heeft verweerder het bezwaar van eiser tegen zijn brief van 14 mei 2020 niet-ontvankelijk verklaard. '
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft verweerder het bezwaar van eiser tegen zijn brief van 14 mei 2020 niet-ontvankelijk verklaard' in 'heeft verweerder het bezwaar van eiser tegen zijn brief van 14 mei 2020 niet-ontvankelijk verklaard. '
#   pattern:'gelet op de ADJN'                  matches:  'Gelet op de competentieregeling'                            in 'Gelet op de competentieregeling (artikel 8:7, eerste lid, van de Awb) bestaat geen aanleiding dit verzoek te honoreren. 3.'
#   pattern:'gelet op de ADJN'                  matches:  'Gelet op de betaling'                                       in 'Gelet op de betaling van het griffierecht is het beroep niet reeds niet-ontvankelijk vanwege het verzuim het griffierecht binnen de gestelde termijn te voldoen (artikel 8:41, zesde lid, van de Awb).'
# In document ECLI:NL:RBNNE:2021:4672
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen naar aanleiding van het onderzoek ter terechtzitting van 11 oktober 2021' in 'Dit vonnis is gewezen naar aanleiding van het onderzoek ter terechtzitting van 11 oktober 2021.'
#   pattern:'ADJN heeft V dat'                  matches:  'De raadsman heeft bepleit dat'                              in 'De raadsman heeft bepleit dat sprake is van een onherstelbaar vormverzuim ex artikel 359a van het Wetboek van Strafvordering (Sv).'
#   pattern:'ADJN heeft V dat'                  matches:  'raadsman heeft bepleit dat'                                 in 'De raadsman heeft bepleit dat sprake is van een onherstelbaar vormverzuim ex artikel 359a van het Wetboek van Strafvordering (Sv).'
#   pattern:'LEGALEVENT van ANYMAX7 DATELIKE'   matches:  'uitspraak van het HvJ EU van 2 maart 2021'                  in 'Het oordeel van de rechtbank Uit de uitspraak van het HvJ EU van 2 maart 2021 in de zaak Prokuratuur (ECLI:EU:C:2021:152) volgt - kort gezegd en voor zover hier van belang - dat voor het opvragen van historische verkeersgegevens van de telecomgegevens van de verdachte een voorafgaande onafhankelijke rechterlijke toetsing nodig is. '
#   pattern:'ADJN heeft V dat'                  matches:  'Verdachte heeft verklaard dat'                              in 'Verdachte heeft verklaard dat hij degene is die door medeverdachten medeverdachte 1 en medeverdachte 2 “ verdachte ” en “ verdachte ” wordt genoemd.'
#   pattern:'ADJN heeft V dat'                  matches:  'het verweer heeft gevoerd dat'                              in 'Voor zover de raadsman van verdachte het verweer heeft gevoerd dat uit de bewijsmiddelen niet kan volgen dat sprake is geweest van diefstal van elektriciteit, overweegt de rechtbank dat uit de inhoud van het proces-verbaal aantreffen hennepkwekerij alsmede de aangifte van benadeelde partij volgt dat de zekeringen die in de meterkast zaten waren gemanipuleerd, waardoor er meer stroom afgenomen kon worden ten behoeve van de hennepkwekerij. '
#   pattern:'ADJN heeft V dat'                  matches:  'verweer heeft gevoerd dat'                                  in 'Voor zover de raadsman van verdachte het verweer heeft gevoerd dat uit de bewijsmiddelen niet kan volgen dat sprake is geweest van diefstal van elektriciteit, overweegt de rechtbank dat uit de inhoud van het proces-verbaal aantreffen hennepkwekerij alsmede de aangifte van benadeelde partij volgt dat de zekeringen die in de meterkast zaten waren gemanipuleerd, waardoor er meer stroom afgenomen kon worden ten behoeve van de hennepkwekerij. '
#   pattern:'volgens ADJN'                      matches:  'volgens een vast patroon'                                   in 'Het is een feit van algemene bekendheid dat het stroomgebruik ten behoeve van een hennepkwekerij volgens een vast patroon verloopt.'
#   pattern:'gelet op de ADJN'                  matches:  'gelet op de aard'                                           in 'Iets anders laat zich moeilijk voorstellen gelet op de aard van deze stoffen en goederen en de aantallen waarin zij bij bedrijf 1 zijn aangetroffen. '
#   pattern:'ADJN heeft V dat'                  matches:  'Verdachte heeft verklaard dat'                              in 'Verdachte heeft verklaard dat hij eigenaar is van de bedrijf 1 en dat hij daar werknemer en directeur tegelijk was.'
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft verdachte verklaard'                                  in 'Daarnaast heeft verdachte verklaard dat een tweetal dames, te weten naam 7 en naam 8 , werkzaamheden voor hem verrichtten in de bedrijf 1 en dat zij hem hielpen met de online verkoop en de administratie.'
#   pattern:'ADJN heeft V dat'                  matches:  'justitie heeft gevorderd dat'                               in 'De officier van justitie heeft gevorderd dat verdachte ter zake van de feiten 1, 2, 4, 5, 6, 7 en 8 wordt veroordeeld tot een onvoorwaardelijke gevangenisstraf voor de duur van 3 jaren, met aftrek van de tijd die verdachte reeds in voorarrest heeft doorgebracht. '
#   pattern:'gelet op de ADJN'                  matches:  'gelet op de verdenking'                                     in 'Mocht de rechtbank desondanks oordelen dat het voorarrest en de verbeurdverklaring van de winkelvoorraad onvoldoende passend is gelet op de verdenking en de overige omstandigheden die in aanmerking moeten worden genomen, verzoekt de raadsman bovenop de reeds uitgezeten gevangenisstraf een voorwaardelijke straf op te leggen, zonder bijzondere voorwaarden. '
#   pattern:'ADJN heeft V dat'                  matches:  'herhaling heeft meegedeeld dat'                             in 'Voorts heeft de rechtbank kennis genomen van voornoemde rapportages van de Reclassering Nederland waaruit - onder meer - volgt dat het risico op recidive wordt ingeschat als laag-gemiddeld en dat verdachte bij herhaling heeft meegedeeld dat hij niet bereid is mee te werken aan reclasseringstoezicht. '
#   pattern:'gelet op de ADJN'                  matches:  'Gelet op de uitspraakdatum'                                 in 'Gelet op de uitspraakdatum in de strafzaak tegen verdachte, concludeert de rechtbank dat de redelijke termijn met bijna 4 maanden is overschreden.'
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft zich op het standpunt gesteld dat de vordering tot schadevergoeding niet ontvankelijk dient te worden verklaard' in 'De officier van justitie heeft zich op het standpunt gesteld dat de vordering tot schadevergoeding niet ontvankelijk dient te worden verklaard, omdat de medeverdachten medeverdachte 1 en medeverdachte 2 reeds bevrijdend hebben betaald aan benadeelde partij Standpunt van de verdediging '
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'De rechtbank zal bepalen dat de benadeelde partij de eigen (buiten)gerechtelijke kosten (WIK en proceskosten) draagt.'
#   pattern:'ADJN heeft V dat'                  matches:  'justitie heeft gevorderd dat'                               in 'De officier van justitie heeft gevorderd dat alle op de lijst van inbeslaggenomen voorwerpen d.d. 7 oktober 2021 vermelde goederen (hierna: de beslaglijst, welke als bijlage 1 aan dit vonnis is gehecht) worden onttrokken aan het verkeer.'
#   pattern:'gelet op de ADJN'                  matches:  'gelet op de bepleite vrijspraak'                            in 'Met betrekking tot het op de beslaglijst onder 10 genoemde goed (de inventaris van de bedrijf 1 ) heeft de raadsman zich primair op het standpunt gesteld dat het beslag dient te worden opgeheven, gelet op de bepleite vrijspraak voor feit 4.'
#   pattern:'gelet op de ADJN'                  matches:  'gelet op de artikelen'                                      in 'De rechtbank heeft gelet op de artikelen 36b, 36d, 36e, 47, 57, 311 van het Wetboek van Strafrecht, de artikelen 3, 11, 11a, 13a van de Opiumwet en de artikelen 26 en 55 van de Wet wapens en munitie. '
#   pattern:'deze v|u|a|b|v V'                  matches:  'dit vonnis gehechte lijst van inbeslaggenomen goederen d.d. 16 juli 2019' in 'de onttrekking aan het verkeer van de voorwerpen die op de aan dit vonnis gehechte lijst van inbeslaggenomen goederen d.d. 16 juli 2019 onder bijlage 2 zijn genummerd: '
#   pattern:'deze v|u|a|b|v V'                  matches:  'dit vonnis gehechte lijst van inbeslaggenomen goederen d.d. 16 juli 2019' in 'de teruggave aan verdachte, voor zover toebehorende en nog niet teruggegeven aan verdachte, van de voorwerpen die op de aan dit vonnis gehechte lijst van inbeslaggenomen goederen d.d. 16 juli 2019 onder bijlage 2 zijn genummerd: '
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken ter openbare terechtzitting van deze rechtbank op 2 november 2021' in 'tot en met Pand B.07.002 Dit vonnis is gewezen door mr. G. Eelsing, voorzitter, mr. R. Depping en mr. M.A.M. Wolters, rechters, bijgestaan door mr. H. Wachtmeester-Koning, griffier, en uitgesproken ter openbare terechtzitting van deze rechtbank op 2 november 2021. '
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. G. Eelsing, voorzitter, mr. R. Depping en mr. M.A.M. Wolters, rechters, bijgestaan door mr. H. Wachtmeester-Koning, griffier, en uitgesproken ter openbare terechtzitting van deze rechtbank op 2 november 2021' in 'tot en met Pand B.07.002 Dit vonnis is gewezen door mr. G. Eelsing, voorzitter, mr. R. Depping en mr. M.A.M. Wolters, rechters, bijgestaan door mr. H. Wachtmeester-Koning, griffier, en uitgesproken ter openbare terechtzitting van deze rechtbank op 2 november 2021. '
# In document ECLI:NL:RBAMS:2004:AR5604
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft ter zitting verklaard'                                in 'De opgeëiste persoon heeft ter zitting verklaard dat de bovenvermelde personalia juist zijn en dat hij niet de Nederlandse, maar de Litouwse nationaliteit heeft. '
#   pattern:'uitgesproken ANYSTAR van DATELIKE' matches:  'uitgesproken ter openbare zitting van 5 november 2004'      in 'L.E. Kalff en S.K. de Groot, rech-ters, in tegenwoordigheid van mr. M.M. Boyer, grif-fier, en uitgesproken ter openbare zitting van 5 november 2004. '
# In document ECLI:NL:CBB:2011:BR6671
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft Tele2 op 29 juli 2011 bezwaar'                        in 'Tegen dit besluit heeft Tele2 op 29 juli 2011 bezwaar gemaakt. '
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft Tele2 de voorzieningenrechter verzocht om een voorlopige voorziening te treffen, inhoudende dat OPTA binnen zes weken na de indiening van het bezwaarschrift als bedoeld in artikel 7:10 van de Algemene wet bestuursrecht (hierna: Awb) een beslissing op bezwaar' in 'Daarnaast heeft Tele2 de voorzieningenrechter verzocht om een voorlopige voorziening te treffen, inhoudende dat OPTA binnen zes weken na de indiening van het bezwaarschrift als bedoeld in artikel 7:10 van de Algemene wet bestuursrecht (hierna: Awb) een beslissing op bezwaar dient te nemen zonder gebruik te maken van de mogelijkheid om die beslissing te verdagen en voorts dat OPTA KPN gelast om hangende de bezwaarprocedure haar inschrijving voor het cluster'
#   pattern:'DPN gelast'                        matches:  'KPN gelast'                                                 in 'Daarnaast heeft Tele2 de voorzieningenrechter verzocht om een voorlopige voorziening te treffen, inhoudende dat OPTA binnen zes weken na de indiening van het bezwaarschrift als bedoeld in artikel 7:10 van de Algemene wet bestuursrecht (hierna: Awb) een beslissing op bezwaar dient te nemen zonder gebruik te maken van de mogelijkheid om die beslissing te verdagen en voorts dat OPTA KPN gelast om hangende de bezwaarprocedure haar inschrijving voor het cluster'
#   pattern:'ADJN heeft V dat'                  matches:  'Tele2 heeft betoogd dat'                                    in 'Tele2 heeft betoogd dat OPTA het bestreden besluit ten onrechte heeft gebaseerd op de laatste door KPN uitgevoerde berekening van 14 december 2010.'
#   pattern:'ADJN heeft V dat'                  matches:  'Tele2 heeft betoogd dat'                                    in '3.3.3 Tele2 heeft betoogd dat OPTA de toets aan gedragsregel 5 ten onrechte heeft toegepast op het niveau van de volledige door KPN aan OT2010 gedane aanbieding, in plaats van te onderkennen dat elke afzonderlijke aan OT2010 geoffreerde dienst op zichzelf aan gedragsregel 5 dient te voldoen. '
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 5 september 2011'           in 'Aldus gewezen door mr. C.M. Wolters, in tegenwoordigheid van mr. G.D. Kleijne als griffier, en uitgesproken in het openbaar op 5 september 2011. '
# In document ECLI:NL:RBNHO:2019:4239
#   pattern:'DPN benoemd'                       matches:  'curator benoemd'                                            in '2.3 Bij (tussen)beschikking van 18 december 2018 heeft de kinderrechter een bijzondere curator benoemd en haar verzocht om, aan de hand van een aantal vragen, een standpunt in te nemen over het verzoek van de GI om de uithuisplaatsing van minderjarige te verlengen.'
#   pattern:'volgens ADJN'                      matches:  'volgens alle hulpverleners'                                 in 'De vader vormt hierin (volgens alle hulpverleners) een beschermende factor.'
#   pattern:'volgens ADJN'                      matches:  'volgens de bijzondere curator'                              in 'De thuisplaatsing is volgens de bijzondere curator een authentieke wens van minderjarige .'
#   pattern:'volgens ADJN'                      matches:  'Volgens de GI'                                              in 'Volgens de GI is de moeder vanwege haar persoonlijke problematiek, beperkte draagkracht en leerbaarheid, onvoldoende in staat om de dagelijkse verzorging en opvoeding van minderjarige op zich te nemen.'
#   pattern:'volgens ADJN'                      matches:  'volgens de bijzondere curator'                              in 'De zorgen die er zijn, zijn eenvoudig weg te nemen volgens de bijzondere curator.'
#   pattern:'gelet op de ADJN'                  matches:  'gelet op de zorgen'                                         in ' 2.13 De kinderrechter vindt, gelet op de zorgen en het afbreukrisico, een (acute) terugplaatsing van minderjarige bij haar ouders niet in haar belang.'
#   pattern:'verklaart ANYPLUS uitvoerbaar'     matches:  'verklaart deze beschikking uitvoerbaar'                     in 'De kinderrechter: - verlengt de machtiging tot uithuisplaatsing van minderjarige , geboren op geboortedatum te plaats , in een voorziening voor pleegzorg, tot uiterlijk 5 juli 2019; - verklaart deze beschikking uitvoerbaar bij voorraad; - ontslaat bijzondere curator van haar taak als bijzondere curator.'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 26 april 2019'                              in 'Deze beschikking is gegeven door mr. G. Drenth, kinderrechter, in tegenwoordigheid van T.B.A. Verbeij als griffier en in het openbaar uitgesproken op 26 april 2019. '
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze beschikking is gegeven door mr. G. Drenth, kinderrechter, in tegenwoordigheid van T.B.A. Verbeij als griffier en in het openbaar uitgesproken op 26 april 2019' in 'Deze beschikking is gegeven door mr. G. Drenth, kinderrechter, in tegenwoordigheid van T.B.A. Verbeij als griffier en in het openbaar uitgesproken op 26 april 2019. '
#   pattern:'deze v|u|a|b|v V'                  matches:  'deze beschikking is vastgesteld op 16 mei 2019'             in 'De schriftelijke uitwerking van deze beschikking is vastgesteld op 16 mei 2019. '
# In document ECLI:NL:HR:2017:1348
#   pattern:'geconcludeerd tot DPN'             matches:  'geconcludeerd tot verwerping'                               in 'KPMG heeft geconcludeerd tot verwerping van het beroep. '
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit arrest is gewezen door de raadsheren A.M.J. van Buchem-Spapens, als voorzitter, A.H.T. Heisterkamp en C.E. du Perron, en in het openbaar uitgesproken door de raadsheer G. de Groot op\n\n14 juli 2017' in 'Dit arrest is gewezen door de raadsheren A.M.J. van Buchem-Spapens, als voorzitter, A.H.T. Heisterkamp en C.E. du Perron, en in het openbaar uitgesproken door de raadsheer G. de Groot op 14 juli 2017 . '
# In document ECLI:NL:GHSHE:2022:4458
#   pattern:'is ANYPLUS ingesteld'              matches:  'is tegen voormeld vonnis hoger beroep ingesteld'            in 'Van de zijde van de verdachte is tegen voormeld vonnis hoger beroep ingesteld. '
# In document ECLI:NL:RBROT:2021:3621
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft verweerder het bezwaar'                               in 'Bij besluit van 7 september 2020 (het bestreden besluit) heeft verweerder het bezwaar van eiser tegen het primaire besluit ongegrond verklaard. '
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft verweerder het bezwaar van eiser tegen het primaire besluit ongegrond verklaard' in 'Bij besluit van 7 september 2020 (het bestreden besluit) heeft verweerder het bezwaar van eiser tegen het primaire besluit ongegrond verklaard. '
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft daartegen geen bezwaar'                               in 'Eiser werd immers conform schaal 7 bezoldigd, heeft daarvan, waaronder over de maand juli 2018, salarisstroken ontvangen en heeft daartegen geen bezwaar gemaakt.'
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft daarvan, waaronder over de maand juli 2018, salarisstroken ontvangen en heeft daartegen geen bezwaar' in 'Eiser werd immers conform schaal 7 bezoldigd, heeft daarvan, waaronder over de maand juli 2018, salarisstroken ontvangen en heeft daartegen geen bezwaar gemaakt.'
#   pattern:'volgens ADJN'                      matches:  'volgens het bestuursorgaan'                                 in 'Als er volgens het bestuursorgaan geen nieuw gebleken feiten of veranderde omstandigheden zijn, de herhaalde aanvraag of het verzoek om terug te komen met toepassing van artikel 4:6, tweede lid, van de Awb afwijzen onder verwijzing naar zijn eerdere afwijzende besluit. '
#   pattern:'ADJN heeft V dat'                  matches:  'het standpunt heeft gesteld dat'                            in 'Bij de tweede keuze wordt aan de hand van de aangevoerde gronden en het (eventueel) door het bestuursorgaan gevoerde beleid over de toepassing van artikel 4:6 van de Awb beoordeeld of het bestuursorgaan zich terecht op het standpunt heeft gesteld dat er geen nieuw gebleken feiten of veranderde omstandigheden zijn en of de afwijzing zorgvuldig is voorbereid en deugdelijk gemotiveerd is (CRvB 20 december 2016, ECLI:NL:'
#   pattern:'ADJN heeft V dat'                  matches:  'standpunt heeft gesteld dat'                                in 'Bij de tweede keuze wordt aan de hand van de aangevoerde gronden en het (eventueel) door het bestuursorgaan gevoerde beleid over de toepassing van artikel 4:6 van de Awb beoordeeld of het bestuursorgaan zich terecht op het standpunt heeft gesteld dat er geen nieuw gebleken feiten of veranderde omstandigheden zijn en of de afwijzing zorgvuldig is voorbereid en deugdelijk gemotiveerd is (CRvB 20 december 2016, ECLI:NL:'
#   pattern:'verklaart ANYPLUS ongegrond'       matches:  'verklaart het beroep ongegrond'                             in 'De rechtbank verklaart het beroep ongegrond.'
# In document ECLI:NL:GHSHE:2023:1603
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft het openbaar ministerie ontvankelijk verklaard'       in 'De rechtbank heeft het openbaar ministerie ontvankelijk verklaard in de vervolging van de aan de verdachte tenlastegelegde feiten.'
#   pattern:'is ANYPLUS ingesteld'              matches:  'is tegen voormeld vonnis hoger beroep ingesteld'            in 'Van de zijde van de verdachte is tegen voormeld vonnis hoger beroep ingesteld. '
#   pattern:'ADJN heeft V dat'                  matches:  'De advocaat-generaal heeft gevorderd dat'                   in 'De advocaat-generaal heeft gevorderd dat het hof het vonnis van de rechtbank zal bevestigen. '
#   pattern:'ADJN heeft V dat'                  matches:  'advocaat-generaal heeft gevorderd dat'                      in 'De advocaat-generaal heeft gevorderd dat het hof het vonnis van de rechtbank zal bevestigen. '
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft primair bepleit dat het openbaar ministerie niet-ontvankelijk zal worden verklaard' in 'De verdediging heeft primair bepleit dat het openbaar ministerie niet-ontvankelijk zal worden verklaard in de vervolging.'
#   pattern:'ADJN heeft V dat'                  matches:  'De verdediging heeft bepleit dat'                           in 'De verdediging heeft bepleit dat het openbaar ministerie niet-ontvankelijk dient te worden verklaard in de vervolging van de verdachte.'
#   pattern:'ADJN heeft V dat'                  matches:  'verdediging heeft bepleit dat'                              in 'De verdediging heeft bepleit dat het openbaar ministerie niet-ontvankelijk dient te worden verklaard in de vervolging van de verdachte.'
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft bepleit dat het openbaar ministerie niet-ontvankelijk dient te worden verklaard' in 'De verdediging heeft bepleit dat het openbaar ministerie niet-ontvankelijk dient te worden verklaard in de vervolging van de verdachte.'
#   pattern:'volgens ADJN'                      matches:  'Volgens rechtspraak'                                        in 'Volgens rechtspraak van de Hoge Raad is dat alleen onvoldoende om het openbaar ministerie niet-ontvankelijk te verklaren, maar meerdere feitenrechters hebben daar – mede gelet op bijkomende omstandigheden – inmiddels anders over geoordeeld.'
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft de advocaat-generaal zich op het standpunt gesteld dat het openbaar ministerie ontvankelijk dient te worden verklaard' in 'Ter terechtzitting in hoger beroep heeft de advocaat-generaal zich op het standpunt gesteld dat het openbaar ministerie ontvankelijk dient te worden verklaard in de vervolging van de verdachte.'
#   pattern:'is ANYPLUS ingesteld'              matches:  'is toegekend om zelfstandig te beslissen of naar aanleiding van een ingesteld' in 'Het hof stelt voorop dat in artikel 167, eerste lid, van het Wetboek van Strafvordering aan het openbaar ministerie de bevoegdheid is toegekend om zelfstandig te beslissen of naar aanleiding van een ingesteld opsporingsonderzoek (verdere) vervolging moet plaatsvinden.'
# In document ECLI:NL:RBMNE:2018:4078
#   pattern:'volgens ADJN'                      matches:  'Volgens de verwerkingsvoorschriften'                        in 'Volgens de verwerkingsvoorschriften diende bij het plaatsen van het isolatiemateriaal de verbindingen te worden afgeplakt met Isodhesif Laine-tape en moest aan de randen een omslag van minstens 5 cm worden gemaakt, hetgeen gedaagde niet heeft gedaan. 2.2. '
#   pattern:'ADJN heeft V dat'                  matches:  'De ongediertebestrijder heeft aangegeven dat'               in 'De ongediertebestrijder heeft aangegeven dat de schapenwol in de isolatie mogelijk de oorzaak was van de tapijtkevers. '
#   pattern:'ADJN heeft V dat'                  matches:  'ongediertebestrijder heeft aangegeven dat'                  in 'De ongediertebestrijder heeft aangegeven dat de schapenwol in de isolatie mogelijk de oorzaak was van de tapijtkevers. '
#   pattern:'volgens ADJN'                      matches:  'volgens de regels'                                          in 'Indien de Triso Laine is geplaatst volgens de regels van Actis kunnen de kevers niet via de isolatie zijn binnengedrongen daarenboven is de Triso Laine behandeld tegen insecten en ongedierte.'
#   pattern:'ADJN heeft V dat'                  matches:  'verder onderzoek heeft uitgewezen dat'                      in 'gedaagde heeft een stuk weggesneden en verder onderzoek heeft uitgewezen dat de kevers zich niet tegoed doen aan de Triso Laine wel aan andere vezels zoals tapijt, bont, kledij en schilderdoeken.'
#   pattern:'ADJN heeft V dat'                  matches:  'onderzoek heeft uitgewezen dat'                             in 'gedaagde heeft een stuk weggesneden en verder onderzoek heeft uitgewezen dat de kevers zich niet tegoed doen aan de Triso Laine wel aan andere vezels zoals tapijt, bont, kledij en schilderdoeken.'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'de proceskosten, te vermeerderen met de wettelijke rente.'
#   pattern:'gelet op de ADJN'                  matches:  'Gelet op de non-conformiteit'                               in 'Gelet op de non-conformiteit is de overeenkomst ontbonden, waardoor ongedaanmakingsverbintenissen zijn ontstaan.'
#   pattern:'volgens ADJN'                      matches:  'volgens eiser'                                              in 'Op dit bedrag strekt volgens eiser c.s. het door hem aan gedaagde betaalde bedrag van € 11.982,54 in mindering, zodat nog een schade van € 16.199,57 resteert. 3.3. '
#   pattern:'ADJN voert verweer'                matches:  'gedaagde voert verweer'                                     in 'gedaagde voert verweer.'
#   pattern:'volgens ADJN'                      matches:  'Volgens gedaagde'                                           in 'Volgens gedaagde heeft eiser c.s. niet tijdig geklaagd, omdat hij pas in 2016 melding heeft gemaakt van de tapijtkevers, terwijl deze zich volgens hem al eerder zouden moeten hebben gemanifesteerd, als het product gebrekkig was.'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 18 juli 2018'                               in 'Dit vonnis is gewezen door mr. M.J. Slootweg en in het openbaar uitgesproken op 18 juli 2018. type: SW 4247 coll: '
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. M.J. Slootweg en in het openbaar uitgesproken op 18 juli 2018' in 'Dit vonnis is gewezen door mr. M.J. Slootweg en in het openbaar uitgesproken op 18 juli 2018. type: SW 4247 coll: '
# In document ECLI:NL:RBZWB:2023:6495
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in '2.8 Gedaagde zal als de hoofdzakelijk in het ongelijk gestelde partij worden veroordeeld in de proceskosten, met dien verstande dat voor de akte na tussenvonnis geen salaris zal worden toegekend nu eiseres haar dagvaarding deugdelijk had moeten weergeven. '
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in '2.9 Gedaagde wordt als de in het ongelijk gestelde partij veroordeeld in de proceskosten aan de zijde van eiseres, tot op heden vastgesteld op: dagvaardingskosten'
#   pattern:'verklaart ANYPLUS uitvoerbaar'     matches:  'verklaart dit vonnis tot zover uitvoerbaar'                 in 'De kantonrechter: veroordeelt gedaagde om tegen behoorlijk bewijs van kwijting aan eiseres te betalen een bedrag van € 28,40; veroordeelt gedaagde in de kosten van dit geding, aan de zijde van eiseres tot op heden vastgesteld op € 274,84; verklaart dit vonnis tot zover uitvoerbaar bij voorraad; wijst het meer of anders gevorderde af.'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 13 september 2023'                          in 'Dit vonnis is gewezen door mr. Ponds, kantonrechter, en in het openbaar uitgesproken op 13 september 2023. '
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. Ponds, kantonrechter, en in het openbaar uitgesproken op 13 september 2023' in 'Dit vonnis is gewezen door mr. Ponds, kantonrechter, en in het openbaar uitgesproken op 13 september 2023. '
# In document ECLI:NL:RVS:2011:BQ9645
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft het college het namens MOB hiertegen gemaakte bezwaar' in 'Bij besluit van 16 februari 2010, kenmerk 2010INT256041, verzonden op 19 februari 2010, heeft het college het namens MOB hiertegen gemaakte bezwaar ongegrond verklaard. '
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft het college het namens MOB hiertegen gemaakte bezwaar ongegrond verklaard' in 'Bij besluit van 16 februari 2010, kenmerk 2010INT256041, verzonden op 19 februari 2010, heeft het college het namens MOB hiertegen gemaakte bezwaar ongegrond verklaard. '
#   pattern:'behandeld op DATELIKE'             matches:  'behandeld op 2 december 2010'                               in 'De Afdeling heeft de zaak ter zitting behandeld op 2 december 2010, waar MOB, vertegenwoordigd door mr. V. Wösten, en het college, vertegenwoordigd door mr. M. Uittenbosch en C.T. Zuidema, beiden werkzaam bij de provincie, zijn verschenen.'
#   pattern:'ADJN heeft V dat'                  matches:  'De Afdeling heeft bepaald dat'                              in 'De Afdeling heeft bepaald dat een nadere zitting achterwege blijft.'
#   pattern:'ADJN heeft V dat'                  matches:  'Afdeling heeft bepaald dat'                                 in 'De Afdeling heeft bepaald dat een nadere zitting achterwege blijft.'
#   pattern:'gelet op de ADJN'                  matches:  'gelet op de kritische depositiewaarde'                      in 'Verder heeft het college meegewogen dat de ammoniakdepositie op het te beschermen natuurgebied van 3,08 mol N/ha/jaar in de bestaande feitelijke situatie naar 4,79 mol N/ha/jaar gaat, welke vergunde depositiewaarde naar de mening van het college, gelet op de kritische depositiewaarde van 1100 mol N/ha/jaar en de achtergronddepositie van 1580 mol N/ha/jaar, als gering kan worden aangemerkt.'
#   pattern:'ADJN heeft V dat'                  matches:  'het standpunt heeft gesteld dat'                            in 'Zij voert verder aan dat de stelling van het college dat flankerend beleid tot een forse emissiereductie zal leiden ongefundeerd is en dat het college zich ten onrechte op het standpunt heeft gesteld dat geen extra maatregelen getroffen hoeven te worden ter bescherming van de schraallanden. 2.3.2.'
#   pattern:'ADJN heeft V dat'                  matches:  'standpunt heeft gesteld dat'                                in 'Zij voert verder aan dat de stelling van het college dat flankerend beleid tot een forse emissiereductie zal leiden ongefundeerd is en dat het college zich ten onrechte op het standpunt heeft gesteld dat geen extra maatregelen getroffen hoeven te worden ter bescherming van de schraallanden. 2.3.2.'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'Het college dient op na te melden wijze in de proceskosten te worden veroordeeld. 3.'
# ...
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken in het openbaar op 12 november 2019'           in 'De beslissing is uitgesproken in het openbaar op 12 november 2019. (getekend)'
# In document ECLI:NL:RBAMS:2018:4481
#   pattern:'ADJN voert verweer'                matches:  'EasyStaff voert verweer'                                    in 'EasyStaff voert verweer.'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'Het verzoek zal worden afgewezen en als de in het ongelijk gestelde partij zal verzoekster in de proceskosten worden veroordeeld.'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'BESLISSING De kantonrechter: wijst het verzoek af; veroordeelt verzoekster in de proceskosten, tot op heden aan de zijde van EasyStaff begroot op € 400,00 aan salaris gemachtigde; veroordeelt verzoekster tot betaling van een bedrag van € 50,00 aan nasalaris, te verhogen met een bedrag van € 68,00 onder de voorwaarde dat betekening van het vonnis heeft plaatsgevonden en verzoekster niet binnen 14 dagen na aanschrijving aan het vonnis heeft voldaan, een en ander voor zover van toepassing, inclusief btw; verklaart de proceskostenveroordelingen uitvoerbaar bij voorraad.'
#   pattern:'veroordeelt ANYPLUS tot DPN'       matches:  'veroordeelt verzoekster tot betaling'                       in 'BESLISSING De kantonrechter: wijst het verzoek af; veroordeelt verzoekster in de proceskosten, tot op heden aan de zijde van EasyStaff begroot op € 400,00 aan salaris gemachtigde; veroordeelt verzoekster tot betaling van een bedrag van € 50,00 aan nasalaris, te verhogen met een bedrag van € 68,00 onder de voorwaarde dat betekening van het vonnis heeft plaatsgevonden en verzoekster niet binnen 14 dagen na aanschrijving aan het vonnis heeft voldaan, een en ander voor zover van toepassing, inclusief btw; verklaart de proceskostenveroordelingen uitvoerbaar bij voorraad.'
#   pattern:'veroordeelt ANYPLUS tot DPN'       matches:  'veroordeelt verzoekster in de proceskosten, tot op heden aan de zijde van EasyStaff begroot op € 400,00 aan salaris gemachtigde;\n\nveroordeelt verzoekster tot betaling' in 'BESLISSING De kantonrechter: wijst het verzoek af; veroordeelt verzoekster in de proceskosten, tot op heden aan de zijde van EasyStaff begroot op € 400,00 aan salaris gemachtigde; veroordeelt verzoekster tot betaling van een bedrag van € 50,00 aan nasalaris, te verhogen met een bedrag van € 68,00 onder de voorwaarde dat betekening van het vonnis heeft plaatsgevonden en verzoekster niet binnen 14 dagen na aanschrijving aan het vonnis heeft voldaan, een en ander voor zover van toepassing, inclusief btw; verklaart de proceskostenveroordelingen uitvoerbaar bij voorraad.'
#   pattern:'verklaart ANYPLUS uitvoerbaar'     matches:  'verklaart de proceskostenveroordelingen uitvoerbaar'        in 'BESLISSING De kantonrechter: wijst het verzoek af; veroordeelt verzoekster in de proceskosten, tot op heden aan de zijde van EasyStaff begroot op € 400,00 aan salaris gemachtigde; veroordeelt verzoekster tot betaling van een bedrag van € 50,00 aan nasalaris, te verhogen met een bedrag van € 68,00 onder de voorwaarde dat betekening van het vonnis heeft plaatsgevonden en verzoekster niet binnen 14 dagen na aanschrijving aan het vonnis heeft voldaan, een en ander voor zover van toepassing, inclusief btw; verklaart de proceskostenveroordelingen uitvoerbaar bij voorraad.'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 27 juni 2018'                               in 'Deze beschikking is gegeven door mr. C.W. Inden, kantonrechter en in het openbaar uitgesproken op 27 juni 2018 in aanwezigheid van de griffier. '
#   pattern:'deze v|u|a|b|v V'                  matches:  'Deze beschikking is gegeven door mr. C.W. Inden, kantonrechter en in het openbaar uitgesproken op 27 juni 2018' in 'Deze beschikking is gegeven door mr. C.W. Inden, kantonrechter en in het openbaar uitgesproken op 27 juni 2018 in aanwezigheid van de griffier. '
# In document ECLI:NL:RBHAA:2007:BB2280
#   pattern:'LEGALEVENT van ANYMAX7 DATELIKE'   matches:  'beschikking van de rechtbank Utrecht d.d. 11 april 2007'    in 'Bij beschikking van de rechtbank Utrecht d.d. 11 april 2007 is op verzoek van na te melden vereffenaar de heropening bevolen van de vereffening van de besloten vennootschap met beperkte aansprakelijkheid Coxon Consultancy & Services B.V. met benoeming van Guillaume Elisabeth Gustave Cox tot vereffenaar. 3. '
#   pattern:'geconcludeerd tot DPN'             matches:  'geconcludeerd tot afwijzing'                                in 'Coxon heeft geconcludeerd tot afwijzing van de voormelde vordering van InterXion, met haar veroordeling in de kosten van het incident, zulks uitvoerbaar bij voorraad.'
#   pattern:'volgens ADJN'                      matches:  'volgens de bepalingen'                                      in 'Nu uit het door InterXion overgelegde uittreksel uit het Handelsregister van InterXion blijkt dat haar statutaire zetel is gevestigd te Amsterdam en dat zij kantoor houdt op het adres Cessnalaan 1-33 te Schiphol-Rijk, welk laatstgenoemd adres is gelegen binnen het arrondissement Haarlem, terwijl de Coxon ingestelde vordering geen aangelegenheid betreft waarin volgens de bepalingen van het rechtspersonenrecht uitsluitend de rechter van de statutaire zetel bevoegd is, is deze rechtbank derhalve mede bevoegd van de vordering van Coxon kennis te nemen. '
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'Uit vorenstaande volgt dat de incidentele vorderingen van InterXion zullen worden afgewezen en dat InterXion als de in het ongelijk gestelde partij in de proceskosten van het incident zal worden veroordeeld. 4. '
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 18 juli 2007'                               in 'Dit vonnis is gewezen door mr. P.M. Wamsteker en in het openbaar uitgesproken op 18 juli 2007.?'
#   pattern:'deze v|u|a|b|v V'                  matches:  'Dit vonnis is gewezen door mr. P.M. Wamsteker en in het openbaar uitgesproken op 18 juli 2007' in 'Dit vonnis is gewezen door mr. P.M. Wamsteker en in het openbaar uitgesproken op 18 juli 2007.?'
# In document ECLI:NL:RVS:2017:2176
#   pattern:'LEGALEVENT van ANYMAX7 DATELIKE'   matches:  'uitspraak van de rechtbank Oost-Brabant van 19 januari 2017' in ', tegen de uitspraak van de rechtbank Oost-Brabant van 19 januari 2017 in zaak nr.'
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft de raad het door appellante daartegen gemaakte bezwaar' in 'Bij besluit van 14 juni 2016 heeft de raad het door appellante daartegen gemaakte bezwaar ongegrond verklaard. '
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft de raad het door appellante daartegen gemaakte bezwaar ongegrond verklaard' in 'Bij besluit van 14 juni 2016 heeft de raad het door appellante daartegen gemaakte bezwaar ongegrond verklaard. '
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft de rechtbank het door appellante daartegen ingestelde beroep ongegrond verklaard' in 'Bij uitspraak van 19 januari 2017 heeft de rechtbank het door appellante daartegen ingestelde beroep ongegrond verklaard.'
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft de raad bij formulier van 22 oktober 2015 verzocht een toevoeging voor gesubsidieerde rechtsbijstand door een advocaat te verlenen om bezwaar' in 'appellante heeft de raad bij formulier van 22 oktober 2015 verzocht een toevoeging voor gesubsidieerde rechtsbijstand door een advocaat te verlenen om bezwaar te kunnen maken tegen dit besluit. 2. '
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft verstrekt, dan wijs je de toevoegaanvraag voor het bezwaar' in 'Als uit de toevoegaanvraag blijkt dat de bijstandsuitkering op grond van de Participatiewet (voorheen Wet werk en bijstand) is afgewezen, buiten behandeling is gesteld of geschorst omdat rechtzoekende niet de gevraagde stukken/ informatie heeft verstrekt, dan wijs je de toevoegaanvraag voor het bezwaar af met tekstcode 130 (zelfredzaamheid).'
#   pattern:'heeft ANYPLUS bezwaar'             matches:  'heeft aan het besluit van 14 juni 2016 ten grondslag gelegd dat appellante zelfstandig bezwaar' in 'De raad heeft aan het besluit van 14 juni 2016 ten grondslag gelegd dat appellante zelfstandig bezwaar kan maken tegen het besluit van 19 augustus 2015.'
#   pattern:'ADJN heeft V dat'                  matches:  'De rechtbank heeft geoordeeld dat'                          in 'De rechtbank heeft geoordeeld dat de raad de aanvraag van appellante terecht en op goede gronden heeft afgewezen.'
#   pattern:'ADJN heeft V dat'                  matches:  'rechtbank heeft geoordeeld dat'                             in 'De rechtbank heeft geoordeeld dat de raad de aanvraag van appellante terecht en op goede gronden heeft afgewezen.'
#   pattern:'ADJN heeft V dat'                  matches:  'onrechte heeft geoordeeld dat'                              in 'appellante betoogt dat de rechtbank ten onrechte heeft geoordeeld dat de raad haar verzoek terecht heeft afgewezen.'
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'Uitgesproken in het openbaar op 16 augustus 2017'           in 'Uitgesproken in het openbaar op 16 augustus 2017 735. '
# In document ECLI:NL:RBAMS:2016:3036
#   pattern:'heeft ANYPLUS verklaard'           matches:  'heeft verweerder de tegen de primaire besluiten gemaakte bezwaren ongegrond verklaard' in 'Bij besluiten van 17 december 2014 en 22 januari 2015 (de bestreden besluiten) heeft verweerder de tegen de primaire besluiten gemaakte bezwaren ongegrond verklaard. '
#   pattern:'volgens ADJN'                      matches:  'Volgens dat lokale beleid'                                  in 'Volgens dat lokale beleid was voor de selectie voor functies schaal 8 en hoger de reguliere sollicitatieprocedure en sollicitatie- en selectiecode van toepassing.'
#   pattern:'ADJN heeft V dat'                  matches:  'Verweerder heeft toegelicht dat'                            in 'Verweerder heeft toegelicht dat de betreffende collega’s behoren tot de zogeheten ‘605-lichting’.'
#   pattern:'volgens ADJN'                      matches:  'Volgens dat eerdere beleid'                                 in 'Volgens dat eerdere beleid gold in beginsel ook de eis van tenminste drie jaar werkervaring, maar daar werd soms van afgeweken. 2.13 '
#   pattern:'aan de hand van de ADJN'           matches:  'aan de hand van de omstandigheden'                          in 'De vraag of de redelijke termijn als bedoeld in artikel 6 van het Europees Verdrag tot bescherming van de rechten van de mens en de fundamentele vrijheden (EVRM) is overschreden, moet worden beoordeeld aan de hand van de omstandigheden van het geval.'
#   pattern:'gelet op de ADJN'                  matches:  'Gelet op de toewijzing'                                     in '2.19 Gelet op de toewijzing van het verzoek om schadevergoeding is er aanleiding toepassing te geven aan artikel 8:74, tweede lid, van de Awb en te bepalen dat verweerder het door eiseres naam eiser I betaalde griffierecht aan haar vergoedt.'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'Daarnaast is er aanleiding om verweerder met toepassing van artikel 8:75 van de Awb te veroordelen in de door eiseres naam eiser I in beroep gemaakte proceskosten.'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'Deze kosten stelt de rechtbank op grond van het Besluit proceskosten bestuursrecht voor de door een derde beroepsmatig verleende rechtsbijstand vast op € 496,- (1 punt voor het indienen van het beroepschrift, 1 punt voor het verschijnen ter zitting, met een waarde per punt van € 496,- en een wegingsfactor 0,5).'
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'Aangezien verweerder uitsluitend wordt veroordeeld in de proceskosten in verband met de toekenning van de schadevergoeding wegens overschrijding van de redelijke termijn hanteert de rechtbank een wegingsfactor voor het gewicht van de zaak van 0,5 (zie de hiervoor genoemde uitspraak van de Hoge Raad van 20 maart 2015).'
#   pattern:'LEGALEVENT van ANYMAX7 DATELIKE'   matches:  'uitspraak van de Hoge Raad van 20 maart 2015'               in 'Aangezien verweerder uitsluitend wordt veroordeeld in de proceskosten in verband met de toekenning van de schadevergoeding wegens overschrijding van de redelijke termijn hanteert de rechtbank een wegingsfactor voor het gewicht van de zaak van 0,5 (zie de hiervoor genoemde uitspraak van de Hoge Raad van 20 maart 2015).'
#   pattern:'verklaart ANYPLUS ongegrond'       matches:  'verklaart de beroepen ongegrond'                            in 'De rechtbank: - verklaart de beroepen ongegrond; veroordeelt verweerder tot het betalen van een schadevergoeding aan eiseres naam eiser I tot een bedrag van € 500,-; draagt verweerder op het betaalde griffierecht van € 167,- aan eiseres naam eiser I te vergoeden; veroordeelt verweerder in de proceskosten van eiseres naam eiser I tot een bedrag van € 496,-. '
#   pattern:'veroordeelt ANYPLUS tot DPN'       matches:  'veroordeelt verweerder tot het betalen van een schadevergoeding aan eiseres naam eiser I tot een bedrag' in 'De rechtbank: - verklaart de beroepen ongegrond; veroordeelt verweerder tot het betalen van een schadevergoeding aan eiseres naam eiser I tot een bedrag van € 500,-; draagt verweerder op het betaalde griffierecht van € 167,- aan eiseres naam eiser I te vergoeden; veroordeelt verweerder in de proceskosten van eiseres naam eiser I tot een bedrag van € 496,-. '
#   pattern:'proceskosten'                      matches:  'proceskosten'                                               in 'De rechtbank: - verklaart de beroepen ongegrond; veroordeelt verweerder tot het betalen van een schadevergoeding aan eiseres naam eiser I tot een bedrag van € 500,-; draagt verweerder op het betaalde griffierecht van € 167,- aan eiseres naam eiser I te vergoeden; veroordeelt verweerder in de proceskosten van eiseres naam eiser I tot een bedrag van € 496,-. '
#   pattern:'veroordeelt ANYPLUS tot DPN'       matches:  'veroordeelt verweerder in de proceskosten van eiseres naam eiser I tot een bedrag' in 'De rechtbank: - verklaart de beroepen ongegrond; veroordeelt verweerder tot het betalen van een schadevergoeding aan eiseres naam eiser I tot een bedrag van € 500,-; draagt verweerder op het betaalde griffierecht van € 167,- aan eiseres naam eiser I te vergoeden; veroordeelt verweerder in de proceskosten van eiseres naam eiser I tot een bedrag van € 496,-. '
#   pattern:'veroordeelt ANYPLUS tot DPN'       matches:  'veroordeelt verweerder tot het betalen van een schadevergoeding aan eiseres naam eiser I tot een bedrag van € 500,-;\n\ndraagt verweerder op het betaalde griffierecht van € 167,- aan eiseres naam eiser I te vergoeden;\n\nveroordeelt verweerder in de proceskosten van eiseres naam eiser I tot een bedrag' in 'De rechtbank: - verklaart de beroepen ongegrond; veroordeelt verweerder tot het betalen van een schadevergoeding aan eiseres naam eiser I tot een bedrag van € 500,-; draagt verweerder op het betaalde griffierecht van € 167,- aan eiseres naam eiser I te vergoeden; veroordeelt verweerder in de proceskosten van eiseres naam eiser I tot een bedrag van € 496,-. '
#   pattern:'uitgesproken ANYSTAR op DATELIKE'  matches:  'uitgesproken op 24 mei 2016'                                in 'De beslissing is in het openbaar uitgesproken op 24 mei 2016. '

# %% [markdown]
# # Discussion

# %% [markdown]
# Pattern matching can be great for very stable patterns,
# but you probably want to know its limitations before you spend a lot of time
# discovering that it _isn't_ enough for your purposes, or how much work you need to do before it is.
#
#
# One of the things to realize is that pattern matching only ever reports what it matches,
# and examples that look great are usually the patterns that are _very_ regular.
#
# If what you need is exact and rigid matching, great!
#
# Yet the more varied, the more _natural_ text is, the harder that is to do,
# amd **it will not tell you what you are missing**, what you need to improve.
#
# That's your job, as your own technician.

# %% [markdown]
# Notes:
# * the above patterns were made in a way that
#   - if it's easy, try to have the matching text contain the useful information
#     In the better cases, these are almost factoids, and seem to you a basic idea of the topic and history.
#
#   - ...but in some cases it's just meant as a "report the entire sentence, this short phrase hints that it is interesting"
#
#   - At the same time, it's missing a lot, and if you check why you will often find an unusual
#     grammatical sentence.
#     For some cases it doesn't do _anything_.
#
# Sentence patterns like that are _really hard_ to get a complete set of, because people use natural language.
#
# Just a thought, but consider giving yourself a more specific task, and a cruder start.
# Say, instead of trying to find specific formulations like the above does (which will never be complete),
# try a method to pick up all _potentially_ useful sentences (maybe just "contains both 'heeft' and 'oordeel'")
# and then force yourself to deal with all of them _somehow_.
#
# It _will_ be messier,  but it will also contain a lot more of the cases you want,
# and maybe you'll have a smart idea about how to sort those formulations, e.g. by categorizing.
