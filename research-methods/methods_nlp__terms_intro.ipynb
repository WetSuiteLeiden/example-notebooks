# %% [markdown]
# # Purpose of this notebook
#
# Provide _some_ answer to "so how you detect interesting terms / phrases?"

# %% [markdown]
# Annoyingly, one has to respond with "that depends on what you mean with interesting phrases"
#
#
# There are varied methods, some simple enough that you could implement yourself in half an hour,
# that will return with some interesting fragments, so seem to work.
# ...yet often have assumptions that turn out to not match up with what you thought when you heard 'interesting'.

# %% [markdown]
# While each of these methods visible do useful things,
# each will miss things you may have wanted to give,
# which is invisible, and it is also not clear why.
#
#
# Consider if your goal was
# - "what multi-word phrases appear in this document"
# - "what multi-word phrases make this document interesting"
# - "what multi-word phrases make this document different from others in a set"
# - "can we make lists of words"
# - "what multi-word phrases make this document interesting"
# - match known phrases
# - match phrases of a specific topic
# They may may seem like subtle variations,
#
# Also, if you have not yet thought what kind of phrases are more interesting,
# or why, then you can't expect a method to prefer those.
#
#
# So for the most part, the below is a start on just the first in that list,
# to introduce some methods, but refined output will need your refined needs (and some refined code).

# %% [markdown]
# For example,
# - **tf-idf** is more of an ingredient for a larger analysis, search, and other things, yet
#   - combined with n-grams, they might tell you combinations of words that are more common than others, but still little about how they compare.
#   - so _by itself_ it's not useful for much more than assistance making stoplists.
#   - there's a [separate notebook that goes into its basics](methods_text_terms_tfidf.ipynb)
#
# - using any language parsing, you could look for patterns.
#   - the output may be clean, but it's unclear what one might miss
#   - a basic example follows below
#
# - **Collocation analysis** often refers to a probability-based "does this combination of words appears more often together than its parts would suggest?", which is still simple and works a little better.
#   - it might pick up "eigen gebruik", "echtgenoot of geregistreerde partner", "werk en inkomen naar arbeidsvermogen"
#   - ...but also just fragments that happen, well, because sentences have structure ("heeft gedaan", "verplichtingen uit"), or have been ripped from their context ("tijdstip zal", "KONING DER").
#   - so 'more common together' turns out to not be quite enough for clean output
#   - there's a [separate notebook that goes into its basics](methods_text_terms_collocations.ipynb)
#
# - topic modelling goes further, asking "what sets of words or phrases seem to join and disinguish documents in a set"
#   - this adds a goal that pushes down in that above list.
#   - there's a [separate notebook that goes into its basics](methods_text_topic_modeling.ipynb)

# %% [markdown]
# ## Spacy pattern matcher
#
# Notes:
# - you can express more complex types of patterns, see https://spacy.io/api/matcher#patterns
# - You could extend this to more complex tasks, like maybe rule-based phrase and named entity extraction.
#   - ...though you might base that on more specific existing code like PhraseMatcher and EntityRuler,
#     which may work faster and/or annotate automatically.
#   - and in the case of NER would probaly still be less effective than existing trained NER model components

# %%
import collections
import spacy.displacy
import spacy.matcher
from spacy.matcher import Matcher

import wetsuite.datasets
import wetsuite.helpers.spacy

# %%
dutch  = spacy.load('nl_core_news_lg')

matcher = Matcher(dutch.vocab)
matcher.add("HW_MetPunct", [   [{"LOWER": "hallo"}, {"IS_PUNCT": True}, {"LOWER": "wereld"}]            ])
matcher.add("HW_Opt",      [   [{"LOWER": "hallo"}, {"IS_PUNCT": True, "OP":'*'}, {"LOWER": "wereld"}]  ])  # punctuation is optional in this one, so matches both

doc = dutch("De hallo, wereld test. Eerste patroon matcht niet op hallo wereld.")
print( list( repr(tok) for tok in doc ) ) # (just to point out what the tokens are)

for match_id, start, end in matcher( doc ):
    match_str = dutch.vocab.strings[match_id]  # Get string representation, seems to point out the pattern name is added to the vocab too, presumably to have an integer-only representation?
    span = doc[start:end]  # The matched span
    print(f"Pattern {match_str:15s} matches token {start:3d}..{end:3d} matches text {repr(span.text)}")
# Out:
# ['De', 'hallo', ',', 'wereld', 'test', '.', 'Eerste', 'patroon', 'matcht', 'niet', 'op', 'hallo', 'wereld', '.']
# Pattern HW_MetPunct     matches token   1..  4 matches text 'hallo, wereld'
# Pattern HW_Opt          matches token   1..  4 matches text 'hallo, wereld'
# Pattern HW_Opt          matches token  11.. 13 matches text 'hallo wereld'

# %%
# Out:
# [[{'LOWER': 'I'}, {'LOWER': 'like'}, {'LOWER': 'cheese'}],
#  [{'LOWER': 'hungry'}, {'LOWER': 'like'}, {'LOWER': 'the'}, {'LOWER': 'wolf'}]]

# %%
# Out:
# ('NOUN', Gender=Com|Number=Sing, 'N|soort|ev|basis|zijd|stan')

# %% [markdown]
# [The things we can match include](https://spacy.io/usage/rule-based-matching#adding-patterns-attributes) attributes on Token -- you will recognize most of these from the [Token documentation](https://spacy.io/api/token#attributes) and our [spacy intro notebook](methods_nlp__spacy_basics.ipynb):
# * token text, derived forms, assigned by the model/parse, and some existin gpatterns
# - ORTH or TEXT - the text as-is
# - LENGTH - length of TEXT
# - LOWER - the lowercase version of the text
# - NORM - the normalized version (seems to do things like resolve contractions, and otherwise often be the lemmatizer output?)
# - LEMMA - lemmatixed
# - SHAPE - alphabetic characters become X or x, numeric by d, and sequences of the same are truncated after 4, so e.g. Katherine80 would become Xxxxxdd
# - POS - coarse tagging  (often following wider conventions), e.g. `NOUN`
# - TAG - finer taggging  (more easily model/language specific, e.g. `'N|soort|ev|basis|zijd|stan'`)
# - MORPH - morphological properties, something like `Gender=Com|Number=Sing`
# - DEP - dependency relation in the parse
# - LIKE_NUM
# - LIKE_URL
# - LIKE_EMAIL
# - IS_SENT_START
# - IS_ALPHA, IS_ASCII, IS_DIGIT
# - IS_LOWER, IS_UPPER, IS_TITLE
# - IS_PUNCT, IS_SPACE, IS_STOP
# - `_` for values in custom attributes

# %% [markdown]
# Operators:
# - REGEX, e.g.
#   - `{"TEXT": {"REGEX": "deff?in[ia]tely"}}` or
#   - `{"TAG": {"REGEX": "^V"}`

# %%
# Out:
#   Input In [71]
#     Operators:
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# There is also, significantly,
#
# OP
#
#
#
# which is a regex-like quantifier you can add to this part of the match
# - `?`, `+`, `*`, `{n}`, `{n,m}`, `{n,}`, `{,m}`
# - ...and `!` which means it must _not_ match (match 0 times at this point) (does it consume so mean an "anything but this?" or does it _not_ consume and mean more of a negative lookahead?)
#
# https://spacy.io/usage/rule-based-matching#quantifiers

# %%
rechtspraak = wetsuite.datasets.load('rechtspraaknl-struc')
rechtspraak_items = list( docdict.get('bodytext')  for _, docdict in rechtspraak.data.random_sample(250) )

# %%
# As an example, look for 
#  < one or more adjectives>  before  <a noun or proper noun>
# This is too simple to be directly useful, but works fine as an example
an_pattern = [
    [ # you can have more rules in a matcher, this has just one 
        {"POS": "ADJ",                "OP": "+"},   
        #{"POS": {"IN":["ADJ","ADV"]},  "OP": "+"},   
        {"POS": {"IN":["NOUN","PROPN"]} } 
    ],
]
matcher = spacy.matcher.Matcher(dutch.vocab)
matcher.add("adjective-noun", an_pattern)


count_pats = collections.defaultdict(int)

larger_rvs_advice = [] # 
for body in rechtspraak_items:
    #body = '\n'.join( item['body'] )
    doc = dutch( body )

    for sent in doc.sents:
        if not 'appellant' in sent.text.lower():
            continue
        #matches = matcher( doc )

        matches = matcher( sent )
        for match_id, start_i, end_i in matches:
            print( '------------------' )

            if 1:
                # display with some context:
                print( sent[ : start_i ].text,      end=''  ) # sentence before match, as-is
                print( " [[  ",                     end=''  ) # match: bracket
                for tok in sent[ start_i : end_i ]:          # and for each token mention part of speech
                    print(f'{tok.text}/{tok.pos_}', end='  ')
                print( "]] ",                       end=''  )
                print( sent[ end_i : ].text.rstrip() ) # sentence before match, as-is

                # print( doc[ start_i-5 : start_i ].text, 
                #     '[',
                #     doc[ start_i : end_i ].text,
                #     ']',
                #     doc[ end_i : end_i+5 ].text,
                #     )
            if 1:
                # just count for now
                count_pats[ doc[ start_i : end_i ].text ] += 1 
    #break

for str, count in sorted( count_pats.items(), key=lambda x:x[1], reverse=True):
    print( f'{count:5d}  {str}')
# Out:
# ------------------
# Namens appellante heeft mr. S.A.E. Vancraeynest [[  hoger/ADJ  beroep/NOUN  ]] ingesteld.
# ------------------
# Bij besluit van 14 januari 2004 heeft CIZ appellante in het kader van de AWBZ voor de periode van 8 december 2003 tot 8 april 2004 geïndiceerd voor [[  huishoudelijke/ADJ  zorg/NOUN  ]] klasse 2 (2 tot 3,9 uur per week).
#
# 1.2.
# ------------------
# Bij het [[  nieuwe/ADJ  besluit/NOUN  ]] op bezwaar van 7 juni 2006 heeft CIZ appellante  geïndiceerd voor hulp bij het huishouden voor de periode van 8 december 2003 tot 12 april 2005.
# ------------------
# Appellante heeft vervolgens zowel het zorgkantoor CZ (zorgkantoor) als CIZ gevraagd om vergoeding van schade die zij heeft geleden doordat zij destijds te weinig [[  persoonsgebonden/ADJ  budget/NOUN  ]] (pgb) heeft ontvangen.
# ------------------
# Appellante heeft zich in [[  hoger/ADJ  beroep/NOUN  ]] gemotiveerd tegen deze uitspraak gekeerd, voor zover daarbij de rechtsgevolgen van het vernietigde besluit van 17 juli 2009 van CIZ in stand zijn gelaten.
# ------------------
# Uit de brief van 28 oktober 2010 van het zorgkantoor blijkt dat niet de wijze van verantwoorden, maar de persoon van de hulpverlener, te weten de echtgenoot van appellante, de reden is om geen [[  hoger/ADJ  pgb/NOUN  ]] toe te kennen.
# ------------------
# De door appellante gestelde schade houdt daarom [[  rechtstreeks/ADJ  verband/NOUN  ]] met de weigering van het zorgkantoor om een hoger pgb te verlenen en vast te stellen en is niet toe te rekenen aan CIZ.
# ------------------
# De door appellante gestelde schade houdt daarom rechtstreeks verband met de weigering van het zorgkantoor om een [[  hoger/ADJ  pgb/NOUN  ]] te verlenen en vast te stellen en is niet toe te rekenen aan CIZ.
# ------------------
# het beroep, voor zover dat ziet op de afwijzing van vergoeding van [[  materiële/ADJ  schade/NOUN  ]] , ongegrond;
# -veroordeelt CIZ in de proceskosten van appellante tot een bedrag van € 874,--;
# -bepaalt dat CIZ aan appellante het in hoger beroep betaalde griffierecht van € 112,--vergoedt.
# ------------------
# het beroep, voor zover dat ziet op de afwijzing van vergoeding van materiële schade, ongegrond;
# -veroordeelt CIZ in de proceskosten van appellante tot een bedrag van € 874,--;
# -bepaalt dat CIZ aan appellante het in [[  hoger/ADJ  beroep/NOUN  ]] betaalde griffierecht van € 112,--vergoedt.
# ------------------
# Tegen deze uitspraak heeft [appellante] [[  hoger/ADJ  beroep/NOUN  ]] ingesteld.
# ------------------
# De korpschef heeft de niet aan [appellante] verstrekte gegevens, onder verwijzing naar artikel 8:29 van de [[  Algemene/ADJ  wet/NOUN  ]] bestuursrecht (hierna: de Awb), overgelegd met de mededeling dat uitsluitend de Afdeling daarvan kennis mag nemen.
# ------------------
# De rechtbank heeft, met toepassing van artikel 8:29, [[  vijfde/ADJ  lid/NOUN  ]] , van de Awb, kennisgenomen van de gegevens waarvan [appellante] geen kennis heeft mogen nemen.
# ------------------
# Het beroep van [appellante] richt zich namelijk niet op de registraties/mutaties waarvan inzage op grond van artikel 27, [[  eerste/ADJ  lid/NOUN  ]] , aanhef en onder d, van de Wpg is geweigerd, aldus de rechtbank.
# ------------------
# Voor zover het in artikel 27, [[  eerste/ADJ  lid/NOUN  ]] , aanhef en onder d, van de Wpg genoemde belang hier wel in het geding is, betoogt [appellante] dat aan het besluit van 3 januari 2020 ten onrechte geen belangenafweging ten grondslag is gelegd.
# ------------------
# Voorts is [appellante] van mening dat het besluit van 3 januari 2020 in strijd is met artikel 3:4, [[  tweede/ADJ  lid/NOUN  ]] , van de Awb.
# ------------------
# De Afdeling heeft met toepassing van artikel 8:29, [[  vijfde/ADJ  lid/NOUN  ]] , van de Awb kennisgenomen van de gegevens waarvan [appellante] geen kennis heeft mogen nemen.
# ------------------
# De Afdeling is van oordeel dat de korpschef zich terecht op het standpunt heeft gesteld dat het belang, genoemd in artikel 27, [[  eerste/ADJ  lid/NOUN  ]] , aanhef en onder d, van de Wpg, hier in het geding is en daarom betrokken moet worden bij de vraag of het verzoek van [appellante] (volledig) moet worden ingewilligd.
# ------------------
# De twijfel van [appellante], die is ingegeven door kennisneming van een mutatie waarvan de inzage door de korpschef (gedeeltelijk) zou zijn geweigerd, wordt door de Afdeling - na kennisneming van de [[  geheime/ADJ  stukken/NOUN  ]] - niet gedeeld.
# ------------------
# Naar aanleiding hiervan en na kennisneming van de [[  geheime/ADJ  stukken/NOUN  ]] , is de Afdeling van oordeel dat de korpschef zich op het standpunt mocht stellen dat het belang van de rechten en vrijheden van derden hier zwaarder weegt dan het belang van [appellante] om inzage te krijgen in de politiegegevens in kwestie.
# ------------------
# Het is ook gezien het voorgaande, dat de Afdeling van oordeel is dat de met het besluit van 3 januari 2020 gepaard gaande [[  nadelige/ADJ  gevolgen/NOUN  ]] voor [appellante] niet onevenredig zijn in verhouding tot het met dat besluit te dienen doel, waaraan de korpschef terecht een zwaarder gewicht heeft toegekend.
# 13.
# ------------------
# Het is ook gezien het voorgaande, dat de Afdeling van oordeel is dat de met het besluit van 3 januari 2020 gepaard gaande nadelige gevolgen voor [appellante] niet onevenredig zijn in verhouding tot het met dat besluit te dienen doel, waaraan de korpschef terecht een [[  zwaarder/ADJ  gewicht/NOUN  ]] heeft toegekend.
# 13.
# ------------------
# veroordeelt de korpschef tot vergoeding van bij [appellante] in verband met de behandeling van het beroep en [[  hoger/ADJ  beroep/NOUN  ]] opgekomen proceskosten tot een bedrag van € 1.518,00, geheel toe te rekenen aan door een derde beroepsmatig verleende rechtsbijstand;
# VII.
# ------------------
# gelast dat de korpschef aan [appellante] het door haar voor de behandeling van het beroep en het [[  hoger/ADJ  beroep/NOUN  ]] betaalde griffierecht ten bedrage van € 448,00 vergoedt.
# ------------------
# bestuursrecht op het [[  hoger/ADJ  beroep/NOUN  ]] van:
#
# de minister voor Immigratie en Asiel,
# appellant,
#
# tegen de uitspraak van de rechtbank 's Gravenhage, nevenzittingsplaats Maastricht, van 4 februari 2011 in zaak nr. 10/22675 in het geding tussen:
#
# (de vreemdeling)
#
# en
#
# de minister.
# ------------------
# Deze resterende boekwaarde houdt verband met het voornemen van appellante nieuwbouw te plegen voordat de [[  oorspronkelijke/ADJ  afschrijvingstermijn/NOUN  ]] van het gebouwencomplex volledig is verstreken.
# ------------------
# Het verval met ingang van 2012 van de gegarandeerde kapitaallastenvergoeding heeft volgens appellante [[  financiële/ADJ  implicaties/NOUN  ]] in verband waarmee zij op het nacalculatieformulier 2009 een bedrag van € 15,8 miljoen heeft opgevoerd als (eenmalige) afschrijving desinvestering.
# ------------------
# Appellante stelt zich op het standpunt dat verweerster ten onrechte niet de post van € 15,8  miljoen voor de [[  versnelde/ADJ  afschrijving/NOUN  ]] van het gebouwencomplex in de nacalculatie 2009 heeft verwerkt.
# ------------------
# Volgens appellante heeft verweerster verder ten onrechte aangenomen dat geen sprake is van [[  onevenredige/ADJ  benadeling/NOUN  ]] van appellante.
# ------------------
# Door een afwaardering van het [[  eigen/ADJ  vermogen/NOUN  ]] van appellante met € 15,8 miljoen zal dit eigen vermogen negatief worden en zal nieuwbouw niet langer extern gefinancierd kunnen worden.
# ------------------
# Door een afwaardering van het eigen vermogen van appellante met € 15,8 miljoen zal dit [[  eigen/ADJ  vermogen/NOUN  ]] negatief worden en zal nieuwbouw niet langer extern gefinancierd kunnen worden.
# ------------------
#
#
# 3.
# Verweerster heeft appellantes verzoek om [[  versnelde/ADJ  afschrijving/NOUN  ]] op grond van de Beleidsregel afschrijving afgewezen.
# ------------------
# Voor appellante gelden bij de bepaling van de [[  aanvaardbare/ADJ  kosten/NOUN  ]] de afschrijvingspercentages zoals vastgesteld de Beleidsregel afschrijving.
# ------------------
# De omstandigheid dat volgens het fusiebesluit van de ACM appellante nooit een [[  hogere/ADJ  prijs/NOUN  ]] in het B-segment mag afspreken met verzekeraars dan de landelijk gemiddelde prijs, vormt volgens verweerster evenmin een bijzondere omstandigheid om af te wijken van de Beleidsregel afschrijving.
# ------------------
# De omstandigheid dat volgens het fusiebesluit van de ACM appellante nooit een hogere prijs in het B-segment mag afspreken met verzekeraars dan de landelijk [[  gemiddelde/ADJ  prijs/NOUN  ]] , vormt volgens verweerster evenmin een bijzondere omstandigheid om af te wijken van de Beleidsregel afschrijving.
# ------------------
# De omstandigheid dat volgens het fusiebesluit van de ACM appellante nooit een hogere prijs in het B-segment mag afspreken met verzekeraars dan de [[  landelijk/ADJ  gemiddelde/ADJ  prijs/NOUN  ]] , vormt volgens verweerster evenmin een bijzondere omstandigheid om af te wijken van de Beleidsregel afschrijving.
# ------------------
# De omstandigheid dat volgens het fusiebesluit van de ACM appellante nooit een hogere prijs in het B-segment mag afspreken met verzekeraars dan de landelijk gemiddelde prijs, vormt volgens verweerster evenmin een [[  bijzondere/ADJ  omstandigheid/NOUN  ]] om af te wijken van de Beleidsregel afschrijving.
# ------------------
# Het was voor appellante derhalve op dat moment reeds duidelijk en voorzienbaar dat zij onder het [[  nieuwe/ADJ  regime/NOUN  ]] van prestatiebekostiging met de zorgverzekeraars tot de hoogte van het prijsplafond zou kunnen contracteren.
# ------------------
# Het prijsplafond geeft een bovengrens aan voor de [[  vrije/ADJ  onderhandelingen/NOUN  ]] tussen appellante en zorgverzekeraars over de tarieven in het B-segment.
# ------------------
# Indien [[  appellante/ADJ  uitvoering/NOUN  ]] gaat geven aan de nieuwbouwplannen per 2014, kan de invoering van de prestatiebekostiging per 1 januari 2012 voor bezwaarde financiële voordelen bieden.
# ------------------
# Indien appellante uitvoering gaat geven aan de nieuwbouwplannen per 2014, kan de invoering van de prestatiebekostiging per 1 januari 2012 voor bezwaarde [[  financiële/ADJ  voordelen/NOUN  ]] bieden.
# ------------------
# Indien appellante uitvoering gaat geven aan de nieuwbouwplannen per 2014, kan de invoering van de prestatiebekostiging per 1 januari 2012 voor [[  bezwaarde/ADJ  financiële/ADJ  voordelen/NOUN  ]] bieden.
# ------------------
# Daardoor ontstaat bij invoering van de kapitaallastenvergoeding met gereguleerde tarieven voor appellante de mogelijkheid om op de restwaarde van het [[  oude/ADJ  gebouwencomplex/NOUN  ]] versneld af te schrijven en/of te sparen voor nieuwbouw.
# ------------------
# Appellante heeft evenmin aannemelijk gemaakt dat sprake is van onevenredige [[  financiële/ADJ  gevolgen/NOUN  ]] of dat de kwaliteit van de zorg in gevaar zou kunnen komen.
# ------------------
# Appellante heeft evenmin aannemelijk gemaakt dat sprake is van [[  onevenredige/ADJ  financiële/ADJ  gevolgen/NOUN  ]] of dat de kwaliteit van de zorg in gevaar zou kunnen komen.
# ------------------
# Hieruit blijkt dat appellante in verband met haar plan voor nieuwbouw zelf – voor [[  eigen/ADJ  rekening/NOUN  ]] – is overgegaan tot versnelde afschrijving van de resterende boekwaarde van het gebouwencomplex.
# ------------------
# Hieruit blijkt dat appellante in verband met haar plan voor nieuwbouw zelf – voor eigen rekening – is overgegaan tot [[  versnelde/ADJ  afschrijving/NOUN  ]] van de resterende boekwaarde van het gebouwencomplex.
# ------------------
# op het [[  hoger/ADJ  beroep/NOUN  ]] van:
#
# [appellant] (hierna: appellant),
#
# tegen de uitspraak van de rechtbank Amsterdam van 2 februari 2005, 03/6132 (hierna: aangevallen uitspraak),
#
# in het geding tussen:
#
# appellant
#
# en
#
# de Raad van bestuur van het Uitvoeringsinstituut werknemersverzekeringen (hierna:
# ------------------
# op het hoger beroep van:
#
# [appellant] (hierna: appellant),
#
# tegen de uitspraak van de rechtbank Amsterdam van 2 februari 2005, 03/6132 (hierna: aangevallen uitspraak),
#
# in het geding tussen:
#
# appellant
#
# en
#
# de Raad van bestuur van het [[  Uitvoeringsinstituut/ADJ  werknemersverzekeringen/NOUN  ]] (hierna:
# ------------------
# Appellant heeft zich per 19 februari 2003, toen hij een werkloosheidsuitkering ontving, wegens [[  psychische/ADJ  klachten/NOUN  ]] ziek gemeld.
# ------------------
# Naar aanleiding hiervan is appellant [[  verschillende/ADJ  keren/NOUN  ]] op het spreekuur geweest van een verzekeringsarts, die inlichtingen heeft ingewonnen bij de behandelend psychiater A. Lisei.
# ------------------
# Mede gelet op de door [[  voornoemde/ADJ  psychiater/NOUN  ]] verstrekte inlichtingen stelde de bezwaarverzekeringsarts vast dat bij appellant, naast hypertensie, sprake was van spanningsklachten in verband met psychosociale problematiek.
# ------------------
# Mede gelet op de door voornoemde psychiater verstrekte inlichtingen stelde de bezwaarverzekeringsarts vast dat bij appellant, naast hypertensie, sprake was van spanningsklachten in verband met [[  psychosociale/ADJ  problematiek/NOUN  ]] .
# ------------------
# De bezwaarverzekeringsarts was van mening dat appellant nog redelijk kon functioneren en geschikt was voor arbeid waarbij geen sprake was van [[  directe/ADJ  conflicthantering/NOUN  ]] , veelvuldige deadlines en/of produktiepieken en vanwege de duizeligheid ook geen werken op hoogtes.
# ------------------
# De bezwaarverzekeringsarts was van mening dat appellant nog redelijk kon functioneren en geschikt was voor arbeid waarbij geen sprake was van directe conflicthantering, [[  veelvuldige/ADJ  deadlines/NOUN  ]] en/of produktiepieken en vanwege de duizeligheid ook geen werken op hoogtes.
# ------------------
# De rechtbank heeft daarbij overwogen dat appellant geen [[  medische/ADJ  gegevens/NOUN  ]] had overgelegd waaruit voortvloeit dat sprake was van ernstiger psychische klachten dan door de bezwaarverzekeringsarts was aangenomen of waaruit valt af te leiden dat het oordeel van de bezwaarverzekeringsarts onjuist zou zijn.
# ------------------
# De rechtbank heeft daarbij overwogen dat appellant geen medische gegevens had overgelegd waaruit voortvloeit dat sprake was van ernstiger [[  psychische/ADJ  klachten/NOUN  ]] dan door de bezwaarverzekeringsarts was aangenomen of waaruit valt af te leiden dat het oordeel van de bezwaarverzekeringsarts onjuist zou zijn.
# ------------------
# De rechtbank heeft daarbij overwogen dat appellant geen medische gegevens had overgelegd waaruit voortvloeit dat sprake was van [[  ernstiger/ADJ  psychische/ADJ  klachten/NOUN  ]] dan door de bezwaarverzekeringsarts was aangenomen of waaruit valt af te leiden dat het oordeel van de bezwaarverzekeringsarts onjuist zou zijn.
# ------------------
# Naar het oordeel van de Raad heeft de bezwaarverzekeringsarts een [[  zorgvuldig/ADJ  onderzoek/NOUN  ]] ingesteld en is er geen reden om aan te nemen dat de psychische beperkingen van appellant zijn onderschat.
# ------------------
# Naar het oordeel van de Raad heeft de bezwaarverzekeringsarts een zorgvuldig onderzoek ingesteld en is er geen reden om aan te nemen dat de [[  psychische/ADJ  beperkingen/NOUN  ]] van appellant zijn onderschat.
# ------------------
# De Raad verwijst verder nog naar het in [[  eerste/ADJ  aanleg/NOUN  ]] uitgebrachte rapport van 9 maart 2004, waarin voornoemde bezwaarverzekeringsarts heeft uiteengezet dat er onvoldoende reden is om aan te nemen dat appellant rugklachten had die hem het werk als orderpikker verhinderden.
# ------------------
# De Raad verwijst verder nog naar het in eerste aanleg uitgebrachte rapport van 9 maart 2004, waarin [[  voornoemde/ADJ  bezwaarverzekeringsarts/NOUN  ]] heeft uiteengezet dat er onvoldoende reden is om aan te nemen dat appellant rugklachten had die hem het werk als orderpikker verhinderden.
# ------------------
# De Raad verwijst verder nog naar het in eerste aanleg uitgebrachte rapport van 9 maart 2004, waarin voornoemde bezwaarverzekeringsarts heeft uiteengezet dat er [[  onvoldoende/ADJ  reden/NOUN  ]] is om aan te nemen dat appellant rugklachten had die hem het werk als orderpikker verhinderden.
# ------------------
# Van de zijde van appellant zijn ook in [[  hoger/ADJ  beroep/NOUN  ]] geen medische gegevens ingebracht die een ander licht werpen op zijn gezondheidstoestand ten tijde in geding.
# ------------------
# Van de zijde van appellant zijn ook in hoger beroep geen [[  medische/ADJ  gegevens/NOUN  ]] ingebracht die een ander licht werpen op zijn gezondheidstoestand ten tijde in geding.
# ------------------
# Van de zijde van appellant zijn ook in hoger beroep geen medische gegevens ingebracht die een [[  ander/ADJ  licht/NOUN  ]] werpen op zijn gezondheidstoestand ten tijde in geding.
# ------------------
# heeft [[  hoger/ADJ  beroep/NOUN  ]] ingesteld tegen het vonnis dat de kantonrechter in de rechtbank Gelderland, zittingsplaats Arnhem, op 1 juni 2022 tussen [appellant] en Menzis Zorgverzekeraar heeft uitgesproken.
# ------------------
# [appellant] woont in een zorginstelling van de [[  Twentse/ADJ  Zorgcentra/NOUN  ]] te Enschede.
# ------------------
# De bedoeling van het [[  hoger/ADJ  beroep/NOUN  ]] is dat de vorderingen van [appellant] alsnog worden toegewezen.
#
# 3
# De motivering van de beslissing
#
# 3.1.
# ------------------
# In de dagvaarding in [[  hoger/ADJ  beroep/NOUN  ]] stelt [appellant] dat de kantonrechter abusievelijk vonnis heeft gewezen tussen hem en Menzis Zorgverzekeraar.
# ------------------
# In de dagvaarding in hoger beroep stelt [appellant] dat de kantonrechter [[  abusievelijk/ADJ  vonnis/NOUN  ]] heeft gewezen tussen hem en Menzis Zorgverzekeraar.
# ------------------
# Het hof dient namelijk allereerst (ambtshalve) te beoordelen of de vorderingen van [appellant] vatbaar zijn voor [[  hoger/ADJ  beroep/NOUN  ]] .
#
# 3.2.
# ------------------
# In [[  eerste/ADJ  aanleg/NOUN  ]] heeft [appellant] betaling gevorderd van een bedrag van € 1.170,54 (bestaande uit € 990,72 aan hoofdsom en uit buitengerechtelijke kosten met de wettelijke rente).
# ------------------
# In eerste aanleg heeft [appellant] betaling gevorderd van een bedrag van € 1.170,54 (bestaande uit € 990,72 aan hoofdsom en uit [[  buitengerechtelijke/ADJ  kosten/NOUN  ]] met de wettelijke rente).
# ------------------
# In eerste aanleg heeft [appellant] betaling gevorderd van een bedrag van € 1.170,54 (bestaande uit € 990,72 aan hoofdsom en uit buitengerechtelijke kosten met de [[  wettelijke/ADJ  rente/NOUN  ]] ).
# ------------------
# Verder neemt het hof in aanmerking dat de gevorderde verklaringen voor recht in deze zaak vorderingen zijn van [[  onbepaalde/ADJ  waarde/NOUN  ]] ten aanzien waarvan – anders dan [appellant] meent – duidelijke aanwijzingen bestaan dat die vorderingen ook geen hogere waarde vertegenwoordigen dan € 1.750,-.
# ------------------
# Verder neemt het hof in aanmerking dat de gevorderde verklaringen voor recht in deze zaak vorderingen zijn van onbepaalde waarde ten aanzien waarvan – anders dan [appellant] meent – [[  duidelijke/ADJ  aanwijzingen/NOUN  ]] bestaan dat die vorderingen ook geen hogere waarde vertegenwoordigen dan € 1.750,-.
# ------------------
# Verder neemt het hof in aanmerking dat de gevorderde verklaringen voor recht in deze zaak vorderingen zijn van onbepaalde waarde ten aanzien waarvan – anders dan [appellant] meent – duidelijke aanwijzingen bestaan dat die vorderingen ook geen [[  hogere/ADJ  waarde/NOUN  ]] vertegenwoordigen dan € 1.750,-.
# ------------------
# Zij hebben betrekking op dezelfde rechtsvraag, namelijk of [appellant] onverschuldigd een bedrag van € 1.170,54 aan premie en [[  buitengerechtelijke/ADJ  kosten/NOUN  ]] heeft betaald.
# ------------------
# Het hof komt daardoor niet toe aan een [[  inhoudelijke/ADJ  behandeling/NOUN  ]] van de zaak en zal [appellant] niet-ontvankelijk verklaren in zijn vordering in hoger beroep.
# ------------------
# Het hof komt daardoor niet toe aan een inhoudelijke behandeling van de zaak en zal [appellant] niet-ontvankelijk verklaren in zijn vordering in [[  hoger/ADJ  beroep/NOUN  ]] .
# ------------------
# Omdat hij in het ongelijk zal worden gesteld, zal het hof [appellant] veroordelen tot betaling van de proceskosten in [[  hoger/ADJ  beroep/NOUN  ]] .
# ------------------
# Het hof:
#
# verklaart [appellant] niet-ontvankelijk in zijn [[  hoger/ADJ  beroep/NOUN  ]] tegen het vonnis van de kantonrechter in de rechtbank Gelderland, zittingsplaats Arnhem, op 1 juni 2022;
#
# veroordeelt
# ------------------
# Uitspraak op het [[  hoger/ADJ  beroep/NOUN  ]] tegen de uitspraak van de rechtbank Zeeland-West-Brabant van 27 oktober 2015, 15/3618 (aangevallen uitspraak)
#
# Partijen:
#
#       [appellant]
# ------------------
# te [woonplaats] (appellant)
#
# de Raad van bestuur van het [[  Uitvoeringsinstituut/ADJ  werknemersverzekeringen/NOUN  ]] (Uwv)
#
# Datum
# ------------------
# Namens appellant heeft mr. J.A.J. Dappers, advocaat, [[  hoger/ADJ  beroep/NOUN  ]] ingesteld.
# ------------------
# Nu appellant sindsdien niet opnieuw heeft voldaan aan de [[  zogenoemde/ADJ  wekeneis/NOUN  ]] , zodat geen nieuw recht op een WW-uitkering is ontstaan.
# ------------------
# Nu appellant sindsdien niet opnieuw heeft voldaan aan de zogenoemde wekeneis, zodat geen [[  nieuw/ADJ  recht/NOUN  ]] op een WW-uitkering is ontstaan.
# ------------------
# Er is niet gebleken van concrete [[  ondubbelzinnige/ADJ  toezeggingen/NOUN  ]] door een daartoe bevoegde persoon waaraan appellant een rechtens te honoreren verwachting kan ontlenen dat hem een WW-uitkering zal worden toegekend.
# ------------------
# Er is niet gebleken van [[  concrete/ADJ  ondubbelzinnige/ADJ  toezeggingen/NOUN  ]] door een daartoe bevoegde persoon waaraan appellant een rechtens te honoreren verwachting kan ontlenen dat hem een WW-uitkering zal worden toegekend.
# ------------------
# Er is niet gebleken van concrete ondubbelzinnige toezeggingen door een daartoe [[  bevoegde/ADJ  persoon/NOUN  ]] waaraan appellant een rechtens te honoreren verwachting kan ontlenen dat hem een WW-uitkering zal worden toegekend.
# ------------------
# Evenmin heeft appellant aannemelijk gemaakt dat een [[  dergelijke/ADJ  toezegging/NOUN  ]] tijdens een telefoongesprek met een medewerker van het Uwv zou zijn gedaan.
#
# 3.1.
# ------------------
# In [[  hoger/ADJ  beroep/NOUN  ]] heeft appellant ter zitting erkend dat voor hem per 5 januari 2015 geen nieuw recht op een WW-uitkering is ontstaan.
# ------------------
# In hoger beroep heeft appellant ter zitting erkend dat voor hem per 5 januari 2015 geen [[  nieuw/ADJ  recht/NOUN  ]] op een WW-uitkering is ontstaan.
# ------------------
# Het [[  hoger/ADJ  beroep/NOUN  ]] is beperkt tot de vraag of bij appellant een rechtens te honoreren verwachting is gewekt dat hij met ingang van 5 januari 2015 in aanmerking zou worden gebracht voor een WW-uitkering.
# ------------------
# Uit het voorgaande blijkt dat de werkcoach informatie aan appellant heeft verstrekt over de WW en dat afspraken met hem zijn gemaakt in het kader van zijn re-integratie op basis van de WW. Hoewel voorstelbaar is dat appellant hieruit heeft afgeleid dat hem een WW-uitkering zou worden verstrekt, is geen sprake van concrete, [[  ondubbelzinnige/ADJ  toezeggingen/NOUN  ]] daarover.
# ------------------
# Evenmin blijkt dat bij appellant het vertrouwen is gewekt dat de werkcoach een [[  dergelijke/ADJ  toezegging/NOUN  ]] zou kunnen doen.
#
# 4.3.
# ------------------
# Tegen deze uitspraak heeft [appellante] [[  hoger/ADJ  beroep/NOUN  ]] ingesteld.
# ------------------
# [appellante] betoogt dat de rechtbank ten onrechte heeft geoordeeld dat de Belastingdienst/Toeslagen zich terecht op het standpunt heeft gesteld dat zij geen recht op kinderopvangtoeslag heeft omdat zij [[  onvoldoende/ADJ  bewijsstukken/NOUN  ]] heeft overgelegd.
# ------------------
# Het had op de weg van de Belastingdienst/Toeslagen gelegen om contact met haar op te nemen, omdat sprake is van bewijsnood en naar een [[  redelijke/ADJ  oplossing/NOUN  ]] had moeten worden gezocht, aldus [appellante].
#
# 3.1.
# ------------------
# [appellante] heeft in reactie op de [[  laatste/ADJ  brief/NOUN  ]] een jaaropgave van de Sociale Dienst, maar niet de gevraagde gegevens overgelegd.
# ------------------
# De rechtbank heeft gelet op het voorgaande terecht en op [[  goede/ADJ  gronden/NOUN  ]] geoordeeld dat de Belastingdienst/Toeslagen zich terecht op het standpunt heeft gesteld, dat [appellante] onvoldoende bewijsstukken heeft overgelegd om het recht op kinderopvangtoeslag over 2010 te kunnen vaststellen.
# ------------------
# De rechtbank heeft gelet op het voorgaande terecht en op goede gronden geoordeeld dat de Belastingdienst/Toeslagen zich terecht op het standpunt heeft gesteld, dat [appellante] [[  onvoldoende/ADJ  bewijsstukken/NOUN  ]] heeft overgelegd om het recht op kinderopvangtoeslag over 2010 te kunnen vaststellen.
# ------------------
# Ook in [[  hoger/ADJ  beroep/NOUN  ]] heeft [appellante] geen bewijs kunnen leveren van de gemaakte kosten.
# ------------------
# Tegen deze uitspraak heeft [appellant] bij brief, bij de Raad van State ingekomen op 5 oktober 2011, [[  hoger/ADJ  beroep/NOUN  ]] ingesteld.
# ------------------
# [appellant] betoogt dat de rechtbank ten onrechte heeft geoordeeld dat uit de processen-verbaal van bevindingen en rapportages van de politie valt af te leiden dat in de inrichting [[  illegale/ADJ  gokactiviteiten/NOUN  ]] hebben plaatsgevonden als bedoeld in de Wet op de kansspelen.
# ------------------
# Uitspraak na vereenvoudigde behandeling (artikel 8:54 van de [[  Algemene/ADJ  wet/NOUN  ]] bestuursrecht (hierna: de Awb)) in het geding tussen:
#
# [appellant], wonend te Molenschot, gemeente Gilze en Rijen,
# appellant,
#
# en
#
# de raad van de gemeente Gilze en Rijen,
# verweerder.
# ------------------
# Mede gelet op de aard en omvang van de [[  ruimtelijke/ADJ  ontwikkelingen/NOUN  ]] die op de door [appellant] bestreden plandelen mogelijk worden gemaakt is deze afstand naar het oordeel van de Afdeling te groot om een rechtstreeks bij het bestreden besluit betrokken belang te kunnen aannemen.
# ------------------
# Voorts heeft [appellant] geen feiten of omstandigheden aangevoerd in verband waarmee zou moeten worden geoordeeld dat ondanks deze afstand een objectief en [[  persoonlijk/ADJ  belang/NOUN  ]] van hem rechtstreeks door het besluit zou worden geraakt.
# ------------------
# Bij dit besluit heeft verweerder beslist op het bezwaar van appellante tegen het besluit van 17 mei 2004, waarbij verweerder zijn [[  eerder/ADJ  besluit/NOUN  ]] tot toekenning aan appellante van akkerbouwsteun over het jaar 2002 in het kader van de Regeling (EG) steunverlening akkerbouwgewassen (hierna: de Regeling) heeft herzien en de uitbetaalde subsidie gedeeltelijk heeft teruggevorderd.
# ------------------
# Appellante heeft bij brief van 2 november 2006 meegedeeld geen [[  nadere/ADJ  behandeling/NOUN  ]] ter zitting te wensen.
# ------------------
# De door appellante overgelegde beschikking op bezwaar, waarbij dat bezwaar gegrond is verklaard, heeft betrekking op een zaak waarin er onvoldoende [[  duidelijke/ADJ  satellietbeelden/NOUN  ]] aanwezig waren om uit te sluiten dat er op een bepaald perceel een akkerbouwgewas had gestaan.
# ------------------
# De door appellante overgelegde beschikking op bezwaar, waarbij dat bezwaar gegrond is verklaard, heeft betrekking op een zaak waarin er [[  onvoldoende/ADJ  duidelijke/ADJ  satellietbeelden/NOUN  ]] aanwezig waren om uit te sluiten dat er op een bepaald perceel een akkerbouwgewas had gestaan.
# ------------------
# Omdat in het geval van appellante wel voldoende [[  duidelijke/ADJ  satellietbeelden/NOUN  ]] beschikbaar zijn, is van een vergelijkbaar geval geen sprake.
# ------------------
# Omdat in het geval van appellante wel [[  voldoende/ADJ  duidelijke/ADJ  satellietbeelden/NOUN  ]] beschikbaar zijn, is van een vergelijkbaar geval geen sprake.
# ------------------
# Omdat in het geval van appellante wel voldoende duidelijke satellietbeelden beschikbaar zijn, is van een [[  vergelijkbaar/ADJ  geval/NOUN  ]] geen sprake.
# ------------------
# Appellante is derhalve gehouden om van haar stelling, dat op het [[  bewuste/ADJ  perceel/NOUN  ]] een akkerbouwgewas is verbouwd, bewijs op perceelsniveau te leveren.
# ------------------
# Dat aan appellante eerder wel subsidie is toegekend, staat er niet aan in de weg dat een [[  latere/ADJ  aanvraag/NOUN  ]] wordt getoetst aan gedetailleerde controlegegevens zoals satellietopnames, die inmiddels ter beschikking van verweerder zijn gekomen.
# ------------------
# De pas ter zitting door appellante geopperde mogelijkheid van een [[  ander/ADJ  gewas/NOUN  ]] of braaklegging van het perceel is dan ook niet onderzocht.
# ------------------
# De eveneens eerst ter zitting door appellante opgeworpen stelling dat het perceel in het najaar van 1991 kan zijn omgeploegd met het oog op de teelt van een akkerbouwgewas in 1992, acht verweerder zonder [[  nader/ADJ  bewijs/NOUN  ]] evenmin afdoende om het preceel premiewaardig te achten.
# ------------------
# Hij verkeerde in de veronderstelling dat appellante had doorgegeven niet op de hoorzitting te zullen verschijnen en was niet bekend met naar zeggen van appellante gemaakte afspraken dat in overleg met haar een [[  nieuwe/ADJ  datum/NOUN  ]] voor een hoorzitting zou worden vastgesteld.
#
# 4.
# ------------------
# Voorts is terugvordering van de reeds uitbetaalde steun in het [[  onderhavige/ADJ  geval/NOUN  ]] onredelijk omdat het niet juist is om appellante op basis van achteraf verkregen bewijsmateriaal af te rekenen op vermeende onregelmatigheden.
# ------------------
# Voorts is terugvordering van de reeds uitbetaalde steun in het onderhavige geval onredelijk omdat het niet juist is om appellante op basis van achteraf verkregen bewijsmateriaal af te rekenen op [[  vermeende/ADJ  onregelmatigheden/NOUN  ]] .
# ------------------
# Appellante heeft in 2002 gehandeld op basis van de op dat moment [[  bekende/ADJ  informatiebronnen/NOUN  ]] .
# ------------------
# Het [[  bevreemdt/ADJ  appellante/NOUN  ]] dat - nu voor de aanvraagperiode 2005 een nieuwe definitie akkerland gehanteerd wordt
# ------------------
# Het bevreemdt appellante dat - nu voor de aanvraagperiode 2005 een [[  nieuwe/ADJ  definitie/NOUN  ]] akkerland gehanteerd wordt
# ------------------
# Er wordt in de optiek van appellante voorbijgegaan aan het feit dat er ook nog [[  andere/ADJ  akkerbouwgewassen/NOUN  ]] kunnen zijn geteeld dan wel een vorm van (groene) braak is toegepast.
# ------------------
# Dat ontneemt appellante niet het recht om, als verweerder aan zijn bevindingen vervolgens de conclusie verbindt, dat de ten onrechte toegekende premie over [[  eerdere/ADJ  jaren/NOUN  ]] teruggevorderd moet worden, alsnog deze bevindingen ter discussie te stellen.
# ------------------
# Het betoog van appellante dat perceelsgebonden bewijs in de praktijk niet of nauwelijks bestaat en dat het voor appellante, gelet op de emigratie van de [[  voormalige/ADJ  eigenaar/NOUN  ]] van het perceel, al helemaal onmogelijk was om bewijs terzake te achterhalen, ontslaat haar niet van de verplichting de subsidiewaardigheid van het door haar opgegeven perceel in een geval als het onderhavige desgevraagd met stukken te onderbouwen.
# ------------------
# Bovendien had het op de weg van appellante gelegen om bij de ingebruikname van het betrokken perceel, op welk moment er nog contact bestond met de [[  voormalige/ADJ  eigenaar/NOUN  ]] , om bewijs te vragen.
# ------------------
# Voorzover appellante heeft willen betogen dat de toekenning van akkerbouwpremie over het [[  eerdere/ADJ  jaar/NOUN  ]] 2002 een fout als hierbovenbedoeld zou opleveren, wijst het College dit betoog van de hand.
# ------------------
# Verweerder is in het [[  onderhavige/ADJ  geval/NOUN  ]] pas op de hoogte geraakt van het feit dat het betrokken perceel niet voldeed, nadat GeoRas in 2003 een teledetectiecontrole had uitgevoerd.
# 5.5	Het standpunt van appellante dat de toegepaste sanctie onevenredig is, kan het College niet onderschrijven.
# ------------------
# Appellante heeft de verklaring van verweerder dat zij zelf van het houden van de hoorzitting heeft afgezien eerst ter zitting bestreden en daartegenover gesteld dat haar bij haar afzegging een [[  nieuwe/ADJ  hoorzitting/NOUN  ]] was toegezegd.
# ------------------
# Uit een oogpunt van [[  efficiënte/ADJ  procesvoering/NOUN  ]] had van appellante verwacht mogen worden dat zij reeds in het beroepschrift, doch in elk geval vóór de zitting, haar van de weergave in het bestreden besluit en het verweerschrift afwijkende relaas naar voren had gebracht.
# ------------------
# Tegen deze uitspraak hebben [appellant] en anderen [[  hoger/ADJ  beroep/NOUN  ]] ingesteld.
# ------------------
# Tegen deze uitspraak hebben [appellant] en [[  anderen/ADJ  hoger/ADJ  beroep/NOUN  ]] ingesteld.
# ------------------
# [appellant] en anderen hebben een [[  nader/ADJ  stuk/NOUN  ]] ingediend.
# ------------------
# [appellant] en anderen betogen dat de rechtbank heeft miskend dat met de aangevraagde en vergunde schokgolfgenerator niet de beste [[  beschikbare/ADJ  technieken/NOUN  ]] (hierna: BBT) worden toegepast, zodat de rechtbank volgens hen de rechtsgevolgen van het besluit van 11 februari 2015 ten onrechte in stand heeft gelaten.
# ------------------
# [appellant] en anderen betogen dat de rechtbank heeft miskend dat met de aangevraagde en vergunde schokgolfgenerator niet de [[  beste/ADJ  beschikbare/ADJ  technieken/NOUN  ]] (hierna: BBT) worden toegepast, zodat de rechtbank volgens hen de rechtsgevolgen van het besluit van 11 februari 2015 ten onrechte in stand heeft gelaten.
# ------------------
# Ook voeren [appellant] en anderen aan dat schokgolfgeneratoren onevenredig veel geluid produceren en hagelnetten een [[  milieuvriendelijk/ADJ  alternatief/NOUN  ]] vormen.
# ------------------
# [appellant] en anderen betogen dat de rechtbank heeft miskend dat onderzoek had moeten worden verricht naar het effect van geluidbeperkende maatregelen en alternatieven nu de [[  maximale/ADJ  geluidsnormen/NOUN  ]] onaanvaardbaar worden overschreden.
# ------------------
# In hetgeen [appellant] en anderen hebben aangevoerd, ziet de Afdeling geen aanleiding voor het oordeel dat [[  nader/ADJ  onderzoek/NOUN  ]] naar geluidbeperkende maatregelen en alternatieven had moeten plaatsvinden en de rechtbank de rechtsgevolgen daarom ten onrechte in stand heeft gelaten.
# ------------------
# Voor zover [appellant] en anderen betogen dat naast [[  natuurlijke/ADJ  personen/NOUN  ]] ook dieren bescherming behoeven tegen geluid en derhalve tegen de schokgolfgenerator, overweegt de Afdeling dat [appellant] en anderen in beroep geen gronden met deze strekking hebben aangevoerd.
# ------------------
# Aangezien het [[  hoger/ADJ  beroep/NOUN  ]] is gericht tegen de uitspraak van de rechtbank en er geen reden is waarom dit betoog niet reeds bij de rechtbank kon worden aangevoerd, en [appellant] en anderen dit uit een oogpunt van een zorgvuldig en doelmatig gebruik van rechtsmiddelen hadden behoren te doen, dient dit betoog buiten beschouwing te blijven.
#
# 4.
# ------------------
# Aangezien het hoger beroep is gericht tegen de uitspraak van de rechtbank en er geen reden is waarom dit betoog niet reeds bij de rechtbank kon worden aangevoerd, en [appellant] en anderen dit uit een oogpunt van een zorgvuldig en [[  doelmatig/ADJ  gebruik/NOUN  ]] van rechtsmiddelen hadden behoren te doen, dient dit betoog buiten beschouwing te blijven.
#
# 4.
# ------------------
# getroffen [[  voorlopige/ADJ  voorzieningen/NOUN  ]] vervallen op het moment waarop het door de raad te nemen besluit in werking treedt;
#
# VI.    veroordeelt de raad van de gemeente Leudal tot vergoeding van bij HG Beheer B.V. en [appellante] in verband met de behandeling van het beroep opgekomen proceskosten tot een bedrag van € 990,00 (zegge:
# ------------------
# Het gerechtshof heeft te beslissen op het
#
#  [[  hoger/ADJ  beroep/NOUN  ]]
# ingesteld door:
#
# [appellant]
# ,
# geboren te [geboorteplaats] op [geboortedatum],
# 			wonende te [adres],
# 			hierna te noemen appellant.
# ------------------
# Het hof heeft gehoord in [[  openbare/ADJ  raadkamer/NOUN  ]] van 17 april 2011 de advocaat-generaal en appellant.
# ------------------
# Het hof heeft kennis genomen van:
# -	het verzoekschrift, ingediend op 4 april 2011 ter griffie van de rechtbank Arnhem door appellant;
# -	het proces-verbaal van de behandeling van het verzoek door de rechtbank;
# -	voormelde beschikking van de rechtbank;
# -	de akte rechtsmiddel van 9 december 2011, opgemaakt door de griffier van de rechtbank te Arnhem, waarbij door appellant [[  hoger/ADJ  beroep/NOUN  ]] werd ingesteld tegen voormelde beschikking;
# - 	de ter zitting van het hof door appellant overgelegde pleitnota;
# -	de overige zich in het dossier bevindende stukken.
#
# OVERWEGINGEN
#
# 1.
# ------------------
# Bij brief van 15 december 2010 heeft de officier van justitie – ingevolge het bepaalde in artikel 266, [[  derde/ADJ  lid/NOUN  ]] , van het Wetboek van Strafvordering – aan appellant kennisgegeven van (verdere) vervolging af te zien.
# ------------------
# Blijkens de verklaring van appellant in [[  eerste/ADJ  aanleg/NOUN  ]] , welke hij ter zitting van het hof heeft bevestigd, heeft hij voornoemde kennisgeving op 16 december 2010 ontvangen.
# ------------------
# Blijkens de verklaring van appellant in eerste aanleg, welke hij ter zitting van het hof heeft bevestigd, heeft hij [[  voornoemde/ADJ  kennisgeving/NOUN  ]] op 16 december 2010 ontvangen.
# ------------------
# Ten aanzien van de ontvankelijkheidvraag acht het hof ten eerste van belang of de kennisgeving van niet [[  verdere/ADJ  vervolging/NOUN  ]] van 15 december 2010 aan appellant had moeten worden betekend.
# ------------------
# In de zaak tegen appellant was er geen sprake van een [[  gerechtelijk/ADJ  vooronderzoek/NOUN  ]] of voorlopige hechtenis.
# ------------------
# In de zaak tegen appellant was er geen sprake van een gerechtelijk vooronderzoek of [[  voorlopige/ADJ  hechtenis/NOUN  ]] .
# ------------------
# ’
#
# Uit het bepaalde in artikel 266, [[  derde/ADJ  lid/NOUN  ]] , van het Wetboek van Strafvordering volgt niet uitdrukkelijk dat de kennisgeving van niet verdere vervolging aan appellant moet worden betekend, te meer nu artikel 245a – anders dan de artikelen 246, 247 en 255 – van het Wetboek van Strafvordering niet van overeenkomstige toepassing wordt verklaard.
# ------------------
# ’
#
# Uit het bepaalde in artikel 266, derde lid, van het Wetboek van Strafvordering volgt niet uitdrukkelijk dat de kennisgeving van niet [[  verdere/ADJ  vervolging/NOUN  ]] aan appellant moet worden betekend, te meer nu artikel 245a – anders dan de artikelen 246, 247 en 255 – van het Wetboek van Strafvordering niet van overeenkomstige toepassing wordt verklaard.
# ------------------
# ’
#
# Uit het bepaalde in artikel 266, derde lid, van het Wetboek van Strafvordering volgt niet uitdrukkelijk dat de kennisgeving van niet verdere vervolging aan appellant moet worden betekend, te meer nu artikel 245a – anders dan de artikelen 246, 247 en 255 – van het Wetboek van Strafvordering niet van [[  overeenkomstige/ADJ  toepassing/NOUN  ]] wordt verklaard.
# ------------------
# Gelet op de bewoordingen van artikel 267 van het Wetboek van Strafvordering volgt naar het oordeel van het hof echter desalniettemin uit het systeem van de wet dat de kennisgeving van niet [[  verdere/ADJ  vervolging/NOUN  ]] van 15 december 2010 aan appellant had moeten worden betekend (Vgl. G.J.M. Corstens, ‘Het Nederlands strafprocesrecht’, Kluwer, Deventer 2011, 7e druk, p. 531).
#
# 6.
# ------------------
# Gelet op de bewoordingen van artikel 267 van het Wetboek van Strafvordering volgt naar het oordeel van het hof echter desalniettemin uit het systeem van de wet dat de kennisgeving van niet verdere vervolging van 15 december 2010 aan appellant had moeten worden betekend (Vgl. G.J.M. Corstens, ‘Het [[  Nederlands/ADJ  strafprocesrecht/NOUN  ]] ’, Kluwer, Deventer 2011, 7e druk, p. 531).
#
# 6.
# ------------------
# Gelet op de bewoordingen van artikel 267 van het Wetboek van Strafvordering volgt naar het oordeel van het hof echter desalniettemin uit het systeem van de wet dat de kennisgeving van niet verdere vervolging van 15 december 2010 aan appellant had moeten worden betekend (Vgl. G.J.M. Corstens, ‘Het Nederlands strafprocesrecht’, Kluwer, Deventer 2011, [[  7e/ADJ  druk/NOUN  ]] , p. 531).
#
# 6.
# ------------------
# Aangezien aan appellant geen kennisgeving van niet [[  verdere/ADJ  vervolging/NOUN  ]] is betekend, is de zaak strikt genomen nog niet geëindigd.
# ------------------
# Daar zal het hof in dit geval om [[  proceseconomische/ADJ  redenen/NOUN  ]] overheen stappen omdat het Openbaar Ministerie zich in eerste aanleg en in hoger beroep uitdrukkelijk op het standpunt heeft gesteld dat de zaak tegen appellant reeds is geëindigd.
# ------------------
# Daar zal het hof in dit geval om proceseconomische redenen overheen stappen omdat het [[  Openbaar/ADJ  Ministerie/NOUN  ]] zich in eerste aanleg en in hoger beroep uitdrukkelijk op het standpunt heeft gesteld dat de zaak tegen appellant reeds is geëindigd.
# ------------------
# Daar zal het hof in dit geval om proceseconomische redenen overheen stappen omdat het Openbaar Ministerie zich in [[  eerste/ADJ  aanleg/NOUN  ]] en in hoger beroep uitdrukkelijk op het standpunt heeft gesteld dat de zaak tegen appellant reeds is geëindigd.
# ------------------
# Daar zal het hof in dit geval om proceseconomische redenen overheen stappen omdat het Openbaar Ministerie zich in eerste aanleg en in [[  hoger/ADJ  beroep/NOUN  ]] uitdrukkelijk op het standpunt heeft gesteld dat de zaak tegen appellant reeds is geëindigd.
# ------------------
# Het inleidende verzoek strekt tot toekenning van een vergoeding aan appellant op grond van artikel 591a van het Wetboek van Strafvordering ter zake van:
# - de door appellant ten behoeve van het onderzoek en de behandeling der zaak gemaakte reis- en verblijfskosten;
# - de door appellant gemaakte kosten van rechtsbijstand ad € 6.356,01, te vermeerderen met de leenrente van 9.9%;
# - schade door opsluiting, intimidatie en [[  fysiek/ADJ  geweld/NOUN  ]] ;
# - het indienen en behandelen van het verzoekschrift.
# ------------------
# De reiskosten van appellant voor het bijwonen van de behandeling van het verzoekschrift ex artikel 36 van het Wetboek van Strafvordering door de rechtbank te Arnhem op 24 maart 2010, voor het bijwonen van de behandeling van het verzoekschrift in [[  eerste/ADJ  aanleg/NOUN  ]] en in hoger beroep zijn voor toewijzing vatbaar op de voet van het bij en krachtens de Wet tarieven in strafzaken bepaalde.
# ------------------
# De reiskosten van appellant voor het bijwonen van de behandeling van het verzoekschrift ex artikel 36 van het Wetboek van Strafvordering door de rechtbank te Arnhem op 24 maart 2010, voor het bijwonen van de behandeling van het verzoekschrift in eerste aanleg en in [[  hoger/ADJ  beroep/NOUN  ]] zijn voor toewijzing vatbaar op de voet van het bij en krachtens de Wet tarieven in strafzaken bepaalde.
# ------------------
# Voor vergoeding van de kosten verbonden aan de indiening en de behandeling van dit verzoekschrift, zoals verzocht bestaat geen ruimte, nu appellant het verzoekschrift zelf heeft opgesteld en zich ook in [[  eerste/ADJ  aanleg/NOUN  ]] en in hoger beroep niet heeft laten vertegenwoordigen door een raadsman.
# ------------------
# Voor vergoeding van de kosten verbonden aan de indiening en de behandeling van dit verzoekschrift, zoals verzocht bestaat geen ruimte, nu appellant het verzoekschrift zelf heeft opgesteld en zich ook in eerste aanleg en in [[  hoger/ADJ  beroep/NOUN  ]] niet heeft laten vertegenwoordigen door een raadsman.
# ------------------
# Het hof:
#
# -	vernietigt de beschikking waarvan beroep en kent aan appellant toe op gronden als hiervoor omschreven een vergoeding uit ’s Rijks kas ten bedrage van € 6.451,41 (zesduizend vierhonderd eenenvijftig  euro en eenenveertig cent) en gelast de tenuitvoerlegging daarvan;
#
# -	wijst af hetgeen meer of anders is verzocht;
#
# -	beveelt de griffier om [[  bovenstaand/ADJ  bedrag/NOUN  ]] over te maken op het bankrekeningnummer[nummer]
# ------------------
# te [woonplaats] (appellante)
#
# het college van burgemeester en wethouders van Almere (college)
#
# PROCESVERLOOP
# Namens appellante heeft mr. S.W.C. Bonnet, advocaat, [[  hoger/ADJ  beroep/NOUN  ]] ingesteld.
# ------------------
# Appellante ontving na het overlijden van haar echtgenoot sinds februari 2009 een nabestaandenuitkeringuitkering ingevolge de [[  Algemene/ADJ  nabestaandenwet/NOUN  ]] van de Sociale verzekeringsbank (Svb).
# ------------------
# Appellante ontving na het overlijden van haar echtgenoot sinds februari 2009 een nabestaandenuitkeringuitkering ingevolge de Algemene nabestaandenwet van de [[  Sociale/ADJ  verzekeringsbank/NOUN  ]] (Svb).
# ------------------
# In [[  voornoemde/ADJ  periode/NOUN  ]] stond appellante ingeschreven op het adres
# ------------------
# Naar aanleiding van diverse [[  anonieme/ADJ  meldingen/NOUN  ]] , inhoudende, voor zover van belang, dat [L.] samenwoont met appellante op haar adres hebben het samenwerkingsverband Sociale Recherche Flevoland (sociale recherche Flevoland), op verzoek van het college, en de sociale recherche in dienst van de Svb (sociale recherche Svb) een gecombineerd onderzoek ingesteld naar de rechtmatigheid van onderscheidenlijk de aan [L.] verleende bijstand en de aan appellante verleende nabestaandenuitkering.
# ------------------
# Naar aanleiding van [[  diverse/ADJ  anonieme/ADJ  meldingen/NOUN  ]] , inhoudende, voor zover van belang, dat [L.] samenwoont met appellante op haar adres hebben het samenwerkingsverband Sociale Recherche Flevoland (sociale recherche Flevoland), op verzoek van het college, en de sociale recherche in dienst van de Svb (sociale recherche Svb) een gecombineerd onderzoek ingesteld naar de rechtmatigheid van onderscheidenlijk de aan [L.] verleende bijstand en de aan appellante verleende nabestaandenuitkering.
# ------------------
# Naar aanleiding van diverse anonieme meldingen, inhoudende, voor zover van belang, dat [L.] samenwoont met appellante op haar adres hebben het samenwerkingsverband Sociale Recherche Flevoland ( [[  sociale/ADJ  recherche/NOUN  ]] Flevoland), op verzoek van het college, en de sociale recherche in dienst van de Svb (sociale recherche Svb) een gecombineerd onderzoek ingesteld naar de rechtmatigheid van onderscheidenlijk de aan [L.] verleende bijstand en de aan appellante verleende nabestaandenuitkering.
# ------------------
# Naar aanleiding van diverse anonieme meldingen, inhoudende, voor zover van belang, dat [L.] samenwoont met appellante op haar adres hebben het samenwerkingsverband Sociale Recherche Flevoland (sociale recherche Flevoland), op verzoek van het college, en de [[  sociale/ADJ  recherche/NOUN  ]] in dienst van de Svb (sociale recherche Svb) een gecombineerd onderzoek ingesteld naar de rechtmatigheid van onderscheidenlijk de aan [L.] verleende bijstand en de aan appellante verleende nabestaandenuitkering.
# ------------------
# Naar aanleiding van diverse anonieme meldingen, inhoudende, voor zover van belang, dat [L.] samenwoont met appellante op haar adres hebben het samenwerkingsverband Sociale Recherche Flevoland (sociale recherche Flevoland), op verzoek van het college, en de sociale recherche in dienst van de Svb ( [[  sociale/ADJ  recherche/NOUN  ]] Svb) een gecombineerd onderzoek ingesteld naar de rechtmatigheid van onderscheidenlijk de aan [L.] verleende bijstand en de aan appellante verleende nabestaandenuitkering.
# ------------------
# In het kader van dit onderzoek is onder [[  andere/ADJ  dossieronderzoek/NOUN  ]] verricht, zijn inlichtingen ingewonnen over het verbruik van water en elektriciteit op beide adressen en zijn appellante en [L.] verhoord.
# ------------------
# Voor de periode van 23 mei 2011 tot en met 18 oktober 2011 heeft het college hieraan ten grondslag gelegd dat [L.] een [[  gezamenlijke/ADJ  huishouding/NOUN  ]] heeft gevoerd met appellante.
# ------------------
# ...
# ------------------
# Appellanten hebben met verwijzing naar hun [[  financiële/ADJ  situatie/NOUN  ]] aangevoerd dat er dringende redenen zijn op grond waarvan het college had moeten afzien van het opleggen van een boete.
# ------------------
# Appellanten hebben met verwijzing naar hun financiële situatie aangevoerd dat er [[  dringende/ADJ  redenen/NOUN  ]] zijn op grond waarvan het college had moeten afzien van het opleggen van een boete.
# ------------------
#  [[  Dringende/ADJ  redenen/NOUN  ]] als bedoeld in artikel 18a, zevende lid, aanhef en onder b, van de WWB moeten zijn gelegen in onaanvaardbare sociale of financiële consequenties van de boete voor appellanten.
# ------------------
# Dringende redenen als bedoeld in artikel 18a, [[  zevende/ADJ  lid/NOUN  ]] , aanhef en onder b, van de WWB moeten zijn gelegen in onaanvaardbare sociale of financiële consequenties van de boete voor appellanten.
# ------------------
# Dringende redenen als bedoeld in artikel 18a, zevende lid, aanhef en onder b, van de WWB moeten zijn gelegen in onaanvaardbare sociale of [[  financiële/ADJ  consequenties/NOUN  ]] van de boete voor appellanten.
# ------------------
# In wat appellanten hebben aangevoerd liggen geen [[  dringende/ADJ  redenen/NOUN  ]] in voornoemde zin besloten.
#
# 4.13.
# ------------------
# In wat appellanten hebben aangevoerd liggen geen dringende redenen in [[  voornoemde/ADJ  zin/NOUN  ]] besloten.
#
# 4.13.
# ------------------
# Voor zover appellanten met de stelling dat ten onrechte geen rekening is gehouden met de [[  psychische/ADJ  problemen/NOUN  ]] van appellant heeft willen betogen dat sprake is van verminderde verwijtbaarheid, houdt die stelling geen stand.
# ------------------
# De [[  beschikbare/ADJ  gegevens/NOUN  ]] bieden geen aanknopingspunten voor de conclusie dat sprake was van verminderde verwijtbaarheid van appellant.
# ------------------
# Tussen partijen is niet in geschil dat appellanten sinds 22 augustus 2014 een bijstandsuitkering ontvangen en dat de boete dient te worden gematigd op grond van de [[  financiële/ADJ  omstandigheden/NOUN  ]] van appellanten.
# ------------------
# Gelet op 4.14 moet bij de vaststelling van de boete in acht worden genomen dat appellanten deze in twaalf maanden uit de voor hen geldende [[  beslagvrije/ADJ  ruimte/NOUN  ]] bij een inkomen op bijstandsniveau kunnen voldoen.
# ------------------
# Aanleiding bestaat om het college te veroordelen in de kosten van appellanten in bezwaar, beroep en [[  hoger/ADJ  beroep/NOUN  ]] .
# ------------------
# De [[  Centrale/ADJ  Raad/PROPN  ]] van Beroep
#
# - vernietigt de aangevallen uitspraak voor zover het betreft de boete;
# - verklaart het beroep tegen het besluit van 8 december 2014, waarbij het bezwaar tegen het
#
#   besluit van 1 juli 2014 ongegrond is verklaard (bestreden besluit 3), gegrond en vernietigt
#   dat besluit;
#
# - herroept het besluit van 1 juli 2014;
# - stelt het bedrag van de boete vast op € 1.691,17 en bepaalt dat deze uitspraak in zoverre in
#   de plaats treedt van het vernietigde bestreden besluit 3;
# - bevestigt de aangevallen uitspraak voor het overige voor zover aangevochten;
# - veroordeelt het college in de kosten van appellanten tot een bedrag van in totaal € 2.970,-;
# - bepaalt dat het college aan appellanten het in beroep en in hoger beroep betaalde griffierecht
#   van € 168,- vergoedt.
# ------------------
# De Centrale Raad van Beroep
#
# - vernietigt de aangevallen uitspraak voor zover het betreft de boete;
# - verklaart het beroep tegen het besluit van 8 december 2014, waarbij het bezwaar tegen het
#
#   besluit van 1 juli 2014 ongegrond is verklaard (bestreden besluit 3), gegrond en vernietigt
#   dat besluit;
#
# - herroept het besluit van 1 juli 2014;
# - stelt het bedrag van de boete vast op € 1.691,17 en bepaalt dat deze uitspraak in zoverre in
#   de plaats treedt van het vernietigde bestreden besluit 3;
# - bevestigt de aangevallen uitspraak voor het overige voor zover aangevochten;
# - veroordeelt het college in de kosten van appellanten tot een bedrag van in [[  totaal/ADJ  €/NOUN  ]] 2.970,-;
# - bepaalt dat het college aan appellanten het in beroep en in hoger beroep betaalde griffierecht
#   van € 168,- vergoedt.
# ------------------
# De Centrale Raad van Beroep
#
# - vernietigt de aangevallen uitspraak voor zover het betreft de boete;
# - verklaart het beroep tegen het besluit van 8 december 2014, waarbij het bezwaar tegen het
#
#   besluit van 1 juli 2014 ongegrond is verklaard (bestreden besluit 3), gegrond en vernietigt
#   dat besluit;
#
# - herroept het besluit van 1 juli 2014;
# - stelt het bedrag van de boete vast op € 1.691,17 en bepaalt dat deze uitspraak in zoverre in
#   de plaats treedt van het vernietigde bestreden besluit 3;
# - bevestigt de aangevallen uitspraak voor het overige voor zover aangevochten;
# - veroordeelt het college in de kosten van appellanten tot een bedrag van in totaal € 2.970,-;
# - bepaalt dat het college aan appellanten het in beroep en in [[  hoger/ADJ  beroep/NOUN  ]] betaalde griffierecht
#   van € 168,- vergoedt.
#    18  Datum uitspraak
#    17  op het
#    17  van de
#    17
#
# Centrale
#    16  van Beroep
#    15  1
#
#    15  uitspraak:
#    14  het hoger
#    13  tegen de
#    13  hoger beroep
#    12  Beroep
#
#    12  Meervoudige kamer
#    12  kamer
#
#
#    12  ],
#    12  ,
#
#    12  de rechtbank
#    11
#
# [
#    11  Raad van
#    10  beroep van
#    10  in de
#     9
# BESTUURSRECHTSPRAAK
#     9
#
# Uitspraak
#     8
#
# AFDELING
#     8
# Het
#     7  Centrale Raad
#     7  appellante]
#     7  Uitspraak op
#     7
# Meervoudige
#     7  de zaak
#     7
#
# Datum
#     7  van
#
#
#     7  : 17
#     7  van het
#     6
# Datum
#     6  aangevallen uitspraak
#     6
#
# U
#     6  woonplaats]
#     6  te [
#     6  2024
#
#
#     6  [appellant
#     6
#
# Meervoudige
#     6  in hoger
#     6  .
#
#
#     6  verloop van
#     6  AFDELING
#
#     6  [appellante
#     5  in het
#     5  besluit van
#     5  U I
#     5  .
#
#     5  :
#
#
#     5  zaak van
#     5  van:
#     5  van 9
#     5  ,
#
#
#     5  WAO
#
#
#     5  Het verdere
#     5  verdere verloop
#     5  de inhoud
#     5  inhoud van
#     4  R A
#     4  voor het
#     4  2017
#
#
#     4  uitspraak van
#     4  appellant]
#     4
# wonende
#     4  Team Handelsrecht
#     4  BESTUURSRECHTSPRAAK
#
#
#     4  . [
#     4  I T
#     4  T S
#     4  beroep
#
#
#     4  ] (
#     4  fosfaatrecht van
#     4  ) heeft
#     4  verwijst naar
#     4  de derde
#     3  )
#
#
#     3  P R
#     3  N.V.
#
#
#     3  van Beroep
#
#     3  WW
#
#     3  2016
#
#
#     3  Uitspraak in
#     3  AWB 04/1062
#     3
#
#       [
#     3  2014
#
#
#     3  Partijen:
#     3  uitspraak)
#     3
#
# in
#     3  [woonplaats
#     3  ]
#
#     3  ] ,
#     3  arrest van
#     3  advocaat:
#     3  zaaknummer 200.308.021/01
#     3  17 juli
#     3  200104033/1.
#     3  en 200104033/1
#     3  de gedingen
#     3  1.
#     3  2002
#
#
#     3  tussen:
#     3  gevestigd te
#     3
#
# 1.1
#     3  september 2019
#     3  hof neemt
#     3  uit:
#     3  geding in
#     3  blijkt uit
#     3  1.2
#
#     3  memorie van
#     3  10 september
#     3  het geding
#     3  besluit)
#     3  eerste aanleg
#     3  GERECHTSHOF TE
#     3  voor burgerlijke
#     3  Bij besluit
#     3
# Enkelvoudige
#     3  college heeft
#     3  procedure bij
#     3  juni 2017
#     3
#
# Partijen
#     3  1.1.
#     3  werkzaam bij
#     3  de hoger
#     3  rechtbank Maastricht
#     3  , 15/7772
#     3  september 2017
#     3  15
#
#     3  15/7771 WWB
#     2  2 november
#     2  :
#
#     2  2009 van
#     2  verwerkt.
#     2  18 september
#     2  Procesverloop
#
#
#     2  van appellante
#     2  A K
#     2  2.
#     2  17 december
#     2  Algemene wet
#     2  Maatschap A
#     2  College van
#     2
#
# AWB
#     2  23 augustus
#     2  anderen,
#     2  Avnr:
#     2
#
# Het
#     2  heeft te
#     2
# 19
#     2  2013,
#     2  GERECHTSHOF ’
#     2  te duiden
#     2
#
# [appellant
#     2
#
# Team
#     2
# advocaat
#     2  aan te
#     2  het hof
#     2  de procedure
#     2
#
# zaaknummer
#     2  april 2024
#     2  juli 2002
#     2  , beiden
#     2  gedingen tussen
#     2  , wonend
#     2  Hoorn,
#     2  S P
#     2  08/4109 WAO
#     2  het tussenarrest
#     2  Het hof
#     2  tussenarrest van
#     2  :
#
#     2  van antwoord
#     2  - de
#     2  blijkt uit:
#     2  artikel 23
#     2
#
# Bij
#     2  verweerder op
#     2  heeft verweerder
#     2  van artikel
#     2  van 3
#     2  eerste kamer
#     2  burgerlijke zaken
#     2  kantoorhoudende te
#     2  LEEUWARDEN
#
#
#     2  beroep ingesteld
#     2  februari 2022
#     2  hof verwijst
#     2  22 februari
#     2  (hierna
#     2  rechtbank Rotterdam
#     2
#
# op
#     2  Beroep
#
#
#     2  : appellante
#     2  de gemeente
#     2  de Raad
#     2  Proces-verbaal van
#     2  Amsterdam van
#     2  de uitspraak
#     2  , wonende
#     2
#
# tegen
#     2  : 26
#     2  H 176/09
#     2  december 2009
#     2  te B
#     2  2019
#
#     2  van 17
#     2  titel 4.5
#     2  2021 (
#     2  15/6622 ZW-T
#     2  , 15/6622
#     2  uitspraken van
#     2  19 februari
#     2  ZW,
#     2  Ruimtelijke Ordening
#     2
#
# No.
#     2  Haag van
#     2  : 7
#     2  verbindend verklaard
#     2  10/1830 (
#     2  :
#
# [
#     2  11/1731 WAJONG
#     2  beroep tegen
#     2  , 09/159
#     2  11/2114 WW
#     2  10/675 WW
#     2
# 10/675
#     2  5 juni
#     2  16 november
#     2  14/11565 en
#     2  van curator
#     2  2940 WIA
#     2  2020
#
#
#     2  15/7772 WWB
#     2  WWB,
#     1  maart 2011
#     1  AWBZ
#
#     1
# 16
#     1
# AFDELING
#     1  2022
#
#     1  november 2022
#     1  appellante verwerkt
#     1  bij tariefbeschikking
#     1  september 2010
#     1  nacalculatie 2009
#     1  2011 heeft
#     1  september 2011 heeft
#     1  voormelde tariefbeschikking
#     1  september 2011
#     1  12 september 2011
#     1  2010 de
#     1  september 2010 de
#     1  K
#
#
#     1  A K
#
#
#     1  in Wageningen
#     1  bij de
#     1  hierna:
#     1  gedaagde
#
#     1  is gevestigd
#     1  Zorgverzekeraar
#
#     1  : Menzis
#     1  gevestigd in
#     1  Menzis
#
#
#     1
# en
#     1  werknemersverzekeringen (
#     1  december 2014
#     1  in enkelvoud
#     1
#
#
#
# Uitspraak
#     1
#
#
#
# Uitspraak in
#     1  Zesde enkelvoudige
#     1
# Zesde enkelvoudige
#     1  november 2006
#     1
# 5135
#     1  te C
#     1  B,
#     1  29 november
#     1  augustus 2017
#
#
#     1  van:
#
#
#     1  201606901/2/R1.
#     1  : 05/700995-10
#     1  de beslissing
#     1
#
# hoger
#     1  05/700995-10
#
#     1  beroep
#
#     1  : 138-12
#     1
# geboren
#     1  hierna te
#     1  is ingesteld
#     1
# Avnr
#     1  het
#
#
#     1
# ingesteld
#     1  houdende de
#     1  geboren te
#     1  ] op
#     1  rechtbank Arnhem
#     1  Enkelvoudige kamer
#     1  WWB
#
#
#     1  Datum uitspraak:
#     1  (appellante
#     1  rechtbank Midden-Nederland
#     1  Raad van Beroep
#     1  ] te
#     1  maart 2013
#     1  februari 2014
#     1  hof gewezen
#     1  200.308.021/01
#
#
#     1  Wittendorp te
#     1  ,
#
#     1  april 2024
#
#
#     1  Maastricht-Airport,
#     1  ’s-HERTOGENBOSCH
#     1
# geïntimeerde
#     1  Oostenrijk)
#     1  vervolg op
#     1
#
# arrest
#     1  te Wehl
#     1
#
# GERECHTSHOF
#     1  te Maastricht-Airport
#     1  9 april
#     1
#
# zaaknummer 200.308.021/01
#     1
# ,
#     1  , 200101478/1
#     1  2]
#     1  appellanten sub
#     1  sub 1
#     1  appellanten sub 1
#     1  beiden wonend
#     1
#
# 1
#     1  [appellanten
#     1  wonend te
#     1  , gevestigd
#     1
# 10
#     1  : 6
#     1  bestuursrecht)
#     1  for the
#     1  geding tussen
#     1  het geding tussen
#     1  :
#
#
#
#     1  : 19
#     1  gemeente Terschelling
#     1  sub 2
#     1  : TCV
#     1  te Hoorn,
#     1  . [appellant
#     1
#
#
#
# AFDELING
#     1  BESTUURSRECHTSPRAAK
#
#
#
#     1
# 201207667/1/R4
#     1  augustus 2006
#     1  Beroep
#
# Meervoudige
#     1  A A
#     1  met producties
#     1  over.
#     1  verloop blijkt uit
#     1
# -
#     1  , tevens
#     1  verloop blijkt
#     1  grieven in
#     1  appel,
#     1  1.1
#
#     1  van 10 september
#     1  hier over
#     1  van 10
#     1  aan deze
#     1  de memorie
#     1  neemt de
#     1
#
# Enkelvoudige
#     1  rectificatie van
#     1
#
# het
#     1  en wethouders
#     1  17 mei
#     1  1]
#     1  3.
#     1  januari 2018
#     1  op grond
#     1  , derde
#     1  23,
#     1  derde lid
#     1  3 januari
#     1  (bestreden
#     1  , van
#     1  7 december
#     1  16 februari
#     1  de eerste
#     1  kamer voor
#     1
#
# HET
#     1  In eerste
#     1  27 augustus
#     1  augustus 2014
#     1  september 2013
#     1  : 27
#     1  juli 2015
#     1  veroordeling tot
#     1  rechtbank Amsterdam
#     1  om veroordeling
#     1  (Awb
#     1  verweerschrift ingediend
#     1  Appellant heeft
#     1  ingediend.
#     1  PROCESVERLOOP
#
#
#     1  eerste lid
#     1  tussenarresten van
#     1  het procesverloop
#     1  procesverloop tot
#     1  Ook verwijst
#     1  . Ook verwijst
#     1  heeft geoordeeld
#     1  tussenarrest heeft
#     1  dat tussenarrest heeft
#     1  juni 2021
#     1  bij het
#     1  hof
#
#
#     1  waarin het
#     1  laatste tussenarrest
#     1  beschreven.
#     1  en 22
#     1  hof verwijst naar
#     1  tussenarrest is
#     1  is beschreven
#     1  2022,
#     1  wat het
#     1  geoordeeld.
#     1  heeft geoordeeld.
#     1  de tussenarresten
#     1  WAO
#
#     1  I T S
#     1  rechtbank Almelo
#     1
#
# de
#     1  " vastgesteld
#     1  201102678/1/R3.
#     1  2 maart
#     1  Procesverloop
#
# Bij
#     1  brief,
#     1  mondelinge uitspraak
#     1  rechtbank Amsterdam van
#     1  8 maart
#     1  Oost-Brabant van
#     1  : 29
#     1  , 12/726
#     1  2007
#
#
#     1  Uitspraak op het
#     1  2016 (
#     1  om extra
#     1  (het
#     1  van 25
#     1  de aanvraag
#     1  rechtstreekse betalingen
#     1  GLB (
#     1  november 2016
#     1  Uitvoeringsregeling rechtstreekse
#     1  ),
#
#
#     1  appellante)
#     1  wonende te
#     1  18
#
#     1  6471 WAO
#     1  januari 2021
#     1  2021
#
# Centrale
#     1  	X
#     1  8 december
#     1
#
# Beschikking
#     1  Registratienummer:
#     1
# Uitspraak
#     1  : 8
#     1  HOF VAN
#     1  2009
#
#
#     1
# VAN
#     1  M.M. Malmberg
#     1  oktober 2017
#     1  artikel 8:51d
#     1  11 oktober
#     1  Tussenuitspraak met
#     1  8:51d van
#     1  de Algemene wet
#     1  2016 in
#     1  december 2016 in
#     1  het bedrijfsleven
#     1  AWB 11/176
#     1  tegen
#
#     1  5101 Regeling
#     1  , appellante
#     1
# 5101
#     1  gemachtigde:
#     1  2006
#
#
#
#
#     1
# [
#     1  BESTUURSRECHTSPRAAK
#
#     1  respectievelijk tussenuitspraak
#     1  A]
#     1  13/4039 WIA
#     1  : 18
#     1  WIA,
#     1  rechtbank Zeeland-West-Brabant
#     1  op het hoger
#     1  Zeeland-West-Brabant van
#     1  energie (
#     1  ) van
#     1  van appellant
#     1  .
#
#
#     1  (ISDE
#     1  het Uitvoeringsinstituut
#     1  uitspraak 2
#     1  28 juni
#     1  Tussenuitspraak op
#     1  op de
#     1  hoger beroepen
#     1
#
# Tussenuitspraak
#     1  RECEPS,
#     1  200809452/1/M1
#
#     1  , Ruimtelijke Ordening
#     1  juni 2009
#     1  24 juni
#     1  naam RECEPS
#     1  minister van
#     1  2001
#
#
#     1  s-Gravenhage,
#     1  mr. W.
#     1  Vijfde enkelvoudige
#     1  Beroep voor het
#     1  enkelvoudige kamer
#     1  02/1912
#     1  201507076/1/A1.
#     1  maart 2017
#
#
#     1  van 2
#     1  1 maart
#     1  rechtbank Noord-Nederland
#     1  WAZ
#
#
#     1  Den Haag
#     1  uitspraak: 7
#     1  12/7748 (
#     1  Spaargaren,
#     1
# Namens
#     1  WSF
#
#
#     1  appellant sub
#     1  de raad
#     1  verweerder.
#     1  onderzoeks- en
#     1  pluimveesector AVINED
#     1  1 april
#     1  van 1 april
#     1  en innovatieagenda
#     1  brancheorganisatie in
#     1  A. te
#     1  te B.
#     1  februari 2011
#     1  Raad van Beroep
#
#     1  (aangevallen
#     1  10/1830 (aangevallen
#     1  van bestuur
#     1
#
# Arrest
#     1  8 juni
#     1  Arrest d.d.
#     1  HET GERECHTSHOF
#     1  appellant,
#     1  d.d. 8
#     1  zaken in
#     1
# 10/671
#     1
# 11/2114
#     1  WW
#
#     1  09/559 (
#     1  4 december
#     1  ZW
#
#
#     1  12/3495 ZW
#     1  Bronnenberg,
#     1  13 februari
#     1  in zaak
#     1  PW-PV
#
#
#     1  B]
#     1  nrs. 14/11565 en
#     1  zaken nrs. 14/11565 en
#     1  [appellant]
#     1  201509095/1/A1.
#     1  2016
#
# AFDELING
#     1  13 november
#     1  26 april
#     1  WIA
#
#
#     1  13/1055 (
#     1  :
#
#
#     1
# 2
#     1  gemeente Westerveld
#     1  ])
#     1  Wapserveen,
#     1  9 februari
#     1  Het procesverloop
#     1  de mondelinge
#     1  Weide,
#     1
#              en
#     1  de zaak van
#     1  en premie
#     1  Quick Werkmaatschappij
#     1  januari 2020
#     1  13 oktober
#     1  15/304,
#     1  , 15/7771
#     1  7770 WWB
#     1  26 september 2017
#     1  de rechtbank Rotterdam
#     1  , 15/7773
#     1
#
# 15
#     1  ter zitting
#     1  der Wal

# %%
an_pattern = [     [ 
        {"LEMMA": "vergrijp"}  
    ],
]
matcher = spacy.matcher.Matcher(dutch.vocab)
matcher.add("adjective-noun", an_pattern)

count_pats = collections.defaultdict(int)

larger_rvs_advice = [] # 
for body in rechtspraak_items:
    #body = '\n'.join( item['body'] )
    doc = dutch( body )

    for sent in doc.sents:
        if not 'appellant' in sent.text.lower():
            continue
        #matches = matcher( doc )

        matches = matcher( sent )
        for match_id, start_i, end_i in matches:
            print( '------------------' )

            if 1:
                # display with some context

                print( sent[ : start_i ].text, end='' )
                print( " [[  ", end='' )
                for tok in sent[ start_i : end_i ]:
                    print(f'{tok.text}/{tok.pos_}', end='  ')
                    
                print( "]] ", end='' )
                print( sent[ end_i : ].text.rstrip() )

                # print( doc[ start_i-5 : start_i ].text, 
                #     '[',
                #     doc[ start_i : end_i ].text,
                #     ']',
                #     doc[ end_i : end_i+5 ].text,
                #     )
            if 1:
                # just count for now
                count_pats[ doc[ start_i : end_i ].text ] += 1 
    #break

for str, count in sorted( count_pats.items(), key=lambda x:x[1], reverse=True):
    print( f'{count:5d}  {str}')

# %%
import requests
r = requests.get("https://restcountries.com/v2/all")
countries = {c["name"]: c   for c in r.json()}
list( countries )

# %% [markdown]
# # Slightly less basic

# %% [markdown]
# ## Extracting patterns with rule-based matching

# %%
import wetsuite.helpers.strings

# %%
rvs = wetsuite.datasets.load('cvdr-mostrecent-text')

# %% [markdown]
# Deze verordening <verb>
# Deze uitspraak
# appellante
# bevestigt
#
# De omgevingsvergunning
#
# Het bestemmingsplan
#
#
# met ingang van

# %%
texts = []
for _, text in wetsuite.datasets.load('cvdr-mostrecent-text').data.random_sample(50):
    texts.append( text )

rechtspraak_nl = wetsuite.datasets.load('rechtspraaknl-struc')
for _, dd in rechtspraak_nl.data.random_sample(50):
    texts.append( dd.get('bodytext') )

len(texts)
# Out:
# 100

# %%
dutch  = spacy.load('nl_core_news_lg')

# %%
an_pattern = [ 
    [ 
        {"ORTH":   "Deze"},   
        {"ORTH":   {"IN":["verordening", "uitspraak"]}},   
        {"POS": {"IN":["VERB","AUX"]} } 
    ],

]

matcher = spacy.matcher.Matcher(dutch.vocab)
matcher.add("pats", an_pattern)

count_pats = collections.defaultdict(int)

for text in texts:
    doc = dutch(text)
    matches = matcher( doc )
    for match_id, start_i, end_i in matches:
        # we could mark and display them in an existing parse, but for now just count them
        #print( doc[ start_i : end_i ].text )
        count_pats[ doc[ start_i : end_i ].text ] += 1 

print( len(count_pats) )
for str, count in sorted( count_pats.items(), key=lambda x:x[1], reverse=True):
    print( f'{count:5d}  {str}')
# Out:
# 6
#    23  Deze verordening treedt
#    19  Deze verordening wordt
#    18  Deze uitspraak is
#    11  Deze verordening kan
#     7  Deze verordening is
#     5  Deze verordening verstaat

# %%
The way spacy handled entities supports this somewhat - 
it handles them as a special thing, but only barely.

You can manually mark up things as entities
 set_ents( list of Spans with labels )

You can make rules that set them, but they tend to be pattern recognition that _ignore_ context.



for example, 

patterns = [
    {"label": "PHONE_NUMBER", 
     "pattern": [
       {"ORTH": "("}, 
       {"SHAPE": "ddd"}, 
       {"ORTH": ")"}, 
       {"SHAPE": "ddd"},
       {"ORTH": "-", "OP": "?"},
       {"SHAPE": "dddd"}]}
    ]


...which matches:
(123)456-7890
(123)4567890
...and nothing else.



You can match entirely-fixed names like:

patterns = []
for name in patterns:
    patterns.append(
 		'label':'PERSON',
 		pattern:name,
    )


nlp = Dutch()
ruler = EntityRuler( nlp )
ruler.add_patterns()
