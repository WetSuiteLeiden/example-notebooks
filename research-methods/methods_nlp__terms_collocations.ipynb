# %% [markdown]
# ## Purpose of this notebook
#
# Explain what collocation analysis does.
#
# ...and how it is a tool, and what it may be good for, and what it is probably _not good enough_ for.

# %% [markdown]
# Collocations are about finding words that are next to each other more than just chance.
#
# There are many reasons to seek them out, which often filters for a specific type of collocations,
# trying to answer questions such as
# - meaningful patterns that are baked into the language, like "in terms of", and nearly-institutionalized phrases "eigen gebruik" or "echtgenoot of geregistreerde partner",
# - "what verbs do we use with this noun", e.g. we _make_ sense rather than _have_ sense
# - _fragments_ of phrases, "tijdstip zal", "verplichtingen uit", "heeft gedaan"
# - so 'statistically more common together' turns out to not be quite enough for clean output
#
# Also note that collocation analysis alone only suggests and doesn't claim something might be lexicalized/institutionalized,
# and it says even less about whether its meaning might be compositional (predictable from the parts) or are _not_ predictable from the parts (e.g. idioms).
# See also the wider term of multi-word expressions (MWE).
#
# For this and other reasons, it turns out 'statistically more common together' is a good start to start seeing phrases, though not quite enough for clean output.
#
# TODO: add some reading

# %%
# For local installs you can install the package once.   In colab you get a disposable environment and will have to start with this install each time. 
# !pip3 install wetsuite -U

# %%
import re
import random

import bs4  # BeautifulSoup is a handy way of scraping some text from HTML or XML

import wetsuite.helpers.koop_parse
import wetsuite.helpers.etree
import wetsuite.helpers.net
import wetsuite.helpers.strings
import wetsuite.helpers.collocation
import wetsuite.helpers.notebook
import wetsuite.helpers.spacy
import wetsuite.datasets

# %% [markdown]
# Fetch Burgerlijk wetboek 7 from KOOP respositories, in XML form.
#
# At 60k words this you may consider this fairly large, yet for this kind of analysis it is fairly small.
#
# But we get the answer quickly, so we can play with the various parameters.
#
# ...which we want in a demo because as we will find out,
# this whole concepts is somewhat finicky,
# in that there is no zone with best results because we never really specified
# what kind of things we find more interesting than others.

# %%
bwb7_xml  = wetsuite.helpers.net.download( 'https://repository.officiele-overheidspublicaties.nl/bwb/BWBR0005290/2008-03-26_0/xml/BWBR0005290_2008-03-26_0.xml' )
bwb7_soup = bs4.BeautifulSoup( bwb7_xml, features='xml' ) # bs4 makes it a little easier to pick things out of that XML.
sents     = []
for al in bwb7_soup.select('lid al'):
    sents.append(  ' '.join( al.find_all(string=True) )  )

# %%
# split each sentence into words - dumb version
tokenized_sents = []
for sent in sents:
    tokenized_sents.append( wetsuite.helpers.strings.simple_tokenize(sent) )

tokenized_sents[0]
# Out:
# ['De',
#  'koop',
#  'van',
#  'een',
#  'tot',
#  'bewoning',
#  'bestemde',
#  'onroerende',
#  'zaak',
#  'of',
#  'bestanddeel',
#  'daarvan',
#  'wordt',
#  'indien',
#  'de',
#  'koper',
#  'een',
#  'natuurlijk',
#  'persoon',
#  'is',
#  'die',
#  'niet',
#  'handelt',
#  'in',
#  'de',
#  'uitoefening',
#  'van',
#  'een',
#  'beroep',
#  'of',
#  'bedrijf',
#  'schriftelijk',
#  'aangegaan']

# %% [markdown]
# parameters include
#  - ***n-gram lengths to include*** - you generally don't want very long, because the more text you process,
#    the more entries there are with just one count  (frankly a problem with almost any n-gram based analysis)
#    We can cheat in the following example, again because there is not a lot of text
#
#  - what this code calls ***connectors*** - does not enter n-gram sequences with one of these words at the _edge_, but accepts them inside.
#    This is a makeshift measure to reduce the amount of somewhat-longer sequences that we pick up in the middle,
#    by ignoring anything that starts or ends with these uninteresting words.
#    (and also keeps down the unique n-gram count, and thereby memory use)
#
#  - ***minimum count*** - removes some things that would score well just because the combo happens once or twice
#
#  - ***scoring method*** on top of the basic counting statistics (mostly trying to get the numbers on a more reasonable, readable scale)

# %%
connectors = 'De de een het  dat die dit deze  van voor met in op bij om na   en of   is   aan  ook   je ik we hij    door kan zal dan als tot lid te heeft niet worden wordt waarin'.split()
gramlens   = (2,3,4,5,6,7,8)  # we can get away with larger n-grams because this is a fairly small text
mincount   = 10               # remove n-gram sequences that didn't occur very much, for cleaner results
showtop    = 500

# do the calculation
coll = wetsuite.helpers.collocation.Collocation( connectors=connectors )
for tokenized_sent in tokenized_sents: # feed in text
    coll.consume_tokens( tokenized_sent, gramlens=gramlens )
coll.cleanup_ngrams(mincount=mincount) 
print( "Scoring, showing top %d\n"%showtop)
scores = coll.score_ngrams()

# show the result
print( ' %9s   %55s    %12s %20s'%( 'score', 'n-gram', 'n-gram count', 'individual counts' ) )
for strtup, score,  tup_count, uni_counts in scores[-showtop:]:
    print( ' %9.3f   %55s    %12s %30s=%d'%(score, ' '.join(strtup),   tup_count, '*'.join(str(n) for n in uni_counts), wetsuite.helpers.collocation.product(uni_counts)) )
# Out:
# Scoring, showing top 500
#
#      score                                                    n-gram    n-gram count    individual counts
#      0.000                  handelt in de uitoefening van een beroep              14   17*1437*5847*57*3537*1759*59=2988591451947501327
#      0.000                                 ten nadele van de huurder              10           273*57*3537*5847*188=60501132707652
#      0.000                               ten nadele van de werknemer              17           273*57*3537*5847*243=78200932169997
#      0.001                     uitoefening van een beroep of bedrijf              20        57*3537*1759*59*1157*60=1452487407525180
#      0.001                                     nadele van de huurder              10               57*3537*5847*188=221615870724
#      0.001                                       bedoeld in de leden              12              308*1437*5847*118=305367339816
#      0.001        arbeidsovereenkomst of bij regeling door of namens              13    122*1157*328*26*472*1157*21=13804956218097408
#      0.001                               sluiten van de overeenkomst              14               27*3537*5847*415=231728800995
#      0.002                                   nadele van de werknemer              17               57*3537*5847*243=286450300989
#      0.002   collectieve arbeidsovereenkomst of bij regeling door of namens              13 17*122*1157*328*26*472*1157*21=234684255707655936
#      0.002                                  zijn niet van toepassing              21               549*748*3537*240=348594269760
#      0.004                                          bedoeld in lid 2              12               308*1437*628*200=55590057600
#      0.004                                       afwijking van lid 1              10                48*3537*628*341=36357190848
#      0.006                                        aanvang van de dag              10                21*3537*5847*61=26492154759
#      0.008               regeling door of namens een daartoe bevoegd              17      26*472*1157*21*1759*60*77=2423124982998720
#      0.008                              omstandigheden van het geval              15               67*3537*1453*120=41319658440
#      0.008                       zijn van overeenkomstige toepassing              14                549*3537*76*240=35418669120
#      0.011                                    indien de overeenkomst              14                   322*5847*415=781334610
#      0.014   regeling door of namens een daartoe bevoegd bestuursorgaan              17   26*472*1157*21*1759*60*77*19=46039374676975680
#      0.017                       regeling door of namens een daartoe              17         26*472*1157*21*1759*60=31469155623360
#      0.021                                          bedoeld in lid 1              36               308*1437*628*341=94781048208
#      0.021                                       uit de overeenkomst              11                   103*5847*415=249930015
#      0.021                                      indien de verhuurder              11                   322*5847*132=248520888
#      0.022                                         Indien de pachter              10                   257*5847*128=192342912
#      0.029                                uitoefening van een beroep              20                57*3537*1759*59=20923183629
#      0.029                                         Indien de rechter              13                   257*5847*168=252450072
#      0.041                                 handelt in de uitoefening              15                17*1437*5847*57=8141672691
#      0.049                                       bepaalde in artikel              10                   118*1437*515=87326490
#      0.051                                         grond van artikel              16                   119*3537*515=216765045
#      0.056                                      uitoefening van zijn              12                    57*3537*549=110683341
#      0.057                                  zijn van overeenkomstige              14                    549*3537*76=147577788
#      0.082                                         nakoming van zijn              14                    53*3537*549=102916089
#      0.085                                           zin van artikel              17                    80*3537*515=145724400
#      0.086                                              leden 2 en 3              12                118*200*859*124=2513777600
#      0.096                                              leden 1 en 2              21                118*341*859*200=6912888400
#      0.096                                     afwijking van artikel              14                    48*3537*515=87434640
#      0.129                                     termijn van opzegging              12                   134*3537*101=47869758
#      0.136                                        Voor de toepassing              14                    44*5847*240=61744320
#      0.178                                          Van de artikelen              11                     63*5847*79=29100519
#      0.211                       arbeidsovereenkomst of bij regeling              13                122*1157*328*26=1203761312
#      0.219                                          voet van artikel              11                    13*3537*515=23680215
#      0.245                                    werkgever is verplicht              10                    176*1184*84=17504256
#      0.290                                                    2 en 3              12                    200*859*124=21303200
#      0.372                                             recht op loon              12                    162*868*118=16592688
#      0.422                                                    1 en 2              24                    341*859*200=58583800
#      0.434           collectieve arbeidsovereenkomst of bij regeling              13             17*122*1157*328*26=20463942304
#      0.464                                          binnen een maand              10                    105*1759*50=9234750
#      0.499                                       eerste lid bedoelde              11                    111*628*149=10386492
#      0.661                                        recht op uitkering              13                     162*868*78=10968048
#      0.681                                overeenkomst tot wijziging              12                     415*508*43=9065260
#      0.697                                  huurder worden afgeweken              10                     188*425*77=6152300
#      1.025                                           tegen het einde              14                     94*1453*60=8194920
#      1.202                                           Van dit artikel              11                     63*133*515=4315185
#      1.362                                        Wet arbeid en zorg              10                   54*88*859*27=110213136
#      1.454                                   regeling door of namens              17                 26*472*1157*21=298172784
#      1.702                                               één of meer              13                     40*1157*92=4257760
#      2.101                                            arbeid en zorg              10                      88*859*27=2040984
#      2.336                                 rechten en verplichtingen              11                      47*859*55=2220515
#      2.541                                namens een daartoe bevoegd              17                  21*1759*60*77=170658180
#      2.558                                  Wet werk en inkomen naar              10                54*42*859*17*62=2053415448
#      2.849                                      arbeid te verrichten              16                      88*695*63=3853080
#      3.256                                                 1 onder b              12                     341*139*40=1895960
#      3.567                                         toepassing indien              15                        240*322=77280
#      3.774                                                 1 onder c              11                     341*139*29=1374571
#      3.776                                               Van artikel              10                         63*515=32445
#      3.946                                      werk en inkomen naar              10                   42*859*17*62=38026212
#      4.289                                        bedoeld in artikel             151                   308*1437*515=227936940
#      4.531                                       Wet werk en inkomen              10                   54*42*859*17=33119604
#      4.681                 namens een daartoe bevoegd bestuursorgaan              17               21*1759*60*77*19=3242505420
#      5.591                                        namens een daartoe              17                     21*1759*60=2216340
#      6.249                                                geen recht              10                        121*162=19602
#      8.668                                       binnen twee maanden              11                     105*57*100=598500
#      8.675                                      overeenkomst waarbij              12                         415*49=20335
#      8.952                  Wet werk en inkomen naar arbeidsvermogen              10             54*42*859*17*62*10=20534154480
#      9.249                                                2 bedoelde              15                        200*149=29800
#      9.612                                           koop op afstand              24                      74*868*40=2569280
#     10.284                                         krachtens artikel              21                        102*515=52530
#     10.419                                     maatregel van bestuur              19                     20*3537*21=1485540
#     10.719                                         beroep of bedrijf              32                     59*1157*60=4095780
#     11.114                                     aanspraak op vakantie              21                      49*868*40=1701280
#     11.313                                                  zou zijn              17                         57*549=31293
#     11.387                                         ingevolge artikel              15                         47*515=24205
#     11.807                                schriftelijke overeenkomst              14                         49*415=20335
#     13.024                            algemene maatregel van bestuur              19                  28*20*3537*21=41595120
#     13.812                      werk en inkomen naar arbeidsvermogen              10                42*859*17*62*10=380262120
#     14.154                                    geheel of gedeeltelijk              12                     29*1157*13=436189
#     14.498                                              andere wijze              11                         142*72=10224
#     14.646                                       zijn verplichtingen              19                         549*55=30195
#     16.527                              echtgenoot of geregistreerde              17                     24*1157*27=749736
#     16.919                                    overeenkomstig artikel              21                         62*515=31930
#     17.747                             veranderingen en toevoegingen              12                      27*859*15=347895
#     17.896                                           werk en inkomen              16                      42*859*17=613326
#     18.297                                               artikel 378              10                         515*13=6695
#     18.436                                                indien zij              21                         322*91=29302
#     18.907                                                     Lid 1              10                         19*341=6479
#     19.761                                            toe te rekenen              19                      49*695*23=783265
#     21.304                                              wijze waarop              12                         72*115=8280
#     21.624                                        verplichtingen uit              10                         55*103=5665
#     23.070                                              vorige leden              10                         45*118=5310
#     24.102                      echtgenoot of geregistreerde partner              17                  24*1157*27*24=17993664
#     24.143                                          vastgesteld loon              10                         43*118=5074
#     24.853                                     geld vastgesteld loon              10                      34*43*118=172516
#     25.146                                                dag waarop              12                         61*115=7015
#     25.578                                             andere partij              13                         142*57=8094
#     25.779                                                Wet arbeid              10                          54*88=4752
#     26.515                                                Voor zover              10                         44*105=4620
#     27.425                                         redelijke termijn              12                         48*134=6432
#     27.855                             bevoegdelijk is onderverhuurd              10                     13*1184*10=153920
#     29.474                                               binnen twee              12                         105*57=5985
#     29.898                                                   leden 2              24                        118*200=23600
#     30.922                                               artikel 634              13                         515*13=6695
#     33.494                                                   1 onder              36                        341*139=47399
#     34.591                                                binnen zes              13                         105*57=5985
#     46.677                                                1 bedoelde              44                        341*149=50809
#     46.925                                                    Boek 3              19                         76*124=9424
#     47.188                                             bepaalde tijd              20                         118*88=10384
#     49.000                                                vorige zin              12                          45*80=3600
#     49.359                                                  ten dele              11                         273*11=3003
#     49.704                                                 ten laste              12                         273*13=3549
#     49.941                                           tijdstip waarop              19                         77*115=8855
#     50.054                                           bedongen arbeid              13                          47*88=4136
#     51.872                                                 ten tijde              17                         273*25=6825
#     52.339                                         vastgestelde loon              11                         24*118=2832
#     54.012                                                  Wet werk              10                          54*42=2268
#     59.402                                                tweede zin              15                          58*80=4640
#     60.681                                                 zes jaren              12                          57*51=2907
#     63.362                                                Een beding              18                          87*72=6264
#     64.419                                                   leden 1              46                        118*341=40238
#     67.009                                               ieder geval              16                         39*120=4680
#     68.376                                                   onder c              15                         139*29=4031
#     70.133                                                  In geval              23                         77*120=9240
#     72.488                                             rechter wijst              13                         168*17=2856
#     74.108                                                 zes weken              10                          57*29=1653
#     76.629                                           daartoe bevoegd              17                          60*77=4620
#     79.459                                                eerste zin              24                         111*80=8880
#     80.994                                               ten gevolge              19                         273*20=5460
#     83.789                                          geld vastgesteld              10                          34*43=1462
#     94.426                                               ten hoogste              22                         273*23=6279
#     95.366                                  gebouwde onroerende zaak              12                      15*26*166=64740
#    100.862                                          gedeelte daarvan              17                         30*117=3510
#    102.083                                     uitkering gerechtigde              13                          78*26=2028
#    103.444                                                zou hebben              19                          57*75=4275
#    103.513                                                 één maand              13                          40*50=2000
#    104.664                                                 vijf jaar              13                          23*86=1978
#    116.224                                              inkomen naar              10                          17*62=1054
#    123.789                                              twee maanden              24                         57*100=5700
#    126.906                                                   onder b              24                         139*40=5560
#    131.250                                            zich daartegen              12                         112*12=1344
#    132.432                                  schriftelijke mededeling              14                          49*37=1813
#    134.615                                                ten minste              30                         273*30=8190
#    135.737                                               ten behoeve              33                         273*36=9828
#    141.158                            daartoe bevoegd bestuursorgaan              17                       60*77*19=87780
#    143.182                                           passende arbeid              12                          14*88=1232
#    160.417                                              In afwijking              22                          77*48=3696
#    164.508                                                   onder a              28                         139*42=5838
#    170.533                                              drie maanden              23                         38*100=3800
#    170.697                           collectieve arbeidsovereenkomst              17                         17*122=2074
#    175.417                                               ten aanzien              41                         273*43=11739
#    175.610                                              der partijen              24                          41*98=4018
#    177.392                                           onroerende zaak              25                         26*166=4316
#    197.581                                      naar arbeidsvermogen              10                          62*10=620
#    230.588                                        natuurlijk persoon              16                          16*85=1360
#    241.986                                    bevoegd bestuursorgaan              17                          77*19=1463
#    248.439                                               zes maanden              34                         57*100=5700
#    255.769                                                ten nadele              57                         273*57=15561
#    257.895                                                ene partij              12                          12*57=684
#    265.636                                             stand gekomen              11                          31*18=558
#    280.729                                           onbepaalde tijd              22                          24*88=2112
#    316.720                                           dringende reden              11                          18*26=468
#    348.158                                overeenkomstige toepassing              72                         76*240=18240
#    350.000                                        gewichtige redenen              10                          14*25=350
#    406.784                              inkomen naar arbeidsvermogen              10                       17*62*10=10540
#    447.391                                                  ter zake              42                         105*46=4830
#    452.308                                       gebouwde onroerende              12                          15*26=390
#    475.352                                                    Boek 6              41                          76*57=4332
#    779.545                                                  los land              14                          14*22=308
#    789.688                                        algemene maatregel              19                          28*20=560
#    914.969                                    geregistreerde partner              22                          27*24=648
#   1008.824                                            dien verstande              28                          34*28=952
#   1085.121                                        aangetekende brief              16                          17*17=289

# %% [markdown]
# ## Similar, in gensim
# Note that collocations are simple enough that a lot of NLP libraries do something like it, sometimes with their own take on it.
#
# See e.g. [this NLTK example](https://www.nltk.org/howto/collocations.html),
# or the below code for gensim (see als [docs](https://radimrehurek.com/gensim/models/phrases.html))

# %%
# gensim separates building a model. 
# Note that the below code uses the input both to build the model, and to then look in the same text.

from gensim.models.phrases import Phrases

phrase_model = Phrases(tokenized_sents, min_count=3, threshold=0.4, connector_words=connectors, scoring='npmi', delimiter=' ')

for phrase, score in sorted( phrase_model.find_phrases( tokenized_sents ).items(), key=lambda x:x[1], reverse=True)[:500]: 
    firstword,rest = phrase.split(' ',1) # (gensim deals with varied-n-grams with a simpler interface)
    print('%5.2f  %20s %-20s'%(score,firstword,rest))
# Out:
#  1.00             gedateerd ontvangstbewijs
#  1.00                  PbEG L
#  1.00               geldsom leent
#  1.00                  2002 65
#  1.00            wederzijds goedvinden
#  1.00              uiterste wilsbeschikking
#  1.00               Wetboek van Burgerlijke
#  1.00                  Onze Minister
#  1.00                 tafel en bed
#  1.00                    II van de Huisvestingswet
#  1.00           uitvoerbaar bij voorraad
#  1.00           Burgerlijke Rechtsvordering
#  1.00                 meest gerede
#  1.00                natuur en landschap
#  1.00                   332 333
#  1.00  Uitvoeringsinstituut werknemersverzekeringen
#  1.00             structuur uitvoeringsorganisatie
#  1.00                mannen en vrouwen
#  1.00               sociaal fiscaalnummer
#  1.00         verschillende werkgevers
#  1.00             elkanders opvolger
#  0.99          aangetekende brief
#  0.98             maatregel van bestuur
#  0.98         geregistreerd partnerschap
#  0.98          persoonlijke levenssfeer
#  0.98             nagelaten betrekkingen
#  0.98             richtlijn nr
#  0.97                  dien verstande
#  0.97               verwijt treft
#  0.97                   429 430
#  0.97          bevoegdelijk is onderverhuurd
#  0.96             stichting of vereniging
#  0.96        geregistreerde partner
#  0.96        Uitvoeringswet huurprijzen
#  0.96                  plan van aanpak
#  0.95              openbare registers
#  0.95              Centrale Grondkamer
#  0.95               ondanks waarschuwing
#  0.95               afhangt of kan afhangen
#  0.95             onderling verhaal
#  0.95                   los land
#  0.95              algemene maatregel
#  0.94            feitelijke stoornis
#  0.94               toonder of order
#  0.93         zwangerschaps of bevallingsverlof
#  0.92              regeling door of namens
#  0.92                   46e en 46f
#  0.92           toekomstige verbintenissen
#  0.92                 bloed of aanverwant
#  0.92                vanuit financieel
#  0.91         elektronische berichten
#  0.91                rechte lijn
#  0.91  schuldsaneringsregeling natuurlijke
#  0.90            echtgenoot of geregistreerde
#  0.90            zorgvuldig schuldenaar
#  0.90              handelen of nalaten
#  0.90                 Dagen of gedeelten
#  0.90              seksuele intimidatie
#  0.90            duidelijke en begrijpelijke
#  0.90     verjaringstermijn te lopen
#  0.90           ondertekend geschrift
#  0.89            financieel toezicht
#  0.89    gemeenschappelijke huishouding
#  0.89               geldend bestemmingsplan
#  0.89                   237 van het Wetboek
#  0.89        kwijtschelding van de reissom
#  0.89             onbekwame minderjarige
#  0.89              Europese Unie
#  0.89                geheel of gedeeltelijk
#  0.89              waarborg biedt
#  0.89         elektronische contactgegevens
#  0.89                aantal vakantiedagen
#  0.88              gebouwde onroerende
#  0.88          zwangerschap of bevalling
#  0.88         veranderingen en toevoegingen
#  0.88                 kende of behoorde
#  0.88           onevenredig wordt geschaad
#  0.88                  werk en inkomen
#  0.87              eigenaar vruchtgebruiker
#  0.87                 allen tijde
#  0.87              bezwaren aan de zijde
#  0.87                  Boek 6
#  0.87         eigenschappen bezit
#  0.87         werkelijkheid niet aanwezig
#  0.87          aanverwanten in de rechte
#  0.87              ernstige overlast
#  0.87               minimum te boven
#  0.86             hoofdstuk II
#  0.86             kennelijk onredelijk
#  0.86              landbouw betrekkelijke
#  0.86                   ter zake
#  0.86              techniek voor communicatie
#  0.86               oogpunt onvoldoende
#  0.86                   327 328
#  0.86              gebonden te willen
#  0.86                   toe te rekenen
#  0.86            gewichtige redenen
#  0.85                 bloed of aanverwanten
#  0.85              algemeen verkrijgbare
#  0.85             Behoudens tegenbewijs
#  0.85                   per week
#  0.85              behoorde te kennen
#  0.85                   252 en 253
#  0.85                  kent of behoort
#  0.84             dringende reden
#  0.84               terzake bijstand
#  0.84            bijzondere onderhandelingsgroep
#  0.84                beroep of bedrijf
#  0.83                 ertoe strekt
#  0.83          zelfstandige woning
#  0.83            opgemaakte akte
#  0.83                    zo spoedig
#  0.83                   had behoren
#  0.83                  dood of letsel
#  0.83               daarbij een last
#  0.83               daaruit voortvloeiende
#  0.83          rechterlijke uitspraak
#  0.83               handelt in de uitoefening
#  0.82                 boven gaat
#  0.82                elkaar opvolgende
#  0.82                 voort te zetten
#  0.82                 stand gekomen
#  0.82           geoorloofde veranderingen
#  0.82              bewoning bestemde
#  0.82              liggende bestemming
#  0.82                namens een daartoe
#  0.82             pachtjaar of het pachtseizoen
#  0.82               gelijke behandeling
#  0.82                   ene partij
#  0.82                    13 14
#  0.82                 mocht verwachten
#  0.82            aanmerking genomen
#  0.82                    25 negende
#  0.82            onbepaalde tijd
#  0.81              Europese Economische
#  0.81       overeenkomstige toepassing
#  0.81             aanspraak op vakantie
#  0.81           voorwaarden verbinden
#  0.81                    al datgene
#  0.81                 lopen met de aanvang
#  0.81             pandrecht rust
#  0.81               genoten een evenredig
#  0.81                nieuwe verjaringstermijn
#  0.81          Overeenkomst betreffende
#  0.81            onderlinge verhouding
#  0.81              leeftijd van zestien
#  0.81              teneinde ernstig
#  0.81             daaronder begrepen
#  0.80                 laten weten
#  0.80           behoorlijke bedrijfsvoering
#  0.80               bevoegd bestuursorgaan
#  0.80            gefixeerde schadevergoeding
#  0.80              dringend nodig
#  0.80               ernstig nadeel
#  0.80        geregistreerde partners
#  0.80             getroffen maatregelen
#  0.80                     d en e
#  0.80           raadpleging van werknemers
#  0.80          vervreemding of bezwaring
#  0.80           vervangende zekerheid
#  0.80                  hulp en bijstand
#  0.80            natuurlijk persoon
#  0.80                risico is gelopen
#  0.80                   wil verwezenlijken
#  0.79          aangebrachte veranderingen
#  0.79                  koop op afstand
#  0.79                  naar arbeidsvermogen
#  0.79                  Raad van de Europese
#  0.79             lidstaten van de Europese
#  0.79                  weet of behoort
#  0.79              verjaart door verloop
#  0.79              bijstand heeft verleend
#  0.79                   zes maanden
#  0.79             Dringende redenen
#  0.79             wettelijk voorgeschreven
#  0.79           onderscheid objectief
#  0.79               exploot of aangetekende
#  0.79            onverwijld medegedeelde
#  0.78                    12 13
#  0.78               billijk zal voorkomen
#  0.78         huurcommissie verzoeken
#  0.78             evenredig deel
#  0.78                   mee te werken
#  0.78                    zo nauwkeurig
#  0.78              Algemene wet
#  0.78            beslissing wordt overgelaten
#  0.78                   ten nadele
#  0.78               waarbij de ene
#  0.78      wetenschappelijk onderzoek
#  0.78                risico s
#  0.78           premievrije waarde
#  0.78                buiten rechte
#  0.78           aannemelijk maakt
#  0.77  uitvoeringsorganisatie werk
#  0.77            wettelijke vertegenwoordiger
#  0.77                behoud ervan
#  0.77              centrale ondernemingsraad
#  0.77                    SE ondernemingsraad
#  0.77                   SCE ondernemingsraad
#  0.77                begint een nieuwe
#  0.77                 diens familieleden
#  0.77           natuurlijke personen
#  0.77                  ware stand
#  0.76                  vier weken
#  0.76             Hetzelfde geldt
#  0.76              bestemde onroerende
#  0.76             termijnen wordt betaald
#  0.76                   Wet op de arbeidsongeschiktheidsverzekering
#  0.76              Europese rechtspersonen
#  0.76           verbintenis op te schorten
#  0.76                   wet overlegt
#  0.76             gedeelten van dagen
#  0.76          redelijkheid en billijkheid
#  0.76             gehandeld met het opzet
#  0.76                  naar tijdruimte
#  0.76           collectieve arbeidsovereenkomst
#  0.76                 hoeve of los
#  0.76                   der Staten
#  0.76            onderdelen a
#  0.76              indirect onderscheid
#  0.76             begrijpen de beslissing
#  0.76               genoemd in hoofdstuk
#  0.76       verwezenlijking van het risico
#  0.75          medegedeelde reden
#  0.75               zestien jaren
#  0.75            onroerende zaak
#  0.75                   der partijen
#  0.75                  drie maanden
#  0.75                zijner beschikking
#  0.75           echtgenoten of geregistreerde
#  0.75              leeftijd van twaalf
#  0.75              passende arbeid
#  0.75                 Ieder der
#  0.75       arbeidsvermogen later
#  0.75           persoonlijk in duurzaam
#  0.75                   Wet structuur
#  0.75                  akte of een afschrift
#  0.75                 wiens hulp
#  0.75               exploot of bij aangetekende
#  0.75             surséance van betaling
#  0.75                    In afwijking
#  0.74       bestemmingsplan op het verhuurde
#  0.74                zonder deugdelijke
#  0.74              daardoor lijdt
#  0.74                   wie bevoegdelijk
#  0.74                 mocht blijken
#  0.74             afwijking van het overeengekomene
#  0.74                  doen afkopen
#  0.74                 onder a
#  0.74             dwingende bepalingen
#  0.74                tijdig in het geding
#  0.74                  zich daartegen
#  0.74                  acht te nemen
#  0.74                  deel vallen
#  0.74                  iets anders
#  0.74                kennis van de ware
#  0.74           uitoefening van een beroep
#  0.74         schriftelijke mededeling
#  0.74                   ten aanzien
#  0.73             vaststaat dat strijd
#  0.73              algemeen belang
#  0.73                   oog op de omstandigheden
#  0.73               inkomen naar
#  0.73             vestiging van een pandrecht
#  0.73             verlangen of gewijzigde
#  0.73            wettelijke rente
#  0.73            aanleiding geven
#  0.73                inhoud van de rechtshandeling
#  0.73                  naam en de woonplaats
#  0.73                gerede partij
#  0.73               aanvang van de reis
#  0.72                brengt van rechtswege
#  0.72             redelijke afweging
#  0.72        tegenprestatie te herzien
#  0.72                tussen beider
#  0.72            verzekerde som
#  0.72            pachtvrije staat
#  0.72             redelijke waardering
#  0.72        overeengekomen arbeidsduur
#  0.72               daarbij behorende
#  0.72                direct onderscheid
#  0.72                  mede gelet
#  0.72                  naar evenredigheid
#  0.72            verwijzing naar
#  0.72              aanwezig is geweest
#  0.72                zoveel mogelijk
#  0.72            grondkamer herziet
#  0.72            uitkomsten van de te verrichten
#  0.72                   rol werknemers
#  0.71                  mede te delen
#  0.71              begrepen degenen
#  0.71               negende lid van de Wet
#  0.71                 onder b
#  0.71                   ten minste
#  0.71                    48 c
#  0.71                    Na het verstrijken
#  0.71              toestemt in een redelijk
#  0.71                  vijf jaar
#  0.71                  twee maanden
#  0.71                   ten behoeve
#  0.71                   één maand
#  0.71               aanvang van de dag
#  0.71               daartoe aanleiding
#  0.71             uitkering gerechtigde
#  0.71             verzoeken uitspraak
#  0.71              beperken tot zodanig
#  0.71               kortere duur
#  0.71                  658a lid 4
#  0.70           betreffende los
#  0.70                 nemen in werkelijkheid
#  0.70                  dood of de ondercuratelestelling
#  0.70         verschuldigde gefixeerde
#  0.70                 wijze van informatieverstrekking
#  0.70           verbintenis van de hoofdschuldenaar
#  0.70                   Elk beding
#  0.70                     4 wordt verdeeld
#  0.70              gemaakte kosten
#  0.70              gerichte verklaring
#  0.70                 zoals een goed
#  0.70           handelingen op het gebied
#  0.70                  vijf jaren
#  0.70                  dier zake
#  0.70              gedeelte daarvan
#  0.70                  naar maatstaven
#  0.70                verder aansprakelijk
#  0.70                   zou hebben
#  0.70               behalve op bedrijfsruimte
#  0.69                  geld vastgesteld
#  0.69                 rente en kosten
#  0.69              verschil tussen
#  0.69            hoofdelijk verbonden
#  0.69           arbeidsduur per
#  0.69             artikelen 313
#  0.69            betrekking hebbende
#  0.69                  geld vastgestelde
#  0.69              gebouwde met het oog
#  0.69              Bedingen waarbij
#  0.69                 leden 1–2
#  0.69        voortvloeiende rechten
#  0.69                 eigen naam
#  0.69               verband houdende
#  0.69          gerechtigden tot een vergoeding
#  0.69            berekening van de schadeloosstelling
#  0.69      rechtsverhouding tot de reisorganisator
#  0.69                  deel uitmaakt
#  0.69              gebreken of ongeschiktheid
#  0.69                  vast te stellen
#  0.69                ziekte verhinderd
#  0.69                  acht weken
#  0.68                  naar billijkheid
#  0.68             vestiging of overdracht
#  0.68             opgezegde huurovereenkomst
#  0.68              verleend is vernietigbaar
#  0.68                 jaren heeft bereikt
#  0.68          veroorzaakte schade
#  0.68                   zes weken
#  0.68           bestanddeel daarvan
#  0.68               bedoeld in artikel
#  0.68              duurzaam gebruik
#  0.68                   ten hoogste
#  0.68        onherroepelijk is beslist
#  0.68               Wanneer de nalatenschap
#  0.68            voorgaande leden
#  0.68               beperkt gerechtigde
#  0.68                  maar korter
#  0.68                   214 van Boek
#  0.68                  zorg van een goed
#  0.67                  vast De toewijzing
#  0.67                bekend was
#  0.67                  zorg te dragen
#  0.67          onderhuurder aan wie
#  0.67             artikelen 450
#  0.67                  duur van de vertraging
#  0.67             pachtjaar volgende
#  0.67              Partijen kunnen
#  0.67                 einde van de pacht
#  0.67               rechter wijst
#  0.67        overeenkomstig de verwachtingen
#  0.67            bijzondere omstandigheden
#  0.67             onderdeel a
#  0.67                 lager is dan de waarde
#  0.67                   ten gevolge
#  0.67                ziekte zwangerschap
#  0.66               verband met ongeschiktheid
#  0.66              bereiken over
#  0.66                 geldt als een veroordeling
#  0.66               geleden schade
#  0.66               daartoe bevoegd
#  0.66               anderen dan de patiënt
#  0.66           verzekeraar te misleiden
#  0.66                   ter plaatse
#  0.66            verhinderd was
#  0.66            verhinderd is de bedongen
#  0.66                   had mogen
#  0.66               bekwame tijd
#  0.66                   ter bevordering
#  0.66        onherroepelijk is geworden
#  0.66             redelijke voorschriften
#  0.66                wegens de omstandigheid
#  0.66               verloop van zes
#  0.66              ontstane kosten
#  0.66             verhuurde persoonlijk
#  0.66          redelijkheid van het voorstel
#  0.66             verrichte arbeid
#  0.66               tijdvak dat het Uitvoeringsinstituut
#  0.66   arbeidsovereenkomst of bij regeling
#  0.65                 onder c
#  0.65               rechten of vorderingen
#  0.65               tijdvak waarover
#  0.65                   267 van Boek
#  0.65             gedurende hetwelk
#  0.65                eerste zin
#  0.65              ernstige reden
#  0.65                wenden met de vordering
#  0.65               aangaan van een nieuwe
#  0.65        rechtspersonen dan wel
#  0.65                 leden 1–3
#  0.65             verhuurde duurzaam
#  0.65          rechtstreeks betrekking
#  0.65                   zes jaren
#  0.65                 ieder geval
#  0.65             verpachte is gelegen
#  0.65          communicatie op afstand
#  0.65              waarover de pachtprijs
#  0.65          onmiddellijk verband
#  0.65                 enige wettelijke
#  0.65               gronden vermeld
#  0.65                  tien jaar
#  0.65            hoofdelijk aansprakelijk
#  0.65       redelijkerwijze geacht
#  0.65               rechten en verplichtingen
#  0.65                   dag waartegen
#  0.65                   had moeten
#  0.65                   uit hoofde
#  0.65                nadeel voor de patiënt
#  0.65                   uit te spreken
#  0.64             redelijke verhouding
#  0.64          inschrijving van de koop
#  0.64                   Wet werk
#  0.64                binnen bekwame
#  0.64                binnen dertig
#  0.64                   ter hand
#  0.64            bepalingen van deze titel
#  0.64               datgene te doen
#  0.64                aanbod tot het aangaan
#  0.64                   zou leiden
#  0.64          vermindering van de pachtprijs
#  0.64                aanbod tot schenking
#  0.64              belangen is uitgesloten
#  0.64                    In geval
#  0.64              bedoelde minimum
#  0.64                  Voor de berekening
#  0.64                   dag volgende
#  0.64                eerste volzin
#  0.64                arbeid en zorg
#  0.64                twaalf jaren
#  0.64                tweede zin
#  0.64                    64 eerste
#  0.64                   Een beding
#  0.64                   één of meer
#  0.64                 vanaf het tijdstip
#  0.64                tweede volzin
#  0.64                eerste graad
#  0.64          vastgestelde loon
#  0.64                  doet eindigen
#  0.64            beslissing tot toewijzing
#  0.64        bedrijfsruimte in de zin
#  0.64                  komt de bevoegdheid
#  0.63               gesteld desverlangd
#  0.63                     c d
#  0.63                     c en d
#  0.63                opgave te verstrekken
#  0.63             artikelen 252
#  0.63                wegens gewichtige
#  0.63               verband houdt
#  0.63              ontstaan waarvan
#  0.63                 gelet op de aard
#  0.63          vernietiging van de schenking
#  0.63                    48 b
#  0.63         toegankelijke wijze
#  0.63                beding dat afwijkt
#  0.63                   wet optreedt
#  0.63                   Bij een consumentenkoop
#  0.63                   ten dele
#  0.63                arbeid te verrichten
#  0.63                    13 van Boek
#  0.63               verzoek van de meest
#  0.63                beroep op de vernietigingsgrond
#  0.63            verrichten van diensten
#  0.63          vervreemding van het verpachte
#  0.63                   ten laste
#  0.63           uitoefening van de landbouw
#  0.63                ingang van een in het vonnis
#  0.63                  gaat kan voorzover
#  0.63                 staat van faillissement
#  0.63        redelijkerwijs mocht
#  0.62                   Wet rol
#  0.62                vorige zin
#  0.62                twaalf maanden
#  0.62                  reis reeds

# %% [markdown]
# Something we probably _should_ touch on in more detail is that the scoring is central to what is even lifted out.
#
# Gensim works differently from our code (based on a little more consideration), so gives different results.

# %% [markdown]
# ## Now with more text

# %%
# Get a bunch more text

# while we're at it, get a spacy model to split sentences, 
# which should reduce the amount of across-sentence-boundary nonsense
# probably doesn't win a lot, but it's simple enough to do

paragraphs  = []
for bwbid, text in wetsuite.datasets.load('bwb-mostrecent-text').data.random_sample(12500):
    paragraphs.extend( re.split(r'[\s]{2,}', text) )


coll = wetsuite.helpers.collocation.Collocation( connectors=connectors )

for paragraph in wetsuite.helpers.notebook.ProgressBar(paragraphs, description='splitting sentences'):
    if len(paragraph) >= 1000000: # spacy refuses (without you upping the limit) for GPU memory reasons
        continue
    # Yes, we could do a full spacy parse, but it would be slower.  sentence_split is  faster and good enough for now.
    sents = wetsuite.helpers.spacy.sentence_split( paragraph, as_plain_sents=True )
    for sent in sents:
        toks = wetsuite.helpers.strings.simple_tokenize(sent)
        coll.consume_tokens( toks, gramlens=(2,3,4,5) )
# Out:
# splitting sentences:   0%|          | 0/293188 [00:00<?, ?it/s]

# %%
print( "Cleanup")
print( '    before:', coll.counts() )
coll.cleanup_ngrams(mincount=8)
print( '     after:', coll.counts() )
# Out:
# Cleanup
#     before: {'from_tokens': 19810501, 'unigrams': 167786, 'ngrams': 10053537}
#      after: {'from_tokens': 19810501, 'unigrams': 167786, 'ngrams': 369461}

# %%
top = 2000
print( "Scoring, showing top %d\n"%top)
scores = coll.score_ngrams( )
print( ' %9s   %55s    %12s %20s'%('score', 'n-gram', 'n-gram count', 'individual counts') )
for strtup, score,  tup_count, uni_counts in scores[-top:]:
    print( ' %9.3f   %55s    %12s %20s=%d'%(score, ' '.join(strtup),   tup_count, '*'.join(str(n) for n in uni_counts), wetsuite.helpers.collocation.product(uni_counts)) )
# Out:
# Scoring, showing top 2000
#
#      score                                                    n-gram    n-gram count    individual counts
#    171.261                polycyclische aromatische koolwaterstoffen              49            51*71*166=601086
#    171.304                    preconcurrentieel ontwikkelingsproject              29                62*97=6014
#    171.500                                  dynamisch aankoopsysteem              14                56*25=1400
#    171.709                     Helicopter landing officer Genormeerd              10          17*68*42*18=873936
#    171.721                                 basisregistratie kadaster             169              705*289=203745
#    171.742                                      Beroepsopleiding VAM              16                22*83=1826
#    171.762                                                   St Goar              12                79*13=1027
#    171.818                    arbeidsondersteuning jonggehandicapten              36               56*165=9240
#    172.154                                           principle based              11                21*41=861
#    172.592                              Verrekeningen verdragslanden              16                23*79=1817
#    172.695                                         Bestuurszaken afd              17                50*41=2050
#    172.856                                  Ruilverkavelingswet 1954              24               26*157=4082
#    172.941                          verkeerskundige landschappelijke              12                12*85=1020
#    172.953                                                 Perna Spp              13                21*57=1197
#    173.082                                Helicopter landing officer              14             17*68*42=48552
#    173.218                                           Stof Percentage              19                69*37=2553
#    173.643                                                   A17 A18              16                42*43=1806
#    173.698                                Rechtspositiebesluit raads              72               457*80=36560
#    173.713                                            eenden duikers              45               238*60=14280
#    173.817                             marktordening gezondheidszorg             273             291*1805=525255
#    173.971                            Senior National Representative              26             70*68*35=166600
#    173.986                                       Grenswaarde Maximum              14                23*60=1380
#    174.023                     betaalgedrag Melding betalingsonmacht               8              8*73*27=15768
#    174.222                                        vrouwelijk jongvee               8                25*18=450
#    174.263                                        Justitieel Incasso              26               144*33=4752
#    174.688                                                    zg vis             265              621*793=492453
#    174.914                                          1499 Netlevering              17                22*92=2024
#    175.000                                              zweer beloof              36               81*112=9072
#    175.073                                               606 2700 ML              42            80*100*54=432000
#    175.608                                       hypothecair krediet              68               72*448=32256
#    175.674                                        steun huurwoningen             226             1113*320=356160
#    175.765                                           normaal kubieke             163              418*443=185174
#    175.857                                                      µg l             270             316*1607=507812
#    175.931                                     portefeuillehouder BF               9                47*12=564
#    176.036                             toetsingscommissie euthanasie              47               183*84=15372
#    176.458                                                   A28 A29              11                28*30=840
#    176.544                                            706 Paragrafen              14                68*20=1360
#    176.833                                                   1388 NC              42               47*260=12220
#    176.934                      standaardrekenmethode luchtkwaliteit              28               46*118=5428
#    177.190                                     stedelijk focusgebied              17               111*18=1998
#    177.376                                   substituut ombudsmannen              16               104*17=1768
#    177.536                                            God Almachtich              10                69*10=690
#    177.631                                     Georganiseerd Overleg              35               44*192=8448
#    177.778                                                   ARR ARR              16                42*42=1764
#    178.624                                          NT2 Profieltoets              13                61*19=1159
#    178.662                                                   NC HVDC              95              260*238=61880
#    178.820                                          ongewoon voorval              56               63*341=21483
#    178.927                                      Universitair Medisch              27               31*161=4991
#    178.995                                                vice versa              32               219*32=7008
#    179.016                                                   IOP TTI              11                46*18=828
#    179.094                     transactiegerelateerde adviesdiensten              10                18*38=684
#    179.324                                           H3E J3C J3E R3E              43          55*93*55*55=15472875
#    179.344                                                   A16 A17              17                47*42=1974
#    179.592                                          macro omzetgrens              62               285*92=26220
#    179.674                                                   A15 A16              18                47*47=2209
#    179.716                         eindverantwoordelijk professional              45              107*129=13803
#    179.755                                               β agonisten               9                23*24=552
#    180.147                                     gebitsschade gebroken              10                10*68=680
#    180.738                           vethoudende scheepsafvalstoffen              12                16*61=976
#    180.738                                  kinderarts subspecialist               9                 61*9=549
#    180.764                                      nominale rekenpremie             133              875*137=119875
#    180.854                                   zeilend passagiersschip              16               17*102=1734
#    180.872                            Maritieme Veiligheidscommissie              22               149*22=3278
#    181.036                                                   Lw Tech              78              248*166=41168
#    181.068                                    Productioneel Protocol              81               81*548=44388
#    181.213                                                     ro ro              15                39*39=1521
#    181.332                    modelverklaring Herplaatsingsonderzoek              45               304*45=13680
#    181.332                                Bijdrage Asielzoekers REBA               9              38*56*9=19152
#    181.481                                 Nederlandschen Marineraad              14                27*49=1323
#    181.583                                                  WVW 1994             356             386*2215=854990
#    181.601                                     anorganische deklagen              13                60*19=1140
#    181.653                                           onroerende zaak            1341            2594*4675=12126950
#    181.731                             Adviesraad programmaonderzoek               9                39*14=546
#    181.741                                      Vervoer dagbesteding             269             461*1058=487738
#    181.858                                    Garantiewet Surinaamse              29               55*103=5665
#    181.894                                  beschrijvend casuïstisch              21                90*33=2970
#    181.931                                     proeftuin kortdurende              15               15*101=1515
#    182.043                                              case reports              12                51*19=969
#    182.112                                         Economische Zaken            1746            2866*7155=20506230
#    182.172                                                   ISO IEC             161              838*208=174304
#    182.179                                          ERA NET HYCO EOS               8          27*25*11*71=527175
#    182.792                                       Veeziektenfonds PPE              62               93*277=25761
#    182.955                                         beeldende kunsten              69               322*99=31878
#    183.057                                                wil zeggen             418             2037*574=1169238
#    183.251                                 kennelijke onredelijkheid              21               134*22=2948
#    183.263                                                  F1 F2 F3               8             31*21*23=14973
#    183.333                                 huisvestingscomponent nhc              22                42*77=3234
#    183.482                                           AI Major Hazard              12             77*19*23=33649
#    183.727                            expertisecentrum onderwijszorg              20               127*21=2667
#    183.750                                  vaccinbroedeieren inlegt               9                15*36=540
#    183.971                                      best practice guides              19            123*36*19=84132
#    184.005                                      +25 Medeplichtigheid              17                52*37=1924
#    184.211                                          algemeenen nutte              10                19*35=665
#    184.443                                          collegial review              35               36*226=8136
#    184.484                                           Shared Services              17               19*101=1919
#    184.532                               Experimentele kaderregeling              44               51*252=12852
#    184.638                                   Stof Emissiegrenswaarde              26                69*65=4485
#    184.692                                   Lichamelijk gehandicapt              28                80*65=5200
#    184.906    slachtofferinformatiepunt schadevergoedingsmaatregelen               8                 8*53=424
#    185.079                              integere bedrijfsuitoefening              93              174*329=57246
#    185.226                                                 high care              29               54*103=5562
#    185.281                                             Vreemde Talen              11                25*32=800
#    185.390                                        Buitenlandse Zaken            1233            1404*7155=10045620
#    185.690                      Subsidieprogramma SDG Results Access               9          114*22*9*29=654588
#    185.906                                                   9000 GT              38               55*173=9515
#    186.048                                         privatisering ABP              99              147*439=64533
#    186.667                                                   A39 A40               8                20*21=420
#    186.727                                     hedendaagse beeldende              69               97*322=31234
#    187.001                                  stoten bedrijfsonderdeel              32                78*86=6708
#    187.041                                    Elektriciteitswet 1998             332             341*2117=721897
#    187.100                                             Zeer moeilijk              74              111*323=35853
#    187.560                                         waterlopen dijken              16                44*38=1672
#    187.560                            teboekgestelde Luchtvaartuigen               8                19*22=418
#    187.702                                    Taskforce DeeltijdPlus              19               124*19=2356
#    187.792                                             re integratie             176              566*357=202062
#    187.926                                         evidence informed               9                48*11=528
#    188.068                                               ten aanzien            9577          52664*11344=597420416
#    188.454                                       beschermde inheemse              64               355*75=26625
#    188.462                                        opschalingsfase 1+              12                72*13=936
#    188.462                               gastouderbureaus gastouders               8                13*32=416
#    188.818                                      boter consumptiemelk              23               143*24=3432
#    188.840                                   aanhangwagens opleggers              67              260*112=29120
#    189.043                              volgestorte kredietprotectie              10                24*27=648
#    189.298                  gemeenschappelijk afwikkelingsmechanisme              87               563*87=48981
#    189.628                                            geneticus 0390              10                34*19=646
#    189.789                                              cross border              11                71*11=781
#    190.030                                            zweer verklaar              34                81*92=7452
#    190.527                                overeenkomstige toepassing            8286           9131*48345=441438195
#    190.556                            aanzichten details maatvoering               8             10*48*30=14400
#    190.675                                          micro organismen             124              224*441=98784
#    190.736                          rechtspersoonlijkheid bezittende              60               367*63=23121
#    190.738                               Specifiek interventiebeleid              96              157*377=59189
#    190.909                                    Cochleaire implantaten              12                12*77=924
#    190.909                                    cochleaire implantaten              12                12*77=924
#    191.040                                                    PbEG L             823            1149*3780=4343220
#    191.116                                 beoordelingsgerichte peer              12                13*71=923
#    191.141                                         getrouwe weergave              90              126*412=51912
#    191.220                                       akkerbouw weidebouw               8                41*10=410
#    191.220                                        Business 2022–2026               8                41*10=410
#    191.258                                      voetgangers fietsers              11                31*25=775
#    191.406                                             Kleine Brogel              15                96*15=1440
#    191.572                                     AI Arbeidsmarktfraude              17                77*24=1848
#    191.706                                         Support Battalion              20                71*36=2556
#    191.739                              gehonoreerde lumpsumafspraak              24               115*32=3680
#    192.006                                                25GP Visio              10                22*29=638
#    192.112                    preconcurrentieel haalbaarheidsproject              33               62*112=6944
#    192.157                                  assisterende kaakchirurg               8                 8*51=408
#    192.157                                                   Neth ER               8                 8*51=408
#    192.297                                                     pv vp               9                43*12=516
#    192.322                             homoseksuele mannen lesbische              11             25*83*13=26975
#    192.634                                           dbc zorgproduct             335             1131*631=713661
#    192.658                         buitengewoon opsporingsambtenaren            1126            5906*1365=8061690
#    192.787                                              Apparaat MRA              12                15*61=915
#    193.103                                   mutatieproces annuleert               8                29*14=406
#    193.301                                       Struthionidae emoes              13                17*63=1071
#    193.388                                           F3F H3E J3C J3E              43          51*55*93*55=14347575
#    193.421                             offshore oliewinningsplatform              12                76*12=912
#    193.580                                      vrijvarende veerpont               8                 9*45=405
#    193.758                          Gemeentelijke Basisadministratie              11                45*17=765
#    194.814                                                 BBRA 1984             160              198*813=160974
#    195.041                                               deeltjes PM              78              164*233=38212
#    195.129                                                  time out              46              108*123=13284
#    195.229                                  kunstmatige filmtechniek              18               107*19=2033
#    195.290                                                 ZrgWlz Vz              11                33*23=759
#    195.710                                         Medeplichtige –33               9                39*13=507
#    195.737                     hygiënevoorschriften pluimveehouderij              39               167*57=9519
#    196.000                                    Benthuizen Hazerswoude               8                16*25=400
#    196.015                  verzetspensioenen vervolgingsuitkeringen              23                57*58=3306
#    196.046                                        teeltseizoen huurt              26                44*96=4224
#    196.097                                               Action Task               9                11*46=506
#    196.097                                             forel meerval               9                22*23=506
#    196.117                                             getrouw beeld             157              244*631=153964
#    196.218                                                   A23 A24              12                31*29=899
#    196.454                                          Associate degree              15                23*61=1403
#    196.475                                       modelbrief verlengd             301             314*1799=564886
#    196.585                                              Front Office              11                13*58=754
#    196.656                      vaststellingsprocedure staatloosheid              12                13*69=897
#    196.875                                               H001G H005G               9                24*21=504
#    196.875                                         Asielzoekers REBA               9                 56*9=504
#    196.973                                              genre fictie              18                31*65=2015
#    197.173                                              OV chipkaart              34               189*38=7182
#    197.208                                          705 Aanpassingen              23               106*31=3286
#    197.214                                       moeilijk opvoedbare              52               323*52=16796
#    197.234                                              Nieuw Guinea              42               249*44=10956
#    197.346                                           F2B F3F H3E J3C              41          49*51*55*93=12782385
#    197.463                              geldboetes schadevergoedings              18                67*30=2010
#    197.581                                              10000 pillen              10                20*31=620
#    197.770                                    Inspectie Leefomgeving             202              961*263=252743
#    197.980                                         onderwijswet 1920              20                45*55=2475
#    197.980                                                    SFN ID              16                16*99=1584
#    198.162                                 cardiopulmonale chirurgie              11                11*68=748
#    198.406                  loopvogels Struthioniformes struisvogels              45            151*46*63=437598
#    198.715                  microbiologische laboratoriumonderzoeken              27               107*42=4494
#    198.733                                        arbeidspool zoeken              48               54*263=14202
#    199.227                                                    ad hoc              66               372*72=26784
#    199.392                                Commando Zeestrijdkrachten              46               200*65=13000
#    199.430                                             ML Zoetermeer              40               54*182=9828
#    199.445                        schonen schillen schrappen snijden               8          19*12*44*48=481536
#    199.927                                       Apparaat MRA 234190               8             15*61*15=13725
#    200.083                                     conventioneel oormerk              14                24*50=1200
#    200.272                           rechtspersoonlijkheid bezittend              60               367*60=22020
#    200.455                                gedragsstoornis verslaving               9                11*45=495
#    200.491                                                  does not              10                13*47=611
#    200.512                                           zorgnetwerk ABR              16                46*34=1564
#    200.863                                           stille reserves              58               92*223=20516
#    200.962                                       intensieve kindzorg              54               225*79=17775
#    201.268                                         gasgestookte oven               9                17*29=493
#    202.104                              tweekleurige verkeerslichten              14                22*54=1188
#    202.500                                       Pannerdensch Kanaal               9                10*49=490
#    203.025                                 veterinair beroepscollege              34               155*45=6975
#    203.168                                     hoogpathogene aviaire              54              118*149=17582
#    203.326                                         vaker inspecteert              22               108*27=2916
#    203.636                     elektronischgeldinstellingen Provisie               8                35*11=385
#    203.664                      generalistische basiszorg neurologie               9             49*12*29=17052
#    204.167                            Uniform Aanbestedingsreglement              10                40*15=600
#    204.167                                         omgekeerde osmose               8                 48*8=384
#    204.167                                                 137331 LZ              16                16*96=1536
#    204.167                      verzetspensioenen oorlogsuitkeringen              19                57*38=2166
#    204.167                                    gewelddadig extremisme              11                22*33=726
#    204.571                                        watervogels zwanen              45               258*47=12126
#    205.066                                       J2B J2C J3C F2C F3C              42       54*42*93*42*51=451799208
#    205.116                                              TV+VEV TV+EV              36                90*86=7740
#    205.236                                              Wonen Wijken              40               191*50=9550
#    205.272                              verblijfsvergunning regulier             456             1883*659=1240897
#    206.316                                 Intelligence Surveillance               8                38*10=380
#    206.316                                  spanningsloos instelbaar               8                10*38=380
#    206.316                                        instelbaar offline               8                38*10=380
#    206.474                                                       t m            2464            4279*8418=36020622
#    206.562                                       bevoegde autoriteit            1135            3532*2163=7639716
#    206.676                                              pakket thuis             155              356*400=142400
#    206.719                                         epilepsiezorg gez              18                80*24=1920
#    206.754                               beginnend beroepsbeoefenaar             141              221*533=117793
#    206.838                                 overdraagbare spongiforme              20               103*23=2369
#    207.055                                        aangetekende brief             257             327*1195=390765
#    207.407                                       Neonatale intensive               8                 9*42=378
#    207.538                               vennootschapsbelasting 1969             359              805*945=760725
#    207.699                                        Helicopter landing              14                17*68=1156
#    207.958                                            graden Celsius              35               176*41=7216
#    208.019                                       HTM Personenvervoer               9                 9*53=477
#    208.300                     Aansturen Operationele Gereedstelling              12            19*120*13=29640
#    208.333                            Deelreglement Filmactiviteiten              20                98*24=2352
#    208.358                                           Auteurswet 1912              31               113*50=5650
#    208.456                                ambergele retroreflectoren               9                17*28=476
#    208.511                                                  HS+TS MS               8                 8*47=376
#    208.695                                     rookvrije vluchtroute              13                16*62=992
#    209.654                                       Bedrijfschap Horeca              45              116*102=11832
#    209.807                                 herhaal polikliniekbezoek              31               31*181=5611
#    209.878                                                metro tram              14                22*52=1144
#    210.409                                       Reporting Standards              42               79*130=10270
#    210.729                                  Interprovinciaal Overleg              34               35*192=6720
#    210.753                           snorfietsers Sanctie modaliteit               8             28*31*15=13020
#    210.753                                           common approach              12                31*27=837
#    210.753                    verzelfstandiging Informatiseringsbank               8                31*12=372
#    212.019                                   Zevenhuizen Moerkapelle              12                32*26=832
#    212.019                                            valse meeldauw              27               156*27=4212
#    212.019                                         neuro psychologie               9                12*39=468
#    212.029                                    financiële overzichten            2611           14333*2748=39387084
#    212.674                                                     C0 C0              15                36*36=1296
#    213.043                                        Structureel versus               8                23*16=368
#    213.043                                               Bos Polaris              20                46*50=2300
#    213.043                            verkeersdelicten puntenstelsel              10                25*23=575
#    213.101                                  overdraagbare dierziekte              49              103*134=13802
#    213.308                                         no claimteruggave              70               402*70=28140
#    213.387                                           common carriers               9                31*15=465
#    214.161                                         beurze genoteerde              10                26*22=572
#    214.561                                                COPD Zware              17                66*25=1650
#    214.912                                           Aangepast Lezen              10                19*30=570
#    214.934                                    oriëntatie Accountancy              46               180*67=12060
#    215.243                                vervolgingsuitkeringen AAW              40               58*157=9106
#    215.651                                           pootklaar huurt              26                40*96=3840
#    215.651                               tandtechnicus tandtechnisch              13                30*32=960
#    215.707                                              Drentsche Aa               9                10*46=460
#    215.978                                      thermische conversie             136              363*289=104907
#    215.993                                       Lozingenbesluit Wvo              22                45*61=2745
#    216.071                                   gezindheid seksualiteit              11                49*14=686
#    216.071                                   Bescherming Koopvaardij              11                49*14=686
#    216.176                                              historie d13              12                68*12=816
#    216.176                                              historie d14              12                68*12=816
#    216.562                                        woensdag donderdag              33                80*77=6160
#    216.602                             functioneel registerbeheerder             119              376*213=80088
#    216.708                                           Leerlingen 25GR              12                37*22=814
#    216.774                                       J3E R3E F3E G3E A1C              42       55*55*58*58*42=427396200
#    217.027                                          mager melkpoeder              29               47*101=4747
#    217.107                                 geneeskundige geestelijke             556            1467*1189=1744263
#    217.312                                          KNMG anesthesist              23                71*42=2982
#    217.599                                  Bondsrepubliek Duitsland              54               54*304=16416
#    217.778                                      edelherten damherten               8                15*24=360
#    217.778                                                 day ahead               8                 45*8=360
#    218.151                                       Restgroep diagnoses              13                13*73=949
#    218.483                                                    NL IGA             195             1066*200=213200
#    218.715                              handvaardigheid handenarbeid              21                65*38=2470
#    218.860                                               ten behoeve           10015          52664*10660=561398240
#    219.358                                                    cd rom              19                72*28=2016
#    219.632                                        NS Railinfrabeheer              20                97*23=2231
#    219.797                                               Mytilus Spp              15                22*57=1254
#    219.815                                          hernieuwbaar gas             199             199*1109=220691
#    219.891                                           zorgnetwerk AMR              17                46*35=1610
#    220.011                                             Vogelwet 1936               9                11*41=451
#    220.117                                      palliatief terminale              23                32*92=2944
#    220.222                                   medisch specialistische             542             1639*997=1634083
#    220.225                                gezoneerd industrieterrein              16                16*89=1424
#    220.271                                        notities verslagen              51               55*263=14465
#    220.286                                   voortgezette beëindigde              97              321*163=52323
#    220.478                                        vloeibare biomassa             356              742*949=704158
#    220.500                                             gebrande kalk               9                18*25=450
#    221.096               struisvogels Struthionidae emoes Dromaiidae              13          63*17*63*17=1147041
#    221.191                                        stoffelijke resten              24                58*55=3190
#    221.386                              wisselende vervoersafstanden              15                83*15=1245
#    221.484                                                  e2 Ernst               9                16*28=448
#    221.887                           zeldzame landbouwhuisdierrassen              12                53*15=795
#    222.226                                       Thermofiele gisting              11                23*29=667
#    222.230                                                   IB 2001            1440            1966*5814=11430324
#    222.338                                          dinsdag woensdag              33                75*80=6000
#    222.727                                                 GI beraad              18                18*99=1782
#    223.346                                    biologisch afbreekbare              38               198*40=7920
#    223.362                                              Goede Doelen               8                27*13=351
#    223.362                                 Onthouding Verstrekkingen               8                 9*39=351
#    223.404                                          leer werktraject              30               141*35=4935
#    223.480                                     zelfgekozen bezigheid               9                12*37=444
#    223.509                                   Inventarisnummer Geheel              26                95*39=3705
#    223.798                             Handleiding Overheidstarieven              19               104*19=1976
#    223.867                                  woonwagens gereedgekomen              25               114*30=3420
#    224.000                                   patiëntmateriaal 079990               8                25*14=350
#    225.000                                            Bron Interview               9                 49*9=441
#    225.000                          Verantwoording Verzekerdenraming               9                 49*9=441
#    225.009                                                     S1 S2              23                64*45=2880
#    225.287                  innovatiesubsidie samenwerkingsprojecten              16                16*87=1392
#    225.455                                       omzetbelasting 1968             416             1641*573=940293
#    225.845                                                  1638c BW             117              125*594=74250
#    225.909                                 burger oorlogsslachtoffer              71               385*71=27335
#    225.936                        Results Access to renewable energy               9        9*29*668*9*12=18829584
#    225.955                                    meerval tilapia paling               8             23*22*24=12144
#    226.092                                     cumulatief preferente              39               123*67=8241
#    226.099                                     Wegenverkeerswet 1994             484             573*2215=1269195
#    226.240                                     wettelijk voorschrift             872            1874*2197=4117178
#    226.554                                      alcoholvrije dranken              75               79*385=30415
#    226.852                                 tijdbasis tijdbevrachting              10                10*54=540
#    227.254                                    viercijferige postcode              77               85*376=31960
#    227.764                                Landelijke Politiediensten              37               199*37=7363
#    227.817                                            gepaard gaande              98              302*171=51642
#    227.823                                          spoedig mogelijk            2260           2359*11642=27463478
#    227.907                                                10073 8000               8                 8*43=344
#    227.907                     energiebesparende isolatiemaatregelen              16                86*16=1376
#    228.073                                               Gemengde Lw              49               52*248=12896
#    228.186                                  lumpsum kwaliteitsbudget              38               57*136=7752
#    228.646                                       A3E A3C A3F F1B F2A              42       55*55*52*56*46=405204800
#    229.010                                           Midden Delfland              62               298*69=20562
#    229.240                                             oneven getale               8                 38*9=342
#    229.349                                         Chief Information              56              134*125=16750
#    229.450                                                bruine rat              11                34*19=646
#    229.450                                               Wit Rusland              11                17*38=646
#    229.568                                        gedekte obligaties              41               78*115=8970
#    229.688                                        WTZ standaardpolis               9                36*12=432
#    229.688                                           e3 Exceptionele               9                16*27=432
#    230.036                      innovatiegerichte onderzoekprogramma              17                19*81=1539
#    230.455                                     ozp stollingsfactoren              39               147*55=8085
#    230.456                                               Groene Hart              15                46*26=1196
#    230.588                                              KONINGIN DER               8                10*34=340
#    230.588                                        Facilitair Bedrijf              36                81*85=6885
#    230.588                                                    SP SEP               8                34*10=340
#    230.697                                       zaterdagen zondagen              20                36*59=2124
#    230.756                                              neikomme sil               9                10*43=430
#    231.294                                       psychologie diëtiek               9                39*11=429
#    232.008                              certificatieschema Stimulans              10                44*12=528
#    232.008                                                    JA NEE              10                48*11=528
#    232.545                                                    Lw LWT              49               248*51=12648
#    232.805        stedenbouwkundige verkeerskundige landschappelijke              12             26*12*85=26520
#    232.941                                                  BRL SIKB              59              162*113=18306
#    233.172                            kweekvis forel meerval tilapia               8          37*22*23*22=411884
#    233.333                                    Pediatrische intensive               8                 8*42=336
#    233.692                                 onevenredige bevoordeling              39               119*67=7973
#    233.727                                       A2B A3E A3C A3F F1B              42       45*55*55*52*56=396396000
#    234.244                                             bonnen zegels              42               75*123=9225
#    234.282                                                 Te denken             116              277*254=70358
#    234.674                                 Partnerschappen Politieke              20                24*87=2088
#    234.702                                        Veterinary Officer              28               33*124=4092
#    235.101                                      STAATSSECRETARIS VAN              57               57*297=16929
#    235.576                                gerechtelijk vooronderzoek              82              185*189=34965
#    235.689                                  Financieel Productioneel              81               421*81=34101
#    235.690                                        hagen boselementen              20                33*63=2079
#    235.829                      pensioengrondslagen welvaartstoeslag              12                44*17=748
#    235.830                                  corrigerende interventie             228              411*657=270027
#    236.250                                    Hogere Functionarissen               9                20*21=420
#    236.250                                    Patiëntgebonden labels               9                14*30=420
#    236.404                                                  Team IFB              22               114*22=2508
#    237.373                                         elementair chloor              19                23*81=1863
#    237.380                                   openlijke geweldpleging               9                22*19=418
#    237.576                                        Hypotheek Garantie               8                11*30=330
#    237.960                                          mondziekten kaak              26               30*116=3480
#    238.057                                           tijgermug Aedes              12                19*39=741
#    238.198                              karakteristieke geluidwering              41               65*133=8645
#    238.336                                   Justitieel Documentatie              41               144*60=8640
#    238.522                                        ambulant begeleide              36               64*104=6656
#    238.522                                                    DCO OO               9                13*32=416
#    238.540                                   majoritaire coproducent              24                58*51=2958
#    238.592                                         topstructuur DGBD              22                35*71=2485
#    238.636                                      Invorderingswet 1990             222              268*944=252992
#    238.636                                        DSC wachtontvanger              15                77*15=1155
#    239.015                                                    EN ISO             451             1244*838=1042472
#    239.024                                           assertion based               8                 8*41=328
#    239.258                                                   APA ATR              25                80*40=3200
#    239.412                                               peer review              56               71*226=16046
#    239.508                                                    NV COS              43               193*49=9457
#    239.939                                   zijdelingse afscherming              43               80*118=9440
#    240.365                                                   pick up              33               37*150=5550
#    241.549                        Continued Professional Development               8              8*20*71=11360
#    242.036                                                Kaderbg Lw              49               49*248=12152
#    242.315                                vervoerbare drukapparatuur              19                25*73=1825
#    242.517                          herstructurering varkenshouderij              50               154*82=12628
#    242.770                                                ve peuters              14                43*23=989
#    242.955                                                    >3 80A              28                59*67=3953
#    243.056                                     aantrekkende woonkern              10                12*42=504
#    243.218                                       A2C J2A J2B J2C J3C              42       42*43*54*42*93=380928744
#    243.218                                       J2A J2B J2C J3C F2C              42       43*54*42*93*42=380928744
#    243.684                                            naaste verwant              38               119*61=7259
#    243.796                                                East North               9                11*37=407
#    244.014                                           Langdurig zieke              66               71*308=21868
#    244.100                                          Productschap Vis             206              914*233=212962
#    244.568                                       A3C A3F F1B F2A F2B              41       55*52*56*46*49=361000640
#    244.830                                      Thermische conversie              76              100*289=28900
#    245.000                                  exceptionele transporten              16                20*64=1280
#    245.000                                      verdekte pepperspray              12                12*60=720
#    245.000                                                   ATH Prf              10                10*50=500
#    245.000                                                   GYM Prf              10                10*50=500
#    245.000                                                   LYC Prf              10                10*50=500
#    245.000                                     doorgaand zelfwerkend              14                49*20=980
#    245.000                                                   big bag              10                50*10=500
#    245.000                        identificatiemiddelen slachtmerken               8                 40*8=320
#    245.300                        voorwaardelijke invrijheidstelling             239              788*362=285256
# ...
#   1225.000                                        rallen steltlopers              45                45*45=2025
#   1225.000                                                   GOD ZIJ              21                21*21=441
#   1225.000                                               GOD ZIJ MET              21             21*21*35=15435
#   1225.000                                               ZIJ MET ONS              21             21*35*21=15435
#   1225.000                                  Hormoongevoelige tumoren               8                  8*8=64
#   1225.000                                slagroom banketbakkersroom              10                10*10=100
#   1225.000                                                  corn cob              11                11*11=121
#   1225.000                                              corn cob mix              11             11*11*35=4235
#   1225.000                                       Ditylenchus dipsaci              36                36*36=1296
#   1225.000                                            1045213 157958              12                12*12=144
#   1225.000                                            1356655 177439              12                12*12=144
#   1225.000                                          mutatis mutandis              19                19*19=361
#   1225.000              Uitvoeringstaken Arbeidsvoorwaardenwetgeving               9                  9*9=81
#   1225.000                                     slikmosselen slippers              12                12*12=144
#   1225.000                                      Hoogere Krijgsschool              11                11*11=121
#   1225.000                                             773523 137331              16                16*16=256
#   1225.000                                              Pels Rijcken              25                25*25=625
#   1225.000                                        Einstein Telescope               8                  8*8=64
#   1225.000                                           3257251 1015438               8                  8*8=64
#   1225.000                                           3334575 1025358              12                12*12=144
#   1225.000                                               Zoute Veren              11                11*11=121
#   1225.000                                         Aviaire Influenza              22                22*22=484
#   1225.000                                 Eengemaakt Octrooigerecht               8                  8*8=64
#   1225.000                                             Gallus gallus              12                12*12=144
#   1225.000                                    Alaskakoolvis Theragra               8                  8*8=64
#   1225.000                                     Theragra chalcogramma               8                  8*8=64
#   1225.000                                           salaire differé              18                18*18=324
#   1225.000                                glasionomeer glascarbomeer               8                  8*8=64
#   1225.000                                   glascarbomeer compomeer               8                  8*8=64
#   1225.000                            Kurzarbeitergeld Insolvenzgeld               9                  9*9=81
#   1225.000                                              Burkina Faso               9                  9*9=81
#   1225.000                                     gemarmerde stinkwants               8                  8*8=64
#   1225.000                                     stinkwants Halymorpha               8                  8*8=64
#   1225.000                                          Halymorpha halys               8                  8*8=64
#   1225.000                                      oprjochtens ferfolje               9                  9*9=81
#   1225.000              meerjarenformatiebeleid bestuursformatieplan              15                15*15=225
#   1225.000                                             192079 192080              10                10*10=100
#   1225.000                                             192080 192087              10                10*10=100
#   1225.000                                        Corporele Membraan               8                  8*8=64
#   1225.000                                       Membraan Oxygenatie               8                  8*8=64
#   1225.000                                             070801 078013               8                  8*8=64
#   1225.000                                Fractuurbehandeling 238041               8                  8*8=64
#   1225.000                                             238041 238042               8                  8*8=64
#   1225.000                                             238042 238044               8                  8*8=64
#   1225.000                                     Mandibulair Repositie              12                12*12=144
#   1225.000                                             083290 083390               9                  9*9=81
#   1225.000                                             083390 084090               9                  9*9=81
#   1225.000                                  Saccharomyces cerevisiae              12                12*12=144
#   1225.000                                                   F3E G3E              58                58*58=3364
#   1225.000                                                   A2A A2B              45                45*45=2025
#   1225.000                                                   A1C A2C              42                42*42=1764
#   1225.000                                    Pseudomonas aeruginosa              19                19*19=361
#   1225.000                                         ponds pondsgewijs              15                15*15=225
#   1225.000                                               fraus legis              10                10*10=100
#   1225.000                            Vierjarige Instellingssubsidie               9                  9*9=81
#   1225.000                                            Print Together              10                10*10=100
#   1225.000                                        Overview Continued               8                  8*8=64
#   1225.000                                 Voortijdig Schoolverlaten               9                  9*9=81
#   1225.000                                                 Hong Kong              17                17*17=289
#   1225.000                                     sleutelbeen littekens              10                10*10=100
#   1225.000                              verwerkingscentra fustopslag               8                  8*8=64
#   1225.000                                     fustopslag dockboards               8                  8*8=64
#   1225.000                                              Lenen Sparen              12                12*12=144
#   1225.000                                     Sparen Retailbeleggen              12                12*12=144
#   1225.000                                                fault ride              17                17*17=289
#   1225.000                                          Heeswijk Dinther              22                22*22=484
#   1284.890                                         trou wêze sil oan               9          10*11*43*20=94600
#   1365.837                                Offered Rate Euribortarief              17             21*24*18=9072
#   1392.045                                           Video On Demand              10             11*20*14=3080
#   1401.144                                       Hendrik Ido Ambacht              10             17*10*18=3060
#   1406.836                                 ferlechje ek hokker jefte               9           10*32*30*9=86400
#   1429.167              tetrafluorethyleen perfluormethyl vinylether               9              15*9*18=2430
#   1465.812                                     kluiten modder stenen              12             12*13*27=4212
#   1474.537                            Programmable Self organisation              13             13*18*21=4914
#   1578.580            oorlogshandeling vijandelijkheden burgeroorlog               9             10*11*20=2200
#   1595.328                                   randschrift GOD ZIJ MET              19          22*21*21*35=339570
#   1595.328                                       randschrift GOD ZIJ              19             22*21*21=9702
#   1631.114                    Corporele Membraan Oxygenatie therapie               8            8*8*8*115=58880
#   1640.027                        Mandibulair Repositie Apparaat MRA              12          12*12*15*61=131760
#   1646.400                                  Pels Rijcken Droogleever              24             25*25*24=15000
#   1646.400                              Rijcken Droogleever Fortuijn              24             25*24*25=15000
#   1700.769                 Mandibulair Repositie Apparaat MRA 234190               8       12*12*15*61*15=1976400
#   1732.323           Afsprakenstelsel Elektronische Toegangsdiensten               8               9*22*8=1584
#   1746.041                                      087092 087096 087097               9              13*9*17=1989
#   1786.458                                    Interbank Offered Rate              21             21*21*24=10584
#   1832.265                                   Normaal Amsterdams Peil              10             18*13*10=2340
#   1864.130                               bruin gemarmerde stinkwants               8               23*8*8=1472
#   1948.864                             perfluormethyl vinylether MFA               9              9*18*11=1782
#   1998.907                                        fault ride through              16             17*17*19=5491
#   2009.766                                            Z913 Z914 Z915               9             12*12*12=1728
#   2009.766                                            V913 V914 V915               9             12*12*12=1728
#   2041.667                                           GOD ZIJ MET ONS              21          21*21*35*21=324135
#   2082.996                   Toezichtcategorie Maatstaf Bandbreedtes              12             13*19*12=2964
#   2143.750                           Overview Continued Professional               8               8*8*20=1280
#   2210.011    oorlogshandeling vijandelijkheden burgeroorlog opstand               9          10*11*20*25=55000
#   2233.073                       Extra Corporele Membraan Oxygenatie               8             84*8*8*8=43008
#   2276.395                      Interbank Offered Rate Euribortarief              17          21*21*24*18=190512
#   2304.960                         Pels Rijcken Droogleever Fortuijn              24          25*25*24*25=375000
#   2328.054                                     pokken kluiten modder              12             17*12*13=2652
#   2381.944                              perfluoralkyl vinylether PFA               9               9*18*9=1458
#   2473.558                               advanced nurse practitioner               9              12*13*9=1404
#   2522.059                          zeesterren slikmosselen slippers              12             17*12*12=2448
#   2522.059                              slikmosselen slippers pokken              12             12*12*17=2448
#   2522.059                                   slippers pokken kluiten              12             12*17*12=2448
#   2522.059                                         We Print Together              10             17*10*10=1700
#   2552.566                                  Middle East North Africa               9           13*11*37*9=47619
#   2658.880                               randschrift GOD ZIJ MET ONS              19       22*21*21*35*21=7130970
#   2722.222                              suzuki fruitvlieg Drosophila               8               8*9*14=1008
#   2722.222                             fruitvlieg Drosophila suzukii               8               9*14*8=1008
#   2807.292                                        Defined Daily Dose              11             12*14*11=1848
#   2858.333                            Mandibulair Repositie Apparaat              12             12*12*15=2160
#   3017.848                              pokken kluiten modder stenen              12          17*12*13*27=71604
#   3530.882                 schelpen zeesterren slikmosselen slippers              12          25*17*12*12=61200
#   3572.917                               Lenen Sparen Retailbeleggen              12             12*12*12=1728
#   3747.815                                       Video On Demand pay              10          11*20*14*13=40040
#   3897.727          verpakcentra distributiecentra verwerkingscentra               8               8*11*8=704
#   3897.727            distributiecentra verwerkingscentra fustopslag               8               11*8*8=704
#   4287.500                                      192079 192080 192087              10             10*10*10=1000
#   4547.348          tetrafluorethyleen perfluormethyl vinylether MFA               9           15*9*18*11=26730
#   4763.889                                   Catharinus Bart Hulshof               8                8*9*8=576
#   4763.889                                      083290 083390 084090               9                9*9*9=729
#   5192.474                   zeesterren slikmosselen slippers pokken              12          17*12*12*17=41616
#   5359.375                       Alaskakoolvis Theragra chalcogramma               8                8*8*8=512
#   5359.375                      glasionomeer glascarbomeer compomeer               8                8*8*8=512
#   5359.375                          gemarmerde stinkwants Halymorpha               8                8*8*8=512
#   5359.375                               stinkwants Halymorpha halys               8                8*8*8=512
#   5359.375                             Corporele Membraan Oxygenatie               8                8*8*8=512
#   5359.375                         Fractuurbehandeling 238041 238042               8                8*8*8=512
#   5359.375                                      238041 238042 238044               8                8*8*8=512
#   5359.375                   verwerkingscentra fustopslag dockboards               8                8*8*8=512
#   6790.158                            slippers pokken kluiten modder              12          12*17*12*13=31824
#   7269.464          schelpen zeesterren slikmosselen slippers pokken              12       25*17*12*12*17=1040400
#   7356.005                      slikmosselen slippers pokken kluiten              12          12*12*17*12=29376
#   8155.571                    bruin gemarmerde stinkwants Halymorpha               8             23*8*8*8=11776
#   8802.057                     slippers pokken kluiten modder stenen              12       12*17*12*13*27=859248
#  11909.722                      suzuki fruitvlieg Drosophila suzukii               8             8*9*14*8=8064
#  15144.716           zeesterren slikmosselen slippers pokken kluiten              12       17*12*12*17*12=499392
#  17052.557   verpakcentra distributiecentra verwerkingscentra fustopslag               8             8*11*8*8=5632
#  17052.557   distributiecentra verwerkingscentra fustopslag dockboards               8             11*8*8*8=5632
#  19804.629               slikmosselen slippers pokken kluiten modder              12       12*12*17*12*13=381888
#  23447.266                    gemarmerde stinkwants Halymorpha halys               8              8*8*8*8=4096
#  23447.266                  Fractuurbehandeling 238041 238042 238044               8              8*8*8*8=4096
#  35680.622              bruin gemarmerde stinkwants Halymorpha halys               8           23*8*8*8*8=94208
#  74604.936   verpakcentra distributiecentra verwerkingscentra fustopslag dockboards               8           8*11*8*8*8=45056

# %% [markdown]
# # Filtering more?
#
# We could try to use linguistic parsing to filter what even goes into n-grams.
#
# For example, we could consider the part of speech of each word.
# The parsing is going to be slower, but let's see if that's potentially worth it.
#
# Since the collocation class only really cares about the count, not the text it is reporting on,
# we can just say "word/POS" is the word and it'll do it.

# %%
# A fancier tokenizer-and-tagger (e.g. spacy's) is now necessary.
#   Note that this is slower than the simpler splitting we did above.
import spacy

nlp = spacy.load("nl_core_news_lg") # _md or even _sm might be preferable for faster testing

def nl_tokenize(nl_sent, with_pos=True):
     doc = nlp( nl_sent.rstrip() ) # this is the slow bit
     if with_pos:
          return list(tok.text+'/'+tok.pos_ for tok in doc)
     else:
          return list(tok.text              for tok in doc)

# %%
# different example text: kamervragen
kv   = wetsuite.datasets.load('tweedekamer-kamervragen-struc')

coll = wetsuite.helpers.collocation.Collocation( ) 
# note that we are not using connectors anymore, we will be imitating that, hopefully more precisely

for kv_id, kv_details in wetsuite.helpers.notebook.ProgressBar( kv.data.random_sample(8000) ):
    vraagdata = kv_details['vraagdata']

    for number in vraagdata:
        try:
            vraag   , _ = vraagdata[number]['vraag']
            antwoord, _ = vraagdata[number]['antwoord']
        except KeyError: # TODO: fix
            continue

        for text in vraag, antwoord:
            for paragraph in re.split(r'[\s]{2,}', text):
                for sentence in wetsuite.helpers.spacy.sentence_split( paragraph, as_plain_sents=True ):
                    coll.consume_tokens(  nl_tokenize( sentence, with_pos=True ), gramlens=(2,3,4,5)  )

# %%
print( coll.counts() )
coll.cleanup_ngrams(mincount=8)
print( coll.counts() )
# Out:
# {'from_tokens': 4028753, 'unigrams': 110032, 'ngrams': 8627273}
# {'from_tokens': 4028753, 'unigrams': 110032, 'ngrams': 117034}

# %% [markdown]
# If you, say, would wish for only specific things, e.g. in the shape of
# ADJECTIVE ADJECTIVE NOUN or DET PRON or ADVERB VERB, you are going to remove a lot of interesting things,
# and will never know, especiallly since there are _many_ possible sequence of POS tags that are reasonable for very simple phrases, e.g.
#
#         opsporing/NOUN en/CCONJ vervolging/NOUN
#         Inspectie/NOUN Gezondheidszorg/PROPN en/CCONJ Jeugd/NOUN
#         het/DET Landelijk/ADJ Register/NOUN
#         de/DET Tweede/PROPN Kamer/PROPN
# and maybe you even care about:
#
#         Hebt/AUX u/PRON kennisgenomen/VERB
#
#
# But, say, we are more interested in things that start with DET (e.g. "the" as part of a name)
# than that end with DET (when we care about phrases, we can declare that as incomplete).
#
# Similarly, we probably don't care about things that _end_ in ADP or PRON.
#
# Or anything containing a PUNCT

# %%
def bad_ngram(ngram):
    flat = ' '.join(ngram)
    if ngram[-1].endswith('/ADP'):
        return True
    if ngram[-1].endswith('/ADV'):
        return True
    if ngram[-1].endswith('/DET'):
        return True
    if ngram[-1].endswith('/AUX'): # but not VERB
        return True
    if ngram[-1].endswith('/CCONJ'):
        return True
    if ngram[-1].endswith('/SCONJ'):
        return True
    if ngram[-1].endswith('/PRON'):
        return True
    if '/PUNCT' in flat:
    #if ngram[-1].endswith('/PUNCT'):
        return True
    return False

coll.cleanup_ngrams_func( bad_ngram )

print( coll.counts() )
# Out:
# {'from_tokens': 4028753, 'unigrams': 110032, 'ngrams': 45855}

# %%
top = 2000
print( "Scoring, showing top %d\n"%top)
scores = coll.score_ngrams( )
print( ' %9s   %55s    %12s %20s'%('score', 'n-gram', 'n-gram count', 'individual counts') )
for strtup, score,  tup_count, uni_counts in scores[-top:]:
    print( ' %9.3f   %55s    %12s %20s=%d'%(score, ' '.join(strtup),   tup_count, '*'.join(str(n) for n in uni_counts), wetsuite.helpers.collocation.product(uni_counts)) )
    # or, to remove the POS in this summary:
    #print( ' %9.3f   %55s    %12s %20s=%d'%(score, ' '.join(s.split('/',1)[0] for s in strtup),   tup_count, '*'.join(str(n) for n in uni_counts), wetsuite.helpers.collocation.product(uni_counts)) )
# Out:
# Scoring, showing top 2000
#
#      score                                                    n-gram    n-gram count    individual counts
#      7.956                              toenmalige/ADJ Minister/NOUN              46             207*1574=325818
#      7.962                           Ondernemend/ADJ Nederland/PROPN              53              53*8154=432162
#      7.966                            humanitaire/ADJ principes/NOUN              10               233*66=15378
#      7.993                             ontbranding/NOUN brengen/VERB               8               8*1226=9808
#      8.000                             biologische/ADJ landbouw/NOUN              12              126*175=22050
#      8.023                                       januari/PROPN jl./X             127            1408*1749=2462592
#      8.054                          agrarische/ADJ kinderopvang/NOUN              18              140*352=49280
#      8.058                                  lagere/ADJ inkomens/NOUN              14               317*94=29798
#      8.068                                 Ik/PRON onderschrijf/VERB              70             6584*113=743992
#      8.069                            luchthaven/NOUN Schiphol/PROPN              30              171*799=136629
#      8.070                          Wetenschappelijke/ADJ Raad/PROPN              10               20*759=15180
#      8.077                                daaraan/ADV verbonden/VERB              22              248*296=73408
#      8.079                             openbare/ADJ bibliotheek/NOUN              11               556*33=18348
#      8.085                                meest/ADV voorkomende/VERB              21              518*129=66822
#      8.106                       wetenschappelijk/ADJ onderzoek/NOUN              97             225*6320=1422000
#      8.116                           maatregelen/NOUN getroffen/VERB             114             3931*499=1961569
#      8.123                              COVID-19/PROPN pandemie/NOUN              11               257*71=18247
#      8.130                                      ermee/ADV bekend/ADJ              93             305*4273=1303265
#      8.132                                       het/DET gebied/NOUN             990          102176*1445=147644320
#      8.135                                 komende/VERB maanden/NOUN              55              684*666=455544
#      8.140                           intensieve/ADJ veehouderij/NOUN               8               112*86=9632
#      8.141                                      actieve/ADJ rol/NOUN              46             185*1721=318385
#      8.156                        voorafgaande/VERB toestemming/NOUN              14               80*368=29440
#      8.207                      toenmalige/ADJ Staatssecretaris/NOUN              21              207*318=65826
#      8.219                            Hogeschool/PROPN Utrecht/PROPN              10               55*271=14905
#      8.226                            Inspectie/NOUN Jeugdzorg/PROPN              19               840*64=53760
#      8.229                             goed/ADJ verhuurderschap/NOUN              15              2233*15=33495
#      8.242                                       vaste/ADJ woon-/SYM               8               328*29=9512
#      8.250                                    Een/DET voorbeeld/NOUN              70             2288*318=727584
#      8.270                                   ogen/NOUN principe/NOUN              18              145*331=47995
#      8.286                                        te/ADP leggen/VERB             416            50069*511=25585259
#      8.288                              onderdeel/NOUN uitmaakt/VERB              28              1332*87=115884
#      8.291                        voorgenomen/VERB concentratie/NOUN              16              347*109=37823
#      8.300                                     eerste/ADJ helft/NOUN              59             1910*269=513790
#      8.312                                    beschut/VERB werk/NOUN               8               9*1048=9432
#      8.323                                  gelijke/ADJ rechten/NOUN              24              199*426=84774
#      8.336                                    laatste/ADJ jaren/NOUN              83             623*1625=1012375
#      8.353                                 directe/ADJ omgeving/NOUN              30              315*419=131985
#      8.362                                      vorige/ADJ week/NOUN              25              280*327=91560
#      8.362                                     ertoe/ADV leiden/VERB              39              229*973=222817
#      8.370                                Welke/DET maatregelen/NOUN             235            2056*3931=8082136
#      8.373                                     grote/ADJ steden/NOUN              37             1757*114=200298
#      8.382                                  houdt/VERB toezicht/NOUN              91             791*1530=1210230
#      8.418                           programmatische/ADJ aanpak/NOUN              15              18*1819=32742
#      8.419                                        staat/VERB los/ADJ              52             1813*217=393421
#      8.426                             wettelijke/ADJ grondslag/NOUN              56             1166*391=455906
#      8.465                              illegale/ADJ immigratie/NOUN               8               421*22=9262
#      8.471                                     31/NUM augustus/PROPN              37              358*553=197974
#      8.478                                  Arctisch/ADJ gebied/NOUN              10              10*1445=14450
#      8.483                                Belgische/ADJ collega/NOUN              21              235*271=63685
#      8.485                            eerlijke/ADJ concurrentie/NOUN              12              110*189=20790
#      8.507                                 zeer/ADV zorgwekkende/ADJ              18              1138*41=46658
#      8.507                                 sterk/ADJ wisselende/VERB               8               384*24=9216
#      8.526                                        Hoe/ADV rijmt/VERB              36              3581*52=186212
#      8.533                                 mijn/PRON ministerie/NOUN             153             3486*964=3360504
#      8.540                              bestuurlijk/ADJ overleg/NOUN              41             137*1760=241120
#      8.573                           internationaal/ADJ verband/NOUN              68             552*1197=660744
#      8.575                                  wettelijke/ADJ taak/NOUN              67             1166*550=641300
#      8.596                                       Dit/PRON geldt/VERB             236            3885*2043=7937055
#      8.601                                          circa/ADV €/NOUN              68             480*1372=658560
#      8.622                         maatschappelijke/ADJ opgaven/NOUN              18               677*68=46036
#      8.673                                  ter/ADP bevordering/NOUN              32              1607*90=144630
#      8.684                          uitzonderlijke/ADJ gevallen/NOUN              35             107*1615=172805
#      8.688                          Belgische/ADJ kerncentrales/NOUN              10               235*60=14100
#      8.694                                      Ik/PRON begrijp/VERB              84             6584*151=994184
#      8.709                                bijdrage/NOUN leveren/VERB              64              885*651=576135
#      8.715                                  Politiewet/NOUN 2012/NUM              10              14*1004=14056
#      8.736                              dierlijke/ADJ producten/NOUN              15               58*544=31552
#      8.770                                      artikel/NOUN 13b/NUM              26              3256*29=94424
#      8.770                        voorbehouden/VERB handelingen/NOUN              10               97*144=13968
#      8.773                                 natuurlijke/ADJ dood/NOUN              11              155*109=16895
#      8.779                                         per/ADP week/NOUN              87             3230*327=1056210
#      8.787                                        te/ADP pakken/VERB             387            50069*417=20878773
#      8.806                         uitgebreide/VERB toelichting/NOUN              20              155*359=55645
#      8.826                                  negatief/ADJ effect/NOUN              29              175*667=116725
#      8.833                               sociale/ADJ huursector/NOUN              12               951*21=19971
#      8.835                               inzake/ADP wapenexport/NOUN              14               632*43=27176
#      8.858                                 contact/NOUN gezocht/VERB              44             1217*220=267740
#      8.868                                sociaal/ADJ advocaten/NOUN              15              259*120=31080
#      8.873                                 liquide/ADJ middelen/NOUN              14              20*1353=27060
#      8.876                          Universiteit/PROPN Utrecht/PROPN              18              165*271=44715
#      8.891                             gezonde/ADJ leefomgeving/NOUN              12              160*124=19840
#      8.898                               afdeling/NOUN klinische/ADJ               9               136*82=11152
#      8.899                                       het/DET aantal/NOUN            1699          102176*3889=397362464
#      8.924                            constructieve/ADJ dialoog/NOUN              10               53*259=13727
#      8.937                                      augustus/PROPN jl./X              84             553*1749=967197
#      8.942                        terroristische/ADJ misdrijven/NOUN              12              144*137=19728
#      8.949                             criminele/ADJ uitbuiting/NOUN              11               202*82=16564
#      8.962                                 Algemeen/ADJ overleg/NOUN              42             137*1760=241120
#      8.962                             gevoelige/ADJ apparatuur/NOUN               8               81*108=8748
#      8.977                                 bewust/ADJ vertraagd/VERB              12               457*43=19651
#      8.978                                publieke/ADJ belangen/NOUN              54              755*527=397885
#      8.981                                 kleine/ADJ gasvelden/NOUN              10               440*31=13640
#      8.993                             Chinese/ADJ autoriteiten/NOUN              41              247*927=228969
#      9.010                              onderdeel/NOUN uitmaken/VERB              34             1332*118=157176
#      9.017                                      uw/PRON oordeel/NOUN             206             6328*911=5764808
#      9.018                         vrijwillige/ADJ voortzetting/NOUN               8               207*42=8694
#      9.038                     Wet/ADV ruimtelijke/ADJ ordening/NOUN               8             68*95*47=303620
#      9.041                                   derde/ADJ kwartaal/NOUN              25              526*161=84686
#      9.046                            wettelijk/ADJ collegegeld/NOUN              15               554*55=30470
#      9.054                                         den/DET brede/ADJ              10               41*330=13530
#      9.054                          dopinggeduide/VERB middelen/NOUN              10              10*1353=13530
#      9.057                               sociale/ADJ huurwoning/NOUN              15               951*32=30432
#      9.074                              Bureau/PROPN Jeugdzorg/PROPN               8               135*64=8640
#      9.103   Principles/SYM on/SYM Business/SYM and/PROPN Human/PROPN              19     22*265*20*203*88=2082942400
#      9.105                          speciaal/ADJ basisonderwijs/NOUN              11               185*88=16280
#      9.109                                    u/PRON bevestigen/VERB             362            34088*517=17623496
#      9.109              Koninkrijk/PROPN der/PROPN Nederlanden/PROPN              16           210*151*38=1204980
#      9.125                                    andere/ADJ landen/NOUN             314            7086*1868=13236648
#      9.161                                  positief/ADJ effect/NOUN              41              337*667=224779
#      9.177                              Turkse/ADJ autoriteiten/NOUN              50              360*927=333720
#      9.177                       ongedocumenteerde/VERB vrouwen/NOUN               9               17*636=10812
#      9.195                              werkelijk/ADJ rendement/NOUN               8               58*147=8526
#      9.201                               economische/ADJ crisis/NOUN              33              587*247=144989
#      9.218                                     Europees/ADJ Hof/NOUN              37              805*226=181930
#      9.219                                     erop/ADV toezien/VERB              15               453*66=29898
#      9.228                           voorlopige/ADJ voorziening/NOUN              18              243*177=43011
#      9.238                         Somalische/ADJ vreemdelingen/NOUN              10               39*340=13260
#      9.247                                nadere/ADJ uitwerking/NOUN              36              453*379=171687
#      9.266                            vertrouwelijke/ADJ inzage/NOUN              11               86*186=15996
#      9.287   Wageningen/PROPN University/PROPN &/PROPN Research/PROPN              13         79*27*173*74=27306666
#      9.297                                   Waarom/ADV wel/niet/ADJ               8                937*9=8433
#      9.300                                 Israël/PROPN bezette/VERB               8               281*30=8430
#      9.306                               hoogste/ADJ prioriteit/NOUN              16              141*239=33699
#      9.317                              oneigenlijk/ADJ gebruik/NOUN              37              60*3000=180000
#      9.361                                    welke/DET termijn/NOUN             265            5412*1698=9189576
#      9.380                                 fossiele/ADJ energie/NOUN              18              129*328=42312
#      9.380                                    onder/ADP leiding/NOUN              82             6363*138=878094
#      9.392                                      200/NUM miljoen/NOUN              34             128*1178=150784
#      9.402                   Binnenlandse/PROPN Zaken/PROPN en/PROPN              61          202*1050*80=16968000
#      9.407                                lange/ADJ wachttijden/NOUN              23              387*178=68886
#      9.408                                 komende/VERB periode/NOUN              86             684*1408=963072
#      9.411                                heb/AUX kennisgenomen/VERB              83             3865*232=896680
#      9.432                                      derde/ADJ graad/NOUN               9               526*20=10520
#      9.439                   wetenschappelijke/ADJ onderbouwing/NOUN              22              361*174=62814
#      9.439                         terroristische/ADJ aanslagen/NOUN               9               144*73=10512
#      9.443                           monetaire/ADJ financiering/NOUN              14               45*565=25425
#      9.446                       kleine/ADJ plastic/ADJ flesjes/NOUN              19           440*133*28=1638560
#      9.450                              mogelijkheden/NOUN ziet/VERB             117             1820*975=1774500
#      9.450                                   milde/ADJ klachten/NOUN               8               17*488=8296
#      9.451                                       ten/ADP gunste/NOUN              26              3370*26=87620
#      9.498                                     het/DET antwoord/NOUN            1959          102176*4844=494940544
#      9.499                                      ernstig/ADJ ziek/ADJ              15               312*93=29016
#      9.521                                      Platform/NOUN 31/NUM               8               23*358=8234
#      9.532                   geconstateerde/VERB tekortkomingen/NOUN              10              108*119=12852
#      9.553                                   aandelen/NOUN ABN/PROPN              15              177*163=28851
#      9.557                                 mijn/PRON voorganger/NOUN              59             3486*128=446208
#      9.567                                      tweede/ADJ golf/NOUN              16               745*44=32780
#      9.578                                         te/ADP komen/VERB            1090           50069*3035=151959415
#      9.597                                   geleden/ADV schade/NOUN              36              211*784=165424
#      9.605                               zakelijke/ADJ relaties/NOUN               8               106*77=8162
#      9.610                         gerechtelijke/ADJ procedures/NOUN              14               72*347=24984
#      9.622                               benadeelde/VERB partij/NOUN               8               21*388=8148
#      9.639                                       te/ADP brengen/VERB             695           50069*1226=61384594
#      9.655                                    Graag/ADV verwijs/VERB              23               68*987=67116
#      9.687                            van/PROPN Commissarissen/PROPN              14               729*34=24786
#      9.690                             onderlinge/ADJ samenhang/NOUN              12              123*148=18204
#      9.694                                       Zie/VERB verder/ADJ             144            1519*1725=2620275
#      9.696                                        per/ADP maand/NOUN              84             3230*276=891480
#      9.720                                  ervaring/NOUN leert/VERB              11               221*69=15249
#      9.722                                    van/PROPN Beroep/PROPN               9               729*14=10206
#      9.758                                        Het/PRON gaat/VERB             413            4405*4861=21412705
#      9.765                              sociaal/ADJ leenstelsel/NOUN               8               259*31=8029
#      9.766                                          vraag/NOUN 7/NUM             168             5072*698=3540256
#      9.777                                   van/PROPN Chicago/PROPN               8               729*11=8019
#      9.780                                 stijgende/VERB trend/NOUN               9               89*114=10146
#      9.794                       buitenlandse/ADJ investeerders/NOUN              24              581*124=72044
#      9.813                                   vigerende/VERB wet-/SYM              16               58*551=31958
#      9.816                                nauw/ADJ samengewerkt/VERB              15              240*117=28080
#      9.819                           gebiedsgerichte/ADJ aanpak/NOUN              27              50*1819=90950
#      9.825                                 regionaal/ADJ niveau/NOUN              32              133*960=127680
#      9.828                                           te/ADV hoog/ADJ              60              984*456=448704
#      9.847                            tijdelijke/ADJ contracten/NOUN              31              484*247=119548
#      9.872                                   het/PRON belangrijk/ADJ             358           13877*1146=15903042
#      9.890                                Koninkrijk/PROPN der/PROPN              16              210*151=31710
#      9.891                                        31/NUM maart/PROPN              57             358*1124=402392
#      9.894                             internationaal/ADJ recht/NOUN              66              552*977=539304
#      9.929                          Coördinator/NOUN Groningen/PROPN               8               21*376=7896
#      9.945                              beschikbaar/ADJ gesteld/VERB             147            1623*1640=2661720
#      9.946                             publiek/NOUN toegankelijk/ADJ              20              238*207=49266
#      9.951                                  best/ADJ beschikbare/ADJ              24              145*489=70905
#      9.967                                       lage/ADJ lonen/NOUN              10               241*51=12291
#      9.991                             conclusies/NOUN verbindt/VERB              15               418*66=27588
#      9.996                                     heer/NOUN Morsi/PROPN              11               674*22=14828
#     10.003                                 contact/NOUN opnemen/VERB              40             1217*161=195937
#     10.021                                    veel/PRON mogelijk/ADJ             133             384*5631=2162304
#     10.022                                       Het/PRON klopt/VERB             122             4405*413=1819265
#     10.024                              bevoegde/ADJ instanties/NOUN              19              171*258=44118
#     10.024                            daarmee/ADV samenhangende/VERB              25              1273*60=76380
#     10.024                               meer/DET duidelijkheid/NOUN              72             2133*297=633501
#     10.038                                    Hieruit/ADV bleek/VERB              14               92*260=23920
#     10.051                                lokaal/ADJ richtsnoer/NOUN               8               312*25=7800
#     10.064   Nationaal/PROPN Cyber/PROPN Security/PROPN Centrum/PROPN              15         324*43*56*43=33548256
#     10.084                  diplomatieke/ADJ vertegenwoordiging/NOUN               9               123*80=9840
#     10.097                                    komende/VERB tijd/NOUN              89             684*1405=961020
#     10.107                                      Ik/PRON beschik/VERB              78             6584*112=737408
#     10.109                             Programma/NOUN Onderwijs/NOUN              18              134*293=39262
#     10.132                                    kleine/ADJ plastic/ADJ              22              440*133=58520
#     10.153                                chronische/ADJ ziekte/NOUN              12               73*238=17374
#     10.159                                     externe/ADJ harde/ADJ              16               343*90=30870
#     10.172                                  zeer/ADV onwenselijk/ADJ              58             1138*356=405128
#     10.215                                           box/PROPN 3/NUM              18              24*1619=38856
#     10.228                                         dit/DET jaar/NOUN             582           10047*4038=40569786
#     10.230                                         Wet/NOUN RO/PROPN              12              1437*12=17244
#     10.234                               mentale/ADJ gezondheid/NOUN               9               24*404=9696
#     10.266                             natuurlijke/ADJ personen/NOUN              42             155*1358=210490
#     10.268                               afgelopen/VERB periode/NOUN             130            1432*1408=2016256
#     10.301                               toenmalig/ADJ Minister/NOUN              30              68*1574=107032
#     10.311                              burgerlijke/ADJ rechter/NOUN              18               47*819=38493
#     10.312                               nadere/ADJ toelichting/NOUN              37              453*359=162627
#     10.314                                  ernstige/ADJ ziekte/NOUN              32              511*238=121618
#     10.319                              oorzakelijk/ADJ verband/NOUN              11              12*1197=14364
#     10.358                                Stichting/PROPN Open/PROPN               8                87*87=7569
#     10.382                               negatieve/ADJ gevolgen/NOUN              80             485*1557=755145
#     10.384                         aanvullende/VERB maatregelen/NOUN             168             847*3931=3329557
#     10.397                                        Hoe/ADV duidt/VERB              49              3581*79=282899
#     10.401                                    totaal/ADJ aantal/NOUN              72             157*3889=610573
#     10.418                           Nederlandse/ADJ Vereniging/NOUN             117             5030*320=1609600
#     10.421                                  openbare/ADJ agenda/NOUN              36              556*274=152344
#     10.425                             eerdere/ADJ schriftelijke/ADJ              48              833*325=270725
#     10.440                        parlementaire/ADJ behandeling/NOUN              24              61*1108=67588
#     10.478                                      deze/DET vragen/NOUN             677           18170*2949=53583330
#     10.480                                          hoe/ADV vaak/ADJ             162             3490*879=3067710
#     10.501                                        tot/ADP stand/NOUN             294            11807*854=10083178
#     10.503                                zowel/CCONJ bilateraal/ADJ              47             1552*166=257632
#     10.516                                     heer/NOUN Laçin/PROPN               9               674*14=9436
#     10.517                                  civiele/ADJ rechter/NOUN              30              128*819=104832
#     10.519                              middellange/ADJ termijn/NOUN              27              50*1698=84900
#     10.558                            digitale/ADJ weerbaarheid/NOUN              17               404*83=33532
#     10.569                                        zes/NUM weken/NOUN              34              290*462=133980
#     10.599                                sociale/ADJ zekerheid/NOUN              48              951*280=266280
#     10.610                                 Bouwbesluit/NOUN 2012/NUM              20              46*1004=46184
#     10.654                                        Ten/ADP tweede/ADJ              56              484*745=360580
#     10.671                                    Welke/DET stappen/NOUN             120             2056*804=1653024
#     10.686                                  kaart/NOUN gebracht/VERB              49              376*732=275232
#     10.711                                 laten/VERB uitvoeren/VERB             119             2507*646=1619522
#     10.714                                           €/NOUN /ton/SYM              12              1372*12=16464
#     10.736                             zelf/ADV verantwoordelijk/ADJ             131             2205*888=1958040
#     10.739                               lichamen/NOUN Bonaire/PROPN               9               56*165=9240
#     10.742                            structurele/ADJ oplossing/NOUN              47              335*752=251920
#     10.760                             zorgwekkende/ADJ stoffen/NOUN              11               41*336=13776
#     10.760                           hernieuwbare/ADJ waterstof/NOUN              11              123*112=13776
#     10.802                                        ’s/DET nachts/NOUN              10               945*12=11340
#     10.807                                            to/SYM the/SYM              21              193*259=49987
#     10.824                        Internationaal/PROPN Verdrag/PROPN               9               89*103=9167
#     10.847                            openbare/ADJ dronkenschap/NOUN               8               556*13=7228
#     10.860                                  werking/NOUN treedt/VERB              23              510*117=59670
#     10.874                                       eerste/ADJ lid/NOUN             144            1910*1223=2335930
#     10.889                              homoseksuele/ADJ mannen/NOUN               8               50*144=7200
#     10.899                                  ter/ADP Beoordeling/NOUN              23              1607*37=59459
#     10.939                                     26/NUM augustus/PROPN              40              324*553=179172
#     10.948                                  me/PRON voorstellen/VERB              16              154*186=28644
#     10.949                               fossiele/ADJ industrie/NOUN              18              129*281=36249
#     10.957                                    extern/ADJ bureau/NOUN              10               130*86=11180
#     10.977                                     ertoe/ADV geleid/VERB              32              229*499=114271
#     10.982                                  geen/DET aanleiding/NOUN             464           10750*2234=24015500
#     11.012                           Bahreinse/ADJ autoriteiten/NOUN              10               12*927=11124
#     11.027                             nogmaals/ADV benadrukken/VERB              16              158*180=28440
#     11.028                    de/PROPN Ruyter/PROPN Ziekenhuis/PROPN               8           145*13*132=248820
#     11.087                                       twee/NUM weken/NOUN              77             1418*462=655116
#     11.087                         particuliere/ADJ verhuurders/NOUN              15              220*113=24860
#     11.107                                   komend/VERB najaar/NOUN              10               41*269=11029
#     11.136                          afzonderlijk/ADJ beantwoord/NOUN              10               200*55=11000
#     11.137                                        de/DET mening/NOUN            3308          236801*5083=1203659483
#     11.141                          financiële/ADJ instellingen/NOUN             125             1888*910=1718080
#     11.146                                        te/ADP voeren/VERB             662            50069*962=48166378
#     11.157                                daarop/ADV gebaseerde/VERB              12               465*34=15810
#     11.168                         effectieve/ADJ belastingdruk/NOUN               8               260*27=7020
#     11.187                                landelijk/ADJ dekkend/VERB              10               438*25=10950
#     11.189                                       Wet/ADV wapens/NOUN              10               68*161=10948
#     11.204                              Welke/DET mogelijkheden/NOUN             185            2056*1820=3741920
#     11.209                                     beide/DET kanten/NOUN              11               551*24=13224
#     11.260                             beschikking/NOUN staande/VERB              17               393*80=31440
#     11.289                                       nr./X 1099/2009/SYM               8               463*15=6945
#     11.290                              huishoudelijke/ADJ hulp/NOUN              16               47*591=27777
#     11.290                                    illegaal/ADJ hout/NOUN              10               217*50=10850
#     11.294                        stijgende/VERB energieprijzen/NOUN               8                89*78=6942
#     11.296                                   zwangere/ADJ vrouw/NOUN               9               72*122=8784
#     11.325                       terroristische/ADJ organisatie/NOUN              33              144*818=117792
#     11.341                                  beslag/NOUN genomen/VERB              55             188*1738=326744
#     11.348                        Provincie/NOUN Noord-Holland/PROPN               8               47*147=6909
#     11.402                                erkend/VERB deskundige/ADJ              10               136*79=10744
#     11.414                                  miljard/NOUN dollar/NOUN              11               302*43=12986
#     11.418                              informeel/ADJ onderwijs/NOUN              31              64*1611=103104
#     11.472                                   Israël/PROPN bezet/VERB              10               281*38=10678
#     11.504                                     cruciale/ADJ ggz/NOUN               9               75*115=8625
#     11.522                                flankerend/ADJ beleid/NOUN              16              17*1601=27217
#     11.564                                  juridisch/ADJ loket/NOUN              12               263*58=15254
#     11.566               gemeente/NOUN Oude/PROPN IJsselstreek/PROPN              10           1951*19*10=370690
#     11.566                               laatste/ADJ levensfase/NOUN              10               623*17=10591
#     11.625                                       groot/ADJ deel/NOUN             148            1249*1848=2308152
#     11.661                                      het/DET kabinet/NOUN            1886          102176*3657=373657632
#     11.662                         reproductieve/ADJ gezondheid/NOUN              10               26*404=10504
#     11.667                  Inspectie/NOUN Overheidsinformatie/PROPN               8                840*8=6720
#     11.707                                  Minister/NOUN Wang/PROPN              19              1574*24=37776
#     11.713                              telefonisch/ADJ contact/NOUN              32              88*1217=107096
#     11.755                                     Europese/ADJ Hof/NOUN              67             2070*226=467820
#     11.755                                   klein/ADJ pensioen/NOUN              19              209*180=37620
#     11.760                            agenda/NOUN bewindslieden/NOUN              11               274*46=12604
#     11.798                                nucleaire/ADJ akkoord/NOUN              12               89*168=14952
#     11.805                             gedwongen/VERB terugkeer/NOUN              25              242*268=64856
#     11.842             Zaken/PROPN en/PROPN Koninkrijksrelaties/NOUN              58          1050*80*145=12180000
#     11.845    brede/ADJ gepaste/ADJ zorgvuldigheidsverplichting/NOUN               8             330*78*9=231660
#     11.847                         verantwoording/NOUN afgelegd/VERB              10               235*44=10340
#     11.869                          Egyptische/ADJ autoriteiten/NOUN              31              107*927=99189
#     11.882                         Jasper/PROPN van/PROPN Dijk/PROPN              10            11*729*45=360855
#     11.885                                         te/ADP geven/VERB            1192           50069*2925=146451825
#     11.887                                    volgend/VERB jaar/NOUN              73             136*4038=549168
#     11.926                       Internationale/ADJ Organisatie/NOUN              10               107*96=10272
#     11.927                           Nederlands/ADJ grondgebied/NOUN              17              291*102=29682
#     11.929                                   kaart/NOUN brengen/VERB              67             376*1226=460976
#     11.932                                       drie/NUM weken/NOUN              66              968*462=447216
#     11.984                                illegaal/ADJ verblijf/NOUN              22              217*228=49476
#     11.986                                       dat/DET moment/NOUN             262            2431*2886=7015866
#     11.987                                    Hoe/ADV verhouden/VERB              58              3581*96=343776
#     11.988                                        Wet/NOUN BIG/PROPN              30              1437*64=91968
#     12.000                           provincie/NOUN Overijssel/PROPN              28              748*107=80036
#     12.000                        duurzame/ADJ energieprojecten/NOUN              12               490*30=14700
#     12.001                    psychische/ADJ kindermishandeling/NOUN               9               106*78=8268
#     12.053                                    lid/NOUN Lodders/PROPN              19              1223*30=36690
#     12.080                                 Mijn/PRON voorganger/NOUN              19              286*128=36608
#     12.113                                  De/PROPN Taskforce/PROPN              13               211*81=17091
#     12.136                        Indonesische/ADJ autoriteiten/NOUN              30               98*927=90846
#     12.136                                   Wet/ADV ruimtelijke/ADJ               8                68*95=6460
#     12.169                            nationale/ADJ parlementen/NOUN              12               906*16=14496
#     12.169                             Algemene/ADJ Verordening/NOUN              19              230*158=36340
#     12.190                       Israëlische/ADJ nederzettingen/NOUN               9               220*37=8140
#     12.211                                   nadere/ADJ duiding/NOUN              17               453*64=28992
#     12.248                   uitgeprocedeerde/VERB asielzoekers/NOUN              12               38*379=14402
#     12.281                                  causaal/ADJ verband/NOUN              12              12*1197=14364
#     12.296                                    rente/NOUN rekent/VERB               9               269*30=8070
#     12.309                                       heer/NOUN Van/PROPN              59              674*514=346436
#     12.311                                        al/ADV geruime/ADJ              45              3474*58=201492
#     12.312                             fundamentele/ADJ rechten/NOUN              21              103*426=43878
#     12.324                                           Ik/PRON ga/VERB             166             6584*416=2738944
#     12.349                                      kort/ADJ gezegd/VERB              30              288*310=89280
#     12.358                  inkomensafhankelijke/ADJ regelingen/NOUN               9               31*259=8029
#     12.361                                         Van/ADP boer/NOUN              14               607*32=19424
#     12.372                                          ouder/ADJ (/NOUN              22              277*173=47921
#     12.423                                nadelige/ADJ gevolgen/NOUN              30              57*1557=88749
#     12.478                                      rol/NOUN speelt/VERB              79             1721*356=612676
#     12.500                                   onnodig/ADJ lijden/VERB              12               147*96=14112
#     12.513                                  vaste/ADJ commissie/NOUN              38              328*431=141368
#     12.532                       uitdrukkelijke/ADJ toestemming/NOUN               8               17*368=6256
#     12.544                                  wankele/ADJ cijfers/NOUN               9               10*791=7910
#     12.554                           verschillende/ADJ manieren/NOUN              81             2453*261=640233
#     12.566                              gepleegde/VERB strafbare/ADJ               9               24*329=7896
#     12.568                                 openbaar/ADJ lichaam/NOUN              23               889*58=51562
#     12.574                                   externe/ADJ inhuur/NOUN              13               343*48=16464
#     12.620                                    interne/ADJ markt/NOUN              52              344*763=262472
#     12.622                       aanvullende/VERB verzekeringen/NOUN              24               847*66=55902
#     12.625                                         het/DET feit/NOUN            1261          102176*1510=154285760
#     12.629                             opvang/NOUN Asielzoekers/NOUN              10               485*20=9700
#     12.685                                  enigerlei/DET wijze/NOUN              35              47*2517=118299
#     12.706                                      november/PROPN jl./X             131             946*1749=1654554
#     12.726                               bewezen/VERB effectieve/ADJ              17              107*260=27820
#     12.754                             politieke/ADJ gevangenen/VERB              18               451*69=31119
#     12.773                                     langere/ADJ tijd/NOUN              61             254*1405=356870
#     12.774                           startende/VERB ondernemers/NOUN              14               37*508=18796
#     12.792                                      Uit/ADP navraag/NOUN              39             1087*134=145658
#     12.800                              gelijke/ADJ behandeling/NOUN              48             199*1108=220492
#     12.829                          Nederlands/ADJ reisdocument/NOUN               8               291*21=6111
#     12.836                          mitigerende/ADJ maatregelen/NOUN              44              47*3931=184757
#     12.837                          Inspectie/NOUN Leefomgeving/NOUN              25               840*71=59640
#     12.869                                          per/ADP dag/NOUN             114             3230*383=1237090
#     12.886                          ondersteunende/ADJ software/NOUN               9               55*140=7700
#     12.893                               startende/VERB leraren/NOUN               9               37*208=7696
#     12.897                                  zich/PRON meebrengt/VERB              76              6773*81=548613
#     12.904                                 Onder/ADP verwijzing/NOUN              13               263*61=16043
#     12.915                             hogere/ADJ huurverhoging/NOUN              12               471*29=13659
#     12.924                                     heer/NOUN Singh/PROPN               8                674*9=6066
#     12.929                              strikte/ADJ voorwaarden/NOUN              35             104*1116=116064
#     12.957                            Nederlandse/ADJ ambassade/NOUN             124             5030*289=1453670
#     12.963                               escalatie/NOUN kanalen/NOUN               8               54*112=6048
#     12.978                                  monetair/ADJ beleid/NOUN              21              26*1601=41626
#     13.021                          feitelijk/ADJ gerealiseerde/VERB              10               168*56=9408
#     13.028                                       Wet/PROPN BIG/PROPN               9               119*64=7616
#     13.036                    overlastgevende/VERB asielzoekers/NOUN              11               30*379=11370
#     13.043                                        het/DET kader/NOUN            1497          102176*2060=210482560
#     13.102                                     vrije/ADJ voeten/NOUN               8               272*22=5984
#     13.125                       bestuursrechtelijke/ADJ premie/NOUN               9               72*105=7560
#     13.175                                        half/ADJ jaar/NOUN              76             133*4038=537054
#     13.230                                     erg/ADJ vervelend/ADJ               9               150*50=7500
#     13.283                                    alle/DET betrokken/ADJ              60              4150*80=332000
#     13.284                                  Hetzelfde/ADJ geldt/VERB              24              26*2043=53118
#     13.292                                  baan/NOUN verliezen/VERB              13               175*89=15575
#     13.293            Algemene/ADJ Plaatselijke/ADJ Verordening/NOUN              13           230*15*158=545100
#     13.305                                  meeste/ADV gevallen/NOUN              77             338*1615=545870
#     13.315                         verschuldigde/VERB belasting/NOUN              12               48*276=13248
#     13.330                                    per/ADP definitie/NOUN             102             3230*296=956080
#     13.347                                            box/NOUN 3/NUM              42             100*1619=161900
#     13.364                                    mindere/PRON mate/NOUN               9                9*825=7425
#     13.379                                      Titanic/PROPN ’s/ADJ               8               10*586=5860
#     13.383                                primair/ADJ onderwijs/NOUN              88             440*1611=708840
#     13.445                                       tweede/ADJ lid/NOUN             100             745*1223=911135
#     13.499                                    Energie/NOUN Unie/NOUN               8                88*66=5808
#     13.503                                     tweede/ADJ helft/NOUN              47              745*269=200405
#     13.514                                     Voorop/ADV staat/VERB              20              20*1813=36260
#     13.558                                      Van/PROPN Dijk/PROPN              16               514*45=23130
#     13.576                                  ons/PRON omringende/VERB              16               525*44=23100
#     13.583                                           mei/PROPN jl./X             138             982*1749=1717518
#     13.592                                mobiele/ADJ netwerken/NOUN              16              206*112=23072
#     13.603                                       onder/ADP druk/NOUN             170             6363*409=2602467
#     13.611    Algemene/ADJ verordening/NOUN gegevensbescherming/NOUN              27           230*208*48=2296320
#     13.617                                        te/ADP zetten/VERB             786           50069*1110=55576590
#     13.631                                          vraag/NOUN 6/NUM             227             5072*913=4630736
#     13.661                                   meter/NOUN afstand/NOUN              33              225*434=97650
#     13.672                                       vorige/ADJ set/NOUN              15               280*72=20160
#     13.709                                 militaire/ADJ missie/NOUN              16               266*86=22876
#     13.725                                  meerdere/PRON keren/NOUN               8               102*56=5712
#     13.728                                 nationaal/ADJ niveau/NOUN              57              302*960=289920
#     13.729                                     drie/NUM maanden/NOUN              85              968*666=644688
#     13.781                                          B/PROPN en/PROPN               9                90*80=7200
#     13.786                           evenwichtige/ADJ verdeling/NOUN              11               48*224=10752
#     13.825                                 Centrale/PROPN Bank/PROPN               8               53*107=5671
#     13.829                               belemmering/NOUN vormt/VERB              17               80*320=25600
#     13.852                                        tien/NUM jaar/NOUN             110             265*4038=1070070
#     13.896                             Caribisch/ADJ Nederland/PROPN             117             148*8154=1206792
#     13.917                                      Kort/ADJ gezegd/VERB               9               23*310=7130
#     13.928                           Syrische/ADJ vluchtelingen/NOUN              15               77*257=19789
#     13.949                              seksuele/ADJ uitbuiting/NOUN              13               181*82=14842
#     13.960                                         te/ADP laten/VERB            1196           50069*2507=125522983
#     13.973                                        cluster/NOUN 6/NUM              27               70*913=63910
#     14.013                               provinciale/ADJ staten/NOUN              11               123*86=10578
#     14.019                                       Van/PROPN Dam/PROPN              10               514*17=8738
# ...
#    634.786                            Agentschap/PROPN Telecom/PROPN              36                61*41=2501
#    636.338                          humanitair/ADJ oorlogsrecht/NOUN              31                50*37=1850
#    637.000                                  Agnes/PROPN Mulder/PROPN              13                13*25=325
#    639.130             Coördinator/PROPN Terrorismebestrijding/PROPN              24                46*24=1104
#    642.302                                Zilveren/PROPN Kruis/PROPN              76               81*136=11016
#    644.737                             Oude/PROPN IJsselstreek/PROPN              10                19*10=190
#    646.154                                 Zeer/ADV Zorgwekkende/ADJ              12                21*13=273
#    648.043                                    Erasmus/PROPN MC/PROPN              28                38*39=1482
#    649.087   Central/PROPN Emergency/PROPN Response/PROPN Fund/PROPN               9          14*16*22*38=187264
#    658.340                            Europees/PROPN Parlement/PROPN              90               157*96=15072
#    659.615                   Meerjarig/ADJ Financieel/ADJ Kader/NOUN              12             12*52*15=9360
#    668.933                       Internationaal/PROPN Strafhof/PROPN              54                89*60=5340
#    672.549                      Gemeenschappelijk/ADJ Standpunt/NOUN              28                51*28=1428
#    673.750                                     joint/SYM venture/SYM              11                20*11=220
#    680.556                                   Jansen/PROPN Steur/NOUN              10                18*10=180
#    680.556                            Tijdelijk/ADJ Steunkader/PROPN              10                18*10=180
#    686.685                   Persoonlijke/ADJ Gezondheidscheck/PROPN              19                28*23=644
#    689.062                          Arbiter/NOUN Bodembeweging/PROPN               9                 9*16=144
#    689.224                                             s/NOUN )/NOUN             107              133*153=20349
#    693.143                                      13b/NUM Opiumwet/ADJ              19                29*22=638
#    700.000                                 Stille/PROPN Oceaan/PROPN               8                 8*14=112
#    700.000                                       no/PROPN deal/PROPN              36                63*36=2268
#    700.000                                     Pro/PROPN Dromi/PROPN              12                21*12=252
#    704.723              Central/PROPN Emergency/PROPN Response/PROPN               9             14*16*22=4928
#    709.211                                  Klaus/PROPN Schwab/PROPN              11                11*19=209
#    712.727                            Signalement/NOUN Mondzorg/NOUN               8                11*10=110
#    735.000                            Gecombineerde/ADJ Opgave/PROPN               9                 15*9=135
#    736.965                                     Nord/SYM Stream/PROPN              15                17*22=374
#    741.176                            Pricing/PROPN Guidelines/PROPN              12                14*17=238
#    742.424                                     bebouwde/ADJ kom/NOUN              10                15*11=165
#    748.004                                    RTL/PROPN Nieuws/PROPN              37                59*38=2242
#    748.981                               Periodic/PROPN Review/PROPN              15                16*23=368
#    748.981                         huwelijkse/ADJ gevangenschap/NOUN              15                16*23=368
#    750.806                                     cold/PROPN cases/NOUN              19                19*31=589
#    752.038                              Verenigde/PROPN Staten/PROPN             227              344*244=83936
#    753.846                                   trusted/SYM flagger/SYM               8                 13*8=104
#    765.625                                       VNO/PROPN NCW/PROPN              10                16*10=160
#    766.391                                     bruine/ADJ vloot/NOUN              25                27*37=999
#    776.371                     Basisregistratie/PROPN Personen/PROPN              17                24*19=456
#    782.729                   Convenant/PROPN Basisbankrekening/PROPN              31                47*32=1504
#    784.641                                 Blauwe/PROPN Tijger/PROPN              14                17*18=306
#    785.256                             Olympische/PROPN Spelen/PROPN              10                12*13=156
#    786.420                                   mijns/PRON inziens/NOUN              52                52*81=4212
#    787.500                                    Round/PROPN Hill/PROPN               9                 14*9=126
#    791.919                                     Terre/PROPN des/PROPN               8                 9*11=99
#    791.919                                    des/PROPN Hommes/PROPN               8                 11*9=99
#    798.190                                Herstelplan/PROPN Gas/NOUN              12                13*17=221
#    816.667                             Besloten/VERB Busvervoer/NOUN              12                18*12=216
#    824.246                                  Human/PROPN Rights/PROPN              73                88*90=7920
#    824.916                              Guiding/PROPN Principles/SYM              20                27*22=594
#    826.875                                  TWO/PROPN Chemical/PROPN               9                12*10=120
#    828.929                         Westelijke/ADJ Jordaanoever/PROPN              26                37*27=999
#    835.227                                 Groene/PROPN Draeck/PROPN              15                22*15=330
#    835.227                            Arabische/PROPN Emiraten/PROPN              15                22*15=330
#    836.161                          Verantwoord/NOUN Ondernemen/VERB              23                31*25=775
#    838.158                                 Prinses/NOUN Máxima/PROPN              13                13*19=247
#    841.346                       Dreigingsbeeld/NOUN Terrorisme/NOUN              25                35*26=910
#    844.587                                    Task/PROPN Force/PROPN              22                27*26=702
#    847.000                             Ruimtelijke/ADJ Ordening/NOUN              22                28*25=700
#    848.077                      Burgerlijke/ADJ Rechtsvordering/NOUN               9                 13*9=117
#    861.328                                    vliegend/ADJ hert/NOUN              15                20*16=320
#    861.667                                  Tweede/PROPN Kamer/PROPN             716              782*932=728824
#    870.395                                       quick/ADJ scan/NOUN              27                27*38=1026
#    872.507                    Zeer/ADV Zorgwekkende/ADJ Stoffen/NOUN              10             21*13*18=4914
#    884.450                                     level/SYM playing/SYM              19                25*20=500
#    886.816                           Verenigd/PROPN Koninkrijk/PROPN             154              156*210=32760
#    890.909                                 Heilige/PROPN Stoel/PROPN               8                 8*11=88
#    890.909                                    269/NUM Libération/SYM               8                 11*8=88
#    898.191                                      Ter/PROPN Apel/PROPN              58                62*74=4588
#    902.632                        rationele/ADJ farmacotherapie/NOUN              14                19*14=266
#    905.435                                   Drentse/ADJ Monden/NOUN              17                23*17=391
#    928.218                          Aanhangsel/NOUN Handelingen/NOUN             256              310*279=86490
#    929.634                                  Juridisch/ADJ Loket/NOUN              33                41*35=1435
#    931.070                                United/PROPN Nations/PROPN              23                29*24=696
#    931.408                                      Den/PROPN Haag/PROPN             263              342*266=90972
#    933.333                            Universal/PROPN Periodic/PROPN              16                21*16=336
#    933.333                                   Zwarte/PROPN Piet/PROPN              32                42*32=1344
#    936.765                              informed/PROPN consent/PROPN              13                17*13=221
#    947.364                                     Schone/ADJ Lucht/NOUN              35                44*36=1584
#    950.160                                wildlife/PROPN crime/PROPN              11                13*12=156
#    951.624                                    Green/PROPN Deal/PROPN              55                66*59=3894
#    956.186                      Koninklijke/PROPN Marechaussee/PROPN              67                81*71=5751
#    956.394                                      ABN/PROPN AMRO/PROPN             133              163*139=22657
#    967.105                        commissie-Van/PROPN Kemenade/PROPN              15                19*15=285
#    967.901                                    Akzo/PROPN Nobel/PROPN               8                  9*9=81
#    980.000                                    Meld/VERB Misdaad/NOUN               8                 8*10=80
#    980.000                                Misdaad/NOUN Anoniem/PROPN               8                 10*8=80
#    980.000                               Olivér/PROPN Várhelyi/PROPN              12                12*15=180
#    980.000                                    Agua/PROPN Zarca/PROPN               8                 10*8=80
#    992.250                            Chemical/PROPN Logistics/PROPN               9                10*10=100
#   1002.273                               Mitch/PROPN Henriquez/PROPN               9                 9*11=99
#   1013.327                          Justitiële/ADJ Inrichtingen/NOUN              30                34*32=1088
#   1013.327                       Ecologische/ADJ Hoofdstructuur/NOUN              15                17*16=272
#   1020.833                                      Tel/PROPN Aviv/PROPN              10                12*10=120
#   1020.833                                 ultimum/ADJ remedium/NOUN              15                15*18=270
#   1020.833                                 Quantum/PROPN Knits/PROPN              10                12*10=120
#   1020.833                                Guantánamo/PROPN Bay/PROPN              10                12*10=120
#   1021.897                                    VDL/PROPN Nedcar/PROPN              31                36*32=1152
#   1024.837                  Multinationale/PROPN Ondernemingen/PROPN              16                17*18=306
#   1043.787                         Aardolie/PROPN Maatschappij/PROPN              12                13*13=169
#   1050.000                                   Be/PROPN Informed/PROPN              12                12*14=168
#   1053.070                                     due/SYM diligence/SYM              49                57*49=2793
#   1065.217                                     playing/SYM field/SYM              20                20*23=460
#   1080.882                                      goeder/ADV trouw/ADJ              15                15*17=255
#   1080.882                                 Milorad/PROPN Dodik/PROPN              15                15*17=255
#   1088.889                                Daphne/PROPN Caruana/PROPN               8                  8*9=72
#   1088.889                           Beschikbare/ADJ Technieken/NOUN               8                  8*9=72
#   1088.889                                   Great/PROPN Reset/PROPN               8                  9*8=72
#   1102.500                                     tick/PROPN size/PROPN               9                 10*9=90
#   1113.636                                   Due/PROPN Diligence/SYM              10                11*10=110
#   1122.917                                Hoeksche/PROPN Waard/PROPN              11                11*12=132
#   1129.218             Barometer/NOUN Culturele/ADJ Diversiteit/NOUN               8              15*9*18=2430
#   1130.769   Uitvoeringsinstituut/PROPN Werknemersverzekeringen/PROPN              24                24*26=624
#   1130.769                                   Juiste/PROPN Plek/PROPN              12                12*13=156
#   1130.769                                Scania/PROPN Gryphus/PROPN              12                13*12=156
#   1130.769                              genitale/ADJ verminking/NOUN              24                24*26=624
#   1137.500                                     Bruins/PRON Slot/NOUN              13                13*14=182
#   1143.333                                         nota/SYM bene/SYM              14                14*15=210
#   1150.758                                  Burkina/PROPN Faso/PROPN              31                31*33=1023
#   1152.941                                 Karel/PROPN Doorman/PROPN              16                17*16=272
#   1156.944                                  Albert/PROPN Heijn/PROPN              17                18*17=306
#   1156.944                         ischemische/ADJ speennecrose/NOUN              17                17*18=306
#   1176.000                                      SOS/PROPN Arts/PROPN              24                24*25=600
#   1185.484                                     KPR/PROPN Mills/PROPN              30                30*31=930
#   1201.214                                    Tata/PROPN Steel/PROPN             101              103*101=10403
#   1225.000                                    modus/SYM operandi/SYM              11                11*11=121
#   1225.000                                            per/SYM se/SYM              18                18*18=324
#   1225.000                                  Pels/PROPN Rijcken/PROPN              26                26*26=676
#   1225.000                                       op/PROPN Zoom/PROPN               8                  8*8=64
#   1225.000                                     Jimmy/PROPN Lai/PROPN               9                  9*9=81
#   1225.000                                Grant/PROPN Thornton/PROPN              10                10*10=100
#   1225.000                         offensief/ADJ cyberprogramma/NOUN               8                  8*8=64
#   1225.000                                   Cherry/PROPN Tree/PROPN               8                  8*8=64
#   1225.000                               Caruana/PROPN Galizia/PROPN               9                  9*9=81
#   1225.000                                   NHL/PROPN Stenden/PROPN               9                  9*9=81
#   1225.000                                  Cabo/PROPN Delgado/PROPN              16                16*16=256
#   1225.000                                    Belly/PROPN Wien/PROPN               8                  8*8=64
#   1225.000                                       OD/PROPN NZKG/PROPN              17                17*17=289
#   1225.000                       Flamingo/PROPN Communications/PROPN              16                16*16=256
#   1248.302               Universal/PROPN Periodic/PROPN Review/PROPN              15             21*16*23=7728
#   1345.902                           level/SYM playing/SYM field/SYM              19             25*20*23=11500
#   2143.750                          Bergen/PROPN op/PROPN Zoom/PROPN               8               20*8*8=1280
#   2894.062                  TWO/PROPN Chemical/PROPN Logistics/PROPN               9             12*10*10=1200
#   3079.686                        Terre/PROPN des/PROPN Hommes/PROPN               8               9*11*9=891
#   4234.568                  Daphne/PROPN Caruana/PROPN Galizia/PROPN               8                8*9*9=648

# %% [markdown]
# This seems viable enough.
