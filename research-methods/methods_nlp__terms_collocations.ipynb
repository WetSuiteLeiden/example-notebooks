# %% [markdown]
# ## Purpose of this notebook
#
# Explain what collocation analysis does.
#
# ...and how it is a tool, and what it may be good for, and what it is probably _not good enough_ for.

# %% [markdown]
# Collocations are about finding words that are next to each other more than just chance.
#
# There are many reasons to seek them out, which often filters for a specific type of collocations,
# trying to answer questions such as
# - meaningful patterns that are baked into the language, like `in terms of`, and nearly-institutionalized phrases `eigen gebruik` or `echtgenoot of geregistreerde partner`,
# - "what verbs do we use with this noun", e.g. we `make sense` rather than `have sense`
#
# We might also use it to detect phrases common to a sepecific document or set of documents.

# %% [markdown]
# However, that may be talking it up too much.
#
# Just plain 'statistically more common together' will also get a mess of _fragments_ of phrases, e.g. `tijdstip zal`, `verplichtingen uit`, `heeft gedaan`, so a simple, unfocused version of this is often not enough for clean output.
#
# If used to find patterns like the make verus have sense, collocation analysis alone only suggests candidantes, and doesn't claim something might be lexicalized/institutionalized, or even a sensible candidate.
#
# It is also a brute-force method, and memory-hungry, so for various purposes you might find newer methods that have similar effect.
# For example, if you are interested in finding topics of a document, you may be more interested in
# [actual topic modelling](methods_nlp__topic_modeling.ipynb).
#
# TODO: add some relevant reading

# %%
# For local installs you can install the package once.   In colab you get a disposable environment and will have to start with this install each time. 
# !pip3 install wetsuite -U

# %%
import re
import random

import bs4  # BeautifulSoup is a handy way of scraping some text from HTML or XML

import wetsuite.helpers.koop_parse
import wetsuite.helpers.etree
import wetsuite.helpers.net
import wetsuite.helpers.strings
import wetsuite.helpers.collocation
import wetsuite.helpers.notebook
import wetsuite.helpers.spacy
import wetsuite.datasets

# %% [markdown]
# Fetch Burgerlijk wetboek 7 from KOOP respositories, in XML form.
#
# At 60k words this you may consider this fairly large, yet for this kind of analysis it is fairly small.
#
# But we get the answer quickly, so we can play with the various parameters.
#
# ...which we want in a demo because as we will find out,
# this whole concepts is somewhat finicky,
# in that there is no zone with best results because we never really specified
# what kind of things we find more interesting than others.

# %%
bwb7_xml  = wetsuite.helpers.net.download( 'https://repository.officiele-overheidspublicaties.nl/bwb/BWBR0005290/2008-03-26_0/xml/BWBR0005290_2008-03-26_0.xml' )
bwb7_soup = bs4.BeautifulSoup( bwb7_xml, features='xml' ) # bs4 makes it a little easier to pick things out of that XML.
sents     = []
for al in bwb7_soup.select('lid al'):
    sents.append(  ' '.join( al.find_all(string=True) )  )

# %%
# split each sentence into words - dumb version
tokenized_sents = []
for sent in sents:
    tokenized_sents.append( wetsuite.helpers.strings.simple_tokenize(sent) )

tokenized_sents[0]
# Out:
# ['De',
#  'koop',
#  'van',
#  'een',
#  'tot',
#  'bewoning',
#  'bestemde',
#  'onroerende',
#  'zaak',
#  'of',
#  'bestanddeel',
#  'daarvan',
#  'wordt',
#  'indien',
#  'de',
#  'koper',
#  'een',
#  'natuurlijk',
#  'persoon',
#  'is',
#  'die',
#  'niet',
#  'handelt',
#  'in',
#  'de',
#  'uitoefening',
#  'van',
#  'een',
#  'beroep',
#  'of',
#  'bedrijf',
#  'schriftelijk',
#  'aangegaan']

# %% [markdown]
# parameters include
#  - ***n-gram lengths to include*** - you generally don't want very long, because the more text you process,
#    the more entries there are with just one count  (frankly a problem with almost any n-gram based analysis)
#    We can cheat in the following example, again because there is not a lot of text
#
#  - what this code calls ***connectors*** - does not enter n-gram sequences with one of these words at the _edge_, but accepts them inside.
#    This is a makeshift measure to reduce the amount of somewhat-longer sequences that we pick up in the middle,
#    by ignoring anything that starts or ends with these uninteresting words.
#    (and also keeps down the unique n-gram count, and thereby memory use)
#
#  - ***minimum count*** - removes some things that would score well just because the combo happens once or twice
#
#  - ***scoring method*** on top of the basic counting statistics (mostly trying to get the numbers on a more reasonable, readable scale)

# %%
connectors = 'De de een het  dat die dit deze  van voor met in op bij om na   en of   is   aan  ook   je ik we hij    door kan zal dan als tot lid te heeft niet worden wordt waarin'.split()
gramlens   = (2,3,4,5,6,7,8)  # we can get away with larger n-grams because this is a fairly small text
mincount   = 10               # remove n-gram sequences that didn't occur very much, for cleaner results
showtop    = 500

# do the calculation
coll = wetsuite.helpers.collocation.Collocation( connectors=connectors )
for tokenized_sent in tokenized_sents: # feed in text
    coll.consume_tokens( tokenized_sent, gramlens=gramlens )
coll.cleanup_ngrams(mincount=mincount) 
print( "Scoring, showing top %d\n"%showtop)
scores = coll.score_ngrams()

# show the result
print( ' %9s   %55s    %12s %20s'%( 'score', 'n-gram', 'n-gram count', 'individual counts' ) )
for strtup, score,  tup_count, uni_counts in scores[-showtop:]:
    print( ' %9.3f   %55s    %12s %30s=%d'%(score, ' '.join(strtup),   tup_count, '*'.join(str(n) for n in uni_counts), wetsuite.helpers.collocation.product(uni_counts)) )
# Out:
# Scoring, showing top 500
#
#      score                                                    n-gram    n-gram count    individual counts
#      0.000                  handelt in de uitoefening van een beroep              14   17*1437*5847*57*3537*1759*59=2988591451947501327
#      0.000                                 ten nadele van de huurder              10           273*57*3537*5847*188=60501132707652
#      0.000                               ten nadele van de werknemer              17           273*57*3537*5847*243=78200932169997
#      0.001                     uitoefening van een beroep of bedrijf              20        57*3537*1759*59*1157*60=1452487407525180
#      0.001                                     nadele van de huurder              10               57*3537*5847*188=221615870724
#      0.001                                       bedoeld in de leden              12              308*1437*5847*118=305367339816
#      0.001        arbeidsovereenkomst of bij regeling door of namens              13    122*1157*328*26*472*1157*21=13804956218097408
#      0.001                               sluiten van de overeenkomst              14               27*3537*5847*415=231728800995
#      0.002                                   nadele van de werknemer              17               57*3537*5847*243=286450300989
#      0.002   collectieve arbeidsovereenkomst of bij regeling door of namens              13 17*122*1157*328*26*472*1157*21=234684255707655936
#      0.002                                  zijn niet van toepassing              21               549*748*3537*240=348594269760
#      0.004                                          bedoeld in lid 2              12               308*1437*628*200=55590057600
#      0.004                                       afwijking van lid 1              10                48*3537*628*341=36357190848
#      0.006                                        aanvang van de dag              10                21*3537*5847*61=26492154759
#      0.008               regeling door of namens een daartoe bevoegd              17      26*472*1157*21*1759*60*77=2423124982998720
#      0.008                              omstandigheden van het geval              15               67*3537*1453*120=41319658440
#      0.008                       zijn van overeenkomstige toepassing              14                549*3537*76*240=35418669120
#      0.011                                    indien de overeenkomst              14                   322*5847*415=781334610
#      0.014   regeling door of namens een daartoe bevoegd bestuursorgaan              17   26*472*1157*21*1759*60*77*19=46039374676975680
#      0.017                       regeling door of namens een daartoe              17         26*472*1157*21*1759*60=31469155623360
#      0.021                                          bedoeld in lid 1              36               308*1437*628*341=94781048208
#      0.021                                       uit de overeenkomst              11                   103*5847*415=249930015
#      0.021                                      indien de verhuurder              11                   322*5847*132=248520888
#      0.022                                         Indien de pachter              10                   257*5847*128=192342912
#      0.029                                uitoefening van een beroep              20                57*3537*1759*59=20923183629
#      0.029                                         Indien de rechter              13                   257*5847*168=252450072
#      0.041                                 handelt in de uitoefening              15                17*1437*5847*57=8141672691
#      0.049                                       bepaalde in artikel              10                   118*1437*515=87326490
#      0.051                                         grond van artikel              16                   119*3537*515=216765045
#      0.056                                      uitoefening van zijn              12                    57*3537*549=110683341
#      0.057                                  zijn van overeenkomstige              14                    549*3537*76=147577788
#      0.082                                         nakoming van zijn              14                    53*3537*549=102916089
#      0.085                                           zin van artikel              17                    80*3537*515=145724400
#      0.086                                              leden 2 en 3              12                118*200*859*124=2513777600
#      0.096                                              leden 1 en 2              21                118*341*859*200=6912888400
#      0.096                                     afwijking van artikel              14                    48*3537*515=87434640
#      0.129                                     termijn van opzegging              12                   134*3537*101=47869758
#      0.136                                        Voor de toepassing              14                    44*5847*240=61744320
#      0.178                                          Van de artikelen              11                     63*5847*79=29100519
#      0.211                       arbeidsovereenkomst of bij regeling              13                122*1157*328*26=1203761312
#      0.219                                          voet van artikel              11                    13*3537*515=23680215
#      0.245                                    werkgever is verplicht              10                    176*1184*84=17504256
#      0.290                                                    2 en 3              12                    200*859*124=21303200
#      0.372                                             recht op loon              12                    162*868*118=16592688
#      0.422                                                    1 en 2              24                    341*859*200=58583800
#      0.434           collectieve arbeidsovereenkomst of bij regeling              13             17*122*1157*328*26=20463942304
#      0.464                                          binnen een maand              10                    105*1759*50=9234750
#      0.499                                       eerste lid bedoelde              11                    111*628*149=10386492
#      0.661                                        recht op uitkering              13                     162*868*78=10968048
#      0.681                                overeenkomst tot wijziging              12                     415*508*43=9065260
#      0.697                                  huurder worden afgeweken              10                     188*425*77=6152300
#      1.025                                           tegen het einde              14                     94*1453*60=8194920
#      1.202                                           Van dit artikel              11                     63*133*515=4315185
#      1.362                                        Wet arbeid en zorg              10                   54*88*859*27=110213136
#      1.454                                   regeling door of namens              17                 26*472*1157*21=298172784
#      1.702                                               één of meer              13                     40*1157*92=4257760
#      2.101                                            arbeid en zorg              10                      88*859*27=2040984
#      2.336                                 rechten en verplichtingen              11                      47*859*55=2220515
#      2.541                                namens een daartoe bevoegd              17                  21*1759*60*77=170658180
#      2.558                                  Wet werk en inkomen naar              10                54*42*859*17*62=2053415448
#      2.849                                      arbeid te verrichten              16                      88*695*63=3853080
#      3.256                                                 1 onder b              12                     341*139*40=1895960
#      3.567                                         toepassing indien              15                        240*322=77280
#      3.774                                                 1 onder c              11                     341*139*29=1374571
#      3.776                                               Van artikel              10                         63*515=32445
#      3.946                                      werk en inkomen naar              10                   42*859*17*62=38026212
#      4.289                                        bedoeld in artikel             151                   308*1437*515=227936940
#      4.531                                       Wet werk en inkomen              10                   54*42*859*17=33119604
#      4.681                 namens een daartoe bevoegd bestuursorgaan              17               21*1759*60*77*19=3242505420
#      5.591                                        namens een daartoe              17                     21*1759*60=2216340
#      6.249                                                geen recht              10                        121*162=19602
#      8.668                                       binnen twee maanden              11                     105*57*100=598500
#      8.675                                      overeenkomst waarbij              12                         415*49=20335
#      8.952                  Wet werk en inkomen naar arbeidsvermogen              10             54*42*859*17*62*10=20534154480
#      9.249                                                2 bedoelde              15                        200*149=29800
#      9.612                                           koop op afstand              24                      74*868*40=2569280
#     10.284                                         krachtens artikel              21                        102*515=52530
#     10.419                                     maatregel van bestuur              19                     20*3537*21=1485540
#     10.719                                         beroep of bedrijf              32                     59*1157*60=4095780
#     11.114                                     aanspraak op vakantie              21                      49*868*40=1701280
#     11.313                                                  zou zijn              17                         57*549=31293
#     11.387                                         ingevolge artikel              15                         47*515=24205
#     11.807                                schriftelijke overeenkomst              14                         49*415=20335
#     13.024                            algemene maatregel van bestuur              19                  28*20*3537*21=41595120
#     13.812                      werk en inkomen naar arbeidsvermogen              10                42*859*17*62*10=380262120
#     14.154                                    geheel of gedeeltelijk              12                     29*1157*13=436189
#     14.498                                              andere wijze              11                         142*72=10224
#     14.646                                       zijn verplichtingen              19                         549*55=30195
#     16.527                              echtgenoot of geregistreerde              17                     24*1157*27=749736
#     16.919                                    overeenkomstig artikel              21                         62*515=31930
#     17.747                             veranderingen en toevoegingen              12                      27*859*15=347895
#     17.896                                           werk en inkomen              16                      42*859*17=613326
#     18.297                                               artikel 378              10                         515*13=6695
#     18.436                                                indien zij              21                         322*91=29302
#     18.907                                                     Lid 1              10                         19*341=6479
#     19.761                                            toe te rekenen              19                      49*695*23=783265
#     21.304                                              wijze waarop              12                         72*115=8280
#     21.624                                        verplichtingen uit              10                         55*103=5665
#     23.070                                              vorige leden              10                         45*118=5310
#     24.102                      echtgenoot of geregistreerde partner              17                  24*1157*27*24=17993664
#     24.143                                          vastgesteld loon              10                         43*118=5074
#     24.853                                     geld vastgesteld loon              10                      34*43*118=172516
#     25.146                                                dag waarop              12                         61*115=7015
#     25.578                                             andere partij              13                         142*57=8094
#     25.779                                                Wet arbeid              10                          54*88=4752
#     26.515                                                Voor zover              10                         44*105=4620
#     27.425                                         redelijke termijn              12                         48*134=6432
#     27.855                             bevoegdelijk is onderverhuurd              10                     13*1184*10=153920
#     29.474                                               binnen twee              12                         105*57=5985
#     29.898                                                   leden 2              24                        118*200=23600
#     30.922                                               artikel 634              13                         515*13=6695
#     33.494                                                   1 onder              36                        341*139=47399
#     34.591                                                binnen zes              13                         105*57=5985
#     46.677                                                1 bedoelde              44                        341*149=50809
#     46.925                                                    Boek 3              19                         76*124=9424
#     47.188                                             bepaalde tijd              20                         118*88=10384
#     49.000                                                vorige zin              12                          45*80=3600
#     49.359                                                  ten dele              11                         273*11=3003
#     49.704                                                 ten laste              12                         273*13=3549
#     49.941                                           tijdstip waarop              19                         77*115=8855
#     50.054                                           bedongen arbeid              13                          47*88=4136
#     51.872                                                 ten tijde              17                         273*25=6825
#     52.339                                         vastgestelde loon              11                         24*118=2832
#     54.012                                                  Wet werk              10                          54*42=2268
#     59.402                                                tweede zin              15                          58*80=4640
#     60.681                                                 zes jaren              12                          57*51=2907
#     63.362                                                Een beding              18                          87*72=6264
#     64.419                                                   leden 1              46                        118*341=40238
#     67.009                                               ieder geval              16                         39*120=4680
#     68.376                                                   onder c              15                         139*29=4031
#     70.133                                                  In geval              23                         77*120=9240
#     72.488                                             rechter wijst              13                         168*17=2856
#     74.108                                                 zes weken              10                          57*29=1653
#     76.629                                           daartoe bevoegd              17                          60*77=4620
#     79.459                                                eerste zin              24                         111*80=8880
#     80.994                                               ten gevolge              19                         273*20=5460
#     83.789                                          geld vastgesteld              10                          34*43=1462
#     94.426                                               ten hoogste              22                         273*23=6279
#     95.366                                  gebouwde onroerende zaak              12                      15*26*166=64740
#    100.862                                          gedeelte daarvan              17                         30*117=3510
#    102.083                                     uitkering gerechtigde              13                          78*26=2028
#    103.444                                                zou hebben              19                          57*75=4275
#    103.513                                                 één maand              13                          40*50=2000
#    104.664                                                 vijf jaar              13                          23*86=1978
#    116.224                                              inkomen naar              10                          17*62=1054
#    123.789                                              twee maanden              24                         57*100=5700
#    126.906                                                   onder b              24                         139*40=5560
#    131.250                                            zich daartegen              12                         112*12=1344
#    132.432                                  schriftelijke mededeling              14                          49*37=1813
#    134.615                                                ten minste              30                         273*30=8190
#    135.737                                               ten behoeve              33                         273*36=9828
#    141.158                            daartoe bevoegd bestuursorgaan              17                       60*77*19=87780
#    143.182                                           passende arbeid              12                          14*88=1232
#    160.417                                              In afwijking              22                          77*48=3696
#    164.508                                                   onder a              28                         139*42=5838
#    170.533                                              drie maanden              23                         38*100=3800
#    170.697                           collectieve arbeidsovereenkomst              17                         17*122=2074
#    175.417                                               ten aanzien              41                         273*43=11739
#    175.610                                              der partijen              24                          41*98=4018
#    177.392                                           onroerende zaak              25                         26*166=4316
#    197.581                                      naar arbeidsvermogen              10                          62*10=620
#    230.588                                        natuurlijk persoon              16                          16*85=1360
#    241.986                                    bevoegd bestuursorgaan              17                          77*19=1463
#    248.439                                               zes maanden              34                         57*100=5700
#    255.769                                                ten nadele              57                         273*57=15561
#    257.895                                                ene partij              12                          12*57=684
#    265.636                                             stand gekomen              11                          31*18=558
#    280.729                                           onbepaalde tijd              22                          24*88=2112
#    316.720                                           dringende reden              11                          18*26=468
#    348.158                                overeenkomstige toepassing              72                         76*240=18240
#    350.000                                        gewichtige redenen              10                          14*25=350
#    406.784                              inkomen naar arbeidsvermogen              10                       17*62*10=10540
#    447.391                                                  ter zake              42                         105*46=4830
#    452.308                                       gebouwde onroerende              12                          15*26=390
#    475.352                                                    Boek 6              41                          76*57=4332
#    779.545                                                  los land              14                          14*22=308
#    789.688                                        algemene maatregel              19                          28*20=560
#    914.969                                    geregistreerde partner              22                          27*24=648
#   1008.824                                            dien verstande              28                          34*28=952
#   1085.121                                        aangetekende brief              16                          17*17=289

# %% [markdown]
# ## Similar, in gensim
# Note that collocations are simple enough that a lot of NLP libraries do something like it, sometimes with their own take on it.
#
# See e.g. [this NLTK example](https://www.nltk.org/howto/collocations.html),
# or the below code for gensim (see als [its documentation](https://radimrehurek.com/gensim/models/phrases.html))

# %%
# gensim separates building a model. 
# Note that the below code uses the input both to build the model, and to then look in the same text.

from gensim.models.phrases import Phrases

phrase_model = Phrases(tokenized_sents, min_count=3, threshold=0.4, connector_words=connectors, scoring='npmi', delimiter=' ')

for phrase, score in sorted( phrase_model.find_phrases( tokenized_sents ).items(), key=lambda x:x[1], reverse=True)[:500]: 
    firstword,rest = phrase.split(' ',1) # (gensim deals with varied-n-grams with a simpler interface)
    print('%5.2f  %20s %-20s'%(score,firstword,rest))
# Out:
#  1.00             gedateerd ontvangstbewijs
#  1.00                  PbEG L
#  1.00               geldsom leent
#  1.00                  2002 65
#  1.00            wederzijds goedvinden
#  1.00              uiterste wilsbeschikking
#  1.00               Wetboek van Burgerlijke
#  1.00                  Onze Minister
#  1.00                 tafel en bed
#  1.00                    II van de Huisvestingswet
#  1.00           uitvoerbaar bij voorraad
#  1.00           Burgerlijke Rechtsvordering
#  1.00                 meest gerede
#  1.00                natuur en landschap
#  1.00                   332 333
#  1.00  Uitvoeringsinstituut werknemersverzekeringen
#  1.00             structuur uitvoeringsorganisatie
#  1.00                mannen en vrouwen
#  1.00               sociaal fiscaalnummer
#  1.00         verschillende werkgevers
#  1.00             elkanders opvolger
#  0.99          aangetekende brief
#  0.98             maatregel van bestuur
#  0.98         geregistreerd partnerschap
#  0.98          persoonlijke levenssfeer
#  0.98             nagelaten betrekkingen
#  0.98             richtlijn nr
#  0.97                  dien verstande
#  0.97               verwijt treft
#  0.97                   429 430
#  0.97          bevoegdelijk is onderverhuurd
#  0.96             stichting of vereniging
#  0.96        geregistreerde partner
#  0.96        Uitvoeringswet huurprijzen
#  0.96                  plan van aanpak
#  0.95              openbare registers
#  0.95              Centrale Grondkamer
#  0.95               ondanks waarschuwing
#  0.95               afhangt of kan afhangen
#  0.95             onderling verhaal
#  0.95                   los land
#  0.95              algemene maatregel
#  0.94            feitelijke stoornis
#  0.94               toonder of order
#  0.93         zwangerschaps of bevallingsverlof
#  0.92              regeling door of namens
#  0.92                   46e en 46f
#  0.92           toekomstige verbintenissen
#  0.92                 bloed of aanverwant
#  0.92                vanuit financieel
#  0.91         elektronische berichten
#  0.91                rechte lijn
#  0.91  schuldsaneringsregeling natuurlijke
#  0.90            echtgenoot of geregistreerde
#  0.90            zorgvuldig schuldenaar
#  0.90              handelen of nalaten
#  0.90                 Dagen of gedeelten
#  0.90              seksuele intimidatie
#  0.90            duidelijke en begrijpelijke
#  0.90     verjaringstermijn te lopen
#  0.90           ondertekend geschrift
#  0.89            financieel toezicht
#  0.89    gemeenschappelijke huishouding
#  0.89               geldend bestemmingsplan
#  0.89                   237 van het Wetboek
#  0.89        kwijtschelding van de reissom
#  0.89             onbekwame minderjarige
#  0.89              Europese Unie
#  0.89                geheel of gedeeltelijk
#  0.89              waarborg biedt
#  0.89         elektronische contactgegevens
#  0.89                aantal vakantiedagen
#  0.88              gebouwde onroerende
#  0.88          zwangerschap of bevalling
#  0.88         veranderingen en toevoegingen
#  0.88                 kende of behoorde
#  0.88           onevenredig wordt geschaad
#  0.88                  werk en inkomen
#  0.87              eigenaar vruchtgebruiker
#  0.87                 allen tijde
#  0.87              bezwaren aan de zijde
#  0.87                  Boek 6
#  0.87         eigenschappen bezit
#  0.87         werkelijkheid niet aanwezig
#  0.87          aanverwanten in de rechte
#  0.87              ernstige overlast
#  0.87               minimum te boven
#  0.86             hoofdstuk II
#  0.86             kennelijk onredelijk
#  0.86              landbouw betrekkelijke
#  0.86                   ter zake
#  0.86              techniek voor communicatie
#  0.86               oogpunt onvoldoende
#  0.86                   327 328
#  0.86              gebonden te willen
#  0.86                   toe te rekenen
#  0.86            gewichtige redenen
#  0.85                 bloed of aanverwanten
#  0.85              algemeen verkrijgbare
#  0.85             Behoudens tegenbewijs
#  0.85                   per week
#  0.85              behoorde te kennen
#  0.85                   252 en 253
#  0.85                  kent of behoort
#  0.84             dringende reden
#  0.84               terzake bijstand
#  0.84            bijzondere onderhandelingsgroep
#  0.84                beroep of bedrijf
#  0.83                 ertoe strekt
#  0.83          zelfstandige woning
#  0.83            opgemaakte akte
#  0.83                    zo spoedig
#  0.83                   had behoren
#  0.83                  dood of letsel
#  0.83               daarbij een last
#  0.83               daaruit voortvloeiende
#  0.83          rechterlijke uitspraak
#  0.83               handelt in de uitoefening
#  0.82                 boven gaat
#  0.82                elkaar opvolgende
#  0.82                 voort te zetten
#  0.82                 stand gekomen
#  0.82           geoorloofde veranderingen
#  0.82              bewoning bestemde
#  0.82              liggende bestemming
#  0.82                namens een daartoe
#  0.82             pachtjaar of het pachtseizoen
#  0.82               gelijke behandeling
#  0.82                   ene partij
#  0.82                    13 14
#  0.82                 mocht verwachten
#  0.82            aanmerking genomen
#  0.82                    25 negende
#  0.82            onbepaalde tijd
#  0.81              Europese Economische
#  0.81       overeenkomstige toepassing
#  0.81             aanspraak op vakantie
#  0.81           voorwaarden verbinden
#  0.81                    al datgene
#  0.81                 lopen met de aanvang
#  0.81             pandrecht rust
#  0.81               genoten een evenredig
#  0.81                nieuwe verjaringstermijn
#  0.81          Overeenkomst betreffende
#  0.81            onderlinge verhouding
#  0.81              leeftijd van zestien
#  0.81              teneinde ernstig
#  0.81             daaronder begrepen
#  0.80                 laten weten
#  0.80           behoorlijke bedrijfsvoering
#  0.80               bevoegd bestuursorgaan
#  0.80            gefixeerde schadevergoeding
#  0.80              dringend nodig
#  0.80               ernstig nadeel
#  0.80        geregistreerde partners
#  0.80             getroffen maatregelen
#  0.80                     d en e
#  0.80           raadpleging van werknemers
#  0.80          vervreemding of bezwaring
#  0.80           vervangende zekerheid
#  0.80                  hulp en bijstand
#  0.80            natuurlijk persoon
#  0.80                risico is gelopen
#  0.80                   wil verwezenlijken
#  0.79          aangebrachte veranderingen
#  0.79                  koop op afstand
#  0.79                  naar arbeidsvermogen
#  0.79                  Raad van de Europese
#  0.79             lidstaten van de Europese
#  0.79                  weet of behoort
#  0.79              verjaart door verloop
#  0.79              bijstand heeft verleend
#  0.79                   zes maanden
#  0.79             Dringende redenen
#  0.79             wettelijk voorgeschreven
#  0.79           onderscheid objectief
#  0.79               exploot of aangetekende
#  0.79            onverwijld medegedeelde
#  0.78                    12 13
#  0.78               billijk zal voorkomen
#  0.78         huurcommissie verzoeken
#  0.78             evenredig deel
#  0.78                   mee te werken
#  0.78                    zo nauwkeurig
#  0.78              Algemene wet
#  0.78            beslissing wordt overgelaten
#  0.78                   ten nadele
#  0.78               waarbij de ene
#  0.78      wetenschappelijk onderzoek
#  0.78                risico s
#  0.78           premievrije waarde
#  0.78                buiten rechte
#  0.78           aannemelijk maakt
#  0.77  uitvoeringsorganisatie werk
#  0.77            wettelijke vertegenwoordiger
#  0.77                behoud ervan
#  0.77              centrale ondernemingsraad
#  0.77                    SE ondernemingsraad
#  0.77                   SCE ondernemingsraad
#  0.77                begint een nieuwe
#  0.77                 diens familieleden
#  0.77           natuurlijke personen
#  0.77                  ware stand
#  0.76                  vier weken
#  0.76             Hetzelfde geldt
#  0.76              bestemde onroerende
#  0.76             termijnen wordt betaald
#  0.76                   Wet op de arbeidsongeschiktheidsverzekering
#  0.76              Europese rechtspersonen
#  0.76           verbintenis op te schorten
#  0.76                   wet overlegt
#  0.76             gedeelten van dagen
#  0.76          redelijkheid en billijkheid
#  0.76             gehandeld met het opzet
#  0.76                  naar tijdruimte
#  0.76           collectieve arbeidsovereenkomst
#  0.76                 hoeve of los
#  0.76                   der Staten
#  0.76            onderdelen a
#  0.76              indirect onderscheid
#  0.76             begrijpen de beslissing
#  0.76               genoemd in hoofdstuk
#  0.76       verwezenlijking van het risico
#  0.75          medegedeelde reden
#  0.75               zestien jaren
#  0.75            onroerende zaak
#  0.75                   der partijen
#  0.75                  drie maanden
#  0.75                zijner beschikking
#  0.75           echtgenoten of geregistreerde
#  0.75              leeftijd van twaalf
#  0.75              passende arbeid
#  0.75                 Ieder der
#  0.75       arbeidsvermogen later
#  0.75           persoonlijk in duurzaam
#  0.75                   Wet structuur
#  0.75                  akte of een afschrift
#  0.75                 wiens hulp
#  0.75               exploot of bij aangetekende
#  0.75             surséance van betaling
#  0.75                    In afwijking
#  0.74       bestemmingsplan op het verhuurde
#  0.74                zonder deugdelijke
#  0.74              daardoor lijdt
#  0.74                   wie bevoegdelijk
#  0.74                 mocht blijken
#  0.74             afwijking van het overeengekomene
#  0.74                  doen afkopen
#  0.74                 onder a
#  0.74             dwingende bepalingen
#  0.74                tijdig in het geding
#  0.74                  zich daartegen
#  0.74                  acht te nemen
#  0.74                  deel vallen
#  0.74                  iets anders
#  0.74                kennis van de ware
#  0.74           uitoefening van een beroep
#  0.74         schriftelijke mededeling
#  0.74                   ten aanzien
#  0.73             vaststaat dat strijd
#  0.73              algemeen belang
#  0.73                   oog op de omstandigheden
#  0.73               inkomen naar
#  0.73             vestiging van een pandrecht
#  0.73             verlangen of gewijzigde
#  0.73            wettelijke rente
#  0.73            aanleiding geven
#  0.73                inhoud van de rechtshandeling
#  0.73                  naam en de woonplaats
#  0.73                gerede partij
#  0.73               aanvang van de reis
#  0.72                brengt van rechtswege
#  0.72             redelijke afweging
#  0.72        tegenprestatie te herzien
#  0.72                tussen beider
#  0.72            verzekerde som
#  0.72            pachtvrije staat
#  0.72             redelijke waardering
#  0.72        overeengekomen arbeidsduur
#  0.72               daarbij behorende
#  0.72                direct onderscheid
#  0.72                  mede gelet
#  0.72                  naar evenredigheid
#  0.72            verwijzing naar
#  0.72              aanwezig is geweest
#  0.72                zoveel mogelijk
#  0.72            grondkamer herziet
#  0.72            uitkomsten van de te verrichten
#  0.72                   rol werknemers
#  0.71                  mede te delen
#  0.71              begrepen degenen
#  0.71               negende lid van de Wet
#  0.71                 onder b
#  0.71                   ten minste
#  0.71                    48 c
#  0.71                    Na het verstrijken
#  0.71              toestemt in een redelijk
#  0.71                  vijf jaar
#  0.71                  twee maanden
#  0.71                   ten behoeve
#  0.71                   één maand
#  0.71               aanvang van de dag
#  0.71               daartoe aanleiding
#  0.71             uitkering gerechtigde
#  0.71             verzoeken uitspraak
#  0.71              beperken tot zodanig
#  0.71               kortere duur
#  0.71                  658a lid 4
#  0.70           betreffende los
#  0.70                 nemen in werkelijkheid
#  0.70                  dood of de ondercuratelestelling
#  0.70         verschuldigde gefixeerde
#  0.70                 wijze van informatieverstrekking
#  0.70           verbintenis van de hoofdschuldenaar
#  0.70                   Elk beding
#  0.70                     4 wordt verdeeld
#  0.70              gemaakte kosten
#  0.70              gerichte verklaring
#  0.70                 zoals een goed
#  0.70           handelingen op het gebied
#  0.70                  vijf jaren
#  0.70                  dier zake
#  0.70              gedeelte daarvan
#  0.70                  naar maatstaven
#  0.70                verder aansprakelijk
#  0.70                   zou hebben
#  0.70               behalve op bedrijfsruimte
#  0.69                  geld vastgesteld
#  0.69                 rente en kosten
#  0.69              verschil tussen
#  0.69            hoofdelijk verbonden
#  0.69           arbeidsduur per
#  0.69             artikelen 313
#  0.69            betrekking hebbende
#  0.69                  geld vastgestelde
#  0.69              gebouwde met het oog
#  0.69              Bedingen waarbij
#  0.69                 leden 1–2
#  0.69        voortvloeiende rechten
#  0.69                 eigen naam
#  0.69               verband houdende
#  0.69          gerechtigden tot een vergoeding
#  0.69            berekening van de schadeloosstelling
#  0.69      rechtsverhouding tot de reisorganisator
#  0.69                  deel uitmaakt
#  0.69              gebreken of ongeschiktheid
#  0.69                  vast te stellen
#  0.69                ziekte verhinderd
#  0.69                  acht weken
#  0.68                  naar billijkheid
#  0.68             vestiging of overdracht
#  0.68             opgezegde huurovereenkomst
#  0.68              verleend is vernietigbaar
#  0.68                 jaren heeft bereikt
#  0.68          veroorzaakte schade
#  0.68                   zes weken
#  0.68           bestanddeel daarvan
#  0.68               bedoeld in artikel
#  0.68              duurzaam gebruik
#  0.68                   ten hoogste
#  0.68        onherroepelijk is beslist
#  0.68               Wanneer de nalatenschap
#  0.68            voorgaande leden
#  0.68               beperkt gerechtigde
#  0.68                  maar korter
#  0.68                   214 van Boek
#  0.68                  zorg van een goed
#  0.67                  vast De toewijzing
#  0.67                bekend was
#  0.67                  zorg te dragen
#  0.67          onderhuurder aan wie
#  0.67             artikelen 450
#  0.67                  duur van de vertraging
#  0.67             pachtjaar volgende
#  0.67              Partijen kunnen
#  0.67                 einde van de pacht
#  0.67               rechter wijst
#  0.67        overeenkomstig de verwachtingen
#  0.67            bijzondere omstandigheden
#  0.67             onderdeel a
#  0.67                 lager is dan de waarde
#  0.67                   ten gevolge
#  0.67                ziekte zwangerschap
#  0.66               verband met ongeschiktheid
#  0.66              bereiken over
#  0.66                 geldt als een veroordeling
#  0.66               geleden schade
#  0.66               daartoe bevoegd
#  0.66               anderen dan de patiënt
#  0.66           verzekeraar te misleiden
#  0.66                   ter plaatse
#  0.66            verhinderd was
#  0.66            verhinderd is de bedongen
#  0.66                   had mogen
#  0.66               bekwame tijd
#  0.66                   ter bevordering
#  0.66        onherroepelijk is geworden
#  0.66             redelijke voorschriften
#  0.66                wegens de omstandigheid
#  0.66               verloop van zes
#  0.66              ontstane kosten
#  0.66             verhuurde persoonlijk
#  0.66          redelijkheid van het voorstel
#  0.66             verrichte arbeid
#  0.66               tijdvak dat het Uitvoeringsinstituut
#  0.66   arbeidsovereenkomst of bij regeling
#  0.65                 onder c
#  0.65               rechten of vorderingen
#  0.65               tijdvak waarover
#  0.65                   267 van Boek
#  0.65             gedurende hetwelk
#  0.65                eerste zin
#  0.65              ernstige reden
#  0.65                wenden met de vordering
#  0.65               aangaan van een nieuwe
#  0.65        rechtspersonen dan wel
#  0.65                 leden 1–3
#  0.65             verhuurde duurzaam
#  0.65          rechtstreeks betrekking
#  0.65                   zes jaren
#  0.65                 ieder geval
#  0.65             verpachte is gelegen
#  0.65          communicatie op afstand
#  0.65              waarover de pachtprijs
#  0.65          onmiddellijk verband
#  0.65                 enige wettelijke
#  0.65               gronden vermeld
#  0.65                  tien jaar
#  0.65            hoofdelijk aansprakelijk
#  0.65       redelijkerwijze geacht
#  0.65               rechten en verplichtingen
#  0.65                   dag waartegen
#  0.65                   had moeten
#  0.65                   uit hoofde
#  0.65                nadeel voor de patiënt
#  0.65                   uit te spreken
#  0.64             redelijke verhouding
#  0.64          inschrijving van de koop
#  0.64                   Wet werk
#  0.64                binnen bekwame
#  0.64                binnen dertig
#  0.64                   ter hand
#  0.64            bepalingen van deze titel
#  0.64               datgene te doen
#  0.64                aanbod tot het aangaan
#  0.64                   zou leiden
#  0.64          vermindering van de pachtprijs
#  0.64                aanbod tot schenking
#  0.64              belangen is uitgesloten
#  0.64                    In geval
#  0.64              bedoelde minimum
#  0.64                  Voor de berekening
#  0.64                   dag volgende
#  0.64                eerste volzin
#  0.64                arbeid en zorg
#  0.64                twaalf jaren
#  0.64                tweede zin
#  0.64                    64 eerste
#  0.64                   Een beding
#  0.64                   één of meer
#  0.64                 vanaf het tijdstip
#  0.64                tweede volzin
#  0.64                eerste graad
#  0.64          vastgestelde loon
#  0.64                  doet eindigen
#  0.64            beslissing tot toewijzing
#  0.64        bedrijfsruimte in de zin
#  0.64                  komt de bevoegdheid
#  0.63               gesteld desverlangd
#  0.63                     c d
#  0.63                     c en d
#  0.63                opgave te verstrekken
#  0.63             artikelen 252
#  0.63                wegens gewichtige
#  0.63               verband houdt
#  0.63              ontstaan waarvan
#  0.63                 gelet op de aard
#  0.63          vernietiging van de schenking
#  0.63                    48 b
#  0.63         toegankelijke wijze
#  0.63                beding dat afwijkt
#  0.63                   wet optreedt
#  0.63                   Bij een consumentenkoop
#  0.63                   ten dele
#  0.63                arbeid te verrichten
#  0.63                    13 van Boek
#  0.63               verzoek van de meest
#  0.63                beroep op de vernietigingsgrond
#  0.63            verrichten van diensten
#  0.63          vervreemding van het verpachte
#  0.63                   ten laste
#  0.63           uitoefening van de landbouw
#  0.63                ingang van een in het vonnis
#  0.63                  gaat kan voorzover
#  0.63                 staat van faillissement
#  0.63        redelijkerwijs mocht
#  0.62                   Wet rol
#  0.62                vorige zin
#  0.62                twaalf maanden
#  0.62                  reis reeds

# %% [markdown]
# Something we probably _should_ touch on in more detail is that the scoring is central to what is even lifted out.
#
# Gensim works differently from our code (based on a little more consideration), so gives different results.

# %% [markdown]
# ## Now with more text

# %%
# Get a bunch more text

# while we're at it, get a spacy model to split sentences, 
# which should reduce the amount of across-sentence-boundary n-grams

paragraphs  = []
for bwbid, text in wetsuite.datasets.load('bwb-mostrecent-text').data.random_sample(12500):
    paragraphs.extend( re.split(r'[\s]{2,}', text) )


coll = wetsuite.helpers.collocation.Collocation( connectors=connectors )

for paragraph in wetsuite.helpers.notebook.ProgressBar(paragraphs, description='splitting sentences'):
    if len(paragraph) >= 1000000: # spacy refuses very large documents for GPU memory reasons
        # we could feed it in in chunks, but we can also be lazier and just skip these for now
        continue
    # sentence_split() is a simple-and-stupid word splitter, mainly got get an answer faster for these quick experiments. 
    # Yes, we could do a full spacy parse, but it would be slower - but see later in this notebook.
    sents = wetsuite.helpers.spacy.sentence_split( paragraph, as_plain_sents=True )
    for sent in sents:
        toks = wetsuite.helpers.strings.simple_tokenize(sent)
        coll.consume_tokens( toks, gramlens=(2,3,4,5) )
# Out:
# splitting sentences:   0%|          | 0/282696 [00:00<?, ?it/s]

# %%
print( "Cleanup")
print( '    before:', coll.counts() )
coll.cleanup_ngrams(mincount=8)
print( '     after:', coll.counts() )
# Out:
# Cleanup
#     before: {'from_tokens': 19846519, 'unigrams': 168555, 'ngrams': 9838733}
#      after: {'from_tokens': 19846519, 'unigrams': 168555, 'ngrams': 362597}

# %%
top = 2000
print( "Scoring, showing top %d\n"%top)
scores = coll.score_ngrams( )
print( ' %9s   %55s    %12s %20s'%('score', 'n-gram', 'n-gram count', 'individual counts') )
for strtup, score,  tup_count, uni_counts in scores[-top:]:
    print( ' %9.3f   %55s    %12s %20s=%d'%(score, ' '.join(strtup),   tup_count, '*'.join(str(n) for n in uni_counts), wetsuite.helpers.collocation.product(uni_counts)) )
# Out:
# Scoring, showing top 2000
#
#      score                                                    n-gram    n-gram count    individual counts
#    157.500                                                 IEC 17025              27               126*45=5670
#    157.560                                       nacalculatie opgave             752            1062*4140=4396680
#    157.861                                Supreme Audit Institutions              15            15*194*21=61110
#    157.914                                                 A126 A127              26                69*76=5244
#    158.090                                            stelsel inzake            2921           5376*12298=66114048
#    158.183                                  thermische drukhydrolyse              43               333*43=14319
#    158.360                                afschaffing tariefbeloning              11                78*12=936
#    158.384                           instellingstoets kwaliteitszorg              16                20*99=1980
#    158.703                                                     C2 C3              21                74*46=3404
#    158.807                                              330 Inspelen             105              746*114=85044
#    158.891                                       demografisch bereik              31               31*239=7409
#    158.902                                         vaker inspecteert              19               121*23=2783
#    159.005                                   draagbaar klimmaterieel              13                62*21=1302
#    159.026                                              evbg extreem               8                17*29=493
#    159.035                           meerjarige activiteitensubsidie              37               285*37=10545
#    159.091                                Tuinbouwongevallenwet 1922              10                10*77=770
#    159.091                                         epilepsiezorg gez              20               110*28=3080
#    159.168                                      boter consumptiemelk              22               149*25=3725
#    159.358                                   Democratische Republiek              21               30*113=3390
#    159.382                                  Academische Ziekenhuizen              11                30*31=930
#    159.505                                                    NOH EX              10                24*32=768
#    159.661                                           Volledig gecoat              20                93*33=3069
#    159.725                                             forel meerval              11                32*29=928
#    159.883                                      tripartiet convenant              40               41*299=12259
#    160.000                         cijferanalyse cijferbeoordelingen               8                35*14=490
#    160.417                               tandtechnicus tandtechnisch              11                33*28=924
#    160.421                                         Open Universiteit              53              110*195=21450
#    160.656                                      Plastische chirurgie               8                 8*61=488
#    160.763                                           Politiewet 2012             575             814*3095=2519330
#    160.859                                          Delft Hydraulics              13                99*13=1287
#    160.934                               vervangende voederproteïnen              65               480*67=32160
#    160.949                                         lageringen bussen              36               36*274=9864
#    160.963                                    extramurale parameters             159              400*481=192400
#    161.114                                          1650 productieve              11                23*40=920
#    161.184                                        antenne opstelpunt              15                95*18=1710
#    161.317                                methaan distikstofmonoxide               8                27*18=486
#    161.358                                        VHF radiotelefonie              35               93*100=9300
#    161.482                                        natuurlijk verloop             443            1116*1334=1488744
#    161.538                  kwalitatieve representativiteitscriteria              96               728*96=69888
#    161.636                                   chief executive officer              11             34*16*59=32096
#    161.712          Subsidieprogramma Orange Corners Innovation Fund               8      106*21*14*23*29=20786388
#    161.792                                     Subsidieprogramma DHI              14               106*14=1484
#    162.037                                 trade controlemechanismen              10                21*36=756
#    162.261                                  woonwagens gereedgekomen              22                87*42=3654
#    162.314                                   automatische schakeling              74               492*84=41328
#    162.467                                   afgelopen oesterseizoen              90              522*117=61074
#    162.467                                            Adres Postcode              10                26*29=754
#    162.768                                             Verkeerde bed              48               51*340=17340
#    162.816                                                 DUO 60102              42               316*42=13272
#    162.931                                       moeilijk opvoedbare              54               406*54=21924
#    163.165                                                   A81 A82              29                82*77=6314
#    163.333                                 Financiële verhoudingswet             166             1245*166=206670
#    163.333                                      voetgangers fietsers              14                49*30=1470
#    163.591                        inzamelaars vervoerders handelaars               9             23*71*13=21229
#    163.643                                 equivalente geluidsniveau              46               99*160=15840
#    163.749                                             televisie VOD              17                94*23=2162
#    164.008                              justitiële jeugdinrichtingen             117              845*121=102245
#    164.008                                                     GL TL               9                55*11=605
#    164.115                                                   A82 A83              28                77*76=5852
#    164.252                                               BTR postbus              42               52*253=13156
#    164.306                                         Domeinen Roerende              13                63*20=1260
#    164.366                                         entity other than              10             47*37*15=26085
#    164.386                                             meest recente             283             1421*420=596820
#    164.451                                             ML Zoetermeer              33               48*169=8112
#    164.552                                    crossmediaal marketing              18               18*134=2412
#    164.578                              vervolgvergunning aardwarmte              51               55*352=19360
#    164.706                                    onbestelbaar terugkomt               8                17*28=476
#    164.746                             Commandant Landstrijdkrachten              55               271*83=22493
#    164.847                                  solidaire premieregeling              15                19*88=1672
#    164.854                                           Republiek Congo              21               113*29=3277
#    164.904                                   Manager Grondverwerving              21               156*21=3276
#    165.053                                 frequentiespectrum overal               8                19*25=475
#    165.092                               energieprestatie huursector              13                38*33=1254
#    165.278                                                 IEC 61400              17               126*17=2142
#    165.317                                    fotografische gelatine              10                39*19=741
#    165.597                                Wetenschappelijk Onderzoek              64              100*303=30300
#    165.700                                praktijktrainer nascholing              28               28*207=5796
#    165.885                                              Dynamisch d6              13                96*13=1248
#    166.102                                       credit institutions              20               118*25=2950
#    166.159                                        Helicopter landing              14                17*85=1445
#    166.198                               windenergiegebied Hollandse              86              194*281=54514
#    166.250                               eenden duikers aalscholvers              38            196*50*38=372400
#    166.310                                               Schengen OT              36               129*74=9546
#    166.358                                                 ZrgWlz Vz              11                33*27=891
#    166.497                                     Productschap Tuinbouw             146              928*169=156832
#    166.651                                              Edammer kaas              24               29*146=4234
#    166.846                                Zorgvraagtypering Volledig              38               114*93=10602
#    167.054                                             verlaagde btw             417             630*2024=1275120
#    167.145                                              `DE MINISTER              41               80*154=12320
#    167.521                                           principle based               8                18*26=468
#    167.521                                                   St Goar              12                81*13=1053
#    167.675                                       brinnummer postcode              53               62*331=20522
#    167.675                                                   3502 GA              11                13*68=884
#    168.000                           rechtspersoonlijkheid bezittend              48               350*48=16800
#    168.051                               gefluoreerde broeikasgassen              38               38*277=10526
#    168.056                                      Ondersteunende Taken              11                21*42=882
#    168.265                                  corrigerende interventie             195              497*557=276829
#    168.269                              drukwerk kopieerfaciliteiten              10                56*13=728
#    168.313                            importerende weefselinstelling              13                15*82=1230
#    168.373                                         vitro diagnostica              14                46*31=1426
#    168.499                                  Ondertekening Langdurige              41              121*101=12221
#    168.613                                kleinschalige experimenten              59               90*281=25290
#    168.750                                                opgaaf ICP              36               224*42=9408
#    168.930                                      Beleidsnota Noordzee              36               37*254=9398
#    168.966                                 allocatie arbeidskrachten              28                98*58=5684
#    168.966                                           Huntington Z920               8                 58*8=464
#    169.147                                          tweetonige hoorn              17                23*91=2093
#    169.361                                 landelijk gastransportnet             413             2046*603=1233738
#    169.400                                           apen hoefdieren              11                25*35=875
#    169.615                             Stafafdeling Crisismanagement               9                45*13=585
#    169.668                                     starre hoofdstructuur              10                19*38=722
#    169.786                               Specifiek interventiebeleid              83              152*327=49704
#    170.021                                 strafverzwarend rijgedrag              19                51*51=2601
#    170.087                                      Leidraad Invordering              19               100*26=2600
#    170.139                                noodmaatregel overbrugging              10                20*36=720
#    170.163                                      Erfgoedcentrum Nieuw              34               38*219=8322
#    170.203                                 arbeidsbelasting werkdruk              21                46*69=3174
#    170.435                              verslaggevingscriteria <naam              16               115*16=1840
#    170.526                                        PV ERA NET Polymol               9         297*16*15*10=712800
#    170.608                                       WL Delft Hydraulics              13             33*99*13=42471
#    170.711                                        interne beheersing            2073           13269*2324=30837156
#    170.806                                                    Vo 918              16                54*34=1836
#    171.094                        methaan distikstofmonoxide lachgas               8             27*18*33=16038
#    171.148                                                   NC HVDC              96              276*239=65964
#    171.343                                                  Dader +0              26               27*179=4833
#    171.414                               Westland Schieland Delfland               8              29*8*69=16008
#    171.569                            Baseline Informatiebeveiliging              10                21*34=714
#    171.930                                                    SV AVF              16               114*16=1824
#    171.930                                   Indonesische Pensioenen              16                48*38=1824
#    171.959                      staffel incassokosten kantonrechters               9             51*18*22=20196
#    172.308                                       Competent Authority               8                13*35=455
#    172.406                                                       t m            2109            4028*7846=31603688
#    172.451                                                Nieuwe pre             122              472*224=105728
#    172.535                                  lumpsum kwaliteitsbudget              30                71*90=6390
#    172.605                                                    zg vis             349             788*1097=864436
#    172.756                               Toelageregeling afschaffing              11                11*78=858
#    172.756                                 intermitterende beademing              11                13*66=858
#    172.927                                         Klasse Inwonertal              21               142*22=3124
#    172.973                                          spoedig mogelijk            2026           2120*13712=29069440
#    173.098                                Onvolledig behandeltraject              13                13*92=1196
#    173.218                                           stille reserves              50               80*221=17680
#    173.349                              wisselende vervoersafstanden              15               106*15=1590
#    173.643                                               Mytilus Spp              16                21*86=1806
#    173.964                                             KX Zoetermeer              24               24*169=4056
#    173.971                                        NS Railinfrabeheer              13                85*14=1190
#    174.029                                 Gemeentelijk Havenbedrijf              16                34*53=1802
#    174.029                                     bovenste analysegrens              16               106*17=1802
#    174.154                                   fokbedrijf opfokbedrijf              21                66*47=3102
#    174.222                                Armoedebeleid Participatie               8                 9*50=450
#    174.263                                             ESF 2007–2013              13                66*18=1188
#    174.487                                   kwaliteitssystemen NVKS              77              125*333=41625
#    174.748                              biologische productiemethode              69               445*75=33375
#    174.827                                           Vlissingen Rede              17                81*25=2025
#    175.000                                           ouderdieren leg              10                20*35=700
#    175.000                                     moist huisdiervoeders              12                24*42=1008
#    175.000                                Ambulant kwaliteitsstatuut              12                12*84=1008
#    175.000                                          Wgp maximumprijs               8                16*28=448
#    175.000                                             CPP2002 2313M               8                 56*8=448
#    175.000                                        opschalingsfase 1+              12                72*14=1008
#    175.000                               gastouderbureaus gastouders               9                21*27=567
#    175.000                                                  emg Z919               8                28*16=448
#    175.203                           vleesprodukten vleesbereidingen              40               99*113=11187
#    175.280                                   Lichamelijk gehandicapt              25                84*52=4368
#    175.346                    Opdrachtgerichte kwaliteitsbeoordeling              39               42*253=10626
#    175.414                                     zittende magistratuur              11                65*13=845
#    175.672                                                   A97 A98              28                77*71=5467
#    175.748                                landelijke politiediensten             214             1471*217=319207
#    175.897                                  universitair hoofddocent              14                65*21=1365
#    175.931                              Windenergie grootverbruikers              18                47*48=2256
#    175.931                                              case reports              18                94*24=2256
#    176.199                              consumptiemelkproducten kaas              21               21*146=3066
#    176.224                                     waarmerkende actuaris              12                13*77=1001
#    176.249                                           meerval tilapia              11                29*29=841
#    176.458                                        Steunpunt Educatie              11                14*60=840
#    176.458                                        Rekening couranten              11                70*12=840
#    176.484                                      setting organization              38               257*39=10023
#    176.555                                                 carve out              38               43*233=10019
#    176.872                        concurrerende capaciteitsaanvragen               9                33*17=561
#    176.970                                    nagelaten betrekkingen              97              195*334=65130
#    177.064                            gehonoreerde productieafspraak              50               94*184=17296
#    177.121                                     hoogpathogene aviaire              43               92*139=12788
#    177.303                                    Productioneel Protocol              66               66*456=30096
#    177.391                                      re integratiebedrijf             106              732*106=77592
#    177.504                              biochemisch zuurstofverbruik               9                13*43=559
#    177.536                                          rondom schijnend              80               552*80=44160
#    178.182                                                 day ahead               8                 55*8=440
#    178.390                                        loonbelasting 1964             354              996*864=860544
#    178.405                                                   1388 NC              43               46*276=12696
#    178.543                                         Goudse boerenkaas              12                38*26=988
#    178.737                         gepaste ontsmettingsvoorzieningen              41               281*41=11521
#    178.784                          herontwerp kwalificatiestructuur               9                15*37=555
#    178.801                                                 high care              17                36*55=1980
#    178.871                                                  P Direkt             212             1425*216=307800
#    178.933                                      Wajong adviesvoucher              13                89*13=1157
#    179.698                                      Thermische conversie              76              125*315=39375
#    179.862                                   persoonsgebonden budget             470             750*2006=1504500
#    179.944                                              Veilig Thuis              26               118*39=4602
#    179.952                                                   Lw Tech              78              248*167=41416
#    180.022                                   hypothetische nulmeting              13                25*46=1150
#    180.409                                        Thematisch Netwerk               9                10*55=550
#    180.441                             Handleiding Overheidstarieven              17               109*18=1962
#    180.500                                            eenden duikers              38               196*50=9800
#    180.665                                        arbeidspool zoeken              49               55*296=16280
#    180.798                           multilaterale handelsfaciliteit              21                83*36=2988
#    181.391                                      vluchtige organische              62               88*295=25960
#    181.481                                                 126m 126t               8                27*16=432
#    181.481                                                   BPR RPR              10                45*15=675
#    181.481                                      kinderdagcentrum kdc               8                12*36=432
#    181.601                                inseminatoren dierenartsen              13                15*76=1140
#    181.648                                      antenne opstelpunten              18                95*23=2185
#    181.814                                          Letland Litouwen              18                59*37=2183
#    181.840                                         commerciële radio             279              808*649=524392
#    181.876                                          rivieren kanalen              32               57*121=6897
#    181.894                              tweekleurige verkeerslichten              14                24*55=1320
#    182.088                                          winkels kantines              20                69*39=2691
#    182.114                                          ● belastingvrije              32               56*123=6888
#    182.292                                arbeidsconflicten tekorten              10                14*48=672
#    182.751                                           PBV Aanbeveling               8                13*33=429
#    183.213                                    biologisch afbreekbaar              23               131*27=3537
#    183.599                                           publieke sector             856            1672*2924=4888928
#    183.750                         gestandaardiseerde laadstructuren              18               108*20=2160
#    183.750                                              Flamingo CTR               9                10*54=540
#    183.934                                                short form              20                37*72=2664
#    184.091                                                    NLR CR               9                49*11=539
#    184.091                                   Onderzoeksprogramma NLR               9                11*49=539
#    184.326                                  risicodragend investeert              12                29*33=957
#    184.471                                                Rode Kruis              27               47*103=4841
#    184.589                                                 ISRS 4410              11                11*73=803
#    184.677                               late zwangerschapsafbreking              17                71*27=1917
#    184.906                           Subsidieprogramma DHI 2019–2023               8            106*14*10=14840
#    185.425                                              TOP internet              64               66*410=27060
#    185.513                                                   183 843              44               188*68=12784
#    185.606                            Uniform Aanbestedingsreglement              10                55*12=660
#    185.850                         buitengewoon opsporingsambtenaren            1019            5419*1263=6844197
#    185.968                                       Veeziektenfonds PPE              70               87*371=32277
#    186.070                                                      µg l             184             206*1082=222892
#    186.085                                     meldplicht datalekken              32               107*63=6741
#    186.122                                    Garantiewet Surinaamse              19                54*44=2376
#    186.124                                   Vaktechniek Belastingen              28                60*86=5160
#    186.163                                     finaal verrekenbeding               9                13*41=533
#    186.368                    modelverklaring Herplaatsingsonderzoek              89               585*89=52065
#    186.513                               jarig Activiteitenprogramma               9                28*19=532
#    186.738                              geldboetes schadevergoedings              10                41*16=656
#    186.738                               Oordeelonthouding Afkeurend              15                36*41=1476
#    186.971                                  financiële verslaggeving            5711           35280*6057=213690960
#    187.014                                        vloeistof verdicht              39               243*41=9963
#    187.184                                         zorgvraagtype d10              13                79*14=1106
#    187.381                                        Buitenlandse Zaken            1142            1345*6339=8525955
#    187.560                                                  903 8220               8                38*11=418
#    187.653                                          obstakels steken              25                80*51=4080
#    188.004                                          werkkring buiten            1320            1349*8416=11353184
#    188.462                                        instelbaar offline               8                32*13=416
#    188.628                                        inwerking getreden             208             276*1018=280968
#    188.786                                     deelcommissie PSOM OS               8             45*17*19=14535
#    188.985                                                 real time              19                26*90=2340
#    189.005                                   algehele controleaanpak             215             1002*299=299598
#    189.043                                   debiteuren subgrootboek              10                54*12=648
#    190.061                            subsidieregels Aangepast Lezen              16             25*42*55=57750
#    190.130                                            dierlijke mest             416             1424*783=1114992
#    190.178               Continued Professional Development Forensic               8          8*25*101*25=505000
#    190.431                                                vers vlees             222             289*1097=317033
#    190.556                                Gecombineerde Nomenclatuur              14                90*14=1260
#    190.596                               accountantsorganisaties VAO              69               360*85=30600
#    190.794                                        televisie Video On               8              94*9*17=14382
#    190.812                             Zintuiglijk gehandicaptenzorg              32               38*173=6574
#    190.909                                           Leerlingen 25GR              12                42*22=924
#    190.914                                          hernieuwbaar gas             193             194*1232=239008
#    191.046                                         Economische Zaken            1659            2784*6339=17647776
#    191.220                                  Coordination Netherlands              16                20*82=1640
#    191.338                                      thermische conversie             128              333*315=104895
#    191.406                                               anti witwas              25               160*25=4000
#    191.739                                  recreatief nachtverblijf              12                40*23=920
#    191.799                                             Zeer moeilijk              84              111*406=45066
#    191.925                                     bloembollen leverbaar              54               282*66=18612
#    191.978                                           RDM Functioneel              21               21*134=2814
#    192.006                                                25GP Visio              10                22*29=638
#    192.157                                          Transactie Modal               8                 51*8=408
#    192.157                                   indicerende verwijzende               8                 8*51=408
#    192.745                                           Poging Voltooid              15                55*26=1430
#    192.745                                              510 Initiële              30               104*55=5720
#    192.772                                     forel meerval tilapia              11             32*29*29=26912
#    192.900                                             Noord Holland             210              709*395=280055
#    193.185                                                      NO x             275             348*1378=479544
#    193.384       loopvogels Struthioniformes struisvogels Rheiformes              38         139*39*53*39=11205207
#    193.428                                        onrechtmatige daad              37               102*85=8670
#    193.687                                   International Financial             142              585*218=127530
#    194.504                                  zelfdragende carrosserie              60               79*287=22673
#    194.559                                                   ILT IOD              27                90*51=4590
#    194.567                                             re integratie             230              732*455=333060
#    194.744                             marktordening gezondheidszorg             266             278*1601=445078
#    194.942                         Pré Brede Herwaarderinglijfrenten              16             34*92*18=56304
#    195.067                                                    Eis TS             132              247*443=109421
#    195.071                                       vergunde kansspelen              65               99*268=26532
#    195.367                                                  risico s            5856          10884*19756=215024304
#    195.375                          kredietrisico liquiditeitsrisico              10                33*19=627
#    195.375                                                  Mijn RvR              10                57*11=627
#    195.507                                      Vervoer dagbesteding             315             471*1320=621720
#    195.511                                         no claimteruggave              64               401*64=25664
#    195.540                                   resulterende meetwaarde              34               142*51=7242
#    195.609                                            gerede twijfel             250             371*1055=391405
#    196.097                                   Beheerplan Deltawateren               9                23*22=506
#    196.102                                                 Te denken             130              391*270=105570
#    196.218                                            tilapia paling              12                29*31=899
#    196.339                                               ten aanzien            9171          48788*10756=524763728
#    196.462                            Maritieme Veiligheidscommissie              17               106*17=1802
#    196.617                                          macro omzetgrens              50               236*66=15576
#    196.656                                      kantines restaurants              12                39*23=897
#    196.875                                      Opleidings Trainings               9                 56*9=504
#    197.048                                      geijkte meetmiddelen              38               47*191=8977
#    197.108                                      splijtstoffen ertsen              33                94*72=6768
#    197.167                                    Toelating Exceptioneel              13                75*14=1050
#    197.426                                                    NR REG             141              281*439=123359
#    197.533                        North Africa Scholarship programme               9          49*23*26*21=615342
#    197.646                                     Wegenverkeerswet 1994             406             468*2183=1021644
#    197.730                                             honden katten              32               104*61=6344
#    197.980                                                  EOS demo               8                36*11=396
#    198.063                                                    AID DO              26               113*37=4181
#    198.113                                    gedistilleerde dranken             150              265*525=139125
#    198.340                                              cut off date              88          105*149*107=1674015
#    198.500                                       gasvormig transport             220             238*1255=298690
#    198.649                                         helpdeskpa minbzk              12                12*74=888
#    198.990                                    meerval tilapia paling              11             29*29*31=26071
#    199.051                            expertisecentrum onderwijszorg              21               118*23=2714
#    199.740                                        watervogels zwanen              38               216*41=8856
#    200.034                                         massale toestroom              11                39*19=741
#    200.034                                               odour units              11                13*57=741
#    200.651                                                  RVV 1990             220             243*1216=295488
#    200.860                                                  Eems Ems               9                38*13=494
#    200.899                         eindverantwoordelijk professional              50              103*148=15244
#    200.939                                        baten lastendienst             166             1012*166=167992
#    201.119                                 voortijdig schoolverlaten              22               134*22=2948
#    201.370                                rijksbrede inkoopcategorie              12                73*12=876
#    201.677                                   Rapporteur Mensenhandel               9                41*12=492
#    201.765                                            https lci rivm               8             170*8*10=13600
#    202.005                                              track record              29               34*150=5100
#    202.062                                      verdekte pepperspray              16                16*97=1552
#    202.787                                            Bedrijf Gebouw              21               111*24=2664
#    202.905                                               avond nacht              43               61*183=11163
#    203.228                                   Europese Gemeenschappen            1154            6920*1160=8027200
#    203.275                                             BRMO uitbraak              38               38*229=8702
#    203.636                                         behandelzorg Z981               8                35*11=385
#    203.894                                            706 Paragrafen              74              235*140=32900
#    204.167                                            Bonn conventie              10                30*20=600
#    204.167                   Bevoegdhedenverordening registerloodsen              10                10*60=600
#    204.167                                             CTR Rooseveld               9                 54*9=486
#    204.167                                                    >3 80A              20                48*50=2400
#    204.182                                      Invorderingswet 1990             230             261*1216=317376
#    204.732                            Geadviseerde zorgvraagtype d10              13             32*79*14=35392
#    205.382                                                 A147 A148              26                64*63=4032
#    205.410                                          COPD Zware astma              18            106*29*22=67628
#    205.435                                                 126g 126o               9                21*23=483
#    205.484                            transactiestroom rekeningsaldo              78              186*195=36270
#    205.639                                      plastische chirurgie              16                25*61=1525
#    205.766                                        steun huurwoningen             236              981*338=331578
#    206.226                                     normering topinkomens              22               115*25=2875
#    206.229                                              Chinese kool              10                27*22=594
#    206.338                                                  ID banen              56              107*174=18618
#    206.342                                     onafgebroken rusttijd              89              275*171=47025
#    206.627                                           DigiD Machtigen              14                83*14=1162
#    206.683                                  vogelverblijfplaats kooi              51               164*94=15416
#    206.719                             basisbedragen minimumbedragen               9                30*16=480
#    206.719                                         Dagbehandeling LG               9                32*15=480
#    207.042                                              historie d13              12                71*12=852
#    207.042                                              historie d14              12                71*12=852
#    207.089                                        3970 AC Driebergen              18             24*65*43=67080
#    207.308                                        ambtenarenwet 1931              11                11*65=715
#    207.509                                    stedelijke vernieuwing              84              118*353=41654
#    207.520                                       bevoegde autoriteit            1260            3879*2416=9371664
#    207.598                       elektrotechnisch installatiebedrijf              11                21*34=714
#    207.627                                                   big bag              10                59*10=590
#    207.699                                              TV+VEV TV+EV              28                68*68=4624
#    207.958                                                  HIV AIDS               8                29*13=377
#    207.980                          tolheffing Blankenburgverbinding              10                31*19=589
#    208.376                                  Financieel Productioneel              66               388*66=25608
#    208.387                                             DN Waardering              98              153*369=56457
#    208.504                      verontreinigingsheffing rijkswateren              25               36*102=3672
#    208.866                                           Midden Delfland              60               306*69=21114
#    209.067                              middenmanager Bestuursbureau               8                25*15=375
#    209.117                              Euro Overnight Index Average               9          138*9*39*12=581256
#    209.531                                                 A148 A149              25                63*58=3654
#    209.539                                  Wageningen Bioveterinary              13                76*13=988
#    209.685                                           Bedrijf Postale              19               111*19=2109
#    210.000                                                 A197 A198              12                28*30=840
#    210.000                                             inlands graan              12                14*60=840
#    211.025                                    versus toekomstgericht              20                86*27=2322
#    211.154                                                    NL IGA             195             1103*200=220600
#    211.157                               vennootschapsbelasting 1969             358              843*882=743526
#    211.438                                     oliehoudende mengsels              42               70*146=10220
#    211.730                            mijnbouwkundige onderzoekingen              39               55*160=8800
#    211.750                                               H001G H005G              11                28*25=700
#    211.782                                                    Lw LWT              49               248*56=13888
#    212.019                                        Utrechts Landschap               9                13*36=468
#    212.239                                      ondersteuning extern             907            3823*1242=4748166
#    212.466                                      liters geconsumeerde               8                 41*9=369
#    212.674                                             Factor Effect              10                24*24=576
#    213.043                                    Structuurschema Groene              12                18*46=828
#    213.043                                            sr casemanager              18                27*69=1863
#    213.043                                           ECG hartfilmpje              12                36*23=828
#    213.043                    ergotherapeut logopedist mondhygiënist               8             23*28*20=12880
#    213.140                                        fysische inperking              47               184*69=12696
#    213.385                                              BN Apeldoorn              25                46*78=3588
#    213.889                                    Politieke Ambtsdragers              11                63*11=693
#    214.912                     radicalisering gewelddadig extremisme               8             32*21*19=12768
#    215.385                                          American Society               8                26*14=364
#    215.452                                      stoffelijk overschot              39               47*184=8648
#    215.485                  loopvogels Struthioniformes struisvogels              38            139*39*53=287313
#    215.524                                       beschermde inheemse              72               355*83=29465
#    215.626                                         OESO modelverdrag              66               339*73=24747
#    215.669                              migrerende beroepsbeoefenaar             120              142*576=81792
#    215.978                                             Animal Health               8                11*33=363
#    216.036                                          driehoekige rode              76               92*356=32752
#    216.803                                      aanbestedende dienst            1711            1859*8898=16541382
#    217.599                                                Energy Ltd               9                19*24=456
#    217.646                              forel meerval tilapia paling              11          32*29*29*31=834272
#    217.778                       Stimuleringsmaatregel Filmproductie               8                 40*9=360
#    217.996                                     alcoholhoudende drank             102              252*232=58464
#    218.273                       capaciteitsvermindering zeevisserij              14                22*50=1100
#    218.929                                              5044 2600 GA              10             12*24*68=19584
#    219.010                                      Accounting Standards             103              172*345=59340
#    219.467                                         symmetrisch links              51               61*238=14518
#    219.608                                      Beroepsopleiding VAM              16                34*42=1428
#    219.626                                               Gemengde Lw              49               54*248=13392
#    220.285                     hygiënevoorschriften pluimveehouderij              41               164*57=9348
#    220.573                                 Projectmanagement Support              11                16*42=672
#    220.578                                    ademanalyse bloedproef              25                89*39=3471
#    220.775               struisvogels Struthionidae emoes Dromaiidae               9          53*14*53*14=550564
#    220.848                                        lichamelijk letsel             192              321*637=204477
#    220.853                                     Georganiseerd Overleg              45               48*234=11232
#    221.011                                       trekkende bevolking              90              184*244=44896
# ...
#   1160.526                                 Transcraniële Magnetische              18                18*19=342
#   1160.526                                    Magnetische Stimulatie              18                19*18=342
#   1161.069                                      Ruimtelijke Ordening             586              612*592=362304
#   1163.750                                       steltlopers meeuwen              38                38*40=1520
#   1169.318                                       physician assistant              63                63*66=4158
#   1177.885                                    Spoedwet wegverbreding              25                26*25=650
#   1197.643                                                  SARS CoV             264              266*268=71288
#   1198.370                                                bijz voorw              45                45*46=2070
#   1216.833                                         continentaal plat             149              149*150=22350
#   1219.556                           Fysisch Chemische Eigenschappen               8              10*25*9=2250
#   1225.000                                                fault ride              17                17*17=289
#   1225.000                                Casuariiformes kasuarissen              39                39*39=1521
#   1225.000                                       Apterygiformes kiwi              39                39*39=1521
#   1225.000                                      aalscholvers reigers              38                38*38=1444
#   1225.000                                         reigers ooievaars              38                38*38=1444
#   1225.000                                         ooievaars ibissen              38                38*38=1444
#   1225.000                                          ibissen flamingo              38                38*38=1444
#   1225.000                                         futen kraanvogels              38                38*38=1444
#   1225.000                                        kraanvogels rallen              38                38*38=1444
#   1225.000                                        rallen steltlopers              38                38*38=1444
#   1225.000                                          WILLEM ALEXANDER               8                  8*8=64
#   1225.000                                                   GOD ZIJ              22                22*22=484
#   1225.000                                         Interbank Offered              21                21*21=441
#   1225.000                                  driemaands termijngelden               9                  9*9=81
#   1225.000                                                 Hong Kong              18                18*18=324
#   1225.000                                         Clarius garipinus               9                  9*9=81
#   1225.000                             Cinematografische Coproductie               8                  8*8=64
#   1225.000                                            Meerlo Wanssum               8                  8*8=64
#   1225.000                                               Modal Shift               8                  8*8=64
#   1225.000                                               modal shift               8                  8*8=64
#   1225.000                                        Einstein Telescope               8                  8*8=64
#   1225.000                                       Ditylenchus dipsaci              12                12*12=144
#   1225.000                                      tinnitus hypoacousis               8                  8*8=64
#   1225.000                                             Gallus gallus              11                11*11=121
#   1225.000                                          BEATRIX KONINGIN              10                10*10=100
#   1225.000                                              ulcus cruris               9                  9*9=81
#   1225.000                                     Obstructive Pulmonary              13                13*13=169
#   1225.000                                      Hoogere Krijgsschool              11                11*11=121
#   1225.000                                       Rijcken Droogleever              12                12*12=144
#   1225.000                                      Droogleever Fortuijn              12                12*12=144
#   1225.000                                              Lenen Sparen              12                12*12=144
#   1225.000                                     Sparen Retailbeleggen              12                12*12=144
#   1225.000                                           3381529 1030844               8                  8*8=64
#   1225.000                                             773523 137331              16                16*16=256
#   1225.000                                        Codex Alimentarius               8                  8*8=64
#   1225.000                            Kurzarbeitergeld Insolvenzgeld              15                15*15=225
#   1225.000                                    Adelsbeleid adelsrecht               9                  9*9=81
#   1225.000                                    fuseepennen lageringen              36                36*36=1296
#   1225.000                                 Clavibacter michiganensis               9                  9*9=81
#   1225.000                                             numerus fixus              15                15*15=225
#   1225.000                                         traan verwekkende              12                12*12=144
#   1225.000                                            Muzzle Loaders              12                12*12=144
#   1225.000                                Wapenverzamelingen Edouard              10                10*10=100
#   1225.000                                Parallelweg Biddingringweg               9                  9*9=81
#   1225.000                                     gemarmerde stinkwants              10                10*10=100
#   1225.000                                     stinkwants Halymorpha              10                10*10=100
#   1225.000                                          Halymorpha halys              10                10*10=100
#   1225.000                                    Hertogin Hedwigepolder               8                  8*8=64
#   1225.000                        belevingsgericht belevingsgerichte               8                  8*8=64
#   1225.000                                           Sinclair Collis               8                  8*8=64
#   1225.000                                            34858995 14696              15                15*15=225
#   1225.000                                                DISAD BIRS              23                23*23=529
#   1225.000                                       airport dutymanager              25                25*25=625
#   1225.000                                            ERM Yersiniose               8                  8*8=64
#   1258.288                                     beschuit koek koekjes               9             12*10*23=2760
#   1267.809                                               ZIJ MET ONS              22             22*31*24=16368
#   1284.274                                     kluiten modder stenen              13             13*14*31=5642
#   1286.765                             oploop rellen ongeregeldheden              10             14*14*17=3332
#   1299.242                             Obstructive Pulmonary Disease              13             13*13*33=5577
#   1383.065                                               GOD ZIJ MET              22             22*22*31=15004
#   1383.065                                      BEATRIX KONINGIN DER              10             10*10*31=3100
#   1410.362          repetitieve Transcraniële Magnetische Stimulatie               9          14*18*19*18=86184
#   1419.925                      Interbank Offered Rate Euribortarief              13          21*21*27*15=178605
#   1429.167              tetrafluorethyleen perfluormethyl vinylether               9              15*9*18=2430
#   1465.454                                       O513 O523 O533 O543               8          16*16*16*16=65536
#   1465.454                                       O523 O533 O543 O553               8          16*16*16*16=65536
#   1502.533                                       randschrift GOD ZIJ              21             26*22*22=12584
#   1507.324                                            Z913 Z914 Z915              12             16*16*16=4096
#   1507.324                                            V913 V914 V915              12             16*16*16=4096
#   1514.606                                    Bundesamt für Finanzen              13             13*23*16=4784
#   1524.444                           Overview Continued Professional               8               9*8*25=1800
#   1587.963                                    Interbank Offered Rate              21             21*21*27=11907
#   1587.963                      laatdoven slechthorenden doofblinden               8               8*24*9=1728
#   1630.422                                             On Demand pay               8              17*9*11=1683
#   1696.408                                   randschrift GOD ZIJ MET              21          26*22*22*31=390104
#   1702.390                                     Waarborg Platina Goud               9             17*10*12=2040
#   1786.458                                           ERA NET Polymol              10             16*15*10=2400
#   1792.861                          BEATRIX KONINGIN DER NEDERLANDEN              10          10*10*31*27=83700
#   1898.962                                        fault ride through              16             17*17*20=5780
#   1910.651                     kopjes paragraafnummers typografische              10             12*17*11=2244
#   1992.738                                           Video On Demand               8               9*17*9=1377
#   1996.093   distikstofmonoxide lachgas zwavelhexafluoride fluorkoolwaterstoffen               8            18*33*9*9=48114
#   2009.766                                WAREN AUTORITEIT ONDERDEEL               9              12*16*9=1728
#   2016.969                                           GOD ZIJ MET ONS              22          22*22*31*24=360096
#   2143.750                               bruin gemarmerde stinkwants              10             20*10*10=2000
#   2143.750                              perfluoralkyl vinylether PFA               9              9*18*10=1620
#   2143.750                             perfluormethyl vinylether MFA               9              9*18*10=1620
#   2206.801                              suzuki fruitvlieg Drosophila              14             14*16*17=3808
#   2206.801                             fruitvlieg Drosophila suzukii              14             16*17*14=3808
#   2256.579                      Transcraniële Magnetische Stimulatie              18             18*19*18=6156
#   2360.835                             televisie Video On Demand pay               8         94*9*17*9*11=1423818
#   2381.944                               Muzzle Loaders Associations               8              12*12*8=1152
#   2401.794                                        Defined Daily Dose              11             12*15*12=2160
#   2473.558                          zeesterren slikmosselen slippers              12             16*12*13=2496
#   2473.929                               randschrift GOD ZIJ MET ONS              21       26*22*22*31*24=9362496
#   2587.527   methaan distikstofmonoxide lachgas zwavelhexafluoride fluorkoolwaterstoffen               8         27*18*33*9*9=1299078
#   2752.505                          beschuit koek koekjes ragoutwerk               9          12*10*23*16=44160
#   2792.726                 schelpen zeesterren slikmosselen slippers              12          31*16*12*13=77376
#   2826.923                              slikmosselen slippers pokken              12             12*13*14=2184
#   2843.750                                     pokken kluiten modder              13             14*13*14=2548
#   3062.500                                   slippers pokken kluiten              13             13*14*13=2366
#   3062.500                             Chronic Obstructive Pulmonary              13             14*13*13=2366
#   3205.681                                  O513 O523 O533 O543 O553               8       16*16*16*16*16=1048576
#   3210.685                              pokken kluiten modder stenen              13          14*13*14*31=78988
#   3248.106                     Chronic Obstructive Pulmonary Disease              13          14*13*13*33=78078
#   3298.077                                  Pels Rijcken Droogleever              12             13*12*12=1872
#   3298.077                   Toezichtcategorie Maatstaf Bandbreedtes              11             11*13*11=1573
#   3303.006                        koek koekjes ragoutwerk kerstbrood               9          10*23*16*10=36800
#   3572.917                              Rijcken Droogleever Fortuijn              12             12*12*12=1728
#   3572.917                               Lenen Sparen Retailbeleggen              12             12*12*12=1728
#   3572.917                               advanced nurse practitioner              10             10*12*10=1200
#   3764.060   zwavelhexafluoride fluorkoolwaterstoffen perfluorkoolstoffen               8                9*9*9=729
#   3992.185   lachgas zwavelhexafluoride fluorkoolwaterstoffen perfluorkoolstoffen               8             33*9*9*9=24057
#   4234.568                                    digital cinema package               8                9*8*9=648
#   4287.500                          gemarmerde stinkwants Halymorpha              10             10*10*10=1000
#   4287.500                               stinkwants Halymorpha halys              10             10*10*10=1000
#   4763.889                       gehoorstoornis tinnitus hypoacousis               8                9*8*8=576
#   5002.083          tetrafluorethyleen perfluormethyl vinylether MFA               9           15*9*18*10=24300
#   5517.004                      suzuki fruitvlieg Drosophila suzukii              14          14*16*17*14=53312
#   6183.894                   zeesterren slikmosselen slippers pokken              12          16*12*13*14=34944
#   6340.529                                       Video On Demand pay               8            9*17*9*11=15147
#   6981.816          schelpen zeesterren slikmosselen slippers pokken              12       31*16*12*13*14=1083264
#   7503.125                    bruin gemarmerde stinkwants Halymorpha              10          20*10*10*10=20000
#   7610.947                      slikmosselen slippers pokken kluiten              12          12*13*14*13=28392
#   7656.250                            slippers pokken kluiten modder              13          13*14*13*14=33124
#   7762.582   distikstofmonoxide lachgas zwavelhexafluoride fluorkoolwaterstoffen perfluorkoolstoffen               8          18*33*9*9*9=433026
#   8644.153                     slippers pokken kluiten modder stenen              13       13*14*13*14*31=1026844
#   9619.391                         Pels Rijcken Droogleever Fortuijn              12          13*12*12*12=22464
#   9633.768               beschuit koek koekjes ragoutwerk kerstbrood               9       12*10*23*16*10=441600
#  15006.250                    gemarmerde stinkwants Halymorpha halys              10          10*10*10*10=10000
#  16648.946           zeesterren slikmosselen slippers pokken kluiten              12       16*12*13*14*13=454272
#  19027.367               slikmosselen slippers pokken kluiten modder              12       12*13*14*13*14=397488
#  26260.938              bruin gemarmerde stinkwants Halymorpha halys              10       20*10*10*10*10=200000

# %% [markdown]
# # Filtering with more detailed knowledge?
#
# We could try to use linguistic parsing to filter what even goes into n-grams.
#
# For example, we could consider the part of speech of each word.
# The parsing is going to be slower, but let's see if that's potentially worth it.
#
# Since the collocation class only really cares about the count, not the text it is reporting on,
# we can just say "word/POS" is the word and it'll do it.

# %%
# A fancier tokenizer-and-tagger (e.g. spacy's) is now necessary.
#   Note that this is slower than the simpler splitting we did above.
import spacy

nlp = spacy.load("nl_core_news_lg") # _md or even _sm might be preferable for faster testing
nlp.disable_pipes('ner', 'lemmatizer', 'attribute_ruler') # disabling spacy components we won't use this time might speed it up a little

def nl_tokenize(nl_sent, with_pos=True):
     doc = nlp( nl_sent.rstrip() ) # this is the slow bit: actually parsing
     if with_pos:
          return list(tok.text+'/'+tok.pos_  for tok in doc)
     else:
          return list(tok.text               for tok in doc)

# %%
# different example data: kamervragen
kv   = wetsuite.datasets.load('tweedekamer-kamervragen-struc')

coll = wetsuite.helpers.collocation.Collocation( ) 
# note that we are not using connectors anymore, we will be imitating that, hopefully more precisely

for kv_id, kv_details in wetsuite.helpers.notebook.ProgressBar( kv.data.random_sample(8000) ):
    vraagdata = kv_details['vraagdata']

    # the added strucure in this dataset means we need a few lines to pick out just the text
    for number in vraagdata:
        try:
            vraag   , _ = vraagdata[number]['vraag']
            antwoord, _ = vraagdata[number]['antwoord']
        except KeyError: # TODO: fix
            continue

        for text in vraag, antwoord:
            for paragraph in re.split(r'[\s]{2,}', text):
                for sentence in wetsuite.helpers.spacy.sentence_split( paragraph, as_plain_sents=True ):
                    coll.consume_tokens(  nl_tokenize( sentence, with_pos=True ), gramlens=(2,3,4,5)  )
# Out:
#   0%|          | 0/8000 [00:00<?, ?it/s]

# %% [markdown]
# If you, say, would wish for only specific things, e.g. in the shape of
# ADJECTIVE ADJECTIVE NOUN or DET PRON or ADVERB VERB, you are going to remove a lot of interesting things,
# and will never know, especiallly since there are _many_ possible sequence of POS tags that are reasonable for very simple phrases, e.g.
#
#         opsporing/NOUN en/CCONJ vervolging/NOUN
#         Inspectie/NOUN Gezondheidszorg/PROPN en/CCONJ Jeugd/NOUN
#         het/DET Landelijk/ADJ Register/NOUN
#         de/DET Tweede/PROPN Kamer/PROPN
# and maybe you even care about:
#
#         Hebt/AUX u/PRON kennisgenomen/VERB
#
#
# But, say, we are more interested in things that start with DET (e.g. "the" as part of a name)
# than that end with DET (when we care about phrases, we can declare that as incomplete).
#
# Similarly, we probably don't care about things that _end_ in ADP or PRON.
#
# Or anything containing a PUNCT

# %%
def is_bad_ngram(ngram, count):
    ''' this is a "say whether to disqualify this n-gram" function as mentioned by cleanup_ngrams_func() 
        This acts a little like the connectors logic before, but a little more controlled, 
        and informed of the sentence it comes from.
    '''
    flat = ' '.join(ngram)
    if ngram[-1].endswith('/ADP'):
        return True
    if ngram[-1].endswith('/ADV'):
        return True
    if ngram[-1].endswith('/DET'):
        return True
    if ngram[-1].endswith('/AUX'): # but not VERB
        return True
    if ngram[-1].endswith('/CCONJ'):
        return True
    if ngram[-1].endswith('/SCONJ'):
        return True
    if ngram[-1].endswith('/PRON'):
        return True
    if '/PUNCT' in flat:
    #if ngram[-1].endswith('/PUNCT'):
        return True
    return False

print( 'Before cleanup:', coll.counts() )
coll.cleanup_ngrams( mincount=8, bad_func=is_bad_ngram )  # filter BOTH by a count and by n-gram contents
print( 'After cleanup:', coll.counts() )
# Out:
# Before cleanup: {'from_tokens': 7734528, 'unigrams': 162332, 'ngrams': 15557863}
# After cleanup: {'from_tokens': 7734528, 'unigrams': 162332, 'ngrams': 90939}

# %%
top = 2000
print( "Scoring, showing top %d\n"%top)
scores = coll.score_ngrams( )
print( ' %9s   %55s    %12s %20s'%('score', 'n-gram', 'n-gram count', 'individual counts') )
for strtup, score,  tup_count, uni_counts in scores[-top:]:
    print( ' %9.3f   %55s    %12s %20s=%d'%(score, ' '.join(strtup),   tup_count, '*'.join(str(n) for n in uni_counts), wetsuite.helpers.collocation.product(uni_counts)) )
    # or, to remove the POS in this summary:
    #print( ' %9.3f   %55s    %12s %20s=%d'%(score, ' '.join(s.split('/',1)[0] for s in strtup),   tup_count, '*'.join(str(n) for n in uni_counts), wetsuite.helpers.collocation.product(uni_counts)) )
# Out:
# Scoring, showing top 2000
#
#      score                                                    n-gram    n-gram count    individual counts
#     22.108                                   meter/NOUN afstand/NOUN              69              384*687=263808
#     22.111                                      wil/VERB zeggen/VERB             185             2682*707=1896174
#     22.139                               Financieel/ADJ Dagblad/NOUN               9                83*54=4482
#     22.148                        Uitvoeringsbesluit/NOUN Wwft/PROPN               9               40*112=4480
#     22.156                          Coördinator/NOUN Groningen/PROPN              21               37*659=24383
#     22.194                           geestelijke/ADJ verzorgers/NOUN              13               176*53=9328
#     22.195                            vergaderjaar/ADV 2012–2013/NUM              27               479*84=40236
#     22.228                         democratische/ADJ rechtstaat/NOUN              20               334*66=22044
#     22.257                          feitelijke/ADJ onjuistheden/NOUN              15               387*32=12384
#     22.257               Meerjarenprogramma/NOUN Infrastructuur/NOUN              15               32*387=12384
#     22.282                               Zoals/SCONJ aangegeven/VERB             749            5273*5849=30841777
#     22.298                                    Rijnstraat/PROPN 8/NUM              27              30*1335=40050
#     22.300                             criminele/ADJ jeugdgroep/NOUN              11               391*17=6647
#     22.325                    Medisch/ADJ Spectrum/NOUN Twente/PROPN              10            79*11*221=192049
#     22.336                        Landelijk/ADJ afvalbeheerplan/NOUN               8               351*10=3510
#     22.353                                        ten/ADP laste/NOUN             122             6686*122=815692
#     22.363                             seksuele/ADJ intimidatie/NOUN              41              447*206=92082
#     22.365                                   met/ADP betrekking/NOUN            1799           63537*2790=177268230
#     22.372                                        12.00/NUM uur/NOUN              15               16*770=12320
#     22.379                                 Juridische/ADJ Zaken/NOUN              10               23*238=5474
#     22.400                       stapsgewijze/ADJ huurverhoging/NOUN               8               25*140=3500
#     22.430                                      Ik/PRON verwijs/VERB             645           12477*1821=22720617
#     22.436                                      Committee/SYM on/SYM              15               27*455=12285
#     22.450                           meldplicht/NOUN datalekken/NOUN              16               229*61=13969
#     22.505                             seksuele/ADJ diversiteit/NOUN              47              447*269=120243
#     22.510                                  seksueel/ADJ geweld/NOUN             113             453*1534=694902
#     22.529                   Dutch/PROPN Relief/PROPN Alliance/PROPN               8             70*29*60=121800
#     22.535                          seksueel/ADJ overschrijdend/VERB              10               453*12=5436
#     22.535                                        LHBT/PROPN ’s/VERB              16               49*284=13916
#     22.575                                daarop/ADV gebaseerde/VERB              33               882*67=59094
#     22.575                              Constitutioneel/ADJ Hof/NOUN              11               14*469=6566
#     22.586                                        ons/PRON land/NOUN             216            1087*2328=2530536
#     22.600                         verantwoording/NOUN afleggen/VERB              26               394*93=36642
#     22.606                  geïntegreerde/VERB gewasbescherming/NOUN              11                79*83=6557
#     22.685                              benoembare/ADJ docenten/NOUN              10               18*300=5400
#     22.693                                   contact/NOUN gehad/VERB             176             2206*758=1672148
#     22.706                                 erkende/VERB kranten/NOUN              11               128*51=6528
#     22.728                   uitgeprocedeerde/VERB asielzoekers/NOUN              37               83*889=73787
#     22.731                         provincie/NOUN Zuid-Holland/PROPN              50             1271*106=134726
#     22.738                    gelijke/ADJ behandelingswetgeving/NOUN               8                431*8=3448
#     22.765                           Huize/PROPN de/PROPN Berg/PROPN               9            15*339*30=152550
#     22.780                        Wageningen/PROPN Universiteit/NOUN              14               155*68=10540
#     22.781                               werkzame/PROPN stoffen/NOUN              23               33*862=28446
#     22.798                gemeentelijke/ADJ schuldhulpverlening/NOUN              47              542*219=118698
#     22.798                    bescherming/NOUN persoonsgegevens/NOUN             170             1645*944=1552880
#     22.802                        Business/SYM and/PROPN Human/PROPN              38           40*419*162=2715120
#     22.820             Waarborgfonds/ADJ Sociale/ADJ Woningbouw/NOUN              13            30*252*42=317520
#     22.820                           Uitvoering/PROPN Onderwijs/NOUN              15               18*671=12078
#     22.844                                 Stichting/NOUN NICE/PROPN              24               792*39=30888
#     22.872                    Centraal/PROPN Bureau/PROPN voor/PROPN              67           275*360*85=8415000
#     22.921                    Internationaal/ADJ Maatschappelijk/ADJ              12               104*74=7696
#     22.945                                  speciaal/ADJ gezant/NOUN              11               323*20=6460
#     22.961       Toekomstbestendige/ADJ Arbeidsmarkt/PROPN Zorg/NOUN              10            18*39*266=186732
#     22.969                                    kubieke/ADJ meter/NOUN              12               20*384=7680
#     22.983                   chemische/ADJ bestrijdingsmiddelen/NOUN              10               130*41=5330
#     22.989                                   indruk/NOUN gewekt/VERB              19               229*84=19236
#     22.998                        thuiszorgorganisatie/NOUN De/PROPN              19               41*469=19229
#     23.081                                      BNG/PROPN Bank/PROPN              11               26*247=6422
#     23.121                   World/PROPN Health/PROPN Assembly/PROPN              10            122*95*16=185440
#     23.144                                        Van/PROPN L./PROPN              28              1092*38=41496
#     23.148                  subsidieregeling/NOUN praktijkleren/VERB              10               252*21=5292
#     23.156                                        na/ADP afloop/NOUN             143             5303*204=1081812
#     23.190                                          1/NUM juli/PROPN             432            5148*1915=9858420
#     23.235                                      ten/ADP gevolge/NOUN             137             6686*148=989528
#     23.241              UN/PROPN Guiding/PROPN Principles/SYM on/SYM              32         81*46*39*455=66117870
#     23.261                                        Centre/SYM for/SYM              13               25*356=8900
#     23.271                                        der/PROPN V./PROPN              10               376*14=5264
#     23.313                              elektrische/ADJ fietsen/NOUN              11               289*22=6358
#     23.388                             nationale/ADJ veiligheid/NOUN             292            1691*2641=4465931
#     23.390                                       hele/ADJ linie/NOUN              15               491*24=11784
#     23.398                              onconventioneel/ADJ gas/NOUN              15               19*620=11780
#     23.398               inkomensafhankelijke/ADJ huurverhoging/NOUN              19              135*140=18900
#     23.402                           sensitieve/ADJ technologie/NOUN               9               16*265=4240
#     23.476                            president/NOUN Bolsonaro/PROPN              11               287*22=6314
#     23.491                   Individuele/PROPN Gezondheidszorg/PROPN               9               11*384=4224
#     23.491                   Geestelijke/PROPN Gezondheidszorg/PROPN               9               11*384=4224
#     23.507                                       De/PROPN Pier/PROPN              12               469*16=7504
#     23.526                                  Stichting/NOUN OPEN/VERB              17               792*19=15048
#     23.558                             geactualiseerde/VERB MER/NOUN              10                65*80=5200
#     23.609                                         R./PROPN de/PROPN              14               30*339=10170
#     23.731                                        RED/PROPN II/PROPN              11               18*347=6246
#     23.750                      auteursrechtelijk/ADJ beschermd/VERB              13               23*379=8717
#     23.769                                           ’/PROPN ers/ADJ              13               130*67=8710
#     23.773                                     wat/PRON betreft/VERB             684            7244*3328=24108032
#     23.807                          maximale/ADJ huurprijsgrens/NOUN              11               566*11=6226
#     23.884                                          juni/PROPN jl./X             365            2044*3343=6833092
#     23.918                               algemeen/ADJ verbindend/ADJ              36              1794*37=66378
#     23.950                                       ter/ADP plekke/NOUN              61              3120*61=190320
#     23.961                                         april/PROPN jl./X             360            1982*3343=6625826
#     23.973                                  hoger/ADJ onderwijs/NOUN             321            1671*3151=5265321
#     23.980                         verpakkend/ADJ bedrijfsleven/NOUN              12               12*613=7356
#     23.993          Actieprogramma/NOUN Integrale/PROPN Aanpak/PROPN              13            73*21*197=302001
#     24.025                    Regeling/NOUN fosfaatreductieplan/NOUN               9               413*10=4130
#     24.070                                     Willem/PROPN II/PROPN              15               33*347=11451
#     24.165                            heffingvrije/ADJ vermogen/NOUN              13               13*659=8567
#     24.171                             onbekende/ADJ bestemming/NOUN              15               63*181=11403
#     24.199                                 Europees/ADJ verband/NOUN             251            1434*2224=3189216
#     24.200        Jaarrapportage/NOUN Bedrijfsvoering/NOUN Rijk/NOUN              13            19*17*927=299421
#     24.226                          sanitaire/ADJ voorzieningen/NOUN              14               17*583=9911
#     24.231                                          Forum/SYM on/SYM               9                9*455=4095
#     24.251                                    On/SYM the/SYM way/SYM               8            17*512*13=113152
#     24.257                              Rights/PROPN Coalition/PROPN               8               202*16=3232
#     24.265                                    Wet/PROPN Dieren/PROPN              13               237*36=8532
#     24.272                                 Animal/PROPN Health/PROPN               8                34*95=3230
#     24.306                            parlementaire/ADJ enquête/NOUN              20              140*144=20160
#     24.311                                     De/PROPN Ruyter/PROPN              11               469*13=6097
#     24.327                                  nominale/ADJ premie/NOUN              17               63*231=14553
#     24.363                             vooruitgang/NOUN geboekt/VERB              14               73*135=9855
#     24.364                                    and/PROPN Profit/PROPN              10               419*12=5028
#     24.371                            volstrekt/ADJ onacceptabel/ADJ              25              102*308=31416
#     24.374                        provincie/NOUN Noord-Holland/PROPN              62             1271*152=193192
#     24.407                  bezoldiging/NOUN topfunctionarissen/NOUN              18               173*94=16262
#     24.430                       zelfstandig/ADJ bestuursorgaan/NOUN              33              479*114=54606
#     24.548                           deugdelijke/ADJ motivering/NOUN               9                47*86=4042
#     24.561                         Nationaal/PROPN Contactpunt/PROPN              12               513*14=7182
#     24.572                           criminele/ADJ jeugdgroepen/NOUN              20               391*51=19941
#     24.607                                     wilde/ADJ dieren/NOUN              58             114*1469=167466
#     24.655                                 humanitaire/ADJ hulp/NOUN             110             446*1348=601208
#     24.668                                            way/SYM to/SYM              10               13*382=4966
#     24.718                             Economisch/ADJ Onderzoek/NOUN              10               21*236=4956
#     24.768                                  langere/ADJ termijn/NOUN             195             581*3237=1880697
#     24.770                                       Van/PROPN den/PROPN              55             1092*137=149604
#     24.889                             schooljaar/NOUN 2012/2013/SYM               8               150*21=3150
#     24.897                                      sprake/NOUN was/VERB             319             6494*771=5006874
#     24.945                                         u/PRON bekend/ADJ            3297           64548*8270=533811960
#     25.032                                 Gemengd/PROPN Comité/NOUN               8               18*174=3132
#     25.039                             Peter/PROPN R./PROPN de/PROPN              14            33*30*339=335610
#     25.061                                       der/PROPN Ham/PROPN              10               376*13=4888
#     25.064                        Islamitische/ADJ Universiteit/NOUN               8                46*68=3128
#     25.068                                Digitale/ADJ Overheid/NOUN              11                81*73=5913
#     25.073       maatschappelijk/ADJ verantwoordelijkheidsbesef/NOUN              14               684*14=9576
#     25.075                                      De/PROPN Vries/PROPN              24               469*60=28140
#     25.082                               herziene/ADJ Woningwet/NOUN              15               99*111=10989
#     25.084                               Economische/ADJ Zaken/PROPN             113             334*1867=623578
#     25.101                                    service/NOUN level/SYM               9                59*67=3953
#     25.214                            overgrote/ADJ meerderheid/NOUN              29              180*227=40860
#     25.225                              betrokken/VERB partijen/NOUN             560            4200*3626=15229200
#     25.225        sociaaleconomische/ADJ gezondheidsverschillen/NOUN               8               111*28=3108
#     25.266                                          Ik/PRON heb/VERB             633           12477*1557=19426689
#     25.269                               daaraan/ADV gekoppelde/VERB              19               473*37=17501
#     25.284                                     wilde/ADJ vogels/NOUN              20              114*170=19380
#     25.301                                   TU/NOUN Eindhoven/PROPN              18               83*189=15687
#     25.320                                uitheemse/ADJ soorten/NOUN              23               57*449=25593
#     25.328                           Palestijnse/ADJ Autoriteit/NOUN              73              362*712=257744
#     25.346                                      breed/ADJ palet/NOUN              22               544*43=23392
#     25.386                                 toenemende/VERB mate/NOUN             126             470*1630=766100
#     25.389                          substantieel/ADJ bezwarende/VERB               8               193*16=3088
#     25.403                            nucleaire/ADJ ontwapening/NOUN               9               186*21=3906
#     25.403                        Adviesraad/NOUN Internationale/ADJ               9               21*186=3906
#     25.442                                    Dat/PRON betekent/VERB             380            3385*2054=6952790
#     25.444                   SEO/PROPN Economisch/ADJ Onderzoek/NOUN              10            34*21*236=168504
#     25.467                                         te/ADP maken/VERB            4234           95123*9065=862289995
#     25.505                             Nationale/ADJ woonagenda/NOUN              14               523*18=9414
#     25.559                            Openbaar/PROPN Ministerie/NOUN             113             190*3221=611990
#     25.601                                Medisch/PROPN Centrum/NOUN              27              107*326=34882
#     25.621                         verwijtbare/ADJ werkloosheid/NOUN               8               18*170=3060
#     25.646                    Vereniging/NOUN Eigen/PROPN Huis/PROPN              35            675*37*82=2047950
#     25.654                                    to/SYM PlanetProof/SYM               8                382*8=3056
#     25.663                           Nederlands/ADJ grondgebied/NOUN              48              611*180=109980
#     25.711                             variabele/ADJ beloningen/NOUN              15               134*80=10720
#     25.722                                     Hoe/ADV oordeelt/VERB             211             6774*313=2120262
#     25.734                       persoonsgebonden/ADJ budgetten/NOUN              11               45*128=5760
#     25.774                         1F/SYM Vluchtelingenverdrag/PROPN              11                81*71=5751
#     25.804                               negatieve/ADJ effecten/NOUN             168             860*1558=1339880
#     25.840                          verantwoord/VERB ondernemen/VERB              92              506*793=401258
#     25.934                                           (/NOUN semi/SYM              12               358*19=6802
#     25.945                              Nationale/ADJ Hypotheek/NOUN              12               523*13=6799
#     25.952                                 houtige/ADJ biomassa/NOUN               8               19*159=3021
#     25.983                                    vrije/ADJ uitloop/NOUN              19               460*37=17020
#     26.045                                  nabije/ADJ toekomst/NOUN              52              82*1551=127182
#     26.062                   interdepartementale/ADJ afstemming/NOUN              22               50*455=22750
#     26.095                                    Hoe/ADV verklaart/VERB             232             6774*373=2526702
#     26.106               Autoriteit/NOUN Financiële/ADJ Markten/NOUN              82           712*165*94=11043120
#     26.112                                             (/SYM re/NOUN               9                95*40=3800
#     26.114                               slecht/ADJ geïsoleerde/VERB              11               258*22=5676
#     26.117                            Laurentius/ADJ ziekenhuis/NOUN              21               21*985=20685
#     26.150                     collectieve/ADJ waardeoverdracht/NOUN              15               310*34=10540
#     26.189                                         maart/PROPN jl./X             385            2074*3343=6933382
#     26.235                              hypothecaire/ADJ lening/NOUN              14               44*208=9152
#     26.259                   Overleg/NOUN Acute/NOUN Zorgketen/PROPN               8             311*42*8=104496
#     26.259                                     last/NOUN resort/NOUN              10               311*15=4665
#     26.356                           Register/NOUN Kinderopvang/NOUN              11                76*74=5624
#     26.359                            kostendekkende/ADJ premie/NOUN              13               34*231=7854
#     26.393                              COVID-19/PROPN respons/PROPN              11               432*13=5616
#     26.415                                     the/PROPN world/PROPN               8               212*14=2968
#     26.517                                Nationale/ADJ Politie/NOUN              56              523*277=144871
#     26.539                               startende/VERB leraren/NOUN              35               96*589=56544
#     26.578                               Dienst/NOUN Regelingen/NOUN              11               143*39=5577
#     26.578                                     Erosion/SYM and/PROPN              10               11*419=4609
#     26.607                           geestelijke/ADJ verzorging/NOUN              29              176*220=38720
#     26.695            particuliere/ADJ beveiligingsorganisaties/NOUN               9                413*9=3717
#     26.783                                     welke/DET manier/NOUN             730           10241*2380=24373580
#     26.842                                aandacht/NOUN besteed/VERB             193             2936*579=1699944
#     26.858                                        vijf/NUM jaar/NOUN             422             988*8221=8122348
#     26.864                            Algemene/ADJ Ouderdomswet/NOUN              10               456*10=4560
#     26.883               elektronische/ADJ gegevensuitwisseling/NOUN              19               175*94=16450
#     26.959                                          B/PROPN en/PROPN              20              128*142=18176
#     26.969                                   Waarop/ADV baseert/VERB              16               51*228=11628
#     27.056                                  forensisch/ADJ arts/NOUN              37              149*416=61984
#     27.093                                    lokaal/ADJ niveau/NOUN             148             564*1756=990384
#     27.096                               hoogste/ADJ prioriteit/NOUN              57              301*488=146888
#     27.107                               mentale/ADJ gezondheid/NOUN              47              118*846=99828
#     27.174                                           7e/ADJ AP/PROPN              10               14*322=4508
#     27.203                            wettelijk/ADJ minimumloon/NOUN              74             1019*242=246598
#     27.222                             Bureau/PROPN Financieel/PROPN               8                360*8=2880
#     27.289                Verbond/PROPN van/PROPN Verzekeraars/PROPN              84           87*1448*88=11085888
#     27.340                            ministeriële/ADJ regeling/NOUN              82             160*1883=301280
#     27.384                             Waarborgfonds/ADJ Sociale/ADJ              13               30*252=7560
#     27.393                                   SEFE/PROPN Energy/PROPN               8               27*106=2862
#     27.410                            Palestijnse/ADJ Gebieden/PROPN               9               362*10=3620
#     27.425                                     Den/PROPN Oever/PROPN              15               670*15=10050
#     27.430                                  teveel/ADV betaalde/VERB              23              125*189=23625
#     27.471                              onveilige/ADJ situaties/NOUN              73             209*1137=237633
#     27.528                                 Openbaar/ADJ Lichaam/NOUN              20               890*20=17800
#     27.574                           vergaderjaar/NOUN 2012–2013/NUM              15               119*84=9996
#     27.592                           provincie/NOUN Gelderland/PROPN              79             1271*218=277078
#     27.597                                       Von/PROPN der/PROPN              12               17*376=6392
#     27.608                                  rurale/ADJ gebieden/NOUN              22               26*826=21476
#     27.623                       Israëlische/ADJ nederzettingen/NOUN              23               340*69=23460
#     27.623                                   Sociale/ADJ Zaken/PROPN             103             252*1867=470484
#     27.628                 and/PROPN Drug/PROPN Administration/PROPN               9            419*15*20=125700
#     27.761                                    ten/ADP grondslag/NOUN             338             6686*754=5041244
#     27.841                                 Institute/PROPN for/PROPN              13               52*143=7436
#     27.931                                          vraag/NOUN 4/NUM             730            9874*2367=23371758
#     27.969                              gemaakte/VERB afspraken/NOUN             189             419*3734=1564546
#     28.037                                      rol/NOUN spelen/VERB             303            3458*1160=4011280
#     28.073                          vliegbasis/NOUN Leeuwarden/PROPN              11                55*96=5280
#     28.115                      Fokker/PROPN Services/PROPN BV/PROPN               8             25*61*64=97600
#     28.125                                      and/SYM balances/SYM               9                392*9=3528
#     28.137                                 ambtelijk/ADJ niveau/NOUN              88             192*1756=337152
#     28.156                               provinciale/ADJ staten/NOUN              39              269*246=66174
#     28.191                                 Dienst/ADJ Justitiële/ADJ               8               27*103=2781
#     28.219   Actieplan/NOUN Arbeidsmarktdiscriminatie/NOUN 2018–2021/NUM               8            221*20*22=97240
#     28.314                                  station/NOUN Emmen/PROPN              18               163*86=14018
#     28.334                                     zijner/PRON tijd/NOUN              64              64*2767=177088
#     28.356                         Bureau/PROPN Fondsenwerving/PROPN              10               360*12=4320
#     28.402                               omringende/VERB landen/NOUN              95             119*3271=389249
#     28.438                                         ZZP/PROPN ’/PROPN              13               56*130=7280
#     28.488                                   gelijke/ADJ kansen/NOUN              69              431*475=204725
#     28.541                           medisch/ADJ specialistische/ADJ              62              647*255=164985
#     28.541                                  vierde/ADJ kwartaal/NOUN              51              269*415=111635
#     28.542                                aangenomen/VERB motie/NOUN             162             743*1516=1126388
#     28.555                              Panel/SYM on/SYM Climate/SYM              10            11*455*30=150150
#     28.573                                bezette/VERB gebieden/NOUN              34               60*826=49560
#     28.632                                  belangrijke/ADJ rol/NOUN             387            1853*3458=6407674
#     28.643                            voorlopig/ADJ energielabel/ADJ              11               207*25=5175
#     28.718                                          Group/SYM on/SYM              16               24*455=10920
#     28.775                                        dit/DET soort/NOUN             672            19478*987=19224786
#     28.788                      wetenschappelijke/ADJ inzichten/NOUN              76              616*399=245784
#     28.870                               Haga/PROPN Ziekenhuis/PROPN              19               69*222=15318
#     28.909                                      Aukje/PROPN de/PROPN               8                8*339=2712
#     28.922                               externe/ADJ deskundigen/ADJ              78              730*353=257690
#     28.950                                mevrouw/NOUN Keijzer/PROPN              11               256*20=5120
#     29.078                               Noordoost/PROPN Syrië/PROPN              14               23*359=8257
#     29.107                     commercieel/ADJ draagmoederschap/NOUN              14               113*73=8249
#     29.109                            gereguleerde/VERB segment/NOUN              11                76*67=5092
#     29.127                    A27/A12/PROPN Ring/PROPN Utrecht/PROPN              15            15*40*552=331200
#     29.218                                       130/NUM km/uur/NOUN              11                89*57=5073
#     29.239         internationaalrechtelijke/ADJ verplichtingen/NOUN              29               45*783=35235
#     29.252                                   &/PROPN Onderwijs/PROPN              14               342*24=8208
#     29.316                               bevroren/VERB tegoeden/NOUN              14               78*105=8190
#     29.322                                      der/PROPN Laan/PROPN              12               376*16=6016
#     29.322                                      der/PROPN Valk/PROPN               9                376*9=3384
#     29.385                  verstandelijk/ADJ gehandicaptenzorg/NOUN               8                58*46=2668
#     29.388                                Stichting/NOUN Mozon/PROPN              19               792*19=15048
#     29.396                             bilaterale/ADJ contacten/NOUN              69              320*620=198400
#     29.496                          International/PROPN Labour/PROPN              16               443*24=10632
#     29.517                                        ene/PRON kant/NOUN              35              205*248=50840
#     29.518                              preferente/ADJ aandelen/NOUN              12               24*249=5976
#     29.538                                      wel/ADV degelijk/ADJ             177             7139*182=1299298
#     29.584                                klinisch/ADJ genetisch/ADJ               9                78*43=3354
#     29.594                             verscherpt/VERB toezicht/NOUN             104             139*3221=447719
#     29.615                                          Panel/SYM on/SYM              11               11*455=5005
#     29.697                              budgettaire/ADJ derving/NOUN              12               165*36=5940
#     29.699                                  ons/PRON omringende/VERB              56             1087*119=129353
#     29.747                                       LHBTI/PROPN ’s/VERB              20               58*284=16472
#     29.844                               wet/NOUN bestuursrecht/NOUN              82             2281*121=276001
#     29.851                             Afwikkeling/NOUN Politie/NOUN               9               12*277=3324
#     29.959                                  digitaal/ADJ vaardig/ADJ               9               207*16=3312
#     29.962                               Wet/NOUN milieubeheer/PROPN              70              2862*70=200340
#     30.031                                 Naar/ADP verwachting/NOUN             188            1064*1355=1441720
#     30.035                               Aanpak/PROPN Stikstof/PROPN              16               197*53=10441
#     30.108              Eenduidige/ADJ Landelijke/ADJ Afspraken/NOUN              16            21*280*62=364560
#     30.108                        Internationale/ADJ Maritieme/PROPN               8               186*14=2604
#     30.149                                    volle/ADJ breedte/NOUN              19               193*76=14668
#     30.154                                    robuuste/ADJ EHS/PROPN               8                65*40=2600
#     30.327                                 Van/PROPN Laarhoven/PROPN              28              1092*29=31668
#     30.435                                Spijkenisse/PROPN MC/PROPN               8                28*92=2576
#     30.521                                       Uw/PRON kamer/PROPN              13               399*17=6783
#     30.562                             veilige/ADJ werkomgeving/NOUN              39               685*89=60965
#     30.625                              koninklijke/ADJ familie/NOUN              15               30*300=9000
#     30.672                               stichting/NOUN Ouders/PROPN              14               412*19=7828
#     30.687                                      u/PRON aangeven/VERB            2354           64548*3427=221205996
#     30.688                          vreedzame/ADJ demonstranten/NOUN              11               46*105=4830
#     30.728                     gekwalificeerde/VERB meerderheid/NOUN              22               85*227=19295
#     30.787                               voorlopige/ADJ aanslag/NOUN              57              513*252=129276
#     30.797                                      MBO/PROPN Raad/PROPN              46              56*1503=84168
#     30.823                        economische/ADJ machtspositie/NOUN              43              1065*69=73485
#     30.856                        Algemene/PROPN Onderwijsbond/PROPN              10               397*10=3970
#     30.945                                openbare/ADJ lichamen/NOUN              46               974*86=83764
#     30.969                                Waren/NOUN Autoriteit/NOUN              18               18*712=12816
#     31.046                                    Van/PROPN Gerven/PROPN              32              1092*37=40404
#     31.139                              ernstige/ADJ benadeling/NOUN              36               927*55=50985
#     31.151                                   heer/NOUN Wilders/PROPN              50              1130*87=98310
#     31.157                                           24/NUM uur/NOUN             122              760*770=585200
#     31.222                                   dierlijke/ADJ mest/NOUN              25              134*183=24522
#     31.227                                Programma/NOUN Aanpak/NOUN              12               269*21=5649
#     31.228                                 duurzame/ADJ energie/NOUN             130              988*671=662948
#     31.329                                           her/NOUN )/NOUN              16               35*286=10010
#     31.369                         Havenbedrijf/NOUN Rotterdam/PROPN              32               52*769=39988
#     31.380                      Internationale/ADJ Vraagstukken/NOUN               9               186*17=3162
#     31.404                              binnenlands/ADJ product/NOUN              22               40*472=18880
#     31.410                       justitiële/ADJ jeugdinrichting/NOUN               8               192*13=2496
#     31.413                                    Dit/PRON betekent/VERB             620            7298*2054=14990092
#     31.597                                dictionary/NOUN tabel/NOUN              13               18*364=6552
#     31.630                                     mindere/ADV mate/NOUN              44              46*1630=74980
#     31.660                        wederrechtelijk/ADJ verkregen/VERB              24               51*437=22287
#     31.938                kwaliteitskader/NOUN verpleeghuiszorg/NOUN              11               119*39=4641
#     31.957                                vrije/ADJ artsenkeuze/NOUN              12               460*12=5520
#     32.007                                   zoveel/ADV mogelijk/ADJ             286            302*10366=3130532
#     32.070                           vergaderjaar/NOUN 2009–2010/SYM               9               119*26=3094
#     32.205                 Emergency/PROPN Response/PROPN Fund/PROPN               9             39*35*79=107835
#     32.230                                          te/ADV vroeg/ADJ             102             1883*210=395430
#     32.293                          Volledigheidshalve/ADJ merk/VERB              11               17*270=4590
#     32.294                              rechtmatig/ADJ verblijf/NOUN              56              203*586=118958
#     32.322                      strafrechtelijke/ADJ vervolging/NOUN              95              523*654=342042
#     32.403                                    beschut/VERB werk/NOUN              67              76*2233=169708
#     32.407                                            not/SYM be/SYM              10                63*60=3780
#     32.429                             Algemene/ADJ Plaatselijke/ADJ              13               456*14=6384
#     32.543                                  enige/DET regelmaat/NOUN              42              527*126=66402
#     32.667                                 Working/PROPN Group/PROPN              10               25*150=3750
#     32.752         Centraal/PROPN Justitieel/ADJ Incassobureau/PROPN              11            275*36*16=158400
#     32.822                                     erop/ADV gericht/VERB             226             856*2227=1906312
#     32.837                              Financial/PROPN Action/PROPN              12                68*79=5372
#     32.845                              Natura/SYM 2000-gebieden/SYM               8                31*77=2387
#     32.917                               Nationaal/PROPN Cyber/PROPN              33               513*79=40527
#     32.921                                     den/PROPN brede/PROPN               9               137*22=3014
#     33.006                                         op/ADP vraag/NOUN            5111           98189*9874=969518186
#     33.049                                 stichting/NOUN Gave/PROPN              17               412*26=10712
#     33.080                            Materieel/ADJ Organisatie/NOUN               8               15*158=2370
#     33.258                                       breed/ADJ scala/SYM              24               544*39=21216
#     33.304                   station/NOUN Emmen/PROPN Bargeres/PROPN              14            163*86*18=252324
#     33.331                                  illegale/ADJ handel/NOUN              98              616*573=352968
#     33.433                                       De/PROPN Bilt/PROPN              16               469*20=9380
#     33.456                                    Van/PROPN Nispen/PROPN              39              1092*51=55692
#     33.463                                       laat/VERB zien/VERB             291            1238*2504=3099952
#     33.526                            voorkomende/VERB gevallen/NOUN             145             234*3283=768222
#     33.545                            omgekeerde/ADJ bewijslast/NOUN               9                34*87=2958
#     33.613                             provinciale/PROPN staten/NOUN               9               12*246=2952
#     33.617                                   terecht/ADJ kunnen/VERB             112              874*523=457102
#     33.635                              bijzondere/ADJ bijstand/NOUN             124              800*700=560000
#     33.736        Koninklijk/ADJ Nederlands/PROPN Meteorologisch/ADJ               9             38*301*9=102942
#     33.749                                moderne/ADJ slavernij/NOUN               8               101*23=2323
#     33.841                                      plastic/ADJ tas/NOUN              11               219*20=4380
#     33.849                         Handelsregisterwet/PROPN 2007/NUM              10               11*329=3619
#     33.927                  Afdeling/NOUN Vreemdelingenpolitie/PROPN              11               257*17=4369
#     33.952            Korps/NOUN Landelijke/ADJ Politiediensten/NOUN              10            41*280*11=126280
#     33.990                              Vermilion/PROPN Energy/PROPN              10               34*106=3604
#     34.072                          hoofdelijk/ADJ aansprakelijk/ADJ               8               13*177=2301
#     34.101                                  naar/ADP aanleiding/NOUN            1702           23922*4350=104060700
#     34.123                                  verloonde/VERB uren/NOUN              10               10*359=3590
#     34.133                                    ervoor/ADV zorgen/VERB             387            1993*2697=5375121
#     34.180                               betrokken/ADJ partijen/NOUN             116             133*3626=482258
#     34.245                                  World/PROPN Health/PROPN              18               122*95=11590
#     34.282                                        en/DET aanbod/NOUN              30              30*1072=32160
#     34.288                          Algemene/PROPN Inlichtingen-/SYM              33               397*98=38906
#     34.300                                 Masterplan/NOUN DJI/PROPN              14               28*250=7000
#     34.402                                      Van/PROPN Haga/PROPN              46              1092*69=75348
#     34.412                                   the/SYM Netherlands/SYM              26               512*47=24064
#     34.485                                          vraag/NOUN 3/NUM             976            9874*3427=33838198
#     34.485                           gevoelige/ADJ bestemmingen/NOUN              17               174*59=10266
#     34.555                           provincie/NOUN Overijssel/PROPN              81             1271*183=232593
#     34.635                                   zwaarder/ADJ weegt/VERB              19              112*114=12768
#     34.668                                         op/ADP basis/NOUN            4145           98189*6183=607102587
#     34.675                                  Medisch/ADJ Centrum/NOUN              27               79*326=25754
#     34.710                              personele/ADJ bezetting/NOUN              26              151*158=23858
#     34.743                            huishoudelijke/ADJ hulpen/NOUN               9               119*24=2856
#     34.746                                Cyber/PROPN Strategie/NOUN              11                79*54=4266
#     34.746                         Tijdelijke/ADJ Noodmaatregel/NOUN              11               158*27=4266
#     34.758                                elektrisch/ADJ rijden/VERB              29               78*380=29640
#     34.790                       discretionaire/ADJ bevoegdheid/NOUN              21               24*647=15528
#     34.797                                  Kamerstukken/NOUN II/NUM              21               345*45=15525
#     34.837                             Afdeling/NOUN advisering/NOUN              33              257*149=38293
#     34.889                                   Action/PROPN Task/PROPN              12                79*64=5056
#     34.900                            Landelijk/ADJ Schakelpunt/NOUN              10               351*10=3510
#     34.933                         ernstig/ADJ verkeersgewonden/VERB              15               526*15=7890
#     34.938                            veiligheidsrisico/NOUN ’s/VERB              36              160*284=45440
#     34.958                            VN/PROPN Veiligheidsraad/PROPN              38               550*92=50600
#     34.959                                 Animal/PROPN Rights/PROPN              14               34*202=6868
#     35.092                                   overgrote/ADJ deel/NOUN             139             180*3747=674460
#     35.125                               ongelijk/ADJ speelveld/NOUN              12               27*186=5022
#     35.150                                  onbepaalde/ADJ tijd/NOUN              85              91*2767=251797
#     35.174                               onbegeleid/VERB verlof/NOUN               9               13*217=2821
#     35.244                               provinciaal/ADJ orgaan/NOUN              13                66*89=5874
#     35.270                           Gedeputeerde/PROPN Staten/PROPN              20               33*421=13893
#     35.272                        Nationale/ADJ Omgevingsvisie/PROPN              16               523*17=8891
#     35.327                                    zzp/ADJ ’/SYM ers/NOUN              97          189*228*265=11419380
#     35.340                           intensieve/ADJ veehouderij/NOUN              42              237*258=61146
#     35.377                                          in/SYM the/PROPN              30              147*212=31164
#     35.437                     Regionaal/ADJ Overleg/NOUN Acute/NOUN              23            49*311*42=640038
#     35.438                                perverse/ADJ prikkels/NOUN               9               28*100=2800
#     35.475                   marktordening/NOUN gezondheidszorg/NOUN              16               26*340=8840
#     35.478                                     uw/PRON antwoord/NOUN            1840           12361*9457=116897977
#     35.522                                  B/PROPN en/PROPN W/PROPN              16           128*142*17=308992
#     35.572                           kerncentrale/NOUN Borssele/NOUN               8               116*19=2204
#     35.677                            medisch/ADJ beroepsgeheim/NOUN              31               647*51=32997
#     35.719                   Koninklijke/ADJ Beroepsorganisatie/NOUN              13               161*36=5796
#     35.719                                verbaal/ADJ opgemaakt/VERB              13               46*126=5796
#     35.748   Nationaal/PROPN Coördinator/PROPN Terrorismebestrijding/PROPN              33            513*67*38=1306098
#     35.762                                      Wet/PROPN Werk/PROPN              16               237*37=8769
#     35.793                                        GGZ/NOUN NHN/PROPN              14               258*26=6708
#     35.819                                   Gezonde/ADJ School/NOUN              10                45*76=3420
#     35.838                                     der/PROPN Vlist/PROPN              11               376*11=4136
#     35.857                      verpleegkundig/ADJ specialisten/NOUN              14               31*216=6696
#     35.886                                 Response/PROPN Fund/PROPN               9                35*79=2765
#     35.891                                         Ik/PRON deel/VERB             518            12477*734=9158118
#     35.897                                             ´/VERB s/NOUN               8                8*273=2184
#     35.897                            Financieel/PROPN Toezicht/NOUN               8                8*273=2184
#     35.959                                  plastic/ADJ rietjes/NOUN              15               219*35=7665
#     35.982                          Maatschappelijk/ADJ Overleg/NOUN              26               74*311=23014
#     36.029                                      sub/NOUN quotum/NOUN               9                54*51=2754
#     36.088                                      der/PROPN Werf/PROPN              12               376*13=4888
#     36.143                                   rule/SYM of/SYM law/SYM               8            13*292*20=75920
#     36.145                                     hoger/ADJ beroep/NOUN             252            1671*1288=2152248
#     36.162                                    best/ADJ practices/NUM               8                271*8=2168
#     36.360                              seksuele/ADJ uitbuiting/NOUN              55              447*228=101916
# ...
#    714.583                               Innovation/PROPN Hubs/PROPN              14                24*14=336
#    720.538                       Ms./PROPN Karel/PROPN Doorman/PROPN              11             18*20*20=7200
#    723.561                                  Sint/PROPN Maarten/PROPN             237              385*247=95095
#    723.864                                   numerus/NOUN fixus/VERB              13                13*22=286
#    726.593                                   NHL/PROPN Stenden/PROPN              11                12*17=204
#    731.250                        Inspectie/PROPN Leefomgeving/PROPN              39                49*52=2548
#    735.000                          Kaderrichtlijn/PROPN Water/PROPN              36                54*40=2160
#    735.000                                  Goede/PROPN Doelen/PROPN               9                 15*9=135
#    735.000                          hydraulische/ADJ stimulatie/NOUN              12                16*15=240
#    735.000                                   Addis/PROPN Abeba/PROPN               9                 15*9=135
#    737.552                                  Hainan/PROPN Ocean/PROPN              17                20*24=480
#    737.552                                Ocean/PROPN Paradise/PROPN              17                24*20=480
#    742.424                                     Asia/PROPN Bibi/PROPN              10                15*11=165
#    758.333                                      Tel/PROPN Aviv/PROPN              13                21*13=273
#    761.216                                    Green/PROPN Deal/PROPN              67                84*86=7224
#    765.625                                    Arif/PROPN Yunus/PROPN              15                15*24=360
#    773.684                       Hoogfrequent/ADJ Spoorvervoer/PROPN              12                19*12=228
#    774.924                             Groene/ADJ Amsterdammer/PROPN              25                38*26=988
#    784.186                               etnisch/ADJ profileren/VERB              52                64*66=4224
#    787.056                                  Human/PROPN Rights/PROPN             145              162*202=32724
#    792.647                                    rotte/VERB appels/NOUN              11                11*17=187
#    792.647                            Regional/PROPN Warehouse/PROPN              11                17*11=187
#    793.800                                        Hr./PROPN Ms/PROPN              18                20*25=500
#    796.250                                   la/PROPN Tourette/PROPN              13                20*13=260
#    797.674           Dreigingsbeeld/NOUN Statelijke/ADJ Actoren/NOUN               8              43*10*8=3440
#    800.962                                     bebouwde/ADJ kom/NOUN              17                26*17=442
#    808.247                                   mijns/PRON inziens/NOUN              96               97*144=13968
#    816.667                            breedfront/NOUN vogeltrek/NOUN               8                 8*12=96
#    819.502                                       Zr./PROPN Ms./PROPN              17                24*18=432
#    823.472                         rooms-katholieke/PROPN kerk/PROPN              11                12*15=180
#    826.875                                   Legal/PROPN Guard/PROPN              18                24*20=480
#    826.875                                  Fair/PROPN Produce/PROPN              18                24*20=480
#    826.875                                      13b/NUM Opiumwet/ADJ               9                12*10=120
#    834.309                                     level/SYM playing/SYM              51                67*57=3819
#    835.227                              informed/PROPN consent/PROPN              15                22*15=330
#    835.227                       Coordinating/NOUN Secretariat/PROPN              15                15*22=330
#    838.158                                  Gouden/PROPN Koets/PROPN              13                19*13=247
#    838.170                                  Tweede/PROPN Kamer/PROPN            1153            1291*1505=1942955
#    838.859                                     Bergen/PROPN op/PROPN              21                28*23=644
#    842.188                                 East/PROPN StratCom/PROPN              22                32*22=704
#    842.604                                       quick/ADJ scan/NOUN              45                46*64=2944
#    842.917                         Normering/PROPN Topinkomens/PROPN              17                20*21=420
#    843.196                                  Juridisch/ADJ Loket/NOUN              56                67*68=4556
#    843.889                     Basisregistratie/PROPN Personen/PROPN              31                45*31=1395
#    848.077                                    Fast/PROPN Track/PROPN              12                16*13=208
#    849.576                          Justitiële/ADJ Inrichtingen/NOUN              77               103*83=8549
#    859.091                                      vice/SYM versa/PROPN              18                22*21=462
#    864.706                           bezettende/VERB mogendheid/NOUN              12                12*17=204
#    864.706                           Mikheil/PROPN Saakashvili/PROPN              12                12*17=204
#    871.111                                   Repair/PROPN Café/PROPN               8                 10*9=90
#    872.231                      Koninklijke/PROPN Marechaussee/PROPN              75               100*79=7900
#    875.000                                         nota/SYM bene/SYM              15                15*21=315
#    877.071                                     civil/SYM society/SYM              11                13*13=169
#    878.431                               eenzame/ADJ opsluiting/NOUN              16                17*21=357
#    884.722                                Misdaad/NOUN Anoniem/PROPN              13                18*13=234
#    884.722                               Woenselse/PROPN Poort/PROPN              13                13*18=234
#    885.938                      Saint/PROPN James/PROPN School/PROPN               9             14*14*20=3920
#    890.909                                     ongare/ADJ kooks/NOUN               8                 8*11=88
#    890.909                                   Card/PROPN Holder/PROPN               8                 11*8=88
#    891.069                                United/PROPN Nations/PROPN              39                51*41=2091
#    894.886                                    Task/PROPN Force/PROPN              60                64*77=4928
#    895.192                           Generation/PROPN Discover/PROPN              19                26*19=494
#    898.333                             draadloze/ADJ microfoons/NOUN              11                15*11=165
#    901.000                                      ABN/PROPN AMRO/PROPN             100              132*103=13596
#    918.750                                zonder/PROPN Grenzen/PROPN              15                15*20=300
#    918.750                             Kennemer/PROPN Gasthuis/PROPN               9                 9*12=108
#    918.750                  Lange/ADJ Termijn/NOUN Spooragenda/PROPN               9             27*14*10=3780
#    918.750                               Profit/PROPN Shifting/PROPN               9                 12*9=108
#    918.750                            Buitenring/NOUN Parkstad/PROPN               9                 9*12=108
#    918.750                                 Haskoning/PROPN DHV/PROPN               9                 12*9=108
#    918.750                         Restschade/PROPN Afwikkeling/NOUN               9                 9*12=108
#    919.753                                      Den/PROPN Haag/PROPN             508              670*513=343710
#    922.353                            Universal/PROPN Periodic/PROPN              16                20*17=340
#    923.753                           Verenigd/PROPN Koninkrijk/PROPN             431              436*565=246340
#    924.219                         offensief/ADJ cyberprogramma/NOUN              13                16*14=224
#    928.030                                   Nobian/PROPN Salt/PROPN              10                11*12=132
#    928.601   Noodmaatregel/NOUN Overbrugging/PROPN Werkgelegenheid/PROPN              13             27*17*17=7803
#    929.405                             Ruimtelijke/ADJ Ordening/NOUN              52                66*54=3564
#    934.797                              Guiding/PROPN Principles/SYM              37                46*39=1794
#    937.136                                      Ter/PROPN Apel/PROPN              87               97*102=9894
#    942.308                              transitional/SYM justice/SYM              10                10*13=130
#    950.160                                 Ahrar/PROPN al-Sham/PROPN              22                26*24=624
#    953.720                  Overbrugging/PROPN Werkgelegenheid/PROPN              15                17*17=289
#    962.500                          Fundamentele/ADJ Vrijheden/PROPN              11                14*11=154
#    965.866                          Aanhangsel/NOUN Handelingen/NOUN             443              509*489=248901
#    967.105                                   mystery/ADJ guests/NOUN              15                19*15=285
#    967.901                      Cylindrocladium/PROPN buxicola/PROPN               8                  9*9=81
#    969.231                              Hypotheek/NOUN Garantie/NOUN              12                13*14=182
#    980.000                               Statelijke/ADJ Actoren/NOUN               8                 10*8=80
#    980.000                              Amie/PROPN Ouderenzorg/PROPN               8                 8*10=80
#    980.000                             Titus/PROPN Brandsmahof/PROPN               8                 10*8=80
#    980.000                              Carint/PROPN Reggeland/PROPN               8                 10*8=80
#    982.620                         Aardolie/PROPN Maatschappij/PROPN              30                33*34=1122
#    983.392                                     due/SYM diligence/SYM              75                91*77=7007
#    985.976   Uitvoeringsinstituut/PROPN Werknemersverzekeringen/PROPN              33                33*41=1353
#    992.250                                carbon/PROPN leakage/PROPN               9                10*10=100
#   1002.273                                    modus/SYM operandi/SYM              18                22*18=396
#   1002.273                                     Round/PROPN Table/SYM               9                 11*9=99
#   1017.313                                       OD/PROPN NZKG/PROPN              51                58*54=3132
#   1036.538                            Leveste/PROPN Middenveld/PROPN              11                11*13=143
#   1037.298                     Royal/PROPN Haskoning/PROPN DHV/PROPN               9              31*12*9=3348
#   1038.587                            Arabische/PROPN Emiraten/PROPN              39                46*39=1794
#   1050.785             Zr./PROPN Ms./PROPN Karel/PROPN Doorman/PROPN              11          24*18*20*20=172800
#   1060.096                                            per/SYM se/SYM              45                45*52=2340
#   1061.667                  Multinationale/PROPN Ondernemingen/PROPN              26                26*30=780
#   1061.667                                         Sci/PROPN 547/NUM              13                13*15=195
#   1067.638                                       op/PROPN Zoom/PROPN              21                23*22=506
#   1071.875                   Artsen/PROPN zonder/PROPN Grenzen/PROPN              15             30*15*20=9000
#   1072.562                                    Tata/PROPN Steel/PROPN              79                88*81=7128
#   1088.889                                   Juiste/PROPN Plek/PROPN               8                  8*9=72
#   1088.889                             Endangered/PROPN Species/NOUN               8                  9*8=72
#   1088.889                                    Meld/VERB Misdaad/NOUN              16                16*18=288
#   1088.889                                Espírito/PROPN Santo/PROPN               8                  8*9=72
#   1096.053                                     Weener/PROPN XL/PROPN              17                17*19=323
#   1096.458                                    VDL/PROPN Nedcar/PROPN              52                57*53=3021
#   1098.276                                      goeder/ADV trouw/ADJ              26                26*29=754
#   1099.446                              genitale/ADJ verminking/NOUN              54                57*57=3249
#   1102.500                                 Goldman/PROPN Sachs/PROPN               9                 10*9=90
#   1102.500                                  vehicle/NOUN borne/PROPN               9                 9*10=90
#   1127.173                             z/SYM =/SYM p/SYM =/SYM r/SYM               8        9*47*10*47*15=2982150
#   1163.750                                     playing/SYM field/SYM              57                57*60=3420
#   1173.958                                 Ballast/PROPN Nedam/PROPN              23                24*23=552
#   1177.885                                 ultimum/ADJ remedium/NOUN              25                25*26=650
#   1197.159                                  Burkina/PROPN Faso/PROPN              43                43*44=1892
#   1225.000                                   Cerca/PROPN Trova/PROPN               9                  9*9=81
#   1225.000                                 Hamit/PROPN Karakus/PROPN              13                13*13=169
#   1225.000                                  Cabo/PROPN Delgado/PROPN              10                10*10=100
#   1225.000                                  EUFOR/PROPN Althea/PROPN              11                11*11=121
#   1225.000                                     Kara/PROPN Tepe/PROPN               8                  8*8=64
#   1225.000                                  Sierra/PROPN Leone/PROPN               8                  8*8=64
#   1225.000                                  Pels/PROPN Rijcken/PROPN              18                18*18=324
#   1225.000                                 Karel/PROPN Doorman/PROPN              20                20*20=400
#   1225.000                              physician/SYM assistants/SYM               9                  9*9=81
#   1225.000                                    Boko/PROPN Haram/PROPN              27                27*27=729
#   1225.000                                   Loro/PROPN Parque/PROPN              12                12*12=144
#   1225.000                                 Zuwe/PROPN Hofpoort/PROPN              10                10*10=100
#   1225.000                                filet/NOUN americain/PROPN              18                18*18=324
#   1225.000                                      Iza/PROPN Cura/PROPN              16                16*16=256
#   1286.250            Advies/PROPN Restschade/PROPN Afwikkeling/NOUN               9              25*9*12=2700
#   1290.716                   Hainan/PROPN Ocean/PROPN Paradise/PROPN              17             20*24*20=9600
#   1334.548                          Bergen/PROPN op/PROPN Zoom/PROPN              21             28*23*22=14168
#   1385.650                      Meld/VERB Misdaad/NOUN Anoniem/PROPN              11             16*18*13=3744
#   1562.247                          Soy/PROPN Fast/PROPN Track/PROPN              12             19*16*13=3952
#   1732.323                         Red/PROPN Card/PROPN Holder/PROPN               8              18*11*8=1584

# %% [markdown]
# This seems viable enough, at least for certain extraction tasks.
