# %% [markdown]
# <a href="https://colab.research.google.com/github/WetSuiteLeiden/example-notebooks/blob/main/datasets/dataset_intro_by_doing__bwb__(definitions_example).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (only) in colab, run this first to install wetsuite from (the most recent) source. 
#    (this should soon simplify to something like   !pip3 install --upgrade wetsuite)
# For your own setup, see wetsuite's install guidelines.
# !pip3 install -U wetsuite

# %% [markdown]
# ## Purpose of this notebook
#
# Explore what is in the Basis WettenBestand dataset(s), and what you could easily do with it.
#
# You may also want to find the [extras_diagnose_koop_bwb_docstructure](zextras_diagnose_koop_bwb_docstructure.ipynb) notebook
# which is some introduction to the structure of the varied documents in here.
#
# Any real research question is probably going to be fairly specific,
# so let's start with something relatively dumb - looking for definition lists.

# %%
import collections
import random
import pprint

import wetsuite.helpers.etree
import wetsuite.helpers.koop_parse
import wetsuite.helpers.net
from wetsuite.helpers import lazy
import wetsuite.datasets

# %%
bwb_text = wetsuite.datasets.load('bwb-mostrecent-text')
bwb_xml  = wetsuite.datasets.load('bwb-mostrecent-xml')
bwb_meta = wetsuite.datasets.load('bwb-mostrecent-meta-struc')  # we don't end up using this

# %%
#print( bwb_text.data.get('BWBR0034320') )
print( wetsuite.helpers.etree.debug_pretty( bwb_xml.data.get('BWBR0034320')) )

# %% [markdown]
# ## Figure out which laws have a definition list.
#
# There are a few different ways. You could e.g. reach into specific parts of the XML,
# and e.g. look for an artikel/kop/titel with text 'Definities' or 'Begripsbepalingen'
#
# But even simplwer would be to look for the following text is present,
# and anywhere in the document is probably good enough of a test
# It happens to often be used literally -- but chances are we're missing something
# We could likely catch more if we allowed more variants, but for a quick test this is plenty.

# %%
wordt_verstaan = 'deze regeling wordt verstaan'

bwbids_with_verstaan = set()
for bwbid, text in bwb_text.data.items():
    if wordt_verstaan in text:
        bwbids_with_verstaan.add( bwbid )
len( bwbids_with_verstaan )
# Out:
# 5344

# %% [markdown]
# fetch the full XML for each of those BWB-ids,
# then fish out just the definitions list -- by looking around the element that contains that same text

# %%
definitions = collections.defaultdict(list)
def_header_titles = collections.Counter() # the name of the header of this section, to see how consistent it is

for test_bwbid in bwbids_with_verstaan:
    xmlbytes = bwb_xml.data.get( test_bwbid )
    etree = lazy.etree( xmlbytes )
    
    # That next line is syntax-fu via XPath, sorry - it's a bunch fewer lines than a bunch of node navigation.
    #   It asks for something like "the parent (if it is an artikel) of a node that contains 'wordt verstaan' as text" 
    for node in list( etree.xpath( "//al[contains(text(),'%s')]/parent::artikel"%wordt_verstaan ) ):

        # this is just for the "what is the header this is in called?",
        kop = node.find('kop')
        titel = kop.find('titel')
        if titel is not None:
            def_header_titles.update( [titel.text] )
        # the rest is picking up the definitions:

        # From looking at some of these documents, most look like:
        #   <al><nadruk type="cur">de minister:</nadruk>de Minister van Binnenlandse Zaken en Koninkrijksrelaties;</al>
        # note: a serious investigation would try for completeness, this is just a proof of concept.
        #       looking for nadruk will later prove too approximate, but it's simple for an example
        for al in node.xpath('//nadruk/parent::al'):
            al_before = wetsuite.helpers.etree.debug_pretty(al)

            nadruk = al.find('nadruk')
            defined_thing = nadruk.text
            if defined_thing is not None  and  len(defined_thing.strip()) >= 2: # skip some empty nodes, and single letters
                defined_thing = defined_thing.rstrip(': ')

                # the further text is often the etree-.tail of the nadruk node, but let's assume there can be markup in there,
                # We can use our own text extractor function on the whole thing 
                #   ...if we remove the term we are defining from the in-memory document 
                #   (specifically nadruk; we just copied it to `what`) before doing so, to avoid it showing up twice
                nadruk.text = ''

                rest_text = (  ' '.join( wetsuite.helpers.etree.all_text_fragments(al) )  ).strip('; ')

                if len(rest_text)==0: # only nadruk, no other text in the alinea -- this is probably wrong and skippable.
                    pass
                    #print('CONFUSED about:')
                    #print( al_before )
                else:
                    definitions[defined_thing].append( (test_bwbid, rest_text) )  # add the BWB-id to signal where it came from

# %%
# Count and list the name of the section we just picked these out of
#   (in part to see how well we would have done if we were looking for them by section name)
dht = list( def_header_titles.items() )
dht.sort( key=lambda x:x[1], reverse=True) # most used on top
for header, count in dht:
    if count >=2: # show only those used more than once
        print( '%5s %s'%(count, header) )
# Turns out there's some variation.
# Out:
#  1230 Begripsbepalingen
#   382 Definities
#   173 Begripsbepaling
#    66 Begripsomschrijvingen
#    23 (begripsbepalingen)
#    21 Begrippen
#    17 Definitiebepalingen
#    15 begripsbepalingen
#    14 (definities)
#    11 Definitiebepaling
#    10 Begripsomschrijving
#     9 Definitie
#     7 (Begripsbepalingen)
#     6 Algemene bepalingen
#     6 (begripsomschrijving)
#     4 definities
#     3 (begripsomschrijvingen)
#     3 Algemene begripsbepalingen
#     3
#
#     2 Begripsbepalingen
#     2 Begrippen en definities
#     2 – Definities –
#     2 - Begripsbepalingen
#     2  Begripsbepalingen
#     2 – definities

# %%
# CONSIDER: using a case insensitive merge on defined_thing
import wetsuite.extras.word_cloud # has a function that counts identical strings

defdata = list( definitions.items() )  
defdata.sort( key=lambda x:len(x[1]), reverse=True)

# items like:  ('Lucky Bamboo', [('BWBR0025197', 'sierplant met de wetenschappelijke naam Dracaena sanderiana')])
# The below throws away that origin ID for brevity,
# yet you might well want that when digging deeper

for defined_thing, definitions_list in defdata[:10]: # print just 10, otherwise this would be 60K lines
    # we'd expect at least things like 'minister' and 'wet' to be "this particular one within this document"-style definitions, not general definitions
    if defined_thing.lower() in ('minister', 'de minister', 'wet','de wet', 'besluit'):
        continue # so ignore them

    # simpler:  print everything
    if len(definitions_list)>0:
        print( defined_thing )
        for origin_bwb, definition in definitions_list:
           print(f'  In {origin_bwb}: {definition}')

    # more complex: only things that appear more often
    counts = wetsuite.extras.word_cloud.count_normalized( 
        list(definition     for origin_bwbid, definition  in definitions_list ),  
        min_count = 2 # show only definitions used more than once
    )
    if len(counts)>0:
        print( defined_thing )
        pprint.pprint(counts)

    print()
# Out:
# school
#   In BWBR0040016: school voor vwo, havo, mavo, vbo of praktijkonderwijs
#   In BWBR0046513: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0048176: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1.1 van de WVO 2020
#   In BWBR0042421: school als bedoeld in artikel 1 van de wet
#   In BWBR0038607: school als bedoeld in artikel 1 van de wet
#   In BWBR0039605: basisschool, speciale school voor basisonderwijs dan wel school voor (voortgezet) speciaal onderwijs als bedoeld in dit artikel
#   In BWBR0048409: school als bedoeld in artikel 1.1 van de WVO 2020 , of artikel 1 van de WEC voor zover het voortgezet speciaal onderwijs betreft
#   In BWBR0033979: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0049052: school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra of artikel 1.1 van de Wet voortgezet onderwijs 2020
#   In BWBR0045041: Uit ’s Rijks kas bekostigde school voor voortgezet onderwijs als bedoeld in artikel 1.1 van de Wet voortgezet onderwijs 2020 .
#   In BWBR0026267: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0045034: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1.1 van de Wet voortgezet onderwijs 2020 , dan wel instelling als bedoeld in artikel 1.1.1 van de Wet educatie en beroepsonderwijs
#   In BWBR0047084: school als bedoeld in artikel 1 van de wet
#   In BWBR0044915: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1.1 van de Wet voortgezet onderwijs 2020
#   In BWBR0046936: school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra , artikel 1.1 van de Wet voortgezet onderwijs 2020 of artikel 67 van de Wet primair onderwijs BES
#   In BWBR0040011: school als bedoeld in artikel 1 van de Wet op het primair onderwijs en artikel 1 van de Wet op de expertisecentra .
#   In BWBR0042049: school als bedoeld in artikel 1 van de wet
#   In BWBR0045608: school voor vwo, havo, mavo, vbo of praktijkonderwijs
#   In BWBR0026484: school voor vwo, havo, mavo, vbo of praktijkonderwijs
#   In BWBR0029599: een internationale school, een buitenlandse school of een ambassadeschool waaraan voltijds onderwijs wordt geboden aan leerlingen in een of meer van de leeftijdsgroepen variërend van 5 jaar tot 18 jaar
#   In BWBR0046516: school als bedoeld in artikel 1 van de wet
#   In BWBR0037068: school als bedoeld in artikel 1 van de wet
#   In BWBR0033971: school als bedoeld in artikel 1 van de wet
#   In BWBR0045681: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra en artikel 1 van de Wet op het voortgezet onderwijs , met uitzondering van de scholen bedoeld in artikel 185 van de Wet op het primair onderwijs
#   In BWBR0036513: basisschool als bedoeld in artikel 1 van de Wet op het primair onderwijs , speciale school voor basisonderwijs als bedoeld in artikel 1 van de Wet op het primair onderwijs of school voor speciaal onderwijs, speciaal voortgezet onderwijs of speciaal en voortgezet speciaal onderwijs als bedoeld in artikel 1 van de Wet op de expertisecentra
#   In BWBR0038536: bekostigde school als bedoeld in de WPO of een bekostigde school of instelling als bedoeld in de WEC .
#   In BWBR0045549: school als bedoeld in artikel 1 van de wet
#   In BWBR0037078: school voor vwo, havo, mavo, vbo of praktijkonderwijs
#   In BWBR0045605: school als bedoeld in artikel 1.1 van de wet
#   In BWBR0030501: school voor vwo, havo, mavo, vbo of praktijkonderwijs
#   In BWBR0033168: school als bedoeld in artikel 1 van de wet
#   In BWBR0048360: school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra of artikel 1.1 van de Wet voortgezet onderwijs 2020
#   In BWBR0027113: een school of scholengemeenschap als bedoeld in artikel 1.1 van de wet , die wordt bekostigd op grond van de wet
#   In BWBR0041424: school als bedoeld in artikel 1 van de wet
#   In BWBR0045350: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0045445: school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra , of artikel 1 van de Wet primair onderwijs BES , niet zijnde een school voor voortgezet speciaal onderwijs als bedoeld in artikel 1 van de Wet op de expertisecentra
#   In BWBR0038987: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het voortgezet onderwijs , artikel 1 van de Wet voortgezet onderwijs BES dan wel een instelling als bedoeld in artikel 1.1.1, onderdeel b, onder 3°, van de Wet educatie en beroepsonderwijs
#   In BWBR0047085: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0035590: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0045146: school dan wel instelling als bedoeld in de onderdelen b, c, d, e, f of h.
#   In BWBR0029691: school als bedoeld in artikel 1 van de wet
#   In BWBR0043312: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0039388: een bekostigde basisschool als bedoeld in de WPO
#   In BWBR0039388: een bekostigde basisschool als bedoeld in de WPO
#   In BWBR0039388: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0043320: school als bedoeld in artikel 1 van de wet
#   In BWBR0026356: basisschool, speciale school voor basisonderwijs, school voor speciaal onderwijs, school voor voortgezet speciaal onderwijs of instelling voor speciaal en voortgezet speciaal onderwijs als bedoeld in artikel 8, eerste lid tweede volzin, van de Wet op de Expertisecentra .
#   In BWBR0025350: een school of scholengemeenschap voor voortgezet onderwijs zoals bedoeld in artikel 1 van de wet , die wordt bekostigd op grond van de wet
#   In BWBR0030618: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0025733: basisschool als bedoeld in artikel 1 van de Wet op het primair onderwijs die in aanmerking komt voor aanvullende bekostiging voor personeelskosten voor de bestrijding van onderwijsachterstanden als bedoeld in artikel 28, eerste lid, van het Besluit bekostiging WPO
#   In BWBR0027810: basisschool als bedoeld in artikel 1 van de Wet op het primair onderwijs
#   In BWBR0045006: basisschool of speciale school voor basisonderwijs als bedoeld in artikel 1 van de Wet op het primair onderwijs of school voor speciaal onderwijs, school voor speciaal voortgezet onderwijs of school voor speciaal en voortgezet speciaal onderwijs als bedoeld in de Wet op de expertisecentra
#   In BWBR0039462: school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet primair onderwijs BES en artikel 1 van de Wet op de expertisecentra
#   In BWBR0043653: school als bedoeld in artikel 1.1 van de wet , of artikel 1 van de Wet op de expertisecentra
#   In BWBR0041334: school als bedoeld in artikel 1.1 van de Wet voortgezet onderwijs 2020 of artikel 1 van de Wet op de expertisecentra
#   In BWBR0026527: uit Rijks kas bekostigde school of scholengemeenschap voor voortgezet onderwijs of instelling bedoeld in artikel 1.3.3, van de WEB
#   In BWBR0044325: school als bedoeld in artikel 1 van de wet
#   In BWBR0036277: een uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het voortgezet onderwijs , dan wel een instelling als bedoeld in artikel 1.1.1, onderdeel b, onder 3°, van de Wet educatie en beroepsonderwijs
#   In BWBR0029869: school als bedoeld in artikel 1 van de wet
#   In BWBR0047123: school als bedoeld in artikel 1 van de WPO of artikel 1 van de WVO 2020
#   In BWBR0042520: school als bedoeld in artikel 1 van de wet
#   In BWBR0045674: school als bedoeld in artikel 1 van de wet
#   In BWBR0045604: school voor voortgezet onderwijs als bedoeld in artikel 1.1 van de wet
#   In BWBR0038647: een bekostigde basisschool als bedoeld in de Wet op het primair onderwijs
#   In BWBR0038647: bekostigde speciale school voor basisonderwijs als bedoeld in de Wet op het primair onderwijs
#   In BWBR0041273: school als bedoeld in artikel 1 van de wet
#   In BWBR0041042: school als bedoeld in artikel 1 van de Wet op het voortgezet onderwijs , artikel 1 van Wet op de expertisecentra , artikel 1 van de Wet voortgezet onderwijs BES of een agrarisch opleidingscentrum als bedoeld in artikel 1.3.3 van de Wet educatie en beroepsonderwijs
#   In BWBR0040685: school als bedoeld in artikel 1 van de wet
#   In BWBR0027777: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0042461: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1.1 van de Wet voortgezet onderwijs 2020 , dan wel instelling als bedoeld in artikel 1.1.1 van de Wet educatie en beroepsonderwijs
#   In BWBR0030689: een uit ’s Rijks kas bekostigde basisschool of een speciale school voor basisonderwijs als bedoeld in artikel 1 van de Wet op het primair onderwijs , een uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op de expertisecentra , een uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het voortgezet onderwijs en een uit ’s Rijks kas bekostigde instelling als bedoeld in artikel 1.1.1 onder b van de Wet educatie beroepsonderwijs , een instituut als bedoeld in artikel 12.3.8 , dan wel een hogeschool als bedoeld in artikel 12.3.9 van de WEB dan wel door rechtsopvolgers,
#   In BWBR0041274: school als bedoeld in artikel 1 van de wet
#   In BWBR0044001: school als bedoeld in artikel 1 van de wet
#   In BWBR0042419: school voor voortgezet onderwijs als bedoeld in artikel 1.1 van de Wet voortgezet onderwijs 2020
#   In BWBR0030520: school als bedoeld in artikel 1 van de wet
#   In BWBR0027516: een uit ’s Rijks kas bekostigde basisschool of een speciale school voor basisonderwijs als bedoeld in artikel 1 van de Wet op het primair onderwijs , dan wel een uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het voortgezet onderwijs ,
#   In BWBR0048344: school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet primair onderwijs BES , artikel 1.1 van de Wet voortgezet onderwijs 2020 , met uitzondering van een school voor praktijkonderwijs, voorbereidend beroepsonderwijs of mavo die deel uitmaakt van een verticale scholengemeenschap of, artikel 1 van de Wet op de expertisecentra
#   In BWBR0022749: een school als bedoeld in artikel 1 van de Wet op het primair onderwijs
#   In BWBR0032037: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0048123: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1.1 van de WVO 2020 , artikel 1 van de WPO , artikel 1 van de WEC of artikel 1 van de WPO BES met inbegrip van een school voor voorbereidend beroepsonderwijs die deel uitmaakt van een verticale scholengemeenschap die van rechtswege is ontstaan na de omzetting op grond van artikel 12.2.4 van de WEB
#   In BWBR0043944: school als bedoeld in artikel 1 van de WPO of artikel 1 van de WEC
#   In BWBR0039819: school als bedoeld in artikel 1 van de WPO , artikel 1 van de WEC en artikel 1.1 van de WVO 2020
#   In BWBR0029688: school als bedoeld in artikel 1 van de wet
#   In BWBR0042621: school als bedoeld In artikel 1 van de wet
#   In BWBR0004229: school voor basisonderwijs als bedoeld in de Wet primair onderwijs BES
#   In BWBR0025839: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op het voortgezet onderwijs , dan wel een instelling als bedoeld in artikel 1.1.1, onderdeel b van de Wet educatie en beroepsonderwijs ,
#   In BWBR0048928: een school als bedoeld in artikel 1 van de WPO en artikel 1.1 van de WVO 2020
#   In BWBR0048797: school als bedoeld in artikel 1 van de wet
#   In BWBR0040490: school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra of artikel 1 van de Wet primair onderwijs BES ,
#   In BWBR0040691: school als bedoeld in de onderdelen b, c, d, e of f.
#   In BWBR0038555: school als bedoeld In artikel 1 van de wet
#   In BWBR0038193: school voor vbo of scholengemeenschap waarvan ten minste een school voor vbo deel uitmaakt
#   In BWBR0030414: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0042037: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0039295: school als bedoeld in artikel 1 van de wet
#   In BWBR0030705: een uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra of artikel 1 van de Wet op het voortgezet onderwijs , dan wel een instelling als bedoeld in artikel 1.1.1, onderdeel b van de Wet educatie en beroepsonderwijs
#   In BWBR0034998: school als bedoeld in artikel 1 van de wet
#   In BWBR0035883: school als bedoeld in artikel 1 van de Wet op het primair onderwijs en artikel 1 van de Wet op de expertisecentra ,
#   In BWBR0043550: school als bedoeld in artikel 1 van de Wet op het primair onderwijs of artikel 1 van de Wet op de expertisecentra
#   In BWBR0040429: school die is aangewezen op grond van artikel 2.66 van de wet alsmede een uit ’s Rijks kas bekostigde school voor voortgezet onderwijs bedoeld in de wet of een school als bedoeld in artikel 14a van de Wet op de expertisecentra
#   In BWBR0046912: basisschool als bedoeld in hoofdstuk 2 van deze regeling en een school voor voortgezet onderwijs als bedoeld in hoofdstuk 3 van deze regeling
#   In BWBR0046912: basisschool, niet zijnde een speciale school voor basisonderwijs of een school waarvan de kwaliteit van het onderwijs zeer zwak is als bedoeld in artikel 10a, eerste en vierde lid, van de wet ; en
#   In BWBR0046912: school voor voortgezet onderwijs of een scholengemeenschap als bedoeld in artikel 1.1 van de wet , niet zijnde een school voor praktijkonderwijs of een school waarvan de kwaliteit van het onderwijs zeer zwak is als bedoeld in artikel 2.94, eerste en derde lid van de wet ; en
#   In BWBR0048709: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0043442: school of verticale scholengemeenschap als bedoeld in artikel 1.1 van de Wet voortgezet onderwijs 2020
#   In BWBR0036265: school als bedoeld in artikel 1 van de Wet op het primair onderwijs of school als bedoeld in artikel 1 van de Wet op het voortgezet onderwijs ,
#   In BWBR0040046: school als bedoeld In artikel 1 van de wet
#   In BWBR0047083: school als bedoeld in artikel 1 van de wet
#   In BWBR0045351: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0044055: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0038484: een school voor voortgezet onderwijs als bedoeld in artikel 1.1 van de wet , met uitzondering van scholen voor praktijkonderwijs
#   In BWBR0035677: school als bedoeld in artikel 1 van de wet
#   In BWBR0037032: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0039946: bekostigde basisschool als bedoeld in de Wet op het primair onderwijs
#   In BWBR0039946: bekostigde basisschool als bedoeld in de Wet op het primair onderwijs
#   In BWBR0039946: bekostigde speciale school voor basisonderwijs als bedoeld in de Wet op het primair onderwijs
#   In BWBR0039972: school als bedoeld in artikel 1 van de Wet op de expertisecentra , artikel 1 van de Wet op het primair onderwijs of artikel 1 van de Wet op het voortgezet onderwijs
#   In BWBR0037064: school als bedoeld in onderscheidenlijk artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra of artikel 1 van de Wet op het voorgezet onderwijs of het voorbereidend beroepsonderwijs dat deel uitmaakt van een agrarisch opleidingscentrum als bedoeld in artikel 1.3.3 van de Wet educatie en beroepsonderwijs en met uitzondering van een school voor voortgezet onderwijs die deel uitmaakt van een scholengemeenschap met een regionaal opleidingencentrum als bedoeld in artikel 1.3.1 van de Wet educatie en beroepsonderwijs of een agrarisch opleidingscentrum als bedoeld in artikel 1.3.3 van de Wet educatie en beroepsonderwijs
#   In BWBR0039721: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op het primair onderwijs BES , of artikel 1.1 van de Wet voortgezet onderwijs 2020 .
#   In BWBR0025694: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0044361: bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra of artikel 1.1 van de Wet voortgezet onderwijs 2020
#   In BWBR0029821: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0027500: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0047992: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1.1 van de WVO 2020 , artikel 1 van de WPO , artikel 1 van de WEC of artikel 1 van de WPO BES met inbegrip van een school voor voorbereidend beroepsonderwijs die deel uitmaakt van een verticale scholengemeenschap die van rechtswege is ontstaan na de omzetting op grond van artikel 12.2.4 van de WEB
#   In BWBR0025827: een uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op het voortgezet onderwijs , dan wel een instelling als bedoeld in artikel 1.1.1, onderdeel b van de Wet educatie en beroepsonderwijs
#   In BWBR0043897: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0048796: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0027606: school voor basisonderwijs, speciale school voor basisonderwijs, school voor voortgezet onderwijs, school voor speciaal onderwijs, school voor voortgezet speciaal onderwijs en school of instelling voor speciaal en voortgezet speciaal onderwijs als bedoeld in artikel 1 van de WPO , artikel 1 van de WEC en artikel 1 van de WVO
#   In BWBR0045686: school als bedoeld in artikel 1.1 van de WVO 2020 of artikel 1 van de Wet op de expertisecentra
#   In BWBR0045606: school of scholengemeenschap voor voortgezet onderwijs als bedoeld in artikel 1.1 van de wet
#   In BWBR0045607: school of scholengemeenschap als bedoeld in artikel 1.1 van de wet
#   In BWBR0042693: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0047996: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1.1 van de WVO 2020 , artikel 1 van de WPO , artikel 1 van de WEC of artikel 1 van de WPO BES met inbegrip van een school voor voorbereidend beroepsonderwijs die deel uitmaakt van een verticale scholengemeenschap die van rechtswege is ontstaan na de omzetting op grond van artikel 12.2.4 van de WEB
#   In BWBR0047050: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1.1 van de WVO 2020 , artikel 1 van de WPO , artikel 1 van het Besluit trekkende bevolking WPO , artikel 1 van de WEC of artikel 1 van de WPO BES met inbegrip van een school voor voorbereidend beroepsonderwijs die deel uitmaakt van een verticale scholengemeenschap die van rechtswege is ontstaan na de omzetting op grond van artikel 12.2.4 van de WEB
#   In BWBR0044023: school als bedoeld in artikel 1 van de wet
#   In BWBR0025977: een school of scholengemeenschap voor voortgezet onderwijs, bedoeld in artikel 1.1 van de Wet voortgezet onderwijs 2020
#   In BWBR0044044: basisschool als bedoeld in de wet
#   In BWBR0048597: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra , artikel 1 van de Wet voortgezet onderwijs 2020 , of instelling als bedoeld in artikel 1.1.1 van de Wet educatie en beroepsonderwijs
#   In BWBR0026680: basisschool, speciale school voor basisonderwijs, school voor speciaal onderwijs, school voor voortgezet speciaal onderwijs of voor speciaal en voortgezet speciaal onderwijs als bedoeld in artikel 8, eerste lid tweede volzin, van de Wet op de Expertisecentra .
#   In BWBR0044510: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op het primair onderwijs BES , artikel 1 van de Wet op de expertisecentra , artikel 1.1 van de Wet voortgezet onderwijs 2020
#   In BWBR0048387: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1.1 van de Wet voortgezet onderwijs 2020 , of artikel 1 van de Wet op de expertisecentra
#   In BWBR0044971: school als bedoeld in artikel 1 van de wet
#   In BWBR0030388: een school als bedoeld in artikel 1 van de wet
#   In BWBR0045553: school als bedoeld in artikel 1 van de wet
#   In BWBR0029808: school als bedoeld in de wet
#   In BWBR0045015: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0038995: school voor voortgezet onderwijs, bedoeld in artikel 1.1 van de Wet voortgezet onderwijs 2020
#   In BWBR0041633: school voor primair of voortgezet onderwijs zoals geïdentificeerd binnen de Basisregistratie instelling (BRIN) met het BRIN-nummer
#   In BWBR0042523: school als bedoeld in artikel 1 van de wet
#   In BWBR0031453: school als bedoeld in artikel 1 van de wet
#   In BWBR0038561: school als bedoeld in artikel 1 van de wet
#   In BWBR0044043: school als bedoeld in de wet
#   In BWBR0041276: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0035057: basisschool als bedoeld in artikel 1 van de Wet op het primair onderwijs die toestemming heeft gekregen om deel te nemen aan de pilot tweetalig primair onderwijs
#   In BWBR0046964: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs BES of artikel 1.1 van de Wet voortgezet onderwijs 2020 , in het openbaar lichaam Bonaire, Saba of Sint Eustatius
#   In BWBR0028666: school voor vwo, havo, mavo, vbo of praktijkonderwijs
#   In BWBR0042547: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0047086: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0039389: school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet primair onderwijs BES en artikel 1 van de Wet op de expertisecentra
#   In BWBR0030078: basisschool als bedoeld in artikel 1 van de Wet op het primair onderwijs die vroegschoolse educatie verzorgt
#   In BWBR0026138: bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .
#   In BWBR0030294: school als bedoeld in artikel 1 van de WPO , artikel 1 van de WEC en artikel 1 van de WVO
#   In BWBR0041367: bekostigde speciale school voor basisonderwijs als bedoeld in de WPO
#   In BWBR0025837: een uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra , artikel 1 van de Wet op het voortgezet onderwijs of een instelling als bedoeld in artikelen 1.1.1, onder b , 12.3.8 of 12.3.9 van de Wet educatie en beroepsonderwijs
#   In BWBR0033593: uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op het voortgezet onderwijs , dan wel een instelling als bedoeld in artikel 1.1.1, onderdeel b, van de Wet educatie en beroepsonderwijs
#   In BWBR0040130: school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra en artikel 1 van de Wet primair onderwijs BES .
#   In BWBR0041307: school als bedoeld in artikel 1 WVO
#   In BWBR0042247: basisschool als bedoeld in artikel 1 van de Wet op het primair onderwijs die heeft meegedaan aan de pilot tweetalig primair onderwijs
#   In BWBR0032051: school als bedoeld in artikel 1 van de wet
# school
# {'bekostigde basisschool als bedoeld in de Wet op het primair onderwijs': 2,
#  'bekostigde school als bedoeld in de Wet op het primair onderwijs of een bekostigde school of instelling als bedoeld in de Wet op de expertisecentra .': 12,
#  'bekostigde speciale school voor basisonderwijs als bedoeld in de WPO': 17,
#  'bekostigde speciale school voor basisonderwijs als bedoeld in de Wet op het primair onderwijs': 2,
#  'een bekostigde basisschool als bedoeld in de WPO': 2,
#  'school als bedoeld In artikel 1 van de wet': 3,
#  'school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet op de expertisecentra of artikel 1.1 van de Wet voortgezet onderwijs 2020': 2,
#  'school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1 van de Wet primair onderwijs BES en artikel 1 van de Wet op de expertisecentra': 2,
#  'school als bedoeld in artikel 1 van de wet': 34,
#  'school als bedoeld in de wet': 2,
#  'school voor vwo, havo, mavo, vbo of praktijkonderwijs': 6,
#  'uit ’s Rijks kas bekostigde school als bedoeld in artikel 1 van de Wet op het primair onderwijs , artikel 1.1 van de Wet voortgezet onderwijs 2020 , dan wel instelling als bedoeld in artikel 1.1.1 van de Wet educatie en beroepsonderwijs': 2,
#  'uit ’s Rijks kas bekostigde school als bedoeld in artikel 1.1 van de WVO 2020 , artikel 1 van de WPO , artikel 1 van de WEC of artikel 1 van de WPO BES met inbegrip van een school voor voorbereidend beroepsonderwijs die deel uitmaakt van een verticale scholengemeenschap die van rechtswege is ontstaan na de omzetting op grond van artikel 12.2.4 van de WEB': 2}
#
# Wet kinderopvang
#   In BWBR0017462: ( artikel 1, eerste lid )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikelen 60 en 60a )
#   In BWBR0017462: ( artikelen 54 en 63, vierde lid )
#   In BWBR0017462: ( artikel 50, derde, vierde en vijfde lid )
#   In BWBR0017462: ( artikel 50, eerste lid )
#   In BWBR0017462: ( artikel 50, eerste lid )
#   In BWBR0017462: ( artikel 55 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 50 )
#   In BWBR0017462: ( artikel 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikel 60a )
#   In BWBR0017462: ( artikel 1, eerste lid )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikelen 60 en 60a )
#   In BWBR0017462: ( artikelen 54 en 63, vierde lid )
#   In BWBR0017462: ( artikel 50, derde, vierde en vijfde lid )
#   In BWBR0017462: ( artikel 50, eerste lid )
#   In BWBR0017462: ( artikel 50, eerste lid )
#   In BWBR0017462: ( artikel 55 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 50 )
#   In BWBR0017462: ( artikel 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikel 60a )
#   In BWBR0017462: (Verzamelwet, wordt in de loop van 2010 vastgesteld)
#   In BWBR0017462: ( artikelen 1 , 45, tweede en derde lid , 46 tweede lid , 47 en 62 )
#   In BWBR0017462: ( artikel 56b, derde, vierde en vijfde lid )
#   In BWBR0017462: ( artikel 1, lid 1 )
#   In BWBR0017462: ( artikel 56b, eerste en tweede lid )
#   In BWBR0017462: ( artikel 1, lid 1 )
#   In BWBR0017462: ( artikelen 1 , 45, tweede en derde lid , 46 tweede lid , 47 en 62 )
#   In BWBR0017462: ( artikel 56b, derde, vierde en vijfde lid )
#   In BWBR0017462: ( artikel 1, lid 1 )
#   In BWBR0017462: ( artikel 56b, eerste en tweede lid )
#   In BWBR0017462: ( artikel 55 )
#   In BWBR0017462: ( artikel 1 )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56b )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56b )
#   In BWBR0017462: ( artikel 1 )
#   In BWBR0017462: ( artikel 1 )
#   In BWBR0017462: ( artikelen 49, tweede lid , en 56b )
#   In BWBR0017462: ( artikelen 49, tweede lid , en 56b )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56b )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56b )
#   In BWBR0017462: ( artikelen 49 en 56 )
#   In BWBR0017462: ( artikelen 49 en 56 )
#   In BWBR0017462: (Verzamelwet, wordt in de loop van 2010 vastgesteld)
#   In BWBR0017462: ( artikelen 1 en 49, derde lid )
#   In BWBR0017462: ( artikel 56, lid 4 )
#   In BWBR0017462: ( artikelen 56, derde lid en 50, derde, vierde en vijfde lid )
#   In BWBR0017462: ( artikelen 1 en 49, derde lid )
#   In BWBR0017462: ( artikelen 1 , 50 , 52 en 56 )
#   In BWBR0017462: ( artikel 56, lid 4 )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikelen 60 en 60a )
#   In BWBR0017462: ( artikelen 56, derde lid en 50, derde, vierde en vijfde lid )
#   In BWBR0017462: ( artikelen 49 en 56 )
#   In BWBR0017462: ( artikel 60a )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56 )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56 )
#   In BWBR0017462: ( artikelen 1, lid 1 en 56, eerste lid )
#   In BWBR0017462: ( artikel 1, eerste lid )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikelen 60 en 60a )
#   In BWBR0017462: ( artikelen 54 en 63, vierde lid )
#   In BWBR0017462: ( artikel 50, derde, vierde en vijfde lid )
#   In BWBR0017462: ( artikel 50, eerste lid )
#   In BWBR0017462: ( artikel 50, eerste lid )
#   In BWBR0017462: ( artikel 55 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 50 )
#   In BWBR0017462: ( artikel 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikel 60a )
#   In BWBR0017462: ( artikel 1, eerste lid )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikelen 60 en 60a )
#   In BWBR0017462: ( artikelen 54 en 63, vierde lid )
#   In BWBR0017462: ( artikel 50, derde, vierde en vijfde lid )
#   In BWBR0017462: ( artikel 50, eerste lid )
#   In BWBR0017462: ( artikel 50, eerste lid )
#   In BWBR0017462: ( artikel 55 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 51 )
#   In BWBR0017462: ( artikel 50 )
#   In BWBR0017462: ( artikel 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikelen 49 en 50 )
#   In BWBR0017462: ( artikel 60a )
#   In BWBR0017462: (Verzamelwet, wordt in de loop van 2010 vastgesteld)
#   In BWBR0017462: ( artikelen 1 , 45, tweede en derde lid , 46 tweede lid , 47 en 62 )
#   In BWBR0017462: ( artikel 56b, derde, vierde en vijfde lid )
#   In BWBR0017462: ( artikel 1, lid 1 )
#   In BWBR0017462: ( artikel 56b, eerste en tweede lid )
#   In BWBR0017462: ( artikel 55 )
#   In BWBR0017462: ( artikel 1 )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56b )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56b )
#   In BWBR0017462: ( artikel 1 )
#   In BWBR0017462: ( artikel 1 )
#   In BWBR0017462: ( artikelen 49, tweede lid , en 56b )
#   In BWBR0017462: ( artikelen 49, tweede lid , en 56b )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56b )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56b )
#   In BWBR0017462: ( artikelen 49 en 56 )
#   In BWBR0017462: ( artikelen 49 en 56 )
#   In BWBR0017462: (Verzamelwet, wordt in de loop van 2010 vastgesteld)
#   In BWBR0017462: ( artikelen 1 en 49, derde lid )
#   In BWBR0017462: ( artikelen 1 , 50 , 52 en 56 )
#   In BWBR0017462: ( artikel 56, lid 4 )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 59 )
#   In BWBR0017462: ( artikel 58 )
#   In BWBR0017462: ( artikelen 60 en 60a )
#   In BWBR0017462: ( artikelen 56, derde lid en 50, derde, vierde en vijfde lid )
#   In BWBR0017462: ( artikel 60a )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56 )
#   In BWBR0017462: ( artikelen 49, tweede lid en 56 )
#   In BWBR0017462: ( artikelen 1, lid 1 en 56, eerste lid )
# Wet kinderopvang
# {'( artikel 1 )': 6,
#  '( artikel 1, eerste lid )': 4,
#  '( artikel 1, lid 1 )': 4,
#  '( artikel 50 )': 8,
#  '( artikel 50, derde, vierde en vijfde lid )': 4,
#  '( artikel 50, eerste lid )': 8,
#  '( artikel 51 )': 24,
#  '( artikel 55 )': 6,
#  '( artikel 56, lid 4 )': 3,
#  '( artikel 56b, derde, vierde en vijfde lid )': 3,
#  '( artikel 56b, eerste en tweede lid )': 3,
#  '( artikel 58 )': 11,
#  '( artikel 59 )': 12,
#  '( artikel 60a )': 6,
#  '( artikelen 1 , 45, tweede en derde lid , 46 tweede lid , 47 en 62 )': 3,
#  '( artikelen 1 , 50 , 52 en 56 )': 2,
#  '( artikelen 1 en 49, derde lid )': 3,
#  '( artikelen 1, lid 1 en 56, eerste lid )': 2,
#  '( artikelen 49 en 50 )': 16,
#  '( artikelen 49 en 56 )': 5,
#  '( artikelen 49, tweede lid , en 56b )': 4,
#  '( artikelen 49, tweede lid en 56 )': 4,
#  '( artikelen 49, tweede lid en 56b )': 8,
#  '( artikelen 54 en 63, vierde lid )': 4,
#  '( artikelen 56, derde lid en 50, derde, vierde en vijfde lid )': 3,
#  '( artikelen 60 en 60a )': 6,
#  '(Verzamelwet, wordt in de loop van 2010 vastgesteld)': 4}
#
# actief
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en instructies
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • organiseert   de logistiek rond vergaderingen (locaties, catering, routebeschrijvingen); verspreidt tijdig de vergaderstukken naar de deelnemers; regelt adequaat de toegang van deelnemers tot vergaderingen, ontvangt en begeleidt vriendelijk de deelnemers naar de vergadering of bijeenkomst
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • participeert   in bestaande netwerken
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • ondersteunt   de informatieverstrekking aan individuele en groepen belanghebbenden (leiding, bedrijfsvoering en uitvoeringspraktijk)
#   In BWBR0033460: • participeert   in netwerken
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies.
#   In BWBR0033460: • participeert   in bestaande netwerken
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • participeert   in bestaande netwerken
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • participeert   in bestaande netwerken
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • informeert   collega’s op straat en ter plaatse
#   In BWBR0033460: • participeert   in bestaande netwerken
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • participeert   in bestaande netwerken
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • participeert   in bestaande netwerken
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • participeert   in bestaande netwerken
#   In BWBR0033460: • participeert   in bestaande netwerken
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • participeert   in bestaande netwerken
#   In BWBR0033460: • instrueert   medewerkers middels handreikingen en werkinstructies
#   In BWBR0033460: • bouwt en onderhoudt   netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • bouwt en onderhoudt   (werkterreingerelateerde) netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • ondersteunt   de informatieverstrekking aan individuele en groepen belanghebbenden (leiding, bedrijfsvoering en uitvoeringspraktijk):
#   In BWBR0033460: • bouwt en onderhoudt   (werkterreingerelateerde) netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • bouwt en onderhoudt   (nieuwe) netwerken met gedeelde belangen; maakt heldere uitvoeringsafspraken met netwerkpartners
#   In BWBR0033460: • stelt − op basis van herkennen van patronen en verbanden in het leerproces van zijn cursisten −   adviezen op voor leiding en/of netwerkpartners voor rendementsverhoging in het verwerven van competenties middels (vaardigheids)trainingen
#   In BWBR0033460: • bevordert   de vakvolwassenheid van cursisten door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen.
#   In BWBR0033460: • bouwt en onderhoudt   netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • bouwt en onderhoudt   netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • informeert   collega’s op straat en ter plaatse
#   In BWBR0033460: • bouwt en onderhoudt   netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • bouwt en onderhoudt   (nieuwe) netwerken met gedeelde belangen en maakt heldere uitvoeringsafspraken met netwerkpartners
#   In BWBR0033460: • bevordert   de vakbekwaamheid van politiemedewerkers door begeleiding, (vaardigheids)training, theorielessen en het op maat formuleren van aanbevelingen.
#   In BWBR0033460: • het   bevorderen van het eigen blauwe vakmanschap
#   In BWBR0033460: • bouwt en onderhoudt   (werkterreingerelateerde)netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • bouwt en onderhoudt   netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • bouwt en onderhoudt   netwerken ter afstemming van inzetmogelijkheden van het vaartuig in relatie tot de te verrichten werkzaamheden van de passagiers en maakt uitvoeringsafspraken.
#   In BWBR0033460: • bouwt en onderhoudt   netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • bouwt en onderhoudt   (werkterreingerelateerde)netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • bouwt en onderhoudt   (werkterreingerelateerde)netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • bouwt en onderhoudt   (werkterreingerelateerde)netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • bouwt en onderhoudt   netwerken en maakt uitvoeringsafspraken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • initieert, bouwt, onderhoudt en regisseert   netwerken met gedeelde en/of tegenstrijdige belangen van netwerkpartner
#   In BWBR0033460: • informeert   de leidinggevende (domein Leiding) ten behoeve van het maken van ontwikkelafspraken en het voeren van beoordelingsgesprekken over de door hem in het kader van organisatorische coördinatie en regie aangestuurde functionarissen
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • informeert   relevante collega’s in aangrenzende vakgebieden
#   In BWBR0033460: • ondersteunt   de informatieverstrekking aan individuele en groepen belanghebbenden (leiding, bedrijfsvoering en uitvoeringspraktijk):
#   In BWBR0033460: • participeert   in bestaande netwerken van bedrijfsvoeringspecialisten
#   In BWBR0033460: • initieert, bouwt, onderhoudt en regisseert   (nieuwe) netwerken met mogelijk ook tegenstrijdige belangen; maakt heldere uitvoeringsafspraken met netwerkpartners
#   In BWBR0033460: • stelt − op basis van specialistische analyses op de leerprestaties van cursisten −   adviezen op voor leiding en/of netwerkpartners voor rendementsverhoging in het verwerven van competenties op mbo-niveau
#   In BWBR0033460: • bevordert   de vakvolwassenheid van cursisten door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen.
#   In BWBR0033460: • initieert, bouwt, onderhoudt en regisseert   netwerken met gedeelde en/of tegenstrijdige belangen van netwerkpartner
#   In BWBR0033460: • informeert   de leidinggevende (domein Leiding) ten behoeve van het maken van ontwikkelafspraken en het voeren van beoordelingsgesprekken over de door hem in het kader van organisatorische coördinatie en regie aangestuurde functionarissen
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • initieert, bouwt, onderhoudt en regisseert   netwerken met gedeelde en/of tegenstrijdige belangen van netwerkpartner
#   In BWBR0033460: • informeert   de leidinggevende (domein Leiding) ten behoeve van het maken van ontwikkelafspraken en het voeren van beoordelingsgesprekken over de door hem in het kader van organisatorische coördinatie en regie aangestuurde functionarissen
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • participeert   in netwerken ter afstemming van inzetmogelijkheden van het vaartuig − binnen geldende restricties − in relatie tot de te verrichten werkzaamheden van de passagiers
#   In BWBR0033460: • neemt   deel aan opsporingsonderzoeken die zijn specialisatie vereisen met inachtneming van het volgende:
#   In BWBR0033460: • initieert, bouwt, onderhoudt en regisseert   netwerken met gedeelde en/of tegenstrijdige belangen van netwerkpartner
#   In BWBR0033460: • informeert   de leidinggevende (domein Leiding) ten behoeve van het maken van ontwikkelafspraken en het voeren van beoordelingsgesprekken over de door hem in het kader van organisatorische coördinatie en regie aangestuurde functionarissen
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • informeert   collega’s op straat en ter plaatse
#   In BWBR0033460: • initieert, bouwt, onderhoudt en regisseert   netwerken met gedeelde en/of tegenstrijdige belangen van netwerkpartner
#   In BWBR0033460: • informeert   de leidinggevende (domein Leiding) ten behoeve van het maken van ontwikkelafspraken en het voeren van beoordelingsgesprekken over de door hem in het kader van organisatorische coördinatie en regie aangestuurde functionarissen
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • initieert, bouwt, onderhoudt en regisseert   netwerken met gedeelde en/of tegenstrijdige belangen van netwerkpartner
#   In BWBR0033460: • informeert   de leidinggevende (domein Leiding) ten behoeve van het maken van ontwikkelafspraken en het voeren van beoordelingsgesprekken
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • het   bevorderen van het eigen blauwe vakmanschap en dat van de collega’s
#   In BWBR0033460: • het   onderzoeken van mogelijkheden tot rendementsverhoging in de aanpak van de problematiek in de uitvoeringspraktijk vanuit de operationele begeleiding
#   In BWBR0033460: • initieert, bouwt, onderhoudt en regisseert   netwerken met gedeelde en/of tegenstrijdige belangen van netwerkpartner
#   In BWBR0033460: • informeert   de leidinggevende (domein Leiding) ten behoeve van het maken van ontwikkelafspraken en het voeren van beoordelingsgesprekken over de door hem in het kader van organisatorische coördinatie en regie aangestuurde functionarissen
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • initieert, bouwt, onderhoudt en regisseert   netwerken met gedeelde en/of tegenstrijdige belangen van netwerkpartner
#   In BWBR0033460: • informeert   de leidinggevende (domein Leiding) ten behoeve van het maken van ontwikkelafspraken en het voeren van beoordelingsgesprekken over de door hem in het kader van organisatorische coördinatie en regie aangestuurde functionarissen
#   In BWBR0033460: • bevordert   de vakvolwassenheid van medewerkers door coaching, overdracht van kennis en vaardigheden en het op maat formuleren van aanbevelingen
#   In BWBR0033460: • initieert, bouwt, onderhoudt en regisseert   netwerken met gedeelde en/of tegenstrijdige belangen van netwerkpartner
#   In BWBR0033460: • informeert   de leidinggevende (domein Leiding) ten behoeve van het maken van ontwikkelafspraken en het voeren van beoordelingsgesprekken over de door hem in het kader van organisatorische coördinatie en regie aangestuurde functionarissen
# ...
#   In BWBR0041184: nieuwe sporthalvloeren of vervangen van bestaande sporthalvloeren inclusief terugname verplichting door de leverancier.
#   In BWBR0041184: de opslag van duurzaam opgewekte energie die wordt gebufferd in een zout(water)batterij,
#   In BWBR0041184: Nieuwe of het vervangen van bestaande sportveldenondervloeren (shockpads) gemaakt van 80% aantoonbaar gerecycled materiaal inclusief terugname verplichting door de leverancier.
#   In BWBR0041184: het opvangen van regenwater van tenminste de eigen sportaccommodatie in een waterdichte opslag of waterdicht sportveld met overloop naar een infiltratiegebied niet zijnde een afwatersloot, al dan niet in combinatie met nuttige toepassing van het opgevangen regenwater,
#   In BWBR0041184: het bufferen van regenwater en verminderen van hittestress en behorende koelvraag,
#   In BWBR0041184: :
#   In BWBR0048993: sportveldverlichting,
#   In BWBR0048993: verlichting in en om nieuwe en bestaande sportaccommodaties, en bestaande uit: LED-verlichtingsarmaturen met een (eventueel uitwisselbare) LED-lichtbron en met een specifieke lichtstroom van ten minste 120 lm/W, EBSsysteem volgens maatregel 5.1.
#   In BWBR0048993: het koelen of verwarmen van bestaande sportaccommodaties door het benutten van koude of warmte in de afzuiglucht,
#   In BWBR0048993: het verwarmen van sportaccommodaties of het nuttig aanwenden van warmte voor de verwarming van tapwater in sportaccommodaties,
#   In BWBR0048993: het terugwinnen van warmte uit (douche)water,
#   In BWBR0048993: afdekken van binnen- en buitenbaden ten doel het warmteverlies via het wateroppervlakte te beperken,
#   In BWBR0048993: het koelen van sportaccommodaties door middel van verdampingskoeling,
#   In BWBR0048993: aanwezigheid gestuurde ruimteverwarming door middel van warmtestraling met behulp van infraroodpaneel, voor bijvoorbeeld kleedruimten in bestaande sportaccommodaties,
#   In BWBR0048993: beglazing in buitengevel- of dakconstructies van bestaande sportaccommodaties,
#   In BWBR0048993: beglazing in buitengevel- of dakconstructies van nieuwe sportaccommodaties,
#   In BWBR0048993: de verbetering van de isolatie van bestaande vloeren, daken, plafonds of wanden van ruimten,
#   In BWBR0048993: het verwarmen van water of lucht,
#   In BWBR0048993: het opwekken van elektrische energie uit zonlicht met behulp van zonnecellen,
#   In BWBR0048993: het verzamelen van warmte door middel van een collectorsysteem onder sportvelden voor het gebruik van het verwarmen van water of lucht,
#   In BWBR0048993: het (realtime) monitoren en visualiseren van het energiegebruik van gas en elektriciteit en eventueel opgewekte energie ten behoeve van verbeterd energiegebruik,
#   In BWBR0048993: bestaande en nieuwe kunstgrasvelden.
#   In BWBR0048993: bestaande en nieuwe kunstgrasvelden ter voorkoming van de verspreiding van microplastics (infill).
#   In BWBR0048993: een betere schoonloop- en opvangvoorziening van microplastics (infill) bij de in- en uitgang van de kunstgrasvelden ter voorkoming van verspreiding.
#   In BWBR0048993: nieuwe sporthalvloeren of vervangen van bestaande sporthalvloeren inclusief terugname verplichting door de leverancier.
#   In BWBR0048993: de opslag van duurzaam opgewekte energie die wordt gebufferd in een zout(water)batterij, en bestaande uit: zout(water)batterij en (eventuele) regeltechniek.
#   In BWBR0048993: Nieuwe of het vervangen van bestaande sportveldenondervloeren (shockpads) gemaakt van 80% aantoonbaar gerecycled materiaal inclusief terugname verplichting door de leverancier.
#   In BWBR0048993: het opvangen van regenwater van tenminste de eigen sportaccommodatie in een waterdichte opslag of waterdicht sportveld met overloop naar een infiltratiegebied niet zijnde een afwatersloot, al dan niet in combinatie met nuttige toepassing van het opgevangen regenwater,
#   In BWBR0048993: het bufferen van regenwater en verminderen van hittestress en behorende koelvraag,
#   In BWBR0048993: 2.   het transporteren van regenwater naar een infiltratiesysteem of infiltreren van regenwater met geperforeerde leidingen,
#   In BWBR0048993: 3.   het bufferen en infiltreren van regenwater in een wadi,
#   In BWBR0041126: : buitenverlichting, niet zijnde reclameverlichting,
#   In BWBR0041126: : vervangen van bestaande binnenverlichting, dan wel in geval van nieuwbouw aanschaf van binnenverlichting,
#   In BWBR0041126: : verlichting in of bij gebouwen
#   In BWBR0041126: : het koelen of verwarmen van bestaande of nieuw te bouwen van zorgvestigingen door het benutten van koude of warmte in de afzuiglucht,
#   In BWBR0041126: : het verwarmen van bestaande dan wel nieuw te bouwen zorgvestigingen,
#   In BWBR0041126: : het nuttig aanwenden van warmte voor de verwarming van tapwater,
#   In BWBR0041126: : het terugwinnen van warmte uit (douche)water,
#   In BWBR0041126: : (vervanging van) beglazing in buitengevel- of dakconstructies van bestaande zorgvestigingen,
#   In BWBR0041126: : (de verbetering van) de isolatie van bestaande vloeren, daken, plafonds of wanden van ruimten,
#   In BWBR0041126: : het verwarmen van water of lucht,
#   In BWBR0041126: : het opwekken van elektrische energie uit zonlicht met behulp van zonnecellen,
#   In BWBR0041126: : het verwarmen van zorgvestigingen en/of de productie van warm tapwater door verbranding van biomassa,
#   In BWBR0014481: het koelen van levensmiddelen voor huishoudelijk gebruik, met behulp van een koelkast of een koel/vries-combinatie of een vrieskist of vrieskast met een inhoud van 1 m 3 of minder.
#   In BWBR0014481: het koelen van levensmiddelen voor huishoudelijk gebruik, met behulp van een koelkast of een koel/vriescombinatie of een vrieskist of vrieskast met een inhoud van 1 m 3 of minder.
#   In BWBR0014481: het reinigen van kleding en huishoudelijk textiel.
#   In BWBR0014481: het drogen van kleding en huishoudelijk textiel door middel van drooglucht die wordt verwarmd door een elektrische installatie.
#   In BWBR0014481: het drogen van kleding en huishoudelijke textiel door middel van drooglucht die direct wordt verwarmd met gas of indirect wordt verwarmd door een gasgestookte installatie.
#   In BWBR0014481: het isoleren van de begane grondvloer of van de vloer boven een onverwarmde ruimte van een woning of de buitenlucht door middel van het aanbrengen van een isolatielaag aan de onderzijde van de vloer, waarbij de voorziening is aangebracht en geleverd door een derde, zijnde een ondernemer. Bij woningen zonder kruipruimte of een kruipruimte met een hoogte (te meten tussen de onderzijde van de begane grondvloer en de vloer van de kruipruimte) van minder dan 60 cm, is het aanbrengen van vloerisolatie aan de bovenzijde van de begane grondvloer toegestaan mits hiervoor bovenop de isolatielaag harde vloerafwerkingsmaterialen worden toegepast.
#   In BWBR0014481: het isoleren van een woning door middel van het bedekken van de bodem van een kruipruimte met een isolerende laag, waarbij tevens het opgaande werk tot aan de begane grondvloer dient te worden geïsoleerd of door het uitsluitend bedekken van de bodem van de kruipruimte met een isolerende laag, waarbij de voorziening is aangebracht en geleverd door een derde, zijnde een ondernemer.
#   In BWBR0014481: het isoleren van de spouwmuur van een buitengevel, buitengeveldeel of binnenwand grenzend aan een onverwarmde ruimte, waarbij de voorziening is aangebracht en geleverd door een derde, zijnde een ondernemer.
#   In BWBR0014481: het isoleren van de binnen- of buitenzijde van een buitengevel, buitengeveldeel (waaronder begrepen borstweringen en het vervangen van glas door een niet transparante laag) of een binnenwand grenzend aan een onverwarmde ruimte, waarbij de voorziening is aangebracht en geleverd door een derde, zijnde een ondernemer.
#   In BWBR0014481: het isoleren van hetzij een dak hetzij een onverwarmde vliering van een woning, met uitzondering van een plat dak aan de onderzijde of van een schuin dak met UF-schuim onder de dakpannen, waarbij de voorziening is aangebracht en geleverd door een derde, zijnde een ondernemer
#   In BWBR0014481: het realiseren van energiebesparing in een woning, waarbij de voorziening door de aanvrager zelf is aangebracht.
#   In BWBR0014481: het beperken van energieverliezen door ramen van een woning door middel van warmtereflecterend isolerend meervoudig glas, waarbij de voorziening is aangebracht en geleverd door een derde, zijnde een ondernemer.
#   In BWBR0014481: het in een bestaande woning aanpassen van een centraal warmwaterverwarmingssysteem op een zodanige wijze dat de ontwerp-aanvoertemperatuur maximaal 55°C bedraagt, waarbij de voorziening is aangebracht en geleverd of aangepast door een derde, zijnde een ondernemer en waarbij de installatie verzorgd dient te zijn door een overeenkomstig de Vestigingswet gevestigde installateur.
#   In BWBR0014481: het in een bestaande woning toevoegen van vloer- en/of wandverwarming in woonkamer en keuken aan een centraal warmwaterverwarmingssysteem conform 2018, waarbij de voorziening is aangebracht en geleverd door een derde, zijnde een ondernemer en waarbij de installatie verzorgd dient te zijn door een overeenkomstig de Vestigingswet gevestigde installateur.
#   In BWBR0014481: het op uniforme en betrouwbare wijze bepalen van de energetische hoedanigheid en de mogelijke verbetering daarin van een woning.
#   In BWBR0014481: het op uniforme en betrouwbare wijze bepalen van de energetische hoedanigheid en de mogelijke verbetering daarin van een woning, deel uitmakend van een woningblok van 2 tot en met 10 technisch gelijksoortige woningen van dezelfde eigenaar.
#   In BWBR0014481: het op uniforme en betrouwbare wijze bepalen van de energetische hoedanigheid en de mogelijke verbetering daarin van een woning, deel uitmakend van een woningblok van meer dan 10 technisch gelijksoortige woningen van dezelfde eigenaar.
#   In BWBR0014481: het op uniforme en betrouwbare wijze bepalen van de energetische hoedanigheid en de mogelijke verbetering daarin van een woning van de aanvrager, zijnde eigenaar-bewoner
#   In BWBR0014481: het op uniforme en betrouwbare wijze bepalen van de energetische hoedanigheid en de mogelijke verbetering van een vrijstaande woning of van alle grondgebonden zelfstandige wooneenheden (m.n. eengezinswoningen) in de betreffende rij(-en) woningen, van dezelfde eigenaar-verhuurder, zijnde woningverhuurders en -beheerders, of van dezelfde Vereniging van Eigenaren.
#   In BWBR0014481: het op uniforme en betrouwbare wijze bepalen van de energetische hoedanigheid en de mogelijke verbetering daarin van alle woningen in het (de) betreffende woongebouw(-en), die niet onder maatregel 2024 of 2025 vallen, van dezelfde eigenaar-verhuurder, zijnde woningverhuurders en -beheerders, of van dezelfde Vereniging van Eigenaren.
#   In BWBR0014481: het opwekken van elektriciteit op een woning, waarbij de opgewekte elektriciteit direct wordt gebruikt of teruggeleverd aan het openbare elektriciteitsnet.
#   In BWBR0014481: het verwarmen van tapwater voor een woning met behulp van zonlicht, waarbij de zonneboiler is aangebracht en geleverd door een derde, zijnde een ondernemer en waarbij de installatie verzorgd dient te zijn door een overeenkomstig de Vestigingswet gevestigde installateur.
#   In BWBR0014481: het verwarmen van tapwater voor een woning met behulp van zonlicht, waarbij de zonneboiler is aangebracht en geleverd door een derde, zijnde een ondernemer en waarbij de installatie verzorgd dient te zijn door een overeenkomstig de Vestigingswet gevestigde installateur.
#   In BWBR0014481: het verwarmen van tapwater voor een woning met behulp van zonlicht, waarbij de zonneboiler is aangebracht en geleverd door een derde, zijnde een ondernemer en waarbij de installatie verzorgd dient te zijn door een overeenkomstig de Vestigingswet gevestigde installateur.
#   In BWBR0014481: het verwarmen van tapwater voor een woning door middel van een warmtepomp die warmte onttrekt aan ventilatieretourlucht, grondwater, oppervlaktewater, de bodem of buitenlucht, waarbij de warmtepomp is aangebracht en geleverd door een derde, zijnde een ondernemer en waarbij de installatie verzorgd dient te zijn door een overeenkomstig de Vestigingswet gevestigde installateur..
#   In BWBR0014481: het verwarmen van warmtapwater voor meerdere woningen door middel van een warmtepomp die warmte onttrekt aan ventilatieretourlucht, grondwater, oppervlaktewater, bodem of buitenlucht, waarbij de warmtepomp is aangebracht en geleverd door een derde, zijnde een ondernemer en waarbij de installatie verzorgd dient te zijn door een overeenkomstig de Vestigingswet gevestigde installateur.
#   In BWBR0014481: ruimteverwarming van een woning met behulp van omgevingswarmte, waarbij de voorziening is aangebracht en geleverd door een derde, zijnde een ondernemer en waarbij de installatie verzorgd dient te zijn door een overeenkomstig de Vestigingswet gevestigde installateur.
#   In BWBR0014481: ruimteverwarming van meerdere woningen met behulp van omgevingswarmte, waarbij de voorziening is aangebracht en geleverd door een derde, zijnde een ondernemer en waarbij de installatie verzorgd dient te zijn door een overeenkomstig de Vestigingswet gevestigde installateur.
# Bestemd voor
# {'Nieuwe of het vervangen van bestaande sportveldenondervloeren (shockpads) gemaakt van 80% aantoonbaar gerecycled materiaal inclusief terugname verplichting door de leverancier.': 2,
#  'aanwezigheid gestuurde ruimteverwarming door middel van warmtestraling met behulp van infraroodpaneel, voor bijvoorbeeld kleedruimten in bestaande sportaccommodaties,': 2,
#  'afdekken van binnen- en buitenbaden ten doel het warmteverlies via het wateroppervlakte te beperken,': 2,
#  'beglazing in buitengevel- of dakconstructies van bestaande sportaccommodaties,': 2,
#  'beglazing in buitengevel- of dakconstructies van nieuwe sportaccommodaties,': 2,
#  'bestaande en nieuwe kunstgrasvelden ter voorkoming van de verspreiding van microplastics (infill).': 2,
#  'bestaande en nieuwe kunstgrasvelden.': 2,
#  'de opslag van duurzaam opgewekte energie die wordt gebufferd in een zout(water)batterij,': 2,
#  'de verbetering van de isolatie van bestaande vloeren, daken, plafonds of wanden van ruimten,': 2,
#  'een betere schoonloop- en opvangvoorziening van microplastics (infill) bij de in- en uitgang van de kunstgrasvelden ter voorkoming van verspreiding.': 2,
#  'het (realtime) monitoren en visualiseren van het energiegebruik van gas en elektriciteit en eventueel opgewekte energie ten behoeve van verbeterd energiegebruik,': 2,
#  'het bufferen van regenwater en verminderen van hittestress en behorende koelvraag,': 2,
#  'het koelen of verwarmen van bestaande sportaccommodaties door het benutten van koude of warmte in de afzuiglucht,': 2,
#  'het koelen van sportaccommodaties door middel van verdampingskoeling,': 2,
#  'het opvangen van regenwater van tenminste de eigen sportaccommodatie in een waterdichte opslag of waterdicht sportveld met overloop naar een infiltratiegebied niet zijnde een afwatersloot, al dan niet in combinatie met nuttige toepassing van het opgevangen regenwater,': 2,
#  'het opwekken van elektrische energie uit zonlicht met behulp van zonnecellen,': 2,
#  'het terugwinnen van warmte uit (douche)water,': 2,
#  'het verwarmen van sportaccommodaties of het nuttig aanwenden van warmte voor de verwarming van tapwater in sportaccommodaties,': 2,
#  'het verwarmen van tapwater voor een woning met behulp van zonlicht, waarbij de zonneboiler is aangebracht en geleverd door een derde, zijnde een ondernemer en waarbij de installatie verzorgd dient te zijn door een overeenkomstig de Vestigingswet gevestigde installateur.': 3,
#  'het verwarmen van water of lucht,': 3,
#  'het verzamelen van warmte door middel van een collectorsysteem onder sportvelden voor het gebruik van het verwarmen van water of lucht,': 2,
#  'nieuwe sporthalvloeren of vervangen van bestaande sporthalvloeren inclusief terugname verplichting door de leverancier.': 2,
#  'sportveldverlichting,': 2}
