# %% [markdown]
# If you want to start playing with this without installation, try: &nbsp;
# <a href="https://colab.research.google.com/github/WetSuiteLeiden/wetsuite-example-notebooks/blob/main/specific-experiments/split-text/split-experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (only) in colab, run this first to install wetsuite from (the most recent) source.   For your own setup, see wetsuite's install guidelines.
#!pip3 install -U wetsuite

# %% [markdown]
# # Purpose of this notebook
#
# Figure out how to open various formats of documents, and split them into smaller pieces of text.
#
# Probably at a paragraph-like level, and providing document-structural hints where we can --
# while explaining why we can _not_ go as far as guaranteeing anything like te natural structure of a document.
#
#
# Note: this notebook is more about the _development_ of this idea, discussion of the tradeoffs, and such.
# There will be a simpler notebook in wetsuite-notebooks later that gives some examples as to its _use_ on existing datasets
# (and the sources they come from).
#
# This entire notebook may disappear into a short summary later.

# %% [markdown]
# ## Extracting, but also splitting
#
# It is probably useful if this project tries to take each kind of raw document that it
# points to as usable (and/or provides in datasets),
# as well as other kinds you are likely to use.
#
# The combination of opening varied data formats, and splitting them as well,
# seems counter to the 'each piece of code does one thing well' philosophy,
# and in part it is, but other notebooks already address how to dig into specific structures of XML, PDF, and others.

# %% [markdown]
# Here, we address a certain ease.
# There are also varied methods that would benefit from receiving such text into bite-sized chunks,
# and/or for those to be split in a way that is at least _somewhat_ useful.
#
# You might e.g.
# - try to ignore introductory things like "Wij Beatrix, bij de gratie Gods" thing in laws,
#   - because there's a bunch of named enitities there, and few to none of them are even relevant to the law.
#   - seeing that within the text, and knowing we have a chunk of text no larger than a paragraph, makes it easy to ignore.
#
# - up to trying to e.g. find similar court decisions based on some content analysis
#   e.g.
#    - focus on the introduction to extract topic, focus on decision to estimate what was done with that topic,
#    - possibly ignoring discussion/argumentation in the middle
#    - possibly ignoring the definitions (can be a good indicator, but only useful in comparisons if both documents have it)
#
# - split text whenever it seems to be switching to different topic
#
#   - e.g. by tring to figure out what section each paragraph belongs to
#     (whether hinted at by the document or even analysed)
#
# - try tricks like feeding smaller chunks at a time into a "nearby words" type method
#   to see which relations come out most _consistently_ throughout a document.
#   - (you may then care more about the amount of distance and less about the split being natural)
#
# ...meaning an automated way to suggests which parts to ignore and/or what parts are,
# even if crude, could be a start.
#
# If we can, we want to support such approaches, at least a little.

# %% [markdown]
# ### Why we can't go very far in this
#
# For one, goals vary.
#
#  It depends a little on who our userbase is.
# * Legal researchers will often find one topic, one data source
#   - The abovementioned mix issue isn't necessarily a problem, in that documents should be fairly consistent within that
#
# * NLP researchers, on the other hand, will probably just take the "more text is better approach"
#   - The abovementioned may or may not be an issue, because they may care _only_ about having a lot of text,
#     and doing any labeling themselves
#   - but e.g. mixing output from different sources will mean a mix of quality
#
# You can often do somehwat better once you focus on a specific kind of document, source, reseach topic, and such.
#
# <!-- -->
#
# Also, input varies.
#
# Consider that you will expect something sensible for _every_ document.
# Maybe one document (e.g. XML) input you can give very well-labeled sections, citations, vocabulary references for one document type.
# Maybe another (e.g. PDF) gives nothing more than typeset text, and it takes work to guarantee as little as unbroken sentences.
# The common denominator between the two isn't a lot.
#
# Inventing a middle way and wrangling each format into that probably has value,
# yet that kind of creativity, if present at all, should probably be tools in your hands as a researcher,
# should be verifiable and not just trusted, not transparently and quietly decided for you.
#
# <!-- -->
#
# So this notebook is tools and examples for, also to help instill how well, or how poorly, it works on the documents you work on.
#
# Even _the way_ it currently works should be considered just one preliminary way of _maybe_ doing it -- you should treat it as provisionary,
# as a "I'll take out all the bits I need and do it myself (and in the cases it happens to already do what I want, great)":

# %% [markdown]
# <!--
# ## On an implementation level
#
# How we envision this is:
#  * in part about getting text out of different formats - HTML, XML, PDF, possibly document formats
#  * in part about getting small fragments of text out of each, with some supporting information
#  * and let _you_ decide when to join or split those fragments, based on the added information.
#
# We would probably end up with a list of handlers like
#  - if you say you recognize this format
#  - read it yourself and hand out the parts
#  - suggest how to split it
#
#
# The "I recognize this" should probably have a specificity, e.g.
#  - I know this is a PDF, from Officiele Publicaties, and a specific waterschappen-specific template
#  - I know this is a PDF, from Officiele Publicaties
#  - I know this is a PDF, I'll give you ''something''
#
# One reason for this approach is that this can be extended and refined over time.
# -->

# %% [markdown]
# <!--
# This still begs a number of questions
# - how to do that with different input formats?
#   - beyond the "detect type how?" and "open file how?" level, also...
#
# - how granular should the output be? Sections? Paragraphs? Sentences? Blocks that might actually be split at arbitrary points belong together?
#   - it's probably easier to join later than to split later, so smallish is good. Paragraphs?
#
# - can we provide intermediate data that leaves some decisions up to you? It would e.g. be nice if you could use the same  thing to
#   - get sections
#   - get paragraphs
#   - break up the thing to get e.g. ~200 words at a time, almost regardless of structure
#
#
# - how much are users expected to do, how much smartness could be merged in later?
#   - e.g. "hey this header says 1.  and the next one says 2." needs some refinement but can later be quite useful
#   - and does that imply that the meta could also use hints like "hint:[ ('feature', 'new-section'), (probability, 0.7)}"
#
# - can we have any document-type-specific handling? (e.g. remove headers and footers from PDF)
#
# - can we have any document-set-specific handling? (e.g. "kamervraag PDFs use a neat template, we can ease _just_ the text out of it fairly easily")
#   - and have that be extensible, so we can incrementally improve it?
#
# - how much of that is for future prohjects because it really is to omuch now?
#
# - how useful is it to point back to the original?
#   - in XML laws this might be useful. In most others not so much. This might be out of scope, really.
#
#
# Indeed, to provide a relatively universal intermediate document format is a nontrivial exercise even when you care only
# about the _aesthetics_ of the result, let alone when seeming to make any promises about the structure you hand over.
# -->

# %% [markdown]
# ## Some experiments
#
# TODO
# <!--
#
# is a scope of 'how good/bad is it to split here',
# which you can force into smaller and larger chunks via some parameters.
#
#
# What you can expect
# - a stream of (metadata, text)
#
# - a function that handles handles that at somewhat higher level, like
#   - get section-sized things
#   - get paragraph-sized fragments
#   - break up the thing to get e.g. ~200 words at a time, almost regardless of structure
#
# - ...which suggests that the intended length of those text fragments should be on the order of a paragraph (or similar, often-larger unbroken text chunk),
#  - because it's easier to join later than to split later.
#  - if you wantedsentence splitting, you might want to do that in your own post-processing; this seems out of scope for our cruder goals
#
# - metadata will probably
#   - not be things like header, section, paragraph, sentence
#   - be more like "document seems to indicate this is three-deep, and the last header was 'intro'; do with that information what you will"
#
# - for this to always be crude.
#   - Do not expect this to be very structured, unless you can restrict yourself to a document set that is uniform enough document format that the _output_ is  similarly uniform.
#   -->

# %%
import random, pprint, collections, warnings

import wetsuite.helpers.koop_parse
import wetsuite.helpers.localdata
import wetsuite.helpers.etree
import wetsuite.helpers.escape
import wetsuite.helpers.util
import wetsuite.helpers.split
import wetsuite.datasets
import wetsuite.extras.pdf
import wetsuite.helpers.notebook

# %% [markdown]
# # Collect some varied documents
#
# ...primarily to see how many get handled decently

# %%
example_docs = {} # some_indicative_id -> docbytes

if 1: # BWB XML
    bwb  = wetsuite.datasets.load('bwb-mostrecent-xml')
    for bwbid, docbytes in bwb.data.random_sample(100):
        example_docs['xml:'+bwbid] = docbytes

if 1: # CVDR XML
    cvdr = wetsuite.datasets.load('cvdr-mostrecent-xml')
    for cvdrid, docbytes in cvdr.data.random_sample(100):
        example_docs['xml:CVDR'+cvdrid] = docbytes

if 1: # CVDR HTML
    cvdr = wetsuite.datasets.load('cvdr-mostrecent-html')
    for cvdrid, docbytes in cvdr.data.random_sample(100):
        example_docs['html:CVDR'+cvdrid] = docbytes

if 1: # Rechtspraak XML
    rechtspraak_xml = wetsuite.helpers.localdata.LocalKV('rechtspraak_fetched.db', key_type=str, value_type=bytes, read_only=True)
    for rsurl, xmlbytes in rechtspraak_xml.random_sample(100):
        example_docs[rsurl] = xmlbytes
    # TODO:
    #rechtspraak  = wetsuite.datasets.load('rechtspraaknl-xml')
    ##for bwbid, docbytes in bwb.data.random_sample(100):
    ##    example_docs[bwbid] = docbytes
    #rechtspraak.data.random_choice()
    #or maybe cache-fetching the URLs mentioned in rechtspraaknl-struc ?

if 1:
    # these should soon be datasets, but for now are internal collection stores
    bus_data = wetsuite.helpers.localdata.LocalKV( 'bus_data.db', key_type=str, value_type=bytes )

    for path in bus_data.random_keys(2000):
        if 'metadata' in path or 'changelog' in path: # (should filter this out above, actually)
            continue
        if '.xml' in path and random.uniform(0,1) < 0.5: # much of this is xml (data or metadata), try to bring up the HTML and PDF
            continue
        if 'gmb' in path and random.uniform(0,1) < 0.9: # roughly three quarters of this store is gmb, try to balance that a little bit
            continue
        bytedoc = bus_data.get( path )
        example_docs[ 'bus:'+path ] = bytedoc

if 0: # CONSIDER: Woo PDF ?
    pass

if 1: # some cherry-picked PDFs
    example_docs[ 'simple2page' ] = wetsuite.helpers.net.download('https://zoek.officielebekendmakingen.nl/wsb-2022-9718.pdf')
    example_docs[ '2023D51633' ] = wetsuite.helpers.net.download('https://www.tweedekamer.nl/downloads/document?id=2023D51633')
    #example_docs[ 'stb-1952-10' ] = wetsuite.helpers.net.download('https://repository.overheid.nl/frbr/officielepublicaties/stb/1952/stb-1952-10/1/pdf/stb-1952-10.pdf')
    #example_docs[ 'stb-1975-102' ] = wetsuite.helpers.net.download('https://repository.overheid.nl/frbr/officielepublicaties/stb/1975/stb-1975-102/1/pdf/stb-1975-102.pdf')
    example_docs[ '3col' ] = wetsuite.helpers.net.download('https://zoek.officielebekendmakingen.nl/stcrt-1995-28-p9-SC1944.pdf')

# %% [markdown]
# ### See what kind of mix of documents we have

# %%
doc_pairs = list( example_docs.items() )  # list of (some_identifier, document_bytes) pairs

random.shuffle( doc_pairs )
for key, by in doc_pairs[:20]:
    print( '%-70s %s'%(key, by[:60]) )
# Out:
# html:CVDR93572                                                         b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" "ht'
# xml:CVDR690607                                                         b'<?xml version="1.0" encoding="utf-8"?><cvdr xmlns="http://st'
# xml:BWBR0044047                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# bus:/2020/03/10/stcrt/stcrt-2020-14468/stcrt-2020-14468.pdf            b'%PDF-1.4\n%\xe2\xe3\xcf\xd3\n1 0 obj\n<</Type/XObject/DecodeParms<</Predict'
# xml:CVDR364485                                                         b'<?xml version="1.0" encoding="UTF-8"?><cvdr xmlns="http://st'
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RVS:1990:AQ4682 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# xml:CVDR56227                                                          b'<?xml version="1.0" encoding="UTF-8"?><cvdr xmlns="http://st'
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBMID:2010:2951 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# html:CVDR455910                                                        b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" "ht'
# xml:BWBR0014504                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# xml:CVDR5527                                                           b'<?xml version="1.0" encoding="UTF-8"?><cvdr xmlns="http://st'
# bus:/2018/12/19/prb/prb-2018-9479/prb-2018-9479.xml                    b'<officiele-publicatie xmlns:xsi="http://www.w3.org/2001/XMLS'
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHAMS:2016:5579 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# bus:/2023/10/19/gmb/gmb-2023-446503/gmb-2023-446503.html.zip           b"PK\x03\x04\x14\x00\x00\x00\x08\x009ISW\xa4\xea\xa0'\x02\x13\x00\x00+;\x00\x00\x14\x00\x00\x00gmb-2023-446503.html\xb5[in\xe3H\xb2\xfe?\xc0"
# xml:CVDR144602                                                         b'<?xml version="1.0" encoding="utf-8"?><cvdr xsi:schemaLocati'
# html:CVDR271752                                                        b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" "ht'
# simple2page                                                            b'%PDF-1.4\n%\xe2\xe3\xcf\xd3\n1 0 obj\n<</Type/Metadata/Subtype/XML/Length 1'
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHSHE:2011:2105 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# bus:/2023/03/06/gmb/gmb-2023-94861/gmb-2023-94861.html.zip             b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xe1HfV\xac\xdb\xe7_\x95\x19\x00\x00eT\x00\x00\x13\x00\x00\x00gmb-2023-94861.html\xcd\\\xebr\xdb8\x96\xfe?U\xf3'
# html:CVDR387890                                                        b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" "ht'

# %% [markdown]
# ### See what portion gets detected as something known
#
# No output shown yet,
# just seeing how many of the documents we gave it seem to be covered by the parsers/splitters currently registered.

# %%
from importlib import reload
reload(wetsuite.helpers.util)
# Out:
# <module 'wetsuite.helpers.util' from '/usr/local/lib/python3.8/dist-packages/wetsuite/helpers/util.py'>

# %%
count = collections.defaultdict(int)

for someid,docbytes in wetsuite.helpers.notebook.ProgressBar( doc_pairs ):
    options = wetsuite.helpers.split.decide( docbytes )
    if len(options)==0:
        #print( '\n------- %s -------'%someid )
        #print( 'NO PARSER' )        
        count['no-parser-applied'] += 1

    else:
        score, splitter = options[0]
        if score > 100:
            count['only-lowscore'] += 1
            continue

        with warnings.catch_warnings(): # disable warnings for code block
            warnings.simplefilter("ignore")
            text = ' '.join( txt  for _,_,txt in splitter.fragments() )

        if len( text.strip() ) == 0:
            basictype = wetsuite.helpers.util._filetype(docbytes)
            count['no-output-for-%s'%basictype] += 1

            # # Trying to figure out what we may need to add to our parsing
            if basictype=='xml':
                pass
                #    print( f'no output for XML {someid}' )
                #    #print( wetsuite.helpers.etree.fromstring(docbytes).tag ) # print root node name  (to point out this is mostly open-rechtspraak XMLs, which is probably all the ones with just metadata, no text)
            elif basictype=='zip':
                print( f'no output for ZIP {someid}' )
                #import zipfile, io
                #with zipfile.ZipFile(io.BytesIO(docbytes)) as z:
                #    for zipinfo in z.filelist:
                #        print( f'ZIP {repr(someid)} HAS FILE {repr(zipinfo.filename)}',  )
            else:
                print( f'no output for {basictype.upper()} {someid}' )
        else:
            count['has-text-output'] += 1

dict( count )
# Out:
#   0%|          | 0/609 [00:00<?, ?it/s]
# no output for PDF bus:/2020/03/10/stcrt/stcrt-2020-14468/stcrt-2020-14468.pdf
# no output for PDF bus:/2023/01/19/stcrt/stcrt-2023-2932/stcrt-2023-2932.pdf
# no output for PDF bus:/2020/10/08/stcrt/stcrt-2020-52685/stcrt-2020-52685.pdf
# no output for PDF bus:/2020/02/14/stcrt/stcrt-2020-9338/stcrt-2020-9338.pdf
# no output for ZIP bus:/2020/09/16/ah/ah-tk-20202021-0001/ah-tk-20202021-0001.html.zip
# no output for ZIP bus:/2020/12/22/stcrt/stcrt-2020-66577/stcrt-2020-66577.html.zip
# no output for ZIP bus:/2020/01/29/stcrt/stcrt-2020-5633/stcrt-2020-5633.html.zip
# no output for ZIP bus:/2016/09/29/kv/kv-tk-2016Z17663/kv-tk-2016Z17663.html.zip
# no output for PDF bus:/2022/02/09/stcrt/stcrt-2022-4344/stcrt-2022-4344.pdf
# no output for ZIP bus:/2018/06/08/kv/kv-tk-2018Z10847/kv-tk-2018Z10847.html.zip
# no output for PDF bus:/2020/09/11/stcrt/stcrt-2020-47779/stcrt-2020-47779.pdf
# no output for PDF bus:/2023/04/04/stcrt/stcrt-2023-10444/stcrt-2023-10444.pdf
# no output for ZIP bus:/2020/09/22/ah/ah-tk-20202021-3/ah-tk-20202021-3.html.zip
# no output for ZIP bus:/2016/04/25/ah/ah-tk-20152016-2389/ah-tk-20152016-2389.html.zip
# no output for HTML bus:/2014/07/29/stcrt/stcrt-2014-21194/stcrt-2014-21194.html
# no output for PDF bus:/2021/07/08/blg/blg-990986/blg-990986.pdf
# no output for ZIP bus:/2022/05/31/ah/ah-tk-20212022-2902/ah-tk-20212022-2902.html.zip
# no output for ZIP bus:/2015/03/25/stcrt/stcrt-2015-8241/stcrt-2015-8241.html.zip
# no output for PDF bus:/2023/04/05/stcrt/stcrt-2023-10126/stcrt-2023-10126.pdf
# {'has-text-output': 496,
#  'no-output-for-pdf': 9,
#  'no-output-for-xml': 83,
#  'no-parser-applied': 11,
#  'no-output-for-zip': 9,
#  'no-output-for-html': 1}

# %% [markdown]
# ### See what the splitter gives us
#
# Start with just one random one, already split

# %%
# re-run until it gives output -- the no-output ones are likely metadata-only rechtspraak doc (but there are also things we have yet to implement )
key, docbytes = random.choice( doc_pairs )
score, splitter = wetsuite.helpers.split.decide( docbytes )[0] # assumes we'll find one

# SplitDebug formats tuples into tables
display( wetsuite.helpers.split.SplitDebug( splitter.fragments() ) )
# Out:
# /usr/local/lib/python3.8/dist-packages/wetsuite/helpers/koop_parse.py:1107: UserWarning: The behaviour of alineas_with_selective_path() is not fully decided, and may still change
#   warnings.warn(
# <table border="1"><tr><th>meta</th><th>intermediate</th><th>len</th><th>text</th></tr><tr><td style="text-align:left"><pre>{'merged': {},
#  'parts': [],
#  'path': '/officiele-publicatie/staatscourant/circulaire/circulaire-tekst/tekst/al'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;al&gt;Burgemeester en wethouders van U'
#         b'trecht maken, ter voldoening aan het'
#         b' bepaalde in artikel 3.8 lid 4 en ar'
#         b'tikel 3.30 e.v. van de Wet ruimtelij'
#         b'ke ordening en artikel 110c van de W'
#         b'et Geluidhinder jo. afdeling 3.4 van'
#         b' de Algemene wet bestuursrecht beken'
#         b'd dat met ingang van 27&amp;#160;februar'
#         b'i 2014 gedurende zes weken ter inzag'
#         b'e ligt:&lt;/al&gt;\n               ',
#  'raw_etree': &lt;Element al at 0x7f548c21f180&gt;,
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">323</td><td style="text-align:left">'Burgemeester en wethouders van Utrecht maken, ter voldoening aan het bepaalde in artikel 3.8 lid 4 en artikel 3.30 e.v. van de Wet ruimtelijke ordening en artikel 110c van de Wet Geluidhinder jo. afdeling 3.4 van de Algemene wet bestuursrecht bekend dat met ingang van 27\xa0februari 2014 gedurende zes weken ter inzage ligt: '</td></tr><tr><td style="text-align:left"><pre>{'merged': {'li-nr': None,
#             'li.nr': '•',
#             'li_vd': None},
#  'parts': [{'what': 'lijst'},
#            {'li-nr': None,
#             'li.nr': '•',
#             'li_vd': None,
#             'what': 'li'}],
#  'path': '/officiele-publicatie/staatscourant/circulaire/circulaire-tekst/tekst/lijst/li[1]/al'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;al&gt;Het op 13&amp;#160;februari 2014 doo'
#         b'r de raad vastgestelde bestemmingspl'
#         b"an 'Hotel- en kantoorontwikkeling Wi"
#         b"nthontlaan 4-6', Merwedekanaalzone' "
#         b'als vervat in GML-bestand &lt;extref do'
#         b'c="http://www.ruimtelijkeplannen.nl/'
#         b'web-roo/?planidn=NL.IMRO.0344.BPHOTE'
#         b'LKANTOORKAN-VA01" soort="URL" status'
#         b'="actief"&gt;NL.IMRO.0344.BPHOTELKANTOO'
#         b'RKAN-VA01&lt;/extref&gt; en het daarbij be'
#         b'horende vaststellingsbesluit;&lt;/al&gt;\n '
#         b'                 ',
#  'raw_etree': &lt;Element al at 0x7f548c21dd00&gt;,
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">244</td><td style="text-align:left">"Het op 13\xa0februari 2014 door de raad vastgestelde bestemmingsplan 'Hotel- en kantoorontwikkeling Winthontlaan 4-6', Merwedekanaalzone' als vervat in GML-bestand  NL.IMRO.0344.BPHOTELKANTOORKAN-VA01 en het daarbij behorende vaststellingsbesluit;"</td></tr><tr><td style="text-align:left"><pre>{'merged': {'li-nr': None,
#             'li.nr': '•',
#             'li_vd': None},
#  'parts': [{'what': 'lijst'},
#            {'li-nr': None,
#             'li.nr': '•',
#             'li_vd': None,
#             'what': 'li'}],
#  'path': '/officiele-publicatie/staatscourant/circulaire/circulaire-tekst/tekst/lijst/li[2]/al'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;al&gt;De omgevingsvergunning (HZ_WABO-'
#         b'13-01705) voor het bouwen van een ho'
#         b'tel met congresruimte, kantoren, ove'
#         b'rige functies en parkeergarages, het'
#         b' aanbrengen van reclame en het maken'
#         b' van een in/uitrit;&lt;/al&gt;\n           '
#         b'       ',
#  'raw_etree': &lt;Element al at 0x7f548eda2a00&gt;,
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">196</td><td style="text-align:left">'De omgevingsvergunning (HZ_WABO-13-01705) voor het bouwen van een hotel met congresruimte, kantoren, overige functies en parkeergarages, het aanbrengen van reclame en het maken van een in/uitrit; '</td></tr><tr><td style="text-align:left"><pre>{'merged': {'li-nr': None,
#             'li.nr': '•',
#             'li_vd': None},
#  'parts': [{'what': 'lijst'},
#            {'li-nr': None,
#             'li.nr': '•',
#             'li_vd': None,
#             'what': 'li'}],
#  'path': '/officiele-publicatie/staatscourant/circulaire/circulaire-tekst/tekst/lijst/li[3]/al'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;al&gt;het besluit (HW 1071) tot vastst'
#         b'elling van hogere waarden voor de te'
#         b'n hoogst toelaatbare geluidsbelastin'
#         b'g ingevolge hoofdstuk 3 Besluit gelu'
#         b'idhinder.&lt;/al&gt;\n                  ',
#  'raw_etree': &lt;Element al at 0x7f548c1fea40&gt;,
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">150</td><td style="text-align:left">'het besluit (HW 1071) tot vaststelling van hogere waarden voor de ten hoogst toelaatbare geluidsbelasting ingevolge hoofdstuk 3 Besluit geluidhinder. '</td></tr><tr><td style="text-align:left"><pre>{'merged': {'circulairedivisie_vd': None},
#  'parts': [{'circulairedivisie_vd': None,
#             'what': 'circulaire.divisie'}],
#  'path': '/officiele-publicatie/staatscourant/circulaire/circulaire-tekst/circulaire.divisie[1]/tekst/al'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;al&gt;Het plangebied wordt globaal beg'
#         b'rensd door de A12, de Europalaan, de'
#         b' Winthontlaan en het Merwedekanaal. '
#         b'Het doel van het bestemmingsplan is '
#         b'het planologisch mogelijk maken van '
#         b'een hotel, een kantoor en aanvullend'
#         b'e functies op het perceel Winthontla'
#         b'an 4-6.&lt;/al&gt;\n               ',
#  'raw_etree': &lt;Element al at 0x7f548c21f4c0&gt;,
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">256</td><td style="text-align:left">'Het plangebied wordt globaal begrensd door de A12, de Europalaan, de Winthontlaan en het Merwedekanaal. Het doel van het bestemmingsplan is het planologisch mogelijk maken van een hotel, een kantoor en aanvullende functies op het perceel Winthontlaan 4-6. '</td></tr><tr><td style="text-align:left"><pre>{'merged': {'circulairedivisie_vd': None},
#  'parts': [{'circulairedivisie_vd': None,
#             'what': 'circulaire.divisie'}],
#  'path': '/officiele-publicatie/staatscourant/circulaire/circulaire-tekst/circulaire.divisie[2]/tekst/al'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;al&gt;Artikel 3.30 e.v. van de Wet rui'
#         b'mtelijke ordening en de Co&amp;#246;rdin'
#         b'atieverordening maken het mogelijk d'
#         b'at diverse procedures gezamenlijk wo'
#         b'rden doorlopen. Dat wil zeggen dat d'
#         b'e voorbereiding en bekendmaking van '
#         b'verschillende besluiten tegelijk wor'
#         b'den behandeld. De aanvrager heeft ve'
#         b'rzocht om op grond van de co&amp;#246;rd'
#         b'inatieverordening naast het verzoek '
#         b'om wijziging van het bestemmingsplan'
#         b' ook het bovenstaande aanverwante be'
#         b'sluiten geco&amp;#246;rdineerd te behand'
#         b'elen.&lt;/al&gt;\n               ',
#  'raw_etree': &lt;Element al at 0x7f548a2448c0&gt;,
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">455</td><td style="text-align:left">'Artikel 3.30 e.v. van de Wet ruimtelijke ordening en de Coördinatieverordening maken het mogelijk dat diverse procedures gezamenlijk worden doorlopen. Dat wil zeggen dat de voorbereiding en bekendmaking van verschillende besluiten tegelijk worden behandeld. De aanvrager heeft verzocht om op grond van de coördinatieverordening naast het verzoek om wijziging van het bestemmingsplan ook het bovenstaande aanverwante besluiten gecoördineerd te behandelen. '</td></tr><tr><td style="text-align:left"><pre>{'merged': {'circulairedivisie_vd': None},
#  'parts': [{'circulairedivisie_vd': None,
#             'what': 'circulaire.divisie'}],
#  'path': '/officiele-publicatie/staatscourant/circulaire/circulaire-tekst/circulaire.divisie[3]/tekst/al[1]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;al&gt;Het bestemmingsplan, de omgeving'
#         b'svergunning en het besluit hogere wa'
#         b'arden liggen met ingang van 27&amp;#160;'
#         b'februari 2014 gedurende zes weken, d'
#         b'us tot en met 9&amp;#160;april 2014 ter '
#         b'inzage.&lt;/al&gt;

# %% [markdown]
# Give a summary of all the stuff we just selected:

# %%
for key, docbytes in doc_pairs:
    if 'metadata' in key: # we care about documents; skip metadata-only, in case the above accidentally filtered them in
        continue

    thresh = 1500
    splitters = wetsuite.helpers.split.decide(docbytes, thresh=thresh)
    if len(splitters)==0:
        print( 'WARN for  %-30s - no splitter says it applies  (under threshold %s)'%(key, thresh) )
        # "stop on the first problem case and display it so we can add it" style logic:
        #if b'<html' in docbytes:
        #    display( wetsuite.helpers.etree.debug_color(docbytes) )
        #    break
        continue
    
    for score, fragproc in splitters: # use each processor that said they would be useful
        with warnings.catch_warnings(): # temporarily disable warnings
            warnings.simplefilter("ignore")
            frags = fragproc.fragments()
        if len(frags) == 0:
            print( f'WARN for  {key[:50]:^50s} - no output from splitter {type(fragproc).__name__}' )
            #if 'html.zip' in key:
            #    print(wetsuite.helpers.util.get_ziphtml(docbytes))
            #    print( fragproc.soup )
        else:
            textlen = sum(  list(len(fragtext)  for _,_,fragtext in frags))
            if textlen < 100:
                print( f'WARN for  {key[:50]:^50s} - {type(fragproc).__name__} gave {textlen} chars of text' )
            else:
                print( f'INFO for  {key[:50]:^50s} - {type(fragproc).__name__} gave {textlen} chars of text' )

            #for o1,o2,o3 in frags:
            #    print( type(o2) )

            if 0: # you may want to disable this print-everything when doing "are we missing anything" debug because it is a _lot_ of output
                #display( wetsuite.helpers.etree.debug_color(docbytes) )
                display( wetsuite.helpers.split.SplitDebug( frags ) )
                break
    #else:
    #    break

    #break
# Out:
# INFO for                    html:CVDR93572                   - Fragments_HTML_CVDR gave 300002 chars of text
# INFO for                    xml:CVDR690607                   - Fragments_XML_CVDR gave 5529 chars of text
# INFO for                   xml:BWBR0044047                   - Fragments_XML_BWB gave 14316 chars of text
# WARN for  bus:/2020/03/10/stcrt/stcrt-2020-14468/stcrt-2020- - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                    xml:CVDR364485                   - Fragments_XML_CVDR gave 1278 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR56227                    - Fragments_XML_CVDR gave 20340 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR455910                   - Fragments_HTML_CVDR gave 126034 chars of text
# INFO for                   xml:BWBR0014504                   - Fragments_XML_BWB gave 2384 chars of text
# INFO for                     xml:CVDR5527                    - Fragments_XML_CVDR gave 102060 chars of text
# INFO for  bus:/2018/12/19/prb/prb-2018-9479/prb-2018-9479.xm - Fragments_XML_OP_Prb gave 983 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id= - Fragments_XML_Rechtspraak gave 13477 chars of text
# INFO for  bus:/2023/10/19/gmb/gmb-2023-446503/gmb-2023-44650 - Fragments_HTML_OP_Gmb gave 3529 chars of text
# INFO for                    xml:CVDR144602                   - Fragments_XML_CVDR gave 1427 chars of text
# INFO for                   html:CVDR271752                   - Fragments_HTML_CVDR gave 198886 chars of text
# INFO for                     simple2page                     - Fragments_PDF_Fallback gave 4339 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2023/03/06/gmb/gmb-2023-94861/gmb-2023-94861. - Fragments_HTML_OP_Gmb gave 40154 chars of text
# INFO for                   html:CVDR387890                   - Fragments_HTML_CVDR gave 8623 chars of text
# INFO for                    html:CVDR30031                   - Fragments_HTML_CVDR gave 49257 chars of text
# INFO for  bus:/2017/08/03/gmb/gmb-2017-135596/gmb-2017-13559 - Fragments_HTML_OP_Gmb gave 13034 chars of text
# INFO for  bus:/2016/09/28/gmb/gmb-2016-131886/gmb-2016-13188 - Fragments_HTML_OP_Gmb gave 10102 chars of text
# INFO for                   xml:BWBR0048528                   - Fragments_XML_BWB gave 56375 chars of text
# INFO for  bus:/2013/06/20/kst/kst-22026-411/kst-22026-411.xm - Fragments_XML_BUS_Kamer gave 544 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2014/10/13/kst/kst-32855-23/kst-32855-23.xml  - Fragments_XML_BUS_Kamer gave 892 chars of text
# INFO for                   xml:BWBR0023392                   - Fragments_XML_BWB gave 631 chars of text
# INFO for  bus:/2019/09/17/h/h-tk-20182019-99-3-n1/h-tk-20182 - Fragments_XML_OP_Handelingen gave 336 chars of text
# INFO for                   xml:BWBR0042024                   - Fragments_XML_BWB gave 24226 chars of text
# INFO for                   html:CVDR692179                   - Fragments_HTML_CVDR gave 40186 chars of text
# INFO for  bus:/2020/02/12/prb/prb-2020-778/prb-2020-778.xml  - Fragments_XML_OP_Prb gave 749 chars of text
# INFO for                   xml:BWBR0008428                   - Fragments_XML_BWB gave 278 chars of text
# INFO for                   xml:BWBR0014153                   - Fragments_XML_BWB gave 18683 chars of text
# INFO for                   xml:BWBR0040352                   - Fragments_XML_BWB gave 11792 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id= - Fragments_XML_Rechtspraak gave 8480 chars of text
# INFO for                    xml:CVDR55917                    - Fragments_XML_CVDR gave 5753 chars of text
# INFO for  bus:/2020/02/20/wsb/wsb-2020-1708/wsb-2020-1708.xm - Fragments_XML_OP_Wsb gave 388 chars of text
# INFO for                   xml:BWBR0014640                   - Fragments_XML_BWB gave 1868 chars of text
# INFO for                    xml:CVDR491932                   - Fragments_XML_CVDR gave 9029 chars of text
# INFO for                   html:CVDR376354                   - Fragments_HTML_CVDR gave 1963415 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id= - Fragments_XML_Rechtspraak gave 11042 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0042783                   - Fragments_XML_BWB gave 848 chars of text
# INFO for  bus:/2017/05/15/gmb/gmb-2017-77354/gmb-2017-77354. - Fragments_XML_OP_Gmb gave 1331 chars of text
# INFO for                    xml:CVDR648634                   - Fragments_XML_CVDR gave 793 chars of text
# INFO for                    xml:CVDR62287                    - Fragments_XML_CVDR gave 5937 chars of text
# INFO for  bus:/2023/02/10/kst/kst-32317-811/kst-32317-811.ht - Fragments_HTML_BUS_kamer gave 891 chars of text
# INFO for                   xml:BWBR0048236                   - Fragments_XML_BWB gave 8452 chars of text
# INFO for                   html:CVDR375989                   - Fragments_HTML_CVDR gave 114022 chars of text
# INFO for                    html:CVDR72099                   - Fragments_HTML_CVDR gave 965347 chars of text
# INFO for                    xml:CVDR54355                    - Fragments_XML_CVDR gave 7370 chars of text
# INFO for  bus:/2022/01/10/wsb/wsb-2022-239/wsb-2022-239.html - Fragments_HTML_OP_Wsb gave 5758 chars of text
# INFO for                   html:CVDR377496                   - Fragments_HTML_CVDR gave 315378 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2010/05/31/stcrt/stcrt-2010-8028/stcrt-2010-8 - Fragments_XML_OP_Stcrt gave 1676 chars of text
# INFO for  bus:/2019/01/23/gmb/gmb-2019-15253/gmb-2019-15253. - Fragments_HTML_OP_Gmb gave 19287 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0046368                   - Fragments_XML_BWB gave 16421 chars of text
# INFO for  bus:/2021/02/25/gmb/gmb-2021-58714/gmb-2021-58714. - Fragments_XML_OP_Gmb gave 1933 chars of text
# INFO for                   xml:BWBR0014899                   - Fragments_XML_BWB gave 2934 chars of text
# INFO for  bus:/2023/06/13/gmb/gmb-2023-256387/gmb-2023-25638 - Fragments_XML_OP_Gmb gave 354 chars of text
# INFO for                   xml:BWBR0020710                   - Fragments_XML_BWB gave 847 chars of text
# INFO for                   html:CVDR660144                   - Fragments_HTML_CVDR gave 512903 chars of text
# INFO for  bus:/2016/04/13/stcrt/stcrt-2016-17179/stcrt-2016- - Fragments_XML_OP_Stcrt gave 3697 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# WARN for  bus:/2023/01/19/stcrt/stcrt-2023-2932/stcrt-2023-2 - Fragments_PDF_Fallback gave 0 chars of text
# INFO for  bus:/2018/08/01/stcrt/stcrt-2018-43642/stcrt-2018- - Fragments_HTML_OP_Stcrt gave 30855 chars of text
# INFO for                    xml:CVDR676673                   - Fragments_XML_CVDR gave 12767 chars of text
# INFO for  bus:/1995/10/30/ah/ah-tk-19951996-132/ah-tk-199519 - Fragments_XML_BUS_Kamer gave 1683 chars of text
# INFO for  bus:/2021/07/23/gmb/gmb-2021-244152/gmb-2021-24415 - Fragments_HTML_OP_Gmb gave 27256 chars of text
# INFO for                   html:CVDR647214                   - Fragments_HTML_CVDR gave 292561 chars of text
# INFO for                   xml:BWBR0007133                   - Fragments_XML_BWB gave 32762 chars of text
# INFO for  bus:/2022/02/15/gmb/gmb-2022-63577/gmb-2022-63577. - Fragments_HTML_OP_Gmb gave 4697 chars of text
# INFO for                   html:CVDR403854                   - Fragments_HTML_CVDR gave 483509 chars of text
# INFO for  bus:/2007/02/13/h/h-tk-20062007-2359-2369/h-tk-200 - Fragments_XML_OP_Handelingen gave 56272 chars of text
# INFO for                   xml:BWBR0048554                   - Fragments_XML_BWB gave 3578 chars of text
# INFO for                    xml:CVDR57886                    - Fragments_XML_CVDR gave 19258 chars of text
# INFO for                   html:CVDR631887                   - Fragments_HTML_CVDR gave 45756 chars of text
# INFO for                    html:CVDR77533                   - Fragments_HTML_CVDR gave 20850 chars of text
# INFO for  bus:/2024/05/02/kst/kst-32429-29/kst-32429-29.xml  - Fragments_XML_BUS_Kamer gave 15021 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0039875                   - Fragments_XML_BWB gave 25766 chars of text
# INFO for  bus:/2019/07/25/stcrt/stcrt-2019-41519/stcrt-2019- - Fragments_XML_OP_Stcrt gave 4094 chars of text
# WARN for  bus:/2018/12/19/h/h-tk-20182019-27-6/h-tk-20182019-27-6.html.zip - no splitter says it applies  (under threshold 1500)
# INFO for  bus:/2018/02/23/stcrt/stcrt-2018-9038/stcrt-2018-9 - Fragments_XML_OP_Stcrt gave 2835 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0003868                   - Fragments_XML_BWB gave 3908 chars of text
# INFO for                    xml:CVDR447731                   - Fragments_XML_CVDR gave 25116 chars of text
# INFO for                   html:CVDR124110                   - Fragments_HTML_CVDR gave 24945 chars of text
# INFO for  bus:/2017/11/14/kst/kst-34765-18/kst-34765-18.html - Fragments_HTML_BUS_kamer gave 10138 chars of text
# INFO for   bus:/1996/03/15/trb/trb-1996-84/trb-1996-84.xml   - Fragments_XML_OP_Trb gave 1822 chars of text
# INFO for                   html:CVDR175557                   - Fragments_HTML_CVDR gave 43238 chars of text
# INFO for                   xml:BWBR0011334                   - Fragments_XML_BWB gave 5106 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR249613                   - Fragments_XML_CVDR gave 9658 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0029682                   - Fragments_XML_BWB gave 8438 chars of text
# INFO for                    xml:CVDR399661                   - Fragments_XML_CVDR gave 10950 chars of text
# INFO for     bus:/2009/09/04/blg/blg-29958/blg-29958.pdf     - Fragments_PDF_Fallback gave 204608 chars of text
# INFO for                     xml:CVDR830                     - Fragments_XML_CVDR gave 2367 chars of text
# INFO for                   xml:BWBR0021853                   - Fragments_XML_BWB gave 713 chars of text
# INFO for                   xml:BWBR0009393                   - Fragments_XML_BWB gave 1449 chars of text
# INFO for                   xml:BWBR0024805                   - Fragments_XML_BWB gave 1432 chars of text
# INFO for                    xml:CVDR299085                   - Fragments_XML_CVDR gave 6962 chars of text
# INFO for  bus:/2023/01/13/gmb/gmb-2023-14994/gmb-2023-14994. - Fragments_HTML_OP_Gmb gave 7106 chars of text
# INFO for  bus:/2019/01/10/stcrt/stcrt-2019-1456/stcrt-2019-1 - Fragments_HTML_OP_Stcrt gave 131565 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR238775                   - Fragments_XML_CVDR gave 27267 chars of text
# INFO for                   xml:BWBR0029247                   - Fragments_XML_BWB gave 33319 chars of text
# INFO for  bus:/2020/09/23/stcrt/stcrt-2020-49642/stcrt-2020- - Fragments_HTML_OP_Stcrt gave 16151 chars of text
# INFO for  bus:/2019/09/06/gmb/gmb-2019-218937/gmb-2019-21893 - Fragments_XML_OP_Gmb gave 962 chars of text
# INFO for                    xml:CVDR88642                    - Fragments_XML_CVDR gave 106485 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# WARN for  bus:/2009/05/04/kst/kst-28345-86/kst-28345-86.html.zip - no splitter says it applies  (under threshold 1500)
# INFO for  bus:/2024/04/02/stcrt/stcrt-2024-11256/stcrt-2024- - Fragments_XML_OP_Stcrt gave 1115 chars of text
# INFO for  bus:/2016/03/23/prb/prb-2016-1650/prb-2016-1650.xm - Fragments_XML_OP_Prb gave 1073 chars of text
# INFO for                    xml:CVDR99133                    - Fragments_XML_CVDR gave 11692 chars of text
# WARN for  bus:/2020/08/12/h/h-tk-20192020-91-101/h-tk-20192020-91-101.html.zip - no splitter says it applies  (under threshold 1500)
# INFO for  bus:/2016/09/21/gmb/gmb-2016-129264/gmb-2016-12926 - Fragments_HTML_OP_Gmb gave 24021 chars of text
# INFO for  bus:/2024/01/03/gmb/gmb-2024-1232/gmb-2024-1232.ht - Fragments_HTML_OP_Gmb gave 88260 chars of text
# INFO for                    xml:CVDR346375                   - Fragments_XML_CVDR gave 9060 chars of text
# INFO for   bus:/2004/03/16/kst/kst-29468-1/kst-29468-1.xml   - Fragments_XML_BUS_Kamer gave 473 chars of text
# INFO for                    xml:CVDR393750                   - Fragments_XML_CVDR gave 89748 chars of text
# INFO for  bus:/2022/02/03/kst/kst-31935-75/kst-31935-75.html - Fragments_HTML_BUS_kamer gave 1402 chars of text
# INFO for                   xml:BWBR0009438                   - Fragments_XML_BWB gave 6813 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2022/12/07/gmb/gmb-2022-535608/gmb-2022-53560 - Fragments_HTML_OP_Gmb gave 96897 chars of text
# INFO for                    html:CVDR73989                   - Fragments_HTML_CVDR gave 499725 chars of text
# INFO for  bus:/2021/07/08/wsb/wsb-2021-8446/wsb-2021-8446.ht - Fragments_HTML_OP_Wsb gave 5761 chars of text
# INFO for  bus:/2022/09/16/kst/kst-35824-19/kst-35824-19.xml  - Fragments_XML_BUS_Kamer gave 722 chars of text
# INFO for                   xml:BWBR0038600                   - Fragments_XML_BWB gave 5019 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR80094                    - Fragments_XML_CVDR gave 30162 chars of text
# INFO for                     xml:CVDR6898                    - Fragments_XML_CVDR gave 1155 chars of text
# INFO for  bus:/2022/01/18/kst/kst-35925-XIX-8/kst-35925-XIX- - Fragments_XML_BUS_Kamer gave 12340 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR675793                   - Fragments_HTML_CVDR gave 939931 chars of text
# INFO for  bus:/2021/10/28/kst/kst-32813-877/kst-32813-877.ht - Fragments_HTML_BUS_kamer gave 701 chars of text
# INFO for                   html:CVDR621853                   - Fragments_HTML_CVDR gave 285087 chars of text
# INFO for                    xml:CVDR43512                    - Fragments_XML_CVDR gave 70699 chars of text
# INFO for                   html:CVDR391830                   - Fragments_HTML_CVDR gave 42279 chars of text
# INFO for                   xml:BWBR0006678                   - Fragments_XML_BWB gave 1232 chars of text
# INFO for                   html:CVDR350854                   - Fragments_HTML_CVDR gave 64743 chars of text
# INFO for                   html:CVDR428382                   - Fragments_HTML_CVDR gave 953165 chars of text
# WARN for  bus:/2020/10/08/stcrt/stcrt-2020-52685/stcrt-2020- - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                   xml:BWBR0018601                   - Fragments_XML_BWB gave 969 chars of text
# INFO for                    xml:CVDR69675                    - Fragments_XML_CVDR gave 14297 chars of text
# INFO for  bus:/2022/09/20/gmb/gmb-2022-421243/gmb-2022-42124 - Fragments_HTML_OP_Gmb gave 23223 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id= - Fragments_XML_Rechtspraak gave 10450 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# WARN for  bus:/2015/07/10/h/h-ek-20142015-36-9/h-ek-20142015-36-9.html.zip - no splitter says it applies  (under threshold 1500)
# INFO for  bus:/2019/01/28/prb/prb-2019-618/prb-2019-618.html - Fragments_HTML_OP_Prb gave 24769 chars of text
# WARN for  bus:/2007/11/14/kst/kst-31200-XVI-21/kst-31200-XVI-21.html.zip - no splitter says it applies  (under threshold 1500)
# INFO for                    xml:CVDR605309                   - Fragments_XML_CVDR gave 4011 chars of text
# INFO for                   xml:BWBR0016204                   - Fragments_XML_BWB gave 21331 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR311006                   - Fragments_HTML_CVDR gave 81060 chars of text
# INFO for                   html:CVDR660251                   - Fragments_HTML_CVDR gave 1249267 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id= - Fragments_XML_Rechtspraak gave 13799 chars of text
# INFO for  bus:/2000/10/18/kst/kst-27400-XV-11/kst-27400-XV-1 - Fragments_XML_BUS_Kamer gave 35582 chars of text
# INFO for                   xml:BWBR0045673                   - Fragments_XML_BWB gave 21549 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id= - Fragments_XML_Rechtspraak gave 4496 chars of text
# INFO for  bus:/2019/04/16/wsb/wsb-2019-4221/wsb-2019-4221.ht - Fragments_HTML_OP_Wsb gave 21339 chars of text
# INFO for  bus:/2022/01/11/gmb/gmb-2022-10998/gmb-2022-10998. - Fragments_XML_OP_Gmb gave 7762 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id= - Fragments_XML_Rechtspraak gave 11400 chars of text
# INFO for                    xml:CVDR57682                    - Fragments_XML_CVDR gave 3475 chars of text
# INFO for                   xml:BWBR0032661                   - Fragments_XML_BWB gave 2904 chars of text
# INFO for                    xml:CVDR602507                   - Fragments_XML_CVDR gave 20989 chars of text
# INFO for                   xml:BWBR0018591                   - Fragments_XML_BWB gave 1697 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for   bus:/2023/05/04/blg/blg-1089769/blg-1089769.pdf   - Fragments_PDF_Fallback gave 5176 chars of text
# INFO for                    html:CVDR81703                   - Fragments_HTML_CVDR gave 80386 chars of text
# INFO for                   html:CVDR175460                   - Fragments_HTML_CVDR gave 176700 chars of text
# INFO for                    xml:CVDR603988                   - Fragments_XML_CVDR gave 3601 chars of text
# INFO for  bus:/2021/03/01/stcrt/stcrt-2021-10814/stcrt-2021- - Fragments_XML_OP_Stcrt gave 4953 chars of text
# INFO for                   html:CVDR684369                   - Fragments_HTML_CVDR gave 193769 chars of text
# INFO for                   xml:BWBR0008903                   - Fragments_XML_BWB gave 16063 chars of text
# INFO for                   html:CVDR101861                   - Fragments_HTML_CVDR gave 36045 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0025582                   - Fragments_XML_BWB gave 706 chars of text
# INFO for                   xml:BWBR0042170                   - Fragments_XML_BWB gave 10354 chars of text
# INFO for                         3col                        - Fragments_PDF_Fallback gave 6783 chars of text
# WARN for  bus:/2020/02/14/stcrt/stcrt-2020-9338/stcrt-2020-9 - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                    xml:CVDR698313                   - Fragments_XML_CVDR gave 1019 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR714258                   - Fragments_HTML_CVDR gave 471128 chars of text
# INFO for  bus:/2022/02/08/kst/kst-29240-123/kst-29240-123.xm - Fragments_XML_BUS_Kamer gave 3417 chars of text
# INFO for  bus:/2018/06/07/kst/kst-28089-88/kst-28089-88.html - Fragments_HTML_BUS_kamer gave 42045 chars of text
# INFO for                   xml:BWBR0039391                   - Fragments_XML_BWB gave 37816 chars of text
# WARN for  bus:/2004/12/28/kst/kst-26956-27-b2/kst-26956-27-b2.xml - no splitter says it applies  (under threshold 1500)
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id= - Fragments_XML_Rechtspraak gave 13400 chars of text
# INFO for    bus:/2020/07/01/blg/blg-938529/blg-938529.pdf    - Fragments_PDF_Fallback gave 79956 chars of text
# INFO for                   xml:BWBR0044185                   - Fragments_XML_BWB gave 5905 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR299833                   - Fragments_XML_CVDR gave 21740 chars of text
# INFO for                   html:CVDR631077                   - Fragments_HTML_CVDR gave 16422 chars of text
# INFO for  bus:/2012/09/05/stcrt/stcrt-2012-18279/stcrt-2012- - Fragments_XML_OP_Stcrt gave 2716 chars of text
# INFO for  bus:/2009/11/27/kst/kst-32222-IIA-1/kst-32222-IIA- - Fragments_XML_BUS_Kamer gave 1569 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id= - Fragments_XML_Rechtspraak gave 10049 chars of text
# INFO for                    xml:CVDR670154                   - Fragments_XML_CVDR gave 14288 chars of text
# INFO for                    xml:CVDR91558                    - Fragments_XML_CVDR gave 8428 chars of text
# INFO for  bus:/2012/02/29/h/h-tk-20112012-24-4/h-tk-20112012 - Fragments_XML_OP_Handelingen gave 104883 chars of text
# INFO for  bus:/2017/05/08/gmb/gmb-2017-76548/gmb-2017-76548. - Fragments_HTML_OP_Gmb gave 300706 chars of text
# INFO for                     xml:CVDR5589                    - Fragments_XML_CVDR gave 1889 chars of text
# WARN for  bus:/2020/09/16/ah/ah-tk-20202021-0001/ah-tk-20202 - no output from splitter Fragments_HTML_BUS_kamer
# INFO for  bus:/2019/06/07/kst/kst-35200-24/kst-35200-24.xml  - Fragments_XML_BUS_Kamer gave 566 chars of text
# INFO for                    html:CVDR86113                   - Fragments_HTML_CVDR gave 96394 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR249041                   - Fragments_HTML_CVDR gave 23657 chars of text
# INFO for  bus:/2019/10/07/kst/kst-35050-39/kst-35050-39.html - Fragments_HTML_BUS_kamer gave 809 chars of text
# INFO for                    xml:CVDR71593                    - Fragments_XML_CVDR gave 64943 chars of text
# INFO for                    html:CVDR39850                   - Fragments_HTML_CVDR gave 7781 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0044530                   - Fragments_XML_BWB gave 1111 chars of text
# INFO for  bus:/2003/09/23/stcrt/stcrt-2003-183-p10-SC61214/s - Fragments_XML_OP_Stcrt gave 15891 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id= - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR632035                   - Fragments_XML_CVDR gave 11849 chars of text
# INFO for                   html:CVDR144811                   - Fragments_HTML_CVDR gave 2053 chars of text
# INFO for  bus:/2020/12/31/gmb/gmb-2020-348549/gmb-2020-34854 - Fragments_HTML_OP_Gmb gave 5476 chars of text
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
#       3     continue
#       5 thresh = 1500
# ----> 6 splitters = wetsuite.helpers.split.decide(docbytes, thresh=thresh)
#       7 if len(splitters)==0:
#       8     print( 'WARN for  %-30s - no splitter says it applies  (under threshold %s)'%(key, thresh) )
#
# File /usr/local/lib/python3.8/dist-packages/wetsuite/helpers/split.py:1446, in decide(docbytes, thresh, first_only, debug)
#    1443 processing_object = PerhapsClass(docbytes, debug=debug)
#    1444 if processing_object.accepts():  # does it say it's getting the right file type?
#    1445     score = (
# -> 1446         processing_object.suitableness()
#    1447     )  # how well does it figure it would treat this?
#    1448     if score < thresh:
#    1449         options.append([score, processing_object])
#
# File /usr/local/lib/python3.8/dist-packages/wetsuite/helpers/split.py:500, in Fragments_HTML_OP_Trb.suitableness(self)
#     498     warnings.simplefilter("ignore")
#     499     self.soup = bs4.BeautifulSoup(self.docbytes, features="lxml")
# --> 500 pname = self.soup.find("meta", attrs={"name": "OVERHEIDop.publicationName"})
#     501 if pname is not None and pname.get("content") == "Tractatenblad":
#     502     return 5
#
# File /usr/local/lib/python3.8/dist-packages/bs4/element.py:2006, in Tag.find(self, name, attrs, recursive, string, **kwargs)
#    1989 """Look in the children of this PageElement and find the first
#    1990 PageElement that matches the given criteria.
#    1991
#    (...)
#    2003 :rtype: bs4.element.Tag | bs4.element.NavigableString
#    2004 """
#    2005 r = None
# -> 2006 l = self.find_all(name, attrs, recursive, string, 1, _stacklevel=3,
#    2007                   **kwargs)
#    2008 if l:
#    2009     r = l[0]
#
# File /usr/local/lib/python3.8/dist-packages/bs4/element.py:2035, in Tag.find_all(self, name, attrs, recursive, string, limit, **kwargs)
#    2033     generator = self.children
#    2034 _stacklevel = kwargs.pop('_stacklevel', 2)
# -> 2035 return self._find_all(name, attrs, string, limit, generator,
#    2036                       _stacklevel=_stacklevel+1, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/bs4/element.py:841, in PageElement._find_all(self, name, attrs, string, limit, generator, **kwargs)
#     839     break
#     840 if i:
# --> 841     found = strainer.search(i)
#     842     if found:
#     843         results.append(found)
#
# File /usr/local/lib/python3.8/dist-packages/bs4/element.py:2315, in SoupStrainer.search(self, markup)
#    2312 found = None
#    2313 # If given a list of items, scan it for a text element that
#    2314 # matches.
# -> 2315 if hasattr(markup, '__iter__') and not isinstance(markup, (Tag, str)):
#    2316     for element in markup:
#    2317         if isinstance(element, NavigableString) \
#    2318                and self.search(element):
#
# KeyboardInterrupt:
