# %% [markdown]
# <a href="https://colab.research.google.com/github/WetSuiteLeiden/example-notebooks/blob/main/specific-experiments/find-references/find_references.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (only) in colab, run this first to install wetsuite from (the most recent) source.   For your own setup, see wetsuite's install guidelines.
# !pip3 install -U wetsuite

# %% [markdown]
# # Purpose of this notebook

# %% [markdown]
# Seeing how well you can extract the more explicit references to laws and jurisprudence from relatively free-form text.
#
# Because there are few standards, and the ones there are are rarely used consistently.
#
# You probably want to skim [notes__legal_identifiers_and_references (notebook)](../../notes/notes__legal_identifiers_and_references.ipynb) first.
#
# Optionally, take a glance at [find_wetnamen](../wetnamen/find_wetnamen.ipynb) extracting the names of laws,
# including less-official references in real-world use.

# %% [markdown]
# Note that there are many more implicit references, such as documents referring to `de staatssecretaris`, `onze wijziging`, `die brief`, `de najaarsnota`, many of which  _could_ be reconciled well enough within their context, but require a more involved a mix of more NLP-like approaches, co-reference and beyond, that this example is not even attempting yet.
#
# The amount of attention that deserves is usually only found in theses and such -- see e.g. [this one](https://scripties.uba.uva.nl/search?id=record_54697).

# %% [markdown]
# ## What is our domain?
#
# There will be references between documents like
# jurisprudence,
# national law,
# EU law,
# policy,
# and other official publications.
#
# Extracting such references may be useful to varied tasks, such as
# - finding related documents by the references they share use,
# - estimate the generla topics a document covers,
# - estimate what a document intends to do, by the legal authority it draws on.
#
# <!-- -->
#
# Particularly ECLI marks what it is in the identifier itself, so is unambiguous.
#
# The full form of a jci is similarly recognizable.
#
#
# Many other things fall on a gliding scale.
# LJN may just look like some letters and numbers.
# The same goes for CELEX except there are some letters in a predictable yet otherwise-unusual place.
# Such details metter if you want to avoid false positives.
#
# Abbreviated references are more easily missed (false negatives), or lead to false positives.
#
# Natural-language references may see a lot of _variation_ in how they are written down,
# but their relative verbosity means that most cases are still fairly unambiguous.

# %% [markdown]
# ### Some practical notes
#
#
# TODO: MOVE WHAT IS RELEVANT TO NOTES_IDENTIFIERS
#
#
# **Nerdnotes:**
# * You could look for very specific text patterns,
#   * but things like regexps are likely to break under even minor variation and/or become a mess to understan (see much of the current implementation)
#   * a good tradeoff might be something that lets you express the parts and how they combine - such as classical classical formal grammars - see acronyms like EBNF, CFGs, and in practice something like [PEG](https://en.wikipedia.org/wiki/Parsing_expression_grammar)s may be more flexible
#
# * There are some things that are essentially global aliases, shared through the community
#   * e.g. referring to part of `Awb` is _very_ likely to be _Algemene wet bestuursrecht_, [BWBR0005537](https://wetten.overheid.nl/BWBR0005537)
#   * and some references into this will be common to the point of almost being concepts in themselves
#
# * Then there are what are essentially local aliases. Consider:
#   - `"Ingevolge artikel 2, eerste lid, van de Wet op de adeldom (hierna: de Wet)"`
#   - `"the European Convention on Human Right and Fundamental Freedoms (hereinafter 'the Convention')"`
#   * which are important if you want to resolve _"article 6 of the Convention"_
#
#
# **Practicalities**
# * Some of the data we have is marked up, meaning there are links that are to a formal identifier, and have a less-formal name.
#   * for example, find `extref` tags in BWB and CVDR's XML form
#
# * Some of the references are nicely in metadata fields. Knowing that can act as disambiguation of the field's value in a way we cannot easily do in free-flowing text.
#
# * We also just have text that happens to be references - e.g. in free-flowing text.
#
#
# * perhaps the most important is actually that it is often not clear where the reference ends. A simple example:
#
#     TODO
#
#
# **Practicalities we cannot cover easily, or at all:**
# * References would be referring to the version valid at the time of reference, though that should be resolvable
#
# * You may find a lot of **less-formal names for laws** from free-form text
#
# * The same may not work as well for **policy** or **jurisprudence**.
#     * Say, "Rensing/Polak II" is practically unambiguous, even though it's **not** `ECLI:NL:HR:2005:AT4537`'s name
#     * yet there are many links that will be named "Besluit", or another name that is unique only within that document and not something we should learn generally
#
# * Not all references have the same function. Consider `"Commission Directive 2014/110/EU of 17 December 2014 amending Directive 2004/33/EC as regards ..."` or `"The substantive provisions of Directive 2004/33/EC were not affected by its amendment by Directive 2014/110/EU ..."` - it would not be hard to extract both references, but it is is up to you to notice that in terms of interpretation, one is referred to, and the other is only mentioned for completeness, or to decide there is a difference between mentions, supporing references, etc.

# %% [markdown]
# ## Some tests

# %% [markdown]
# ### Test what we can extract: More on the identifier end

# %%
import pprint

import wetsuite.helpers.patterns
import wetsuite.helpers.meta
import wetsuite.helpers.split
import wetsuite.helpers.net

# %%
matches = wetsuite.helpers.patterns.find_references( """
BWBR0006501

CVDR101405_1  CVDR101405/1  CVDR101405

ECLI:NL:HR:2005:AT4537   is an exampe of LJN in ECLI - and note it will get an overlapping detection
ECLI:EU:C:1998:27        is not detailed further, we currently focus on dutch only
ECLI:EU:F:2010:80
ECLI:EU:T:2012:426

kst-26643-144-h1        is not something you usually find in text
h-tk-20082009-7140-7144 so this is also disabled by default
ah-tk-20082009-2945
stcrt-2009-9231

32000L0060
32012A0424(01)
32009L0164R(01)          is a corrigendum
52018PC0033              is internal
11957E086                is a treaty
72013L0032AUT_202103576  is a national transposition (the added p
                                                    ECLI:NL:HR:1841:1
OJ L 69, 13.3.2013, p. 1
OJ L 168, 30.6.2009, p. 41–47 
Council Directive 93/42/EEC of 14 June 1993
Council Regulation (EEC) No 2658/87 

Stb. 2011, 35;

LJN: BO6106
LJN: AO7817, NJ 2005, 270
""", ljn=True, bekendmaking_ids=True) # by default does not look for LJN, because that easily leads to some false positives

for match in matches:
    #print( match )
    print('%r'%match['text'])
    for k, v in match.items():
        print( '    %20r:  %-r'%(k, v) )
# Out:
# 'BWBR0006501'
#                   'type':  'bwb'
#                  'start':  1
#                    'end':  12
#                   'text':  'BWBR0006501'
# 'CVDR101405_1'
#                   'type':  'cvdr'
#                  'start':  14
#                    'end':  26
#                   'text':  'CVDR101405_1'
#                'details':  {'workid': '101405', 'expressionid': '101405_1'}
# 'CVDR101405/1'
#                   'type':  'cvdr'
#                  'start':  28
#                    'end':  40
#                   'text':  'CVDR101405/1'
#                'details':  {'workid': '101405', 'expressionid': '101405_1'}
# 'CVDR101405'
#                   'type':  'cvdr'
#                  'start':  42
#                    'end':  52
#                   'text':  'CVDR101405'
#                'details':  {'workid': '101405', 'expressionid': None}
# 'ECLI:NL:HR:2005:AT4537'
#                   'type':  'ecli'
#                  'start':  54
#                    'end':  76
#                   'text':  'ECLI:NL:HR:2005:AT4537'
#                'details':  {'normalized': 'ECLI:NL:HR:2005:AT4537', 'country_code': 'NL', 'court_code': 'HR', 'year': '2005', 'caseid': 'AT4537', 'court_details': {'abbrev': 'HR', 'extra': ['hr'], 'name': 'Hoge Raad'}}
# 'AT4537'
#                   'type':  'ljn'
#                  'start':  70
#                    'end':  76
#                   'text':  'AT4537'
# 'ECLI:EU:C:1998:27'
#                   'type':  'ecli'
#                  'start':  155
#                    'end':  172
#                   'text':  'ECLI:EU:C:1998:27'
#                'details':  {'normalized': 'ECLI:EU:C:1998:27', 'country_code': 'EU', 'court_code': 'C', 'year': '1998', 'caseid': '27'}
# 'ECLI:EU:F:2010:80'
#                   'type':  'ecli'
#                  'start':  238
#                    'end':  255
#                   'text':  'ECLI:EU:F:2010:80'
#                'details':  {'normalized': 'ECLI:EU:F:2010:80', 'country_code': 'EU', 'court_code': 'F', 'year': '2010', 'caseid': '80'}
# 'ECLI:EU:T:2012:426'
#                   'type':  'ecli'
#                  'start':  256
#                    'end':  274
#                   'text':  'ECLI:EU:T:2012:426'
#                'details':  {'normalized': 'ECLI:EU:T:2012:426', 'country_code': 'EU', 'court_code': 'T', 'year': '2012', 'caseid': '426'}
# 'kst-26643-144-h1'
#                   'type':  'bekend'
#                  'start':  276
#                    'end':  292
#                   'text':  'kst-26643-144-h1'
#                'details':  {'type': 'kst', 'docnum': '144-h1', 'dossiernum': '26643'}
# 'h-tk-20082009-7140-7144'
#                   'type':  'bekend'
#                  'start':  342
#                    'end':  365
#                   'text':  'h-tk-20082009-7140-7144'
#                'details':  {'type': 'h-tk', 'jaar': '20082009', 'docnum': '7140-7144'}
# 'ah-tk-20082009-2945'
#                   'type':  'bekend'
#                  'start':  402
#                    'end':  421
#                   'text':  'ah-tk-20082009-2945'
#                'details':  {'type': 'ah-tk', 'jaar': '20082009', 'docnum': '2945'}
# 'stcrt-2009-9231'
#                   'type':  'bekend'
#                  'start':  422
#                    'end':  437
#                   'text':  'stcrt-2009-9231'
#                'details':  {'type': 'stcrt', 'jaar': '2009', 'docnum': '9231'}
# '32000L0060'
#                   'type':  'celex'
#                  'start':  439
#                    'end':  449
#                   'text':  '32000L0060'
#                'details':  {'norm': '32000L0060', 'sector_number': '3', 'sector_name': 'Legislation', 'year': '2000', 'document_type': 'L', 'document_type_description': 'Directives', 'document_number': '0060', 'nattrans': '', 'specdate': '', 'id': '32000L0060'}
# '32012A0424(01)'
#                   'type':  'celex'
#                  'start':  450
#                    'end':  464
#                   'text':  '32012A0424(01)'
#                'details':  {'norm': '32012A0424(01)', 'sector_number': '3', 'sector_name': 'Legislation', 'year': '2012', 'document_type': 'A', 'document_type_description': 'Opinions', 'document_number': '0424(01)', 'nattrans': '', 'specdate': '', 'id': '32012A0424(01)'}
# '32009L0164'
#                   'type':  'celex'
#                  'start':  465
#                    'end':  475
#                   'text':  '32009L0164'
#                'details':  {'norm': '32009L0164', 'sector_number': '3', 'sector_name': 'Legislation', 'year': '2009', 'document_type': 'L', 'document_type_description': 'Directives', 'document_number': '0164', 'nattrans': '', 'specdate': '', 'id': '32009L0164'}
# '52018PC0033'
#                   'type':  'celex'
#                  'start':  507
#                    'end':  518
#                   'text':  '52018PC0033'
#                'details':  {'norm': '52018PC0033', 'sector_number': '5', 'sector_name': 'Proposals + other preparatory documents', 'year': '2018', 'document_type': 'PC', 'document_type_description': 'European Commission - COM – legislative proposals, and documents related', 'document_number': '0033', 'nattrans': '', 'specdate': '', 'id': '52018PC0033'}
# '72013L0032'
#                   'type':  'celex'
#                  'start':  581
#                    'end':  591
#                   'text':  '72013L0032'
#                'details':  {'norm': '72013L0032', 'sector_number': '7', 'sector_name': 'National Implementation', 'year': '2013', 'document_type': 'L', 'document_type_description': 'National measures to transpose directives', 'document_number': '0032', 'nattrans': '', 'specdate': '', 'id': '72013L0032'}
# 'ECLI:NL:HR:1841:1'
#                   'type':  'ecli'
#                  'start':  699
#                    'end':  716
#                   'text':  'ECLI:NL:HR:1841:1'
#                'details':  {'normalized': 'ECLI:NL:HR:1841:1', 'country_code': 'NL', 'court_code': 'HR', 'year': '1841', 'caseid': '1', 'court_details': {'abbrev': 'HR', 'extra': ['hr'], 'name': 'Hoge Raad'}}
# 'OJ L 69, 13.3.2013, p. 1'
#                   'type':  'euoj'
#                  'start':  717
#                    'end':  741
#                   'text':  'OJ L 69, 13.3.2013, p. 1'
# 'OJ L 168, 30.6.2009, p. 41–47'
#                   'type':  'euoj'
#                  'start':  742
#                    'end':  771
#                   'text':  'OJ L 168, 30.6.2009, p. 41–47'
# 'Council Directive 93/42/EEC'
#                   'type':  'eudir'
#                  'start':  773
#                    'end':  800
#                   'text':  'Council Directive 93/42/EEC'
# 'Council Regulation (EEC) No 2658/87'
#                   'type':  'eureg'
#                  'start':  817
#                    'end':  852
#                   'text':  'Council Regulation (EEC) No 2658/87'
#                'details':  {'what': 'EEC', 'number': 'No 2658/87'}
# 'Stb. 2011, 35'
#                   'type':  'vindplaats'
#                  'start':  855
#                    'end':  868
#                   'text':  'Stb. 2011, 35'
#                'details':  {'what': 'Stb', 'jaar': '2011', 'nummer': '35'}
# 'BO6106'
#                   'type':  'ljn'
#                  'start':  876
#                    'end':  882
#                   'text':  'BO6106'
# 'AO7817'
#                   'type':  'ljn'
#                  'start':  888
#                    'end':  894
#                   'text':  'AO7817'

# %% [markdown]
# ### Test: matching less-structured cases

# %%
# These have more varied form, see how well we do at that
for test_text in '''Kamerstukken II 2015/16, 34442, nr. 3, p. 7.
Kamerstukken I 1995/96, 23700, nr. 188b, p. 3.
Kamerstukken I 2014/15, 33802, C, p. 3.
Kamerstukken 2014/15, 33802, C, p. 3.  as a test of missing number
Kamerstukken II 1999/2000, 2000/2001, 2001/2002, 26 855.
Kamerstukken I 2000/2001, 26 855 (250, 250a); 2001/2002, 26 855 (16, 16a, 16b, 16c).
Handelingen II 2000/2001, blz. 4225–4227; 4277.
Handelingen I 2001/2002, zie vergadering d.d. 4 december 2001.
Bijlage bij Kamerstukken II 2015/16, 34389, nr. 9.
Wetsvoorstel partnerschapsregistratie (Kamerstukken II 1993/94-1996/97, 23761).
Wetsvoorstel partnerschapsregistratie (Kamerstukken 1993/94-1996/97, 23761)
Aanhangsel Handelingen, vergaderjaar 2022–2023, nr. 2427
Aanhangsel Handelingen II, vergaderjaar 2023-2024, nr. 766 
'''.splitlines():
    
    matches = wetsuite.helpers.patterns.find_references( test_text )
    if len(matches)==0:
        print( "\nDID NOT MATCH IN %r"%test_text)
    else:
        for match in matches:
            print('\nMatched: %r'%match['text'])
            for k, v in match.items():
                print( '    %20r:  %-r'%(k, v) )
# Out:
# Matched: 'Kamerstukken II 2015/16, 34442, nr. 3, p. 7'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  43
#                   'text':  'Kamerstukken II 2015/16, 34442, nr. 3, p. 7'
#
# Matched: 'Kamerstukken I 1995/96, 23700, nr. 188'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  38
#                   'text':  'Kamerstukken I 1995/96, 23700, nr. 188'
#
# Matched: 'Kamerstukken I 2014/15, 33802, C, p. 3'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  38
#                   'text':  'Kamerstukken I 2014/15, 33802, C, p. 3'
#
# Matched: 'Kamerstukken 2014/15, 33802, C, p. 3'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  36
#                   'text':  'Kamerstukken 2014/15, 33802, C, p. 3'
#
# Matched: 'Kamerstukken II 1999/2000, 2000'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  31
#                   'text':  'Kamerstukken II 1999/2000, 2000'
#
# Matched: 'Kamerstukken I 2000/2001, 26'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  28
#                   'text':  'Kamerstukken I 2000/2001, 26'
#
# Matched: 'Handelingen II 2000/2001, blz. 4225'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  35
#                   'text':  'Handelingen II 2000/2001, blz. 4225'
#
# Matched: 'Handelingen I 2001/2002'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  23
#                   'text':  'Handelingen I 2001/2002'
#
# Matched: 'Kamerstukken II 2015/16, 34389, nr. 9'
#                   'type':  'kamerstukken'
#                  'start':  12
#                    'end':  49
#                   'text':  'Kamerstukken II 2015/16, 34389, nr. 9'
#
# Matched: 'Kamerstukken II 1993/94'
#                   'type':  'kamerstukken'
#                  'start':  39
#                    'end':  62
#                   'text':  'Kamerstukken II 1993/94'
#
# Matched: 'Kamerstukken 1993/94'
#                   'type':  'kamerstukken'
#                  'start':  39
#                    'end':  59
#                   'text':  'Kamerstukken 1993/94'
#
# DID NOT MATCH IN 'Aanhangsel Handelingen, vergaderjaar 2022–2023, nr. 2427'
#
# Matched: 'Aanhangsel Handelingen II, vergaderjaar 2023-2024, nr. 766'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  58
#                   'text':  'Aanhangsel Handelingen II, vergaderjaar 2023-2024, nr. 766'

# %% [markdown]
# ...even less structured...

# %%
looser_testcases = (
    'artikel 8:75a, eerste lid, tweede volzin, van de Awb',

    'artikel 5:9, aanhef en onder b, Awb',
    'artikel 8, aanhef en onder c, Wet bescherming persoonsgegevens (Wbp).',
    'artikel 10, tweede lid, aanhef en onder e, van de Wob',
    "artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad",
    "Artikel 10, tweede lid, aanhef en onder e van de. Wet openbaarheid van bestuur",
    "artikel 6:80 lid 1 aanhef en onder b BW",
    'artikel 4, aanhef en onder d en g, van de standaardvoorwaarden',
    'artikel 3.3, zevende lid, aanhef en onder i, Woo',
    'artikel 15, aanhef en onder a of c (oud) RWN',

    '  artikel 81q lid 3c Gemeentewet  ',
    'artikel 4:25, 4:35 van de Awb en artikel 10 van de ASV',
    'Wabo, art. 2.12, eerste lid, aanhef en onder a, sub 1\xBA',
    'artikel 79, aanhef en onder 6\xBA',
    'artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo',
    'artikel 142, eerste lid, aanhef en onder b (en derde lid), van het Wetboek van Strafvordering',
    'artikel 2, eerste, tweede, vijfde, en zesenzestigste lid',
    'art. 166 lid 1 in verbinding met art. 353 lid 1 Rv',
    'artikel 13, derde lid, van de Wet tarieven in burgerlijke zaken',
    'artikel 7, eerste lid, onderdeel a',
    'artikel 7, eerste lid, aanhef en onderdeel b', 

    'artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad',
    'artikel 5:9, aanhef en onder b, Awb',
    'artikel 8, aanhef en onder c, Wet bescherming persoonsgegevens (Wbp)',
    'artikel 10, tweede lid, aanhef en onder e, van de Wob',
    'artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad',
    'Artikel 10, tweede lid, aanhef en onder e van de Wet openbaarheid van bestuur',
    'artikel 6:80 lid 1 aanhef en onder b BW',
    'artikel 142, eerste lid, aanhef en onder b (en derde lid), van het Wetboek van Strafvordering',
    'artikel 4, aanhef en onder d en g, van de standaardvoorwaarden',
    'artikel 3.3, zevende lid, aanhef en onder i, Woo',
    'artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo',
    'artikel 79, aanhef en onder 6\xBA',
    'artikel 15, aanhef en onder a of c (oud) RWN',
    'Wabo, art. 2.12, eerste lid, aanhef en onder a, sub 1\xBA',
    'artikel 2, eerste, tweede, en vijfde lid, gestelde eisen voldoen. (Artikel 3, eerste lid, van de Tabaks- en rookwarenwet)',
    'artikel 2, eerste, tweede, vijfde, even zesenzestigste lid',

    'art 18 lid 2 en 4 Besluit kwaliteit; art 21 lid 1 sub a Regeling',
    'artikel 2, onderdeel 8, subonderdeel b, van Verordening 2018/1805', 
    '(Art. 81 RO)',
    "(81 WWB)",
    '(als bedoeld in art. 22 Rv.)',
    'artikel 166 Rv',
    'artikel 3:303 BW',
    'artikel 22 Rv',
)

# %%
for test_text in looser_testcases:
    matches = wetsuite.helpers.patterns.find_references( test_text, debug=0 )
    if len(matches)==0:
        print( 'NO MATCH IN %r'%test_text )
    else:
        #continue
        # Note that right now, we do not yet try to match the mentioned law -- that's on a TODO list
        print( '\n%r -->'%test_text )
        for match in matches:
            #pprint.pprint( match )
            for k, v in match['details'].items():
                print( '    %15s:  %-r'%(k, v) )
# Out:
# 'artikel 2, onderdeel 8, subonderdeel b, van Verordening 2018/1805' -->
#             artikel:  '2'
#         aanhefonder:  'onderdeel b'
#
# 'artikel 8:75a, eerste lid, tweede volzin, van de Awb' -->
#             artikel:  '8:75a'
#                 lid:  'eerste'
#              volzin:  'tweede'
#             lid_num:  [1]
#          volzin_num:  [2]
#
# 'artikel 5:9, aanhef en onder b, Awb' -->
#             artikel:  '5:9'
#         aanhefonder:  'aanhef en onder b'
#
# 'artikel 8, aanhef en onder c, Wet bescherming persoonsgegevens (Wbp).' -->
#             artikel:  '8'
#         aanhefonder:  'aanhef en onder c'
#
# 'artikel 10, tweede lid, aanhef en onder e, van de Wob' -->
#             artikel:  '10'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder e'
#             lid_num:  [2]
#
# 'artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad' -->
#             artikel:  '4'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder d'
#             lid_num:  [2]
#
# 'Artikel 10, tweede lid, aanhef en onder e van de. Wet openbaarheid van bestuur' -->
#             artikel:  '10'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder e'
#             lid_num:  [2]
#
# 'artikel 6:80 lid 1 aanhef en onder b BW' -->
#             artikel:  '6:80'
#                 lid:  '1'
#         aanhefonder:  'aanhef en onder b'
#             lid_num:  [1]
#
# 'artikel 4, aanhef en onder d en g, van de standaardvoorwaarden' -->
#             artikel:  '4'
#         aanhefonder:  'aanhef en onder d'
#
# 'artikel 3.3, zevende lid, aanhef en onder i, Woo' -->
#             artikel:  '3.3'
#                 lid:  'zevende'
#         aanhefonder:  'aanhef en onder i'
#             lid_num:  [7]
#
# 'artikel 15, aanhef en onder a of c (oud) RWN' -->
#             artikel:  '15'
#         aanhefonder:  'aanhef en onder a'
#
# '  artikel 81q lid 3c Gemeentewet  ' -->
#             artikel:  '81q'
#                 lid:  '3c'
#             lid_num:  []
#
# 'artikel 4:25, 4:35 van de Awb en artikel 10 van de ASV' -->
#             artikel:  '4:25'
#             artikel:  '10'
#
# 'Wabo, art. 2.12, eerste lid, aanhef en onder a, sub 1º' -->
#             artikel:  '2.12'
#                 lid:  'eerste'
#         aanhefonder:  'aanhef en onder a'
#             lid_num:  [1]
#
# 'artikel 79, aanhef en onder 6º' -->
#             artikel:  '79'
#         aanhefonder:  'aanhef en onder 6º'
#
# 'artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo' -->
#             artikel:  '3.3'
#                 lid:  'zevende'
#         aanhefonder:  'aanhef en onder i'
#             lid_num:  [7]
#
# 'artikel 142, eerste lid, aanhef en onder b (en derde lid), van het Wetboek van Strafvordering' -->
#             artikel:  '142'
#                 lid:  'derde'
#         aanhefonder:  'aanhef en onder b'
#             lid_num:  [3]
#
# 'artikel 2, eerste, tweede, vijfde, en zesenzestigste lid' -->
#             artikel:  '2'
#                 lid:  'eerste, tweede, vijfde, en zesenzestigste'
#             lid_num:  [1, 2, 5, 66]
#
# 'art. 166 lid 1 in verbinding met art. 353 lid 1 Rv' -->
#             artikel:  '166'
#                 lid:  '1'
#             lid_num:  [1]
#             artikel:  '353'
#                 lid:  '1'
#             lid_num:  [1]
#
# 'artikel 13, derde lid, van de Wet tarieven in burgerlijke zaken' -->
#             artikel:  '13'
#                 lid:  'derde'
#             lid_num:  [3]
#
# 'artikel 7, eerste lid, onderdeel a' -->
#             artikel:  '7'
#                 lid:  'eerste'
#         aanhefonder:  'onderdeel a'
#             lid_num:  [1]
#
# 'artikel 7, eerste lid, aanhef en onderdeel b' -->
#             artikel:  '7'
#                 lid:  'eerste'
#         aanhefonder:  'aanhef en onderdeel b'
#             lid_num:  [1]
#
# 'art 18 lid 2 en 4 Besluit kwaliteit; art 21 lid 1 sub a Regeling' -->
#             artikel:  '18'
#                 lid:  '2'
#             lid_num:  [2]
#             artikel:  '21'
#                 lid:  '1'
#             lid_num:  [1]
#
# '(Art. 81 RO)' -->
#             artikel:  '81'
# NO MATCH IN '(81 WWB)'
#
# '(als bedoeld in art. 22 Rv.)' -->
#             artikel:  '22'
#
# 'artikel 166 Rv' -->
#             artikel:  '166'
#
# 'artikel 3:303 BW' -->
#             artikel:  '3:303'
#
# 'artikel 22 Rv' -->
#             artikel:  '22'
#
# 'artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad' -->
#             artikel:  '4'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder d'
#             lid_num:  [2]
#
# 'artikel 5:9, aanhef en onder b, Awb' -->
#             artikel:  '5:9'
#         aanhefonder:  'aanhef en onder b'
#
# 'artikel 8, aanhef en onder c, Wet bescherming persoonsgegevens (Wbp)' -->
#             artikel:  '8'
#         aanhefonder:  'aanhef en onder c'
#
# 'artikel 10, tweede lid, aanhef en onder e, van de Wob' -->
#             artikel:  '10'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder e'
#             lid_num:  [2]
#
# 'artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad' -->
#             artikel:  '4'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder d'
#             lid_num:  [2]
#
# 'Artikel 10, tweede lid, aanhef en onder e van de Wet openbaarheid van bestuur' -->
#             artikel:  '10'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder e'
#             lid_num:  [2]
#
# 'artikel 6:80 lid 1 aanhef en onder b BW' -->
#             artikel:  '6:80'
#                 lid:  '1'
#         aanhefonder:  'aanhef en onder b'
#             lid_num:  [1]
#
# 'artikel 142, eerste lid, aanhef en onder b (en derde lid), van het Wetboek van Strafvordering' -->
#             artikel:  '142'
#                 lid:  'derde'
#         aanhefonder:  'aanhef en onder b'
#             lid_num:  [3]
#
# 'artikel 4, aanhef en onder d en g, van de standaardvoorwaarden' -->
#             artikel:  '4'
#         aanhefonder:  'aanhef en onder d'
#
# 'artikel 3.3, zevende lid, aanhef en onder i, Woo' -->
#             artikel:  '3.3'
#                 lid:  'zevende'
#         aanhefonder:  'aanhef en onder i'
#             lid_num:  [7]
#
# 'artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo' -->
#             artikel:  '3.3'
#                 lid:  'zevende'
#         aanhefonder:  'aanhef en onder i'
#             lid_num:  [7]
#
# 'artikel 79, aanhef en onder 6º' -->
#             artikel:  '79'
#         aanhefonder:  'aanhef en onder 6º'
#
# 'artikel 15, aanhef en onder a of c (oud) RWN' -->
#             artikel:  '15'
#         aanhefonder:  'aanhef en onder a'
#
# 'Wabo, art. 2.12, eerste lid, aanhef en onder a, sub 1º' -->
#             artikel:  '2.12'
#                 lid:  'eerste'
#         aanhefonder:  'aanhef en onder a'
#             lid_num:  [1]
#
# 'artikel 2, eerste, tweede, en vijfde lid, gestelde eisen voldoen. (Artikel 3, eerste lid, van de Tabaks- en rookwarenwet)' -->
#             artikel:  '2'
#                 lid:  'eerste, tweede, en vijfde'
#             lid_num:  [1, 2, 5]
#             artikel:  '3'
#                 lid:  'eerste'
#             lid_num:  [1]
#
# 'artikel 2, eerste, tweede, vijfde, even zesenzestigste lid' -->
#             artikel:  '2'
#                 lid:  'zesenzestigste'
#             lid_num:  [66]

# %% [markdown]
# ### Test: an actual document

# %%
htmldata = wetsuite.helpers.net.download('https://zoek.officielebekendmakingen.nl/stb-2001-580.html')
htmltext = ' '.join( wetsuite.helpers.split.feeling_lucky(htmldata) )  # helper function that should extract just the text
# Out:
# /usr/local/lib/python3.8/dist-packages/wetsuite/helpers/split.py:138: UserWarning: _split_officielepublicaties_html() needs some basic refinement
#   warnings.warn("_split_officielepublicaties_html() needs some basic refinement")

# %%
matches = wetsuite.helpers.patterns.find_references( htmltext )
for match in matches:
    print('\nMatched: %r'%match['text'])
    for k, v in match.items():
        print( '    %20r:  %-r'%(k, v) )
# Out:
# Matched: 'artikel 1.1.5, onder c. 4.  Het derde lid, aanhef en onder b'
#                   'type':  'artikel'
#                  'start':  7064
#                    'end':  7124
#                   'text':  'artikel 1.1.5, onder c. 4.  Het derde lid, aanhef en onder b'
#                'details':  OrderedDict([('artikel', '1.1.5'), ('lid', 'derde'), ('aanhefonder', 'aanhef en onder b'), ('lid_num', [3])])
#
# Matched: 'artikel\r\n767'
#                   'type':  'artikel'
#                  'start':  8974
#                    'end':  8986
#                   'text':  'artikel\r\n767'
#                'details':  OrderedDict([('artikel', '767')])
#
# Matched: 'artikel 1.1.10'
#                   'type':  'artikel'
#                  'start':  10056
#                    'end':  10070
#                   'text':  'artikel 1.1.10'
#                'details':  OrderedDict([('artikel', '1.1.10')])
#
# Matched: 'artikel 1.2.3.'
#                   'type':  'artikel'
#                  'start':  11577
#                    'end':  11591
#                   'text':  'artikel 1.2.3.'
#                'details':  OrderedDict([('artikel', '1.2.3.')])
#
# Matched: 'artikel 13, derde lid, van de'
#                   'type':  'artikel'
#                  'start':  17246
#                    'end':  17275
#                   'text':  'artikel 13, derde lid, van de'
#                'details':  OrderedDict([('artikel', '13'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'Artikel 1.3.12, tweede en derde lid'
#                   'type':  'artikel'
#                  'start':  19823
#                    'end':  19858
#                   'text':  'Artikel 1.3.12, tweede en derde lid'
#                'details':  OrderedDict([('artikel', '1.3.12'), ('lid', 'tweede en derde'), ('lid_num', [2, 3])])
#
# Matched: 'artikel 2.11.3'
#                   'type':  'artikel'
#                  'start':  20535
#                    'end':  20549
#                   'text':  'artikel 2.11.3'
#                'details':  OrderedDict([('artikel', '2.11.3')])
#
# Matched: 'artikel\r\n3.4.13 van het'
#                   'type':  'artikel'
#                  'start':  20568
#                    'end':  20591
#                   'text':  'artikel\r\n3.4.13 van het'
#                'details':  OrderedDict([('artikel', '3.4.13')])
#
# Matched: 'artikel 1.4.1 kan\r\nelk van de'
#                   'type':  'artikel'
#                  'start':  23973
#                    'end':  24002
#                   'text':  'artikel 1.4.1 kan\r\nelk van de'
#                'details':  OrderedDict([('artikel', '1.4.1')])
#
# Matched: 'artikel 1.4.5'
#                   'type':  'artikel'
#                  'start':  24766
#                    'end':  24779
#                   'text':  'artikel 1.4.5'
#                'details':  OrderedDict([('artikel', '1.4.5')])
#
# Matched: 'Artikel 1.6.3'
#                   'type':  'artikel'
#                  'start':  28900
#                    'end':  28913
#                   'text':  'Artikel 1.6.3'
#                'details':  OrderedDict([('artikel', '1.6.3')])
#
# Matched: 'artikel 1.6.2, eerste lid'
#                   'type':  'artikel'
#                  'start':  28978
#                    'end':  29003
#                   'text':  'artikel 1.6.2, eerste lid'
#                'details':  OrderedDict([('artikel', '1.6.2'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 1 van Boek 2\r\nvan het Burgerlijk Wetboek, met uitzondering van de'
#                   'type':  'artikel'
#                  'start':  30281
#                    'end':  30354
#                   'text':  'artikel 1 van Boek 2\r\nvan het Burgerlijk Wetboek, met uitzondering van de'
#                'details':  OrderedDict([('artikel', '1')])
#
# Matched: 'artikel 1.6.10, tweede en vierde lid'
#                   'type':  'artikel'
#                  'start':  35872
#                    'end':  35908
#                   'text':  'artikel 1.6.10, tweede en vierde lid'
#                'details':  OrderedDict([('artikel', '1.6.10'), ('lid', 'tweede en vierde'), ('lid_num', [2, 4])])
#
# Matched: 'Trb. 1966, 91'
#                   'type':  'vindplaats'
#                  'start':  36809
#                    'end':  36822
#                   'text':  'Trb. 1966, 91'
#                'details':  {'what': 'Trb', 'jaar': '1966', 'nummer': '91'}
#
# Matched: 'artikel 1.6.3 en doet hij bovendien een afschrift van het exploot\r\ntoekomen aan het parket van de ambtenaar van het'
#                   'type':  'artikel'
#                  'start':  37229
#                    'end':  37344
#                   'text':  'artikel 1.6.3 en doet hij bovendien een afschrift van het exploot\r\ntoekomen aan het parket van de ambtenaar van het'
#                'details':  OrderedDict([('artikel', '1.6.3')])
#
# Matched: 'artikel 193'
#                   'type':  'artikel'
#                  'start':  38105
#                    'end':  38116
#                   'text':  'artikel 193'
#                'details':  OrderedDict([('artikel', '193')])
#
# Matched: 'artikel 783 van\r\nBoek 8 van het'
#                   'type':  'artikel'
#                  'start':  38120
#                    'end':  38151
#                   'text':  'artikel 783 van\r\nBoek 8 van het'
#                'details':  OrderedDict([('artikel', '783')])
#
# Matched: 'artikel 194,\r\nzesde lid'
#                   'type':  'artikel'
#                  'start':  38357
#                    'end':  38380
#                   'text':  'artikel 194,\r\nzesde lid'
#                'details':  OrderedDict([('artikel', '194'), ('lid', 'zesde'), ('lid_num', [6])])
#
# Matched: 'artikel 784, zevende lid'
#                   'type':  'artikel'
#                  'start':  38385
#                    'end':  38409
#                   'text':  'artikel 784, zevende lid'
#                'details':  OrderedDict([('artikel', '784'), ('lid', 'zevende'), ('lid_num', [7])])
#
# Matched: 'artikel\r\n1302 van Boek 8 van het'
#                   'type':  'artikel'
#                  'start':  38868
#                    'end':  38900
#                   'text':  'artikel\r\n1302 van Boek 8 van het'
#                'details':  OrderedDict([('artikel', '1302')])
#
# Matched: 'artikel 1303, zesde lid, van Boek 8 van het'
#                   'type':  'artikel'
#                  'start':  39116
#                    'end':  39159
#                   'text':  'artikel 1303, zesde lid, van Boek 8 van het'
#                'details':  OrderedDict([('artikel', '1303'), ('lid', 'zesde'), ('lid_num', [6])])
#
# Matched: 'artikel 1.6.3'
#                   'type':  'artikel'
#                  'start':  39658
#                    'end':  39671
#                   'text':  'artikel 1.6.3'
#                'details':  OrderedDict([('artikel', '1.6.3')])
#
# Matched: 'artikel 1003, onder 1'
#                   'type':  'artikel'
#                  'start':  40525
#                    'end':  40546
#                   'text':  'artikel 1003, onder 1'
#                'details':  OrderedDict([('artikel', '1003'), ('aanhefonder', 'onder 1')])
#
# Matched: 'artikel 3 van\r\nde'
#                   'type':  'artikel'
#                  'start':  42928
#                    'end':  42945
#                   'text':  'artikel 3 van\r\nde'
#                'details':  OrderedDict([('artikel', '3')])
#
# Matched: 'Trb. 1968, 142'
#                   'type':  'vindplaats'
#                  'start':  43067
#                    'end':  43081
#                   'text':  'Trb. 1968, 142'
#                'details':  {'what': 'Trb', 'jaar': '1968', 'nummer': '142'}
#
# Matched: 'artikel 4 van de'
#                   'type':  'artikel'
#                  'start':  43359
#                    'end':  43375
#                   'text':  'artikel 4 van de'
#                'details':  OrderedDict([('artikel', '4')])
#
# Matched: 'artikel 13 van de'
#                   'type':  'artikel'
#                  'start':  43666
#                    'end':  43683
#                   'text':  'artikel 13 van de'
#                'details':  OrderedDict([('artikel', '13')])
#
# Matched: 'artikel 2.4.5'
#                   'type':  'artikel'
#                  'start':  46553
#                    'end':  46566
#                   'text':  'artikel 2.4.5'
#                'details':  OrderedDict([('artikel', '2.4.5')])
#
# Matched: 'artikel 1.8.4'
#                   'type':  'artikel'
#                  'start':  49071
#                    'end':  49084
#                   'text':  'artikel 1.8.4'
#                'details':  OrderedDict([('artikel', '1.8.4')])
#
# Matched: 'artikel\r\n3.1.1'
#                   'type':  'artikel'
#                  'start':  50145
#                    'end':  50159
#                   'text':  'artikel\r\n3.1.1'
#                'details':  OrderedDict([('artikel', '3.1.1')])
#
# Matched: 'artikel 2.1.8, tweede lid'
#                   'type':  'artikel'
#                  'start':  55649
#                    'end':  55674
#                   'text':  'artikel 2.1.8, tweede lid'
#                'details':  OrderedDict([('artikel', '2.1.8'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 2.1.10, tweede lid'
#                   'type':  'artikel'
#                  'start':  57204
#                    'end':  57230
#                   'text':  'Artikel 2.1.10, tweede lid'
#                'details':  OrderedDict([('artikel', '2.1.10'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 2.8.6.'
#                   'type':  'artikel'
#                  'start':  58429
#                    'end':  58443
#                   'text':  'artikel 2.8.6.'
#                'details':  OrderedDict([('artikel', '2.8.6.')])
#
# Matched: 'artikel 2.1.10'
#                   'type':  'artikel'
#                  'start':  58518
#                    'end':  58532
#                   'text':  'artikel 2.1.10'
#                'details':  OrderedDict([('artikel', '2.1.10')])
#
# Matched: 'artikel 2.1.11'
#                   'type':  'artikel'
#                  'start':  58536
#                    'end':  58550
#                   'text':  'artikel 2.1.11'
#                'details':  OrderedDict([('artikel', '2.1.11')])
#
# Matched: 'artikel 1.3.4\r\nwor'
#                   'type':  'artikel'
#                  'start':  58576
#                    'end':  58594
#                   'text':  'artikel 1.3.4\r\nwor'
#                'details':  OrderedDict([('artikel', '1.3.4'), ('nameref', '\r\nwor')])
#
# Matched: 'artikel 2.2.12'
#                   'type':  'artikel'
#                  'start':  62231
#                    'end':  62245
#                   'text':  'artikel 2.2.12'
#                'details':  OrderedDict([('artikel', '2.2.12')])
#
# Matched: 'artikel\r\n2.2.3'
#                   'type':  'artikel'
#                  'start':  62412
#                    'end':  62426
#                   'text':  'artikel\r\n2.2.3'
#                'details':  OrderedDict([('artikel', '2.2.3')])
#
# Matched: 'Artikel 1.8.5, eerste\r\nlid en derde lid'
#                   'type':  'artikel'
#                  'start':  63830
#                    'end':  63869
#                   'text':  'Artikel 1.8.5, eerste\r\nlid en derde lid'
#                'details':  OrderedDict([('artikel', '1.8.5'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 1.6.1, tweede lid'
#                   'type':  'artikel'
#                  'start':  64364
#                    'end':  64389
#                   'text':  'artikel 1.6.1, tweede lid'
#                'details':  OrderedDict([('artikel', '1.6.1'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 2.6.1'
#                   'type':  'artikel'
#                  'start':  65447
#                    'end':  65460
#                   'text':  'artikel 2.6.1'
#                'details':  OrderedDict([('artikel', '2.6.1')])
#
# Matched: 'artikel 2.6.2, tweede lid'
#                   'type':  'artikel'
#                  'start':  65499
#                    'end':  65524
#                   'text':  'artikel 2.6.2, tweede lid'
#                'details':  OrderedDict([('artikel', '2.6.2'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Trb. 1966,\r\n91'
#                   'type':  'vindplaats'
#                  'start':  66926
#                    'end':  66940
#                   'text':  'Trb. 1966,\r\n91'
#                'details':  {'what': 'Trb', 'jaar': '1966', 'nummer': '91'}
#
# Matched: 'artikel 1003,\r\nonder 1'
#                   'type':  'artikel'
#                  'start':  67898
#                    'end':  67920
#                   'text':  'artikel 1003,\r\nonder 1'
#                'details':  OrderedDict([('artikel', '1003'), ('aanhefonder', 'onder 1')])
#
# Matched: 'Artikel 2.3.1, tweede lid, aanhef en onderdelen g'
#                   'type':  'artikel'
#                  'start':  68619
#                    'end':  68668
#                   'text':  'Artikel 2.3.1, tweede lid, aanhef en onderdelen g'
#                'details':  OrderedDict([('artikel', '2.3.1'), ('lid', 'tweede'), ('aanhefonder', 'aanhef en onderdelen g'), ('lid_num', [2])])
#
# Matched: 'artikel 2.3.1, derde lid'
#                   'type':  'artikel'
#                  'start':  69557
#                    'end':  69581
#                   'text':  'artikel 2.3.1, derde lid'
#                'details':  OrderedDict([('artikel', '2.3.1'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel\r\n2.3.2, eerste lid'
#                   'type':  'artikel'
#                  'start':  72241
#                    'end':  72267
#                   'text':  'artikel\r\n2.3.2, eerste lid'
#                'details':  OrderedDict([('artikel', '2.3.2'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 2.3.2, eerste lid'
#                   'type':  'artikel'
#                  'start':  73535
#                    'end':  73560
#                   'text':  'artikel 2.3.2, eerste lid'
#                'details':  OrderedDict([('artikel', '2.3.2'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 2.3.12, eerste lid'
#                   'type':  'artikel'
#                  'start':  74107
#                    'end':  74133
#                   'text':  'artikel 2.3.12, eerste lid'
#                'details':  OrderedDict([('artikel', '2.3.12'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 2.3.9, derde lid'
#                   'type':  'artikel'
#                  'start':  76596
#                    'end':  76620
#                   'text':  'artikel 2.3.9, derde lid'
#                'details':  OrderedDict([('artikel', '2.3.9'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 2.1.10'
#                   'type':  'artikel'
#                  'start':  76791
#                    'end':  76805
#                   'text':  'artikel 2.1.10'
#                'details':  OrderedDict([('artikel', '2.1.10')])
#
# Matched: 'artikel 2.1.11'
#                   'type':  'artikel'
#                  'start':  76810
#                    'end':  76824
#                   'text':  'artikel 2.1.11'
#                'details':  OrderedDict([('artikel', '2.1.11')])
#
# Matched: 'artikel 2.4.7'
#                   'type':  'artikel'
#                  'start':  77121
#                    'end':  77134
#                   'text':  'artikel 2.4.7'
#                'details':  OrderedDict([('artikel', '2.4.7')])
#
# Matched: 'artikel 2.4.7'
#                   'type':  'artikel'
#                  'start':  77344
#                    'end':  77357
#                   'text':  'artikel 2.4.7'
#                'details':  OrderedDict([('artikel', '2.4.7')])
#
# Matched: 'artikel 1.3.1 of met\r\nhet oog op een goede instructie van de'
#                   'type':  'artikel'
#                  'start':  77472
#                    'end':  77532
#                   'text':  'artikel 1.3.1 of met\r\nhet oog op een goede instructie van de'
#                'details':  OrderedDict([('artikel', '1.3.1')])
#
# Matched: 'artikel 1.3.1 of met het oog op een goede instructie van de'
#                   'type':  'artikel'
#                  'start':  77644
#                    'end':  77703
#                   'text':  'artikel 1.3.1 of met het oog op een goede instructie van de'
#                'details':  OrderedDict([('artikel', '1.3.1')])
#
# Matched: 'artikel 2.4.7'
#                   'type':  'artikel'
#                  'start':  78699
#                    'end':  78712
#                   'text':  'artikel 2.4.7'
#                'details':  OrderedDict([('artikel', '2.4.7')])
#
# Matched: 'Artikel 2.3.1, derde lid'
#                   'type':  'artikel'
#                  'start':  79676
#                    'end':  79700
#                   'text':  'Artikel 2.3.1, derde lid'
#                'details':  OrderedDict([('artikel', '2.3.1'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 2.3.7. De kosten die een gevolg zijn van het'
#                   'type':  'artikel'
#                  'start':  81136
#                    'end':  81188
#                   'text':  'artikel 2.3.7. De kosten die een gevolg zijn van het'
#                'details':  OrderedDict([('artikel', '2.3.7.')])
#
# Matched: 'Artikel 2.3.1, tweede lid, onder i'
#                   'type':  'artikel'
#                  'start':  82367
#                    'end':  82401
#                   'text':  'Artikel 2.3.1, tweede lid, onder i'
#                'details':  OrderedDict([('artikel', '2.3.1'), ('lid', 'tweede'), ('aanhefonder', 'onder i'), ('lid_num', [2])])
#
# Matched: 'Artikel 2.4.4, vijfde\r\nlid'
#                   'type':  'artikel'
#                  'start':  83490
#                    'end':  83516
#                   'text':  'Artikel 2.4.4, vijfde\r\nlid'
#                'details':  OrderedDict([('artikel', '2.4.4'), ('lid', 'vijfde'), ('lid_num', [5])])
#
# Matched: 'Artikel 2.3.1, derde lid'
#                   'type':  'artikel'
#                  'start':  83659
#                    'end':  83683
#                   'text':  'Artikel 2.3.1, derde lid'
#                'details':  OrderedDict([('artikel', '2.3.1'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 2.4.2'
#                   'type':  'artikel'
#                  'start':  83769
#                    'end':  83782
#                   'text':  'artikel 2.4.2'
#                'details':  OrderedDict([('artikel', '2.4.2')])
#
# Matched: 'artikel 2.8.9'
#                   'type':  'artikel'
#                  'start':  88000
#                    'end':  88013
#                   'text':  'artikel 2.8.9'
#                'details':  OrderedDict([('artikel', '2.8.9')])
#
# Matched: 'artikel 2.8.22, eerste lid'
#                   'type':  'artikel'
#                  'start':  93922
#                    'end':  93948
#                   'text':  'artikel 2.8.22, eerste lid'
#                'details':  OrderedDict([('artikel', '2.8.22'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 2.8.27'
#                   'type':  'artikel'
#                  'start':  95744
#                    'end':  95758
#                   'text':  'artikel 2.8.27'
#                'details':  OrderedDict([('artikel', '2.8.27')])
#
# Matched: 'artikel 2.8.6 is bepaald. 1.  Van het'
#                   'type':  'artikel'
#                  'start':  99175
#                    'end':  99212
#                   'text':  'artikel 2.8.6 is bepaald. 1.  Van het'
#                'details':  OrderedDict([('artikel', '2.8.6')])
#
# Matched: 'artikel 2.8.33'
#                   'type':  'artikel'
#                  'start':  100059
#                    'end':  100073
#                   'text':  'artikel 2.8.33'
#                'details':  OrderedDict([('artikel', '2.8.33')])
#
# Matched: 'artikel 2.8.30\r\naangeduid, de summiere inhoud van de'
#                   'type':  'artikel'
#                  'start':  100342
#                    'end':  100394
#                   'text':  'artikel 2.8.30\r\naangeduid, de summiere inhoud van de'
#                'details':  OrderedDict([('artikel', '2.8.30')])
#
# Matched: 'artikel 2.8.30 omtrent het afleggen van de eed,\r\nalleen de nietigheid van het'
#                   'type':  'artikel'
#                  'start':  101128
#                    'end':  101205
#                   'text':  'artikel 2.8.30 omtrent het afleggen van de eed,\r\nalleen de nietigheid van het'
#                'details':  OrderedDict([('artikel', '2.8.30')])
#
# Matched: 'artikel 2.8.41'
#                   'type':  'artikel'
#                  'start':  103735
#                    'end':  103749
#                   'text':  'artikel 2.8.41'
#                'details':  OrderedDict([('artikel', '2.8.41')])
#
# Matched: 'Artikel 2.1.10,\r\ntweede en derde lid'
#                   'type':  'artikel'
#                  'start':  104693
#                    'end':  104729
#                   'text':  'Artikel 2.1.10,\r\ntweede en derde lid'
#                'details':  OrderedDict([('artikel', '2.1.10'), ('lid', 'tweede en derde'), ('lid_num', [2, 3])])
#
# Matched: 'artikel 2.1.11, tweede lid, derde lid'
#                   'type':  'artikel'
#                  'start':  104734
#                    'end':  104771
#                   'text':  'artikel 2.1.11, tweede lid, derde lid'
#                'details':  OrderedDict([('artikel', '2.1.11'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 2.1.10, derde lid'
#                   'type':  'artikel'
#                  'start':  105100
#                    'end':  105125
#                   'text':  'artikel 2.1.10, derde lid'
#                'details':  OrderedDict([('artikel', '2.1.10'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 2.8.46, eerste lid'
#                   'type':  'artikel'
#                  'start':  107664
#                    'end':  107690
#                   'text':  'artikel 2.8.46, eerste lid'
#                'details':  OrderedDict([('artikel', '2.8.46'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 18'
#                   'type':  'artikel'
#                  'start':  107935
#                    'end':  107945
#                   'text':  'artikel 18'
#                'details':  OrderedDict([('artikel', '18')])
#
# Matched: 'artikel 18a van de'
#                   'type':  'artikel'
#                  'start':  107949
#                    'end':  107967
#                   'text':  'artikel 18a van de'
#                'details':  OrderedDict([('artikel', '18a')])
#
# Matched: 'artikel 25 van de'
#                   'type':  'artikel'
#                  'start':  108477
#                    'end':  108494
#                   'text':  'artikel 25 van de'
#                'details':  OrderedDict([('artikel', '25')])
#
# Matched: 'artikel 2.8.47'
#                   'type':  'artikel'
#                  'start':  108622
#                    'end':  108636
#                   'text':  'artikel 2.8.47'
#                'details':  OrderedDict([('artikel', '2.8.47')])
#
# Matched: 'artikel 2.8.47'
#                   'type':  'artikel'
#                  'start':  112299
#                    'end':  112313
#                   'text':  'artikel 2.8.47'
#                'details':  OrderedDict([('artikel', '2.8.47')])
#
# Matched: 'artikel 2.8.47, derde tot en met vijfde volzin,\r\nhet tweede lid'
#                   'type':  'artikel'
#                  'start':  112528
#                    'end':  112591
#                   'text':  'artikel 2.8.47, derde tot en met vijfde volzin,\r\nhet tweede lid'
#                'details':  OrderedDict([('artikel', '2.8.47'), ('volzin', 'vijfde'), ('lid', 'tweede'), ('lid_num', [2]), ('volzin_num', [5])])
#
# Matched: 'artikel\r\n2.8.22'
#                   'type':  'artikel'
#                  'start':  115022
#                    'end':  115037
#                   'text':  'artikel\r\n2.8.22'
#                'details':  OrderedDict([('artikel', '2.8.22')])
#
# Matched: 'artikel 2.8.50, het bedrag van de'
#                   'type':  'artikel'
#                  'start':  116891
#                    'end':  116924
#                   'text':  'artikel 2.8.50, het bedrag van de'
#                'details':  OrderedDict([('artikel', '2.8.50')])
#
# Matched: 'Artikel 2.11.14, derde\r\nlid'
#                   'type':  'artikel'
#                  'start':  117345
#                    'end':  117372
#                   'text':  'Artikel 2.11.14, derde\r\nlid'
#                'details':  OrderedDict([('artikel', '2.11.14'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 2.8.55'
#                   'type':  'artikel'
#                  'start':  117691
#                    'end':  117705
#                   'text':  'artikel 2.8.55'
#                'details':  OrderedDict([('artikel', '2.8.55')])
#
# Matched: 'artikel 2.4.7.'
#                   'type':  'artikel'
#                  'start':  119636
#                    'end':  119650
#                   'text':  'artikel 2.4.7.'
#                'details':  OrderedDict([('artikel', '2.4.7.')])
#
# Matched: 'artikel 2.4.7'
#                   'type':  'artikel'
#                  'start':  119704
#                    'end':  119717
#                   'text':  'artikel 2.4.7'
#                'details':  OrderedDict([('artikel', '2.4.7')])
#
# Matched: 'artikel 2.9.5'
#                   'type':  'artikel'
#                  'start':  120864
#                    'end':  120877
#                   'text':  'artikel 2.9.5'
#                'details':  OrderedDict([('artikel', '2.9.5')])
#
# Matched: 'Artikel 2.3.11'
#                   'type':  'artikel'
#                  'start':  122459
#                    'end':  122473
#                   'text':  'Artikel 2.3.11'
#                'details':  OrderedDict([('artikel', '2.3.11')])
#
# Matched: 'Artikel 2.9.13, tweede en derde lid'
#                   'type':  'artikel'
#                  'start':  123829
#                    'end':  123864
#                   'text':  'Artikel 2.9.13, tweede en derde lid'
#                'details':  OrderedDict([('artikel', '2.9.13'), ('lid', 'tweede en derde'), ('lid_num', [2, 3])])
#
# Matched: 'Artikel 2.10.1, derde en vierde lid'
#                   'type':  'artikel'
#                  'start':  126536
#                    'end':  126571
#                   'text':  'Artikel 2.10.1, derde en vierde lid'
#                'details':  OrderedDict([('artikel', '2.10.1'), ('lid', 'derde en vierde'), ('lid_num', [3, 4])])
#
# Matched: 'artikel 2.10.1, eerste lid'
#                   'type':  'artikel'
#                  'start':  126623
#                    'end':  126649
#                   'text':  'artikel 2.10.1, eerste lid'
#                'details':  OrderedDict([('artikel', '2.10.1'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'Artikel 2.10.3, tweede lid'
#                   'type':  'artikel'
#                  'start':  127858
#                    'end':  127884
#                   'text':  'Artikel 2.10.3, tweede lid'
#                'details':  OrderedDict([('artikel', '2.10.3'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 1.3.10, vijfde en zesde lid'
#                   'type':  'artikel'
#                  'start':  129961
#                    'end':  129996
#                   'text':  'Artikel 1.3.10, vijfde en zesde lid'
#                'details':  OrderedDict([('artikel', '1.3.10'), ('lid', 'vijfde en zesde'), ('lid_num', [5, 6])])
#
# Matched: 'artikel 2.8.47'
#                   'type':  'artikel'
#                  'start':  130927
#                    'end':  130941
#                   'text':  'artikel 2.8.47'
#                'details':  OrderedDict([('artikel', '2.8.47')])
#
# Matched: 'artikel 96, tweede lid, van Boek\r\n6 van het'
#                   'type':  'artikel'
#                  'start':  134694
#                    'end':  134737
#                   'text':  'artikel 96, tweede lid, van Boek\r\n6 van het'
#                'details':  OrderedDict([('artikel', '96'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 96, tweede lid, onder b en c, van Boek 6 van het'
#                   'type':  'artikel'
#                  'start':  134997
#                    'end':  135053
#                   'text':  'artikel 96, tweede lid, onder b en c, van Boek 6 van het'
#                'details':  OrderedDict([('artikel', '96'), ('lid', 'tweede'), ('aanhefonder', 'onder b'), ('lid_num', [2])])
#
# Matched: 'artikel 37 van de'
#                   'type':  'artikel'
#                  'start':  136268
#                    'end':  136285
#                   'text':  'artikel 37 van de'
#                'details':  OrderedDict([('artikel', '37')])
#
# Matched: 'Artikel 22 van de'
#                   'type':  'artikel'
#                  'start':  136539
#                    'end':  136556
#                   'text':  'Artikel 22 van de'
#                'details':  OrderedDict([('artikel', '22')])
#
# Matched: 'artikel 2.8.50, het bedrag van de'
#                   'type':  'artikel'
#                  'start':  136844
#                    'end':  136877
#                   'text':  'artikel 2.8.50, het bedrag van de'
#                'details':  OrderedDict([('artikel', '2.8.50')])
#
# Matched: 'Artikel 2.11.14, derde lid'
#                   'type':  'artikel'
#                  'start':  137344
#                    'end':  137370
#                   'text':  'Artikel 2.11.14, derde lid'
#                'details':  OrderedDict([('artikel', '2.11.14'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 2.8.50, het bedrag van de'
#                   'type':  'artikel'
#                  'start':  138621
#                    'end':  138654
#                   'text':  'artikel 2.8.50, het bedrag van de'
#                'details':  OrderedDict([('artikel', '2.8.50')])
#
# Matched: 'artikel 2.11.15, tweede lid'
#                   'type':  'artikel'
#                  'start':  138791
#                    'end':  138818
#                   'text':  'artikel 2.11.15, tweede lid'
#                'details':  OrderedDict([('artikel', '2.11.15'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 2.12.3, tweede lid'
#                   'type':  'artikel'
#                  'start':  139132
#                    'end':  139158
#                   'text':  'Artikel 2.12.3, tweede lid'
#                'details':  OrderedDict([('artikel', '2.12.3'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 316, tweede lid, van Boek 3 van het'
#                   'type':  'artikel'
#                  'start':  139585
#                    'end':  139628
#                   'text':  'artikel 316, tweede lid, van Boek 3 van het'
#                'details':  OrderedDict([('artikel', '316'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 2.12.3, tweede lid'
#                   'type':  'artikel'
#                  'start':  141625
#                    'end':  141651
#                   'text':  'Artikel 2.12.3, tweede lid'
#                'details':  OrderedDict([('artikel', '2.12.3'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 316, tweede lid, van Boek 3 van het'
#                   'type':  'artikel'
#                  'start':  141866
#                    'end':  141909
#                   'text':  'artikel 316, tweede lid, van Boek 3 van het'
#                'details':  OrderedDict([('artikel', '316'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 2.1.2, tweede lid'
#                   'type':  'artikel'
#                  'start':  143159
#                    'end':  143184
#                   'text':  'artikel 2.1.2, tweede lid'
#                'details':  OrderedDict([('artikel', '2.1.2'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 2.1.2'
#                   'type':  'artikel'
#                  'start':  143900
#                    'end':  143913
#                   'text':  'Artikel 2.1.2'
#                'details':  OrderedDict([('artikel', '2.1.2')])
#
# Matched: 'artikel 50, eerste lid, van de'
#                   'type':  'artikel'
#                  'start':  144030
#                    'end':  144060
#                   'text':  'artikel 50, eerste lid, van de'
#                'details':  OrderedDict([('artikel', '50'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'Trb. 1995, 130'
#                   'type':  'vindplaats'
#                  'start':  144224
#                    'end':  144238
#                   'text':  'Trb. 1995, 130'
#                'details':  {'what': 'Trb', 'jaar': '1995', 'nummer': '130'}
#
# Matched: 'Artikel 3.4.1'
#                   'type':  'artikel'
#                  'start':  153196
#                    'end':  153209
#                   'text':  'Artikel 3.4.1'
#                'details':  OrderedDict([('artikel', '3.4.1')])
#
# Matched: 'Artikel 2.4.6'
#                   'type':  'artikel'
#                  'start':  154374
#                    'end':  154387
#                   'text':  'Artikel 2.4.6'
#                'details':  OrderedDict([('artikel', '2.4.6')])
#
# Matched: 'artikel 2.8.17, tweede lid, onder\r\na'
#                   'type':  'artikel'
#                  'start':  154775
#                    'end':  154811
#                   'text':  'artikel 2.8.17, tweede lid, onder\r\na'
#                'details':  OrderedDict([('artikel', '2.8.17'), ('lid', 'tweede'), ('aanhefonder', 'onder\r\na'), ('lid_num', [2])])
#
# Matched: 'artikel 2.11.2, eerste en derde lid'
#                   'type':  'artikel'
#                  'start':  156596
#                    'end':  156631
#                   'text':  'artikel 2.11.2, eerste en derde lid'
#                'details':  OrderedDict([('artikel', '2.11.2'), ('lid', 'eerste en derde'), ('lid_num', [1, 3])])
#
# Matched: 'artikel 2.11.2,\r\ntweede lid'
#                   'type':  'artikel'
#                  'start':  156806
#                    'end':  156833
#                   'text':  'artikel 2.11.2,\r\ntweede lid'
#                'details':  OrderedDict([('artikel', '2.11.2'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 1.3.10, vijfde en zesde lid'
#                   'type':  'artikel'
#                  'start':  158062
#                    'end':  158097
#                   'text':  'Artikel 1.3.10, vijfde en zesde lid'
#                'details':  OrderedDict([('artikel', '1.3.10'), ('lid', 'vijfde en zesde'), ('lid_num', [5, 6])])
#
# Matched: 'Artikel 331, tweede lid'
#                   'type':  'artikel'
#                  'start':  158527
#                    'end':  158550
#                   'text':  'Artikel 331, tweede lid'
#                'details':  OrderedDict([('artikel', '331'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 332'
#                   'type':  'artikel'
#                  'start':  158727
#                    'end':  158738
#                   'text':  'Artikel 332'
#                'details':  OrderedDict([('artikel', '332')])
#
# Matched: 'artikel 1.8.3, tweede lid'
#                   'type':  'artikel'
#                  'start':  160167
#                    'end':  160192
#                   'text':  'artikel 1.8.3, tweede lid'
#                'details':  OrderedDict([('artikel', '1.8.3'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 332'
#                   'type':  'artikel'
#                  'start':  160310
#                    'end':  160321
#                   'text':  'artikel 332'
#                'details':  OrderedDict([('artikel', '332')])
#
# Matched: 'artikel 43 van de'
#                   'type':  'artikel'
#                  'start':  160586
#                    'end':  160603
#                   'text':  'artikel 43 van de'
#                'details':  OrderedDict([('artikel', '43')])
#
# Matched: 'artikel 332'
#                   'type':  'artikel'
#                  'start':  160728
#                    'end':  160739
#                   'text':  'artikel 332'
#                'details':  OrderedDict([('artikel', '332')])
#
# Matched: 'Artikel 335'
#                   'type':  'artikel'
#                  'start':  160764
#                    'end':  160775
#                   'text':  'Artikel 335'
#                'details':  OrderedDict([('artikel', '335')])
#
# Matched: 'artikel 2.6.2, tweede lid'
#                   'type':  'artikel'
#                  'start':  161048
#                    'end':  161073
#                   'text':  'artikel 2.6.2, tweede lid'
#                'details':  OrderedDict([('artikel', '2.6.2'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 336'
#                   'type':  'artikel'
#                  'start':  161259
#                    'end':  161270
#                   'text':  'Artikel 336'
#                'details':  OrderedDict([('artikel', '336')])
#
# Matched: 'Artikel 337'
#                   'type':  'artikel'
#                  'start':  161282
#                    'end':  161293
#                   'text':  'Artikel 337'
#                'details':  OrderedDict([('artikel', '337')])
#
# Matched: 'artikel 1.8.6, eerste lid'
#                   'type':  'artikel'
#                  'start':  161630
#                    'end':  161655
#                   'text':  'artikel 1.8.6, eerste lid'
#                'details':  OrderedDict([('artikel', '1.8.6'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'Artikel 339'
#                   'type':  'artikel'
#                  'start':  161678
#                    'end':  161689
#                   'text':  'Artikel 339'
#                'details':  OrderedDict([('artikel', '339')])
#
# Matched: 'artikel 341'
#                   'type':  'artikel'
#                  'start':  162538
#                    'end':  162549
#                   'text':  'artikel 341'
#                'details':  OrderedDict([('artikel', '341')])
#
# Matched: 'Artikel 343'
#                   'type':  'artikel'
#                  'start':  162599
#                    'end':  162610
#                   'text':  'Artikel 343'
#                'details':  OrderedDict([('artikel', '343')])
#
# Matched: 'Artikel 344 wordt als volgt gewijzigd: 1.  In het eerste lid'
#                   'type':  'artikel'
#                  'start':  162856
#                    'end':  162916
#                   'text':  'Artikel 344 wordt als volgt gewijzigd: 1.  In het eerste lid'
#                'details':  OrderedDict([('artikel', '344'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'Artikel 344a'
#                   'type':  'artikel'
#                  'start':  163121
#                    'end':  163133
#                   'text':  'Artikel 344a'
#                'details':  OrderedDict([('artikel', '344a')])
#
# Matched: 'Artikel 345'
#                   'type':  'artikel'
#                  'start':  163145
#                    'end':  163156
#                   'text':  'Artikel 345'
#                'details':  OrderedDict([('artikel', '345')])
#
# Matched: 'Artikel 347 wordt als volgt gewijzigd: 1.  Het eerste lid'
#                   'type':  'artikel'
#                  'start':  163168
#                    'end':  163225
#                   'text':  'Artikel 347 wordt als volgt gewijzigd: 1.  Het eerste lid'
#                'details':  OrderedDict([('artikel', '347'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 348'
#                   'type':  'artikel'
#                  'start':  163360
#                    'end':  163371
#                   'text':  'artikel 348'
#                'details':  OrderedDict([('artikel', '348')])
#
# Matched: 'artikel 141'
#                   'type':  'artikel'
#                  'start':  163379
#                    'end':  163390
#                   'text':  'artikel 141'
#                'details':  OrderedDict([('artikel', '141')])
#
# Matched: 'artikel\r\n2.4.4.'
#                   'type':  'artikel'
#                  'start':  163408
#                    'end':  163423
#                   'text':  'artikel\r\n2.4.4.'
#                'details':  OrderedDict([('artikel', '2.4.4.')])
#
# Matched: 'artikel 350'
#                   'type':  'artikel'
#                  'start':  163429
#                    'end':  163440
#                   'text':  'artikel 350'
#                'details':  OrderedDict([('artikel', '350')])
#
# Matched: 'Artikel 353 wordt als volgt gewijzigd: 1.  Het eerste lid'
#                   'type':  'artikel'
#                  'start':  163693
#                    'end':  163750
#                   'text':  'Artikel 353 wordt als volgt gewijzigd: 1.  Het eerste lid'
#                'details':  OrderedDict([('artikel', '353'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 2.4.7'
#                   'type':  'artikel'
#                  'start':  164008
#                    'end':  164021
#                   'text':  'artikel 2.4.7'
#                'details':  OrderedDict([('artikel', '2.4.7')])
#
# Matched: 'artikel 2.9.17. 3.  In het tweede lid'
#                   'type':  'artikel'
#                  'start':  164190
#                    'end':  164227
#                   'text':  'artikel 2.9.17. 3.  In het tweede lid'
#                'details':  OrderedDict([('artikel', '2.9.17.'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel.'
#                   'type':  'artikel'
#                  'start':  164283
#                    'end':  164291
#                   'text':  'artikel.'
#                'details':  OrderedDict([('artikel', '.')])
#
# Matched: 'Artikel 355'
#                   'type':  'artikel'
#                  'start':  164294
#                    'end':  164305
#                   'text':  'Artikel 355'
#                'details':  OrderedDict([('artikel', '355')])
#
# Matched: 'Artikel 356'
#                   'type':  'artikel'
#                  'start':  164693
#                    'end':  164704
#                   'text':  'Artikel 356'
#                'details':  OrderedDict([('artikel', '356')])
#
# Matched: 'Artikel 357 vervalt. Y Aan het slot van de'
#                   'type':  'artikel'
#                  'start':  164882
#                    'end':  164924
#                   'text':  'Artikel 357 vervalt. Y Aan het slot van de'
#                'details':  OrderedDict([('artikel', '357')])
#
# Matched: 'artikel 3.1.1'
#                   'type':  'artikel'
#                  'start':  165089
#                    'end':  165102
#                   'text':  'artikel 3.1.1'
#                'details':  OrderedDict([('artikel', '3.1.1')])
#
# Matched: 'artikel 1.8.6, eerste lid'
#                   'type':  'artikel'
#                  'start':  165936
#                    'end':  165961
#                   'text':  'artikel 1.8.6, eerste lid'
#                'details':  OrderedDict([('artikel', '1.8.6'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 3.4.1, eerste lid'
#                   'type':  'artikel'
#                  'start':  166387
#                    'end':  166412
#                   'text':  'artikel 3.4.1, eerste lid'
#                'details':  OrderedDict([('artikel', '3.4.1'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 3.4.8'
#                   'type':  'artikel'
#                  'start':  168113
#                    'end':  168126
#                   'text':  'artikel 3.4.8'
#                'details':  OrderedDict([('artikel', '3.4.8')])
#
# Matched: 'artikel 341'
#                   'type':  'artikel'
#                  'start':  169133
#                    'end':  169144
#                   'text':  'artikel 341'
#                'details':  OrderedDict([('artikel', '341')])
#
# Matched: 'artikel 2.3.1'
#                   'type':  'artikel'
#                  'start':  169704
#                    'end':  169717
#                   'text':  'artikel 2.3.1'
#                'details':  OrderedDict([('artikel', '2.3.1')])
#
# Matched: 'artikel 382,\r\ntenzij de aard van de'
#                   'type':  'artikel'
#                  'start':  170810
#                    'end':  170845
#                   'text':  'artikel 382,\r\ntenzij de aard van de'
#                'details':  OrderedDict([('artikel', '382')])
#
# Matched: 'Artikel 401'
#                   'type':  'artikel'
#                  'start':  171150
#                    'end':  171161
#                   'text':  'Artikel 401'
#                'details':  OrderedDict([('artikel', '401')])
#
# Matched: 'Artikel 401a'
#                   'type':  'artikel'
#                  'start':  171174
#                    'end':  171186
#                   'text':  'Artikel 401a'
#                'details':  OrderedDict([('artikel', '401a')])
#
# Matched: 'artikel 1.8.6, eerste lid'
#                   'type':  'artikel'
#                  'start':  171521
#                    'end':  171546
#                   'text':  'artikel 1.8.6, eerste lid'
#                'details':  OrderedDict([('artikel', '1.8.6'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 402 wordt een derde lid'
#                   'type':  'artikel'
#                  'start':  171575
#                    'end':  171606
#                   'text':  'artikel 402 wordt een derde lid'
#                'details':  OrderedDict([('artikel', '402'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 403, tweede lid'
#                   'type':  'artikel'
#                  'start':  171925
#                    'end':  171948
#                   'text':  'artikel 403, tweede lid'
#                'details':  OrderedDict([('artikel', '403'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 407 wordt als volgt gewijzigd: 1.  In het tweede lid wordt «artikel 5, onder 3'
#                   'type':  'artikel'
#                  'start':  172000
#                    'end':  172086
#                   'text':  'Artikel 407 wordt als volgt gewijzigd: 1.  In het tweede lid wordt «artikel 5, onder 3'
#                'details':  OrderedDict([('artikel', '407'), ('lid', 'tweede'), ('aanhefonder', 'onder 3'), ('lid_num', [2])])
#
# Matched: 'artikel 5, onder 3'
#                   'type':  'artikel'
#                  'start':  172068
#                    'end':  172086
#                   'text':  'artikel 5, onder 3'
#                'details':  OrderedDict([('artikel', '5'), ('aanhefonder', 'onder 3')])
#
# Matched: 'artikel 2.3.1, tweede lid, onder d. 2.  Het vijfde lid'
#                   'type':  'artikel'
#                  'start':  172106
#                    'end':  172160
#                   'text':  'artikel 2.3.1, tweede lid, onder d. 2.  Het vijfde lid'
#                'details':  OrderedDict([('artikel', '2.3.1'), ('lid', 'vijfde'), ('aanhefonder', 'onder d'), ('lid_num', [5])])
#
# Matched: 'Artikel 408a, vierde lid'
#                   'type':  'artikel'
#                  'start':  172173
#                    'end':  172197
#                   'text':  'Artikel 408a, vierde lid'
#                'details':  OrderedDict([('artikel', '408a'), ('lid', 'vierde'), ('lid_num', [4])])
#
# Matched: 'artikel 411, derde lid'
#                   'type':  'artikel'
#                  'start':  172214
#                    'end':  172236
#                   'text':  'artikel 411, derde lid'
#                'details':  OrderedDict([('artikel', '411'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 141'
#                   'type':  'artikel'
#                  'start':  172245
#                    'end':  172256
#                   'text':  'artikel 141'
#                'details':  OrderedDict([('artikel', '141')])
#
# Matched: 'artikel 2.4.4.'
#                   'type':  'artikel'
#                  'start':  172275
#                    'end':  172289
#                   'text':  'artikel 2.4.4.'
#                'details':  OrderedDict([('artikel', '2.4.4.')])
#
# Matched: 'artikel 414, eerste lid'
#                   'type':  'artikel'
#                  'start':  172296
#                    'end':  172319
#                   'text':  'artikel 414, eerste lid'
#                'details':  OrderedDict([('artikel', '414'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'Artikel 2.9.17'
#                   'type':  'artikel'
#                  'start':  172387
#                    'end':  172401
#                   'text':  'Artikel 2.9.17'
#                'details':  OrderedDict([('artikel', '2.9.17')])
#
# Matched: 'Artikel 418 wordt als volgt gewijzigd: 1.  Het eerste lid'
#                   'type':  'artikel'
#                  'start':  172409
#                    'end':  172466
#                   'text':  'Artikel 418 wordt als volgt gewijzigd: 1.  Het eerste lid'
#                'details':  OrderedDict([('artikel', '418'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'Artikel 418a'
#                   'type':  'artikel'
#                  'start':  172707
#                    'end':  172719
#                   'text':  'Artikel 418a'
#                'details':  OrderedDict([('artikel', '418a')])
#
# Matched: 'artikel 2.4.1'
#                   'type':  'artikel'
#                  'start':  172904
#                    'end':  172917
#                   'text':  'artikel 2.4.1'
#                'details':  OrderedDict([('artikel', '2.4.1')])
#
# Matched: 'artikel 2.9.17'
#                   'type':  'artikel'
#                  'start':  172960
#                    'end':  172974
#                   'text':  'artikel 2.9.17'
#                'details':  OrderedDict([('artikel', '2.9.17')])
#
# Matched: 'artikel 422a'
#                   'type':  'artikel'
#                  'start':  173065
#                    'end':  173077
#                   'text':  'artikel 422a'
#                'details':  OrderedDict([('artikel', '422a')])
#
# ...
#                  'start':  192408
#                    'end':  192431
#                   'text':  'artikel 858, vierde lid'
#                'details':  OrderedDict([('artikel', '858'), ('lid', 'vierde'), ('lid_num', [4])])
#
# Matched: 'artikel 797a'
#                   'type':  'artikel'
#                  'start':  192440
#                    'end':  192452
#                   'text':  'artikel 797a'
#                'details':  OrderedDict([('artikel', '797a')])
#
# Matched: 'artikel 856.'
#                   'type':  'artikel'
#                  'start':  192471
#                    'end':  192483
#                   'text':  'artikel 856.'
#                'details':  OrderedDict([('artikel', '856.')])
#
# Matched: 'artikel 861, tweede lid'
#                   'type':  'artikel'
#                  'start':  192490
#                    'end':  192513
#                   'text':  'artikel 861, tweede lid'
#                'details':  OrderedDict([('artikel', '861'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 988, derde lid'
#                   'type':  'artikel'
#                  'start':  192568
#                    'end':  192590
#                   'text':  'artikel 988, derde lid'
#                'details':  OrderedDict([('artikel', '988'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 995, tweede lid'
#                   'type':  'artikel'
#                  'start':  192684
#                    'end':  192707
#                   'text':  'artikel 995, tweede lid'
#                'details':  OrderedDict([('artikel', '995'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 429d'
#                   'type':  'artikel'
#                  'start':  192716
#                    'end':  192728
#                   'text':  'artikel 429d'
#                'details':  OrderedDict([('artikel', '429d')])
#
# Matched: 'artikel 3.4.1.'
#                   'type':  'artikel'
#                  'start':  192747
#                    'end':  192761
#                   'text':  'artikel 3.4.1.'
#                'details':  OrderedDict([('artikel', '3.4.1.')])
#
# Matched: 'artikel 996'
#                   'type':  'artikel'
#                  'start':  192769
#                    'end':  192780
#                   'text':  'artikel 996'
#                'details':  OrderedDict([('artikel', '996')])
#
# Matched: 'artikel 1001'
#                   'type':  'artikel'
#                  'start':  192973
#                    'end':  192985
#                   'text':  'artikel 1001'
#                'details':  OrderedDict([('artikel', '1001')])
#
# Matched: 'artikel 2.3.2'
#                   'type':  'artikel'
#                  'start':  193031
#                    'end':  193044
#                   'text':  'artikel 2.3.2'
#                'details':  OrderedDict([('artikel', '2.3.2')])
#
# Matched: 'artikel 1003'
#                   'type':  'artikel'
#                  'start':  193185
#                    'end':  193197
#                   'text':  'artikel 1003'
#                'details':  OrderedDict([('artikel', '1003')])
#
# Matched: 'artikel 5, eerste lid'
#                   'type':  'artikel'
#                  'start':  193214
#                    'end':  193235
#                   'text':  'artikel 5, eerste lid'
#                'details':  OrderedDict([('artikel', '5'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 2.3.1, tweede lid'
#                   'type':  'artikel'
#                  'start':  193254
#                    'end':  193279
#                   'text':  'artikel 2.3.1, tweede lid'
#                'details':  OrderedDict([('artikel', '2.3.1'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 1004'
#                   'type':  'artikel'
#                  'start':  193287
#                    'end':  193299
#                   'text':  'artikel 1004'
#                'details':  OrderedDict([('artikel', '1004')])
#
# Matched: 'artikel 429d'
#                   'type':  'artikel'
#                  'start':  193307
#                    'end':  193319
#                   'text':  'artikel 429d'
#                'details':  OrderedDict([('artikel', '429d')])
#
# Matched: 'artikel\r\n3.4.1.'
#                   'type':  'artikel'
#                  'start':  193337
#                    'end':  193352
#                   'text':  'artikel\r\n3.4.1.'
#                'details':  OrderedDict([('artikel', '3.4.1.')])
#
# Matched: 'Artikel 1005'
#                   'type':  'artikel'
#                  'start':  193356
#                    'end':  193368
#                   'text':  'Artikel 1005'
#                'details':  OrderedDict([('artikel', '1005')])
#
# Matched: 'artikel 240 van Boek 6 van het\r\nBurgerlijk Wetboek'
#                   'type':  'artikel'
#                  'start':  193441
#                    'end':  193491
#                   'text':  'artikel 240 van Boek 6 van het\r\nBurgerlijk Wetboek'
#                'details':  OrderedDict([('artikel', '240'), ('nameref', '\r\nBurgerlijk Wetboek')])
#
# Matched: 'artikel 1003 onder 1'
#                   'type':  'artikel'
#                  'start':  193506
#                    'end':  193526
#                   'text':  'artikel 1003 onder 1'
#                'details':  OrderedDict([('artikel', '1003'), ('aanhefonder', 'onder 1')])
#
# Matched: 'artikel 1006, onder 1'
#                   'type':  'artikel'
#                  'start':  193693
#                    'end':  193714
#                   'text':  'artikel 1006, onder 1'
#                'details':  OrderedDict([('artikel', '1006'), ('aanhefonder', 'onder 1')])
#
# Matched: 'artikel 429k, tweede lid'
#                   'type':  'artikel'
#                  'start':  193768
#                    'end':  193792
#                   'text':  'artikel 429k, tweede lid'
#                'details':  OrderedDict([('artikel', '429k'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 1022'
#                   'type':  'artikel'
#                  'start':  193974
#                    'end':  193986
#                   'text':  'Artikel 1022'
#                'details':  OrderedDict([('artikel', '1022')])
#
# Matched: 'artikel 289'
#                   'type':  'artikel'
#                  'start':  194043
#                    'end':  194054
#                   'text':  'artikel 289'
#                'details':  OrderedDict([('artikel', '289')])
#
# Matched: 'artikel\r\n2.13.1. 2.  Toegevoegd wordt een derde lid'
#                   'type':  'artikel'
#                  'start':  194072
#                    'end':  194123
#                   'text':  'artikel\r\n2.13.1. 2.  Toegevoegd wordt een derde lid'
#                'details':  OrderedDict([('artikel', '2.13.1.'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'Artikel 2.8.40, eerste lid'
#                   'type':  'artikel'
#                  'start':  194407
#                    'end':  194433
#                   'text':  'Artikel 2.8.40, eerste lid'
#                'details':  OrderedDict([('artikel', '2.8.40'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel\r\n289'
#                   'type':  'artikel'
#                  'start':  194570
#                    'end':  194582
#                   'text':  'artikel\r\n289'
#                'details':  OrderedDict([('artikel', '289')])
#
# Matched: 'artikel 2.13.1.'
#                   'type':  'artikel'
#                  'start':  194608
#                    'end':  194623
#                   'text':  'artikel 2.13.1.'
#                'details':  OrderedDict([('artikel', '2.13.1.')])
#
# Matched: 'artikel 1062, vierde lid'
#                   'type':  'artikel'
#                  'start':  194629
#                    'end':  194653
#                   'text':  'artikel 1062, vierde lid'
#                'details':  OrderedDict([('artikel', '1062'), ('lid', 'vierde'), ('lid_num', [4])])
#
# Matched: 'artikel 1064, eerste lid'
#                   'type':  'artikel'
#                  'start':  194844
#                    'end':  194868
#                   'text':  'artikel 1064, eerste lid'
#                'details':  OrderedDict([('artikel', '1064'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'Artikel 1068'
#                   'type':  'artikel'
#                  'start':  194924
#                    'end':  194936
#                   'text':  'Artikel 1068'
#                'details':  OrderedDict([('artikel', '1068')])
#
# Matched: 'artikel\r\n1064, derde lid'
#                   'type':  'artikel'
#                  'start':  195138
#                    'end':  195162
#                   'text':  'artikel\r\n1064, derde lid'
#                'details':  OrderedDict([('artikel', '1064'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 1064.'
#                   'type':  'artikel'
#                  'start':  195475
#                    'end':  195488
#                   'text':  'artikel 1064.'
#                'details':  OrderedDict([('artikel', '1064.')])
#
# Matched: 'artikel 341'
#                   'type':  'artikel'
#                  'start':  195616
#                    'end':  195627
#                   'text':  'artikel 341'
#                'details':  OrderedDict([('artikel', '341')])
#
# Matched: 'artikel 2.3.1'
#                   'type':  'artikel'
#                  'start':  195738
#                    'end':  195751
#                   'text':  'artikel 2.3.1'
#                'details':  OrderedDict([('artikel', '2.3.1')])
#
# Matched: 'Artikel 1066'
#                   'type':  'artikel'
#                  'start':  195845
#                    'end':  195857
#                   'text':  'Artikel 1066'
#                'details':  OrderedDict([('artikel', '1066')])
#
# Matched: 'Artikel 1067'
#                   'type':  'artikel'
#                  'start':  196029
#                    'end':  196041
#                   'text':  'Artikel 1067'
#                'details':  OrderedDict([('artikel', '1067')])
#
# Matched: 'artikel 1077»\r\ngeplaatst. 2.  Het eerste lid'
#                   'type':  'artikel'
#                  'start':  196245
#                    'end':  196289
#                   'text':  'artikel 1077»\r\ngeplaatst. 2.  Het eerste lid'
#                'details':  OrderedDict([('artikel', '1077'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 10'
#                   'type':  'artikel'
#                  'start':  196504
#                    'end':  196514
#                   'text':  'artikel 10'
#                'details':  OrderedDict([('artikel', '10')])
#
# Matched: 'Artikel 38'
#                   'type':  'artikel'
#                  'start':  196650
#                    'end':  196660
#                   'text':  'Artikel 38'
#                'details':  OrderedDict([('artikel', '38')])
#
# Matched: 'Artikel 43'
#                   'type':  'artikel'
#                  'start':  197725
#                    'end':  197735
#                   'text':  'Artikel 43'
#                'details':  OrderedDict([('artikel', '43')])
#
# Matched: 'artikel 43a'
#                   'type':  'artikel'
#                  'start':  198039
#                    'end':  198050
#                   'text':  'artikel 43a'
#                'details':  OrderedDict([('artikel', '43a')])
#
# Matched: 'artikel 49 vervalt de aanduiding «1.» voor de tekst van\r\nhet eerste lid. Het tweede en derde lid'
#                   'type':  'artikel'
#                  'start':  198106
#                    'end':  198202
#                   'text':  'artikel 49 vervalt de aanduiding «1.» voor de tekst van\r\nhet eerste lid. Het tweede en derde lid'
#                'details':  OrderedDict([('artikel', '49'), ('lid', 'tweede en derde'), ('lid_num', [2, 3])])
#
# Matched: 'Artikel 53'
#                   'type':  'artikel'
#                  'start':  198216
#                    'end':  198226
#                   'text':  'Artikel 53'
#                'details':  OrderedDict([('artikel', '53')])
#
# Matched: 'Artikel 54'
#                   'type':  'artikel'
#                  'start':  198391
#                    'end':  198401
#                   'text':  'Artikel 54'
#                'details':  OrderedDict([('artikel', '54')])
#
# Matched: 'artikel 8:9\r\nvan de'
#                   'type':  'artikel'
#                  'start':  199033
#                    'end':  199052
#                   'text':  'artikel 8:9\r\nvan de'
#                'details':  OrderedDict([('artikel', '8:9')])
#
# Matched: 'Artikel 69'
#                   'type':  'artikel'
#                  'start':  199953
#                    'end':  199963
#                   'text':  'Artikel 69'
#                'details':  OrderedDict([('artikel', '69')])
#
# Matched: 'artikel 70, tweede lid'
#                   'type':  'artikel'
#                  'start':  199978
#                    'end':  200000
#                   'text':  'artikel 70, tweede lid'
#                'details':  OrderedDict([('artikel', '70'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 72, zesde lid'
#                   'type':  'artikel'
#                  'start':  200116
#                    'end':  200137
#                   'text':  'artikel 72, zesde lid'
#                'details':  OrderedDict([('artikel', '72'), ('lid', 'zesde'), ('lid_num', [6])])
#
# Matched: 'artikel 88, eerste lid'
#                   'type':  'artikel'
#                  'start':  200221
#                    'end':  200243
#                   'text':  'artikel 88, eerste lid'
#                'details':  OrderedDict([('artikel', '88'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 96, eerste lid'
#                   'type':  'artikel'
#                  'start':  200409
#                    'end':  200431
#                   'text':  'artikel 96, eerste lid'
#                'details':  OrderedDict([('artikel', '96'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 398, tweede\r\nlid'
#                   'type':  'artikel'
#                  'start':  200452
#                    'end':  200476
#                   'text':  'artikel 398, tweede\r\nlid'
#                'details':  OrderedDict([('artikel', '398'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 398'
#                   'type':  'artikel'
#                  'start':  200494
#                    'end':  200505
#                   'text':  'artikel 398'
#                'details':  OrderedDict([('artikel', '398')])
#
# Matched: 'Artikel 100'
#                   'type':  'artikel'
#                  'start':  200527
#                    'end':  200538
#                   'text':  'Artikel 100'
#                'details':  OrderedDict([('artikel', '100')])
#
# Matched: 'Artikel 102'
#                   'type':  'artikel'
#                  'start':  201200
#                    'end':  201211
#                   'text':  'Artikel 102'
#                'details':  OrderedDict([('artikel', '102')])
#
# Matched: 'Stb. 481.'
#                   'type':  'vindplaats'
#                  'start':  204195
#                    'end':  204204
#                   'text':  'Stb. 481.'
#                'details':  {'what': 'Stb', 'jaar': '481.', 'nummer': None}
#
# Matched: 'Stb. 1999, 195'
#                   'type':  'vindplaats'
#                  'start':  204205
#                    'end':  204219
#                   'text':  'Stb. 1999, 195'
#                'details':  {'what': 'Stb', 'jaar': '1999', 'nummer': '195'}
#
# Matched: 'Stb. 494.'
#                   'type':  'vindplaats'
#                  'start':  204276
#                    'end':  204285
#                   'text':  'Stb. 494.'
#                'details':  {'what': 'Stb', 'jaar': '494.', 'nummer': None}
#
# Matched: 'Kamerstukken II 1999/2000, 2000'
#                   'type':  'kamerstukken'
#                  'start':  204333
#                    'end':  204364
#                   'text':  'Kamerstukken II 1999/2000, 2000'
#
# Matched: 'Handelingen II 2000/2001, blz. 4225'
#                   'type':  'kamerstukken'
#                  'start':  204390
#                    'end':  204425
#                   'text':  'Handelingen II 2000/2001, blz. 4225'
#
# Matched: 'Kamerstukken I 2000/2001, 26'
#                   'type':  'kamerstukken'
#                  'start':  204438
#                    'end':  204466
#                   'text':  'Kamerstukken I 2000/2001, 26'
#
# Matched: 'Handelingen I 2001/2002'
#                   'type':  'kamerstukken'
#                  'start':  204524
#                    'end':  204547
#                   'text':  'Handelingen I 2001/2002'

# %% [markdown]
# ## Marking this up in spacy
#
# In visualizations it might be useful to mark them in the document,
# as if they are (named) entities (note to self: spanruler style might make more sense).

# %%
import spacy, spacy.displacy
dutch = spacy.load('nl_core_news_lg')

# %%
test_texts = [
    # different types
    " BWBR000011  CVDR101405  CVDR101405_1 CVDR101405/1  Stb. 2011, 35;  33684R2020  ECLI:NL:HR:2005:AT4537   OJ L 69, 13.3.2013, p. 1  Council Directive 93/42/EEC of 14 June 1993   LJNs: BO6106  AO7817, NJ 2005, 270 ",
    # varied 'artikel' style cases
    '\n'.join(looser_testcases),
    # 
    'art. 2.12, eerste lid, aanhef en onder a, sub 1º artikel 79, aanhef en onder 6º artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo',
    htmltext[35500:37000], # a fragment of it, we get the idea
]

for test_text in test_texts:
    print( '-'*80 )

    doc = dutch( test_text )
    # note that you have to give exactly the same string to find_references and mark_references_spacy,
    # or the offsets will be wrong;   we use doc.text which should ensure that
    matches = wetsuite.helpers.patterns.find_references( doc.text, ljn=True) 
    wetsuite.helpers.patterns.mark_references_spacy( doc, matches )
    spacy.displacy.render( doc, style='ent', jupyter=True,
        # these are not the regular entity names displacy already chose some colors for, so:
        options={"colors":{'ECLI':'#ffaaaa', 'BWB':'#ff5577', 'CVDR':'#7755ff', 'CELEX':'#ffaaff', 'VINDPLAATS':'#aaaaff', 'EUOJ':'#aaffaa', 'EUDIR':'#aaffdd', 'LJN':'#5588ff', 'ARTIKEL':'#ffaa77'}}
    )

    #for reference in wetsuite.helpers.patterns.find_references( test_text, ljn=True ):
    #    print()
    #    pprint.pprint( reference )
# Out:
# --------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff5577; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BWBR000011
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BWB</span>
# </mark>
#
# <mark class="entity" style="background: #7755ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CVDR101405
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CVDR</span>
# </mark>
#
# <mark class="entity" style="background: #7755ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CVDR101405_1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CVDR</span>
# </mark>
#
# <mark class="entity" style="background: #7755ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CVDR101405/1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CVDR</span>
# </mark>
#
# <mark class="entity" style="background: #aaaaff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stb. 2011, 35
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VINDPLAATS</span>
# </mark>
# ;
# <mark class="entity" style="background: #ffaaff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     33684R2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELEX</span>
# </mark>
#
# <mark class="entity" style="background: #ffaaaa; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ECLI:NL:HR:2005:AT4537
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ECLI</span>
# </mark>
#
# <mark class="entity" style="background: #aaffaa; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OJ L 69, 13.3.2013, p. 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EUOJ</span>
# </mark>
#
# <mark class="entity" style="background: #aaffdd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Council Directive 93/42/EEC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EUDIR</span>
# </mark>
#  of 14 June 1993   LJNs:
# <mark class="entity" style="background: #5588ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BO6106
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LJN</span>
# </mark>
#
# <mark class="entity" style="background: #5588ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AO7817
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LJN</span>
# </mark>
# , NJ 2005, 270 </div></span>
# --------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 8:75a, eerste lid, tweede volzin, van de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  Awb</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 5:9, aanhef en onder b
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# , Awb</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 8, aanhef en onder c
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# , Wet bescherming persoonsgegevens (Wbp).</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 10, tweede lid, aanhef en onder e, van de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  Wob</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 4, tweede lid, aanhef en onder d, van het
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  reglement van orde voor de ministerraad</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artikel 10, tweede lid, aanhef en onder e van de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# . Wet openbaarheid van bestuur</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 6:80 lid 1 aanhef en onder b
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  BW</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 4, aanhef en onder d en g, van de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  standaardvoorwaarden</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 3.3, zevende lid, aanhef en onder i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# , Woo</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 15, aanhef en onder a
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  of c (oud) RWN</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 81q lid 3c
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  Gemeentewet  </br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 4:25, 4:35 van de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  Awb en
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 10 van de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  ASV</br>Wabo,
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 2.12, eerste lid, aanhef en onder a, sub 1º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 79, aanhef en onder 6º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# , Woo</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 142, eerste lid, aanhef en onder b (en derde lid), van het
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  Wetboek van Strafvordering</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 2, eerste, tweede, vijfde, en zesenzestigste lid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 166 lid 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  in verbinding met
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 353 lid 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  Rv</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 13, derde lid, van de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  Wet tarieven in burgerlijke zaken</br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 7, eerste lid, onderdeel a
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 7, eerst
# --------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 2.12, eerste lid, aanhef en onder a, sub 1º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 79, aanhef en onder 6º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# , Woo</div></span>
# --------------------------------------------------------------------------------
# </br>bedoeld in
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 1.6.10, tweede en vierde lid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# </br>stukken in burgerlijke en in handelszaken (
# <mark class="entity" style="background: #aaaaff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trb. 1966, 91
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VINDPLAATS</span>
# </mark>
# </br>dan wordt het exploot geacht te zijn gedaan aan hem in persoon. 1.  Ten aan</div></span>

# %% [markdown]
# ## Going further?
#
# It would be quite interesting that if
#
# - we resolved what it's pointing to, e.g. made input like `"artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad"` give any or all of:
#    - BWBR0006501
#    - https://wetten.overheid.nl/jci1.3:c:BWBR0006501&artikel=4    or
#      https://wetten.overheid.nl/jci1.3:c:BWBR0006501&paragraaf=2&artikel=4
#    - jci1.3:c:BWBR0006501&paragraaf=2&artikel=4
#    - ['4',
#       '2',
#       'Te dien einde beraadslaagt en besluit de raad onder meer over:',
#       'het bekendheid geven aan beleidsvoornemens in welke vorm dan ook, die van invloed kunnen zijn op de positie van het kabinet, '
#       'of die belangrijke financiële consequenties kunnen hebben, benevens over beleidsvoornemens van een minister die het beleid van '
#       'andere ministers kunnen raken en waarover het bereiken van overeenstemming niet mogelijk is gebleken;'
#      ]
#
# - we could deal with **document-internal references**, e.g. BWBR0004302's artikel 3, lid 1 has "artikel 2, eerste, tweede, en vijfde lid", which in that context ought to give something like:
#    - ['2',
#       ['1', '2', '5'],
#       ['Bij of krachtens algemene maatregel van bestuur worden in het belang van de volksgezondheid eisen gesteld aan tabaksproducten, ',
#        'elektronische dampwaar, nicotinehoudende vloeistof en niet-nicotinehoudende vloeistof met betrekking tot maximumemissieniveaus ',
#        'en ingrediënten en worden technische eisen gesteld, en kunnen methoden van onderzoek worden aangewezen die bij uitsluiting ',
#        'beslissend zijn voor de vaststelling of met betrekking tot een product al dan niet aan de daaraan gestelde eisen is voldaan.,
#
#               Bij of krachtens algemene maatregel van bestuur worden in het belang van de volksgezondheid eisen gesteld aan de verpakkingseenheid en de buitenverpakking van tabaksproducten en aanverwante producten. De eisen hebben betrekking op:
#
#           a. de aanduidingen op verpakkingseenheden en buitenverpakkingen;
#
#           b. de hoeveelheid of het aantal stuks dat is verpakt;
#
#           c. de presentatie van het product;
#
#           d. de sluiting, vorm, afmetingen en materiaal van de verpakkingseenheid of de buitenverpakking; en
#
#           e. andere elementen van de verpakkingseenheid en de buitenverpakking die gebruikt kunnen worden om een onderscheid te maken tussen de verschillende merken van een tabaksproduct of een aanverwant product.
#
#        'De verpakkingseenheid van elektronische dampwaar bevat een bijsluiter. Onze Minister stelt nadere regels over de inhoud van de bijsluiter.'
#       ]
#      ]
