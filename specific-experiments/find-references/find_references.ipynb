# %% [markdown]
# <a href="https://colab.research.google.com/github/WetSuiteLeiden/example-notebooks/blob/main/specific-experiments/find-references/find_references.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (only) in colab, run this first to install wetsuite from (the most recent) source.   For your own setup, see wetsuite's install guidelines.
# !pip3 install -U wetsuite

# %% [markdown]
# # Purpose of this notebook

# %% [markdown]
# Seeing how well you can extract the more explicit references to laws and jurisprudence from relatively free-form text.
#
# Because there are few standards, and the ones there are are rarely used consistently, you can argue over how best to extract them.
#
# You probably want to skim [notes__legal_identifiers_and_references (notebook)](../../archive/notes__legal_identifiers_and_references.ipynb)
# first.
#
# Optionally, take a glance at [find_wetnamen](../find-wetnamen/find_wetnamen.ipynb) extracting the names of laws,
# including less-official references in real-world use.

# %% [markdown]
# Some of them will be identifiers, others more naturally flowing text.
#
# Note that we focus on things that are relatively clear in _any_ context.
#
# There are even more implicit references,
# such as documents referring to `de staatssecretaris`, `onze wijziging`, `die brief`, `de najaarsnota`,
# many of which _could_ be reconciled well enough within their context,
# but require a more involved a mix of more NLP-like approaches, co-reference and beyond.
#
# The amount of attention that deserves is usually only found in theses and such -- see e.g. [this one](https://scripties.uba.uva.nl/search?id=record_54697),
# and might be very interesting when you start analysing specific documents,
# but this example only takes the wider view of finding references between documents.

# %% [markdown]
# ## What is our domain?
#
# There will be references between documents like
# jurisprudence,
# national law,
# EU law,
# policy,
# and other official publications.
#
# Extracting such references may be useful to varied tasks, such as
# - finding related documents by the references they share use,
# - estimate the generla topics a document covers,
# - estimate what a document intends to do, by the legal authority it draws on.
#
# <!-- -->
#
# Particularly ECLI marks what it is in the identifier itself, so is unambiguous.
#
# The full form of a jci is similarly recognizable.
#
#
# Many other things fall on a gliding scale.
# LJN may just look like some letters and numbers.
# The same goes for CELEX except there are some letters in a predictable yet otherwise-unusual place.
# Such details metter if you want to avoid false positives.
#
# Abbreviated references are more easily missed (false negatives), or lead to false positives.
#
# Natural-language references may see a lot of _variation_ in how they are written down,
# but their relative verbosity means that most cases are still fairly unambiguous.

# %% [markdown]
# ### Some practical notes
#
#
# TODO: MOVE WHAT IS RELEVANT TO NOTES_IDENTIFIERS
#
#
# **Nerdnotes:**
# * You could look for very specific text patterns,
#   * but things like regexps are likely to break under even minor variation and/or become a mess to understan (see much of the current implementation)
#   * a good tradeoff might be something that lets you express the parts and how they combine - such as classical classical formal grammars - see acronyms like EBNF, CFGs, and in practice something like [PEG](https://en.wikipedia.org/wiki/Parsing_expression_grammar)s may be more flexible
#
# * There are some things that are essentially global aliases, shared through the community
#   * e.g. referring to part of `Awb` is _very_ likely to be _Algemene wet bestuursrecht_, [BWBR0005537](https://wetten.overheid.nl/BWBR0005537)
#   * and some references into this will be common to the point of almost being concepts in themselves
#
# * Then there are what are essentially local aliases. Consider:
#   - `"Ingevolge artikel 2, eerste lid, van de Wet op de adeldom (hierna: de Wet)"`
#   - `"the European Convention on Human Right and Fundamental Freedoms (hereinafter 'the Convention')"`
#   * which are important if you want to resolve _"article 6 of the Convention"_
#
#
# **Practicalities**
# * Some of the data we have is marked up, meaning there are links that are to a formal identifier, and have a less-formal name.
#   * for example, find `extref` tags in BWB and CVDR's XML form
#
# * Some of the references are nicely in metadata fields. Knowing that can act as disambiguation of the field's value in a way we cannot easily do in free-flowing text.
#
# * We also just have text that happens to be references - e.g. in free-flowing text.
#
#
# * perhaps the most important is actually that it is often not clear where the reference ends. A simple example:
#
#     TODO
#
#
# **Practicalities we cannot cover easily, or at all:**
# * References would be referring to the version valid at the time of reference, though that should be resolvable
#
# * You may find a lot of **less-formal names for laws** from free-form text
#
# * The same may not work as well for **policy** or **jurisprudence**.
#     * Say, "Rensing/Polak II" is practically unambiguous, even though it's **not** `ECLI:NL:HR:2005:AT4537`'s name
#     * yet there are many links that will be named "Besluit", or another name that is unique only within that document and not something we should learn generally
#
# * Not all references have the same function. Consider `"Commission Directive 2014/110/EU of 17 December 2014 amending Directive 2004/33/EC as regards ..."` or `"The substantive provisions of Directive 2004/33/EC were not affected by its amendment by Directive 2014/110/EU ..."` - it would not be hard to extract both references, but it is is up to you to notice that in terms of interpretation, one is referred to, and the other is only mentioned for completeness, or to decide there is a difference between mentions, supporing references, etc.

# %% [markdown]
# ## Some tests

# %% [markdown]
# ### Test what we can extract: More on the identifier end

# %%
import pprint

import wetsuite.helpers.patterns
import wetsuite.helpers.meta
import wetsuite.helpers.split
import wetsuite.helpers.net

# %%
matches = wetsuite.helpers.patterns.find_references( """
BWBR0006501

CVDR101405_1  CVDR101405/1  CVDR101405

ECLI:NL:HR:2005:AT4537   is an exampe of LJN in ECLI - and note it will get an overlapping detection
ECLI:EU:C:1998:27        is not detailed further, we currently focus on dutch only
ECLI:EU:F:2010:80
ECLI:EU:T:2012:426

kst-26643-144-h1        is not something you usually find in text
h-tk-20082009-7140-7144 so this is also disabled by default
ah-tk-20082009-2945
stcrt-2009-9231

32000L0060
32012A0424(01)
32009L0164R(01)          is a corrigendum
52018PC0033              is internal
11957E086                is a treaty
72013L0032AUT_202103576  is a national transposition (the added p
                                                    ECLI:NL:HR:1841:1
OJ L 69, 13.3.2013, p. 1
OJ L 168, 30.6.2009, p. 41–47 
Council Directive 93/42/EEC of 14 June 1993
Council Regulation (EEC) No 2658/87 

Stb. 2011, 35;

LJN: BO6106
LJN: AO7817, NJ 2005, 270
""", ljn=True, bekendmaking_ids=True) # by default does not look for LJN, because that easily leads to some false positives

for match in matches:
    #print( match )
    print('%r'%match['text'])
    for k, v in match.items():
        print( '    %20r:  %-r'%(k, v) )
# Out:
# 'BWBR0006501'
#                   'type':  'bwb'
#                  'start':  1
#                    'end':  12
#                   'text':  'BWBR0006501'
# 'CVDR101405_1'
#                   'type':  'cvdr'
#                  'start':  14
#                    'end':  26
#                   'text':  'CVDR101405_1'
#                'details':  {'workid': '101405', 'expressionid': '101405_1'}
# 'CVDR101405/1'
#                   'type':  'cvdr'
#                  'start':  28
#                    'end':  40
#                   'text':  'CVDR101405/1'
#                'details':  {'workid': '101405', 'expressionid': '101405_1'}
# 'CVDR101405'
#                   'type':  'cvdr'
#                  'start':  42
#                    'end':  52
#                   'text':  'CVDR101405'
#                'details':  {'workid': '101405', 'expressionid': None}
# 'ECLI:NL:HR:2005:AT4537'
#                   'type':  'ecli'
#                  'start':  54
#                    'end':  76
#                   'text':  'ECLI:NL:HR:2005:AT4537'
#                'details':  {'normalized': 'ECLI:NL:HR:2005:AT4537', 'country_code': 'NL', 'court_code': 'HR', 'year': '2005', 'caseid': 'AT4537', 'court_details': {'abbrev': 'HR', 'extra': ['hr'], 'name': 'Hoge Raad'}}
# 'AT4537'
#                   'type':  'ljn'
#                  'start':  70
#                    'end':  76
#                   'text':  'AT4537'
# 'ECLI:EU:C:1998:27'
#                   'type':  'ecli'
#                  'start':  155
#                    'end':  172
#                   'text':  'ECLI:EU:C:1998:27'
#                'details':  {'normalized': 'ECLI:EU:C:1998:27', 'country_code': 'EU', 'court_code': 'C', 'year': '1998', 'caseid': '27'}
# 'ECLI:EU:F:2010:80'
#                   'type':  'ecli'
#                  'start':  238
#                    'end':  255
#                   'text':  'ECLI:EU:F:2010:80'
#                'details':  {'normalized': 'ECLI:EU:F:2010:80', 'country_code': 'EU', 'court_code': 'F', 'year': '2010', 'caseid': '80'}
# 'ECLI:EU:T:2012:426'
#                   'type':  'ecli'
#                  'start':  256
#                    'end':  274
#                   'text':  'ECLI:EU:T:2012:426'
#                'details':  {'normalized': 'ECLI:EU:T:2012:426', 'country_code': 'EU', 'court_code': 'T', 'year': '2012', 'caseid': '426'}
# 'kst-26643-144-h1'
#                   'type':  'bekend'
#                  'start':  276
#                    'end':  292
#                   'text':  'kst-26643-144-h1'
#                'details':  {'docnum': '26643-144-h1', 'dossiernum': '26643', 'type': 'kst', 'variant': 'dos-doc'}
# 'h-tk-20082009-7140-7144'
#                   'type':  'bekend'
#                  'start':  342
#                    'end':  365
#                   'text':  'h-tk-20082009-7140-7144'
#                'details':  {'type': 'h-tk', 'jaar': '20082009', 'docnum': '7140-7144'}
# 'ah-tk-20082009-2945'
#                   'type':  'bekend'
#                  'start':  402
#                    'end':  421
#                   'text':  'ah-tk-20082009-2945'
#                'details':  {'type': 'ah-tk', 'jaar': '20082009', 'docnum': '2945'}
# 'stcrt-2009-9231'
#                   'type':  'bekend'
#                  'start':  422
#                    'end':  437
#                   'text':  'stcrt-2009-9231'
#                'details':  {'type': 'stcrt', 'jaar': '2009', 'docnum': '9231'}
# '32000L0060'
#                   'type':  'celex'
#                  'start':  439
#                    'end':  449
#                   'text':  '32000L0060'
#                'details':  {'norm': '32000L0060', 'sector_number': '3', 'sector_name': 'Legislation', 'year': '2000', 'document_type': 'L', 'document_type_description': 'Directives', 'document_number': '0060', 'nattrans': '', 'specdate': '', 'id': '32000L0060'}
# '32012A0424(01)'
#                   'type':  'celex'
#                  'start':  450
#                    'end':  464
#                   'text':  '32012A0424(01)'
#                'details':  {'norm': '32012A0424(01)', 'sector_number': '3', 'sector_name': 'Legislation', 'year': '2012', 'document_type': 'A', 'document_type_description': 'Opinions', 'document_number': '0424(01)', 'nattrans': '', 'specdate': '', 'id': '32012A0424(01)'}
# '32009L0164'
#                   'type':  'celex'
#                  'start':  465
#                    'end':  475
#                   'text':  '32009L0164'
#                'details':  {'norm': '32009L0164', 'sector_number': '3', 'sector_name': 'Legislation', 'year': '2009', 'document_type': 'L', 'document_type_description': 'Directives', 'document_number': '0164', 'nattrans': '', 'specdate': '', 'id': '32009L0164'}
# '52018PC0033'
#                   'type':  'celex'
#                  'start':  507
#                    'end':  518
#                   'text':  '52018PC0033'
#                'details':  {'norm': '52018PC0033', 'sector_number': '5', 'sector_name': 'Proposals + other preparatory documents', 'year': '2018', 'document_type': 'PC', 'document_type_description': 'European Commission - COM – legislative proposals, and documents related', 'document_number': '0033', 'nattrans': '', 'specdate': '', 'id': '52018PC0033'}
# '72013L0032'
#                   'type':  'celex'
#                  'start':  581
#                    'end':  591
#                   'text':  '72013L0032'
#                'details':  {'norm': '72013L0032', 'sector_number': '7', 'sector_name': 'National Implementation', 'year': '2013', 'document_type': 'L', 'document_type_description': 'National measures to transpose directives', 'document_number': '0032', 'nattrans': '', 'specdate': '', 'id': '72013L0032'}
# 'ECLI:NL:HR:1841:1'
#                   'type':  'ecli'
#                  'start':  699
#                    'end':  716
#                   'text':  'ECLI:NL:HR:1841:1'
#                'details':  {'normalized': 'ECLI:NL:HR:1841:1', 'country_code': 'NL', 'court_code': 'HR', 'year': '1841', 'caseid': '1', 'court_details': {'abbrev': 'HR', 'extra': ['hr'], 'name': 'Hoge Raad'}}
# 'OJ L 69, 13.3.2013, p. 1'
#                   'type':  'euoj'
#                  'start':  717
#                    'end':  741
#                   'text':  'OJ L 69, 13.3.2013, p. 1'
# 'OJ L 168, 30.6.2009, p. 41–47'
#                   'type':  'euoj'
#                  'start':  742
#                    'end':  771
#                   'text':  'OJ L 168, 30.6.2009, p. 41–47'
# 'Council Directive 93/42/EEC'
#                   'type':  'eudir'
#                  'start':  773
#                    'end':  800
#                   'text':  'Council Directive 93/42/EEC'
# 'Council Regulation (EEC) No 2658/87'
#                   'type':  'eureg'
#                  'start':  817
#                    'end':  852
#                   'text':  'Council Regulation (EEC) No 2658/87'
#                'details':  {'what': 'EEC', 'number': 'No 2658/87'}
# 'Stb. 2011, 35'
#                   'type':  'vindplaats'
#                  'start':  855
#                    'end':  868
#                   'text':  'Stb. 2011, 35'
#                'details':  {'what': 'Stb', 'jaar': '2011', 'nummer': '35'}
# 'BO6106'
#                   'type':  'ljn'
#                  'start':  876
#                    'end':  882
#                   'text':  'BO6106'
# 'AO7817'
#                   'type':  'ljn'
#                  'start':  888
#                    'end':  894
#                   'text':  'AO7817'

# %% [markdown]
# ### Test: matching less-structured cases

# %%
# These have more varied form, see how well we do at that
for test_text in '''Kamerstukken II 2015/16, 34442, nr. 3, p. 7.
Kamerstukken I 1995/96, 23700, nr. 188b, p. 3.
Kamerstukken I 2014/15, 33802, C, p. 3.
Kamerstukken 2014/15, 33802, C, p. 3.  as a test of missing number
Kamerstukken II 1999/2000, 2000/2001, 2001/2002, 26 855.
Kamerstukken I 2000/2001, 26 855 (250, 250a); 2001/2002, 26 855 (16, 16a, 16b, 16c).
Handelingen II 2000/2001, blz. 4225–4227; 4277.
Handelingen I 2001/2002, zie vergadering d.d. 4 december 2001.
Bijlage bij Kamerstukken II 2015/16, 34389, nr. 9.
Wetsvoorstel partnerschapsregistratie (Kamerstukken II 1993/94-1996/97, 23761).
Wetsvoorstel partnerschapsregistratie (Kamerstukken 1993/94-1996/97, 23761)
Aanhangsel Handelingen, vergaderjaar 2022–2023, nr. 2427
Aanhangsel Handelingen II, vergaderjaar 2023-2024, nr. 766 
'''.splitlines():
    
    matches = wetsuite.helpers.patterns.find_references( test_text )
    if len(matches)==0:
        print( "\nDID NOT MATCH IN %r"%test_text)
    else:
        for match in matches:
            print('\nMatched: %r'%match['text'])
            for k, v in match.items():
                print( '    %20r:  %-r'%(k, v) )
# Out:
# Matched: 'Kamerstukken II 2015/16, 34442, nr. 3, p. 7'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  43
#                   'text':  'Kamerstukken II 2015/16, 34442, nr. 3, p. 7'
#
# Matched: 'Kamerstukken I 1995/96, 23700, nr. 188'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  38
#                   'text':  'Kamerstukken I 1995/96, 23700, nr. 188'
#
# Matched: 'Kamerstukken I 2014/15, 33802, C, p. 3'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  38
#                   'text':  'Kamerstukken I 2014/15, 33802, C, p. 3'
#
# Matched: 'Kamerstukken 2014/15, 33802, C, p. 3'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  36
#                   'text':  'Kamerstukken 2014/15, 33802, C, p. 3'
#
# Matched: 'Kamerstukken II 1999/2000, 2000'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  31
#                   'text':  'Kamerstukken II 1999/2000, 2000'
#
# Matched: 'Kamerstukken I 2000/2001, 26'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  28
#                   'text':  'Kamerstukken I 2000/2001, 26'
#
# Matched: 'Handelingen II 2000/2001, blz. 4225'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  35
#                   'text':  'Handelingen II 2000/2001, blz. 4225'
#
# Matched: 'Handelingen I 2001/2002'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  23
#                   'text':  'Handelingen I 2001/2002'
#
# Matched: 'Kamerstukken II 2015/16, 34389, nr. 9'
#                   'type':  'kamerstukken'
#                  'start':  12
#                    'end':  49
#                   'text':  'Kamerstukken II 2015/16, 34389, nr. 9'
#
# Matched: 'Kamerstukken II 1993/94'
#                   'type':  'kamerstukken'
#                  'start':  39
#                    'end':  62
#                   'text':  'Kamerstukken II 1993/94'
#
# Matched: 'Kamerstukken 1993/94'
#                   'type':  'kamerstukken'
#                  'start':  39
#                    'end':  59
#                   'text':  'Kamerstukken 1993/94'
#
# DID NOT MATCH IN 'Aanhangsel Handelingen, vergaderjaar 2022–2023, nr. 2427'
#
# Matched: 'Aanhangsel Handelingen II, vergaderjaar 2023-2024, nr. 766'
#                   'type':  'kamerstukken'
#                  'start':  0
#                    'end':  58
#                   'text':  'Aanhangsel Handelingen II, vergaderjaar 2023-2024, nr. 766'

# %% [markdown]
# ...even less structured...

# %%
looser_testcases = (
    'artikel 8:75a, eerste lid, tweede volzin, van de Awb',

    'artikel 5:9, aanhef en onder b, Awb',
    'artikel 8, aanhef en onder c, Wet bescherming persoonsgegevens (Wbp).',
    'artikel 10, tweede lid, aanhef en onder e, van de Wob',
    "artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad",
    "Artikel 10, tweede lid, aanhef en onder e van de. Wet openbaarheid van bestuur",
    "artikel 6:80 lid 1 aanhef en onder b BW",
    'artikel 4, aanhef en onder d en g, van de standaardvoorwaarden',
    'artikel 3.3, zevende lid, aanhef en onder i, Woo',
    'artikel 15, aanhef en onder a of c (oud) RWN',

    '  artikel 81q lid 3c Gemeentewet  ',
    'artikel 4:25, 4:35 van de Awb en artikel 10 van de ASV',
    'Wabo, art. 2.12, eerste lid, aanhef en onder a, sub 1\xBA',
    'artikel 79, aanhef en onder 6\xBA',
    'artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo',
    'artikel 142, eerste lid, aanhef en onder b (en derde lid), van het Wetboek van Strafvordering',
    'artikel 2, eerste, tweede, vijfde, en zesenzestigste lid',
    'art. 166 lid 1 in verbinding met art. 353 lid 1 Rv',
    'artikel 13, derde lid, van de Wet tarieven in burgerlijke zaken',
    'artikel 7, eerste lid, onderdeel a',
    'artikel 7, eerste lid, aanhef en onderdeel b', 

    'artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad',
    'artikel 5:9, aanhef en onder b, Awb',
    'artikel 8, aanhef en onder c, Wet bescherming persoonsgegevens (Wbp)',
    'artikel 10, tweede lid, aanhef en onder e, van de Wob',
    'artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad',
    'Artikel 10, tweede lid, aanhef en onder e van de Wet openbaarheid van bestuur',
    'artikel 6:80 lid 1 aanhef en onder b BW',
    'artikel 142, eerste lid, aanhef en onder b (en derde lid), van het Wetboek van Strafvordering',
    'artikel 4, aanhef en onder d en g, van de standaardvoorwaarden',
    'artikel 3.3, zevende lid, aanhef en onder i, Woo',
    'artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo',
    'artikel 79, aanhef en onder 6\xBA',
    'artikel 15, aanhef en onder a of c (oud) RWN',
    'Wabo, art. 2.12, eerste lid, aanhef en onder a, sub 1\xBA',
    'artikel 2, eerste, tweede, en vijfde lid, gestelde eisen voldoen. (Artikel 3, eerste lid, van de Tabaks- en rookwarenwet)',
    'artikel 2, eerste, tweede, vijfde, even zesenzestigste lid',

    'artikel 79, aanhef en onder a en b',
    'artikel 79, aanhef en onder a tot c',
    'artikel 79, aanhef en onder a tot en met c',

    'art 18 lid 2 en 4 Besluit kwaliteit; art 21 lid 1 sub a Regeling',
    'artikel 2, onderdeel 8, subonderdeel b, van Verordening 2018/1805', 
    '(Art. 81 RO)',
    "(81 WWB)",
    '(als bedoeld in art. 22 Rv.)',
    'artikel 166 Rv',
    'artikel 3:303 BW',
    'artikel 22 Rv',
    'artikel. 94c Sv',
)

# %%
for test_text in looser_testcases:
    matches = wetsuite.helpers.patterns.find_references( test_text, debug=0 )
    if len(matches)==0:
        print( 'NO MATCH IN %r'%test_text )
    else:
        #continue
        # Note that right now, we do not yet try to match the mentioned law -- that's on a TODO list
        print( '\n%r -->'%test_text )
        for match in matches:
            #pprint.pprint( match )
            for k, v in match['details'].items():
                print( '    %15s:  %-r'%(k, v) )
# Out:
# 'artikel 8:75a, eerste lid, tweede volzin, van de Awb' -->
#             artikel:  '8:75a'
#                 lid:  'eerste'
#              volzin:  'tweede'
#             lid_num:  [1]
#          volzin_num:  [2]
#             nameref:  'Awb'
#
# 'artikel 5:9, aanhef en onder b, Awb' -->
#             artikel:  '5:9'
#         aanhefonder:  'aanhef en onder b'
#             nameref:  'Awb'
#
# 'artikel 8, aanhef en onder c, Wet bescherming persoonsgegevens (Wbp).' -->
#             artikel:  '8'
#         aanhefonder:  'aanhef en onder c'
#             nameref:  'Wet bescherming persoonsgegevens (Wbp)'
#
# 'artikel 10, tweede lid, aanhef en onder e, van de Wob' -->
#             artikel:  '10'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder e'
#             lid_num:  [2]
#             nameref:  'Wob'
#
# 'artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad' -->
#             artikel:  '4'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder d'
#             lid_num:  [2]
#             nameref:  'reglement van orde voor de ministerraad'
#
# 'Artikel 10, tweede lid, aanhef en onder e van de. Wet openbaarheid van bestuur' -->
#             artikel:  '10'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder e'
#             lid_num:  [2]
#
# 'artikel 6:80 lid 1 aanhef en onder b BW' -->
#             artikel:  '6:80'
#                 lid:  '1'
#         aanhefonder:  'aanhef en onder b'
#             lid_num:  [1]
#             nameref:  'BW'
#
# 'artikel 4, aanhef en onder d en g, van de standaardvoorwaarden' -->
#             artikel:  '4'
#         aanhefonder:  'aanhef en onder d en g'
#
# 'artikel 3.3, zevende lid, aanhef en onder i, Woo' -->
#             artikel:  '3.3'
#                 lid:  'zevende'
#         aanhefonder:  'aanhef en onder i'
#             lid_num:  [7]
#             nameref:  'Woo'
#
# 'artikel 15, aanhef en onder a of c (oud) RWN' -->
#             artikel:  '15'
#         aanhefonder:  'aanhef en onder a'
#
# '  artikel 81q lid 3c Gemeentewet  ' -->
#             artikel:  '81q'
#                 lid:  '3c'
#             lid_num:  []
#             nameref:  'Gemeentewet'
#
# 'artikel 4:25, 4:35 van de Awb en artikel 10 van de ASV' -->
#             artikel:  '4:25'
#             artikel:  '10'
#
# 'Wabo, art. 2.12, eerste lid, aanhef en onder a, sub 1º' -->
#             artikel:  '2.12'
#                 lid:  'eerste'
#         aanhefonder:  'aanhef en onder a'
#             lid_num:  [1]
#
# 'artikel 79, aanhef en onder 6º' -->
#             artikel:  '79'
#         aanhefonder:  'aanhef en onder 6º'
#
# 'artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo' -->
#             artikel:  '3.3'
#                 lid:  'zevende'
#         aanhefonder:  'aanhef en onder i'
#             lid_num:  [7]
#             nameref:  'Woo'
#
# 'artikel 142, eerste lid, aanhef en onder b (en derde lid), van het Wetboek van Strafvordering' -->
#             artikel:  '142'
#                 lid:  'derde'
#         aanhefonder:  'aanhef en onder b'
#             lid_num:  [3]
#
# 'artikel 2, eerste, tweede, vijfde, en zesenzestigste lid' -->
#             artikel:  '2'
#                 lid:  'eerste, tweede, vijfde, en zesenzestigste'
#             lid_num:  [1, 2, 5, 66]
#
# 'art. 166 lid 1 in verbinding met art. 353 lid 1 Rv' -->
#             artikel:  '166'
#                 lid:  '1'
#             lid_num:  [1]
#             artikel:  '353'
#                 lid:  '1'
#             lid_num:  [1]
#             nameref:  'Rv'
#
# 'artikel 13, derde lid, van de Wet tarieven in burgerlijke zaken' -->
#             artikel:  '13'
#                 lid:  'derde'
#             lid_num:  [3]
#             nameref:  'Wet tarieven in burgerlijke zaken'
#
# 'artikel 7, eerste lid, onderdeel a' -->
#             artikel:  '7'
#                 lid:  'eerste'
#         aanhefonder:  'onderdeel a'
#             lid_num:  [1]
#
# 'artikel 7, eerste lid, aanhef en onderdeel b' -->
#             artikel:  '7'
#                 lid:  'eerste'
#         aanhefonder:  'aanhef en onderdeel b'
#             lid_num:  [1]
#
# 'artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad' -->
#             artikel:  '4'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder d'
#             lid_num:  [2]
#             nameref:  'reglement van orde voor de ministerraad'
#
# 'artikel 5:9, aanhef en onder b, Awb' -->
#             artikel:  '5:9'
#         aanhefonder:  'aanhef en onder b'
#             nameref:  'Awb'
#
# 'artikel 8, aanhef en onder c, Wet bescherming persoonsgegevens (Wbp)' -->
#             artikel:  '8'
#         aanhefonder:  'aanhef en onder c'
#             nameref:  'Wet bescherming persoonsgegevens (Wbp)'
#
# 'artikel 10, tweede lid, aanhef en onder e, van de Wob' -->
#             artikel:  '10'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder e'
#             lid_num:  [2]
#             nameref:  'Wob'
#
# 'artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad' -->
#             artikel:  '4'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder d'
#             lid_num:  [2]
#             nameref:  'reglement van orde voor de ministerraad'
#
# 'Artikel 10, tweede lid, aanhef en onder e van de Wet openbaarheid van bestuur' -->
#             artikel:  '10'
#                 lid:  'tweede'
#         aanhefonder:  'aanhef en onder e'
#             lid_num:  [2]
#             nameref:  'Wet openbaarheid van bestuur'
#
# 'artikel 6:80 lid 1 aanhef en onder b BW' -->
#             artikel:  '6:80'
#                 lid:  '1'
#         aanhefonder:  'aanhef en onder b'
#             lid_num:  [1]
#             nameref:  'BW'
#
# 'artikel 142, eerste lid, aanhef en onder b (en derde lid), van het Wetboek van Strafvordering' -->
#             artikel:  '142'
#                 lid:  'derde'
#         aanhefonder:  'aanhef en onder b'
#             lid_num:  [3]
#
# 'artikel 4, aanhef en onder d en g, van de standaardvoorwaarden' -->
#             artikel:  '4'
#         aanhefonder:  'aanhef en onder d en g'
#
# 'artikel 3.3, zevende lid, aanhef en onder i, Woo' -->
#             artikel:  '3.3'
#                 lid:  'zevende'
#         aanhefonder:  'aanhef en onder i'
#             lid_num:  [7]
#             nameref:  'Woo'
#
# 'artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo' -->
#             artikel:  '3.3'
#                 lid:  'zevende'
#         aanhefonder:  'aanhef en onder i'
#             lid_num:  [7]
#             nameref:  'Woo'
#
# 'artikel 79, aanhef en onder 6º' -->
#             artikel:  '79'
#         aanhefonder:  'aanhef en onder 6º'
#
# 'artikel 15, aanhef en onder a of c (oud) RWN' -->
#             artikel:  '15'
#         aanhefonder:  'aanhef en onder a'
#
# 'Wabo, art. 2.12, eerste lid, aanhef en onder a, sub 1º' -->
#             artikel:  '2.12'
#                 lid:  'eerste'
#         aanhefonder:  'aanhef en onder a'
#             lid_num:  [1]
#
# 'artikel 2, eerste, tweede, en vijfde lid, gestelde eisen voldoen. (Artikel 3, eerste lid, van de Tabaks- en rookwarenwet)' -->
#             artikel:  '2'
#                 lid:  'eerste, tweede, en vijfde'
#             lid_num:  [1, 2, 5]
#             artikel:  '3'
#                 lid:  'eerste'
#             lid_num:  [1]
#             nameref:  'Tabaks- en rookwarenwet'
#
# 'artikel 2, eerste, tweede, vijfde, even zesenzestigste lid' -->
#             artikel:  '2'
#                 lid:  'zesenzestigste'
#             lid_num:  [66]
#
# 'artikel 79, aanhef en onder a en b' -->
#             artikel:  '79'
#         aanhefonder:  'aanhef en onder a en b'
#
# 'artikel 79, aanhef en onder a tot c' -->
#             artikel:  '79'
#         aanhefonder:  'aanhef en onder a tot c'
#
# 'artikel 79, aanhef en onder a tot en met c' -->
#             artikel:  '79'
#         aanhefonder:  'aanhef en onder a tot en met c'
#
# 'art 18 lid 2 en 4 Besluit kwaliteit; art 21 lid 1 sub a Regeling' -->
#             artikel:  '18'
#                 lid:  '2'
#             lid_num:  [2]
#             artikel:  '21'
#                 lid:  '1'
#             lid_num:  [1]
#             nameref:  'Regeling'
#
# 'artikel 2, onderdeel 8, subonderdeel b, van Verordening 2018/1805' -->
#             artikel:  '2'
#         aanhefonder:  'onderdeel b'
#
# '(Art. 81 RO)' -->
#             artikel:  '81'
#             nameref:  'RO'
# NO MATCH IN '(81 WWB)'
#
# '(als bedoeld in art. 22 Rv.)' -->
#             artikel:  '22'
#             nameref:  'Rv'
#
# 'artikel 166 Rv' -->
#             artikel:  '166'
#             nameref:  'Rv'
#
# 'artikel 3:303 BW' -->
#             artikel:  '3:303'
#             nameref:  'BW'
#
# 'artikel 22 Rv' -->
#             artikel:  '22'
#             nameref:  'Rv'
#
# 'artikel. 94c Sv' -->
#             artikel:  '94c'
#             nameref:  'Sv'

# %% [markdown]
# ### Test: an actual document

# %%
#htmldata = wetsuite.helpers.net.download('https://zoek.officielebekendmakingen.nl/stb-2001-580.html')
htmldata = wetsuite.helpers.net.download('https://zoek.officielebekendmakingen.nl/stb-2022-14.html')
#https://zoek.officielebekendmakingen.nl/.html

htmltext = ' '.join( wetsuite.helpers.split.feeling_lucky(htmldata) )  # helper function that should extract just the text

# %%
matches = wetsuite.helpers.patterns.find_references( htmltext )
for match in matches:
    print('\nMatched: %r'%match['text'])
    for k, v in match.items():
        print( '    %20r:  %-r'%(k, v) )
# Out:
# Matched: 'artikel 2.2, eerste lid'
#                   'type':  'artikel'
#                  'start':  1634
#                    'end':  1657
#                   'text':  'artikel 2.2, eerste lid'
#                'details':  OrderedDict([('artikel', '2.2'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 19.1a van de Wet milieubeheer;'
#                   'type':  'artikel'
#                  'start':  1963
#                    'end':  2001
#                   'text':  'artikel 19.1a van de Wet milieubeheer;'
#                'details':  OrderedDict([('artikel', '19.1a'), ('nameref', 'Wet milieubeheer;')])
#
# Matched: 'artikel 2.2, eerste lid'
#                   'type':  'artikel'
#                  'start':  2192
#                    'end':  2215
#                   'text':  'artikel 2.2, eerste lid'
#                'details':  OrderedDict([('artikel', '2.2'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 2.3'
#                   'type':  'artikel'
#                  'start':  2245
#                    'end':  2256
#                   'text':  'artikel 2.3'
#                'details':  OrderedDict([('artikel', '2.3')])
#
# Matched: 'artikel 9, eerste\n                                    lid, van de Wet Nationale ombudsman'
#                   'type':  'artikel'
#                  'start':  3008
#                    'end':  3097
#                   'text':  'artikel 9, eerste\n                                    lid, van de Wet Nationale ombudsman'
#                'details':  OrderedDict([('artikel', '9'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Wet Nationale ombudsman')])
#
# Matched: 'artikel 9:17, onderdeel b, van de Algemene wet bestuursrecht.'
#                   'type':  'artikel'
#                  'start':  3186
#                    'end':  3247
#                   'text':  'artikel 9:17, onderdeel b, van de Algemene wet bestuursrecht.'
#                'details':  OrderedDict([('artikel', '9:17'), ('aanhefonder', 'onderdeel b'), ('nameref', 'Algemene wet bestuursrecht.')])
#
# Matched: 'artikel 5, eerste lid'
#                   'type':  'artikel'
#                  'start':  4539
#                    'end':  4560
#                   'text':  'artikel 5, eerste lid'
#                'details':  OrderedDict([('artikel', '5'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 4.1'
#                   'type':  'artikel'
#                  'start':  12477
#                    'end':  12488
#                   'text':  'artikel 4.1'
#                'details':  OrderedDict([('artikel', '4.1')])
#
# Matched: 'artikel 2, onderdeel a'
#                   'type':  'artikel'
#                  'start':  15335
#                    'end':  15357
#                   'text':  'artikel 2, onderdeel a'
#                'details':  OrderedDict([('artikel', '2'), ('aanhefonder', 'onderdeel a')])
#
# Matched: 'artikel 22, eerste lid'
#                   'type':  'artikel'
#                  'start':  15721
#                    'end':  15743
#                   'text':  'artikel 22, eerste lid'
#                'details':  OrderedDict([('artikel', '22'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel\n                                          31'
#                   'type':  'artikel'
#                  'start':  15745
#                    'end':  15797
#                   'text':  'artikel\n                                          31'
#                'details':  OrderedDict([('artikel', '31')])
#
# Matched: 'artikel 46 van de Uitvoeringswet Algemene verordening gegevensbescherming'
#                   'type':  'artikel'
#                  'start':  15801
#                    'end':  15874
#                   'text':  'artikel 46 van de Uitvoeringswet Algemene verordening gegevensbescherming'
#                'details':  OrderedDict([('artikel', '46'), ('nameref', 'Uitvoeringswet Algemene verordening gegevensbescherming')])
#
# Matched: 'artikel\n                                    105'
#                   'type':  'artikel'
#                  'start':  19450
#                    'end':  19497
#                   'text':  'artikel\n                                    105'
#                'details':  OrderedDict([('artikel', '105')])
#
# Matched: 'artikel 65 van de Grondwet'
#                   'type':  'artikel'
#                  'start':  19659
#                    'end':  19685
#                   'text':  'artikel 65 van de Grondwet'
#                'details':  OrderedDict([('artikel', '65'), ('nameref', 'Grondwet')])
#
# Matched: 'artikel 3.3,\n                              tweede lid, onderdeel k'
#                   'type':  'artikel'
#                  'start':  24320
#                    'end':  24386
#                   'text':  'artikel 3.3,\n                              tweede lid, onderdeel k'
#                'details':  OrderedDict([('artikel', '3.3'), ('lid', 'tweede'), ('aanhefonder', 'onderdeel k'), ('lid_num', [2])])
#
# Matched: 'artikel 3.3,\n                              tweede lid, onderdeel k'
#                   'type':  'artikel'
#                  'start':  25503
#                    'end':  25569
#                   'text':  'artikel 3.3,\n                              tweede lid, onderdeel k'
#                'details':  OrderedDict([('artikel', '3.3'), ('lid', 'tweede'), ('aanhefonder', 'onderdeel k'), ('lid_num', [2])])
#
# Matched: 'artikel 3.3,\n                              tweede lid, onderdeel l'
#                   'type':  'artikel'
#                  'start':  26665
#                    'end':  26731
#                   'text':  'artikel 3.3,\n                              tweede lid, onderdeel l'
#                'details':  OrderedDict([('artikel', '3.3'), ('lid', 'tweede'), ('aanhefonder', 'onderdeel l'), ('lid_num', [2])])
#
# Matched: 'artikel 4:5, vierde lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  31431
#                    'end':  31489
#                   'text':  'artikel 4:5, vierde lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '4:5'), ('lid', 'vierde'), ('lid_num', [4]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 4.1, eerste lid'
#                   'type':  'artikel'
#                  'start':  33183
#                    'end':  33206
#                   'text':  'artikel 4.1, eerste lid'
#                'details':  OrderedDict([('artikel', '4.1'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 4.4, eerste lid'
#                   'type':  'artikel'
#                  'start':  33836
#                    'end':  33859
#                   'text':  'artikel 4.4, eerste lid'
#                'details':  OrderedDict([('artikel', '4.4'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel\n                                    5.5'
#                   'type':  'artikel'
#                  'start':  34879
#                    'end':  34926
#                   'text':  'artikel\n                                    5.5'
#                'details':  OrderedDict([('artikel', '5.5')])
#
# Matched: 'artikel 5.6'
#                   'type':  'artikel'
#                  'start':  34928
#                    'end':  34939
#                   'text':  'artikel 5.6'
#                'details':  OrderedDict([('artikel', '5.6')])
#
# Matched: 'artikel 5.7'
#                   'type':  'artikel'
#                  'start':  34944
#                    'end':  34955
#                   'text':  'artikel 5.7'
#                'details':  OrderedDict([('artikel', '5.7')])
#
# Matched: 'artikel 4:15 van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  36151
#                    'end':  36197
#                   'text':  'artikel 4:15 van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '4:15'), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 4:8 van de Algemene wet'
#                   'type':  'artikel'
#                  'start':  36428
#                    'end':  36459
#                   'text':  'artikel 4:8 van de Algemene wet'
#                'details':  OrderedDict([('artikel', '4:8'), ('nameref', 'Algemene wet')])
#
# Matched: 'artikel 8:81 van de Algemene wet bestuursrecht,'
#                   'type':  'artikel'
#                  'start':  37571
#                    'end':  37618
#                   'text':  'artikel 8:81 van de Algemene wet bestuursrecht,'
#                'details':  OrderedDict([('artikel', '8:81'), ('nameref', 'Algemene wet bestuursrecht,')])
#
# Matched: 'artikel 2.4, derde lid'
#                   'type':  'artikel'
#                  'start':  38374
#                    'end':  38396
#                   'text':  'artikel 2.4, derde lid'
#                'details':  OrderedDict([('artikel', '2.4'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 46'
#                   'type':  'artikel'
#                  'start':  40600
#                    'end':  40610
#                   'text':  'artikel 46'
#                'details':  OrderedDict([('artikel', '46')])
#
# Matched: 'artikel 5.1, tweede of vijfde lid'
#                   'type':  'artikel'
#                  'start':  46963
#                    'end':  46996
#                   'text':  'artikel 5.1, tweede of vijfde lid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'vijfde'), ('lid_num', [5])])
#
# Matched: 'artikel 5.2'
#                   'type':  'artikel'
#                  'start':  47025
#                    'end':  47036
#                   'text':  'artikel 5.2'
#                'details':  OrderedDict([('artikel', '5.2')])
#
# Matched: 'artikel 5.2, eerste lid, wor'
#                   'type':  'artikel'
#                  'start':  48023
#                    'end':  48051
#                   'text':  'artikel 5.2, eerste lid, wor'
#                'details':  OrderedDict([('artikel', '5.2'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'wor')])
#
# Matched: 'artikel 5.1, eerste lid, onderdelen a'
#                   'type':  'artikel'
#                  'start':  48633
#                    'end':  48670
#                   'text':  'artikel 5.1, eerste lid, onderdelen a'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste'), ('aanhefonder', 'onderdelen a'), ('lid_num', [1])])
#
# Matched: 'artikel 5.1, tweede of vijfde lid'
#                   'type':  'artikel'
#                  'start':  48837
#                    'end':  48870
#                   'text':  'artikel 5.1, tweede of vijfde lid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'vijfde'), ('lid_num', [5])])
#
# Matched: 'artikel 5.2'
#                   'type':  'artikel'
#                  'start':  48875
#                    'end':  48886
#                   'text':  'artikel 5.2'
#                'details':  OrderedDict([('artikel', '5.2')])
#
# Matched: 'artikel 2.4, eerste lid'
#                   'type':  'artikel'
#                  'start':  52322
#                    'end':  52345
#                   'text':  'artikel 2.4, eerste lid'
#                'details':  OrderedDict([('artikel', '2.4'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 2.2, eerste lid'
#                   'type':  'artikel'
#                  'start':  53284
#                    'end':  53307
#                   'text':  'artikel 2.2, eerste lid'
#                'details':  OrderedDict([('artikel', '2.2'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 7.2, vierde lid'
#                   'type':  'artikel'
#                  'start':  56665
#                    'end':  56688
#                   'text':  'artikel 7.2, vierde lid'
#                'details':  OrderedDict([('artikel', '7.2'), ('lid', 'vierde'), ('lid_num', [4])])
#
# Matched: 'artikel\n                              6:7 van de Algemene wet bestuursrecht,'
#                   'type':  'artikel'
#                  'start':  57104
#                    'end':  57180
#                   'text':  'artikel\n                              6:7 van de Algemene wet bestuursrecht,'
#                'details':  OrderedDict([('artikel', '6:7'), ('nameref', 'Algemene wet bestuursrecht,')])
#
# Matched: 'artikel 7:10, eerste lid, van de Algemene wet'
#                   'type':  'artikel'
#                  'start':  57732
#                    'end':  57777
#                   'text':  'artikel 7:10, eerste lid, van de Algemene wet'
#                'details':  OrderedDict([('artikel', '7:10'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Algemene wet')])
#
# Matched: 'artikel 5.5, vierde lid'
#                   'type':  'artikel'
#                  'start':  59248
#                    'end':  59271
#                   'text':  'artikel 5.5, vierde lid'
#                'details':  OrderedDict([('artikel', '5.5'), ('lid', 'vierde'), ('lid_num', [4])])
#
# Matched: 'artikel 5.7, tweede of derde lid'
#                   'type':  'artikel'
#                  'start':  59322
#                    'end':  59354
#                   'text':  'artikel 5.7, tweede of derde lid'
#                'details':  OrderedDict([('artikel', '5.7'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 8:55d, eerste lid, van\n                              de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  60247
#                    'end':  60337
#                   'text':  'artikel 8:55d, eerste lid, van\n                              de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '8:55d'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 8:55d, eerste lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  60835
#                    'end':  60895
#                   'text':  'artikel 8:55d, eerste lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '8:55d'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 8:74, eerste lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  61063
#                    'end':  61122
#                   'text':  'artikel 8:74, eerste lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '8:74'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 8:75,\n                              eerste lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  61222
#                    'end':  61311
#                   'text':  'artikel 8:75,\n                              eerste lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '8:75'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 4:15, tweede lid'
#                   'type':  'artikel'
#                  'start':  61624
#                    'end':  61648
#                   'text':  'artikel 4:15, tweede lid'
#                'details':  OrderedDict([('artikel', '4:15'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 7:10, vierde lid'
#                   'type':  'artikel'
#                  'start':  61823
#                    'end':  61847
#                   'text':  'artikel 7:10, vierde lid'
#                'details':  OrderedDict([('artikel', '7:10'), ('lid', 'vierde'), ('lid_num', [4])])
#
# Matched: 'artikel 8:74, eerste lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  62008
#                    'end':  62067
#                   'text':  'artikel 8:74, eerste lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '8:74'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 8:75,\n                              eerste lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  62167
#                    'end':  62256
#                   'text':  'artikel 8:75,\n                              eerste lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '8:75'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 4.2, tweede lid'
#                   'type':  'artikel'
#                  'start':  62608
#                    'end':  62631
#                   'text':  'artikel 4.2, tweede lid'
#                'details':  OrderedDict([('artikel', '4.2'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 10 van de Wet openbaarheid'
#                   'type':  'artikel'
#                  'start':  64307
#                    'end':  64341
#                   'text':  'Artikel 10 van de Wet openbaarheid'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid')])
#
# Matched: 'Artikel 5.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  64403
#                    'end':  64439
#                   'text':  'Artikel 5.1 van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 21a vervalt het tweede lid'
#                   'type':  'artikel'
#                  'start':  64523
#                    'end':  64557
#                   'text':  'artikel 21a vervalt het tweede lid'
#                'details':  OrderedDict([('artikel', '21a'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'Artikel 27d, vierde en vijfde lid'
#                   'type':  'artikel'
#                  'start':  64643
#                    'end':  64676
#                   'text':  'Artikel 27d, vierde en vijfde lid'
#                'details':  OrderedDict([('artikel', '27d'), ('lid', 'vierde en vijfde'), ('lid_num', [4, 5])])
#
# Matched: 'artikel 3:7, tweede lid, wor'
#                   'type':  'artikel'
#                  'start':  64750
#                    'end':  64778
#                   'text':  'artikel 3:7, tweede lid, wor'
#                'details':  OrderedDict([('artikel', '3:7'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'wor')])
#
# Matched: 'Artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  64782
#                    'end':  64828
#                   'text':  'Artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'Artikel 5.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  64870
#                    'end':  64906
#                   'text':  'Artikel 5.1 van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 3:11, tweede lid, wor'
#                   'type':  'artikel'
#                  'start':  64936
#                    'end':  64965
#                   'text':  'artikel 3:11, tweede lid, wor'
#                'details':  OrderedDict([('artikel', '3:11'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'wor')])
#
# Matched: 'Artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  64969
#                    'end':  65015
#                   'text':  'Artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'Artikel 5.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  65057
#                    'end':  65093
#                   'text':  'Artikel 5.1 van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 8:29 wor'
#                   'type':  'artikel'
#                  'start':  65326
#                    'end':  65342
#                   'text':  'artikel 8:29 wor'
#                'details':  OrderedDict([('artikel', '8:29'), ('nameref', 'wor')])
#
# Matched: 'Artikel 8:39, eerste lid'
#                   'type':  'artikel'
#                  'start':  65867
#                    'end':  65891
#                   'text':  'Artikel 8:39, eerste lid'
#                'details':  OrderedDict([('artikel', '8:39'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'Artikel 9:36 wor'
#                   'type':  'artikel'
#                  'start':  66368
#                    'end':  66384
#                   'text':  'Artikel 9:36 wor'
#                'details':  OrderedDict([('artikel', '9:36'), ('nameref', 'wor')])
#
# Matched: 'artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  66437
#                    'end':  66483
#                   'text':  'artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'artikel 5.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  66528
#                    'end':  66564
#                   'text':  'artikel 5.1 van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 9:36 wor'
#                   'type':  'artikel'
#                  'start':  66854
#                    'end':  66870
#                   'text':  'artikel 9:36 wor'
#                'details':  OrderedDict([('artikel', '9:36'), ('nameref', 'wor')])
#
# Matched: 'artikel 9:18'
#                   'type':  'artikel'
#                  'start':  67159
#                    'end':  67171
#                   'text':  'artikel 9:18'
#                'details':  OrderedDict([('artikel', '9:18')])
#
# Matched: 'artikel 4 van bi'
#                   'type':  'artikel'
#                  'start':  67312
#                    'end':  67328
#                   'text':  'artikel 4 van bi'
#                'details':  OrderedDict([('artikel', '4'), ('nameref', 'bi')])
#
# Matched: 'artikel 20 van de Bankwet 1998'
#                   'type':  'artikel'
#                  'start':  67504
#                    'end':  67534
#                   'text':  'artikel 20 van de Bankwet 1998'
#                'details':  OrderedDict([('artikel', '20'), ('nameref', 'Bankwet 1998')])
#
# Matched: 'artikel 2, eerste lid'
#                   'type':  'artikel'
#                  'start':  67545
#                    'end':  67566
#                   'text':  'artikel 2, eerste lid'
#                'details':  OrderedDict([('artikel', '2'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 1.89, eerste lid van de Wet op het financieel toezicht'
#                   'type':  'artikel'
#                  'start':  67854
#                    'end':  67916
#                   'text':  'artikel 1.89, eerste lid van de Wet op het financieel toezicht'
#                'details':  OrderedDict([('artikel', '1.89'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Wet op het financieel toezicht')])
#
# Matched: 'artikel 17, tweede lid, van de Wet verplichte deelneming in een bedrijfstakpensioenfonds'
#                   'type':  'artikel'
#                  'start':  68251
#                    'end':  68339
#                   'text':  'artikel 17, tweede lid, van de Wet verplichte deelneming in een bedrijfstakpensioenfonds'
#                'details':  OrderedDict([('artikel', '17'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'Wet verplichte deelneming in een bedrijfstakpensioenfonds')])
#
# Matched: 'artikel 7.40'
#                   'type':  'artikel'
#                  'start':  68573
#                    'end':  68585
#                   'text':  'artikel 7.40'
#                'details':  OrderedDict([('artikel', '7.40')])
#
# Matched: 'artikel\n                                    2.2 van die wet'
#                   'type':  'artikel'
#                  'start':  69347
#                    'end':  69406
#                   'text':  'artikel\n                                    2.2 van die wet'
#                'details':  OrderedDict([('artikel', '2.2'), ('nameref', 'van die wet')])
#
# Matched: 'artikel 7.41, eerste lid'
#                   'type':  'artikel'
#                  'start':  69715
#                    'end':  69739
#                   'text':  'artikel 7.41, eerste lid'
#                'details':  OrderedDict([('artikel', '7.41'), ('lid', 'eerste'), ('lid_num', [1])])
#
# Matched: 'artikel 2.36, tweede lid, wor'
#                   'type':  'artikel'
#                  'start':  70141
#                    'end':  70170
#                   'text':  'artikel 2.36, tweede lid, wor'
#                'details':  OrderedDict([('artikel', '2.36'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'wor')])
#
# Matched: 'artikel 10, eerste lid, van de Wet openbaarheid'
#                   'type':  'artikel'
#                  'start':  70174
#                    'end':  70221
#                   'text':  'artikel 10, eerste lid, van de Wet openbaarheid'
#                'details':  OrderedDict([('artikel', '10'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Wet openbaarheid')])
#
# Matched: 'artikel 5.1, eerste lid, van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  70275
#                    'end':  70324
#                   'text':  'artikel 5.1, eerste lid, van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 10, tweede lid, van die wet'
#                   'type':  'artikel'
#                  'start':  70360
#                    'end':  70395
#                   'text':  'artikel 10, tweede lid, van die wet'
#                'details':  OrderedDict([('artikel', '10'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'van die wet')])
#
# Matched: 'artikel 5.1, tweede lid,\n                        van die wet'
#                   'type':  'artikel'
#                  'start':  70413
#                    'end':  70473
#                   'text':  'artikel 5.1, tweede lid,\n                        van die wet'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'van die wet')])
#
# Matched: 'artikel 9.7.4.14, eerste lid, wor'
#                   'type':  'artikel'
#                  'start':  70503
#                    'end':  70536
#                   'text':  'artikel 9.7.4.14, eerste lid, wor'
#                'details':  OrderedDict([('artikel', '9.7.4.14'), ('lid', 'eerste'), ('lid_num', [1]), ('nameref', 'wor')])
#
# Matched: 'Artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  70540
#                    'end':  70586
#                   'text':  'Artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'Artikel 5.1, eerste en tweede lid, van de wet open overheid'
#                   'type':  'artikel'
#                  'start':  70628
#                    'end':  70687
#                   'text':  'Artikel 5.1, eerste en tweede lid, van de wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'wet open overheid')])
#
# Matched: 'artikel 12.24, derde lid, wor'
#                   'type':  'artikel'
#                  'start':  70717
#                    'end':  70746
#                   'text':  'artikel 12.24, derde lid, wor'
#                'details':  OrderedDict([('artikel', '12.24'), ('lid', 'derde'), ('lid_num', [3]), ('nameref', 'wor')])
#
# Matched: 'Artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  70750
#                    'end':  70796
#                   'text':  'Artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'Artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  70838
#                    'end':  70897
#                   'text':  'Artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 13.6'
#                   'type':  'artikel'
#                  'start':  70926
#                    'end':  70938
#                   'text':  'artikel 13.6'
#                'details':  OrderedDict([('artikel', '13.6')])
#
# Matched: 'Artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  70948
#                    'end':  70994
#                   'text':  'Artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'artikel 16.4a, tweede lid, wor'
#                   'type':  'artikel'
#                  'start':  71072
#                    'end':  71102
#                   'text':  'artikel 16.4a, tweede lid, wor'
#                'details':  OrderedDict([('artikel', '16.4a'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'wor')])
#
# Matched: 'Artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  71106
#                    'end':  71152
#                   'text':  'Artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'Artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  71194
#                    'end':  71253
#                   'text':  'Artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 16.46b, negende lid, wor'
#                   'type':  'artikel'
#                  'start':  71282
#                    'end':  71314
#                   'text':  'artikel 16.46b, negende lid, wor'
#                'details':  OrderedDict([('artikel', '16.46b'), ('lid', 'negende'), ('lid_num', [9]), ('nameref', 'wor')])
#
# Matched: 'Artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  71318
#                    'end':  71364
#                   'text':  'Artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'Artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  71406
#                    'end':  71465
#                   'text':  'Artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'Wet open overheid')])
#
# Matched: 'Artikel 19.1a, tweede lid'
#                   'type':  'artikel'
#                  'start':  71491
#                    'end':  71516
#                   'text':  'Artikel 19.1a, tweede lid'
#                'details':  OrderedDict([('artikel', '19.1a'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 2.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  71569
#                    'end':  71605
#                   'text':  'artikel 2.1 van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '2.1'), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 19.1c wor'
#                   'type':  'artikel'
#                  'start':  71716
#                    'end':  71733
#                   'text':  'artikel 19.1c wor'
#                'details':  OrderedDict([('artikel', '19.1c'), ('nameref', 'wor')])
#
# Matched: 'artikel 8 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  71737
#                    'end':  71782
#                   'text':  'artikel 8 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '8'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'Artikel 19.3 wor'
#                   'type':  'artikel'
#                  'start':  71898
#                    'end':  71914
#                   'text':  'Artikel 19.3 wor'
#                'details':  OrderedDict([('artikel', '19.3'), ('nameref', 'wor')])
#
# Matched: 'artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  71967
#                    'end':  72013
#                   'text':  'artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  72058
#                    'end':  72117
#                   'text':  'artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 10, eerste lid, aanhef en onder b'
#                   'type':  'artikel'
#                  'start':  72173
#                    'end':  72214
#                   'text':  'artikel 10, eerste lid, aanhef en onder b'
#                'details':  OrderedDict([('artikel', '10'), ('lid', 'eerste'), ('aanhefonder', 'aanhef en onder b'), ('lid_num', [1])])
#
# Matched: 'artikel 10, tweede lid, aanhef en onder a, van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  72261
#                    'end':  72339
#                   'text':  'artikel 10, tweede lid, aanhef en onder a, van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('lid', 'tweede'), ('aanhefonder', 'aanhef en onder a'), ('lid_num', [2]), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'artikel 5.1, eerste lid, aanhef en onder b'
#                   'type':  'artikel'
#                  'start':  72384
#                    'end':  72426
#                   'text':  'artikel 5.1, eerste lid, aanhef en onder b'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste'), ('aanhefonder', 'aanhef en onder b'), ('lid_num', [1])])
#
# Matched: 'artikel 19.6b wor'
#                   'type':  'artikel'
#                  'start':  72560
#                    'end':  72577
#                   'text':  'artikel 19.6b wor'
#                'details':  OrderedDict([('artikel', '19.6b'), ('nameref', 'wor')])
#
# Matched: 'artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  72581
#                    'end':  72627
#                   'text':  'artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  72677
#                    'end':  72736
#                   'text':  'artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'Wet open overheid')])
#
# Matched: 'Artikel 19.7 wor'
#                   'type':  'artikel'
#                  'start':  72762
#                    'end':  72778
#                   'text':  'Artikel 19.7 wor'
#                'details':  OrderedDict([('artikel', '19.7'), ('nameref', 'wor')])
#
# Matched: 'artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  72831
#                    'end':  72877
#                   'text':  'artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  72922
#                    'end':  72981
#                   'text':  'artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 10, eerste lid, aanhef en onder b'
#                   'type':  'artikel'
#                  'start':  73037
#                    'end':  73078
#                   'text':  'artikel 10, eerste lid, aanhef en onder b'
#                'details':  OrderedDict([('artikel', '10'), ('lid', 'eerste'), ('aanhefonder', 'aanhef en onder b'), ('lid_num', [1])])
#
# Matched: 'artikel 10, tweede lid, aanhef en onder a, van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  73125
#                    'end':  73203
#                   'text':  'artikel 10, tweede lid, aanhef en onder a, van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('lid', 'tweede'), ('aanhefonder', 'aanhef en onder a'), ('lid_num', [2]), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'artikel 5.1, eerste lid, aanhef en onder b'
#                   'type':  'artikel'
#                  'start':  73248
#                    'end':  73290
#                   'text':  'artikel 5.1, eerste lid, aanhef en onder b'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste'), ('aanhefonder', 'aanhef en onder b'), ('lid_num', [1])])
#
# Matched: 'artikel 9.8 wor'
#                   'type':  'artikel'
#                  'start':  73424
#                    'end':  73439
#                   'text':  'artikel 9.8 wor'
#                'details':  OrderedDict([('artikel', '9.8'), ('nameref', 'wor')])
#
# Matched: 'artikel 10, zevende lid, onder b, van de Wet openbaarheid'
#                   'type':  'artikel'
#                  'start':  73443
#                    'end':  73500
#                   'text':  'artikel 10, zevende lid, onder b, van de Wet openbaarheid'
#                'details':  OrderedDict([('artikel', '10'), ('lid', 'zevende'), ('aanhefonder', 'onder b'), ('lid_num', [7]), ('nameref', 'Wet openbaarheid')])
#
# Matched: 'artikel 5.1, tweede lid, onder h, van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  73554
#                    'end':  73612
#                   'text':  'artikel 5.1, tweede lid, onder h, van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'tweede'), ('aanhefonder', 'onder h'), ('lid_num', [2]), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 25, eerste en tweede lid, wor'
#                   'type':  'artikel'
#                  'start':  73683
#                    'end':  73720
#                   'text':  'artikel 25, eerste en tweede lid, wor'
#                'details':  OrderedDict([('artikel', '25'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'wor')])
#
# Matched: 'artikel 10 van de Wet openbaarheid'
#                   'type':  'artikel'
#                  'start':  73724
#                    'end':  73758
#                   'text':  'artikel 10 van de Wet openbaarheid'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid')])
#
# Matched: 'artikel 5.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  73820
#                    'end':  73856
#                   'text':  'artikel 5.1 van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 55, eerste en tweede lid, wor'
#                   'type':  'artikel'
#                  'start':  73885
#                    'end':  73922
#                   'text':  'artikel 55, eerste en tweede lid, wor'
#                'details':  OrderedDict([('artikel', '55'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'wor')])
#
# Matched: 'artikel 10 van de Wet openbaarheid'
#                   'type':  'artikel'
#                  'start':  73926
#                    'end':  73960
#                   'text':  'artikel 10 van de Wet openbaarheid'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid')])
#
# Matched: 'artikel 5.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  74022
#                    'end':  74058
#                   'text':  'artikel 5.1 van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 86, eerste en tweede lid, wor'
#                   'type':  'artikel'
#                  'start':  74087
#                    'end':  74124
#                   'text':  'artikel 86, eerste en tweede lid, wor'
#                'details':  OrderedDict([('artikel', '86'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'wor')])
#
# Matched: 'artikel 10 van de Wet openbaarheid'
#                   'type':  'artikel'
#                  'start':  74128
#                    'end':  74162
#                   'text':  'artikel 10 van de Wet openbaarheid'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid')])
#
# Matched: 'artikel 5.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  74224
#                    'end':  74260
#                   'text':  'artikel 5.1 van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 31n wor'
#                   'type':  'artikel'
#                  'start':  74331
#                    'end':  74346
#                   'text':  'artikel 31n wor'
#                'details':  OrderedDict([('artikel', '31n'), ('nameref', 'wor')])
#
# Matched: 'Artikel 10 van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  74350
#                    'end':  74396
#                   'text':  'Artikel 10 van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'Artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  74446
#                    'end':  74505
#                   'text':  'Artikel 5.1, eerste en tweede lid, van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 120, derde lid, wor'
#                   'type':  'artikel'
#                  'start':  74534
#                    'end':  74561
#                   'text':  'artikel 120, derde lid, wor'
#                'details':  OrderedDict([('artikel', '120'), ('lid', 'derde'), ('lid_num', [3]), ('nameref', 'wor')])
#
# Matched: 'artikel\n                        10, eerste lid, onderdeel c, van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  74610
#                    'end':  74706
#                   'text':  'artikel\n                        10, eerste lid, onderdeel c, van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('lid', 'eerste'), ('aanhefonder', 'onderdeel c'), ('lid_num', [1]), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'artikel 5.1, eerste lid, onderdeel c'
#                   'type':  'artikel'
#                  'start':  74782
#                    'end':  74818
#                   'text':  'artikel 5.1, eerste lid, onderdeel c'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'eerste'), ('aanhefonder', 'onderdeel c'), ('lid_num', [1])])
#
# Matched: 'artikel 123, derde en vierde lid, en vijfde lid, onderdeel c, wor'
#                   'type':  'artikel'
#                  'start':  74961
#                    'end':  75026
#                   'text':  'artikel 123, derde en vierde lid, en vijfde lid, onderdeel c, wor'
#                'details':  OrderedDict([('artikel', '123'), ('lid', 'derde en vierde'), ('aanhefonder', 'onderdeel c'), ('lid_num', [3, 4]), ('nameref', 'wor')])
#
# Matched: 'artikel 10,\n                        eerste lid, onderdeel c, van de Wet openbaarheid van bestuur'
#                   'type':  'artikel'
#                  'start':  75030
#                    'end':  75126
#                   'text':  'artikel 10,\n                        eerste lid, onderdeel c, van de Wet openbaarheid van bestuur'
#                'details':  OrderedDict([('artikel', '10'), ('lid', 'eerste'), ('aanhefonder', 'onderdeel c'), ('lid_num', [1]), ('nameref', 'Wet openbaarheid van bestuur')])
#
# Matched: 'artikel 5.1, eerste lid, onderdeel c, of tweede lid, onderdeel f, van de Wet open'
#                   'type':  'artikel'
#                  'start':  75176
#                    'end':  75257
#                   'text':  'artikel 5.1, eerste lid, onderdeel c, of tweede lid, onderdeel f, van de Wet open'
#                'details':  OrderedDict([('artikel', '5.1'), ('lid', 'tweede'), ('aanhefonder', 'onderdeel f'), ('lid_num', [2]), ('nameref', 'Wet open')])
#
# Matched: 'artikel 25, eerste en tweede lid, wor'
#                   'type':  'artikel'
#                  'start':  75362
#                    'end':  75399
#                   'text':  'artikel 25, eerste en tweede lid, wor'
#                'details':  OrderedDict([('artikel', '25'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'wor')])
#
# Matched: 'artikel 10 van de Wet openbaarheid'
#                   'type':  'artikel'
#                  'start':  75403
#                    'end':  75437
#                   'text':  'artikel 10 van de Wet openbaarheid'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid')])
#
# Matched: 'artikel 5.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  75499
#                    'end':  75535
#                   'text':  'artikel 5.1 van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 55, eerste en tweede lid, wor'
#                   'type':  'artikel'
#                  'start':  75564
#                    'end':  75601
#                   'text':  'artikel 55, eerste en tweede lid, wor'
#                'details':  OrderedDict([('artikel', '55'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'wor')])
#
# Matched: 'artikel 10 van de Wet openbaarheid'
#                   'type':  'artikel'
#                  'start':  75605
#                    'end':  75639
#                   'text':  'artikel 10 van de Wet openbaarheid'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid')])
#
# Matched: 'artikel 5.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  75701
#                    'end':  75737
#                   'text':  'artikel 5.1 van de Wet open overheid'
#                'details':  OrderedDict([('artikel', '5.1'), ('nameref', 'Wet open overheid')])
#
# Matched: 'artikel 91, eerste en tweede lid, wor'
#                   'type':  'artikel'
#                  'start':  75766
#                    'end':  75803
#                   'text':  'artikel 91, eerste en tweede lid, wor'
#                'details':  OrderedDict([('artikel', '91'), ('lid', 'eerste en tweede'), ('lid_num', [1, 2]), ('nameref', 'wor')])
#
# Matched: 'artikel 10 van de Wet openbaarheid'
#                   'type':  'artikel'
#                  'start':  75807
#                    'end':  75841
#                   'text':  'artikel 10 van de Wet openbaarheid'
#                'details':  OrderedDict([('artikel', '10'), ('nameref', 'Wet openbaarheid')])
#
# Matched: 'artikel 5.1 van de Wet open overheid'
#                   'type':  'artikel'
#                  'start':  75903
#                    'end':  75939
#                   'text':  'artikel 5.1 van de Wet open overheid'
# ...
#
# Matched: 'artikel\n                           5:20, tweede lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  108842
#                    'end':  108928
#                   'text':  'artikel\n                           5:20, tweede lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '5:20'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 1a'
#                   'type':  'artikel'
#                  'start':  109192
#                    'end':  109202
#                   'text':  'artikel 1a'
#                'details':  OrderedDict([('artikel', '1a')])
#
# Matched: 'artikel 39, eerste lid, onderdeel b'
#                   'type':  'artikel'
#                  'start':  109247
#                    'end':  109282
#                   'text':  'artikel 39, eerste lid, onderdeel b'
#                'details':  OrderedDict([('artikel', '39'), ('lid', 'eerste'), ('aanhefonder', 'onderdeel b'), ('lid_num', [1])])
#
# Matched: 'artikel 5:20, tweede lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  109356
#                    'end':  109415
#                   'text':  'artikel 5:20, tweede lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '5:20'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 13'
#                   'type':  'artikel'
#                  'start':  110061
#                    'end':  110071
#                   'text':  'artikel 13'
#                'details':  OrderedDict([('artikel', '13')])
#
# Matched: 'artikel 67'
#                   'type':  'artikel'
#                  'start':  110122
#                    'end':  110132
#                   'text':  'artikel 67'
#                'details':  OrderedDict([('artikel', '67')])
#
# Matched: 'artikel 9.2, derde lid'
#                   'type':  'artikel'
#                  'start':  110171
#                    'end':  110193
#                   'text':  'artikel 9.2, derde lid'
#                'details':  OrderedDict([('artikel', '9.2'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel\n                           5:20, tweede lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  110240
#                    'end':  110326
#                   'text':  'artikel\n                           5:20, tweede lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '5:20'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 68'
#                   'type':  'artikel'
#                  'start':  110634
#                    'end':  110644
#                   'text':  'artikel 68'
#                'details':  OrderedDict([('artikel', '68')])
#
# Matched: 'artikel 65'
#                   'type':  'artikel'
#                  'start':  110843
#                    'end':  110853
#                   'text':  'artikel 65'
#                'details':  OrderedDict([('artikel', '65')])
#
# Matched: 'artikel 28'
#                   'type':  'artikel'
#                  'start':  110989
#                    'end':  110999
#                   'text':  'artikel 28'
#                'details':  OrderedDict([('artikel', '28')])
#
# Matched: 'artikel 20a'
#                   'type':  'artikel'
#                  'start':  111097
#                    'end':  111108
#                   'text':  'artikel 20a'
#                'details':  OrderedDict([('artikel', '20a')])
#
# Matched: 'artikel 10'
#                   'type':  'artikel'
#                  'start':  111316
#                    'end':  111326
#                   'text':  'artikel 10'
#                'details':  OrderedDict([('artikel', '10')])
#
# Matched: 'artikel 59, vijfde lid'
#                   'type':  'artikel'
#                  'start':  111396
#                    'end':  111418
#                   'text':  'artikel 59, vijfde lid'
#                'details':  OrderedDict([('artikel', '59'), ('lid', 'vijfde'), ('lid_num', [5])])
#
# Matched: 'artikel 11a.2, derde lid'
#                   'type':  'artikel'
#                  'start':  111860
#                    'end':  111884
#                   'text':  'artikel 11a.2, derde lid'
#                'details':  OrderedDict([('artikel', '11a'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 36'
#                   'type':  'artikel'
#                  'start':  111922
#                    'end':  111932
#                   'text':  'artikel 36'
#                'details':  OrderedDict([('artikel', '36')])
#
# Matched: 'artikel 43'
#                   'type':  'artikel'
#                  'start':  112050
#                    'end':  112060
#                   'text':  'artikel 43'
#                'details':  OrderedDict([('artikel', '43')])
#
# Matched: 'artikel 32'
#                   'type':  'artikel'
#                  'start':  112283
#                    'end':  112293
#                   'text':  'artikel 32'
#                'details':  OrderedDict([('artikel', '32')])
#
# Matched: 'artikel 22'
#                   'type':  'artikel'
#                  'start':  112369
#                    'end':  112379
#                   'text':  'artikel 22'
#                'details':  OrderedDict([('artikel', '22')])
#
# Matched: 'artikel 24'
#                   'type':  'artikel'
#                  'start':  112441
#                    'end':  112451
#                   'text':  'artikel 24'
#                'details':  OrderedDict([('artikel', '24')])
#
# Matched: 'artikel 18b'
#                   'type':  'artikel'
#                  'start':  112785
#                    'end':  112796
#                   'text':  'artikel 18b'
#                'details':  OrderedDict([('artikel', '18b')])
#
# Matched: 'artikel 10, tweede lid'
#                   'type':  'artikel'
#                  'start':  113264
#                    'end':  113286
#                   'text':  'artikel 10, tweede lid'
#                'details':  OrderedDict([('artikel', '10'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 5:20, tweede lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  113352
#                    'end':  113411
#                   'text':  'artikel 5:20, tweede lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '5:20'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 7.2.10, zesde lid'
#                   'type':  'artikel'
#                  'start':  113684
#                    'end':  113709
#                   'text':  'artikel 7.2.10, zesde lid'
#                'details':  OrderedDict([('artikel', '7.2.10'), ('lid', 'zesde'), ('lid_num', [6])])
#
# Matched: 'artikel 8'
#                   'type':  'artikel'
#                  'start':  113783
#                    'end':  113792
#                   'text':  'artikel 8'
#                'details':  OrderedDict([('artikel', '8')])
#
# Matched: 'artikel 25, vierde, vijfde en zesde lid'
#                   'type':  'artikel'
#                  'start':  113940
#                    'end':  113979
#                   'text':  'artikel 25, vierde, vijfde en zesde lid'
#                'details':  OrderedDict([('artikel', '25'), ('lid', 'vierde, vijfde en zesde'), ('lid_num', [4, 5, 6])])
#
# Matched: 'artikel 2.24'
#                   'type':  'artikel'
#                  'start':  114047
#                    'end':  114059
#                   'text':  'artikel 2.24'
#                'details':  OrderedDict([('artikel', '2.24')])
#
# Matched: 'artikel 1.57d'
#                   'type':  'artikel'
#                  'start':  114539
#                    'end':  114552
#                   'text':  'artikel 1.57d'
#                'details':  OrderedDict([('artikel', '1.57d')])
#
# Matched: 'artikel 5:20, tweede lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  114987
#                    'end':  115046
#                   'text':  'artikel 5:20, tweede lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '5:20'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 10.4.1, tweede lid'
#                   'type':  'artikel'
#                  'start':  115324
#                    'end':  115350
#                   'text':  'artikel 10.4.1, tweede lid'
#                'details':  OrderedDict([('artikel', '10.4.1'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 5:20, tweede lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  115416
#                    'end':  115475
#                   'text':  'artikel 5:20, tweede lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '5:20'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 5:20, tweede lid, van de\n                           Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  115948
#                    'end':  116034
#                   'text':  'artikel 5:20, tweede lid, van de\n                           Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '5:20'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 8'
#                   'type':  'artikel'
#                  'start':  116305
#                    'end':  116314
#                   'text':  'artikel 8'
#                'details':  OrderedDict([('artikel', '8')])
#
# Matched: 'artikel\n                           18'
#                   'type':  'artikel'
#                  'start':  116419
#                    'end':  116456
#                   'text':  'artikel\n                           18'
#                'details':  OrderedDict([('artikel', '18')])
#
# Matched: 'artikel 87, tweede lid'
#                   'type':  'artikel'
#                  'start':  116539
#                    'end':  116561
#                   'text':  'artikel 87, tweede lid'
#                'details':  OrderedDict([('artikel', '87'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 5:20, tweede lid'
#                   'type':  'artikel'
#                  'start':  116635
#                    'end':  116659
#                   'text':  'artikel 5:20, tweede lid'
#                'details':  OrderedDict([('artikel', '5:20'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 3a'
#                   'type':  'artikel'
#                  'start':  117027
#                    'end':  117037
#                   'text':  'artikel 3a'
#                'details':  OrderedDict([('artikel', '3a')])
#
# Matched: 'artikel 2, tweede lid, van die wet'
#                   'type':  'artikel'
#                  'start':  117207
#                    'end':  117241
#                   'text':  'artikel 2, tweede lid, van die wet'
#                'details':  OrderedDict([('artikel', '2'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'van die wet')])
#
# Matched: 'artikel 1:42'
#                   'type':  'artikel'
#                  'start':  117618
#                    'end':  117630
#                   'text':  'artikel 1:42'
#                'details':  OrderedDict([('artikel', '1:42')])
#
# Matched: 'artikel 1.25'
#                   'type':  'artikel'
#                  'start':  117735
#                    'end':  117747
#                   'text':  'artikel 1.25'
#                'details':  OrderedDict([('artikel', '1.25')])
#
# Matched: 'artikel 5'
#                   'type':  'artikel'
#                  'start':  117800
#                    'end':  117809
#                   'text':  'artikel 5'
#                'details':  OrderedDict([('artikel', '5')])
#
# Matched: 'artikel 6, vierde, zesde en zevende lid'
#                   'type':  'artikel'
#                  'start':  117868
#                    'end':  117907
#                   'text':  'artikel 6, vierde, zesde en zevende lid'
#                'details':  OrderedDict([('artikel', '6'), ('lid', 'vierde, zesde en zevende'), ('lid_num', [4, 6, 7])])
#
# Matched: 'artikel 10b4, zevende lid'
#                   'type':  'artikel'
#                  'start':  117969
#                    'end':  117994
#                   'text':  'artikel 10b4, zevende lid'
#                'details':  OrderedDict([('artikel', '10b'), ('lid', 'zevende'), ('lid_num', [7])])
#
# Matched: 'artikel 46, derde lid'
#                   'type':  'artikel'
#                  'start':  118422
#                    'end':  118443
#                   'text':  'artikel 46, derde lid'
#                'details':  OrderedDict([('artikel', '46'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 1.5'
#                   'type':  'artikel'
#                  'start':  118977
#                    'end':  118988
#                   'text':  'artikel 1.5'
#                'details':  OrderedDict([('artikel', '1.5')])
#
# Matched: 'artikel 43'
#                   'type':  'artikel'
#                  'start':  119055
#                    'end':  119065
#                   'text':  'artikel 43'
#                'details':  OrderedDict([('artikel', '43')])
#
# Matched: 'artikel 49'
#                   'type':  'artikel'
#                  'start':  119490
#                    'end':  119500
#                   'text':  'artikel 49'
#                'details':  OrderedDict([('artikel', '49')])
#
# Matched: 'artikel 17, tweede\n                           lid'
#                   'type':  'artikel'
#                  'start':  119705
#                    'end':  119754
#                   'text':  'artikel 17, tweede\n                           lid'
#                'details':  OrderedDict([('artikel', '17'), ('lid', 'tweede'), ('lid_num', [2])])
#
# Matched: 'artikel 204 van de Pensioenwet'
#                   'type':  'artikel'
#                  'start':  119763
#                    'end':  119793
#                   'text':  'artikel 204 van de Pensioenwet'
#                'details':  OrderedDict([('artikel', '204'), ('nameref', 'Pensioenwet')])
#
# Matched: 'artikel 13.1, derde lid'
#                   'type':  'artikel'
#                  'start':  119866
#                    'end':  119889
#                   'text':  'artikel 13.1, derde lid'
#                'details':  OrderedDict([('artikel', '13.1'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 5:20, tweede lid, van de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  119958
#                    'end':  120017
#                   'text':  'artikel 5:20, tweede lid, van de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '5:20'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel\n                           60, derde lid'
#                   'type':  'artikel'
#                  'start':  120331
#                    'end':  120379
#                   'text':  'artikel\n                           60, derde lid'
#                'details':  OrderedDict([('artikel', '60'), ('lid', 'derde'), ('lid_num', [3])])
#
# Matched: 'artikel 5:20, tweede lid, van\n                           de Algemene wet bestuursrecht'
#                   'type':  'artikel'
#                  'start':  120421
#                    'end':  120507
#                   'text':  'artikel 5:20, tweede lid, van\n                           de Algemene wet bestuursrecht'
#                'details':  OrderedDict([('artikel', '5:20'), ('lid', 'tweede'), ('lid_num', [2]), ('nameref', 'Algemene wet bestuursrecht')])
#
# Matched: 'artikel 29'
#                   'type':  'artikel'
#                  'start':  120785
#                    'end':  120795
#                   'text':  'artikel 29'
#                'details':  OrderedDict([('artikel', '29')])
#
# Matched: 'artikel 93'
#                   'type':  'artikel'
#                  'start':  121144
#                    'end':  121154
#                   'text':  'artikel 93'
#                'details':  OrderedDict([('artikel', '93')])

# %% [markdown]
# ## Marking this up in spacy
#
# In visualizations it might be useful to mark them in the document,
# as if they are (named) entities (note to self: spanruler style might make more sense).

# %%
import spacy, spacy.displacy
dutch = spacy.load('nl_core_news_lg')

# %%
test_texts = [
    # different types
    " BWBR000011  CVDR101405  CVDR101405_1 CVDR101405/1  Stb. 2011, 35;  33684R2020  ECLI:NL:HR:2005:AT4537   OJ L 69, 13.3.2013, p. 1  Council Directive 93/42/EEC of 14 June 1993   LJNs: BO6106  AO7817, NJ 2005, 270 ",
    # varied 'artikel' style cases
    '\n'.join(looser_testcases),
    # 
    'art. 2.12, eerste lid, aanhef en onder a, sub 1º artikel 79, aanhef en onder 6º artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo',
    htmltext[35500:37000], # a fragment of it, we get the idea
]

for test_text in test_texts:
    print( '-'*80 )

    doc = dutch( test_text )
    # note that you have to give exactly the same string to find_references and mark_references_spacy,
    # or the offsets will be wrong;   we use doc.text which should ensure that
    matches = wetsuite.helpers.patterns.find_references( doc.text, ljn=True) 
    wetsuite.helpers.patterns.mark_references_spacy( doc, matches )
    spacy.displacy.render( doc, style='ent', jupyter=True,
        # these are not the regular entity names displacy already chose some colors for, so:
        options={"colors":{'ECLI':'#ffaaaa', 'BWB':'#ff5577', 'CVDR':'#7755ff', 'CELEX':'#ffaaff', 'VINDPLAATS':'#aaaaff', 'EUOJ':'#aaffaa', 'EUDIR':'#aaffdd', 'LJN':'#5588ff', 'ARTIKEL':'#ffaa77'}}
    )

    #for reference in wetsuite.helpers.patterns.find_references( test_text, ljn=True ):
    #    print()
    #    pprint.pprint( reference )
# Out:
# --------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ff5577; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BWBR000011
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">BWB</span>
# </mark>
#
# <mark class="entity" style="background: #7755ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CVDR101405
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CVDR</span>
# </mark>
#
# <mark class="entity" style="background: #7755ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CVDR101405_1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CVDR</span>
# </mark>
#
# <mark class="entity" style="background: #7755ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CVDR101405/1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CVDR</span>
# </mark>
#
# <mark class="entity" style="background: #aaaaff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stb. 2011, 35
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VINDPLAATS</span>
# </mark>
# ;
# <mark class="entity" style="background: #ffaaff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     33684R2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CELEX</span>
# </mark>
#
# <mark class="entity" style="background: #ffaaaa; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ECLI:NL:HR:2005:AT4537
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ECLI</span>
# </mark>
#
# <mark class="entity" style="background: #aaffaa; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OJ L 69, 13.3.2013, p. 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EUOJ</span>
# </mark>
#
# <mark class="entity" style="background: #aaffdd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Council Directive 93/42/EEC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EUDIR</span>
# </mark>
#  of 14 June 1993   LJNs:
# <mark class="entity" style="background: #5588ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BO6106
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LJN</span>
# </mark>
#
# <mark class="entity" style="background: #5588ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AO7817
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LJN</span>
# </mark>
# , NJ 2005, 270 </div></span>
# --------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 8:75a, eerste lid, tweede volzin, van de Awb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 5:9, aanhef en onder b, Awb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 8, aanhef en onder c, Wet bescherming persoonsgegevens (Wbp)
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 10, tweede lid, aanhef en onder e, van de Wob
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Artikel 10, tweede lid, aanhef en onder e
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  van de. Wet openbaarheid van bestuur<br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 6:80 lid 1 aanhef en onder b BW
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 4, aanhef en onder d en g
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# , van de standaardvoorwaarden<br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 3.3, zevende lid, aanhef en onder i, Woo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 15, aanhef en onder a
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  of c (oud) RWN<br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 81q lid 3c Gemeentewet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#   <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 4:25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# , 4:35 van de Awb en
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  van de ASV<br>Wabo,
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 2.12, eerste lid, aanhef en onder a, sub 1º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 79, aanhef en onder 6º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 142, eerste lid, aanhef en onder b (en derde lid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# ), van het Wetboek van Strafvordering<br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 2, eerste, tweede, vijfde, en zesenzestigste lid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 166 lid 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  in verbinding met
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 353 lid 1 Rv
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 13, derde lid, van de Wet tarieven in burgerlijke zaken
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 7, eerste lid, onderdeel a
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 7, eerste lid, aanhef en ond
# --------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     art. 2.12, eerste lid, aanhef en onder a, sub 1º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 79, aanhef en onder 6º
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 3.3, zevende lid jo. vijfde lid, aanhef en onder i, Woo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# </div></span>
# --------------------------------------------------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> bestuursorgaan beslist op het verzoek om informatie zo spoedig mogelijk, doch<br>                              uiterlijk binnen vier weken gerekend vanaf de dag na die waarop het verzoek is ontvangen.<br>                            2.  Het bestuursorgaan kan de beslissing voor ten hoogste twee weken verdagen, indien<br>                              de omvang of de gecompliceerdheid van de informatie een verlenging rechtvaardigt.<br>                              Van de verdaging wordt voor de afloop van de eerste termijn schriftelijk gemotiveerd<br>                              mededeling gedaan aan de verzoeker.<br>                            3.  Onverminderd
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 4:15 van de Algemene wet bestuursrecht
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
#  wordt de termijn voor<br>                              het geven van een beschikking opgeschort gerekend vanaf de dag na die waarop het bestuursorgaan<br>                              de verzoeker meedeelt dat toepassing is gegeven aan
# <mark class="entity" style="background: #ffaa77; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artikel 4:8 van de Algemene wet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ARTIKEL</span>
# </mark>
# <br>                              bestuursrecht, tot en met de dag waarop door de belanghebbende of belanghebbenden<br>                              een zienswijze naar voren is gebracht of de daarvoor gestelde termijn ongebruikt is<br>                              verstreken.<br>                            4.  Indien de opschorting, bedoeld in het derde lid, eindigt, doet het bestuursorgaan<br>                              daarvan zo spoedig mogelijk mededeling aan de verzoeker, onder vermelding van de termijn<br>                              binnen we</div></span>

# %% [markdown]
# ## Going further?
#
# It would be quite interesting that if
#
# - we resolved what it's pointing to, e.g. made input like `"artikel 4, tweede lid, aanhef en onder d, van het reglement van orde voor de ministerraad"` give any or **preferably all** of:
#    - BWBR0006501
#    - https://wetten.overheid.nl/jci1.3:c:BWBR0006501&artikel=4    or
#      https://wetten.overheid.nl/jci1.3:c:BWBR0006501&paragraaf=2&artikel=4
#    - jci1.3:c:BWBR0006501&paragraaf=2&artikel=4
#    - ['4',
#       '2',
#       'Te dien einde beraadslaagt en besluit de raad onder meer over:',
#       'het bekendheid geven aan beleidsvoornemens in welke vorm dan ook, die van invloed kunnen zijn op de positie van het kabinet, '
#       'of die belangrijke financiële consequenties kunnen hebben, benevens over beleidsvoornemens van een minister die het beleid van '
#       'andere ministers kunnen raken en waarover het bereiken van overeenstemming niet mogelijk is gebleken;'
#      ]
#
# - we could deal with **document-internal references**, e.g. BWBR0004302's artikel 3, lid 1 has "artikel 2, eerste, tweede, en vijfde lid", which in that context ought to give something like:
#    - ['2',
#       ['1', '2', '5'],
#       ['Bij of krachtens algemene maatregel van bestuur worden in het belang van de volksgezondheid eisen gesteld aan tabaksproducten, ',
#        'elektronische dampwaar, nicotinehoudende vloeistof en niet-nicotinehoudende vloeistof met betrekking tot maximumemissieniveaus ',
#        'en ingrediënten en worden technische eisen gesteld, en kunnen methoden van onderzoek worden aangewezen die bij uitsluiting ',
#        'beslissend zijn voor de vaststelling of met betrekking tot een product al dan niet aan de daaraan gestelde eisen is voldaan.,
#
#               Bij of krachtens algemene maatregel van bestuur worden in het belang van de volksgezondheid eisen gesteld aan de verpakkingseenheid en de buitenverpakking van tabaksproducten en aanverwante producten. De eisen hebben betrekking op:
#
#           a. de aanduidingen op verpakkingseenheden en buitenverpakkingen;
#
#           b. de hoeveelheid of het aantal stuks dat is verpakt;
#
#           c. de presentatie van het product;
#
#           d. de sluiting, vorm, afmetingen en materiaal van de verpakkingseenheid of de buitenverpakking; en
#
#           e. andere elementen van de verpakkingseenheid en de buitenverpakking die gebruikt kunnen worden om een onderscheid te maken tussen de verschillende merken van een tabaksproduct of een aanverwant product.
#
#        'De verpakkingseenheid van elektronische dampwaar bevat een bijsluiter. Onze Minister stelt nadere regels over de inhoud van de bijsluiter.'
#       ]
#      ]
