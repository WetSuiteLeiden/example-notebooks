# %% [markdown]
# If you want to start playing with this without installation, try: &nbsp;
# <a href="https://colab.research.google.com/github/WetSuiteLeiden/data-collection/blob/main/split-experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (only) in colab, run this first to install wetsuite from (the most recent) source.   For your own setup, see wetsuite's install guidelines.
#!pip3 install -U --no-cache-dir --quiet https://github.com/knobs-dials/wetsuite-dev/archive/refs/heads/main.zip

# %% [markdown]
# # Purpose of this notebook
#
# Figure out how to open various formats of documents, and split them into smaller pieces of text.
#
# Probably at a paragraph-like level, and providing document-structural hints where we can --
# while explaining why we can _not_ go as far as guaranteeing anything like te natural structure of a document.
#
#
# Note: this notebook is more about the _development_ of this idea, discussion of the tradeoffs, and such.
# There will be a simpler notebook in wetsuite-notebooks later that gives some examples as to its _use_ on existing datasets
# (and the sources they come from).
#
# This entire notebook may disappear into a short summary later.

# %% [markdown]
# ## Extracting, but also splitting
#
# It is probably useful if this project tries to parse each kind of document that it itself provides,
# as well as other kinds you are likely to use.
#
# At least to flatten varied formats into plain text.

# %% [markdown]
# ...and there are also varied methods that would benefit from receiving such text into bite-sized chunks,
# and/or for those to be split in a way that is at least _somewhat_ useful.
#
# You might e.g.
# - try to ignore introductory things like "Wij Beatrix, bij de gratie Gods" thing in laws,
#   - because there's a bunch of named enitities there, and few to none of them are even relevant to the law.
#   - seeing that within the text, and knowing we have a chunk of text no larger than a paragraph, makes it easy to ignore.
#
# - up to trying to e.g. find similar court decisions based on some content analysis
#   e.g.
#    - focus on the introduction to extract topic, focus on decision to estimate what was done with that topic,
#    - possibly ignoring discussion/argumentation in the middle
#    - possibly ignoring the definitions (can be a good indicator, but only useful in comparisons if both documents have it)
#
# - split text whenever it seems to be switching to different topic
#
#   - e.g. by tring to figure out what section each paragraph belongs to
#     (whether hinted at by the document or even analysed)
#
# - try tricks like feeding smaller chunks at a time into a "nearby words" type method
#   to see which relations come out most _consistently_ throughout a document.
#   - (you may then care more about the amount of distance and less about the split being natural)
#
# ...meaning an automated way to suggests which parts to ignore and/or what parts are,
# even if crude, could be a start.
#
# If we can, we want to support such approaches, at least a little.

# %% [markdown]
# ### Why we can't go very far in this
#
# Varying goals, and varying input.
#
#
# On the varying input side, consider that you as use expect something sensible for _every_ document.
#
# Maybe
# you can give very well-labeled sections, citations, vocabulary references for one document type.
# Or it's more document-like but consistent enough that once you are used to it, you _can_ pick out a lot of structure.
# ...but if you mix it with PDFs you may not even be able to guaranee unbroken sentences.
#
#
# So we would want to provide something that works similarly well for all input,
# but the more varied the input is, the more that such a common denominator is... not a lot.
#
# Yes, we can try to invent some overlap, or intended structure, and wrangle each format into that,
# and there is probably some value,
# yet that kind of creativity, if present at all,
# should be tools in your hands as a researcher,
# should be verifiable and not just trusted,
# not transparently and quietly decided for you.
#
#
# The problen here is that depending on what you do, you may get a mix of great and terrible,
# a mix that you did not expect, and that is almost as hard to understand as doing it yourself.
#
#
#
# On the goals side, it depends a little on who our userbase is.
# * Legal researchers will often find one topic, one data source
#   - The abovementioned mix issue isn't necessarily a problem, in that documents should be fairly consistent within that
#
# * NLP researchers, on the other hand, will probably just take the "more text is better approach"
#   - The abovementioned may or may not be an issue, because they may care _only_ about having a lot of text,
#     and doing any labeling themselves
#
# You can often do somehwat better once you focus on a specific kind of document, source, reseach topic, and such.
#
#
#
# So this notebook is tools and examples for, also to help instill how well, or how poorly, it works on the documents you work on.
#
# Even _the way_ it currently works should be considered just one preliminary way of _maybe_ doing it -- you should treat it as provisionary,
# as a "I'll take out all the bits I need and do it myself (and in the cases it happens to already do what I want, great)":

# %% [markdown]
# ## On an implementation level
#
# How we envision this is:
#  * in part about getting text out of different formats - HTML, XML, PDF, possibly document formats
#  * in part about getting small fragments of text out of each, with some supporting information
#  * and let _you_ decide when to join or split those fragments, based on the added information.
#
# We would probably end up with a list of handlers like
#  - if you say you recognize this format
#  - read it yourself and hand out the parts
#  - suggest how to split it
#
#
# The "I recognize this" should probably have a specificity, e.g.
#  - I know this is a PDF, from Officiele Publicaties, and a specific waterschappen-specific template
#  - I know this is a PDF, from Officiele Publicaties
#  - I know this is a PDF, I'll give you ''something''
#
# One reason for this approach is that this can be extended and refined over time.

# %% [markdown]
# This still begs a number of questions
# - how to do that with different input formats?
#   - beyond the "detect type how?" and "open file how?" level, also...
#
# - how granular should the output be? Sections? Paragraphs? Sentences? Blocks that might actually be split at arbitrary points belong together?
#   - it's probably easier to join later than to split later, so smallish is good. Paragraphs?
#
# - can we provide intermediate data that leaves some decisions up to you? It would e.g. be nice if you could use the same  thing to
#   - get sections
#   - get paragraphs
#   - break up the thing to get e.g. ~200 words at a time, almost regardless of structure
#
#
# - how much are users expected to do, how much smartness could be merged in later?
#   - e.g. "hey this header says 1.  and the next one says 2." needs some refinement but can later be quite useful
#   - and does that imply that the meta could also use hints like "hint:[ ('feature', 'new-section'), (probability, 0.7)}"
#
# - can we have any document-type-specific handling? (e.g. remove headers and footers from PDF)
#
# - can we have any document-set-specific handling? (e.g. "kamervraag PDFs use a neat template, we can ease _just_ the text out of it fairly easily")
#   - and have that be extensible, so we can incrementally improve it?
#
# - how much of that is for future prohjects because it really is to omuch now?
#
# - how useful is it to point back to the original?
#   - in XML laws this might be useful. In most others not so much. This might be out of scope, really.
#
#
# Indeed, to provide a relatively universal intermediate document format is a nontrivial exercise even when you care only
# about the _aesthetics_ of the result, let alone when seeming to make any promises about the structure you hand over.

# %% [markdown]
# ## Some experiments
#
# TODO
# <!--
#
# is a scope of 'how good/bad is it to split here',
# which you can force into smaller and larger chunks via some parameters.
#
#
# What you can expect
# - a stream of (metadata, text)
#
# - a function that handles handles that at somewhat higher level, like
#   - get section-sized things
#   - get paragraph-sized fragments
#   - break up the thing to get e.g. ~200 words at a time, almost regardless of structure
#
# - ...which suggests that the intended length of those text fragments should be on the order of a paragraph (or similar, often-larger unbroken text chunk),
#  - because it's easier to join later than to split later.
#  - if you wantedsentence splitting, you might want to do that in your own post-processing; this seems out of scope for our cruder goals
#
# - metadata will probably
#   - not be things like header, section, paragraph, sentence
#   - be more like "document seems to indicate this is three-deep, and the last header was 'intro'; do with that information what you will"
#
# - for this to always be crude.
#   - Do not expect this to be very structured, unless you can restrict yourself to a document set that is uniform enough document format that the _output_ is  similarly uniform.
#   -->

# %%
import random, pprint, collections, warnings

import wetsuite.helpers.koop_parse
import wetsuite.helpers.localdata
import wetsuite.helpers.etree
import wetsuite.helpers.escape
import wetsuite.helpers.util
import wetsuite.helpers.split
import wetsuite.datasets
import wetsuite.extras.pdf
import wetsuite.helpers.notebook

# %% [markdown]
# # Collect some varied documents

# %%
# pick out varied documents, to see how many we process decently
example_docs = {} # some_indicative_id -> docbytes

if 1: # BWB XML
    bwb  = wetsuite.datasets.load('bwb-mostrecent-xml')
    for bwbid, docbytes in bwb.data.random_sample(100):
        example_docs['xml:'+bwbid] = docbytes

if 1: # CVDR XML
    cvdr = wetsuite.datasets.load('cvdr-mostrecent-xml')
    for cvdrid, docbytes in cvdr.data.random_sample(100):
        example_docs['xml:CVDR'+cvdrid] = docbytes

if 1: # CVDR HTML
    cvdr = wetsuite.datasets.load('cvdr-mostrecent-html')
    for cvdrid, docbytes in cvdr.data.random_sample(100):
        example_docs['html:CVDR'+cvdrid] = docbytes

if 1: # Rechtspraak XML
    rechtspraak_xml = wetsuite.helpers.localdata.LocalKV('rechtspraak_fetched.db', key_type=str, value_type=bytes, read_only=True)
    for rsurl, xmlbytes in rechtspraak_xml.random_sample(100):
        example_docs[rsurl] = xmlbytes
    # TODO:
    #rechtspraak  = wetsuite.datasets.load('rechtspraaknl-xml')
    ##for bwbid, docbytes in bwb.data.random_sample(100):
    ##    example_docs[bwbid] = docbytes
    #rechtspraak.data.random_choice()
    #or maybe cache-fetching the URLs mentioned in rechtspraaknl-struc ?

if 0: # Woo PDF ?
    pass

if 0:
    # these should soon be datasets, but for now are internal collection stores
    bus_data = wetsuite.helpers.localdata.LocalKV( 'bus_data.db', key_type=str, value_type=bytes )

    for path in bus_data.random_keys(250000):
        if 'metadata' in path or 'changelog' in path: # (should filter this out above, actually)
            continue
        if '.xml' in path and random.uniform(0,1) < 0.5: # much of this is xml (data or metadata), try to bring up the HTML and PDF
            continue
        if 'gmb' in path and random.uniform(0,1) < 0.9: # roughly three quarters of this store is gmb, try to balance that a little bit
            continue
        bytedoc = bus_data.get( path )
        example_docs[ path ] = bytedoc

if 1: # some cherry-picked PDFs
    example_docs[ 'simple2page' ] = wetsuite.helpers.net.download('https://zoek.officielebekendmakingen.nl/wsb-2022-9718.pdf')
    example_docs[ '2023D51633' ] = wetsuite.helpers.net.download('https://www.tweedekamer.nl/downloads/document?id=2023D51633')
    #example_docs[ 'stb-1952-10' ] = wetsuite.helpers.net.download('https://repository.overheid.nl/frbr/officielepublicaties/stb/1952/stb-1952-10/1/pdf/stb-1952-10.pdf')
    #example_docs[ 'stb-1975-102' ] = wetsuite.helpers.net.download('https://repository.overheid.nl/frbr/officielepublicaties/stb/1975/stb-1975-102/1/pdf/stb-1975-102.pdf')
    example_docs[ '3col' ] = wetsuite.helpers.net.download('https://zoek.officielebekendmakingen.nl/stcrt-1995-28-p9-SC1944.pdf')

# %% [markdown]
# ### See what kind of mix of documents we have

# %%
edpairs = list( example_docs.items() )
random.shuffle( edpairs )
for key, by in edpairs[:20]:
    print( '%-70s %s'%(key, by[:60]) )
# Out:
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBROT:2008:1751 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# xml:BWBR0038256                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# xml:CVDR353984                                                         b'<?xml version="1.0" encoding="UTF-8"?><cvdr xmlns="http://st'
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHLEE:2005:1741 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# xml:BWBR0013253                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBGEL:2020:3072 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# xml:BWBR0004386                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBLIM:2020:10530 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# html:CVDR660941                                                        b'\n<!DOCTYPE html\n  PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" '
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBARN:2009:BJ5387 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# xml:CVDR702298                                                         b'<?xml version="1.0" encoding="utf-8"?><cvdr xmlns="http://st'
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:CRVB:2024:103 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# html:CVDR705259                                                        b'\n<!DOCTYPE html\n  PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" '
# html:CVDR687497                                                        b'\n<!DOCTYPE html\n  PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" '
# xml:BWBR0029582                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# html:CVDR458123                                                        b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" "ht'
# html:CVDR373666                                                        b'<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" "ht'
# xml:BWBR0017112                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# xml:CVDR684905                                                         b'<?xml version="1.0" encoding="utf-8"?><cvdr xmlns="http://st'
# xml:BWBR0035866                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'

# %% [markdown]
# ### See what portion gets detected as something known
#
# No fragment output yet, just seeing how many of the documents we gave it
# seem to be covered by the parsers/splitters currently registered.

# %%
count = collections.defaultdict(int)

for someid,docbytes in wetsuite.helpers.notebook.ProgressBar( edpairs ):
    options = wetsuite.helpers.split.decide( docbytes )
    if len(options)==0:
        print( '\n------- %s -------'%someid )
        print( 'NOTHING' )        
        count['nothing'] += 1

    else:
        score, splitter = options[0]
        if score > 100:
            count['only-lowscore'] += 1
            continue

        with warnings.catch_warnings(): # temporarily disable warnings
            warnings.simplefilter("ignore")
            text = ' '.join( txt  for _,_,txt in splitter.fragments() )
        if len( text.strip() ) == 0:
            count['no-output'] += 1
            continue

        count['seems-okay'] += 1

dict( count )
# Out:
#   0%|          | 0/403 [00:00<?, ?it/s]
# {'no-output': 77, 'seems-okay': 326}

# %% [markdown]
# ### See what the splitter gives us
#
# ...a few at a time, because otherwise this would be a _lot_ of text

# %%
for key, docbytes in edpairs[:200]:
    if 'metadata' in key: # we care about documents; skip metadata-only, in case the above accidentally filtered them in
        continue

    thresh = 1500
    splitters = wetsuite.helpers.split.decide(docbytes, thresh=thresh)
    if len(splitters)==0:
        print( 'WARN for  %-30s - no splitter says it applies  (under threshold %s)'%(key, thresh) )
        # "stop on the first problem case and display it so we can add it" style logic:
        #if b'<html' in docbytes:
        #    display( wetsuite.helpers.etree.debug_color(docbytes) )
        #    break
        continue
    
    for score, fragproc in splitters: # use each processor that said they would be useful
        with warnings.catch_warnings(): # temporarily disable warnings
            warnings.simplefilter("ignore")
            frags = fragproc.fragments()
        if len(frags) == 0:
            print( 'WARN for  %-30s - no output from splitter %s'%(key, type(fragproc).__name__ ) )
            #if 'html.zip' in key:
            #    print(wetsuite.helpers.util.get_ziphtml(docbytes))
            #    print( fragproc.soup )
        else:
            textlen = sum(  list(len(fragtext)  for _,_,fragtext in frags))
            print( f'INFO for  {key:^30s} - {type(fragproc).__name__} gave {textlen} chars of text' )

            #for o1,o2,o3 in frags:
            #    print( type(o2) )

            if 0: # you may want to disable this print-everything when doing "are we missing anything" debug
                #display( wetsuite.helpers.etree.debug_color(docbytes) )
                display( wetsuite.helpers.split.SplitDebug( frags ) )
                break
    #else:
    #    break

    #break
# Out:
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBROT:2008:1751 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0038256         - Fragments_XML_BWB gave 4698 chars of text
# INFO for          xml:CVDR353984         - Fragments_XML_CVDR gave 14611 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHLEE:2005:1741 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0013253         - Fragments_XML_BWB gave 4015 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBGEL:2020:3072 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0004386         - Fragments_XML_BWB gave 1965 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBLIM:2020:10530 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         html:CVDR660941         - Fragments_HTML_CVDR gave 251000 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBARN:2009:BJ5387 - Fragments_XML_Rechtspraak gave 11000 chars of text
# INFO for          xml:CVDR702298         - Fragments_XML_CVDR gave 10538 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:CRVB:2024:103 - Fragments_XML_Rechtspraak gave 9052 chars of text
# INFO for         html:CVDR705259         - Fragments_HTML_CVDR gave 124890 chars of text
# INFO for         html:CVDR687497         - Fragments_HTML_CVDR gave 19934 chars of text
# INFO for         xml:BWBR0029582         - Fragments_XML_BWB gave 1103 chars of text
# INFO for         html:CVDR458123         - Fragments_HTML_CVDR gave 96321 chars of text
# INFO for         html:CVDR373666         - Fragments_HTML_CVDR gave 6669 chars of text
# INFO for         xml:BWBR0017112         - Fragments_XML_BWB gave 18394 chars of text
# INFO for          xml:CVDR684905         - Fragments_XML_CVDR gave 26104 chars of text
# INFO for         xml:BWBR0035866         - Fragments_XML_BWB gave 9788 chars of text
# INFO for          xml:CVDR624809         - Fragments_XML_CVDR gave 3584 chars of text
# INFO for          xml:CVDR687242         - Fragments_XML_CVDR gave 49276 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBUTR:2011:2413 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0002144         - Fragments_XML_BWB gave 7760 chars of text
# INFO for         html:CVDR649049         - Fragments_HTML_CVDR gave 220917 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBROE:2009:8129 - no output from splitter Fragments_XML_Rechtspraak
# INFO for          xml:CVDR673290         - Fragments_XML_CVDR gave 59567 chars of text
# INFO for         xml:BWBR0046938         - Fragments_XML_BWB gave 4264 chars of text
# INFO for         xml:BWBR0040129         - Fragments_XML_BWB gave 1089 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBROT:2022:7692 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0045516         - Fragments_XML_BWB gave 26824 chars of text
# INFO for          html:CVDR75851         - Fragments_HTML_CVDR gave 93583 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBSGR:2008:14824 - no output from splitter Fragments_XML_Rechtspraak
# INFO for          xml:CVDR39387          - Fragments_XML_CVDR gave 21315 chars of text
# INFO for         xml:BWBR0030312         - Fragments_XML_BWB gave 3860 chars of text
# INFO for         html:CVDR339329         - Fragments_HTML_CVDR gave 226348 chars of text
# INFO for          xml:CVDR232995         - Fragments_XML_CVDR gave 5838 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHAMS:2006:AZ3682 - Fragments_XML_Rechtspraak gave 24360 chars of text
# INFO for         xml:BWBR0008538         - Fragments_XML_BWB gave 2546 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:PHR:2003:AF0627 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         html:CVDR399716         - Fragments_HTML_CVDR gave 4257 chars of text
# INFO for          xml:CVDR379074         - Fragments_XML_CVDR gave 7805 chars of text
# INFO for         html:CVDR624198         - Fragments_HTML_CVDR gave 30916 chars of text
# INFO for         html:CVDR681325         - Fragments_HTML_CVDR gave 46227 chars of text
# INFO for          xml:CVDR103291         - Fragments_XML_CVDR gave 44330 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RVS:2014:4280 - Fragments_XML_Rechtspraak gave 9317 chars of text
# INFO for          xml:CVDR226663         - Fragments_XML_CVDR gave 9101 chars of text
# INFO for          html:CVDR7288          - Fragments_HTML_CVDR gave 119150 chars of text
# INFO for         html:CVDR696704         - Fragments_HTML_CVDR gave 79979 chars of text
# INFO for          xml:CVDR616892         - Fragments_XML_CVDR gave 6509 chars of text
# INFO for         html:CVDR491870         - Fragments_HTML_CVDR gave 56372 chars of text
# INFO for         xml:BWBR0013626         - Fragments_XML_BWB gave 2526 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBSHE:2009:1799 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0048950         - Fragments_XML_BWB gave 2189 chars of text
# INFO for         xml:BWBR0009551         - Fragments_XML_BWB gave 1490 chars of text
# INFO for         xml:BWBR0014594         - Fragments_XML_BWB gave 9600 chars of text
# INFO for         xml:BWBR0022741         - Fragments_XML_BWB gave 629 chars of text
# INFO for          xml:CVDR50457          - Fragments_XML_CVDR gave 5917 chars of text
# INFO for         html:CVDR623870         - Fragments_HTML_CVDR gave 62201 chars of text
# INFO for         html:CVDR681365         - Fragments_HTML_CVDR gave 62458 chars of text
# INFO for         html:CVDR610907         - Fragments_HTML_CVDR gave 255136 chars of text
# INFO for         html:CVDR348442         - Fragments_HTML_CVDR gave 1037028 chars of text
# INFO for          xml:CVDR338265         - Fragments_XML_CVDR gave 28265 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBDHA:2021:5992 - no output from splitter Fragments_XML_Rechtspraak
# INFO for          xml:CVDR643234         - Fragments_XML_CVDR gave 20171 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBDOR:2012:937 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0048313         - Fragments_XML_BWB gave 1504 chars of text
# INFO for         html:CVDR671622         - Fragments_HTML_CVDR gave 86337 chars of text
# INFO for          html:CVDR14044         - Fragments_HTML_CVDR gave 1009 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBGEL:2021:436 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         html:CVDR676905         - Fragments_HTML_CVDR gave 40390 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBLIM:2018:9745 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0015753         - Fragments_XML_BWB gave 625 chars of text
# INFO for          xml:CVDR677971         - Fragments_XML_CVDR gave 17081 chars of text
# INFO for         html:CVDR666939         - Fragments_HTML_CVDR gave 67747 chars of text
# INFO for         html:CVDR672006         - Fragments_HTML_CVDR gave 161502 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:PHR:2011:BR2051 - Fragments_XML_Rechtspraak gave 27773 chars of text
# INFO for         html:CVDR441678         - Fragments_HTML_CVDR gave 18299 chars of text
# INFO for          xml:CVDR431022         - Fragments_XML_CVDR gave 6171 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBOBR:2022:1763 - Fragments_XML_Rechtspraak gave 9180 chars of text
# INFO for         xml:BWBR0029446         - Fragments_XML_BWB gave 1391 chars of text
# INFO for         html:CVDR608715         - Fragments_HTML_CVDR gave 103595 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBUTR:2011:2516 - no output from splitter Fragments_XML_Rechtspraak
# INFO for          xml:CVDR642498         - Fragments_XML_CVDR gave 479 chars of text
# INFO for          xml:CVDR652545         - Fragments_XML_CVDR gave 6070 chars of text
# INFO for          xml:CVDR263497         - Fragments_XML_CVDR gave 11583 chars of text
# INFO for         xml:BWBR0048207         - Fragments_XML_BWB gave 12332 chars of text
# INFO for          xml:CVDR652635         - Fragments_XML_CVDR gave 9134 chars of text
# INFO for          xml:CVDR342393         - Fragments_XML_CVDR gave 2909 chars of text
# INFO for         html:CVDR713749         - Fragments_HTML_CVDR gave 133748 chars of text
# INFO for         html:CVDR631920         - Fragments_HTML_CVDR gave 113598 chars of text
# INFO for         xml:BWBR0013564         - Fragments_XML_BWB gave 2316 chars of text
# INFO for         xml:BWBR0023257         - Fragments_XML_BWB gave 654 chars of text
# INFO for         html:CVDR648779         - Fragments_HTML_CVDR gave 42948 chars of text
# INFO for         html:CVDR626713         - Fragments_HTML_CVDR gave 16960 chars of text
# INFO for         html:CVDR632521         - Fragments_HTML_CVDR gave 546587 chars of text
# INFO for          html:CVDR1489          - Fragments_HTML_CVDR gave 2580 chars of text
# INFO for          xml:CVDR669988         - Fragments_XML_CVDR gave 5949 chars of text
# INFO for          xml:CVDR699054         - Fragments_XML_CVDR gave 61804 chars of text
# INFO for            2023D51633           - Fragments_PDF_Fallback gave 96337 chars of text
# INFO for           xml:CVDR9100          - Fragments_XML_CVDR gave 8536 chars of text
# INFO for          xml:CVDR56903          - Fragments_XML_CVDR gave 1237 chars of text
# INFO for         xml:BWBR0039453         - Fragments_XML_BWB gave 3219 chars of text
# INFO for         html:CVDR695234         - Fragments_HTML_CVDR gave 24782 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBAMS:2020:2847 - Fragments_XML_Rechtspraak gave 8264 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:CRVB:2015:2454 - Fragments_XML_Rechtspraak gave 5416 chars of text
# INFO for         xml:BWBR0048829         - Fragments_XML_BWB gave 10529 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBROT:2009:772 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0006515         - Fragments_XML_BWB gave 19430 chars of text
# INFO for         html:CVDR256281         - Fragments_HTML_CVDR gave 47182 chars of text
# INFO for          xml:CVDR661465         - Fragments_XML_CVDR gave 1197 chars of text
# INFO for         html:CVDR648415         - Fragments_HTML_CVDR gave 197484 chars of text
# INFO for          xml:CVDR104562         - Fragments_XML_CVDR gave 84857 chars of text
# INFO for          xml:CVDR413248         - Fragments_XML_CVDR gave 45833 chars of text
# INFO for          xml:CVDR134253         - Fragments_XML_CVDR gave 42809 chars of text
# INFO for           simple2page           - Fragments_PDF_Fallback gave 4339 chars of text
# INFO for          xml:CVDR664039         - Fragments_XML_CVDR gave 908 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:XX:1956:BE0137 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0010452         - Fragments_XML_BWB gave 1382 chars of text
# INFO for          xml:CVDR18996          - Fragments_XML_CVDR gave 3228 chars of text
# INFO for           xml:CVDR8092          - Fragments_XML_CVDR gave 49224 chars of text
# INFO for         html:CVDR601029         - Fragments_HTML_CVDR gave 315643 chars of text
# INFO for          html:CVDR6308          - Fragments_HTML_CVDR gave 49 chars of text
# INFO for          xml:CVDR92856          - Fragments_XML_CVDR gave 59624 chars of text
# INFO for         xml:BWBR0014674         - Fragments_XML_BWB gave 1424 chars of text
# INFO for         html:CVDR644709         - Fragments_HTML_CVDR gave 1500040 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:CRVB:2024:112 - Fragments_XML_Rechtspraak gave 14708 chars of text
# INFO for         xml:BWBR0047673         - Fragments_XML_BWB gave 33820 chars of text
# INFO for          xml:CVDR330657         - Fragments_XML_CVDR gave 11344 chars of text
# INFO for         html:CVDR417890         - Fragments_HTML_CVDR gave 292088 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBAMS:2012:7445 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHAMS:1958:AY0722 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         html:CVDR663417         - Fragments_HTML_CVDR gave 79312 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBDOR:2009:66 - no output from splitter Fragments_XML_Rechtspraak
# INFO for          xml:CVDR290500         - Fragments_XML_CVDR gave 8974 chars of text
# INFO for         html:CVDR670021         - Fragments_HTML_CVDR gave 24110 chars of text
# INFO for         xml:BWBR0042445         - Fragments_XML_BWB gave 6427 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBMNE:2023:4836 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0033498         - Fragments_XML_BWB gave 36534 chars of text
# INFO for         xml:BWBR0043096         - Fragments_XML_BWB gave 1180 chars of text
# INFO for         xml:BWBR0030321         - Fragments_XML_BWB gave 6489 chars of text
# INFO for          xml:CVDR628783         - Fragments_XML_CVDR gave 18820 chars of text
# INFO for         xml:BWBR0003574         - Fragments_XML_BWB gave 8342 chars of text
# INFO for         xml:BWBR0024888         - Fragments_XML_BWB gave 2252 chars of text
# INFO for         xml:BWBR0004529         - Fragments_XML_BWB gave 10575 chars of text
# INFO for         html:CVDR601232         - Fragments_HTML_CVDR gave 77227 chars of text
# INFO for         xml:BWBR0020731         - Fragments_XML_BWB gave 54622 chars of text
# INFO for         xml:BWBR0027217         - Fragments_XML_BWB gave 6731 chars of text
# INFO for         xml:BWBR0038159         - Fragments_XML_BWB gave 4797 chars of text
# INFO for         html:CVDR332815         - Fragments_HTML_CVDR gave 2984034 chars of text
# INFO for         html:CVDR486634         - Fragments_HTML_CVDR gave 71294 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:CRVB:2020:3471 - Fragments_XML_Rechtspraak gave 5816 chars of text
# INFO for          xml:CVDR709235         - Fragments_XML_CVDR gave 9295 chars of text
# INFO for          html:CVDR70978         - Fragments_HTML_CVDR gave 98449 chars of text
# INFO for         html:CVDR695935         - Fragments_HTML_CVDR gave 157454 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBGEL:2020:5709 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:HR:1924:267 - no output from splitter Fragments_XML_Rechtspraak
# INFO for          xml:CVDR399536         - Fragments_XML_CVDR gave 11008 chars of text
# INFO for         xml:BWBR0020083         - Fragments_XML_BWB gave 9936 chars of text
# INFO for         xml:BWBR0023098         - Fragments_XML_BWB gave 67889 chars of text
# INFO for          xml:CVDR70361          - Fragments_XML_CVDR gave 11987 chars of text
# INFO for         html:CVDR713507         - Fragments_HTML_CVDR gave 317347 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBSGR:2009:7267 - no output from splitter Fragments_XML_Rechtspraak
# INFO for          xml:CVDR142809         - Fragments_XML_CVDR gave 811 chars of text
# INFO for         xml:BWBR0048973         - Fragments_XML_BWB gave 6470 chars of text
# INFO for          xml:CVDR42081          - Fragments_XML_CVDR gave 31474 chars of text
# INFO for         xml:BWBR0014011         - Fragments_XML_BWB gave 1224 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHDHA:2015:1871 - Fragments_XML_Rechtspraak gave 23052 chars of text
# INFO for         html:CVDR175158         - Fragments_HTML_CVDR gave 191097 chars of text
# INFO for         xml:BWBR0017644         - Fragments_XML_BWB gave 11931 chars of text
# INFO for         xml:BWBR0014277         - Fragments_XML_BWB gave 5847 chars of text
# INFO for          xml:CVDR630640         - Fragments_XML_CVDR gave 8305 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBDHA:2020:5909 - no output from splitter Fragments_XML_Rechtspraak
# INFO for          xml:CVDR674025         - Fragments_XML_CVDR gave 2543 chars of text
# INFO for          xml:CVDR418189         - Fragments_XML_CVDR gave 302426 chars of text
# INFO for          html:CVDR21877         - Fragments_HTML_CVDR gave 12879 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:HR:2006:AZ0981 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBALK:2009:5459 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0013857         - Fragments_XML_BWB gave 2415 chars of text
# INFO for         xml:BWBR0039785         - Fragments_XML_BWB gave 939 chars of text
# INFO for          html:CVDR59235         - Fragments_HTML_CVDR gave 592032 chars of text
# INFO for          xml:CVDR395099         - Fragments_XML_CVDR gave 3206 chars of text
# INFO for          xml:CVDR43401          - Fragments_XML_CVDR gave 9213 chars of text
# INFO for         html:CVDR390349         - Fragments_HTML_CVDR gave 103429 chars of text
# INFO for         xml:BWBR0007771         - Fragments_XML_BWB gave 1131 chars of text
# INFO for         html:CVDR626613         - Fragments_HTML_CVDR gave 98826 chars of text
# INFO for         xml:BWBR0017607         - Fragments_XML_BWB gave 3742 chars of text
# INFO for         html:CVDR625486         - Fragments_HTML_CVDR gave 84263 chars of text
# INFO for          xml:CVDR47206          - Fragments_XML_CVDR gave 28849 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBZWB:2021:849 - no output from splitter Fragments_XML_Rechtspraak
# INFO for          xml:CVDR600386         - Fragments_XML_CVDR gave 2677 chars of text
# INFO for         xml:BWBR0041161         - Fragments_XML_BWB gave 1750 chars of text
# INFO for         xml:BWBR0031923         - Fragments_XML_BWB gave 466 chars of text
# INFO for         xml:BWBR0008710         - Fragments_XML_BWB gave 1009 chars of text
# INFO for         xml:BWBR0015031         - Fragments_XML_BWB gave 2563 chars of text
# INFO for         html:CVDR681172         - Fragments_HTML_CVDR gave 7429 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBNNE:2020:2648 - no output from splitter Fragments_XML_Rechtspraak
# INFO for         xml:BWBR0047942         - Fragments_XML_BWB gave 17108 chars of text
# INFO for         html:CVDR383011         - Fragments_HTML_CVDR gave 75057 chars of text
# INFO for         html:CVDR691999         - Fragments_HTML_CVDR gave 682040 chars of text

# %%
sum(  list(len(fragtext)  for _,_,fragtext in frags)  )
# Out:
# 20247
