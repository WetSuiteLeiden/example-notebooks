# %% [markdown]
# If you want to start playing with this without installation, try: &nbsp;
# <a href="https://colab.research.google.com/github/WetSuiteLeiden/data-collection/blob/main/split-experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# (only) in colab, run this first to install wetsuite from (the most recent) source.   For your own setup, see wetsuite's install guidelines.
#!pip3 install -U --no-cache-dir --quiet https://github.com/knobs-dials/wetsuite-dev/archive/refs/heads/main.zip

# %% [markdown]
# # Purpose of this notebook
#
# Figure out how to open various formats of documents, and split them into smaller pieces of text.
#
# Probably at a paragraph-like level, and providing document-structural hints where we can --
# while explaining why we can _not_ go as far as guaranteeing anything like te natural structure of a document.
#
#
# Note: this notebook is more about the _development_ of this idea, discussion of the tradeoffs, and such.
# There will be a simpler notebook in wetsuite-notebooks later that gives some examples as to its _use_ on existing datasets
# (and the sources they come from).
#
# This entire notebook may disappear into a short summary later.

# %% [markdown]
# ## Extracting, but also splitting
#
# It is probably useful if this project tries to take each kind of raw document that it
# points to as usable (and/or provides in datasets),
# as well as other kinds you are likely to use.
#
# The combination of opening varied data formats, and splitting them as well,
# seems counter to the 'each piece of code does one thing well' philosophy,
# and in part it is, but other notebooks already address how to dig into specific structures of XML, PDF, and others.

# %% [markdown]
# Here, we address a certain ease.
# There are also varied methods that would benefit from receiving such text into bite-sized chunks,
# and/or for those to be split in a way that is at least _somewhat_ useful.
#
# You might e.g.
# - try to ignore introductory things like "Wij Beatrix, bij de gratie Gods" thing in laws,
#   - because there's a bunch of named enitities there, and few to none of them are even relevant to the law.
#   - seeing that within the text, and knowing we have a chunk of text no larger than a paragraph, makes it easy to ignore.
#
# - up to trying to e.g. find similar court decisions based on some content analysis
#   e.g.
#    - focus on the introduction to extract topic, focus on decision to estimate what was done with that topic,
#    - possibly ignoring discussion/argumentation in the middle
#    - possibly ignoring the definitions (can be a good indicator, but only useful in comparisons if both documents have it)
#
# - split text whenever it seems to be switching to different topic
#
#   - e.g. by tring to figure out what section each paragraph belongs to
#     (whether hinted at by the document or even analysed)
#
# - try tricks like feeding smaller chunks at a time into a "nearby words" type method
#   to see which relations come out most _consistently_ throughout a document.
#   - (you may then care more about the amount of distance and less about the split being natural)
#
# ...meaning an automated way to suggests which parts to ignore and/or what parts are,
# even if crude, could be a start.
#
# If we can, we want to support such approaches, at least a little.

# %% [markdown]
# ### Why we can't go very far in this
#
# For one, goals vary.
#
#  It depends a little on who our userbase is.
# * Legal researchers will often find one topic, one data source
#   - The abovementioned mix issue isn't necessarily a problem, in that documents should be fairly consistent within that
#
# * NLP researchers, on the other hand, will probably just take the "more text is better approach"
#   - The abovementioned may or may not be an issue, because they may care _only_ about having a lot of text,
#     and doing any labeling themselves
#   - but e.g. mixing output from different sources will mean a mix of quality
#
# You can often do somehwat better once you focus on a specific kind of document, source, reseach topic, and such.
#
# <!-- -->
#
# Also, input varies.
#
# Consider that you will expect something sensible for _every_ document.
# Maybe one document (e.g. XML) input you can give very well-labeled sections, citations, vocabulary references for one document type.
# Maybe another (e.g. PDF) gives nothing more than typeset text, and it takes work to guarantee as little as unbroken sentences.
# The common denominator between the two isn't a lot.
#
# Inventing a middle way and wrangling each format into that probably has value,
# yet that kind of creativity, if present at all, should probably be tools in your hands as a researcher,
# should be verifiable and not just trusted, not transparently and quietly decided for you.
#
# <!-- -->
#
# So this notebook is tools and examples for, also to help instill how well, or how poorly, it works on the documents you work on.
#
# Even _the way_ it currently works should be considered just one preliminary way of _maybe_ doing it -- you should treat it as provisionary,
# as a "I'll take out all the bits I need and do it myself (and in the cases it happens to already do what I want, great)":

# %% [markdown]
# <!--
# ## On an implementation level
#
# How we envision this is:
#  * in part about getting text out of different formats - HTML, XML, PDF, possibly document formats
#  * in part about getting small fragments of text out of each, with some supporting information
#  * and let _you_ decide when to join or split those fragments, based on the added information.
#
# We would probably end up with a list of handlers like
#  - if you say you recognize this format
#  - read it yourself and hand out the parts
#  - suggest how to split it
#
#
# The "I recognize this" should probably have a specificity, e.g.
#  - I know this is a PDF, from Officiele Publicaties, and a specific waterschappen-specific template
#  - I know this is a PDF, from Officiele Publicaties
#  - I know this is a PDF, I'll give you ''something''
#
# One reason for this approach is that this can be extended and refined over time.
# -->

# %% [markdown]
# <!--
# This still begs a number of questions
# - how to do that with different input formats?
#   - beyond the "detect type how?" and "open file how?" level, also...
#
# - how granular should the output be? Sections? Paragraphs? Sentences? Blocks that might actually be split at arbitrary points belong together?
#   - it's probably easier to join later than to split later, so smallish is good. Paragraphs?
#
# - can we provide intermediate data that leaves some decisions up to you? It would e.g. be nice if you could use the same  thing to
#   - get sections
#   - get paragraphs
#   - break up the thing to get e.g. ~200 words at a time, almost regardless of structure
#
#
# - how much are users expected to do, how much smartness could be merged in later?
#   - e.g. "hey this header says 1.  and the next one says 2." needs some refinement but can later be quite useful
#   - and does that imply that the meta could also use hints like "hint:[ ('feature', 'new-section'), (probability, 0.7)}"
#
# - can we have any document-type-specific handling? (e.g. remove headers and footers from PDF)
#
# - can we have any document-set-specific handling? (e.g. "kamervraag PDFs use a neat template, we can ease _just_ the text out of it fairly easily")
#   - and have that be extensible, so we can incrementally improve it?
#
# - how much of that is for future prohjects because it really is to omuch now?
#
# - how useful is it to point back to the original?
#   - in XML laws this might be useful. In most others not so much. This might be out of scope, really.
#
#
# Indeed, to provide a relatively universal intermediate document format is a nontrivial exercise even when you care only
# about the _aesthetics_ of the result, let alone when seeming to make any promises about the structure you hand over.
# -->

# %% [markdown]
# ## Some experiments
#
# TODO
# <!--
#
# is a scope of 'how good/bad is it to split here',
# which you can force into smaller and larger chunks via some parameters.
#
#
# What you can expect
# - a stream of (metadata, text)
#
# - a function that handles handles that at somewhat higher level, like
#   - get section-sized things
#   - get paragraph-sized fragments
#   - break up the thing to get e.g. ~200 words at a time, almost regardless of structure
#
# - ...which suggests that the intended length of those text fragments should be on the order of a paragraph (or similar, often-larger unbroken text chunk),
#  - because it's easier to join later than to split later.
#  - if you wantedsentence splitting, you might want to do that in your own post-processing; this seems out of scope for our cruder goals
#
# - metadata will probably
#   - not be things like header, section, paragraph, sentence
#   - be more like "document seems to indicate this is three-deep, and the last header was 'intro'; do with that information what you will"
#
# - for this to always be crude.
#   - Do not expect this to be very structured, unless you can restrict yourself to a document set that is uniform enough document format that the _output_ is  similarly uniform.
#   -->

# %%
import random, pprint, collections, warnings

import wetsuite.helpers.koop_parse
import wetsuite.helpers.localdata
import wetsuite.helpers.etree
import wetsuite.helpers.escape
import wetsuite.helpers.util
import wetsuite.helpers.split
import wetsuite.datasets
import wetsuite.extras.pdf
import wetsuite.helpers.notebook

# %% [markdown]
# # Collect some varied documents
#
# ...primarily to see how many get handled decently

# %%
example_docs = {} # some_indicative_id -> docbytes

if 1: # BWB XML
    bwb  = wetsuite.datasets.load('bwb-mostrecent-xml')
    for bwbid, docbytes in bwb.data.random_sample(100):
        example_docs['xml:'+bwbid] = docbytes

if 1: # CVDR XML
    cvdr = wetsuite.datasets.load('cvdr-mostrecent-xml')
    for cvdrid, docbytes in cvdr.data.random_sample(100):
        example_docs['xml:CVDR'+cvdrid] = docbytes

if 1: # CVDR HTML
    cvdr = wetsuite.datasets.load('cvdr-mostrecent-html')
    for cvdrid, docbytes in cvdr.data.random_sample(100):
        example_docs['html:CVDR'+cvdrid] = docbytes

if 1: # Rechtspraak XML
    rechtspraak_xml = wetsuite.helpers.localdata.LocalKV('rechtspraak_fetched.db', key_type=str, value_type=bytes, read_only=True)
    for rsurl, xmlbytes in rechtspraak_xml.random_sample(100):
        example_docs[rsurl] = xmlbytes
    # TODO:
    #rechtspraak  = wetsuite.datasets.load('rechtspraaknl-xml')
    ##for bwbid, docbytes in bwb.data.random_sample(100):
    ##    example_docs[bwbid] = docbytes
    #rechtspraak.data.random_choice()
    #or maybe cache-fetching the URLs mentioned in rechtspraaknl-struc ?

if 1:
    # these should soon be datasets, but for now are internal collection stores
    bus_data = wetsuite.helpers.localdata.LocalKV( 'bus_data.db', key_type=str, value_type=bytes )

    for path in bus_data.random_keys(2000):
        if 'metadata' in path or 'changelog' in path: # (should filter this out above, actually)
            continue
        if '.xml' in path and random.uniform(0,1) < 0.5: # much of this is xml (data or metadata), try to bring up the HTML and PDF
            continue
        if 'gmb' in path and random.uniform(0,1) < 0.9: # roughly three quarters of this store is gmb, try to balance that a little bit
            continue
        bytedoc = bus_data.get( path )
        example_docs[ 'bus:'+path ] = bytedoc

if 0: # CONSIDER: Woo PDF ?
    pass

if 1: # some cherry-picked PDFs
    example_docs[ 'simple2page' ] = wetsuite.helpers.net.download('https://zoek.officielebekendmakingen.nl/wsb-2022-9718.pdf')
    example_docs[ '2023D51633' ] = wetsuite.helpers.net.download('https://www.tweedekamer.nl/downloads/document?id=2023D51633')
    #example_docs[ 'stb-1952-10' ] = wetsuite.helpers.net.download('https://repository.overheid.nl/frbr/officielepublicaties/stb/1952/stb-1952-10/1/pdf/stb-1952-10.pdf')
    #example_docs[ 'stb-1975-102' ] = wetsuite.helpers.net.download('https://repository.overheid.nl/frbr/officielepublicaties/stb/1975/stb-1975-102/1/pdf/stb-1975-102.pdf')
    example_docs[ '3col' ] = wetsuite.helpers.net.download('https://zoek.officielebekendmakingen.nl/stcrt-1995-28-p9-SC1944.pdf')

# %% [markdown]
# ### See what kind of mix of documents we have

# %%
doc_pairs = list( example_docs.items() )
random.shuffle( doc_pairs )
for key, by in doc_pairs[:20]:
    print( '%-70s %s'%(key, by[:60]) )
# Out:
# bus:/2020/02/14/stb/stb-2020-54/stb-2020-54.xml                        b'\xef\xbb\xbf<?xml version="1.0" encoding="utf-8"?>\r\n<officiele-public'
# bus:/2022/06/02/ah/ah-tk-20212022-2945/ah-tk-20212022-2945.xml         b'\xef\xbb\xbf<?xml version="1.0" encoding="utf-8"?>\r\n<officiele-public'
# xml:CVDR686207                                                         b'<?xml version="1.0" encoding="utf-8"?><cvdr xmlns="http://st'
# xml:BWBR0043402                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHSHE:2011:557 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# xml:CVDR713038                                                         b'<?xml version="1.0" encoding="utf-8"?><cvdr xmlns="http://st'
# bus:/1998/03/03/ah/ah-tk-19971998-770/ah-tk-19971998-770.xml           b'<?xml version="1.0" encoding="UTF-8"?><!DOCTYPE vraagdoc PUB'
# xml:CVDR662450                                                         b'<?xml version="1.0" encoding="utf-8"?><cvdr xmlns="http://st'
# xml:BWBR0039397                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# xml:BWBR0044791                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# xml:CVDR646757                                                         b'<?xml version="1.0" encoding="utf-8"?><cvdr xmlns="http://st'
# xml:CVDR42659                                                          b'<?xml version="1.0" encoding="UTF-8"?><cvdr xmlns="http://st'
# xml:BWBR0048053                                                        b'<?xml version="1.0" encoding="UTF-8"?><toestand xmlns:xsi="h'
# bus:/2018/05/11/prb/prb-2018-3508/prb-2018-3508.xml                    b'<officiele-publicatie xmlns:xsi="http://www.w3.org/2001/XMLS'
# bus:/2017/12/04/wsb/wsb-2017-11161/wsb-2017-11161.xml                  b'<officiele-publicatie xmlns:xsi="http://www.w3.org/2001/XMLS'
# https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBMNE:2017:1948 b'<?xml version="1.0" encoding="utf-8"?>\r\n<open-rechtspraak>\r\n'
# bus:/2016/10/24/gmb/gmb-2016-146755/gmb-2016-146755.html.zip           b'PK\x03\x04\x14\x00\x00\x00\x08\x00=HXI\x80\x0f+K\x87\x13\x00\x003<\x00\x00\x14\x00\x00\x00gmb-2016-146755.html\xc5[\xe9r\xdbH\x92\xfe\xdd\x13'
# xml:CVDR75914                                                          b'<?xml version="1.0" encoding="utf-8"?><cvdr xml:lang="nl-NL"'
# bus:/2023/11/02/kst/kst-22112-JF/kst-22112-JF.html.zip                 b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xdc|qW"9\x16\x8a\xb4\x16\x00\x003R\x00\x00\x11\x00\x00\x00kst-22112-JF.html\xed\\\xc9r\x1bI\x92\xbd\xf7WDa.'
# bus:/2016/12/06/prb/prb-2016-6489/prb-2016-6489.xml                    b'<officiele-publicatie xmlns:xsi="http://www.w3.org/2001/XMLS'

# %% [markdown]
# ### See what portion gets detected as something known
#
# No fragment output shown yet,
# just seeing how many of the documents we gave it seem to be covered by the parsers/splitters currently registered.

# %%
count = collections.defaultdict(int)

for someid,docbytes in wetsuite.helpers.notebook.ProgressBar( doc_pairs ):
    options = wetsuite.helpers.split.decide( docbytes )
    if len(options)==0:
        #print( '\n------- %s -------'%someid )
        #print( 'NO PARSER' )        
        count['no-parser-applied'] += 1

    else:
        score, splitter = options[0]
        if score > 100:
            count['only-lowscore'] += 1
            continue

        with warnings.catch_warnings(): # temporarily disable warnings
            warnings.simplefilter("ignore")
            text = ' '.join( txt  for _,_,txt in splitter.fragments() )
        if len( text.strip() ) == 0:
            count['no-output'] += 1
            continue

        count['seems-okay'] += 1

dict( count )
# Out:
#   0%|          | 0/646 [00:00<?, ?it/s]
# {'seems-okay': 532, 'no-output': 102, 'no-parser-applied': 12}

# %% [markdown]
# ### See what the splitter gives us
#
# Start with just one random one, already split

# %%
# re-run until it gives output -- the no-output ones are likely metadata-only rechtspraak doc (but there are also things we have yet to implement )
key, docbytes = random.choice( doc_pairs )
score, splitter = wetsuite.helpers.split.decide( docbytes )[0] # assumes we'll find one

display( wetsuite.helpers.split.SplitDebug( splitter.fragments() ) )
# Out:
# <table border="1"><tr><th>meta</th><th>intermediate</th><th>len</th><th>text</th></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/bridgehead'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;bridgehead role="bold"&gt;RECHTBANK ZE'
#         b'ELAND-WEST-BRABANT&lt;/bridgehead&gt;\n    ',
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">30</td><td style="text-align:left">'RECHTBANK ZEELAND-WEST-BRABANT'</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/para[1]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;para/&gt;\n    ', 'rawtype': 'xml'}</pre></td><td style="text-align:left">0</td><td style="text-align:left">''</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/parablock[1]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;parablock&gt;\n      &lt;para&gt;Cluster II H'
#         b'andelszaken&lt;/para&gt;\n    &lt;/parablock&gt;\n'
#         b'    ',
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">23</td><td style="text-align:left">'Cluster II Handelszaken'</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/para[2]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;para/&gt;\n    ', 'rawtype': 'xml'}</pre></td><td style="text-align:left">0</td><td style="text-align:left">''</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/parablock[2]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;parablock&gt;\n      &lt;para&gt;Breda&lt;/para&gt;'
#         b'\n    &lt;/parablock&gt;\n    ',
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">5</td><td style="text-align:left">'Breda'</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/para[3]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;para/&gt;\n    ', 'rawtype': 'xml'}</pre></td><td style="text-align:left">0</td><td style="text-align:left">''</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/para[4]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;para/&gt;\n    ', 'rawtype': 'xml'}</pre></td><td style="text-align:left">0</td><td style="text-align:left">''</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/parablock[3]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;parablock&gt;\n      &lt;para&gt;zaaknummer /'
#         b' rekestnummer: C/02/402562 / HA RK 2'
#         b'2-205&lt;/para&gt;\n    &lt;/parablock&gt;\n    ',
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">53</td><td style="text-align:left">'zaaknummer / rekestnummer: C/02/402562 / HA RK 22-205'</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/para[5]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;para/&gt;\n    ', 'rawtype': 'xml'}</pre></td><td style="text-align:left">0</td><td style="text-align:left">''</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/parablock[4]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;parablock&gt;\n      &lt;para&gt;\n        &lt;em'
#         b'phasis role="bold"&gt;Beschikking van 1'
#         b'5 februari 2023&lt;/emphasis&gt;\n      &lt;/p'
#         b'ara&gt;\n    &lt;/parablock&gt;\n    ',
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">32</td><td style="text-align:left">'Beschikking van 15 februari 2023'</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/para[6]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;para/&gt;\n    ', 'rawtype': 'xml'}</pre></td><td style="text-align:left">0</td><td style="text-align:left">''</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/parablock[5]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;parablock&gt;\n      &lt;para&gt;in de zaak v'
#         b'an&lt;/para&gt;\n    &lt;/parablock&gt;\n    ',
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">14</td><td style="text-align:left">'in de zaak van'</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/para[7]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;para/&gt;\n    ', 'rawtype': 'xml'}</pre></td><td style="text-align:left">0</td><td style="text-align:left">''</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/parablock[6]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;parablock&gt;\n      &lt;para&gt;\n        &lt;em'
#         b'phasis role="bold"&gt;\n          [verzo'
#         b'eker]\n        &lt;/emphasis&gt;,&lt;/para&gt;\n  '
#         b'    &lt;para&gt;wonende te [woonplaats 1] '
#         b',&lt;/para&gt;\n      &lt;para&gt;verzoeker,&lt;/par'
#         b'a&gt;\n      &lt;para&gt;advocaat mr. R.G. van'
#         b' Moll te &amp;#8217;s-Hertogenbosch, &lt;/p'
#         b'ara&gt;\n    &lt;/parablock&gt;\n    ',
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">102</td><td style="text-align:left">'[verzoeker] , wonende te [woonplaats 1] ,  verzoeker,  advocaat mr. R.G. van Moll te ’s-Hertogenbosch,'</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/para[8]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;para/&gt;\n    ', 'rawtype': 'xml'}</pre></td><td style="text-align:left">0</td><td style="text-align:left">''</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/parablock[7]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;parablock&gt;\n      &lt;para&gt;en&lt;/para&gt;\n  '
#         b'  &lt;/parablock&gt;\n    ',
#  'rawtype': 'xml'}</pre></td><td style="text-align:left">2</td><td style="text-align:left">'en'</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/para[9]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;para/&gt;\n    ', 'rawtype': 'xml'}</pre></td><td style="text-align:left">0</td><td style="text-align:left">''</td></tr><tr><td style="text-align:left"><pre>{'hints': [],
#  'part': '/open-rechtspraak/uitspraak/uitspraak.info',
#  'path': '/open-rechtspraak/uitspraak/uitspraak.info/parablock[8]'}</pre></td><td style="text-align:left"><pre>{'raw': b'&lt;parablock&gt;\n      &lt;para&gt;\n        &lt;em'
#         b'phasis role="bold"&gt;\n          [verwe'
#         b'erder] &lt;/emphasis&gt;h.o.d.n.&lt;emphasis '
#         b'role="bold"&gt; [bedrijf verweerder]&lt;/e'
#         b'mphasis&gt;,&lt;/para&gt;\n      &lt;para&gt;wonende'
#         b' te [woonplaats

# %% [markdown]
# Give a summary of all the stuff we just selected:

# %%
for key, docbytes in doc_pairs:
    if 'metadata' in key: # we care about documents; skip metadata-only, in case the above accidentally filtered them in
        continue

    thresh = 1500
    splitters = wetsuite.helpers.split.decide(docbytes, thresh=thresh)
    if len(splitters)==0:
        print( 'WARN for  %-30s - no splitter says it applies  (under threshold %s)'%(key, thresh) )
        # "stop on the first problem case and display it so we can add it" style logic:
        #if b'<html' in docbytes:
        #    display( wetsuite.helpers.etree.debug_color(docbytes) )
        #    break
        continue
    
    for score, fragproc in splitters: # use each processor that said they would be useful
        with warnings.catch_warnings(): # temporarily disable warnings
            warnings.simplefilter("ignore")
            frags = fragproc.fragments()
        if len(frags) == 0:
            print( 'WARN for  %-30s - no output from splitter %s'%(key, type(fragproc).__name__ ) )
            #if 'html.zip' in key:
            #    print(wetsuite.helpers.util.get_ziphtml(docbytes))
            #    print( fragproc.soup )
        else:
            textlen = sum(  list(len(fragtext)  for _,_,fragtext in frags))
            if textlen < 100:
                print( f'WARN for  {key:^50s} - {type(fragproc).__name__} gave {textlen} chars of text' )
            else:
                print( f'INFO for  {key:^50s} - {type(fragproc).__name__} gave {textlen} chars of text' )

            #for o1,o2,o3 in frags:
            #    print( type(o2) )

            if 0: # you may want to disable this print-everything when doing "are we missing anything" debug because it is a _lot_ of output
                #display( wetsuite.helpers.etree.debug_color(docbytes) )
                display( wetsuite.helpers.split.SplitDebug( frags ) )
                break
    #else:
    #    break

    #break
# Out:
# INFO for   bus:/2020/02/14/stb/stb-2020-54/stb-2020-54.xml   - Fragments_XML_OP_Stb gave 525 chars of text
# INFO for  bus:/2022/06/02/ah/ah-tk-20212022-2945/ah-tk-20212022-2945.xml - Fragments_XML_BUS_Kamer gave 10295 chars of text
# INFO for                    xml:CVDR686207                   - Fragments_XML_CVDR gave 101245 chars of text
# INFO for                   xml:BWBR0043402                   - Fragments_XML_BWB gave 18317 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHSHE:2011:557 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR713038                   - Fragments_XML_CVDR gave 111380 chars of text
# INFO for  bus:/1998/03/03/ah/ah-tk-19971998-770/ah-tk-19971998-770.xml - Fragments_XML_BUS_Kamer gave 4201 chars of text
# INFO for                    xml:CVDR662450                   - Fragments_XML_CVDR gave 49660 chars of text
# INFO for                   xml:BWBR0039397                   - Fragments_XML_BWB gave 254492 chars of text
# INFO for                   xml:BWBR0044791                   - Fragments_XML_BWB gave 829 chars of text
# INFO for                    xml:CVDR646757                   - Fragments_XML_CVDR gave 44296 chars of text
# INFO for                    xml:CVDR42659                    - Fragments_XML_CVDR gave 3608 chars of text
# INFO for                   xml:BWBR0048053                   - Fragments_XML_BWB gave 4210 chars of text
# INFO for  bus:/2018/05/11/prb/prb-2018-3508/prb-2018-3508.xml - Fragments_XML_OP_Prb gave 626 chars of text
# INFO for  bus:/2017/12/04/wsb/wsb-2017-11161/wsb-2017-11161.xml - Fragments_XML_OP_Wsb gave 2026 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBMNE:2017:1948 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2016/10/24/gmb/gmb-2016-146755/gmb-2016-146755.html.zip - Fragments_HTML_OP_Gmb gave 6608 chars of text
# INFO for                    xml:CVDR75914                    - Fragments_XML_CVDR gave 4618 chars of text
# INFO for  bus:/2023/11/02/kst/kst-22112-JF/kst-22112-JF.html.zip - Fragments_HTML_BUS_kamer gave 9323 chars of text
# INFO for  bus:/2016/12/06/prb/prb-2016-6489/prb-2016-6489.xml - Fragments_XML_OP_Prb gave 618 chars of text
# WARN for  bus:/2023/11/28/stcrt/stcrt-2023-33017/stcrt-2023-33017.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for  bus:/2021/12/15/wsb/wsb-2021-15120/wsb-2021-15120.xml - Fragments_XML_OP_Wsb gave 756 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:HR:1998:ZD8692 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR697255                   - Fragments_XML_CVDR gave 6092 chars of text
# INFO for                    xml:CVDR679567                   - Fragments_XML_CVDR gave 117874 chars of text
# INFO for  bus:/2020/02/14/kst/kst-35368-5/kst-35368-5.html.zip - Fragments_HTML_BUS_kamer gave 17445 chars of text
# INFO for                     xml:CVDR9611                    - Fragments_XML_CVDR gave 1058 chars of text
# INFO for                    xml:CVDR437072                   - Fragments_XML_CVDR gave 2878 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RVS:2008:2305 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBZWB:2013:1869 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  bus:/2019/01/30/h/h-tk-20182019-39-25/h-tk-20182019-39-25.html.zip - no splitter says it applies  (under threshold 1500)
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBROT:2015:8140 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR649430                   - Fragments_HTML_CVDR gave 259904 chars of text
# INFO for                   html:CVDR624365                   - Fragments_HTML_CVDR gave 6562 chars of text
# INFO for                   xml:BWBR0043988                   - Fragments_XML_BWB gave 505 chars of text
# INFO for                   xml:BWBR0007303                   - Fragments_XML_BWB gave 4501 chars of text
# INFO for  bus:/2023/05/26/gmb/gmb-2023-230517/gmb-2023-230517.xml - Fragments_XML_OP_Gmb gave 1286 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHLEE:2003:AO1860 - Fragments_XML_Rechtspraak gave 7759 chars of text
# INFO for                    xml:CVDR306715                   - Fragments_XML_CVDR gave 5972 chars of text
# INFO for                   html:CVDR391532                   - Fragments_HTML_CVDR gave 20019 chars of text
# INFO for                   html:CVDR156527                   - Fragments_HTML_CVDR gave 423413 chars of text
# WARN for  bus:/2021/02/03/stcrt/stcrt-2021-5584/stcrt-2021-5584.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for  bus:/2022/06/30/stcrt/stcrt-2022-17606/stcrt-2022-17606.pdf - Fragments_PDF_Fallback gave 233 chars of text
# INFO for                    xml:CVDR11126                    - Fragments_XML_CVDR gave 2911 chars of text
# INFO for                   xml:BWBR0003437                   - Fragments_XML_BWB gave 5793 chars of text
# INFO for                    html:CVDR53182                   - Fragments_HTML_CVDR gave 31409 chars of text
# INFO for                   xml:BWBR0011313                   - Fragments_XML_BWB gave 3881 chars of text
# INFO for                   xml:BWBR0034971                   - Fragments_XML_BWB gave 7905 chars of text
# INFO for                    xml:CVDR326845                   - Fragments_XML_CVDR gave 1628 chars of text
# INFO for  bus:/2013/08/26/stcrt/stcrt-2013-24284/stcrt-2013-24284.xml - Fragments_XML_OP_Stcrt gave 3549 chars of text
# INFO for  bus:/2012/07/02/kst/kst-32043-117/kst-32043-117.xml - Fragments_XML_BUS_Kamer gave 21213 chars of text
# INFO for  bus:/2020/06/17/gmb/gmb-2020-148627/gmb-2020-148627.html.zip - Fragments_HTML_OP_Gmb gave 96739 chars of text
# INFO for   bus:/2024/02/28/blg/blg-1129043/blg-1129043.pdf   - Fragments_PDF_Fallback gave 5634 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBHAA:2008:324 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBMAA:2008:5770 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2022/10/13/gmb/gmb-2022-457229/gmb-2022-457229.html.zip - Fragments_HTML_OP_Gmb gave 61151 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHAMS:2012:1404 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR248178                   - Fragments_XML_CVDR gave 6163 chars of text
# INFO for                   html:CVDR691111                   - Fragments_HTML_CVDR gave 29226 chars of text
# INFO for                   xml:BWBR0021782                   - Fragments_XML_BWB gave 4547 chars of text
# INFO for  bus:/2022/05/25/gmb/gmb-2022-230383/gmb-2022-230383.html.zip - Fragments_HTML_OP_Gmb gave 9210 chars of text
# INFO for                   xml:BWBR0028614                   - Fragments_XML_BWB gave 85033 chars of text
# INFO for                   html:CVDR605976                   - Fragments_HTML_CVDR gave 48790 chars of text
# INFO for  bus:/2016/03/03/kst/kst-34374-10/kst-34374-10.html.zip - Fragments_HTML_BUS_kamer gave 706 chars of text
# INFO for                   xml:BWBR0005454                   - Fragments_XML_BWB gave 2958 chars of text
# INFO for                   html:CVDR609220                   - Fragments_HTML_CVDR gave 53822 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBASS:2010:450 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR684124                   - Fragments_HTML_CVDR gave 15921 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBSGR:2006:7229 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/1999/07/23/stcrt/stcrt-1999-139-p5-SC19807/stcrt-1999-139-p5-SC19807.xml - Fragments_XML_OP_Stcrt gave 4820 chars of text
# INFO for                   xml:BWBR0032696                   - Fragments_XML_BWB gave 7432 chars of text
# INFO for                   xml:BWBR0014800                   - Fragments_XML_BWB gave 9704 chars of text
# INFO for  bus:/2018/02/07/gmb/gmb-2018-24951/gmb-2018-24951.xml - Fragments_XML_OP_Gmb gave 548 chars of text
# INFO for                   xml:BWBR0019211                   - Fragments_XML_BWB gave 8986 chars of text
# INFO for                   xml:BWBR0007603                   - Fragments_XML_BWB gave 21797 chars of text
# INFO for  bus:/2020/02/26/kst/kst-34264-AH/kst-34264-AH.xml  - Fragments_XML_BUS_Kamer gave 8316 chars of text
# INFO for  bus:/2024/03/04/gmb/gmb-2024-98726/gmb-2024-98726.html.zip - Fragments_HTML_OP_Gmb gave 376493 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBUTR:2009:5275 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR76721                    - Fragments_XML_CVDR gave 14099 chars of text
# INFO for     bus:/2010/02/05/blg/blg-52441/blg-52441.pdf     - Fragments_PDF_Fallback gave 52100 chars of text
# INFO for                    xml:CVDR617236                   - Fragments_XML_CVDR gave 8371 chars of text
# INFO for  bus:/2009/07/30/stcrt/stcrt-2009-10766-v1/stcrt-2009-10766-v1.xml - Fragments_XML_OP_Stcrt gave 1665 chars of text
# INFO for                   xml:BWBR0015968                   - Fragments_XML_BWB gave 7179 chars of text
# INFO for                   xml:BWBR0015047                   - Fragments_XML_BWB gave 24805 chars of text
# INFO for  bus:/2017/04/14/stcrt/stcrt-2017-20907/stcrt-2017-20907.xml - Fragments_XML_OP_Stcrt gave 126 chars of text
# INFO for  bus:/2024/03/11/gmb/gmb-2024-107865/gmb-2024-107865.html.zip - Fragments_HTML_OP_Gmb gave 8719 chars of text
# WARN for  bus:/2017/05/11/stcrt/stcrt-2017-26974/stcrt-2017-26974.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                    html:CVDR11015                   - Fragments_HTML_CVDR gave 396676 chars of text
# INFO for  bus:/2017/07/27/gmb/gmb-2017-130938/gmb-2017-130938.html.zip - Fragments_HTML_OP_Gmb gave 4024 chars of text
# INFO for                   html:CVDR698305                   - Fragments_HTML_CVDR gave 75116 chars of text
# INFO for  bus:/2022/07/22/kst/kst-25657-350/kst-25657-350.html.zip - Fragments_HTML_BUS_kamer gave 2847 chars of text
# INFO for  bus:/2022/06/14/gmb/gmb-2022-267223/gmb-2022-267223.xml - Fragments_XML_OP_Gmb gave 1044 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBZWB:2017:8281 - Fragments_XML_Rechtspraak gave 9780 chars of text
# INFO for  bus:/2020/07/14/wsb/wsb-2020-7820/wsb-2020-7820.html.zip - Fragments_HTML_OP_Wsb gave 31127 chars of text
# INFO for                    xml:CVDR372846                   - Fragments_XML_CVDR gave 6575 chars of text
# INFO for                    html:CVDR85630                   - Fragments_HTML_CVDR gave 4624 chars of text
# INFO for                   html:CVDR684907                   - Fragments_HTML_CVDR gave 110108 chars of text
# INFO for                    xml:CVDR340482                   - Fragments_XML_CVDR gave 63832 chars of text
# INFO for                   xml:BWBR0029673                   - Fragments_XML_BWB gave 4260 chars of text
# INFO for                    xml:CVDR330911                   - Fragments_XML_CVDR gave 230 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHARL:2015:6245 - Fragments_XML_Rechtspraak gave 48629 chars of text
# INFO for  bus:/2017/05/26/gmb/gmb-2017-89010/gmb-2017-89010.html.zip - Fragments_HTML_OP_Gmb gave 80997 chars of text
# INFO for   bus:/2009/09/24/kst/kst-32143-2/kst-32143-2.xml   - Fragments_XML_BUS_Kamer gave 595 chars of text
# INFO for    bus:/2018/10/04/blg/blg-857264/blg-857264.pdf    - Fragments_PDF_Fallback gave 42454 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:CRVB:2006:AV1978 - Fragments_XML_Rechtspraak gave 12413 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:PHR:2014:1730 - Fragments_XML_Rechtspraak gave 61847 chars of text
# WARN for  bus:/2006/05/30/kst/kst-29515-143-b2/kst-29515-143-b2.xml - no splitter says it applies  (under threshold 1500)
# INFO for  bus:/2019/11/20/stcrt/stcrt-2019-64089/stcrt-2019-64089.xml - Fragments_XML_OP_Stcrt gave 1559 chars of text
# INFO for                   xml:BWBR0007093                   - Fragments_XML_BWB gave 13057 chars of text
# INFO for                   xml:BWBR0031361                   - Fragments_XML_BWB gave 1728 chars of text
# INFO for                   html:CVDR629965                   - Fragments_HTML_CVDR gave 98457 chars of text
# INFO for                   html:CVDR490874                   - Fragments_HTML_CVDR gave 198928 chars of text
# INFO for  bus:/2021/07/29/gmb/gmb-2021-254447/gmb-2021-254447.html.zip - Fragments_HTML_OP_Gmb gave 7682 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBMID:1920:10 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR648010                   - Fragments_XML_CVDR gave 3125 chars of text
# INFO for  bus:/2023/05/04/gmb/gmb-2023-195410/gmb-2023-195410.html.zip - Fragments_HTML_OP_Gmb gave 4015 chars of text
# INFO for                   html:CVDR481965                   - Fragments_HTML_CVDR gave 167173 chars of text
# INFO for                   xml:BWBR0035217                   - Fragments_XML_BWB gave 208982 chars of text
# INFO for                   html:CVDR364362                   - Fragments_HTML_CVDR gave 5254 chars of text
# INFO for                    xml:CVDR238948                   - Fragments_XML_CVDR gave 16306 chars of text
# INFO for                   html:CVDR335772                   - Fragments_HTML_CVDR gave 150180 chars of text
# INFO for  bus:/2018/03/14/kst/kst-32849-118/kst-32849-118.xml - Fragments_XML_BUS_Kamer gave 626 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:CRVB:2017:3873 - Fragments_XML_Rechtspraak gave 5184 chars of text
# INFO for                   xml:BWBR0006430                   - Fragments_XML_BWB gave 928 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RVS:2010:3156 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/1977/03/29/stb/stb-1977-144/stb-1977-144.pdf  - Fragments_PDF_Fallback gave 1459 chars of text
# INFO for  bus:/2022/08/26/gmb/gmb-2022-386370/gmb-2022-386370.html.zip - Fragments_HTML_OP_Gmb gave 11440 chars of text
# INFO for  bus:/2015/11/13/stcrt/stcrt-2015-40769/stcrt-2015-40769.html.zip - Fragments_HTML_OP_Stcrt gave 70341 chars of text
# INFO for  bus:/2018/03/15/gmb/gmb-2018-54604/gmb-2018-54604.html.zip - Fragments_HTML_OP_Gmb gave 5868 chars of text
# INFO for                   xml:BWBR0046540                   - Fragments_XML_BWB gave 670 chars of text
# INFO for  bus:/2009/02/05/stcrt/stcrt-2009-1802/stcrt-2009-1802.xml - Fragments_XML_OP_Stcrt gave 1743 chars of text
# INFO for  bus:/2017/04/14/kst/kst-34432-9/kst-34432-9.html.zip - Fragments_HTML_BUS_kamer gave 1638 chars of text
# INFO for                   html:CVDR654084                   - Fragments_HTML_CVDR gave 228496 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RVS:2010:5816 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:HR:2012:BW6675 - Fragments_XML_Rechtspraak gave 8840 chars of text
# INFO for                    xml:CVDR650561                   - Fragments_XML_CVDR gave 3548 chars of text
# INFO for                    xml:CVDR640954                   - Fragments_XML_CVDR gave 40560 chars of text
# INFO for                   xml:BWBR0007259                   - Fragments_XML_BWB gave 2844 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:XX:2012:BY4075 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0034026                   - Fragments_XML_BWB gave 20743 chars of text
# INFO for  bus:/2020/07/03/gmb/gmb-2020-168406/gmb-2020-168406.html.zip - Fragments_HTML_OP_Gmb gave 19168 chars of text
# INFO for                   html:CVDR311152                   - Fragments_HTML_CVDR gave 157705 chars of text
# INFO for                    xml:CVDR609285                   - Fragments_XML_CVDR gave 6060 chars of text
# INFO for                    xml:CVDR364698                   - Fragments_XML_CVDR gave 9776 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBDHA:2015:13588 - Fragments_XML_Rechtspraak gave 34931 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHARN:2010:BL4486 - Fragments_XML_Rechtspraak gave 21640 chars of text
# INFO for                   xml:BWBR0003567                   - Fragments_XML_BWB gave 909 chars of text
# INFO for  bus:/2015/06/09/kst/kst-34200-V-7/kst-34200-V-7.html.zip - Fragments_HTML_BUS_kamer gave 18898 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBAMS:2018:7202 - Fragments_XML_Rechtspraak gave 19781 chars of text
# INFO for                    xml:CVDR349214                   - Fragments_XML_CVDR gave 17845 chars of text
# INFO for                   xml:BWBR0015754                   - Fragments_XML_BWB gave 633 chars of text
# INFO for   bus:/2017/03/28/kst/kst-34589-B/kst-34589-B.xml   - Fragments_XML_BUS_Kamer gave 33373 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBROT:2014:2605 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  bus:/2022/06/24/stcrt/stcrt-2022-16998/stcrt-2022-16998.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                    xml:CVDR333677                   - Fragments_XML_CVDR gave 9158 chars of text
# INFO for  bus:/2016/12/15/kst/kst-34550-A-53/kst-34550-A-53.html.zip - Fragments_HTML_BUS_kamer gave 4332 chars of text
# INFO for                   html:CVDR231701                   - Fragments_HTML_CVDR gave 145396 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBLIM:2020:2343 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/1995/11/08/kst/kst-24400-V-13/kst-24400-V-13.xml - Fragments_XML_BUS_Kamer gave 226006 chars of text
# INFO for                   xml:BWBR0039920                   - Fragments_XML_BWB gave 3033 chars of text
# INFO for                   xml:BWBR0014028                   - Fragments_XML_BWB gave 5641 chars of text
# INFO for  bus:/2022/06/16/gmb/gmb-2022-273598/gmb-2022-273598.html.zip - Fragments_HTML_OP_Gmb gave 18341 chars of text
# INFO for                   html:CVDR675401                   - Fragments_HTML_CVDR gave 578603 chars of text
# INFO for                   html:CVDR638077                   - Fragments_HTML_CVDR gave 189289 chars of text
# INFO for                   html:CVDR710069                   - Fragments_HTML_CVDR gave 123390 chars of text
# INFO for  bus:/2004/06/21/stcrt/stcrt-2004-115-p10-SC65555/stcrt-2004-115-p10-SC65555.xml - Fragments_XML_OP_Stcrt gave 538 chars of text
# INFO for   bus:/2022/11/18/kst/kst-28165-Y/kst-28165-Y.xml   - Fragments_XML_BUS_Kamer gave 57945 chars of text
# INFO for  bus:/2022/12/06/kst/kst-36200-XVI-169/kst-36200-XVI-169.html.zip - Fragments_HTML_BUS_kamer gave 1238 chars of text
# INFO for                    html:CVDR77553                   - Fragments_HTML_CVDR gave 91678 chars of text
# INFO for                   xml:BWBR0014290                   - Fragments_XML_BWB gave 2164 chars of text
# INFO for                   html:CVDR365323                   - Fragments_HTML_CVDR gave 61295 chars of text
# INFO for                   xml:BWBR0003220                   - Fragments_XML_BWB gave 18889 chars of text
# INFO for                    xml:CVDR675509                   - Fragments_XML_CVDR gave 11413 chars of text
# WARN for   bus:/2022/11/21/blg/blg-1060688/blg-1060688.pdf   - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                   html:CVDR249089                   - Fragments_HTML_CVDR gave 55423 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBLIM:2017:6974 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR325372                   - Fragments_XML_CVDR gave 3656 chars of text
# INFO for                   html:CVDR358643                   - Fragments_HTML_CVDR gave 510863 chars of text
# INFO for                   html:CVDR636089                   - Fragments_HTML_CVDR gave 136499 chars of text
# INFO for                   xml:BWBR0024433                   - Fragments_XML_BWB gave 16502 chars of text
# INFO for                    xml:CVDR427147                   - Fragments_XML_CVDR gave 7794 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RVS:2020:3132 - Fragments_XML_Rechtspraak gave 8573 chars of text
# INFO for                    xml:CVDR94066                    - Fragments_XML_CVDR gave 6249 chars of text
# INFO for                    xml:CVDR272559                   - Fragments_XML_CVDR gave 17490 chars of text
# INFO for  bus:/2019/02/27/gmb/gmb-2019-46557/gmb-2019-46557.html.zip - Fragments_HTML_OP_Gmb gave 113848 chars of text
# INFO for  bus:/2012/04/05/stcrt/stcrt-2012-6601/stcrt-2012-6601.xml - Fragments_XML_OP_Stcrt gave 1608 chars of text
# INFO for                   xml:BWBR0025689                   - Fragments_XML_BWB gave 6540 chars of text
# INFO for  bus:/2022/03/18/kst/kst-35925-XVI-178/kst-35925-XVI-178.html.zip - Fragments_HTML_BUS_kamer gave 822 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBAMS:2015:6036 - Fragments_XML_Rechtspraak gave 9763 chars of text
# INFO for  bus:/2018/01/15/stcrt/stcrt-2018-2603/stcrt-2018-2603.html.zip - Fragments_HTML_OP_Stcrt gave 26021 chars of text
# INFO for  bus:/2018/02/07/prb/prb-2018-1042/prb-2018-1042.xml - Fragments_XML_OP_Prb gave 1126 chars of text
# INFO for                    xml:CVDR374885                   - Fragments_XML_CVDR gave 961 chars of text
# INFO for                   xml:BWBR0045496                   - Fragments_XML_BWB gave 3407 chars of text
# INFO for  bus:/2017/03/29/gmb/gmb-2017-49967/gmb-2017-49967.xml - Fragments_XML_OP_Gmb gave 206 chars of text
# INFO for                    xml:CVDR477589                   - Fragments_XML_CVDR gave 6558 chars of text
# INFO for  bus:/2018/03/22/bgr/bgr-2018-363/bgr-2018-363.xml  - Fragments_XML_OP_Bgr gave 421 chars of text
# INFO for                   html:CVDR648971                   - Fragments_HTML_CVDR gave 23202 chars of text
# INFO for                   xml:BWBR0032176                   - Fragments_XML_BWB gave 10344 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBNNE:2020:47 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0029296                   - Fragments_XML_BWB gave 22108 chars of text
# INFO for  bus:/2021/10/26/gmb/gmb-2021-376947/gmb-2021-376947.html.zip - Fragments_HTML_OP_Gmb gave 4220 chars of text
# WARN for  bus:/2020/11/09/stcrt/stcrt-2020-58911/stcrt-2020-58911.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for  bus:/2024/02/16/gmb/gmb-2024-74660/gmb-2024-74660.html.zip - Fragments_HTML_OP_Gmb gave 8128 chars of text
# INFO for                    xml:CVDR689955                   - Fragments_XML_CVDR gave 144540 chars of text
# INFO for  bus:/2021/10/18/gmb/gmb-2021-364252/gmb-2021-364252.html.zip - Fragments_HTML_OP_Gmb gave 25395 chars of text
# INFO for  bus:/2022/10/14/kst/kst-30950-318/kst-30950-318.html.zip - Fragments_HTML_BUS_kamer gave 1983 chars of text
# INFO for                   xml:BWBR0009766                   - Fragments_XML_BWB gave 19260 chars of text
# INFO for  bus:/2019/06/17/gmb/gmb-2019-147258/gmb-2019-147258.xml - Fragments_XML_OP_Gmb gave 1040 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBOVE:2016:3259 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0038051                   - Fragments_XML_BWB gave 2912 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBOVE:2014:5966 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0019632                   - Fragments_XML_BWB gave 1503 chars of text
# INFO for  bus:/2012/08/24/kv/kv-tk-2012Z15337/kv-tk-2012Z15337.xml - Fragments_XML_BUS_Kamer gave 1355 chars of text
# INFO for                   xml:BWBR0033868                   - Fragments_XML_BWB gave 516 chars of text
# INFO for  bus:/2017/06/21/kst/kst-31142-68/kst-31142-68.html.zip - Fragments_HTML_BUS_kamer gave 600 chars of text
# INFO for  bus:/2019/12/02/stcrt/stcrt-2019-66451/stcrt-2019-66451.html.zip - Fragments_HTML_OP_Stcrt gave 65702 chars of text
# INFO for  bus:/2017/04/24/kst/kst-34302-AA/kst-34302-AA.html.zip - Fragments_HTML_BUS_kamer gave 17789 chars of text
# INFO for                   html:CVDR619324                   - Fragments_HTML_CVDR gave 98791 chars of text
# INFO for   bus:/2023/02/22/blg/blg-1075897/blg-1075897.pdf   - Fragments_PDF_Fallback gave 758 chars of text
# INFO for                   xml:BWBR0002806                   - Fragments_XML_BWB gave 1304 chars of text
# INFO for                    html:CVDR7601                    - Fragments_HTML_CVDR gave 362533 chars of text
# INFO for    bus:/2013/09/11/blg/blg-248708/blg-248708.pdf    - Fragments_PDF_Fallback gave 143517 chars of text
# INFO for  bus:/2017/09/19/ah/ah-tk-20162017-2732/ah-tk-20162017-2732.xml - Fragments_XML_BUS_Kamer gave 2876 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBROT:2023:1351 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0031395                   - Fragments_XML_BWB gave 1128 chars of text
# INFO for  bus:/2007/07/17/kv/kv-2060721190/kv-2060721190.xml - Fragments_XML_BUS_Kamer gave 1536 chars of text
# INFO for                   html:CVDR404932                   - Fragments_HTML_CVDR gave 1450685 chars of text
# INFO for                   html:CVDR689481                   - Fragments_HTML_CVDR gave 764510 chars of text
# INFO for                   html:CVDR350205                   - Fragments_HTML_CVDR gave 5295 chars of text
# WARN for  bus:/2021/01/19/stcrt/stcrt-2021-1603/stcrt-2021-1603.html.zip - no output from splitter Fragments_HTML_OP_Stcrt
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHLEE:2008:1474 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2020/11/25/gmb/gmb-2020-306727/gmb-2020-306727.xml - Fragments_XML_OP_Gmb gave 176 chars of text
# WARN for  bus:/2015/02/12/ah/ah-tk-20142015-1258/ah-tk-20142015-1258.html.zip - no output from splitter Fragments_HTML_BUS_kamer
# INFO for  bus:/2013/07/11/stcrt/stcrt-2013-19382/stcrt-2013-19382.xml - Fragments_XML_OP_Stcrt gave 2610 chars of text
# INFO for   bus:/2004/04/15/kst/kst-29410-3/kst-29410-3.xml   - Fragments_XML_BUS_Kamer gave 1014 chars of text
# INFO for                    xml:CVDR675940                   - Fragments_XML_CVDR gave 20058 chars of text
# INFO for  bus:/2014/10/01/gmb/gmb-2014-53948/gmb-2014-53948.html.zip - Fragments_HTML_OP_Gmb gave 9165 chars of text
# INFO for                    xml:CVDR608683                   - Fragments_XML_CVDR gave 4870 chars of text
# INFO for  bus:/1995/09/21/stb/stb-1995-435/stb-1995-435.xml  - Fragments_XML_OP_Stb gave 1513 chars of text
# INFO for                   html:CVDR660685                   - Fragments_HTML_CVDR gave 114773 chars of text
# INFO for   bus:/2023/01/17/blg/blg-1069403/blg-1069403.pdf   - Fragments_PDF_Fallback gave 36054 chars of text
# WARN for  bus:/2018/05/31/h/h-tk-20172018-77-32/h-tk-20172018-77-32.html.zip - no splitter says it applies  (under threshold 1500)
# INFO for                   xml:BWBR0019344                   - Fragments_XML_BWB gave 10798 chars of text
# INFO for                   xml:BWBR0013421                   - Fragments_XML_BWB gave 1499 chars of text
# WARN for  bus:/2021/10/15/stcrt/stcrt-2021-43947/stcrt-2021-43947.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                    html:CVDR11781                   - Fragments_HTML_CVDR gave 33914 chars of text
# INFO for                   html:CVDR354822                   - Fragments_HTML_CVDR gave 56304 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBZWB:2017:7234 - Fragments_XML_Rechtspraak gave 16203 chars of text
# WARN for  bus:/2015/10/07/h/h-tk-20152016-3-4/h-tk-20152016-3-4.html.zip - no splitter says it applies  (under threshold 1500)
# INFO for                   xml:BWBR0020873                   - Fragments_XML_BWB gave 22989 chars of text
# INFO for  bus:/2018/11/20/kst/kst-35000-VIII-108/kst-35000-VIII-108.html.zip - Fragments_HTML_BUS_kamer gave 1169 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBSGR:2008:13923 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2022/08/08/wsb/wsb-2022-8645/wsb-2022-8645.html.zip - Fragments_HTML_OP_Wsb gave 20473 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBZUT:2008:806 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR708808                   - Fragments_XML_CVDR gave 13369 chars of text
# INFO for    bus:/2013/10/21/blg/blg-257243/blg-257243.pdf    - Fragments_PDF_Fallback gave 195933 chars of text
# INFO for                    html:CVDR17841                   - Fragments_HTML_CVDR gave 92948 chars of text
# INFO for  bus:/2022/05/19/gmb/gmb-2022-226569/gmb-2022-226569.html.zip - Fragments_HTML_OP_Gmb gave 11955 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBHAA:2008:7327 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR341422                   - Fragments_HTML_CVDR gave 55589 chars of text
# INFO for                   html:CVDR682003                   - Fragments_HTML_CVDR gave 153808 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBARN:2009:1050 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2022/08/19/kv/kv-tk-2022Z15617/kv-tk-2022Z15617.xml - Fragments_XML_BUS_Kamer gave 1344 chars of text
# INFO for                   html:CVDR238360                   - Fragments_HTML_CVDR gave 623 chars of text
# WARN for  bus:/2021/12/13/stcrt/stcrt-2021-49611/stcrt-2021-49611.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                    xml:CVDR616015                   - Fragments_XML_CVDR gave 3711 chars of text
# INFO for  bus:/2014/09/02/stcrt/stcrt-2014-24823/stcrt-2014-24823.xml - Fragments_XML_OP_Stcrt gave 3423 chars of text
# WARN for  bus:/2023/04/24/stcrt/stcrt-2023-12186/stcrt-2023-12186.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for  bus:/2019/03/26/ah/ah-tk-20182019-2042/ah-tk-20182019-2042.xml - Fragments_XML_BUS_Kamer gave 8484 chars of text
# INFO for  bus:/2021/11/25/gmb/gmb-2021-424468/gmb-2021-424468.xml - Fragments_XML_OP_Gmb gave 326 chars of text
# INFO for                   html:CVDR314694                   - Fragments_HTML_CVDR gave 87865 chars of text
# INFO for  bus:/2021/07/06/gmb/gmb-2021-213883/gmb-2021-213883.xml - Fragments_XML_OP_Gmb gave 528 chars of text
# INFO for  bus:/2018/05/02/stcrt/stcrt-2018-23638/stcrt-2018-23638.xml - Fragments_XML_OP_Stcrt gave 2066 chars of text
# INFO for  bus:/2018/09/27/wsb/wsb-2018-9577/wsb-2018-9577.xml - Fragments_XML_OP_Wsb gave 564 chars of text
# INFO for    bus:/2019/10/04/blg/blg-902075/blg-902075.pdf    - Fragments_PDF_Fallback gave 89172 chars of text
# INFO for                   xml:BWBR0038145                   - Fragments_XML_BWB gave 67091 chars of text
# INFO for                    xml:CVDR61918                    - Fragments_XML_CVDR gave 25443 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBSHE:2012:646 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHAMS:2017:724 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR387663                   - Fragments_XML_CVDR gave 9638 chars of text
# INFO for  bus:/2019/11/22/gmb/gmb-2019-283485/gmb-2019-283485.html.zip - Fragments_HTML_OP_Gmb gave 15694 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBZWB:2018:992 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0003111                   - Fragments_XML_BWB gave 3405 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHARN:2009:BJ1388 - Fragments_XML_Rechtspraak gave 7250 chars of text
# INFO for  bus:/2020/04/22/kst/kst-35336-16/kst-35336-16.html.zip - Fragments_HTML_BUS_kamer gave 967 chars of text
# INFO for                   html:CVDR285526                   - Fragments_HTML_CVDR gave 1843182 chars of text
# INFO for  bus:/2019/02/28/gmb/gmb-2019-42475/gmb-2019-42475.html.zip - Fragments_HTML_OP_Gmb gave 6508 chars of text
# INFO for                      2023D51633                     - Fragments_PDF_Fallback gave 96337 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBLIM:2022:7306 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR703334                   - Fragments_XML_CVDR gave 4415 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBDHA:2015:778 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0044311                   - Fragments_XML_BWB gave 636 chars of text
# INFO for                    xml:CVDR634657                   - Fragments_XML_CVDR gave 12853 chars of text
# INFO for                    xml:CVDR477244                   - Fragments_XML_CVDR gave 19768 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:CRVB:1989:ZB1110 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2019/02/27/stcrt/stcrt-2019-9767/stcrt-2019-9767.html.zip - Fragments_HTML_OP_Stcrt gave 17563 chars of text
# WARN for  bus:/2019/05/23/stcrt/stcrt-2019-29565/stcrt-2019-29565.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                     simple2page                     - Fragments_PDF_Fallback gave 4339 chars of text
# INFO for  bus:/2004/06/01/ah/ah-tk-20032004-1584/ah-tk-20032004-1584.xml - Fragments_XML_BUS_Kamer gave 5367 chars of text
# INFO for  bus:/2022/11/23/wsb/wsb-2022-12927/wsb-2022-12927.xml - Fragments_XML_OP_Wsb gave 1890 chars of text
# INFO for  bus:/2020/05/28/gmb/gmb-2020-131464/gmb-2020-131464.html.zip - Fragments_HTML_OP_Gmb gave 2231 chars of text
# INFO for                    xml:CVDR338492                   - Fragments_XML_CVDR gave 942 chars of text
# INFO for  bus:/2002/06/05/kst/kst-28380-12/kst-28380-12.xml  - Fragments_XML_BUS_Kamer gave 70335 chars of text
# INFO for  bus:/2021/07/13/prb/prb-2021-5703/prb-2021-5703.xml - Fragments_XML_OP_Prb gave 1870 chars of text
# INFO for                   html:CVDR651468                   - Fragments_HTML_CVDR gave 91417 chars of text
# INFO for                    html:CVDR41322                   - Fragments_HTML_CVDR gave 13618 chars of text
# INFO for                    xml:CVDR382291                   - Fragments_XML_CVDR gave 3374 chars of text
# INFO for  bus:/2018/06/19/gmb/gmb-2018-129939/gmb-2018-129939.xml - Fragments_XML_OP_Gmb gave 1716 chars of text
# INFO for    bus:/2013/12/30/blg/blg-274235/blg-274235.pdf    - Fragments_PDF_Fallback gave 15392 chars of text
# INFO for  bus:/2021/12/22/gmb/gmb-2021-468369/gmb-2021-468369.xml - Fragments_XML_OP_Gmb gave 5063 chars of text
# INFO for  bus:/2020/11/18/prb/prb-2020-8385/prb-2020-8385.xml - Fragments_XML_OP_Prb gave 3336 chars of text
# INFO for                   xml:BWBR0021601                   - Fragments_XML_BWB gave 12570 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBMNE:2021:6383 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBHAA:2010:2747 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0010530                   - Fragments_XML_BWB gave 948 chars of text
# INFO for                    xml:CVDR623872                   - Fragments_XML_CVDR gave 614 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:CBB:1995:ZG1009 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBSHE:2009:6716 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0018005                   - Fragments_XML_BWB gave 81940 chars of text
# INFO for                   xml:BWBR0048344                   - Fragments_XML_BWB gave 6241 chars of text
# INFO for                   html:CVDR643407                   - Fragments_HTML_CVDR gave 66850 chars of text
# WARN for  bus:/1980/11/13/trb/trb-1980-176/trb-1980-176.xml - no splitter says it applies  (under threshold 1500)
# INFO for                    xml:CVDR667542                   - Fragments_XML_CVDR gave 1856 chars of text
# INFO for  bus:/2018/07/30/gmb/gmb-2018-164045/gmb-2018-164045.xml - Fragments_XML_OP_Gmb gave 891 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHAMS:2008:BD4173 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBBRE:2007:2277 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR677458                   - Fragments_HTML_CVDR gave 50184 chars of text
# INFO for                   xml:BWBR0004039                   - Fragments_XML_BWB gave 4711 chars of text
# INFO for                    xml:CVDR50203                    - Fragments_XML_CVDR gave 12644 chars of text
# INFO for                    xml:CVDR407899                   - Fragments_XML_CVDR gave 4232 chars of text
# INFO for                   xml:BWBR0013456                   - Fragments_XML_BWB gave 607 chars of text
# WARN for  bus:/2022/07/26/stcrt/stcrt-2022-19928/stcrt-2022-19928.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for  bus:/2014/05/09/stcrt/stcrt-2014-12848/stcrt-2014-12848.xml - Fragments_XML_OP_Stcrt gave 6196 chars of text
# INFO for                   xml:BWBR0018735                   - Fragments_XML_BWB gave 1279 chars of text
# INFO for  bus:/2006/12/13/kst/kst-30234-11/kst-30234-11.xml  - Fragments_XML_BUS_Kamer gave 12053 chars of text
# INFO for                   html:CVDR265477                   - Fragments_HTML_CVDR gave 36600 chars of text
# INFO for                    xml:CVDR344878                   - Fragments_XML_CVDR gave 5123 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBHAA:2010:5476 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR440023                   - Fragments_HTML_CVDR gave 129199 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBAMS:2014:6745 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0016851                   - Fragments_XML_BWB gave 17729 chars of text
# INFO for                   xml:BWBR0030237                   - Fragments_XML_BWB gave 5104 chars of text
# INFO for  bus:/2013/05/30/kst/kst-21501-20-793/kst-21501-20-793.xml - Fragments_XML_BUS_Kamer gave 252 chars of text
# INFO for  bus:/2020/07/30/kst/kst-35420-85/kst-35420-85.html.zip - Fragments_HTML_BUS_kamer gave 47399 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBLIM:2015:1830 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0023234                   - Fragments_XML_BWB gave 788 chars of text
# INFO for  bus:/2023/01/26/gmb/gmb-2023-35595/gmb-2023-35595.html.zip - Fragments_HTML_OP_Gmb gave 6954 chars of text
# INFO for  bus:/2020/02/06/kst/kst-31936-716/kst-31936-716.html.zip - Fragments_HTML_BUS_kamer gave 804 chars of text
# INFO for                    xml:CVDR23226                    - Fragments_XML_CVDR gave 5879 chars of text
# INFO for  bus:/2018/10/24/gmb/gmb-2018-225636/gmb-2018-225636.html.zip - Fragments_HTML_OP_Gmb gave 3236 chars of text
# INFO for                   html:CVDR336805                   - Fragments_HTML_CVDR gave 49858 chars of text
# WARN for  bus:/2016/07/08/ah/ah-tk-20152016-3050/ah-tk-20152016-3050.html.zip - no output from splitter Fragments_HTML_BUS_kamer
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBGRO:2010:224 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR144354                   - Fragments_XML_CVDR gave 10430 chars of text
# INFO for   bus:/2014/01/29/stb/stb-2014-36/stb-2014-36.xml   - Fragments_XML_OP_Stb gave 501 chars of text
# WARN for  bus:/2021/06/09/stcrt/stcrt-2021-29638/stcrt-2021-29638.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                    xml:CVDR707395                   - Fragments_XML_CVDR gave 40551 chars of text
# INFO for                   xml:BWBR0032657                   - Fragments_XML_BWB gave 2806 chars of text
# INFO for                    xml:CVDR345555                   - Fragments_XML_CVDR gave 11198 chars of text
# INFO for                    xml:CVDR326841                   - Fragments_XML_CVDR gave 22614 chars of text
# WARN for  bus:/2024/01/19/stcrt/stcrt-2024-2168/stcrt-2024-2168.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                   xml:BWBR0042497                   - Fragments_XML_BWB gave 1209 chars of text
# INFO for  bus:/2011/09/08/stcrt/stcrt-2011-16126/stcrt-2011-16126.xml - Fragments_XML_OP_Stcrt gave 449 chars of text
# INFO for  bus:/2000/01/07/kst/kst-26800-V-141/kst-26800-V-141.xml - Fragments_XML_BUS_Kamer gave 2347 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBGEL:2020:5176 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  bus:/2007/12/17/kst/kst-30853-8/kst-30853-8.html.zip - no splitter says it applies  (under threshold 1500)
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBNNE:2017:1256 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    html:CVDR41741                   - Fragments_HTML_CVDR gave 13897 chars of text
# INFO for                   html:CVDR326388                   - Fragments_HTML_CVDR gave 82253 chars of text
# INFO for  bus:/2021/04/07/prb/prb-2021-2415/prb-2021-2415.xml - Fragments_XML_OP_Prb gave 735 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBLIM:2022:2500 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBOVE:2018:348 - Fragments_XML_Rechtspraak gave 8403 chars of text
# WARN for  bus:/2015/03/26/h/h-tk-20142015-60-12/h-tk-20142015-60-12.xml - Fragments_XML_OP_Handelingen gave 20 chars of text
# INFO for                     xml:CVDR9851                    - Fragments_XML_CVDR gave 5185 chars of text
# INFO for                   xml:BWBR0021166                   - Fragments_XML_BWB gave 18452 chars of text
# INFO for                    xml:CVDR671324                   - Fragments_XML_CVDR gave 4820 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBROT:2023:6528 - Fragments_XML_Rechtspraak gave 4663 chars of text
# WARN for  bus:/2020/12/03/stcrt/stcrt-2020-64050/stcrt-2020-64050.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                   html:CVDR618492                   - Fragments_HTML_CVDR gave 42796 chars of text
# INFO for  bus:/2004/12/22/h/h-ek-20042005-353-361/h-ek-20042005-353-361.xml - Fragments_XML_OP_Handelingen gave 47656 chars of text
# INFO for                   xml:BWBR0035051                   - Fragments_XML_BWB gave 504314 chars of text
# INFO for  bus:/2009/05/01/ah/ah-tk-20082009-2426/ah-tk-20082009-2426.xml - Fragments_XML_BUS_Kamer gave 1388 chars of text
# INFO for                   html:CVDR704843                   - Fragments_HTML_CVDR gave 262751 chars of text
# INFO for  bus:/2024/01/03/gmb/gmb-2024-1627/gmb-2024-1627.xml - Fragments_XML_OP_Gmb gave 695 chars of text
# INFO for  bus:/2015/07/17/stb/stb-2015-297/stb-2015-297.xml  - Fragments_XML_OP_Stb gave 388 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHLEE:2011:4369 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR415963                   - Fragments_HTML_CVDR gave 33256 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBAMS:2016:6610 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    html:CVDR74988                   - Fragments_HTML_CVDR gave 192405 chars of text
# INFO for                    xml:CVDR675078                   - Fragments_XML_CVDR gave 50614 chars of text
# INFO for  bus:/2023/08/07/gmb/gmb-2023-344926/gmb-2023-344926.xml - Fragments_XML_OP_Gmb gave 1977 chars of text
# INFO for  bus:/2024/02/29/gmb/gmb-2024-89534/gmb-2024-89534.html.zip - Fragments_HTML_OP_Gmb gave 16248 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHLEE:2012:BY3915 - Fragments_XML_Rechtspraak gave 21871 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBSGR:2012:13969 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR61944                    - Fragments_XML_CVDR gave 99240 chars of text
# INFO for                   html:CVDR712514                   - Fragments_HTML_CVDR gave 32250 chars of text
# INFO for  bus:/1998/07/20/stcrt/stcrt-1998-134-p8-SC14731/stcrt-1998-134-p8-SC14731.xml - Fragments_XML_OP_Stcrt gave 47572 chars of text
# INFO for  bus:/2019/09/26/wsb/wsb-2019-10391/wsb-2019-10391.html.zip - Fragments_HTML_OP_Wsb gave 6704 chars of text
# INFO for  bus:/1998/04/29/kst/kst-25180-64/kst-25180-64.xml  - Fragments_XML_BUS_Kamer gave 1018 chars of text
# INFO for                    xml:CVDR343355                   - Fragments_XML_CVDR gave 18725 chars of text
# INFO for                   html:CVDR694699                   - Fragments_HTML_CVDR gave 30779 chars of text
# INFO for                   xml:BWBR0011151                   - Fragments_XML_BWB gave 23153 chars of text
# INFO for                   html:CVDR225872                   - Fragments_HTML_CVDR gave 6631 chars of text
# INFO for  bus:/2018/03/21/gmb/gmb-2018-59172/gmb-2018-59172.xml - Fragments_XML_OP_Gmb gave 1751 chars of text
# INFO for  bus:/2022/10/07/prb/prb-2022-11898/prb-2022-11898.xml - Fragments_XML_OP_Prb gave 2738 chars of text
# INFO for                    html:CVDR57012                   - Fragments_HTML_CVDR gave 62565 chars of text
# INFO for  bus:/2018/11/13/stcrt/stcrt-2018-63364/stcrt-2018-63364.xml - Fragments_XML_OP_Stcrt gave 1778 chars of text
# WARN for  bus:/2021/03/24/kv/kv-tk-2021Z04885/kv-tk-2021Z04885.html.zip - no output from splitter Fragments_HTML_BUS_kamer
# INFO for  bus:/2015/06/03/gmb/gmb-2015-48663/gmb-2015-48663.html.zip - Fragments_HTML_OP_Gmb gave 4086 chars of text
# WARN for  bus:/2018/03/15/h/h-tk-20172018-53-10/h-tk-20172018-53-10.html.zip - no splitter says it applies  (under threshold 1500)
# INFO for                   xml:BWBR0036573                   - Fragments_XML_BWB gave 1815 chars of text
# INFO for                    xml:CVDR713762                   - Fragments_XML_CVDR gave 12877 chars of text
# INFO for                    xml:CVDR619890                   - Fragments_XML_CVDR gave 28700 chars of text
# INFO for                    xml:CVDR690119                   - Fragments_XML_CVDR gave 5446 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:KTGEMM:1997:AG2194 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2009/06/16/kst/kst-21501-33-231/kst-21501-33-231.xml - Fragments_XML_BUS_Kamer gave 16174 chars of text
# ...
# INFO for                   html:CVDR703524                   - Fragments_HTML_CVDR gave 71222 chars of text
# INFO for   bus:/2013/03/20/kst/kst-33465-7/kst-33465-7.xml   - Fragments_XML_BUS_Kamer gave 5035 chars of text
# INFO for                   html:CVDR200721                   - Fragments_HTML_CVDR gave 67102 chars of text
# INFO for  bus:/2009/01/08/kst/kst-24557-93/kst-24557-93.xml  - Fragments_XML_BUS_Kamer gave 27831 chars of text
# INFO for    bus:/2020/09/30/blg/blg-948220/blg-948220.pdf    - Fragments_PDF_Fallback gave 5191 chars of text
# WARN for  bus:/2023/01/06/stcrt/stcrt-2023-732/stcrt-2023-732.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for  bus:/2016/04/25/wsb/wsb-2016-3123/wsb-2016-3123.xml - Fragments_XML_OP_Wsb gave 706 chars of text
# WARN for  bus:/2021/03/05/stcrt/stcrt-2021-11689/stcrt-2021-11689.pdf - Fragments_PDF_Fallback gave 0 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBOBR:2015:945 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2021/10/27/gmb/gmb-2021-372659/gmb-2021-372659.html.zip - Fragments_HTML_OP_Gmb gave 20343 chars of text
# INFO for                    html:CVDR35358                   - Fragments_HTML_CVDR gave 172059 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBBRE:2010:2054 - no output from splitter Fragments_XML_Rechtspraak
# INFO for  bus:/2015/06/10/prb/prb-2015-2901/prb-2015-2901.xml - Fragments_XML_OP_Prb gave 1227 chars of text
# INFO for  bus:/2013/02/19/stcrt/stcrt-2013-4153/stcrt-2013-4153.xml - Fragments_XML_OP_Stcrt gave 2203 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:OGHNAA:2009:BJ5689 - Fragments_XML_Rechtspraak gave 5891 chars of text
# INFO for  bus:/2018/12/21/kst/kst-35000-A-80/kst-35000-A-80.html.zip - Fragments_HTML_BUS_kamer gave 535681 chars of text
# INFO for                    xml:CVDR641965                   - Fragments_XML_CVDR gave 38064 chars of text
# WARN for  bus:/2019/12/12/stcrt/stcrt-2019-68643/stcrt-2019-68643.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                   xml:BWBR0013029                   - Fragments_XML_BWB gave 3825 chars of text
# INFO for                   html:CVDR681134                   - Fragments_HTML_CVDR gave 108478 chars of text
# WARN for  bus:/2016/03/18/stcrt/stcrt-2016-14781/stcrt-2016-14781.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for                   html:CVDR248862                   - Fragments_HTML_CVDR gave 100201 chars of text
# INFO for  bus:/2024/02/02/gmb/gmb-2024-52243/gmb-2024-52243.html.zip - Fragments_HTML_OP_Gmb gave 11514 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBOVE:2014:502 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR689567                   - Fragments_XML_CVDR gave 8364 chars of text
# INFO for                   xml:BWBR0002236                   - Fragments_XML_BWB gave 1174 chars of text
# INFO for                    xml:CVDR609665                   - Fragments_XML_CVDR gave 14628 chars of text
# INFO for                   html:CVDR232941                   - Fragments_HTML_CVDR gave 4332 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHSGR:2012:BX3973 - Fragments_XML_Rechtspraak gave 8658 chars of text
# INFO for                   xml:BWBR0006571                   - Fragments_XML_BWB gave 1217 chars of text
# WARN for  bus:/2018/10/24/stcrt/stcrt-2018-59311/stcrt-2018-59311.xml - no output from splitter Fragments_XML_OP_Stcrt
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBOBR:2023:5684 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  bus:/2008/06/27/kst/kst-31305-44/kst-31305-44.html.zip - no splitter says it applies  (under threshold 1500)
# INFO for  bus:/2023/03/03/gmb/gmb-2023-93849/gmb-2023-93849.xml - Fragments_XML_OP_Gmb gave 4136 chars of text
# INFO for                   xml:BWBR0041638                   - Fragments_XML_BWB gave 12695 chars of text
# INFO for                   xml:BWBR0041877                   - Fragments_XML_BWB gave 5694 chars of text
# INFO for                   xml:BWBR0004900                   - Fragments_XML_BWB gave 3633 chars of text
# INFO for                   html:CVDR651641                   - Fragments_HTML_CVDR gave 177042 chars of text
# INFO for                    html:CVDR8083                    - Fragments_HTML_CVDR gave 619727 chars of text
# INFO for                   xml:BWBR0049178                   - Fragments_XML_BWB gave 19758 chars of text
# WARN for  bus:/2023/01/31/stcrt/stcrt-2023-4082/stcrt-2023-4082.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for  bus:/2015/11/19/gmb/gmb-2015-109761/gmb-2015-109761.html.zip - Fragments_HTML_OP_Gmb gave 13659 chars of text
# INFO for  bus:/2017/11/23/kst/kst-22112-2431/kst-22112-2431.html.zip - Fragments_HTML_BUS_kamer gave 657 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHARL:2020:11211 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    xml:CVDR195528                   - Fragments_XML_CVDR gave 6500 chars of text
# INFO for                   html:CVDR632463                   - Fragments_HTML_CVDR gave 941624 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBZUT:2009:330 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   html:CVDR141721                   - Fragments_HTML_CVDR gave 202800 chars of text
# INFO for                   html:CVDR107407                   - Fragments_HTML_CVDR gave 54322 chars of text
# INFO for                    xml:CVDR135780                   - Fragments_XML_CVDR gave 32723 chars of text
# INFO for  bus:/2016/10/04/gmb/gmb-2016-135768/gmb-2016-135768.xml - Fragments_XML_OP_Gmb gave 651 chars of text
# INFO for                   html:CVDR706032                   - Fragments_HTML_CVDR gave 76926 chars of text
# INFO for                   html:CVDR326186                   - Fragments_HTML_CVDR gave 777097 chars of text
# INFO for  bus:/2023/09/05/gmb/gmb-2023-383532/gmb-2023-383532.html.zip - Fragments_HTML_OP_Gmb gave 13055 chars of text
# WARN for  bus:/2007/11/29/kst/kst-31052-6/kst-31052-6.html.zip - no splitter says it applies  (under threshold 1500)
# INFO for  bus:/2022/05/06/stcrt/stcrt-2022-11921/stcrt-2022-11921.xml - Fragments_XML_OP_Stcrt gave 60014 chars of text
# INFO for                   html:CVDR392472                   - Fragments_HTML_CVDR gave 329358 chars of text
# INFO for                    xml:CVDR678514                   - Fragments_XML_CVDR gave 18566 chars of text
# INFO for  bus:/2011/07/21/h/h-tk-20102011-95-23/h-tk-20102011-95-23.xml - Fragments_XML_OP_Handelingen gave 1221 chars of text
# INFO for                   html:CVDR165174                   - Fragments_HTML_CVDR gave 25662 chars of text
# INFO for                   xml:BWBR0021912                   - Fragments_XML_BWB gave 25765 chars of text
# INFO for                   xml:BWBR0009676                   - Fragments_XML_BWB gave 1244 chars of text
# INFO for                   html:CVDR634161                   - Fragments_HTML_CVDR gave 114748 chars of text
# INFO for                    xml:CVDR310588                   - Fragments_XML_CVDR gave 10052 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:PHR:2022:1035 - Fragments_XML_Rechtspraak gave 29539 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBAMS:2015:10188 - Fragments_XML_Rechtspraak gave 28086 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RVS:2008:2448 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                     xml:CVDR5856                    - Fragments_XML_CVDR gave 5139 chars of text
# INFO for                   html:CVDR326561                   - Fragments_HTML_CVDR gave 7266 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:GHSHE:2012:5719 - Fragments_XML_Rechtspraak gave 42620 chars of text
# INFO for                    xml:CVDR329378                   - Fragments_XML_CVDR gave 40083 chars of text
# INFO for  bus:/2023/10/11/gmb/gmb-2023-433383/gmb-2023-433383.html.zip - Fragments_HTML_OP_Gmb gave 14620 chars of text
# INFO for                    xml:CVDR646119                   - Fragments_XML_CVDR gave 7234 chars of text
# INFO for                    xml:CVDR362490                   - Fragments_XML_CVDR gave 15431 chars of text
# INFO for                    xml:CVDR644705                   - Fragments_XML_CVDR gave 37214 chars of text
# INFO for                   xml:BWBR0044199                   - Fragments_XML_BWB gave 3047 chars of text
# WARN for                    xml:CVDR22435                    - Fragments_XML_CVDR gave 88 chars of text
# INFO for                   xml:BWBR0042852                   - Fragments_XML_BWB gave 7182 chars of text
# WARN for  bus:/2019/03/27/kv/kv-tk-2019Z05987/kv-tk-2019Z05987.html.zip - no output from splitter Fragments_HTML_BUS_kamer
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBARN:2010:BL6501 - Fragments_XML_Rechtspraak gave 22467 chars of text
# INFO for  bus:/2023/03/17/kst/kst-32793-686/kst-32793-686.html.zip - Fragments_HTML_BUS_kamer gave 223 chars of text
# INFO for  bus:/2024/02/09/gmb/gmb-2024-64190/gmb-2024-64190.html.zip - Fragments_HTML_OP_Gmb gave 22062 chars of text
# INFO for                    xml:CVDR55733                    - Fragments_XML_CVDR gave 7586 chars of text
# INFO for  bus:/2019/05/31/nds/nds-tk-2019D21478/nds-tk-2019D21478.xml - Fragments_XML_BUS_Kamer gave 665 chars of text
# WARN for  bus:/2017/11/09/stb/stb-2017-406/stb-2017-406.html.zip - no output from splitter Fragments_HTML_OP_Stb
# INFO for  bus:/2023/10/18/kst/kst-36410-XIII-77/kst-36410-XIII-77.html.zip - Fragments_HTML_BUS_kamer gave 1404 chars of text
# INFO for                   xml:BWBR0005464                   - Fragments_XML_BWB gave 6328 chars of text
# INFO for                   xml:BWBR0004695                   - Fragments_XML_BWB gave 632 chars of text
# INFO for                   html:CVDR333601                   - Fragments_HTML_CVDR gave 10992 chars of text
# INFO for  bus:/2014/05/27/stcrt/stcrt-2014-14659/stcrt-2014-14659.xml - Fragments_XML_OP_Stcrt gave 2085 chars of text
# INFO for  bus:/2014/12/23/wsb/wsb-2014-8791/wsb-2014-8791.xml - Fragments_XML_OP_Wsb gave 3603 chars of text
# INFO for                   html:CVDR615596                   - Fragments_HTML_CVDR gave 2346343 chars of text
# INFO for  bus:/2022/02/02/kst/kst-31322-D/kst-31322-D.html.zip - Fragments_HTML_BUS_kamer gave 5745 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:CRVB:1992:ZB2154 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBHAA:2010:2121 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                   xml:BWBR0008019                   - Fragments_XML_BWB gave 5932 chars of text
# INFO for  bus:/2016/08/30/gmb/gmb-2016-119346/gmb-2016-119346.html.zip - Fragments_HTML_OP_Gmb gave 9680 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBMAA:2005:977 - no output from splitter Fragments_XML_Rechtspraak
# WARN for  bus:/2021/09/07/stcrt/stcrt-2021-40608/stcrt-2021-40608.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for  bus:/2019/06/26/gmb/gmb-2019-152629/gmb-2019-152629.xml - Fragments_XML_OP_Gmb gave 122 chars of text
# INFO for                    xml:CVDR78122                    - Fragments_XML_CVDR gave 7689 chars of text
# INFO for                   xml:BWBR0004952                   - Fragments_XML_BWB gave 8395 chars of text
# INFO for  bus:/2016/03/17/wsb/wsb-2016-1949/wsb-2016-1949.xml - Fragments_XML_OP_Wsb gave 2309 chars of text
# INFO for  bus:/2017/04/25/stcrt/stcrt-2017-24428/stcrt-2017-24428.xml - Fragments_XML_OP_Stcrt gave 912 chars of text
# INFO for                   xml:BWBR0010250                   - Fragments_XML_BWB gave 499 chars of text
# INFO for  bus:/2021/07/06/nds/nds-tk-2021D20315/nds-tk-2021D20315.xml - Fragments_XML_BUS_Kamer gave 19042 chars of text
# INFO for                   xml:BWBR0034420                   - Fragments_XML_BWB gave 6885 chars of text
# INFO for  bus:/2017/12/07/kst/kst-21501-32-1071/kst-21501-32-1071.html.zip - Fragments_HTML_BUS_kamer gave 1422 chars of text
# WARN for  bus:/2022/07/22/stcrt/stcrt-2022-19733/stcrt-2022-19733.pdf - Fragments_PDF_Fallback gave 0 chars of text
# INFO for  bus:/2016/11/25/wsb/wsb-2016-9475/wsb-2016-9475.xml - Fragments_XML_OP_Wsb gave 2475 chars of text
# INFO for                    xml:CVDR629149                   - Fragments_XML_CVDR gave 7130 chars of text
# INFO for                   xml:BWBR0014404                   - Fragments_XML_BWB gave 10293 chars of text
# INFO for                   xml:BWBR0009115                   - Fragments_XML_BWB gave 8099 chars of text
# INFO for  bus:/2024/02/01/gmb/gmb-2024-51728/gmb-2024-51728.xml - Fragments_XML_OP_Gmb gave 755 chars of text
# WARN for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:HR:1998:BI5812 - no output from splitter Fragments_XML_Rechtspraak
# INFO for                    html:CVDR37353                   - Fragments_HTML_CVDR gave 7294 chars of text
# INFO for  bus:/2018/02/09/stcrt/stcrt-2018-7408/stcrt-2018-7408.xml - Fragments_XML_OP_Stcrt gave 2808 chars of text
# INFO for                         3col                        - Fragments_PDF_Fallback gave 6783 chars of text
# INFO for  bus:/2020/08/21/gmb/gmb-2020-214050/gmb-2020-214050.html.zip - Fragments_HTML_OP_Gmb gave 27608 chars of text
# INFO for                    xml:CVDR696654                   - Fragments_XML_CVDR gave 1464 chars of text
# INFO for  bus:/2022/11/02/kst/kst-36067-54/kst-36067-54.html.zip - Fragments_HTML_BUS_kamer gave 32333 chars of text
# INFO for  bus:/2020/04/22/gmb/gmb-2020-103591/gmb-2020-103591.html.zip - Fragments_HTML_OP_Gmb gave 14556 chars of text
# INFO for                   html:CVDR606918                   - Fragments_HTML_CVDR gave 133333 chars of text
# INFO for    bus:/2020/08/11/blg/blg-942911/blg-942911.pdf    - Fragments_PDF_Fallback gave 27275 chars of text
# INFO for  bus:/2021/09/07/gmb/gmb-2021-304437/gmb-2021-304437.html.zip - Fragments_HTML_OP_Gmb gave 26645 chars of text
# INFO for  bus:/2006/03/01/kst/kst-29764-46/kst-29764-46.xml  - Fragments_XML_BUS_Kamer gave 29681 chars of text
# INFO for  bus:/2013/06/06/kst/kst-33638-2-n1/kst-33638-2-n1.xml - Fragments_XML_BUS_Kamer gave 6294 chars of text
# INFO for  bus:/2017/04/26/prb/prb-2017-1877/prb-2017-1877.html.zip - Fragments_HTML_OP_Prb gave 5817 chars of text
# INFO for                   xml:BWBR0017873                   - Fragments_XML_BWB gave 3159 chars of text
# INFO for                   html:CVDR605111                   - Fragments_HTML_CVDR gave 591030 chars of text
# INFO for                   xml:BWBR0019249                   - Fragments_XML_BWB gave 1319 chars of text
# INFO for  https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBZWB:2023:1034 - Fragments_XML_Rechtspraak gave 12884 chars of text
# INFO for     bus:/2009/09/18/blg/blg-31825/blg-31825.pdf     - Fragments_PDF_Fallback gave 12954 chars of text
# INFO for                    xml:CVDR649911                   - Fragments_XML_CVDR gave 43778 chars of text
# INFO for  bus:/2015/10/08/gmb/gmb-2015-93429/gmb-2015-93429.html.zip - Fragments_HTML_OP_Gmb gave 12523 chars of text
# INFO for  bus:/2020/01/15/wsb/wsb-2020-308/wsb-2020-308.html.zip - Fragments_HTML_OP_Wsb gave 27844 chars of text
# INFO for                   html:CVDR262629                   - Fragments_HTML_CVDR gave 91678 chars of text
# INFO for  bus:/2010/11/18/stcrt/stcrt-2010-18304/stcrt-2010-18304.xml - Fragments_XML_OP_Stcrt gave 1540 chars of text
# INFO for                   xml:BWBR0004633                   - Fragments_XML_BWB gave 13424 chars of text
