# %% [markdown]
# Continuing from the rechtspraak datacollection notebook in our datacollect repository...

# %% [markdown]
# ## What does the data XML look like, and what can I easily do with it?

# %%
import collections
import pprint

import wetsuite.datasets
import wetsuite.helpers.net
import wetsuite.helpers.localdata
import wetsuite.helpers.etree
import wetsuite.datacollect.rechtspraaknl

# %%
rechtspraak_sample = wetsuite.datasets.load('rechtspraaknl-sample-xml')

#if False: # let's show have a cherry-picked example
#xmlbytes = wetsuite.helpers.net.download('https://data.rechtspraak.nl/uitspraken/content?id=ECLI:NL:RBZWB:2020:5807') 
#else: # or a random example   (note that a lot of them will be without text, that's normal)
_, xmlbytes = rechtspraak_sample.data.random_choice()

display( wetsuite.helpers.etree.debug_color( xmlbytes ) ) # print indented and colored, as an indication what the XML looks like
# Out:
# <style>pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# .highlight .hll { background-color: #ffffcc }
# .highlight { background: #f8f8f8; }
# .highlight .c { color: #3D7B7B; font-style: italic } /* Comment */
# .highlight .err { border: 1px solid #FF0000 } /* Error */
# .highlight .k { color: #008000; font-weight: bold } /* Keyword */
# .highlight .o { color: #666666 } /* Operator */
# .highlight .ch { color: #3D7B7B; font-style: italic } /* Comment.Hashbang */
# .highlight .cm { color: #3D7B7B; font-style: italic } /* Comment.Multiline */
# .highlight .cp { color: #9C6500 } /* Comment.Preproc */
# .highlight .cpf { color: #3D7B7B; font-style: italic } /* Comment.PreprocFile */
# .highlight .c1 { color: #3D7B7B; font-style: italic } /* Comment.Single */
# .highlight .cs { color: #3D7B7B; font-style: italic } /* Comment.Special */
# .highlight .gd { color: #A00000 } /* Generic.Deleted */
# .highlight .ge { font-style: italic } /* Generic.Emph */
# .highlight .gr { color: #E40000 } /* Generic.Error */
# .highlight .gh { color: #000080; font-weight: bold } /* Generic.Heading */
# .highlight .gi { color: #008400 } /* Generic.Inserted */
# .highlight .go { color: #717171 } /* Generic.Output */
# .highlight .gp { color: #000080; font-weight: bold } /* Generic.Prompt */
# .highlight .gs { font-weight: bold } /* Generic.Strong */
# .highlight .gu { color: #800080; font-weight: bold } /* Generic.Subheading */
# .highlight .gt { color: #0044DD } /* Generic.Traceback */
# .highlight .kc { color: #008000; font-weight: bold } /* Keyword.Constant */
# .highlight .kd { color: #008000; font-weight: bold } /* Keyword.Declaration */
# .highlight .kn { color: #008000; font-weight: bold } /* Keyword.Namespace */
# .highlight .kp { color: #008000 } /* Keyword.Pseudo */
# .highlight .kr { color: #008000; font-weight: bold } /* Keyword.Reserved */
# .highlight .kt { color: #B00040 } /* Keyword.Type */
# .highlight .m { color: #666666 } /* Literal.Number */
# .highlight .s { color: #BA2121 } /* Literal.String */
# .highlight .na { color: #687822 } /* Name.Attribute */
# .highlight .nb { color: #008000 } /* Name.Builtin */
# .highlight .nc { color: #0000FF; font-weight: bold } /* Name.Class */
# .highlight .no { color: #880000 } /* Name.Constant */
# .highlight .nd { color: #AA22FF } /* Name.Decorator */
# .highlight .ni { color: #717171; font-weight: bold } /* Name.Entity */
# .highlight .ne { color: #CB3F38; font-weight: bold } /* Name.Exception */
# .highlight .nf { color: #0000FF } /* Name.Function */
# .highlight .nl { color: #767600 } /* Name.Label */
# .highlight .nn { color: #0000FF; font-weight: bold } /* Name.Namespace */
# .highlight .nt { color: #008000; font-weight: bold } /* Name.Tag */
# .highlight .nv { color: #19177C } /* Name.Variable */
# .highlight .ow { color: #AA22FF; font-weight: bold } /* Operator.Word */
# .highlight .w { color: #bbbbbb } /* Text.Whitespace */
# .highlight .mb { color: #666666 } /* Literal.Number.Bin */
# .highlight .mf { color: #666666 } /* Literal.Number.Float */
# .highlight .mh { color: #666666 } /* Literal.Number.Hex */
# .highlight .mi { color: #666666 } /* Literal.Number.Integer */
# .highlight .mo { color: #666666 } /* Literal.Number.Oct */
# .highlight .sa { color: #BA2121 } /* Literal.String.Affix */
# .highlight .sb { color: #BA2121 } /* Literal.String.Backtick */
# .highlight .sc { color: #BA2121 } /* Literal.String.Char */
# .highlight .dl { color: #BA2121 } /* Literal.String.Delimiter */
# .highlight .sd { color: #BA2121; font-style: italic } /* Literal.String.Doc */
# .highlight .s2 { color: #BA2121 } /* Literal.String.Double */
# .highlight .se { color: #AA5D1F; font-weight: bold } /* Literal.String.Escape */
# .highlight .sh { color: #BA2121 } /* Literal.String.Heredoc */
# .highlight .si { color: #A45A77; font-weight: bold } /* Literal.String.Interpol */
# .highlight .sx { color: #008000 } /* Literal.String.Other */
# .highlight .sr { color: #A45A77 } /* Literal.String.Regex */
# .highlight .s1 { color: #BA2121 } /* Literal.String.Single */
# .highlight .ss { color: #19177C } /* Literal.String.Symbol */
# .highlight .bp { color: #008000 } /* Name.Builtin.Pseudo */
# .highlight .fm { color: #0000FF } /* Name.Function.Magic */
# .highlight .vc { color: #19177C } /* Name.Variable.Class */
# .highlight .vg { color: #19177C } /* Name.Variable.Global */
# .highlight .vi { color: #19177C } /* Name.Variable.Instance */
# .highlight .vm { color: #19177C } /* Name.Variable.Magic */
# .highlight .il { color: #666666 } /* Literal.Number.Integer.Long */
# * { background-color: transparent !important; color:inherit };</style><div class="highlight"><pre><span></span><span class="nt">&lt;open-rechtspraak&gt;</span>
#   <span class="nt">&lt;RDF&gt;</span>
#     <span class="nt">&lt;Description&gt;</span>
#       <span class="nt">&lt;identifier&gt;</span>ECLI:NL:RBROT:2024:3270<span class="nt">&lt;/identifier&gt;</span>
#       <span class="nt">&lt;format&gt;</span>text/xml<span class="nt">&lt;/format&gt;</span>
#       <span class="nt">&lt;accessRights&gt;</span>public<span class="nt">&lt;/accessRights&gt;</span>
#       <span class="nt">&lt;modified&gt;</span>2024-04-23T16:16:16<span class="nt">&lt;/modified&gt;</span>
#       <span class="nt">&lt;issued</span> <span class="na">label=</span><span class="s">&quot;Publicatiedatum&quot;</span><span class="nt">&gt;</span>2024-04-15<span class="nt">&lt;/issued&gt;</span>
#       <span class="nt">&lt;publisher</span> <span class="na">resourceIdentifier=</span><span class="s">&quot;http://rechtspraak.nl/&quot;</span><span class="nt">&gt;</span>Raad voor de Rechtspraak<span class="nt">&lt;/publisher&gt;</span>
#       <span class="nt">&lt;language&gt;</span>nl<span class="nt">&lt;/language&gt;</span>
#       <span class="nt">&lt;creator</span> <span class="na">resourceIdentifier=</span><span class="s">&quot;http://standaarden.overheid.nl/owms/terms/Rechtbank_Rotterdam&quot;</span> <span class="na">scheme=</span><span class="s">&quot;overheid.RechterlijkeMacht&quot;</span> <span class="na">label=</span><span class="s">&quot;Instantie&quot;</span><span class="nt">&gt;</span>Rechtbank Rotterdam<span class="nt">&lt;/creator&gt;</span>
#       <span class="nt">&lt;date</span> <span class="na">label=</span><span class="s">&quot;Uitspraakdatum&quot;</span><span class="nt">&gt;</span>2024-03-27<span class="nt">&lt;/date&gt;</span>
#       <span class="nt">&lt;zaaknummer</span> <span class="na">label=</span><span class="s">&quot;Zaaknr&quot;</span><span class="nt">&gt;</span>C/10/674554 / FA RK 24-1553<span class="nt">&lt;/zaaknummer&gt;</span>
#       <span class="nt">&lt;type</span> <span class="na">resourceIdentifier=</span><span class="s">&quot;http://psi.rechtspraak.nl/uitspraak&quot;</span> <span class="na">language=</span><span class="s">&quot;nl&quot;</span><span class="nt">&gt;</span>Uitspraak<span class="nt">&lt;/type&gt;</span>
#       <span class="nt">&lt;procedure</span> <span class="na">resourceIdentifier=</span><span class="s">&quot;http://psi.rechtspraak.nl/procedure#mondelingeUitspraak&quot;</span> <span class="na">language=</span><span class="s">&quot;nl&quot;</span> <span class="na">label=</span><span class="s">&quot;Procedure&quot;</span><span class="nt">&gt;</span>Mondelinge uitspraak<span class="nt">&lt;/procedure&gt;</span>
#       <span class="nt">&lt;coverage&gt;</span>NL<span class="nt">&lt;/coverage&gt;</span>
#       <span class="nt">&lt;spatial</span> <span class="na">label=</span><span class="s">&quot;Zittingsplaats&quot;</span><span class="nt">&gt;</span>Rotterdam<span class="nt">&lt;/spatial&gt;</span>
#       <span class="nt">&lt;subject</span> <span class="na">resourceIdentifier=</span><span class="s">&quot;http://psi.rechtspraak.nl/rec

# %% [markdown]
# It seems
# * there are specific ideas about what should be in what structure (e.g. para in parablock in paragroup,  overview stuff in uitspraak.info)
#
# But at the same time, that structure is missing from a lot of documents.
#
# TODO: see if that's a thing over time.

# %%
pprint.pprint(   wetsuite.datacollect.rechtspraaknl.parse_content( example_tree )   )
# Out:
# {'bodytext': '\n'
#              '\n'
#              '1\n'
#              'Procesverloop\n'
#              '\n'
#              '1.1.\n'
#              '\n'
#              'Het verloop van de procedure blijkt uit het verzoekschrift van '
#              'het CIZ, ingekomen ter griffie op 28 februari 2024.\n'
#              'Bij het verzoekschrift zijn de volgende bijlagen gevoegd:\n'
#              '\n'
#              'het indicatiebesluit op grond van artikel 3.2.3 van de Wet '
#              'langdurige zorg van 8 februari 2024;\n'
#              '\n'
#              'de medische verklaring, opgesteld en ondertekend door [naam 1], '
#              'specialist ouderengeneeskunde, van 19 februari 2024;\n'
#              '\n'
#              'de aanvraag voor een rechterlijke machtiging van 23 februari '
#              '2024.\n'
#              '\n'
#              '1.2.\n'
#              'Op 19 maart 2024 is de mondelinge behandeling aangehouden omdat '
#              '[naam 2], casemanager bij Careyn, niet aanwezig was. Gebleken is '
#              'dat [naam 2] niet langer meer werkzaam is bij Careyn. Hierdoor '
#              'kon het verzoek niet worden toegelicht en daarom is de '
#              'mondelinge behandeling aangehouden. Hiervan is proces-verbaal '
#              'opgemaakt.\n'
#              '\n'
#              '1.3.\n'
#              'De voortgezette mondelinge behandeling van het verzoek heeft '
#              'plaatsgevonden op 27 maart 2024. Bij die gelegenheid zijn '
#              'verschenen: \n'
#              '\n'
#              'betrokkene met advocaat mr. T. Gümüs namens de hierboven '
#              'genoemde advocaat;\n'
#              '\n'
#              '            [naam 3], casemanager, verbonden aan Careyn;\n'
#              '\n'
#              '            [naam 4], maatschappelijk werkster, verbonden aan '
#              'Humanitas;\n'
#              '\n'
#              '            [naam 5], de echtgenote van betrokkene.\n'
#              '\n'
#              '2\n'
#              'Beoordeling\n'
#              '\n'
#              '2.1.\n'
#              'Uit de overgelegde stukken en de mondelinge behandeling is '
#              'gebleken dat betrokkene lijdt aan een psychogeriatrische '
#              'aandoening, te weten gemengde dementie, Alzheimer en vasculaire '
#              'dementie.\n'
#              '\n'
#              '2.2.\n'
#              'Het gedrag van betrokkene leidt als gevolg van deze '
#              'psychogeriatrische aandoening tot ernstig nadeel. Het ernstig '
#              'nadeel is gelegen in het bestaan van of het aanzienlijk risico '
#              'op ernstig lichamelijk letsel, ernstige psychische schade, '
#              'ernstige verwaarlozing en maatschappelijke teloorgang. '
#              'Betrokkene woont thuis met zijn echtgenote en hun kat in een '
#              'relatief kleine ruimte. Betrokkene raakt gefrustreerd als dingen '
#              'niet gaan zoals hij wil of als hij overprikkeld raakt. Dit '
#              'reageert hij af op zijn echtgenote en de kat. Betrokkene '
#              'barricadeert de deur, loopt boos achter zijn echtgenote aan en '
#              'in het verleden heeft hij haar ook fysiek mishandeld en '
#              'bijvoorbeeld de telefoon kapotgemaakt. Ook heeft betrokkene op '
#              'de nek van zijn kat gestaan uit frustratie. De echtgenote van '
#              'betrokkene draagt vrijwel volledige zorg voor hem. Betrokkene is '
#              'volgens de casemanager niet zelfstandig in staat zich staande te '
#              'houden. Wanneer de echtgenote kortdurend het huis uit is om '
#              'boodschappen te doen, wordt betrokkene boos omdat hij vergeten '
#              'is waar zij naartoe is. Betrokkene wordt meerdere malen per '
#              'nacht wakker en houdt hierbij zijn echtgenote uit haar slaap. De '
#              'echtgenote heeft verklaard dat zij alles voor betrokkene moet '
#              'neerzetten en klaarmaken, waaronder bijvoorbeeld zijn '
#              'tandenborstel met tandpasta klaarleggen en ook zijn kleding. De '
#              'echtgenote is constant bezig met de zorg voor betrokkene. '
#              'Hierdoor is zij overbelast en zij heeft geen tijd om '
#              'activiteiten voor haarzelf te ondernemen. \n'
#              '\n'
#              '2.3.\n'
#              'De opname en het verblijf zijn noodzakelijk en geschikt om het '
#              'ernstig nadeel te voorkomen of af te wenden.\n'
#              '\n'
#              '2.4.\n'
#              '\n'
#              'De advocaat bepleit namens betrokkene afwijzing. Betrokkene wil '
#              'thuis blijven wonen. De advocaat stelt dat, gelet op het '
#              'ziektebeeld en het verloop hiervan, het te verwachten is dat een '
#              'opname op enig moment zal volgen, maar dat dit niet het moment '
#              'is. \n'
#              'Uit de stukken blijkt dat betrokkene in november 2023 met '
#              'ontslag is gegaan nadat hij middels een (voortgezette) '
#              'inbewaringstelling was opgenomen. Er waren afspraken omtrent de '
#              'zorg gemaakt en betrokkene zou tevens niet het niveau voor een '
#              'verpleeghuis hebben gehad, aldus de zorgaanbieder destijds. De '
#              'casemanager heeft aangegeven dat de afspraken niet zijn '
#              'nagekomen. Het betrof afspraken over inname van pijnstilling en '
#              'zelfzorg met behulp van thuiszorg en dagbesteding.\n'
#              'De rechtbank oordeelt dat het altijd lastig te bepalen is wat '
#              'het juiste moment is. De spanning thuis tussen betrokkene en '
#              'zijn echtgenote heeft een hoogtepunt bereikt. De echtgenote van '
#              'betrokkene draagt volledig de zorg en dit is uiterst belastend '
#              'voor haar, mede gelet op de verbale en fysieke agressie die zich '
#              'voordoet. Als er langer gewacht wordt, gaat het mis. De '
#              'rechtbank is van oordeel dat dit voorkomen dient te worden. Een '
#              'opname kan dit risico wegnemen en een crisissituatie voorkomen. '
#              'Een opname is momenteel dan ook noodzakelijk. Er zijn geen '
#              'minder ingrijpende mogelijkheden om het ernstig nadeel te '
#              'voorkomen of af te wenden.\n'
#              '\n'
#              '2.5.\n'
#              'Gebleken is dat betrokkene zich verzet tegen de opname en het '
#              'verblijf. Betrokkene wil niet worden opgenomen. Hij wil thuis '
#              'wonen met zijn kat en zijn echtgenote. Tevens weigert betrokkene '
#              'zorg. Hij weigert zijn pijnstillende medicatie in te nemen, '
#              'staat geen thuiszorg toe en weigert naar de dagbesteding te '
#              'gaan. De casemanager heeft verklaard dat er geprobeerd is '
#              'betrokkene te stimuleren en enthousiasmeren voor onder andere de '
#              'dagbesteding, en dat hoewel betrokkene hier initieel voor open '
#              'stond, dit zeer snel is stopgezet omdat het niet verliep zoals '
#              'betrokkene dat wilde.\n'
#              '\n'
#              '2.6.\n'
#              'Gelet op het voorgaande is de rechtbank van oordeel dat is '
#              'voldaan aan de criteria voor een rechterlijke machtiging tot '
#              'opname en verblijf als bedoeld in de Wzd. De machtiging zal '
#              'worden verleend voor de verzochte duur van zes maanden.\n'
#              '\n'
#              '3\n'
#              'Beslissing\n'
#              '\n'
#              'De rechtbank:\n'
#              '\n'
#              '3.1.\n'
#              'verleent een machtiging tot opname en verblijf ten aanzien van '
#              '[betrokkene] voornoemd;\n'
#              '\n'
#              '3.2.\n'
#              'bepaalt dat deze machtiging geldt tot en met 27 september 2024;\n'
#              '\n'
#              '3.3.\n'
#              'wijst af het meer of anders verzochte.\n'
#              '\n'
#              'Deze beschikking is op 27 maart 2024 mondeling gegeven door mr. '
#              'S.L. Raphael, rechter, in tegenwoordigheid van A.M.M. '
#              'Wassenberg, griffier, en op 10 april 2024 schriftelijk '
#              'uitgewerkt en getekend.\n'
#              '\n'
#              '!NIET VERWIJDEREN, PLAATS VOOR HANDTEKENING SECRETARIS!!NIET '
#              'VERWIJDEREN, PLAATS VOOR HANDTEKENING SECRETARIS!\n'
#              '\n'
#              '!NIET VERWIJDEREN, PLAATS VOOR HANDTEKENING RECHTER!!NIET '
#              'VERWIJDEREN, PLAATS VOOR HANDTEKENING RECHTER!\n'
#              '\n'
#              '!NIET VERWIJDEREN, PLAATS VOOR STEMPELS!!NIET VERWIJDEREN, '
#              'PLAATS VOOR STEMPELS!\n'
#              '\n'
#              'Tegen deze beschikking staat het rechtsmiddel van cassatie '
#              'open.\n'
#              '\n',
#  'creator': 'Rechtbank Rotterdam',
#  'date': '2024-03-27',
#  'identifier': 'ECLI:NL:RBROT:2024:3270',
#  'inhoudsindicatie': 'Wet zorg en dwang (Wzd), rechterlijke machtiging tot '
#                      'opname en verblijf, art. 24 Wzd, toegewezen, langer '
#                      'wachten met opname zal betekenen dat de zaak escaleert.',
#  'issued': '2024-04-15',
#  'modified': '2024-04-23T16:16:16',
#  'publisher': 'Raad voor de Rechtspraak',
#  'spatial': 'Rotterdam',
#  'subject': 'Civiel recht; Personen- en familierecht',
#  'type': 'Uitspraak',
#  'zaaknummer': 'C/10/674554 / FA RK 24-1553'}

# %% [markdown]
# ## Inspect the fetched documents, looking for its text
#
# Like in the exploration of the BWB and CVDR data, let's point out there are [schemas](https://www.rechtspraak.nl/SiteCollectionDocuments/Schema-Open-Data-voor-de-Rechtspraak.zip)
# to the text's structure, but we should take a look at how they're followed or not.
#
# And, regardless of that, of how we should flatten that text when we want to,
# which we do for this dataset.
#
# One of the things we do is counting paths, like in the [bwb_docstructure](koop_bwb_docstructure.ipynb) notebook.
#
# As of this writing, that has guided how rechtspraaknl.parse_content() is implemented, though this needs more work.

# %%
count_paths = collections.defaultdict(int)

for key, xmldoc_bytes in rechtspraak_sample.data.random_sample( 1000 ): # we want a small selection to get only a reasonable amount of things to review
    tree = wetsuite.helpers.etree.fromstring( xmldoc_bytes )
    tree = wetsuite.helpers.etree.strip_namespace( tree )

    #print(  )
    #print( '-----------------------------------' )
    #print( key )

    uitspraak = tree.find('uitspraak')
    conclusie = tree.find('conclusie')
    
    if uitspraak is not None:

        for path, count in wetsuite.helpers.etree.path_count( uitspraak ).items():
            count_paths[path] += count

        try:
            parsed = wetsuite.datacollect.rechtspraaknl.parse_content( tree )
            #print( parsed['bodytext'] )
        except Exception as e:
            print( 'ERROR', e )
            print( wetsuite.helpers.etree.tostring(uitspraak).decode('u8') )
            #raise

    elif conclusie is not None:
        for path, count in wetsuite.helpers.etree.path_count( conclusie ).items():
            count_paths[path] += count

        try:
            parsed = wetsuite.datacollect.rechtspraaknl.parse_content( tree )
            #print(   parsed['bodytext'] )
        except Exception as e:
            print( 'ERROR', e )
            print( wetsuite.helpers.etree.tostring(conclusie).decode('u8') )
            #raise

# %%
# Show those counted paths
path_count = list( count_paths.items() ) # will be  alist of (path, count)
path_count.sort( key=lambda x:x[0] ) # sort by path
for path, count in path_count:
    print('%7d   %s'%(count, path))
# Out:
#      21   conclusie
#       2   conclusie/bridgehead
#      13   conclusie/conclusie.info
#     179   conclusie/conclusie.info/para
#       3   conclusie/conclusie.info/para/emphasis
#     112   conclusie/conclusie.info/parablock
#     156   conclusie/conclusie.info/parablock/para
#      38   conclusie/conclusie.info/parablock/para/emphasis
#     370   conclusie/footnote
#     371   conclusie/footnote/para
#     169   conclusie/footnote/para/emphasis
#       1   conclusie/informaltable
#       1   conclusie/informaltable/tgroup
#       3   conclusie/informaltable/tgroup/colspec
#       1   conclusie/informaltable/tgroup/tbody
#       2   conclusie/informaltable/tgroup/tbody/row
#       6   conclusie/informaltable/tgroup/tbody/row/entry
#       6   conclusie/informaltable/tgroup/tbody/row/entry/para
#       3   conclusie/informaltable/tgroup/tbody/row/entry/para/emphasis
#       1   conclusie/orderedlist
#       2   conclusie/orderedlist/listitem
#       2   conclusie/orderedlist/listitem/para
#      68   conclusie/para
#      10   conclusie/para/emphasis
#       3   conclusie/para/footnote-ref
#     482   conclusie/parablock
#     623   conclusie/parablock/para
#     160   conclusie/parablock/para/emphasis
#      15   conclusie/paragroup
#       8   conclusie/paragroup/informaltable
#       8   conclusie/paragroup/informaltable/tgroup
#      37   conclusie/paragroup/informaltable/tgroup/colspec
#       8   conclusie/paragroup/informaltable/tgroup/tbody
#      67   conclusie/paragroup/informaltable/tgroup/tbody/row
#     316   conclusie/paragroup/informaltable/tgroup/tbody/row/entry
#     317   conclusie/paragroup/informaltable/tgroup/tbody/row/entry/para
#      30   conclusie/paragroup/informaltable/tgroup/tbody/row/entry/para/emphasis
#       2   conclusie/paragroup/nr
#       2   conclusie/paragroup/orderedlist
#       5   conclusie/paragroup/orderedlist/listitem
#       5   conclusie/paragroup/orderedlist/listitem/para
#     267   conclusie/paragroup/para
#      34   conclusie/paragroup/para/emphasis
#      42   conclusie/paragroup/para/footnote-ref
#     156   conclusie/paragroup/parablock
#     399   conclusie/paragroup/parablock/para
#      84   conclusie/paragroup/parablock/para/emphasis
#      15   conclusie/paragroup/parablock/para/footnote-ref
#       1   conclusie/paragroup/paragroup
#       1   conclusie/paragroup/paragroup/nr
#       1   conclusie/paragroup/paragroup/para
#       1   conclusie/paragroup/paragroup/parablock
#       6   conclusie/paragroup/paragroup/parablock/para
#      86   conclusie/section
#       5   conclusie/section/bridgehead
#       2   conclusie/section/informaltable
#       2   conclusie/section/informaltable/tgroup
#       5   conclusie/section/informaltable/tgroup/colspec
#       2   conclusie/section/informaltable/tgroup/tbody
#       8   conclusie/section/informaltable/tgroup/tbody/row
#      20   conclusie/section/informaltable/tgroup/tbody/row/entry
#      24   conclusie/section/informaltable/tgroup/tbody/row/entry/para
#       3   conclusie/section/informaltable/tgroup/tbody/row/entry/para/emphasis
#       1   conclusie/section/orderedlist
#       3   conclusie/section/orderedlist/listitem
#       3   conclusie/section/orderedlist/listitem/para
#     484   conclusie/section/para
#      12   conclusie/section/para/emphasis
#       4   conclusie/section/para/footnote-ref
#     433   conclusie/section/parablock
#     772   conclusie/section/parablock/para
#     135   conclusie/section/parablock/para/emphasis
#      10   conclusie/section/parablock/para/footnote-ref
#     559   conclusie/section/paragroup
#       2   conclusie/section/paragroup/informaltable
#       2   conclusie/section/paragroup/informaltable/tgroup
#       6   conclusie/section/paragroup/informaltable/tgroup/colspec
#       2   conclusie/section/paragroup/informaltable/tgroup/tbody
#       7   conclusie/section/paragroup/informaltable/tgroup/tbody/row
#      21   conclusie/section/paragroup/informaltable/tgroup/tbody/row/entry
#      22   conclusie/section/paragroup/informaltable/tgroup/tbody/row/entry/para
#       6   conclusie/section/paragroup/informaltable/tgroup/tbody/row/entry/para/emphasis
#       7   conclusie/section/paragroup/mediaobject
#       7   conclusie/section/paragroup/mediaobject/imageobject
#       7   conclusie/section/paragroup/mediaobject/imageobject/imagedata
#     556   conclusie/section/paragroup/nr
#    1132   conclusie/section/paragroup/para
#     143   conclusie/section/paragroup/para/emphasis
#     217   conclusie/section/paragroup/para/footnote-ref
#     677   conclusie/section/paragroup/parablock
#    1168   conclusie/section/paragroup/parablock/para
#     222   conclusie/section/paragroup/parablock/para/emphasis
#      76   conclusie/section/paragroup/parablock/para/footnote-ref
#       8   conclusie/section/paragroup/paragroup
#       8   conclusie/section/paragroup/paragroup/nr
#      34   conclusie/section/paragroup/paragroup/para
#       3   conclusie/section/paragroup/paragroup/para/emphasis
#       3   conclusie/section/paragroup/paragroup/para/footnote-ref
#      15   conclusie/section/paragroup/paragroup/parablock
#      30   conclusie/section/paragroup/paragroup/parablock/para
#       2   conclusie/section/paragroup/paragroup/parablock/para/emphasis
#      86   conclusie/section/title
#      71   conclusie/section/title/nr
#     979   uitspraak
#     122   uitspraak/bridgehead
#       2   uitspraak/bridgehead/nr
#    1711   uitspraak/footnote
#    1758   uitspraak/footnote/para
#     104   uitspraak/footnote/para/emphasis
#       2   uitspraak/informaltable
#       2   uitspraak/informaltable/tgroup
#      10   uitspraak/informaltable/tgroup/colspec
#       2   uitspraak/informaltable/tgroup/tbody
#       4   uitspraak/informaltable/tgroup/tbody/row
#      20   uitspraak/informaltable/tgroup/tbody/row/entry
#      20   uitspraak/informaltable/tgroup/tbody/row/entry/para
#       3   uitspraak/itemizedlist
#      11   uitspraak/itemizedlist/listitem
#      11   uitspraak/itemizedlist/listitem/para
#       6   uitspraak/mediaobject
#       6   uitspraak/mediaobject/imageobject
#       6   uitspraak/mediaobject/imageobject/imagedata
#       2   uitspraak/orderedlist
#       4   uitspraak/orderedlist/listitem
#       4   uitspraak/orderedlist/listitem/para
#     478   uitspraak/para
#     163   uitspraak/para/emphasis
#       8   uitspraak/para/footnote-ref
#      26   uitspraak/para/inlinemediaobject
#      26   uitspraak/para/inlinemediaobject/imageobject
#      26   uitspraak/para/inlinemediaobject/imageobject/imagedata
#     929   uitspraak/parablock
#    6299   uitspraak/parablock/para
#     138   uitspraak/parablock/para/emphasis
#       1   uitspraak/parablock/para/footnote-ref
#       2   uitspraak/paragroup
#       1   uitspraak/paragroup/informaltable
#       1   uitspraak/paragroup/informaltable/tgroup
#       3   uitspraak/paragroup/informaltable/tgroup/colspec
#       1   uitspraak/paragroup/informaltable/tgroup/tbody
#       7   uitspraak/paragroup/informaltable/tgroup/tbody/row
#      13   uitspraak/paragroup/informaltable/tgroup/tbody/row/entry
#      14   uitspraak/paragroup/informaltable/tgroup/tbody/row/entry/para
#       1   uitspraak/paragroup/itemizedlist
#       2   uitspraak/paragroup/itemizedlist/listitem
#       2   uitspraak/paragroup/itemizedlist/listitem/para
#       2   uitspraak/paragroup/itemizedlist/listitem/para/emphasis
#      42   uitspraak/paragroup/para
#      39   uitspraak/paragroup/parablock
#      63   uitspraak/paragroup/parablock/para
#      19   uitspraak/paragroup/parablock/para/emphasis
#    4989   uitspraak/section
#     187   uitspraak/section/bridgehead
#     153   uitspraak/section/informaltable
#     153   uitspraak/section/informaltable/tgroup
#     340   uitspraak/section/informaltable/tgroup/colspec
#     153   uitspraak/section/informaltable/tgroup/tbody
#     287   uitspraak/section/informaltable/tgroup/tbody/row
#     683   uitspraak/section/informaltable/tgroup/tbody/row/entry
#     793   uitspraak/section/informaltable/tgroup/tbody/row/entry/para
#      24   uitspraak/section/informaltable/tgroup/tbody/row/entry/para/emphasis
#     365   uitspraak/section/itemizedlist
#    1370   uitspraak/section/itemizedlist/listitem
#    1370   uitspraak/section/itemizedlist/listitem/para
#      51   uitspraak/section/itemizedlist/listitem/para/emphasis
#       1   uitspraak/section/itemizedlist/listitem/para/footnote-ref
#      79   uitspraak/section/mediaobject
#      79   uitspraak/section/mediaobject/imageobject
#      79   uitspraak/section/mediaobject/imageobject/imagedata
#      85   uitspraak/section/orderedlist
#     394   uitspraak/section/orderedlist/listitem
#     394   uitspraak/section/orderedlist/listitem/para
#      54   uitspraak/section/orderedlist/listitem/para/emphasis
#       1   uitspraak/section/orderedlist/listitem/para/footnote-ref
#   29927   uitspraak/section/para
#     461   uitspraak/section/para/emphasis
#     313   uitspraak/section/para/footnote-ref
#   11481   uitspraak/section/parablock
#   18841   uitspraak/section/parablock/para
#    4549   uitspraak/section/parablock/para/emphasis
#     172   uitspraak/section/parablock/para/footnote-ref
#       1   uitspraak/section/parablock/para/inlinemediaobject
#       1   uitspraak/section/parablock/para/inlinemediaobject/imageobject
#       1   uitspraak/section/parablock/para/inlinemediaobject/imageobject/imagedata
#   12007   uitspraak/section/paragroup
#      72   uitspraak/section/paragroup/informaltable
#      72   uitspraak/section/paragroup/informaltable/tgroup
#     294   uitspraak/section/paragroup/informaltable/tgroup/colspec
#      72   uitspraak/section/paragroup/informaltable/tgroup/tbody
#     412   uitspraak/section/paragroup/informaltable/tgroup/tbody/row
#    1629   uitspraak/section/paragroup/informaltable/tgroup/tbody/row/entry
#    1734   uitspraak/section/paragroup/informaltable/tgroup/tbody/row/entry/para
#     329   uitspraak/section/paragroup/informaltable/tgroup/tbody/row/entry/para/emphasis
#       1   uitspraak/section/paragroup/informaltable/tgroup/tbody/row/entry/para/footnote-ref
#     272   uitspraak/section/paragroup/itemizedlist
#    1085   uitspraak/section/paragroup/itemizedlist/listitem
#    1085   uitspraak/section/paragroup/itemizedlist/listitem/para
#      78   uitspraak/section/paragroup/itemizedlist/listitem/para/emphasis
#       9   uitspraak/section/paragroup/itemizedlist/listitem/para/footnote-ref
#      46   uitspraak/section/paragroup/mediaobject
#      46   uitspraak/section/paragroup/mediaobject/imageobject
#      46   uitspraak/section/paragroup/mediaobject/imageobject/imagedata
#   11924   uitspraak/section/paragroup/nr
#      56   uitspraak/section/paragroup/orderedlist
#     203   uitspraak/section/paragroup/orderedlist/listitem
#     203   uitspraak/section/paragroup/orderedlist/listitem/para
#      19   uitspraak/section/paragroup/orderedlist/listitem/para/emphasis
#       1   uitspraak/section/paragroup/orderedlist/listitem/para/footnote-ref
#   30279   uitspraak/section/paragroup/para
#    1283   uitspraak/section/paragroup/para/emphasis
#     645   uitspraak/section/paragroup/para/footnote-ref
#       2   uitspraak/section/paragroup/para/inlinemediaobject
#       2   uitspraak/section/paragroup/para/inlinemediaobject/imageobject
#       2   uitspraak/section/paragroup/para/inlinemediaobject/imageobject/imagedata
#    6810   uitspraak/section/paragroup/parablock
#   12033   uitspraak/section/paragroup/parablock/para
#    4883   uitspraak/section/paragroup/parablock/para/emphasis
#     327   uitspraak/section/paragroup/parablock/para/footnote-ref
#       1   uitspraak/section/paragroup/parablock/para/inlinemediaobject
#       1   uitspraak/section/paragroup/parablock/para/inlinemediaobject/imageobject
#       1   uitspraak/section/paragroup/parablock/para/inlinemediaobject/imageobject/imagedata
#     921   uitspraak/section/paragroup/paragroup
#       3   uitspraak/section/paragroup/paragroup/informaltable
#       3   uitspraak/section/paragroup/paragroup/informaltable/tgroup
#      12   uitspraak/section/paragroup/paragroup/informaltable/tgroup/colspec
#       3   uitspraak/section/paragroup/paragroup/informaltable/tgroup/tbody
#      24   uitspraak/section/paragroup/paragroup/informaltable/tgroup/tbody/row
#     102   uitspraak/section/paragroup/paragroup/informaltable/tgroup/tbody/row/entry
#     102   uitspraak/section/paragroup/paragroup/informaltable/tgroup/tbody/row/entry/para
#      22   uitspraak/section/paragroup/paragroup/itemizedlist
#      66   uitspraak/section/paragroup/paragroup/itemizedlist/listitem
#      66   uitspraak/section/paragroup/paragroup/itemizedlist/listitem/para
#      12   uitspraak/section/paragroup/paragroup/itemizedlist/listitem/para/emphasis
#      15   uitspraak/section/paragroup/paragroup/mediaobject
#      15   uitspraak/section/paragroup/paragroup/mediaobject/imageobject
#      15   uitspraak/section/paragroup/paragroup/mediaobject/imageobject/imagedata
#     920   uitspraak/section/paragroup/paragroup/nr
#       4   uitspraak/section/paragroup/paragroup/orderedlist
#      21   uitspraak/section/paragroup/paragroup/orderedlist/listitem
#      21   uitspraak/section/paragroup/paragroup/orderedlist/listitem/para
#    3038   uitspraak/section/paragroup/paragroup/para
#     233   uitspraak/section/paragroup/paragroup/para/emphasis
#      49   uitspraak/section/paragroup/paragroup/para/footnote-ref
#    1457   uitspraak/section/paragroup/paragroup/parablock
#    2801   uitspraak/section/paragroup/paragroup/parablock/para
#     951   uitspraak/section/paragroup/paragroup/parablock/para/emphasis
#     158   uitspraak/section/paragroup/paragroup/parablock/para/footnote-ref
#    4989   uitspraak/section/title
#       7   uitspraak/section/title/footnote-ref
#    2490   uitspraak/section/title/nr
#     647   uitspraak/uitspraak.info
#    1061   uitspraak/uitspraak.info/bridgehead
#       7   uitspraak/uitspraak.info/informaltable
#       7   uitspraak/uitspraak.info/informaltable/tgroup
#      14   uitspraak/uitspraak.info/informaltable/tgroup/colspec
#       7   uitspraak/uitspraak.info/informaltable/tgroup/tbody
#      19   uitspraak/uitspraak.info/informaltable/tgroup/tbody/row
#      38   uitspraak/uitspraak.info/informaltable/tgroup/tbody/row/entry
#      38   uitspraak/uitspraak.info/informaltable/tgroup/tbody/row/entry/para
#      10   uitspraak/uitspraak.info/itemizedlist
#      46   uitspraak/uitspraak.info/itemizedlist/listitem
#      46   uitspraak/uitspraak.info/itemizedlist/listitem/para
#       2   uitspraak/uitspraak.info/itemizedlist/listitem/para/emphasis
#       5   uitspraak/uitspraak.info/mediaobject
#       5   uitspraak/uitspraak.info/mediaobject/imageobject
#       5   uitspraak/uitspraak.info/mediaobject/imageobject/imagedata
#    6637   uitspraak/uitspraak.info/para
#     146   uitspraak/uitspraak.info/para/emphasis
#       3   uitspraak/uitspraak.info/para/footnote-ref
#     186   uitspraak/uitspraak.info/para/inlinemediaobject
#     186   uitspraak/uitspraak.info/para/inlinemediaobject/imageobject
#     186   uitspraak/uitspraak.info/para/inlinemediaobject/imageobject/imagedata
#    3972   uitspraak/uitspraak.info/parablock
#    7026   uitspraak/uitspraak.info/parablock/para
#    1526   uitspraak/uitspraak.info/parablock/para/emphasis
#      13   uitspraak/uitspraak.info/parablock/para/footnote-ref
#      18   uitspraak/uitspraak.info/paragroup
#      17   uitspraak/uitspraak.info/paragroup/nr
#      93   uitspraak/uitspraak.info/paragroup/para
#       2   uitspraak/uitspraak.info/paragroup/para/footnote-ref
#      47   uitspraak/uitspraak.info/paragroup/parablock
#      92   uitspraak/uitspraak.info/paragroup/parablock/para
#      83   uitspraak/uitspraak.info/paragroup/parablock/para/emphasis

# %% [markdown]
# ##
